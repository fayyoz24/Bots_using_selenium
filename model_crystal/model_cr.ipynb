# %%
import pandas as pd

df=pd.read_csv('Linkedin Profile Data.csv')
# Out:
# C:\Users\fayyo\AppData\Local\Temp\ipykernel_15148\196839525.py:3: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv('Linkedin Profile Data.csv')

# %%
df.columns
# Out:
# Index(['c_id', 'avg_time_in_previous_position', 'avg_current_position_length',
#        'avg_previous_position_length', 'm_urn', 'm_urn_id', 'no_of_promotions',
#        'no_of_previous_positions', 'current_position_length', 'age', 'beauty',
#        'beauty_female', 'beauty_male', 'blur', 'emo_anger', 'emp_disgust',
#        'emo_fear', 'emo_happiness', 'emo_neutral', 'emo_sadness',
#        'emo_surprise', 'ethnicity', 'gender', 'glass', 'head_pitch',
#        'head_roll', 'head_yaw', 'mouth_close', 'mouth_mask', 'mouth_open',
#        'mouth_other', 'skin_acne', 'skin_dark_circle', 'skin_health',
#        'skin_stain', 'smile', 'nationality', 'african', 'celtic_english',
#        'east_asian', 'european', 'greek', 'hispanic', 'jewish', 'muslim',
#        'nordic', 'south_asian', 'n_followers', 'face_quality'],
#       dtype='object')

# %%
len(df[df['gender']=='Female'])
# Out:
# 14925

# %%
import pandas as pd
df1=pd.read_csv('linkedin_data.csv', encoding='latin-1')

# %%
df1.columns
# Out:
# Index(['Unnamed: 0', 'avg_n_pos_per_prev_tenure', 'avg_pos_len',
#        'avg_prev_tenure_len', 'c_name', 'm_urn', 'n_pos', 'n_prev_tenures',
#        'tenure_len', 'age', 'beauty', 'beauty_female', 'beauty_male', 'blur',
#        'blur_gaussian', 'blur_motion', 'emo_anger', 'emo_disgust', 'emo_fear',
#        'emo_happiness', 'emo_neutral', 'emo_sadness', 'emo_surprise',
#        'ethnicity', 'face_quality', 'gender', 'glass', 'head_pitch',
#        'head_roll', 'head_yaw', 'img', 'mouth_close', 'mouth_mask',
#        'mouth_open', 'mouth_other', 'skin_acne', 'skin_dark_circle',
#        'skin_health', 'skin_stain', 'smile', 'african', 'celtic_english',
#        'east_asian', 'european', 'greek', 'hispanic', 'jewish', 'muslim',
#        'nationality', 'nordic', 'south_asian', 'n_followers'],
#       dtype='object')

# %%
df1.coulm

# %%
import requests

url = "https://linkedin-profiles1.p.rapidapi.com/extract"

querystring = {"url":"https://nl.linkedin.com/in/leon-goertz","html":"1"}

headers = {
	"X-RapidAPI-Key": "a2710d2793msha50e353bab1c00cp17eb91jsn1b9de68c7661",
	"X-RapidAPI-Host": "linkedin-profiles1.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)
res_json=response.json()
print(res_json['graph'])
# Out:
# {'@context': 'http://schema.org', '@graph': [{'@type': 'Person', 'address': {'@type': 'PostalAddress', 'addressLocality': 'Utrecht, Utrecht, Nederland', 'addressCountry': 'nl'}, 'alumniOf': [{'@type': 'Organization', 'name': 'Utrecht University', 'url': 'https://nl.linkedin.com/company/universiteit-utrecht?trk=ppro_cprof', 'member': {'@type': 'OrganizationRole', 'description': "Teaching a group of students and correcting assignments in the bachelor's course Fields and Galois Theory", 'startDate': '2022-09', 'endDate': '2022-11'}}, {'@type': 'Organization', 'name': 'Utrecht University', 'url': 'https://nl.linkedin.com/company/universiteit-utrecht?trk=ppro_cprof', 'member': {'@type': 'OrganizationRole', 'description': "Hybrid online/on-site teaching a group of students and correcting assignments and the exam in the bachelor's course Introduction to Groups and Rings", 'startDate': '2021-04', 'endDate': '2021-06'}}, {'@type': 'Organization', 'name': 'Utrecht University', 'url': 'https://
# ...

# %%
res_json.keys()
# Out:
# dict_keys(['graph', 'extractor', 'raw'])

# %%
res_json['graph']['@graph'][0]
# Out:
# {'@type': 'Person',
#  'address': {'@type': 'PostalAddress',
#   'addressLocality': 'Utrecht, Utrecht, Nederland',
#   'addressCountry': 'nl'},
#  'alumniOf': [{'@type': 'Organization',
#    'name': 'Utrecht University',
#    'url': 'https://nl.linkedin.com/company/universiteit-utrecht?trk=ppro_cprof',
#    'member': {'@type': 'OrganizationRole',
#     'description': "Teaching a group of students and correcting assignments in the bachelor's course Fields and Galois Theory",
#     'startDate': '2022-09',
#     'endDate': '2022-11'}},
#   {'@type': 'Organization',
#    'name': 'Utrecht University',
#    'url': 'https://nl.linkedin.com/company/universiteit-utrecht?trk=ppro_cprof',
#    'member': {'@type': 'OrganizationRole',
#     'description': "Hybrid online/on-site teaching a group of students and correcting assignments and the exam in the bachelor's course Introduction to Groups and Rings",
#     'startDate': '2021-04',
#     'endDate': '2021-06'}},
#   {'@type': 'Organization',
# ...

# %%
for i in range(0, len(res_json['graph']['@graph'][0]['alumniOf'])):
    a=res_json['graph']['@graph'][0]['alumniOf'][i]['member']['description']
    print(f'{i}--->{a}')
# Out:
# 0--->Teaching a group of students and correcting assignments in the bachelor's course Fields and Galois Theory
# 1--->Hybrid online/on-site teaching a group of students and correcting assignments and the exam in the bachelor's course Introduction to Groups and Rings
# 2--->Online teaching a group of students and correcting assignments in the bachelor's course Elementary Number Theory
# 3--->Specialization in Mathematical Sciences: Algebraic Topology, Category Theory, Differential Geometry<br>Specialization in Theoretical Physics: Quantum Field Theory and String Theory<br><br>Further electives include:<br>- Natural Language Processing<br>- Mathematical Neuroscience
# 4--->Elective courses: <br>- Deep Learning<br>- Artificial and Biological Neural Systems<br>- Mathematical Physics: Quantum Relativisitc Theories<br>- Italian Language B1
# ...

# %%
import requests
import pandas as pd
import datetime
import time

# %%
positions0=[]
positions1=[]
experinces0=[]
experinces1=[]
skills=[]
influencer=[]
country=[]
field_of_studies0=[]
field_of_studies1=[]
degrees0=[]
degrees1=[]
industries=[]
names=[]
summaries=[]
certifications=[]

# %%
# positions0.append(None)
# positions1.append(None)
experinces0.append(None)
experinces1.append(None)
skills.append(None)
influencer.append(None)
country.append(None)
field_of_studies0.append(None)
field_of_studies1.append(None)
degrees0.append(None)
degrees1.append(None)
industries.append(None)
names.append(None)

# %%
url = "https://api.iscraper.io/v2/profile-details"
# Set API key
headers = {
'X-API-KEY': 'hVSqiv11cY1W5YUawXUDLBn0jb4G5W44',
}
# Set payload
payload = {
'profile_id': 'ismatulla-kuyliev-43286a199',
}
# Get Response
resp = requests.post(url, json=payload, headers=headers)

# %%
positions0=[]
positions1=[]
experinces0=[]
experinces1=[]
skills=[]
influencer=[]
country=[]
field_of_studies0=[]
field_of_studies1=[]
degrees0=[]
degrees1=[]
industries=[]
names=[]
summaries=[]
certifications=[]

df = pd.read_csv('../linkedin_data_Scraping/datas/cs_values/    Liberal Arts and Science1.csv')
df = df.dropna().reset_index(drop=True)
for link in df['links']:
	id = link.split('/')[4]
	url = "https://api.iscraper.io/v2/profile-details"

	payload = {
		'profile_id': id,
	}

	headers = {
		'X-API-KEY': 'hVSqiv11cY1W5YUawXUDLBn0jb4G5W44',
	}

	response = requests.post(url, json=payload, headers=headers)
	res=response.json()
	try:
		skills.append(res['skills'])
	except:
		skills.append(None)
	position0=""
	try:
		position0=res['position_groups'][0]['profile_positions'][0]['title']
		positions0.append(position0)
	except:
		positions0.append(None)

	position1=""
	try:
		position1=res['position_groups'][1]['profile_positions'][0]['title']
		positions1.append(position1)
	except:
		positions1.append(None)

	experince0=0
	try:
		experince0=res['position_groups'][0]['date']['start']['year']-res['position_groups'][0]['date']['end']['year']
		experinces0.append(experince0)
	except:
		try:
			experince0=datetime.date.today().year - res['position_groups'][0]['date']['start']['year']
			experinces0.append(experince0)
		except:
			experinces0.append(None)

	experince1=0
	try:
		experince1=res['position_groups'][1]['date']['start']['year']-res['position_groups'][1]['date']['end']['year']
		experinces1.append(experince1)
	except:
		try:
			experince1=datetime.date.today().year - res['position_groups'][1]['date']['start']['year']
			experinces1.append(experince1)
		except:
			experinces1.append(None)
				
	try:
		influencer.append(res['influencer'])
	except:
		influencer.append(None)
	try:
		country.append(res['location']['country'])
	except:
		country.append(None)
	field_of_study0=""
	try:
		field_of_study0=res['education'][0]['field_of_study']
		field_of_studies0.append(field_of_study0)
	except:
		field_of_study0=None
		field_of_studies0.append(field_of_study0)

	field_of_study1=""
	try:
		field_of_study1=res['education'][1]['field_of_study']
		field_of_studies1.append(field_of_study1)
	except:
		field_of_study1=None
		field_of_studies1.append(field_of_study1)

	degree_name0=''
	try:
		degree_name0=res['education'][0]['degree_name']
		degrees0.append(degree_name0)
	except:
		degree_name0=None
		degrees0.append(degree_name0)

	degree_name1=''
	try:
		degree_name1=res['education'][1]['degree_name']
		degrees1.append(degree_name1)
	except:
		degree_name1=None
		degrees1.append(degree_name1)

	try:
		industries.append(res['industry'])
	except:
		industries.append(None)
	try:
		name=res['first_name']+" "+res['last_name']
		names.append(name)
	except:
		names.append(None)
	try:
		if len(res[certifications])==0:
			certifications.append(None)
		for certify in res['certifications']:
			certifications.append(certify['name'])
	except:
		certifications.append(None)
	try:
		summaries.append(res['summary'])
	except:
		summaries.append(None)
df2=pd.DataFrame({
	"name":names,
	'position 1':positions0,
	'position 2':positions1,
	"experince 1":experinces0,
	"experince 2":experinces1,
	"field of studies 1":field_of_studies0,
	"field of studies 2":field_of_studies1,
	"degree 1":degrees0,
	"degree 2":degrees1,
	"industry":industries,
	"certifications":certifications,
	"skills":skills,
	"influencer":influencer,
	"country":country,
	"summary":summaries
})
d = pd.concat([df,df2], axis=1)
d.to_csv('../linkedin_data_Scraping/datas/linkedin profiles/Liberal Arts and Science1.csv')
d
# Out:
#                                                 links       characters  \
# 0   https://nl.linkedin.com/in/babak-rezaeedaryake...  Stabilizer (SC)
# 1   https://nl.linkedin.com/in/eva-nieuwenhuijs-b0...  Harmonizer (IS)
# 2   https://nl.linkedin.com/in/milan-van-genderen-...     Planner (Sc)
# 3   https://nl.linkedin.com/in/shannen-chin-561488121  Encourager (Is)
# 4   https://nl.linkedin.com/in/jennifer-esch-74509...  Stabilizer (SC)
# 5   https://nl.linkedin.com/in/adele-beinaraviciut...  Encourager (Is)
# 6            https://nl.linkedin.com/in/ay-ling-thung     Planner (Sc)
# 7   https://nl.linkedin.com/in/max-michael-de-jong...  Stabilizer (SC)
# 8      https://nl.linkedin.com/in/rob-stuart-90408221   Counselor (Si)
# 9   https://nl.linkedin.com/in/arno-minasian-b7071...  Harmonizer (IS)
# 10         https://nl.linkedin.com/in/jarremiddeljans  Influencer (Id)
# 11   https://nl.linkedin.com/in/merijn-dorr-2427b11a1  Influencer (Id)
# ...

# %%
df
# Out:
# Empty DataFrame
# Columns: [links, characters]
# Index: []

# %%
d
# Out:
#                                                  links       characters  \
# 0    https://nl.linkedin.com/in/sijf-s-7956711b9?tr...     Skeptic (Cd)
# 1               https://nl.linkedin.com/in/koen-haenen      Analyst (C)
# 2    https://nl.linkedin.com/in/roderick-van-den-br...  Encourager (Is)
# 3    https://nl.linkedin.com/in/yentl-van-dop-077b9...   Counselor (Si)
# 4         https://nl.linkedin.com/in/merve-y-929035206  Encourager (Is)
# ..                                                 ...              ...
# 127     https://nl.linkedin.com/in/bas-pronk-b699161ba    Motivator (I)
# 128  https://nl.linkedin.com/in/charlotte-hoogers-6...     Planner (Sc)
# 129  https://nl.linkedin.com/in/remko-van-steen-732...      Analyst (C)
# 130  https://nl.linkedin.com/in/jasper-van-winkelho...      Editor (Cs)
# 131             https://nl.linkedin.com/in/tom-huibers      Editor (Cs)
#
#                        name  \
# 0                      None
# 1               Koen Haenen
# ...

# %%
df2=pd.DataFrame({
	"name":names,
	'position 1':positions0,
	'position 2':positions1,
	"experince 1":experinces0,
	"experince 2":experinces1,
	"field of studies 1":field_of_studies0,
	"field of studies 2":field_of_studies1,
	"degree 1":degrees0,
	"degree 2":degrees1,
	"industry":industries,
	"certifications":certifications,
	"skills":skills,
	"influencer":influencer,
	"country":country,
	"summary":summaries
})
d = pd.concat([df,df2], axis=1)
d.to_csv('../linkedin_data_Scraping/datas/linkedin profiles/second.csv')

# %%
len(names)
# Out:
# 63

# %%
len(certifications)
# Out:
# 45

# %%
df2=pd.DataFrame({
	"name":names,
	'position 1':positions0,
	'position 2':positions1,
	"experince 1":experinces0,
	"experince 2":experinces1,
	"field of studies 1":field_of_studies0,
	"field of studies 2":field_of_studies1,
	"degree 1":degrees0,
	"degree 2":degrees1,
	"industry":industries,
	# "certifications":certifications,
	"skills":skills,
	"influencer":influencer,
	"country":country,
	"summary":summaries
})

# %%
df = df.dropna(axis = 0)

# %%
df
# Out:
#                                                 links       characters
# 0   https://nl.linkedin.com/in/lishiana-van-dorpel...   Counselor (Si)
# 1   https://nl.linkedin.com/in/rosalie-farenhout-4...   Initiator (DI)
# 2   https://nl.linkedin.com/in/priscilla-bosma-b95...  Encourager (Is)
# 3   https://nl.linkedin.com/in/fabian-kuijf-0510b220a      Analyst (C)
# 4   https://nl.linkedin.com/in/martine-burgstaller...      Captain (D)
# 5            https://nl.linkedin.com/in/machteldpronk      Captain (D)
# 6   https://nl.linkedin.com/in/mees-clement-443ab7...   Initiator (DI)
# 7   https://nl.linkedin.com/in/maarten-ridderbos-3...  Encourager (Is)
# 8   https://nl.linkedin.com/in/luna-hammecher-8819...    Motivator (I)
# 9   https://nl.linkedin.com/in/jurre-de-boer-61bb0...  Encourager (Is)
# 12  https://nl.linkedin.com/in/naniek-scherpenzeel...  Influencer (Id)
# 13   https://nl.linkedin.com/in/ellen-sontag-28654b11  Encourager (Is)
# ...

# %%
d = pd.concat([df,df2], axis=1)

# %%
url = "https://linkedin-profiles-and-company-data.p.rapidapi.com/profile-details"

payload = {
    "profile_id": "martinastefanic",
    "profile_type": "personal",
    "contact_info": False,
    "recommendations": False,
    "related_profiles": False
}
headers = {
    "content-type": "application/json",
    "X-RapidAPI-Key": "a2710d2793msha50e353bab1c00cp17eb91jsn1b9de68c7661",
    "X-RapidAPI-Host": "linkedin-profiles-and-company-data.p.rapidapi.com"
}

response = requests.post(url, json=payload, headers=headers)
res=response.json()

# %%
import datetime

# %%
positions0=[]
position0=""
try:
    position0=res['position_groups'][0]['profile_positions'][0]['title']
    positions0.append(position0)
except:
    positions0.append(None)

positions1=[]
position1=""
try:
    position1=res['position_groups'][1]['profile_positions'][0]['title']
    positions1.append(position1)
except:
    positions1.append(None)


experinces0=[]
experince0=0
try:
    experince0=res['position_groups'][0]['date']['start']['year']-res['position_groups'][0]['date']['end']['year']
    experinces0.append(experince0)
except:
    experince0=datetime.date.today().year - res['position_groups'][0]['date']['start']['year']
    experinces0.append(experince0)

experinces1=[]
experince1=0
try:
    experince1=res['position_groups'][1]['date']['start']['year']-res['position_groups'][1]['date']['end']['year']
    experinces1.append(experince1)
except:
    experince1=datetime.date.today().year - res['position_groups'][1]['date']['start']['year']
    experinces1.append(experince1)

skills=[]
skills.append(res['skills'])

influencer=[]
influencer.append(res['influencer'])

country=[]
country.append(res['location']['country'])

field_of_studies0=[]
field_of_study0=""
try:
    field_of_study0=res['education'][0]['field_of_study']
    field_of_studies0.append(field_of_study0)
except:
    field_of_study0=None
    field_of_studies0.append(field_of_study0)


field_of_studies1=[]
field_of_study1=""
try:
    field_of_study1=res['education'][1]['field_of_study']
    field_of_studies1.append(field_of_study1)
except:
    field_of_study1=None
    field_of_studies1.append(field_of_study1)

degrees0=[]
degree_name0=''
try:
    degree_name0=res['education'][0]['degree_name']
    degrees0.append(degree_name0)
except:
    degree_name0=None
    degrees0.append(degree_name0)


degrees1=[]
degree_name1=''
try:
    degree_name1=res['education'][1]['degree_name']
    degrees1.append(degree_name1)
except:
    degree_name1=None
    degrees1.append(degree_name1)


industries=[]    
industries.append(res['industry'])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 res['position_groups'][0]['profile_positions'][2]['title']
#
# IndexError: list index out of range

# %%
import requests
# Set API URL
url = "https://api.iscraper.io/v2/profile-details"
# Set API key
headers = {
'X-API-KEY': 'ZB7DAMN753mSa71jBr6tBb83IOFfEeiI',
}
# Set payload
payload = {
'profile_id': 'williamhgates',
}
# Get Response
resp = requests.post(url, json=payload, headers=headers)

# %%
import requests
# Set API URL
url = "https://api.iscraper.io/v2/profile-details"
# Set API key
headers = {
'X-API-KEY': 'hVSqiv11cY1W5YUawXUDLBn0jb4G5W44',
}
# Set payload
payload = {
'profile_id': 'ismatulla-kuyliev-43286a199',
}
# Get Response
resp = requests.post(url, json=payload, headers=headers)

# %%
res=resp.json()

# %%
skills.append(res['skills'])
position0=""
try:
    position0=res['position_groups'][0]['profile_positions'][0]['title']
    positions0.append(position0)
except:
    positions0.append(None)

position1=""
try:
    position1=res['position_groups'][1]['profile_positions'][0]['title']
    positions1.append(position1)
except:
    positions1.append(None)


experince0=0
try:
    experince0=res['position_groups'][0]['date']['start']['year']-res['position_groups'][0]['date']['end']['year']
    experinces0.append(experince0)
except:
    try:
        experince0=datetime.date.today().year - res['position_groups'][0]['date']['start']['year']
        experinces0.append(experince0)
    except:
        experinces0.append(None)


experince1=0
try:
    experince1=res['position_groups'][1]['date']['start']['year']-res['position_groups'][1]['date']['end']['year']
    experinces1.append(experince1)
except:
    try:
        experince1=datetime.date.today().year - res['position_groups'][1]['date']['start']['year']
        experinces1.append(experince1)
    except:
        experinces1.append(None)
            

influencer.append(res['influencer'])

country.append(res['location']['country'])

field_of_study0=""
try:
    field_of_study0=res['education'][0]['field_of_study']
    field_of_studies0.append(field_of_study0)
except:
    field_of_study0=None
    field_of_studies0.append(field_of_study0)


field_of_study1=""
try:
    field_of_study1=res['education'][1]['field_of_study']
    field_of_studies1.append(field_of_study1)
except:
    field_of_study1=None
    field_of_studies1.append(field_of_study1)

degree_name0=''
try:
    degree_name0=res['education'][0]['degree_name']
    degrees0.append(degree_name0)
except:
    degree_name0=None
    degrees0.append(degree_name0)


degree_name1=''
try:
    degree_name1=res['education'][1]['degree_name']
    degrees1.append(degree_name1)
except:
    degree_name1=None
    degrees1.append(degree_name1)


industries.append(res['industry'])
name=res['first_name']+" "+res['last_name']
names.append(name)

summaries.append(res['summary'])


for certify in res['certifications']:
    certifications.append(certify['name'])
    print()

# %%
for certify in res['certifications']:
    print(certify['name'])
# Out:
# CSS Essential Training
# JavaScript Essential Training
# React.js Code Challenges
# React.js Essential Training

# %% [markdown]
# concatenating data

# %%
import pandas as pd

# %%
a1=pd.read_csv('../linkedin_data_Scraping/datas/linkedin profiles/   Literatuurwetenschap 1.csv')
a2=pd.read_csv('../linkedin_data_Scraping/datas/linkedin profiles/   Media and Culture1.csv')
a3=pd.read_csv('../linkedin_data_Scraping/datas/linkedin profiles/   Media and Information1.csv')
a4=pd.read_csv('../linkedin_data_Scraping/datas/linkedin profiles/   Media en Journalistiek1.csv')
a5=pd.read_csv('../linkedin_data_Scraping/datas/linkedin profiles/   Notarieel Recht1.csv')
a6=pd.read_csv('../linkedin_data_Scraping/datas/linkedin profiles/   Spaanse en Latijns-Amerikaanse studies1.csv')
a7=pd.read_csv('../linkedin_data_Scraping/datas/linkedin profiles/   Taalwetenschap1.csv')
a8=pd.read_csv('../linkedin_data_Scraping/datas/linkedin profiles/  Media and Culture1.csv')
a9=pd.read_csv('../linkedin_data_Scraping/datas/linkedin profiles/  Media en cultuur1.csv')
a10=pd.read_csv('../linkedin_data_Scraping/datas/linkedin profiles/  Media, Art, Design and Architecture1.csv')
a11=pd.read_csv('../linkedin_data_Scraping/datas/linkedin profiles/  Medische informatiekunde1.csv')
a12=pd.read_csv('../linkedin_data_Scraping/datas/linkedin profiles/  Onderwijswetenschappen1.csv')

# %%
concat([df,df2], axis=1)

# %%
df4=pd.concat([a1,a2], axis=0, ignore_index=True)

# %%
a1=pd.read_csv('../linkedin_data_Scraping/datas/linkedin profiles/   Literatuurwetenschap 1.csv')
a2=pd.read_csv('../linkedin_data_Scraping/datas/linkedin profiles/   Media and Culture1.csv')
a3=pd.read_csv('../linkedin_data_Scraping/datas/linkedin profiles/   Media and Information1.csv')
a4=pd.read_csv('../linkedin_data_Scraping/datas/linkedin profiles/   Media en Journalistiek1.csv')
a5=pd.read_csv('../linkedin_data_Scraping/datas/linkedin profiles/   Notarieel Recht1.csv')
a6=pd.read_csv('../linkedin_data_Scraping/datas/linkedin profiles/   Spaanse en Latijns-Amerikaanse studies1.csv')
a7=pd.read_csv('../linkedin_data_Scraping/datas/linkedin profiles/   Taalwetenschap1.csv')
a8=pd.read_csv('../linkedin_data_Scraping/datas/linkedin profiles/  Media and Culture1.csv')
a9=pd.read_csv('../linkedin_data_Scraping/datas/linkedin profiles/  Media en cultuur1.csv')
a10=pd.read_csv('../linkedin_data_Scraping/datas/linkedin profiles/  Media, Art, Design and Architecture1.csv')
a=pd.read_csv('../linkedin_data_Scraping/datas/linkedin profiles/  Medische informatiekunde1.csv')
a=pd.read_csv('../linkedin_data_Scraping/datas/linkedin profiles/  Onderwijswetenschappen1.csv')
a=pd.read_csv('../linkedin_data_Scraping/datas/linkedin profiles/  Oudheidwetenschappen1.csv')
a=pd.read_csv('../linkedin_data_Scraping/datas/linkedin profiles/  Rechtsgeleerdheid1.csv')
a=pd.read_csv('../linkedin_data_Scraping/datas/linkedin profiles/  Religiewetenschappen1.csv')
a=pd.read_csv('../linkedin_data_Scraping/datas/linkedin profiles/  Tandheelkunde1.csv')
a=pd.read_csv('../linkedin_data_Scraping/datas/linkedin profiles/  Theology1.csv')
a=pd.read_csv('../linkedin_data_Scraping/datas/linkedin profiles/ Linguistics1.csv')
a=pd.read_csv('../linkedin_data_Scraping/datas/linkedin profiles/ Media, Kunst, Design en Architectuur1.csv')
a=pd.read_csv('../linkedin_data_Scraping/datas/linkedin profiles/ Muziekwetenschap1.csv')
a=pd.read_csv('../linkedin_data_Scraping/datas/linkedin profiles/ Natuur- en Sterrenkunde1.csv')
a=pd.read_csv('../linkedin_data_Scraping/datas/linkedin profiles/ Nederlandse taal en cultuur1.csv')
a=pd.read_csv('../linkedin_data_Scraping/datas/linkedin profiles/ Nieuwgriekse taal en cultuur1.csv')
a=pd.read_csv('../linkedin_data_Scraping/datas/linkedin profiles/ Pedagogische wetenschappen1.csv')
a=pd.read_csv('../linkedin_data_Scraping/datas/linkedin profiles/ Philosophy, Politics and Economics1.csv')
a=pd.read_csv('../linkedin_data_Scraping/datas/linkedin profiles/ Political Science and Economics1.csv')
a=pd.read_csv('../linkedin_data_Scraping/datas/linkedin profiles/ Political Science1.csv')
a=pd.read_csv('../linkedin_data_Scraping/datas/linkedin profiles/ Russische en Slavische studies1.csv')
a=pd.read_csv('../linkedin_data_Scraping/datas/linkedin profiles/ Scandinavië studies1.csv')
a=pd.read_csv('../linkedin_data_Scraping/datas/linkedin profiles/ Scheikunde1.csv')
a=pd.read_csv('../linkedin_data_Scraping/datas/linkedin profiles/ Sociology1.csv')
a=pd.read_csv('../linkedin_data_Scraping/datas/linkedin profiles/ Theaterwetenschap1.csv')
a=pd.read_csv('../linkedin_data_Scraping/datas/linkedin profiles/ Universitaire Pabo van Amsterdam1.csv')
a=pd.read_csv('../linkedin_data_Scraping/datas/linkedin profiles/ Universitaire Pabo1.csv')
a=pd.read_csv('../linkedin_data_Scraping/datas/linkedin profiles/Aarde, Economie en Duurzaamheid1.csv')
a=pd.read_csv('../linkedin_data_Scraping/datas/linkedin profiles/Aardewetenschappen1.csv')
a=pd.read_csv('../linkedin_data_Scraping/datas/linkedin profiles/Actuarial Science1.csv')
a=pd.read_csv('../linkedin_data_Scraping/datas/linkedin profiles/Actuariële Wetenschappen1.csv')
a=pd.read_csv('../linkedin_data_Scraping/datas/linkedin profiles/Ancient sciences1.csv')
a=pd.read_csv('../linkedin_data_Scraping/datas/linkedin profiles/Ancient studies1.csv')
a=pd.read_csv('../linkedin_data_Scraping/datas/linkedin profiles/Arabische taal en cultuur1.csv')
a=pd.read_csv('../linkedin_data_Scraping/datas/linkedin profiles/Archeologie1.csv')
a=pd.read_csv('../linkedin_data_Scraping/datas/linkedin profiles/art-history_cs.csv')
a=pd.read_csv('../linkedin_data_Scraping/datas/linkedin profiles/Artificial Intelligence1.csv')
a=pd.read_csv('../linkedin_data_Scraping/datas/linkedin profiles/Bedrijfskunde1.csv')
a=pd.read_csv('../linkedin_data_Scraping/datas/linkedin profiles/Bestuurs- en organistatiewetenschap1.csv')
a=pd.read_csv('../linkedin_data_Scraping/datas/linkedin profiles/Beta-gamma.csv')
a=pd.read_csv('../linkedin_data_Scraping/datas/linkedin profiles/biochemistry.csv')
a=pd.read_csv('../linkedin_data_Scraping/datas/linkedin profiles/biology.csv')
a=pd.read_csv('../linkedin_data_Scraping/datas/linkedin profiles/biomedical-science.csv')
a=pd.read_csv('../linkedin_data_Scraping/datas/linkedin profiles/Biomedische wetenschappen1.csv')
a=pd.read_csv('../linkedin_data_Scraping/datas/linkedin profiles/Business administration.csv')
a=pd.read_csv('../linkedin_data_Scraping/datas/linkedin profiles/Business Analytics1.csv')
a=pd.read_csv('../linkedin_data_Scraping/datas/linkedin profiles/chemistry.csv')
a=pd.read_csv('../linkedin_data_Scraping/datas/linkedin profiles/Cognition, Language and Communication1.csv')
a=pd.read_csv('../linkedin_data_Scraping/datas/linkedin profiles/Communicatie- en informatiewetenschappen1.csv')
a=pd.read_csv('../linkedin_data_Scraping/datas/linkedin profiles/Communicatiewetenschap1.csv')
a=pd.read_csv('../linkedin_data_Scraping/datas/linkedin profiles/Communication and Information Studies1.csv')
a=pd.read_csv('../linkedin_data_Scraping/datas/linkedin profiles/Communication Social Science1.csv')
a=pd.read_csv('../linkedin_data_Scraping/datas/linkedin profiles/Computational Social Science (Data- en sociale wetenschap)1.csv')
a=pd.read_csv('../linkedin_data_Scraping/datas/linkedin profiles/Computational Social Science1.csv')
a=pd.read_csv('../linkedin_data_Scraping/datas/linkedin profiles/computer-science.csv')
a=pd.read_csv('../linkedin_data_Scraping/datas/linkedin profiles/Criminologie1.csv')
a=pd.read_csv('../linkedin_data_Scraping/datas/linkedin profiles/Cultural anthropology and Development Sociology1.csv')
a=pd.read_csv('../linkedin_data_Scraping/datas/linkedin profiles/Culturele antropologie en Ontwikkelingssociolgie1.csv')
a=pd.read_csv('../linkedin_data_Scraping/datas/linkedin profiles/Culturele antropologie en ontwikkelingssociologie 1.csv')
a=pd.read_csv('../linkedin_data_Scraping/datas/linkedin profiles/Cultuurwetenschappen1.csv')
a=pd.read_csv('../linkedin_data_Scraping/datas/linkedin profiles/Duitse Taal en Cultuur1.csv')
a=pd.read_csv('../linkedin_data_Scraping/datas/linkedin profiles/Duitslandstudies1.csv')
a=pd.read_csv('../linkedin_data_Scraping/datas/linkedin profiles/Econometrics and Business economics1.csv')
a=pd.read_csv('../linkedin_data_Scraping/datas/linkedin profiles/Econometrie en Operationele Research1.csv')
a=pd.read_csv('../linkedin_data_Scraping/datas/linkedin profiles/Econometrie1.csv')
a=pd.read_csv('../linkedin_data_Scraping/datas/linkedin profiles/Economics and Business Economics1.csv')
a=pd.read_csv('../linkedin_data_Scraping/datas/linkedin profiles/Economie en Bedrijfskunde1.csv')
a=pd.read_csv('../linkedin_data_Scraping/datas/linkedin profiles/Englisch language and Culture1.csv')
a=pd.read_csv('../linkedin_data_Scraping/datas/linkedin profiles/English Language and Communication Studies1.csv')
a=pd.read_csv('../linkedin_data_Scraping/datas/linkedin profiles/english-literature.csv')
a=pd.read_csv('../linkedin_data_Scraping/datas/linkedin profiles/European Studies1.csv')
a=pd.read_csv('../linkedin_data_Scraping/datas/linkedin profiles/Farmaceutische Wetenschappen1.csv')
a=pd.read_csv('../linkedin_data_Scraping/datas/linkedin profiles/Filosofie1.csv')
a=pd.read_csv('../linkedin_data_Scraping/datas/linkedin profiles/Fiscaal recht1.csv')
a=pd.read_csv('../linkedin_data_Scraping/datas/linkedin profiles/Franse taal en cultuur1.csv')
a=pd.read_csv('../linkedin_data_Scraping/datas/linkedin profiles/Future Planet Studies1.csv')
a=pd.read_csv('../linkedin_data_Scraping/datas/linkedin profiles/Geneeskunde 1.csv')
a=pd.read_csv('../linkedin_data_Scraping/datas/linkedin profiles/Geschiedenis1.csv')
a=pd.read_csv('../linkedin_data_Scraping/datas/linkedin profiles/Gezondheidswetenschappen1.csv')
a=pd.read_csv('../linkedin_data_Scraping/datas/linkedin profiles/Global Arts, Culture and Politics 1.csv')
a=pd.read_csv('../linkedin_data_Scraping/datas/linkedin profiles/Griekse en Latijnse taal en cultuur1.csv')
a=pd.read_csv('../linkedin_data_Scraping/datas/linkedin profiles/History and International Studies1.csv')
a=pd.read_csv('../linkedin_data_Scraping/datas/linkedin profiles/history.csv')
a=pd.read_csv('../linkedin_data_Scraping/datas/linkedin profiles/Informatica1.csv')
a=pd.read_csv('../linkedin_data_Scraping/datas/linkedin profiles/Informatiekunde1.csv')
a=pd.read_csv('../linkedin_data_Scraping/datas/linkedin profiles/Interdisciplinaire sociale wetenschap1.csv')
a=pd.read_csv('../linkedin_data_Scraping/datas/linkedin profiles/Interdisciplinaire sociale wetenschap1.csv')
a=pd.read_csv('../linkedin_data_Scraping/datas/linkedin profiles/International Business Administration1.csv')
a=pd.read_csv('../linkedin_data_Scraping/datas/linkedin profiles/Italië studies1.csv')
a=pd.read_csv('../linkedin_data_Scraping/datas/linkedin profiles/Kunstgeschiedenis1.csv')
a=pd.read_csv('../linkedin_data_Scraping/datas/linkedin profiles/Kunstmatige intelligentie1.csv')
a=pd.read_csv('../linkedin_data_Scraping/datas/linkedin profiles/Language Learning and Language Teaching1.csv')
a=pd.read_csv('../linkedin_data_Scraping/datas/linkedin profiles/Law in Society1.csv')
a=pd.read_csv('../linkedin_data_Scraping/datas/linkedin profiles/Liberal Arts and Science1.csv')
a=pd.read_csv('../linkedin_data_Scraping/datas/linkedin profiles/Literature and Society1.csv')
a=pd.read_csv('../linkedin_data_Scraping/datas/linkedin profiles/Nieuwgriekse taal en cultuur1.csv')
a=pd.read_csv('../linkedin_data_Scraping/datas/linkedin profiles/physics.csv')
a=pd.read_csv('../linkedin_data_Scraping/datas/linkedin profiles/Politicologie1.csv')
a=pd.read_csv('../linkedin_data_Scraping/datas/linkedin profiles/Politics, Psychology, Law and Economics (PPLE)1.csv')
a=pd.read_csv('../linkedin_data_Scraping/datas/linkedin profiles/Psychobiologie1.csv')
a=pd.read_csv('../linkedin_data_Scraping/datas/linkedin profiles/Sign Language Linguistics1.csv')
a=pd.read_csv('../linkedin_data_Scraping/datas/linkedin profiles/Sociale geografie en Planologie1.csv')
a=pd.read_csv('../linkedin_data_Scraping/datas/linkedin profiles/Wiskunde1.csv')
a=pd.read_csv('../linkedin_data_Scraping/datas/linkedin profiles/')
