# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense, Dropout

# Load and preprocess data
data = pd.read_csv('valuable_data_lastone.csv')
text_cols = ['position 1', 'position 2', 'experince 1', 'experince 2', 
             'field of studies 1', 'field of studies 2', 'degree 1', 
             'degree 2', 'industry', 'skills', 'influencer', 'country', 'summary']

data[text_cols] = data[text_cols].fillna("Unknown")

# Convert all columns to string type
for col in text_cols:
    data[col] = data[col].astype(str)

text_data = data[text_cols].apply(lambda x: ' '.join(x), axis=1).tolist()
labels = data['characters'].tolist()

# Tokenize and pad sequences
tokenizer = Tokenizer()
tokenizer.fit_on_texts(text_data)
sequences = tokenizer.texts_to_sequences(text_data)
max_sequence_length = max(len(seq) for seq in sequences)
padded_sequences = pad_sequences(sequences, maxlen=max_sequence_length)

# Split data
X_train_text, X_test_text, y_train, y_test = train_test_split(
    padded_sequences, labels, test_size=0.1, random_state=42)

# Define and compile the model
model = Sequential([
    Embedding(len(tokenizer.word_index) + 1, 100, input_length=max_sequence_length),
    LSTM(100, dropout=0.2, recurrent_dropout=0.2),
    Dense(64, activation='relu'),
    Dropout(0.5),
    Dense(1, activation='sigmoid')  # Use 'sigmoid' for binary classification
])

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train the model
model.fit(X_train_text, y_train, validation_data=(X_test_text, y_test),
          epochs=10, batch_size=32)

# Save the model
model.save('simplified_regularized_model.h5')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[69], line 47
#      44 model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
#      46 # Train the model
# ---> 47 model.fit(X_train_text, y_train, validation_data=(X_test_text, y_test),
#      48           epochs=10, batch_size=32)
#      50 # Save the model
#      51 model.save('simplified_regularized_model.h5')
#
# File c:\Users\fayyo\.conda\envs\keras1\lib\site-packages\keras\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File c:\Users\fayyo\.conda\envs\keras1\lib\site-packages\keras\engine\data_adapter.py:1083, in select_data_adapter(x, y)
#    1080 adapter_cls = [cls for cls in ALL_ADAPTER_CLS if cls.can_handle(x, y)]
#    1081 if not adapter_cls:
#    1082     # TODO(scottzhu): This should be a less implementation-specific error.
# -> 1083     raise ValueError(
#    1084         "Failed to find data adapter that can handle "
#    1085         "input: {}, {}".format(_type_name(x), _type_name(y))
#    1086     )
#    1087 elif len(adapter_cls) > 1:
#    1088     raise RuntimeError(
#    1089         "Data adapters should be mutually exclusive for "
#    1090         "handling inputs. Found multiple adapters {} to handle "
#    1091         "input: {}, {}".format(adapter_cls, _type_name(x), _type_name(y))
#    1092     )
#
# ValueError: Failed to find data adapter that can handle input: <class 'numpy.ndarray'>, (<class 'list'> containing values of types {"<class 'str'>"})

# %%
import requests
import pandas as pd
import datetime
import csv

positions0=[]
positions1=[]
experinces0=[]
experinces1=[]
skills=[]
influencer=[]
country=[]
field_of_studies0=[]
field_of_studies1=[]
degrees0=[]
degrees1=[]
industries=[]
names=[]
summaries=[]
certifications=[]
# model_crystal\datas\13000_profiles_without_duplicates.csv
df = pd.read_csv('../model_crystal/datas/13000_profiles_without_duplicates.csv')
for csv in range(10):
	res=pd.read_csv(f'../model_crystal/datas/responses/{csv}.csv')
	
	try:
		skills.append(res['skills'])
	except:
		skills.append(None)
	try:
		position0=res['position_groups'][0]['profile_positions'][0]['title']
		print(position0)
		positions0.append(position0)
	except:
		positions0.append(None)

	try:
		position1=res['position_groups'][1]['profile_positions'][0]['title']
		positions1.append(position1)
	except:
		positions1.append(None)

	experince0=0
	try:
		experince0=res['position_groups'][0]['date']['start']['year']-res['position_groups'][0]['date']['end']['year']
		experinces0.append(abs(experince0))
	except:
		try:
			experince0=datetime.date.today().year - res['position_groups'][0]['date']['start']['year']
			experinces0.append(abs(experince0))
		except:
			experinces0.append(None)

	experince1=0
	try:
		experince1=res['position_groups'][1]['date']['start']['year']-res['position_groups'][1]['date']['end']['year']
		experinces1.append(abs(experince1))
	except:
		try:
			experince1=datetime.date.today().year - res['position_groups'][1]['date']['start']['year']
			experinces1.append(abs(experince1))
		except:
			experinces1.append(None)
				
	try:
		influencer.append(res['influencer'])
	except:
		influencer.append(None)
	try:
		country.append(res['location']['country'])
	except:
		country.append(None)
	field_of_study0=""
	try:
		field_of_study0=res['education'][0]['field_of_study']
		field_of_studies0.append(field_of_study0)
	except:
		field_of_study0=None
		field_of_studies0.append(field_of_study0)

	try:
		field_of_study1=res['education'][1]['field_of_study']
		field_of_studies1.append(field_of_study1)
	except:
		field_of_study1=None
		field_of_studies1.append(field_of_study1)

	try:
		degree_name0=res['education'][0]['degree_name']
		degrees0.append(degree_name0)
	except:
		degree_name0=None
		degrees0.append(degree_name0)

	try:
		degree_name1=res['education'][1]['degree_name']
		degrees1.append(degree_name1)
	except:
		degree_name1=None
		degrees1.append(degree_name1)

	try:
		industries.append(res['industry'])
	except:
		industries.append(None)
	try:
		name=res['first_name']+" "+res['last_name']
		names.append(name)
		print(name)
	except:
		names.append(None)
	try:
		if len(res[certifications])==0:
			certifications.append(None)
		for certify in res['certifications']:
			certifications.append(certify['name'])
	except:
		certifications.append(None)
	try:
		summaries.append(res['summary'])
	except:
		summaries.append(None)

df2=pd.DataFrame({
	"name":names,
	'position 1':positions0,
	'position 2':positions1,
	"experince 1":experinces0,
	"experince 2":experinces1,
	"field of studies 1":field_of_studies0,
	"field of studies 2":field_of_studies1,
	"degree 1":degrees0,
	"degree 2":degrees1,
	"industry":industries,
	"certifications":certifications,
	"skills":skills,
	"influencer":influencer,
	"country":country,
	"summary":summaries,
})
d = pd.concat([df, df2], axis=1)
d.to_csv('valuable_data_last.csv')
# Out:
# 0    Laurel Rohloff
# dtype: object
# 0    Merel Keijzer
# dtype: object
# 0    Amy MacGregor
# dtype: object
# 0    Sarah Johnson
# dtype: object
# 0    Annemarie Voyce
# dtype: object
# 0    Elise Adayme
# dtype: object
# 0    Aidan Quinn
# dtype: object
# 0    Megan Hershey
# dtype: object
# 0    Andreea (Andi) Dumitru
# dtype: object
# 0    Claire Niven
# dtype: object
# max_sequence------>>>>519
# 1/1 [==============================] - 1s 1s/step
# Text: Frontend mentor 	Predicted Label: Analyst (C)
# Text: Javascript Developer	Predicted Label: Driver (Di);
# Text: 0	Predicted Label: Analyst (C)
# Text: Petroleum Engineering	Predicted Label: Captain (D)
# Text: Oil and Gas	Predicted Label: Analyst (C)
# Text: Master of Science - MS	Predicted Label: Driver (Di);
# Text: Bachelor's degree	Predicted Label: Analyst (C)
# Text: Computer Software	Predicted Label: Encourager (Is)
# Text: ['Next.js', 'Python (Programming Language)', 'Django', 'REST APIs', 'Problem Solving', 'Responsive Web Design', 'Front-End Development', 'Firebase', 'Web Development', 'Communication', 'Contract Negotiation', 'Construction', 'Management', 'Analytical Skills', 'Software as a Service (SaaS)', 'Translation', 'Technical Translation', 'English Translation', 'Russian Translation', 'Redux.js']	Predicted Label: Counselor (Si)
# Text: Highly skilled Frontend Developer with over 1.5 years of experience in HTML5, CSS3, JavaScript, Reactjs,Nextjs,TypeScript, Redux Toolkit, MaterialUI, TailwindCSS, Materialize UI, and Bootstrap.	Predicted Label: Motivator (I)
# Analyst (C)

# %%
df2
# Out:
#                                         name position 1 position 2  \
# 0          0    Laurel Rohloff
# dtype: object       None       None
# 1           0    Merel Keijzer
# dtype: object       None       None
# 2           0    Amy MacGregor
# dtype: object       None       None
# 3           0    Sarah Johnson
# dtype: object       None       None
# 4         0    Annemarie Voyce
# dtype: object       None       None
# 5            0    Elise Adayme
# dtype: object       None       None
# 6             0    Aidan Quinn
# dtype: object       None       None
# 7           0    Megan Hershey
# dtype: object       None       None
# 8  0    Andreea (Andi) Dumitru
# dtype: object       None       None
# 9            0    Claire Niven
# dtype: object       None       None
#
#   experince 1 experince 2 field of studies 1 field of studies 2 degree 1  \
# 0        None        None               None               None     None
# 1        None        None               None               None     None
# 2        None        None               None               None     None
# 3        None        None               None               None     None
# 4        None        None               None               None     None
# 5        None        None               None               None     None
# 6        None        None               None               None     None
# 7        None        None               None               None     None
# 8        None        None               None               None     None
# 9        None        None               None               None     None
#
#   degree 2                                           industry certifications  \
# 0     None  0    Primary/Secondary Education
# Name: industr...           None
# 1     None        0    Research
# Name: industry, dtype: object           None
# 2     None  0    Marketing & Advertising
# Name: industry, d...           None
# 3     None  0    Higher Education
# Name: industry, dtype: o...           None
# 4     None  0    Higher Education
# Name: industry, dtype: o...           None
# 5     None  0    Translation & Localization
# Name: industry...           None
# 6     None  0    Primary/Secondary Education
# Name: industr...           None
# 7     None  0    Translation & Localization
# Name: industry...           None
# 8     None  0    Professional Training & Coaching
# Name: in...           None
# 9     None  0    Translation & Localization
# Name: industry...           None
#
#                                               skills  \
# 0  0    ['Parler en public', 'Réseaux sociaux', '...
# 1  0    ['Statistical Analysis of fMRI Data', 'St...
# 2  0    ['Proofreading', 'Press Releases', 'Publi...
# 3  0    ['Public Speaking', 'Coaching', 'Teaching...
# 4  0    ['Business English', 'Secondary Education...
# 5  0    ['Translation', 'English', 'French', 'Pre...
# 6  0    ['Public Speaking', 'Research', 'Manageme...
# 7  0    ['Translation', 'English', 'Dutch', 'Text...
# 8  0    ['E-Learning', 'Blended Learning', 'Leade...
# 9  0    ['Translation', 'Copy Editing', 'English ...
#
#                                  influencer country  \
# 0  0    False
# Name: influencer, dtype: bool    None
# 1  0    False
# Name: influencer, dtype: bool    None
# 2  0    False
# Name: influencer, dtype: bool    None
# 3  0    False
# Name: influencer, dtype: bool    None
# 4  0    False
# Name: influencer, dtype: bool    None
# 5  0    False
# Name: influencer, dtype: bool    None
# 6  0    False
# Name: influencer, dtype: bool    None
# 7  0    False
# Name: influencer, dtype: bool    None
# 8  0    False
# Name: influencer, dtype: bool    None
# 9  0    False
# Name: influencer, dtype: bool    None
#
#                                              summary
# 0              0   NaN
# Name: summary, dtype: float64
# 1  0    I am a second language development and bi...
# 2  0    English teacher with 5 years experience w...
# 3  0    Over a period of more than 10 years of la...
# 4  0    I previously worked as a secondary school...
# 5  0    Experienced freelance translator and inte...
# 6  0    I am a qualified secondary school teacher...
# 7  0    I’m a professional Dutch-to-English trans...
# 8  0    Does your speech resonate with your peers...
# 9  0    You want your English copy to sound as go...

# %%
d
# Out:
#        Unnamed: 0.1  Unnamed: 0                names  \
# 0                 0         0.0       Laurel Rohloff
# 1                 1         1.0        Merel Keijzer
# 2                 2         2.0        Amy Macgregor
# 3                 3         3.0        Sarah Johnson
# 4                 4         4.0           Anne Voyce
# ...             ...         ...                  ...
# 13086         13086         NaN      Tosin Obayuwana
# 13087         13087         NaN  Carolina Montenegro
# 13088         13088         NaN  Cristyna Montenegro
# 13089         13089         NaN    Lorena Montenegro
# 13090         13090         NaN     Anna Wiesenhofer
#
#                                                    links       characters  \
# 0      https://www.linkedin.com/in/laurel-rohloff-a52...   Counselor (Si)
# 1      https://www.linkedin.com/in/merel-keijzer-7263...  Influencer (Id)
# 2      https://www.linkedin.com/in/amy-macgregor-5325...    Supporter (S)
# 3      https://www.linkedin.com/in/sarah-johnson-54a4...  Influencer (Id)
# 4                     https://www.linkedin.com/in/avoyce    Motivator (I)
# ...                                                  ...              ...
# 13086  https://www.linkedin.com/in/tosin-obayuwana-a3...   Initiator (DI)
# 13087  https://www.linkedin.com/in/carolina-montenegr...  Encourager (Is)
# 13088     https://www.linkedin.com/in/cristynamontenegro      Analyst (C)
# 13089  https://www.linkedin.com/in/lorena-montenegro-...      Editor (Cs)
# 13090  https://www.linkedin.com/in/anna-maria-montene...      Editor (Cs)
#
#                                      name position 1 position 2 experince 1  \
# 0       0    Laurel Rohloff
# dtype: object       None       None        None
# 1        0    Merel Keijzer
# dtype: object       None       None        None
# 2        0    Amy MacGregor
# dtype: object       None       None        None
# 3        0    Sarah Johnson
# dtype: object       None       None        None
# 4      0    Annemarie Voyce
# dtype: object       None       None        None
# ...                                   ...        ...        ...         ...
# 13086                                 NaN        NaN        NaN         NaN
# 13087                                 NaN        NaN        NaN         NaN
# 13088                                 NaN        NaN        NaN         NaN
# 13089                                 NaN        NaN        NaN         NaN
# 13090                                 NaN        NaN        NaN         NaN
#
#       experince 2 field of studies 1 field of studies 2 degree 1 degree 2  \
# 0            None               None               None     None     None
# 1            None               None               None     None     None
# 2            None               None               None     None     None
# 3            None               None               None     None     None
# 4            None               None               None     None     None
# ...           ...                ...                ...      ...      ...
# 13086         NaN                NaN                NaN      NaN      NaN
# 13087         NaN                NaN                NaN      NaN      NaN
# 13088         NaN                NaN                NaN      NaN      NaN
# 13089         NaN                NaN                NaN      NaN      NaN
# 13090         NaN                NaN                NaN      NaN      NaN
#
#                                                 industry certifications  \
# 0      0    Primary/Secondary Education
# Name: industr...           None
# 1            0    Research
# Name: industry, dtype: object           None
# 2      0    Marketing & Advertising
# Name: industry, d...           None
# 3      0    Higher Education
# Name: industry, dtype: o...           None
# 4      0    Higher Education
# Name: industry, dtype: o...           None
# ...                                                  ...            ...
# 13086                                                NaN            NaN
# 13087                                                NaN            NaN
# 13088                                                NaN            NaN
# 13089                                                NaN            NaN
# 13090                                                NaN            NaN
#
#                                                   skills  \
# 0      0    ['Parler en public', 'Réseaux sociaux', '...
# 1      0    ['Statistical Analysis of fMRI Data', 'St...
# 2      0    ['Proofreading', 'Press Releases', 'Publi...
# 3      0    ['Public Speaking', 'Coaching', 'Teaching...
# 4      0    ['Business English', 'Secondary Education...
# ...                                                  ...
# 13086                                                NaN
# 13087                                                NaN
# 13088                                                NaN
# 13089                                                NaN
# 13090                                                NaN
#
#                                      influencer country  \
# 0      0    False
# Name: influencer, dtype: bool    None
# 1      0    False
# Name: influencer, dtype: bool    None
# 2      0    False
# Name: influencer, dtype: bool    None
# 3      0    False
# Name: influencer, dtype: bool    None
# 4      0    False
# Name: influencer, dtype: bool    None
# ...                                         ...     ...
# 13086                                       NaN     NaN
# 13087                                       NaN     NaN
# 13088                                       NaN     NaN
# 13089                                       NaN     NaN
# 13090                                       NaN     NaN
#
#                                                  summary
# 0                  0   NaN
# Name: summary, dtype: float64
# 1      0    I am a second language development and bi...
# 2      0    English teacher with 5 years experience w...
# 3      0    Over a period of more than 10 years of la...
# 4      0    I previously worked as a secondary school...
# ...                                                  ...
# 13086                                                NaN
# 13087                                                NaN
# 13088                                                NaN
# 13089                                                NaN
# 13090                                                NaN
#
# [13091 rows x 20 columns]

# %%
df=pd.read_csv('../model_crystal/valuable_data_last.csv')

# %%
res['position_groups'][0]['profile_positions'][0]['title']
# Out:
# 'Frontend mentor '

# %%
df
# Out:
#        Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0                names  \
# 0                 0             0         0.0       Laurel Rohloff
# 1                 1             1         1.0        Merel Keijzer
# 2                 2             2         2.0        Amy Macgregor
# 3                 3             3         3.0        Sarah Johnson
# 4                 4             4         4.0           Anne Voyce
# ...             ...           ...         ...                  ...
# 13086         13086         13086         NaN      Tosin Obayuwana
# 13087         13087         13087         NaN  Carolina Montenegro
# 13088         13088         13088         NaN  Cristyna Montenegro
# 13089         13089         13089         NaN    Lorena Montenegro
# 13090         13090         13090         NaN     Anna Wiesenhofer
#
#                                                    links       characters  \
# 0      https://www.linkedin.com/in/laurel-rohloff-a52...   Counselor (Si)
# 1      https://www.linkedin.com/in/merel-keijzer-7263...  Influencer (Id)
# 2      https://www.linkedin.com/in/amy-macgregor-5325...    Supporter (S)
# 3      https://www.linkedin.com/in/sarah-johnson-54a4...  Influencer (Id)
# 4                     https://www.linkedin.com/in/avoyce    Motivator (I)
# ...                                                  ...              ...
# 13086  https://www.linkedin.com/in/tosin-obayuwana-a3...   Initiator (DI)
# 13087  https://www.linkedin.com/in/carolina-montenegr...  Encourager (Is)
# 13088     https://www.linkedin.com/in/cristynamontenegro      Analyst (C)
# 13089  https://www.linkedin.com/in/lorena-montenegro-...      Editor (Cs)
# 13090  https://www.linkedin.com/in/anna-maria-montene...      Editor (Cs)
#
#                                                     name  position 1  \
# 0                     0    Laurel Rohloff\ndtype: object         NaN
# 1                      0    Merel Keijzer\ndtype: object         NaN
# 2                      0    Amy MacGregor\ndtype: object         NaN
# 3                      0    Sarah Johnson\ndtype: object         NaN
# 4                    0    Annemarie Voyce\ndtype: object         NaN
# ...                                                  ...         ...
# 13086                0    Tosin Obayuwana\ndtype: object         NaN
# 13087            0    Carolina Montenegro\ndtype: object         NaN
# 13088            0    Cristyna Montenegro\ndtype: object         NaN
# 13089             0    Lorena Montenegro \ndtype: object         NaN
# 13090  0    Anna Maria Montenegro Wiesenhofer\ndtype:...         NaN
#
#        position 2  experince 1  ...  field of studies 1  field of studies 2  \
# 0             NaN          NaN  ...                 NaN                 NaN
# 1             NaN          NaN  ...                 NaN                 NaN
# 2             NaN          NaN  ...                 NaN                 NaN
# 3             NaN          NaN  ...                 NaN                 NaN
# 4             NaN          NaN  ...                 NaN                 NaN
# ...           ...          ...  ...                 ...                 ...
# 13086         NaN          NaN  ...                 NaN                 NaN
# 13087         NaN          NaN  ...                 NaN                 NaN
# 13088         NaN          NaN  ...                 NaN                 NaN
# 13089         NaN          NaN  ...                 NaN                 NaN
# 13090         NaN          NaN  ...                 NaN                 NaN
#
#        degree 1  degree 2                                           industry  \
# 0           NaN       NaN  0    Primary/Secondary Education\nName: indust...
# 1           NaN       NaN       0    Research\nName: industry, dtype: object
# 2           NaN       NaN  0    Marketing & Advertising\nName: industry, ...
# 3           NaN       NaN  0    Higher Education\nName: industry, dtype: ...
# 4           NaN       NaN  0    Higher Education\nName: industry, dtype: ...
# ...         ...       ...                                                ...
# 13086       NaN       NaN  0    Management Consulting\nName: industry, dt...
# 13087       NaN       NaN  0    International Affairs\nName: industry, dt...
# 13088       NaN       NaN       0    Research\nName: industry, dtype: object
# 13089       NaN       NaN   0    Construction\nName: industry, dtype: object
# 13090       NaN       NaN  0    Pharmaceuticals\nName: industry, dtype: o...
#
#       certifications                                             skills  \
# 0                NaN  0    ['Parler en public', 'Réseaux sociaux', '...
# 1                NaN  0    ['Statistical Analysis of fMRI Data', 'St...
# 2                NaN  0    ['Proofreading', 'Press Releases', 'Publi...
# 3                NaN  0    ['Public Speaking', 'Coaching', 'Teaching...
# 4                NaN  0    ['Business English', 'Secondary Education...
# ...              ...                                                ...
# 13086            NaN  0    ['Business Analysis', 'Team Management', ...
# 13087            NaN  0    ['Journalism', 'International Relations',...
# 13088            NaN  0    ['C++', 'Programming', 'Logic Programming...
# 13089            NaN  0    ['Gestión de proyectos', 'Microsoft Offic...
# 13090            NaN  0    ['SAP', 'Microsoft Excel', 'Microsoft Off...
#
#                                       influencer country  \
# 0      0    False\nName: influencer, dtype: bool     NaN
# 1      0    False\nName: influencer, dtype: bool     NaN
# 2      0    False\nName: influencer, dtype: bool     NaN
# 3      0    False\nName: influencer, dtype: bool     NaN
# 4      0    False\nName: influencer, dtype: bool     NaN
# ...                                          ...     ...
# 13086  0    False\nName: influencer, dtype: bool     NaN
# 13087  0    False\nName: influencer, dtype: bool     NaN
# 13088  0    False\nName: influencer, dtype: bool     NaN
# 13089  0    False\nName: influencer, dtype: bool     NaN
# 13090  0    False\nName: influencer, dtype: bool     NaN
#
#                                                  summary
# 0                 0   NaN\nName: summary, dtype: float64
# 1      0    I am a second language development and bi...
# 2      0    English teacher with 5 years experience w...
# 3      0    Over a period of more than 10 years of la...
# 4      0    I previously worked as a secondary school...
# ...                                                  ...
# 13086  0    I am a goal getter that have not been  re...
# 13087             0   NaN\nName: summary, dtype: float64
# 13088  0    Civil Engineer with a master's degree in ...
# 13089  0    Master student of Building Technology at ...
# 13090  0    Pharmacist with 6+ years of experience in...
#
# [13091 rows x 21 columns]

# %%
skills
# Out:
# [['Next.js',
#   'Python (Programming Language)',
#   'Django',
#   'REST APIs',
#   'Problem Solving',
#   'Responsive Web Design',
#   'Front-End Development',
#   'Firebase',
#   'Web Development',
#   'Communication',
#   'Contract Negotiation',
#   'Construction',
#   'Management',
#   'Analytical Skills',
#   'Software as a Service (SaaS)',
#   'Translation',
#   'Technical Translation',
#   'English Translation',
#   'Russian Translation',
#   'Redux.js']]

# %%
# Out:
#   Cell In[5], line 1
#     len(positions1)import requests
#                    ^
# SyntaxError: invalid syntax

# %%
=[]
experinces0=[]
experinces1=[]
skills=[]
influencer=[]
country=[]
field_of_studies0=[]
field_of_studies1=[]
degrees0=[]
degrees1=[]
industries=[]
names=[]
summaries=[]
certifications=[]

# %%
import requests
import pandas as pd
import datetime
import csv
import json

positions0=[]
positions1=[]
experinces0=[]
experinces1=[]
skills=[]
influencer=[]
country=[]
field_of_studies0=[]
field_of_studies1=[]
degrees0=[]
degrees1=[]
industries=[]
names=[]
summaries=[]
certifications=[]
# model_crystal\datas\13000_profiles_without_duplicates.csv
df = pd.read_csv('../model_crystal/datas/13000_profiles_without_duplicates.csv')
for csv in range(13091):
	# res=pd.read_json(f'../model_crystal/datas/json_responses/{csv}.json')
	# res=pd.read_csv(f'../model_crystal/datas/responses/{csv}.csv')
	try:
		with open(f'../model_crystal/datas/json_responses/{csv}.json') as f:
			res = json.load(f)
	except:
		print("NAN")
	try:
		skills.append(res['skills'])
	except:
		skills.append(None)
	try:
		position0=res['position_groups'][0]['profile_positions'][0]['title']
		positions0.append(position0)
	except:
		positions0.append(None)

	try:
		position1=res['position_groups'][1]['profile_positions'][0]['title']
		positions1.append(position1)
	except:
		positions1.append(None)

	experince0=0
	try:
		experince0=res['position_groups'][0]['date']['start']['year']-res['position_groups'][0]['date']['end']['year']
		experinces0.append(abs(experince0))
	except:
		try:
			experince0=datetime.date.today().year - res['position_groups'][0]['date']['start']['year']
			experinces0.append(abs(experince0))
		except:
			experinces0.append(None)

	experince1=0
	try:
		experince1=res['position_groups'][1]['date']['start']['year']-res['position_groups'][1]['date']['end']['year']
		experinces1.append(abs(experince1))
	except:
		try:
			experince1=datetime.date.today().year - res['position_groups'][1]['date']['start']['year']
			experinces1.append(abs(experince1))
		except:
			experinces1.append(None)
				
	try:
		influencer.append(res['influencer'])
	except:
		influencer.append(None)
	try:
		country.append(res['location']['country'])
	except:
		country.append(None)
	field_of_study0=""
	try:
		field_of_study0=res['education'][0]['field_of_study']
		field_of_studies0.append(field_of_study0)
	except:
		field_of_study0=None
		field_of_studies0.append(field_of_study0)

	try:
		field_of_study1=res['education'][1]['field_of_study']
		field_of_studies1.append(field_of_study1)
	except:
		field_of_study1=None
		field_of_studies1.append(field_of_study1)

	try:
		degree_name0=res['education'][0]['degree_name']
		degrees0.append(degree_name0)
	except:
		degree_name0=None
		degrees0.append(degree_name0)

	try:
		degree_name1=res['education'][1]['degree_name']
		degrees1.append(degree_name1)
	except:
		degree_name1=None
		degrees1.append(degree_name1)

	try:
		industries.append(res['industry'])
	except:
		industries.append(None)
	try:
		name=res['first_name']+" "+res['last_name']
		names.append(name)
	except:
		names.append(None)
	try:
		if len(res[certifications])==0:
			certifications.append(None)
		for certify in res['certifications']:
			certifications.append(certify['name'])
	except:
		certifications.append(None)
	try:
		summaries.append(res['summary'])
	except:
		summaries.append(None)

df2=pd.DataFrame({
	"name":names,
	'position 1':positions0,
	'position 2':positions1,
	"experince 1":experinces0,
	"experince 2":experinces1,
	"field of studies 1":field_of_studies0,
	"field of studies 2":field_of_studies1,
	"degree 1":degrees0,
	"degree 2":degrees1,
	"industry":industries,
	"certifications":certifications,
	"skills":skills,
	"influencer":influencer,
	"country":country,
	"summary":summaries,
})
d = pd.concat([df, df2], axis=1)
d.to_csv('valuable_data_last.csv')
# Out:
# Laurel Rohloff
# Merel Keijzer
# Amy MacGregor
# Sarah Johnson
# Annemarie Voyce
# Elise Adayme
# Aidan Quinn
# Megan Hershey
# Andreea (Andi) Dumitru
# Claire Niven
# Charlie Shader
# Deborah Knight
# Francesca Vane
# Yesica Natalia Chappe
# Karen Yaworski, Ph.D
# Dominique Broady, English Marketing Translation Expert
# Lilian Sit
# Rebeca S. G.
# Moira Powers
# Marike Duizendstra-Wolters
# Ali Shalileh
# Ebony Burnside
# Cata Amaro Madariaga, M.A.
# Keith Martin
# Carlos José González Largo
# Shahnoza Shamsitdinova
# Christine Gardner
# Jan Leonard E.
# Buffi Duberman
# Tom Johnston
# Maya Zupnik
# Bianca Pellet
# Anna Machejko
# Siji Jabbar
# Nadia van den Berg, MA
# Dimitrios Stergioulis
# Lauren Rahman
# Joy Burrough-Boenisch
# Sandra Wormgoor
# Serena Lyon
# Katharina Pabst
# Valerie Graef
# Janne van Zanen
# Ami Cormack
# Karen Hopp
# Lucia Grajeda
# Kemi Obakin
# Erman Gultop
# Jitka M.
# Agnieszka Karolina Brzozowska
# Sandra Norman
# Xenia Stroi
# Claire Schuyffel
# Jackie Wilson
# Emily Suff
# Sanaz Khelghati
# Fransy Vasilaki
# Brenda de Jong-Pauley, M.A.
# Sandarenu Kumarasamy
# Deborah Peerdeman
# Kleio Noga
# Mark O'Donnell
# Stan Lommelen
# Dominika Flaga
# Xesca Salvans Ploegmakers
# Erik van Vliet
# Muhammad Sheraz Ahsan
# Muneeb Saeed
# Muhammad Haris Zia
# Tehreem Anwar
# Uzma Shujjat
# Grace W.
# Lourdes Montenegro
# Andrea Montenegro
# Jeff Amrish Ritoe
# Catherine Prince
# Zyfra Day
# Roy van Gerven
# Tosin Obayuwana
# Carolina Montenegro
# Cristyna Montenegro
# Lorena Montenegro
# Anna Maria Montenegro Wiesenhofer

# %%
# d=d.drop(['Unnamed: 0.1', 'Unnamed: 0'], axis=1)
d.to_csv('valuable_data_lastone.csv')

# %%
d
# Out:
#                      names                                              links  \
# 0           Laurel Rohloff  https://www.linkedin.com/in/laurel-rohloff-a52...
# 1            Merel Keijzer  https://www.linkedin.com/in/merel-keijzer-7263...
# 2            Amy Macgregor  https://www.linkedin.com/in/amy-macgregor-5325...
# 3            Sarah Johnson  https://www.linkedin.com/in/sarah-johnson-54a4...
# 4               Anne Voyce                 https://www.linkedin.com/in/avoyce
# ...                    ...                                                ...
# 13086      Tosin Obayuwana  https://www.linkedin.com/in/tosin-obayuwana-a3...
# 13087  Carolina Montenegro  https://www.linkedin.com/in/carolina-montenegr...
# 13088  Cristyna Montenegro     https://www.linkedin.com/in/cristynamontenegro
# 13089    Lorena Montenegro  https://www.linkedin.com/in/lorena-montenegro-...
# 13090     Anna Wiesenhofer  https://www.linkedin.com/in/anna-maria-montene...
#
#             characters                               name  \
# 0       Counselor (Si)                     Laurel Rohloff
# 1      Influencer (Id)                      Merel Keijzer
# 2        Supporter (S)                      Amy MacGregor
# 3      Influencer (Id)                      Sarah Johnson
# 4        Motivator (I)                    Annemarie Voyce
# ...                ...                                ...
# 13086   Initiator (DI)                    Tosin Obayuwana
# 13087  Encourager (Is)                Carolina Montenegro
# 13088      Analyst (C)                Cristyna Montenegro
# 13089      Editor (Cs)                 Lorena Montenegro
# 13090      Editor (Cs)  Anna Maria Montenegro Wiesenhofer
#
#                                               position 1  \
# 0                             French and English teacher
# 1      Professor of English Linguistics and English a...
# 2                               English Teacher (IB MYP)
# 3                                               Youtuber
# 4      Teaching Dutch and English as a foreign langua...
# ...                                                  ...
# 13086                              Executive Coordinator
# 13087  Advocacy Protection Officer (NEAR/Network for ...
# 13088                                      Test Engineer
# 13089  Senior Sustainability, Health and Well-being c...
# 13090                        Quality Assurance Associate
#
#                                               position 2  experince 1  \
# 0                                    University Lecturer          2.0
# 1             Assistant Professor of Applied Linguistics          NaN
# 2                                    Magazine Translator          7.0
# 3      Private Tutor English - specialist in solving ...          6.0
# 4                                        English Teacher          0.0
# ...                                                  ...          ...
# 13086                                                CEO          1.0
# 13087              Advocacy 4 Protection expert (NORCAP)          1.0
# 13088                                 Engineering Intern          7.0
# 13089                     Graduation thesis - Internship          4.0
# 13090                                Procedure Assistant          2.0
#
#        experince 2                      field of studies 1  \
# 0              1.0                             Linguistics
# 1             10.0                                    None
# 2              3.0                               Education
# 3             14.0       The teaching of French and German
# 4              6.0       English; Literature and Visuality
# ...            ...                                     ...
# 13086         12.0                                    None
# 13087          0.0                                    None
# 13088          1.0                  Structural Engineering
# 13089          1.0  Building technology- Building physics
# 13090          0.0                 Pharmaceutical Medicine
#
#                                       field of studies 2  \
# 0                                      Études françaises
# 1                                            Linguistics
# 2                English/Language Arts Teacher Education
# 3                                                   None
# 4      Teaching English as a Second or Foreign Langua...
# ...                                                  ...
# 13086                                               None
# 13087                                               None
# 13088                                  Civil Engineering
# 13089                               disciplina academica
# 13090                                      Biotechnology
#
#                                                 degree 1  \
# 0                                        Master's degree
# 1                  Academic Teaching Qualification (BKO)
# 2      International Post Graduate Certificate in Edu...
# 3      Post Graduate Certificate of Education in Mode...
# 4                                        Master's degree
# ...                                                  ...
# 13086                                               None
# 13087  Executive Certificate in Evidence in Public Po...
# 13088                          Master of Science (M.Sc.)
# 13089            Master of Science - Building Technology
# 13090                                    Master's degree
#
#                                                 degree 2  \
# 0                                      Bachelor's degree
# 1                            Doctoral degree Linguistics
# 2      CELTA (Certificate in Teaching English to Spea...
# 3                    BA (Hons) European Business Studies
# 4                           120-hour Premier TEFL course
# ...                                                  ...
# 13086                                               None
# 13087  Executive Certificate in Advocacy in Internati...
# 13088                                  Bachelor's degree
# 13089                             Grado en Arquitectura
# 13090                                   Natural Sciences
#
#                           industry certifications  \
# 0      Primary/Secondary Education           None
# 1                         Research           None
# 2          Marketing & Advertising           None
# 3                 Higher Education           None
# 4                 Higher Education           None
# ...                            ...            ...
# 13086        Management Consulting           None
# 13087        International Affairs           None
# 13088                     Research           None
# 13089                 Construction           None
# 13090              Pharmaceuticals           None
#
#                                                   skills influencer  \
# 0      [Parler en public, Réseaux sociaux, Planificat...      False
# 1      [Statistical Analysis of fMRI Data, Statistica...      False
# 2      [Proofreading, Press Releases, Public Speaking...      False
# 3      [Public Speaking, Coaching, Teaching, Dutch, E...      False
# 4      [Business English, Secondary Education, Teachi...      False
# ...                                                  ...        ...
# 13086  [Business Analysis, Team Management, Digital M...      False
# 13087  [Journalism, International Relations, Media Re...      False
# 13088  [C++, Programming, Logic Programming, Structur...      False
# 13089  [Gestión de proyectos, Microsoft Office, AutoC...      False
# 13090  [SAP, Microsoft Excel, Microsoft Office, GMP, ...      False
#
#               country                                            summary
# 0         Netherlands                                               None
# 1         Netherlands  I am a second language development and bilingu...
# 2         Netherlands  English teacher with 5 years experience workin...
# 3         Netherlands  Over a period of more than 10 years of languag...
# 4      United Kingdom  I previously worked as a secondary school Engl...
# ...               ...                                                ...
# 13086         Nigeria  I am a goal getter that have not been  restric...
# 13087     Netherlands                                               None
# 13088     Netherlands  Civil Engineer with a master's degree in Struc...
# 13089     Netherlands  Master student of Building Technology at the D...
# 13090     Netherlands  Pharmacist with 6+ years of experience in Phar...
#
# [13091 rows x 18 columns]

# %%
import json
with open('../model_crystal/datas/json_responses/732.json') as f:
  data = json.load(f)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[52], line 3
#       1 import json
#       2 with open('../model_crystal/datas/json_responses/732.json') as f:
# ----> 3   data = json.load(f)
#
# File c:\Users\fayyo\.conda\envs\keras1\lib\json\__init__.py:293, in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     274 def load(fp, *, cls=None, object_hook=None, parse_float=None,
#     275         parse_int=None, parse_constant=None, object_pairs_hook=None, **kw):
#     276     """Deserialize ``fp`` (a ``.read()``-supporting file-like object containing
#     277     a JSON document) to a Python object.
#     278
#    (...)
#     291     kwarg; otherwise ``JSONDecoder`` is used.
#     292     """
# --> 293     return loads(fp.read(),
#     294         cls=cls, object_hook=object_hook,
#     295         parse_float=parse_float, parse_int=parse_int,
#     296         parse_constant=parse_constant, object_pairs_hook=object_pairs_hook, **kw)
#
# File c:\Users\fayyo\.conda\envs\keras1\lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# File c:\Users\fayyo\.conda\envs\keras1\lib\json\decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     332 def decode(self, s, _w=WHITESPACE.match):
#     333     """Return the Python representation of ``s`` (a ``str`` instance
#     334     containing a JSON document).
#     335
#     336     """
# --> 337     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338     end = _w(s, end).end()
#     339     if end != len(s):
#
# File c:\Users\fayyo\.conda\envs\keras1\lib\json\decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     353     obj, end = self.scan_once(s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
res=pd.read_json(f'../model_crystal/datas/json_responses/0.json')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 res=pd.read_json(f'../model_crystal/datas/json_responses/0.json')
#
# File c:\Users\fayyo\.conda\envs\keras1\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File c:\Users\fayyo\.conda\envs\keras1\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File c:\Users\fayyo\.conda\envs\keras1\lib\site-packages\pandas\io\json\_json.py:757, in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, encoding_errors, lines, chunksize, compression, nrows, storage_options)
#     754     return json_reader
#     756 with json_reader:
# --> 757     return json_reader.read()
#
# File c:\Users\fayyo\.conda\envs\keras1\lib\site-packages\pandas\io\json\_json.py:915, in JsonReader.read(self)
#     913         obj = self._get_object_parser(self._combine_lines(data_lines))
#     914 else:
# --> 915     obj = self._get_object_parser(self.data)
#     916 self.close()
#     917 return obj
#
# File c:\Users\fayyo\.conda\envs\keras1\lib\site-packages\pandas\io\json\_json.py:937, in JsonReader._get_object_parser(self, json)
#     935 obj = None
#     936 if typ == "frame":
# --> 937     obj = FrameParser(json, **kwargs).parse()
#     939 if typ == "series" or obj is None:
#     940     if not isinstance(dtype, bool):
#
# File c:\Users\fayyo\.conda\envs\keras1\lib\site-packages\pandas\io\json\_json.py:1064, in Parser.parse(self)
#    1062     self._parse_numpy()
#    1063 else:
# -> 1064     self._parse_no_numpy()
#    1066 if self.obj is None:
#    1067     return None
#
# File c:\Users\fayyo\.conda\envs\keras1\lib\site-packages\pandas\io\json\_json.py:1320, in FrameParser._parse_no_numpy(self)
#    1317 orient = self.orient
#    1319 if orient == "columns":
# -> 1320     self.obj = DataFrame(
#    1321         loads(json, precise_float=self.precise_float), dtype=None
#    1322     )
#    1323 elif orient == "split":
#    1324     decoded = {
#    1325         str(k): v
#    1326         for k, v in loads(json, precise_float=self.precise_float).items()
#    1327     }
#
# File c:\Users\fayyo\.conda\envs\keras1\lib\site-packages\pandas\core\frame.py:664, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     658     mgr = self._init_mgr(
#     659         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     660     )
#     662 elif isinstance(data, dict):
#     663     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 664     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     665 elif isinstance(data, ma.MaskedArray):
#     666     import numpy.ma.mrecords as mrecords
#
# File c:\Users\fayyo\.conda\envs\keras1\lib\site-packages\pandas\core\internals\construction.py:493, in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     489     else:
#     490         # dtype check to exclude e.g. range objects, scalars
#     491         arrays = [x.copy() if hasattr(x, "dtype") else x for x in arrays]
# --> 493 return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#
# File c:\Users\fayyo\.conda\envs\keras1\lib\site-packages\pandas\core\internals\construction.py:118, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     115 if verify_integrity:
#     116     # figure out the index, if necessary
#     117     if index is None:
# --> 118         index = _extract_index(arrays)
#     119     else:
#     120         index = ensure_index(index)
#
# File c:\Users\fayyo\.conda\envs\keras1\lib\site-packages\pandas\core\internals\construction.py:666, in _extract_index(data)
#     664 lengths = list(set(raw_lengths))
#     665 if len(lengths) > 1:
# --> 666     raise ValueError("All arrays must be of the same length")
#     668 if have_dicts:
#     669     raise ValueError(
#     670         "Mixing dicts with non-Series may lead to ambiguous ordering."
#     671     )
#
# ValueError: All arrays must be of the same length

# %%
res=data
res['position_groups'][0]['profile_positions'][0]
# Out:
# {'location': 'Almere, Flevoland, Pays-Bas',
#  'date': {'start': {'month': 8, 'day': None, 'year': 2021},
#   'end': {'month': None, 'day': None, 'year': None}},
#  'company': 'International School of Almere',
#  'description': None,
#  'title': 'French and English teacher',
#  'employment_type': 'Contract'}

# %%
import datetime
import requests
import numpy as np
import json
import pandas as pd
# from tensorflow.keras.models import load_model
# from tensorflow.keras.preprocessing.text import Tokenizer
# from tensorflow.keras.preprocessing.sequence import pad_sequences
data=pd.read_csv("./partly_45878_reach_50.csv")
for i in range(5000, 10000):
  link=data['links'][i]
  id = link.split('/')[4]
  url = "https://api.iscraper.io/v2/profile-details"

  payload = {
    'profile_id': id,
  }

  headers = {
    'X-API-KEY': 'YLPyKt7fl3n05qOsf5rTkoQqWab3xGR6',
  }

  response = requests.post(url, json=payload, headers=headers)
  res=response.json()

  with open(f"./datas/json_responses_50k/{i}.json", "w") as json_file:
      json.dump(res, json_file, indent=4)
  print(i)
# Out:
# 5000
# 5001
# 5002
# 5003
# 5004
# 5005
# 5006
# 5007
# 5008
# 5009
# 5010
# 5011
# 5012
# 5013
# 5014
# 5015
# 5016
# 5017
# 5018
# 5019
# 5020
# 5021
# 5022
# 5023
# 5024
# 5025
# 5026
# 5027
# 5028
