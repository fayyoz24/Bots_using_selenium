# %%
from bs4 import BeautifulSoup
import time
from selenium.webdriver.chrome.options import Options
from selenium import webdriver
from selenium.webdriver.common.by import By
import pandas as pd

options = Options()
options.add_argument("user-data-dir=C:/Users/dell/AppData/Local/Google/Chrome/User Data/Profile 1")
driver = webdriver.Chrome(options=options,executable_path='C:/Users/dell/OneDrive/Desktop/chromedriver.exe')
driver.get('https://www.crystalknows.com/app/register')
time.sleep(10)

df= pd.read_csv(f'../linkedin_data_Scraping/15000_linkedin_profiles.csv')
j=0
for study in range(10000,12000, 100):
    j+=1
    try:
        dots=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/div[1]/nav/div/div/div/div[6]/div/div[1]/div[2]/div/div/div')
        dots.click()
        time.sleep(2)
    except:
        print('dots problem')
    try:
        logout=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/div[1]/nav/div/div/div/div[6]/div/div[2]/div[6]/a')
        logout.click()
        time.sleep(5)
    except:
        print('logout problem')
    try:
        signup=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div[3]/div/form/div[3]/div/a')
        signup.click()
        time.sleep(8)
    except:
        print('signup probelm')
    try:
        first_name_input=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div[2]/div[3]/div[1]/input')
        first_name_input.click()
        first_name_input.send_keys(f'Alibek')
    except Exception as e:
        print('first_name-->problem')
    try:
        last_name_input=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div[2]/div[3]/div[2]/input')
        last_name_input.click()
        last_name_input.send_keys(f'Aliyev')
    except Exception as e:
        print('last_name-->problem')
    try:
        comp_email_input=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div[2]/div[4]/div/input')
        comp_email_input.click()
        comp_email_input.send_keys(f'shoqol{str(j)+str(study)}@mail.ru')
    except Exception as e:
        print('comp_email-->problem')
    try:
        first_pass_input=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div[2]/div[5]/div[1]/input')
        first_pass_input.click()
        first_pass_input.send_keys('Aa2301667')
    except Exception as e:
        print('first_pass-->problem')
    try:    
        sec_pass_input=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div[2]/div[5]/div[2]/input')
        sec_pass_input.click()
        sec_pass_input.send_keys('Aa2301667')
    except Exception as e:
        print('sec_pass-->problem')
    try:
        agree_button=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div[2]/div[6]/div/label/div/img')
        agree_button.click()
    except Exception as e:
        print('agree_button-->problem')
    try:                                            #/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div/div[6]/button
        signup_button=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div[2]/div[7]/button')
        signup_button.click()
        time.sleep(10)
    except Exception as e:
        print('signup_button-->problem')
    try:
        country_button=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[1]/div[2]/div/div[2]/img')
        country_button.click()
        first_country=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[1]/div[2]/div[2]/div[1]')
        first_country.click()
    except Exception as e:
        print('country_button-->problem')                                # second country    '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[1]/div[2]/div[2]/div[2]'
    try:
        job_title_input=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[2]/div[2]/div/input')
        job_title_input.click()
        job_title_input.send_keys('software engineer')
    except Exception as e:
        print('job_title-->problem')
    try:    
        my_department_input=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[2]/div[4]/div[1]/div[2]/img')
        my_department_input.click()
        first_department=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[2]/div[4]/div[2]/div[6]')                              #  second department           '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[2]/div[3]/div[2]/div[2]'
        first_department.click()
    except Exception as e:
        print('department-->problem')
    try:    
        next_button=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[2]/a')
        next_button.click()
        time.sleep(10)
    except Exception as e:
        print('next_button-->problem')
    i=0
    dict_={}
    st1=0
    for link in df.links[st1:study]:
        print('AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA')
        print(i)
        st1=study
        print(f"ST1{st1}")
        print(f"STUDY1{study}")
        i+=1
        try: 
            link_enterong_button=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/div[1]/nav/div/div[1]/div/div[1]/div/input')
            link_enterong_button.click()
            link_enterong_button.clear()
            link_enterong_button.send_keys(link)
            time.sleep(8) 
        except Exception as e:
            print("linkedin user not found")
        try:                          # /html/body/div[2]/div/div/div[2]/div[1]/nav/div/div[1]/div/div[1]/div/div[2]/div/div/div/div/div[2]
            first_user=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/div[1]/nav/div/div[1]/div/div[1]/div/div[2]/div/div/div/div/div[2]')
            first_user.click()
            time.sleep(10)
            # src = driver.page_source
            # soup = BeautifulSoup(src, 'lxml')
            # cs=soup.find('div', {'class':'styles_disc-pill-wrapper__aB3OJ'})
            # /html/body/div[2]/div/div/div[4]/div[1]/div/div/div[1]/div/span
            dict_[link]=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/div[1]/div/div/div[1]/div/span').text
            print(dict_[link])
        except Exception as e:
            dict_[link]='nan'
        
        # price_butt=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/div[1]/nav/div/div[2]/div/div[1]').text
        # print(price_butt)
        print(f'IIIIIIIIIIII{i}')
        if i%10==0:
            print('Matched!!')
            try:
                dots1=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/div[1]/nav/div/div[1]/div/div[6]/div/div[1]/div[2]/div/div')
                dots1.click()
                print(dots1)
                time.sleep(2)

                logout1=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/div[1]/nav/div/div/div/div[6]/div/div[2]/div[6]/a')
                logout1.click()
                time.sleep(5)
                signup=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div[3]/div/form/div[3]/div/a')
                signup.click()
                time.sleep(8)

                first_name_input=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div[2]/div[3]/div[1]/input')
                # first_name_input.click()                        /html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div[2]/div[4]/div/input
                first_name_input.send_keys(f'Abror+{str(i)}')
            
                last_name_input=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div[2]/div[3]/div[2]/input')
                last_name_input.click()
                last_name_input.send_keys(f'Aliyev{str(i)}')
                comp_email_input_for_10=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div[2]/div[4]/div/input')
                comp_email_input_for_10.click()
                comp_email_input_for_10.send_keys(f'shoqol{str(study//i)}{str(i)}@mail.ru')
            
                first_pass_input=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div[2]/div[5]/div[1]/input')
                first_pass_input.click()
                first_pass_input.send_keys('12345678')
                
                sec_pass_input=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div[2]/div[5]/div[2]/input')
                sec_pass_input.click()
                sec_pass_input.send_keys('12345678')
            
                agree_button1=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div[2]/div[6]/div/label/div/img')
                agree_button1.click()
        
                signup_button1=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div[2]/div[7]/button')
                signup_button1.click()
                time.sleep(10)
            
                country_button=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[1]/div[2]/div/div[2]/img')
                country_button.click()

                first_country=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[1]/div[2]/div[2]/div[4]')
                first_country.click()
            except Exception as e:
                print('i is divisible 10-->problem')                                # second country    '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[1]/div[2]/div[2]/div[2]'
            try:
                job_title_input=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[2]/div[2]/div/input')
                job_title_input.click()
                job_title_input.send_keys('software engineer')
            except Exception as e:
                print('job_title-->problem')
            try:    
                my_department_input=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[2]/div[4]/div/div[2]/img')
                my_department_input.click()
                first_department=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[2]/div[4]/div[2]/div[4]')
                first_department.click()
            except Exception as e:
                print('department-->problem')
            try:    
                next_button=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[2]/a')
                next_button.click()
                time.sleep(10)
            except Exception as e:
                print('next_button-->problem')
        if len(dict_)%100==0:
            df1 = pd.DataFrame({
            'links':list(dict_.keys()),
            'characters':list(dict_.values())
            })
            x = len(dict_)//100
            df1.to_csv(f'datas/cs_values_new/extra_data/data_till_12000{x}.csv', index=False)
    df1 = pd.DataFrame({
    'links':list(dict_.keys()),
    'characters':list(dict_.values())
    })
    df1.to_csv(f'datas/cs_values_new/data_till_12000{study}.csv', index=False)
    print(list(dict_.values())[-10:])
    print(f'{study} is done!')

# %%
math_cs={}
math_chars={}

# %%
# Out:
# C:\Users\fayyo\AppData\Local\Temp\ipykernel_13120\4036878417.py:10: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(options=options,executable_path='C:/Users/dell/OneDrive/Desktop/chromedriver.exe')
# Incompatible release of chromedriver (version 111.0.5563.64) detected in PATH: c:\Users\GitHub\Bots_using_selenium\linkedin_data_Scraping\chromedriver.exe
# ---------------------------------------------------------------------------
# TimeoutException                          Traceback (most recent call last)
# Cell In[1], line 11
#       9 options.add_argument("user-data-dir=C:/Users/dell/AppData/Local/Google/Chrome/User Data/Profile 13")
#      10 driver = webdriver.Chrome(options=options,executable_path='C:/Users/dell/OneDrive/Desktop/chromedriver.exe')
# ---> 11 driver.get('https://www.crystalknows.com/app/ce/installed')
#      12 time.sleep(10)
#      14 df= pd.read_csv(f'../linkedin_data_Scraping/15000_linkedin_profiles.csv')
#
# File c:\Users\GitHub\Bots_using_selenium\venv\lib\site-packages\selenium\webdriver\remote\webdriver.py:449, in WebDriver.get(self, url)
#     447 def get(self, url: str) -> None:
#     448     """Loads a web page in the current browser session."""
# --> 449     self.execute(Command.GET, {"url": url})
#
# File c:\Users\GitHub\Bots_using_selenium\venv\lib\site-packages\selenium\webdriver\remote\webdriver.py:440, in WebDriver.execute(self, driver_command, params)
#     438 response = self.command_executor.execute(driver_command, params)
#     439 if response:
# --> 440     self.error_handler.check_response(response)
#     441     response["value"] = self._unwrap_value(response.get("value", None))
#     442     return response
#
# File c:\Users\GitHub\Bots_using_selenium\venv\lib\site-packages\selenium\webdriver\remote\errorhandler.py:245, in ErrorHandler.check_response(self, response)
#     243         alert_text = value["alert"].get("text")
#     244     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 245 raise exception_class(message, screen, stacktrace)
#
# TimeoutException: Message: timeout: Timed out receiving message from renderer: 297.954
#   (Session info: chrome=115.0.5790.110)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x00B0A813+48355]
# 	(No symbol) [0x00A9C4B1]
# 	(No symbol) [0x009A5358]
# 	(No symbol) [0x0099849F]
# 	(No symbol) [0x009982EC]
# 	(No symbol) [0x00996F26]
# 	(No symbol) [0x009977AA]
# 	(No symbol) [0x009A03E5]
# 	(No symbol) [0x009AC668]
# 	(No symbol) [0x009AF566]
# 	(No symbol) [0x00997BC3]
# 	(No symbol) [0x009AC539]
# 	(No symbol) [0x009FCB1F]
# 	(No symbol) [0x009EA536]
# 	(No symbol) [0x009C82DC]
# 	(No symbol) [0x009C93DD]
# 	GetHandleVerifier [0x00D6AABD+2539405]
# 	GetHandleVerifier [0x00DAA78F+2800735]
# 	GetHandleVerifier [0x00DA456C+2775612]
# 	GetHandleVerifier [0x00B951E0+616112]
# 	(No symbol) [0x00AA5F8C]
# 	(No symbol) [0x00AA2328]
# 	(No symbol) [0x00AA240B]
# 	(No symbol) [0x00A94FF7]
# 	BaseThreadInitThunk [0x76B600C9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77887B1E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77887AEE+238]

# %%
from bs4 import BeautifulSoup
import time
from selenium.webdriver.chrome.options import Options
from selenium import webdriver
from selenium.webdriver.common.by import By
import pandas as pd

options = Options()
options.add_argument("user-data-dir=C:/Users/dell/AppData/Local/Google/Chrome/User Data/Profile 16")
driver = webdriver.Chrome(options=options,executable_path='C:/Users/dell/OneDrive/Desktop/chromedriver.exe')
driver.get('https://www.crystalknows.com/app/ce/installed')
time.sleep(15)
import pandas as pd
st1=0
for study in range(100, 10000, 100):
    print(f'study{study}')
    dict_={}
    # df = pd.read_csv(f'datas/linkedin_aaccount_links/{study}.csv')
    df= pd.read_csv(f'../linkedin_data_Scraping/15000_linkedin_profiles.csv')

    i=0
    for link in df.links[st1:study]:
        print(link)
        print(f'st1{st1}')
        st1=study
        i+=1
        try: 
            link_enterong_button=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/div[1]/nav/div/div[1]/div/div[1]/div/input')
            link_enterong_button.click()
            link_enterong_button.clear()
            link_enterong_button.send_keys(link)
            time.sleep(8) 
        except Exception as e:
            print("problem account")
        try:                          # /html/body/div[2]/div/div/div[2]/div[1]/nav/div/div[1]/div/div[1]/div/div[2]/div/div/div/div/div[2]
            first_user=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/div[1]/nav/div/div[1]/div/div[1]/div/div[2]/div/div/div/div/div[2]')
            first_user.click()
            time.sleep(10)
            src = driver.page_source
            soup = BeautifulSoup(src, 'lxml')
            cs=soup.find('div', {'class':'styles_disc-pill-wrapper__aB3OJ'})
            # print(cs.text.strip())              
            math_cs[link]=cs.text.strip()       #styles_quality_dm_So styles_DI_sElCv
            # print(cs.text.strip())              #styles_container__BY0sl
        except Exception as e:
            math_cs[link]='nan'
            continue
        if i%10==0:
            try:
                dots=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/div[1]/nav/div/div/div/div[6]/div/div[1]/div[2]/div/div/div')
                dots.click()
                time.sleep(2)
                logout=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/div[1]/nav/div/div/div/div[6]/div/div[2]/div[6]/a')
                logout.click()
                time.sleep(5)
                signup=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div[3]/div/form/div[3]/div/a')
                signup.click()
                time.sleep(8)
                try:
                    cookies_button=driver.find_element(By.XPATH, '/html/body/div[2]/div/div[2]/div')
                    cookies_button.click()
                    time.sleep(2)
                    signup_button=driver.find_element(By.XPATH, '/html/body/div[3]/div/div/div[1]/nav/div/div/div[2]')
                    signup_button.click()
                except Exception as e:
                    print('Cookie button not found!')
                try:
                    first_name_input=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div/div[2]/div[1]/input')
                    first_name_input.click()
                    first_name_input.send_keys(f'Alibek+{str(i)}')
                except Exception as e:
                    print('first_name-->problem')
                try:
                    last_name_input=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div/div[2]/div[2]/input')
                    last_name_input.click()
                    last_name_input.send_keys(f'Aliyev{str(i)}')
                except Exception as e:
                    print('last_name-->problem')
                try:
                    comp_email_input=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div/div[3]/div/input')
                    comp_email_input.click()
                    comp_email_input.send_keys(f'{study[:2]}{str(i)}@acf.com')
                except Exception as e:
                    print('comp_email-->problem')
                try:
                    first_pass_input=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div/div[4]/div[1]/input')
                    first_pass_input.click()
                    first_pass_input.send_keys('Aa2301667')
                except Exception as e:
                    print('first_pass-->problem')
                try:    
                    sec_pass_input=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div/div[4]/div[2]/input')
                    sec_pass_input.click()
                    sec_pass_input.send_keys('Aa2301667')
                except Exception as e:
                    print('sec_pass-->problem')
                try:
                    agree_button=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div/div[5]/div/label/div/img')
                    agree_button.click()
                except Exception as e:
                    print('agree_button-->problem')
                try:
                    signup_button=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div/div[6]/button')
                    signup_button.click()
                    time.sleep(10)
                except Exception as e:
                    print('signup_button-->problem')
                try:
                    country_button=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[1]/div[2]/div/div[2]/img')
                    country_button.click()
                    first_country=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[1]/div[2]/div[2]/div[1]')
                    first_country.click()
                except Exception as e:
                    print('country_button-->problem')                                # second country    '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[1]/div[2]/div[2]/div[2]'

                try:
                    job_title_input=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[2]/input')
                    job_title_input.click()
                    job_title_input.send_keys('software engineer')
                except Exception as e:
                    print('job_title-->problem')
                try:    
                    my_department_input=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[2]/div[3]/div/div[2]')
                    my_department_input.click()
                    first_department=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[2]/div[3]/div[2]/div[1]')                              #  second department           '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[2]/div[3]/div[2]/div[2]'
                    first_department.click()
                except Exception as e:
                    print('department-->problem')
                try:    
                    my_company_input=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[3]/div[2]/div/input')
                    my_company_input.click()
                    my_company_input.send_keys(f'{study[:2]}')
                    first_company=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[3]/div[2]/div[2]/div[1]/div')
                    first_company.click()
                except Exception as e:
                    print('my_company-->problem') 
                try:    
                    next_button=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[2]/a')
                    next_button.click()
                    time.sleep(10)
                except Exception as e:
                    print('next_button-->problem')
            except Exception as e:
                print('cannot create new account!')
    df = pd.DataFrame({
    'links':list(dict_.keys()),
    'characters':list(dict_.values())
    })
    df.to_csv(f'datas/cs_values/data_with_cs{study}.csv', index=False)
# Out:
# C:\Users\fayyo\AppData\Local\Temp\ipykernel_10008\1988154290.py:10: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(options=options,executable_path='C:/Users/dell/OneDrive/Desktop/chromedriver.exe')
# Incompatible release of chromedriver (version 111.0.5563.64) detected in PATH: c:\Users\GitHub\Bots_using_selenium\linkedin_data_Scraping\chromedriver.exe
# study100
# https://nl.linkedin.com/in/darrenhain
# st10
# problem account
# https://nl.linkedin.com/in/susana-matthews-37364052
# st1100
# problem account
# https://nl.linkedin.com/in/rebekah-lawler-19409a126
# st1100
# problem account
# https://nl.linkedin.com/in/giovanna-digregorio-a8064763/en
# st1100
# problem account
# https://nl.linkedin.com/in/beth-hutchinson-358a19101
# st1100
# problem account
# https://nl.linkedin.com/in/olga-gandra-9712b564/en
# st1100
# problem account
# https://nl.linkedin.com/in/rosanabenatti
# st1100
# problem account
# https://nl.linkedin.com/in/verityckerkhoff
# st1100
# problem account
# https://nl.linkedin.com/in/elebasilio
# st1100
# problem account
# https://nl.linkedin.com/in/lidalanguageservices
# st1100
# problem account
# https://nl.linkedin.com/in/andidumitru
# st1100
# problem account
# https://nl.linkedin.com/in/hersheytranslation
# st1100
# problem account
# https://nl.linkedin.com/in/aidanquinn93
# st1100
# problem account
# https://nl.linkedin.com/in/eliseadayme
# st1100
# problem account
# https://nl.linkedin.com/in/financial-italian-translator
# st1100
# problem account
# https://nl.linkedin.com/in/sarah-johnson-54a4573a
# st1100
# problem account
# https://nl.linkedin.com/in/avoyce
# st1100
# problem account
# https://nl.linkedin.com/in/amy-macgregor-53251765
# st1100
# problem account
# https://nl.linkedin.com/in/merel-keijzer-726392269
# st1100
# problem account
# https://nl.linkedin.com/in/laurel-rohloff-a52669144
# st1100
# problem account
# https://nl.linkedin.com/in/lilian-sit-9485aa175
# st1100
# problem account
# https://nl.linkedin.com/in/rebeca-s-g-242a67184
# st1100
# problem account
# https://nl.linkedin.com/in/rose-l-83465b89?trk=public_profile_samename-profile
# st1100
# problem account
# https://nl.linkedin.com/in/dominiquebroady
# st1100
# problem account
# https://nl.linkedin.com/in/karenyaworski
# st1100
# problem account
# https://nl.linkedin.com/in/yesica-natalia-chappe-/en
# st1100
# problem account
# https://nl.linkedin.com/in/francesca-vane-64491313a
# st1100
# problem account
# https://nl.linkedin.com/in/deborah-knight-7b031753
# st1100
# problem account
# https://nl.linkedin.com/in/charlie-shader-75118114
# st1100
# problem account
# https://nl.linkedin.com/in/echt-english
# st1100
# problem account
# https://nl.linkedin.com/in/shahnoza-shamsitdinova-486966121/en
# st1100
# problem account
# https://nl.linkedin.com/in/penta-translations-856b79257/en?trk=people-guest_people_search-card
# st1100
# problem account
# https://nl.linkedin.com/in/carlosjgonzalezl
# st1100
# problem account
# https://nl.linkedin.com/in/keith-martin-7b523662/en
# st1100
# problem account
# https://nl.linkedin.com/in/catherineamaromadariaga
# st1100
# problem account
# https://nl.linkedin.com/in/ali-shalileh-428b4348
# st1100
# problem account
# https://nl.linkedin.com/in/ebony-burnside-722785169
# st1100
# problem account
# https://nl.linkedin.com/in/marike-duizendstra-wolters-723ab115
# st1100
# problem account
# https://nl.linkedin.com/in/shane-sexton-768195210
# st1100
# problem account
# https://nl.linkedin.com/in/moiracpowers
# st1100
# problem account
# https://nl.linkedin.com/in/dimitrios-stergioulis-7a490712a
# st1100
# problem account
# https://nl.linkedin.com/in/nadia-van-den-berg-ma-94bb20160
# st1100
# problem account
# https://nl.linkedin.com/in/sijijabbar
# st1100
# problem account
# https://nl.linkedin.com/in/anna-machejko
# st1100
# problem account
# https://nl.linkedin.com/in/bianca-pellet-10b7047
# st1100
# problem account
# https://nl.linkedin.com/in/maya-zupnik-32617817b
# st1100
# problem account
# https://nl.linkedin.com/in/tomjohnston3
# st1100
# problem account
# https://nl.linkedin.com/in/buffiduberman
# st1100
# problem account
# https://nl.linkedin.com/in/jan-leonard-e-a2295bb2
# st1100
# problem account
# https://nl.linkedin.com/in/schotinderoos
# st1100
# problem account
# https://nl.linkedin.com/in/serena-lyon-348a1815
# st1100
# problem account
# https://nl.linkedin.com/in/sandra-wormgoor-5485691a
# st1100
# problem account
# https://nl.linkedin.com/in/joyburroughboenisch
# st1100
# problem account
# https://nl.linkedin.com/in/laurenrahman01
# st1100
# problem account
# https://nl.linkedin.com/in/janepocock
# st1100
# problem account
# https://nl.linkedin.com/in/tatiana-fateeva-81527233
# st1100
# problem account
# https://nl.linkedin.com/in/craig-bell-6749891a/nl
# st1100
# problem account
# https://nl.linkedin.com/in/irisdorreboom
# st1100
# problem account
# https://nl.linkedin.com/in/ian-mcclure
# st1100
# problem account
# https://nl.linkedin.com/in/pep-mac-ruairi-med-4218a213
# st1100
# problem account
# https://nl.linkedin.com/in/erman-gultop
# st1100
# problem account
# https://nl.linkedin.com/in/jitkaguttnerova
# st1100
# problem account
# https://nl.linkedin.com/in/kemiobakin
# st1100
# problem account
# https://nl.linkedin.com/in/yuliya-baradzeika
# st1100
# problem account
# https://nl.linkedin.com/in/lucia-grajeda-120135182
# st1100
# problem account
# https://nl.linkedin.com/in/karen-hopp-09643b93
# st1100
# problem account
# https://nl.linkedin.com/in/ami-cormack-31b611161
# st1100
# problem account
# https://nl.linkedin.com/in/jannevanzanen
# st1100
# problem account
# https://nl.linkedin.com/in/valerie-graef-4606a123
# st1100
# problem account
# https://nl.linkedin.com/in/katharina-pabst-97098555
# st1100
# problem account
# https://nl.linkedin.com/in/kristina-lupton-0a089930?trk=pub-pbmap
# st1100
# problem account
# https://nl.linkedin.com/in/william-hutchinson-7b5343110?trk=pub-pbmap
# st1100
# problem account
# https://nl.linkedin.com/in/fransy-vasilaki-30230026
# st1100
# problem account
# https://nl.linkedin.com/in/khelghati
# st1100
# problem account
# https://nl.linkedin.com/in/emily-suff-36983464
# st1100
# problem account
# https://nl.linkedin.com/in/jackie-wilson200
# st1100
# problem account
# https://nl.linkedin.com/in/claire-schuyffel-525b2219
# st1100
# problem account
# https://nl.linkedin.com/in/xenia-stroi-846b0592
# st1100
# problem account
# https://nl.linkedin.com/in/sandranorman
# st1100
# problem account
# https://nl.linkedin.com/in/agnieszka-karolina-brzozowska-5986751
# st1100
# problem account
# https://nl.linkedin.com/in/alice-pickering-26091611a
# st1100
# problem account
# https://nl.linkedin.com/in/nicole-reith-14462b11
# st1100
# problem account
# https://nl.linkedin.com/in/stephanie-wang-ba382b194/en?trk=people-guest_people_search-card
# st1100
# problem account
# https://nl.linkedin.com/in/anastasiia-shkovyra-22a148243
# st1100
# problem account
# https://nl.linkedin.com/in/beata-magori-3588aa41
# st1100
# problem account
# https://nl.linkedin.com/in/rosalind-minnaar-79573130
# st1100
# problem account
# https://nl.linkedin.com/in/jamie-mcgeorge-893a9764
# st1100
# problem account
# https://nl.linkedin.com/in/lauraschevers/en
# st1100
# problem account
# https://nl.linkedin.com/in/cgsampson/nl
# st1100
# problem account
# https://nl.linkedin.com/in/irmaktok
# st1100
# problem account
# https://nl.linkedin.com/in/quinon
# st1100
# problem account
# https://nl.linkedin.com/in/xesca-salvans-ploegmakers-57914a14b/en
# st1100
# problem account
# https://nl.linkedin.com/in/dominika-flaga-894162210/en
# st1100
# problem account
# https://nl.linkedin.com/in/stanlommelen
# st1100
# problem account
# https://nl.linkedin.com/in/mark-o-donnell-38355919b
# st1100
# problem account
# https://nl.linkedin.com/in/kleio-noga-b37a3759
# st1100
# problem account
# https://nl.linkedin.com/in/deborahpeerdeman
# st1100
# problem account
# https://nl.linkedin.com/in/terrycostin
# st1100
# problem account
# https://nl.linkedin.com/in/sandarenu-kumarasamy
# st1100
# problem account
# https://nl.linkedin.com/in/bjdejongpauley
# st1100
# problem account
# study200
# https://nl.linkedin.com/in/rens-teunissen
# st1100
# problem account
# https://nl.linkedin.com/in/pieter-pelleboer-8432007b
# st1200
# problem account
# https://nl.linkedin.com/in/rogieroud/en
# st1200
# problem account
# https://nl.linkedin.com/in/philip-blinko-67498126
# st1200
# problem account
# https://nl.linkedin.com/in/noemi-majnusz-9a763841
# st1200
# problem account
# https://nl.linkedin.com/in/bernadette-quinn-82409083/en
# st1200
# problem account
# https://nl.linkedin.com/in/mariadbpopescu
# st1200
# problem account
# https://nl.linkedin.com/in/roy-bicknell-a1947835
# st1200
# problem account
# https://nl.linkedin.com/in/marcweide
# st1200
# problem account
# https://nl.linkedin.com/in/wiktoria-cembala-188132236/en?trk=people-guest_people_search-card
# st1200
# problem account
# https://nl.linkedin.com/in/ellen-singer-47831715
# st1200
# problem account
# https://nl.linkedin.com/in/engelise-hageman-0a29a613/nl
# st1200
# problem account
# https://nl.linkedin.com/in/shevalidielbandhoesing
# st1200
# problem account
# https://nl.linkedin.com/in/geraldinenesbitt
# st1200
# problem account
# https://nl.linkedin.com/in/myrthe-sleutjes-46727a254/en?trk=people-guest_people_search-card
# st1200
# problem account
# https://nl.linkedin.com/in/samuel-bourne-994684169?trk=pub-pbmap
# st1200
# problem account
# https://nl.linkedin.com/in/allison-kirk-04b469168
# st1200
# problem account
# https://nl.linkedin.com/in/natalia-de-coninck-17563929
# st1200
# problem account
# https://nl.linkedin.com/in/jozsef-martinusz-4a481a198
# st1200
# problem account
# https://nl.linkedin.com/in/louis-raubenheimer-profile
# st1200
# problem account
# https://nl.linkedin.com/in/richardglass1
# st1200
# problem account
# https://nl.linkedin.com/in/helen-lambert-52225a15/fr
# st1200
# problem account
# https://nl.linkedin.com/in/richard-thrift-07318668
# st1200
# problem account
# https://nl.linkedin.com/in/mmbentkowski
# st1200
# problem account
# https://nl.linkedin.com/in/acomirzan
# st1200
# problem account
# https://nl.linkedin.com/in/nickhalleducationconsultant
# st1200
# problem account
# https://nl.linkedin.com/in/ghada-rozzi?trk=public_profile_browsemap_profile-result-card_result-card_full-click
# st1200
# problem account
# https://nl.linkedin.com/in/anneloes-saarloos-36aa1336
# st1200
# problem account
# https://nl.linkedin.com/in/francesca-pouwer-37940049
# st1200
# problem account
# https://nl.linkedin.com/in/hildemvonk
# st1200
# problem account
# https://nl.linkedin.com/in/sarah-esther-welling
# st1200
# problem account
# https://nl.linkedin.com/in/berthyn-van-hofslot-9066b313
# st1200
# problem account
# https://nl.linkedin.com/in/coralinereeder
# st1200
# problem account
# https://nl.linkedin.com/in/marie-walker-41048954?trk=org-employees
# st1200
# problem account
# https://nl.linkedin.com/in/gabriela-acevedo-b31b52a2
# st1200
# problem account
# https://nl.linkedin.com/in/rhiannon-jorna-schaeffer-5083ba16
# st1200
# problem account
# https://nl.linkedin.com/in/raginiwerner/nl
# st1200
# problem account
# https://nl.linkedin.com/in/amy-verkerk-ab479078
# st1200
# problem account
# https://nl.linkedin.com/in/evanluijt
# st1200
# problem account
# https://nl.linkedin.com/in/carla-arnold-795297211/en
# st1200
# problem account
# https://nl.linkedin.com/in/matheus-guimaraes-381a68102
# st1200
# problem account
# https://nl.linkedin.com/in/anhelina-lisna-b571b520a?trk=org-employees
# st1200
# problem account
# https://nl.linkedin.com/in/bureaukennedy
# st1200
# problem account
# https://nl.linkedin.com/in/svetlana-kuznetsova-8b6a0462
# st1200
# problem account
# https://nl.linkedin.com/in/francisco-ortiz-66497a4b
# st1200
# problem account
# https://nl.linkedin.com/in/aneta-zarakowska-0396a998
# st1200
# problem account
# https://nl.linkedin.com/in/smiljanaapetrovic/nl
# st1200
# problem account
# https://nl.linkedin.com/in/richardveerman/en
# st1200
# problem account
# https://nl.linkedin.com/in/sarah-hiley-96049329
# st1200
# problem account
# https://nl.linkedin.com/in/beatrix-van-der-schalk-7641378
# st1200
# problem account
# https://nl.linkedin.com/in/marian-venderbos-verhooren-88701122
# st1200
# problem account
# https://nl.linkedin.com/in/tara-gooding-businessenglishcoaching-neurolanguagecoaching
# st1200
# problem account
# https://nl.linkedin.com/in/sabiha-siddique-0bb2a561/en?trk=people-guest_people_search-card
# st1200
# problem account
# https://nl.linkedin.com/in/suvi-glasbergen-811143128
# st1200
# problem account
# https://nl.linkedin.com/in/olga-gandra-9712b564
# st1200
# problem account
# https://nl.linkedin.com/in/ramil-huseynov-32340079
# st1200
# problem account
# https://nl.linkedin.com/in/patricia-van-berkel-kelly-31987419
# st1200
# problem account
# https://nl.linkedin.com/in/elizabethmoltrotterdam
# st1200
# problem account
# https://nl.linkedin.com/in/robin-deelen-3832887b
# st1200
# problem account
# https://nl.linkedin.com/in/branwenspence955aa
# st1200
# problem account
# https://nl.linkedin.com/in/charlotte-g-77128473
# st1200
# problem account
# https://nl.linkedin.com/in/susanne-huiberts-01ab544
# st1200
# problem account
# https://nl.linkedin.com/in/maja-koroleva-7ab10894
# st1200
# problem account
# https://nl.linkedin.com/in/tineke-hoornweg-b637a93b
# st1200
# problem account
# https://nl.linkedin.com/in/richardveerman/en?trk=public_profile_locale-url
# st1200
# problem account
# https://nl.linkedin.com/in/galina-vedmetskaya-1472b824/nl
# st1200
# problem account
# https://nl.linkedin.com/in/josephshinners/nl?trk=people-guest_people_search-card
# st1200
# problem account
# https://nl.linkedin.com/in/sara-roversi-2b925b27/en
# st1200
# problem account
# https://nl.linkedin.com/in/irina-krupkina-5a993b43
# st1200
# problem account
# https://nl.linkedin.com/in/kristi-lo-fo-sang-456966106
# st1200
# problem account
# https://nl.linkedin.com/in/tessa-prevo-437231114
# st1200
# problem account
# https://nl.linkedin.com/in/grollman-global-english-94585610b/en
# st1200
# problem account
# https://nl.linkedin.com/in/michelle-mellion-doorewaard-bb1391b
# st1200
# problem account
# https://nl.linkedin.com/in/zuzanamolcanova
# st1200
# problem account
# https://nl.linkedin.com/in/jannykok
# st1200
# problem account
# https://nl.linkedin.com/in/lente-van-den-berg-1729461b2/en
# st1200
# problem account
# https://nl.linkedin.com/in/yeliz-canpolat-stienstra-a3b0065
# st1200
# problem account
# https://nl.linkedin.com/in/sarah-norris-9b6ba4b3
# st1200
# problem account
# https://nl.linkedin.com/in/suzanne-peraino-1682b491
# st1200
# problem account
# https://nl.linkedin.com/in/wanda-nunes-de-pina-2b269b13
# st1200
# problem account
# https://nl.linkedin.com/in/holly-potter-adams-a269a7126
# st1200
# problem account
# https://nl.linkedin.com/in/myriam-tabet-3222415a
# st1200
# problem account
# https://nl.linkedin.com/in/neville-backler-583b961b/nl
# st1200
# problem account
# https://nl.linkedin.com/in/lory-esposito-8a9b1316
# st1200
# problem account
# https://nl.linkedin.com/in/rosalyn-gingell-94620612
# st1200
# problem account
# https://nl.linkedin.com/in/dannyisrael/nl
# st1200
# problem account
# https://nl.linkedin.com/in/jennifer-steers-72001426
# st1200
# problem account
# https://nl.linkedin.com/in/karin-tolsma-8432963b
# st1200
# problem account
# https://nl.linkedin.com/in/martyna-zimek-33461b233
# st1200
# problem account
# https://nl.linkedin.com/in/soren-johnson-5822b94
# st1200
# problem account
# https://nl.linkedin.com/in/adamfrick1978
# st1200
# problem account
# https://nl.linkedin.com/in/charlotte-wenner-3903a525
# st1200
# problem account
# https://nl.linkedin.com/in/michaelapausova/en
# st1200
# problem account
# https://nl.linkedin.com/in/linda-smidt-747b3610
# st1200
# problem account
# https://nl.linkedin.com/in/rianne-frissen-5637a2ba
# st1200
# problem account
# https://nl.linkedin.com/in/englishwithashley
# st1200
# problem account
# https://nl.linkedin.com/in/ian-hancock-07795021a
# st1200
# problem account
# https://nl.linkedin.com/in/karenwatersfrank
# st1200
# problem account
# https://nl.linkedin.com/in/keith-martin-7b523662
# st1200
# problem account
# https://nl.linkedin.com/in/joellevantrigt/en
# st1200
# problem account
# study300
# https://nl.linkedin.com/in/inmaculada-paredes-lorca-06377610a/en
# st1200
# problem account
# https://nl.linkedin.com/in/kassandra-kelder-89a61820
# st1300
# problem account
# https://nl.linkedin.com/in/erinstallings
# st1300
# problem account
# https://nl.linkedin.com/in/ralfbarkerkimp/nl
# st1300
# problem account
# https://nl.linkedin.com/in/ranjani-ramachandra-573295b9
# st1300
# problem account
# https://nl.linkedin.com/in/sandra-van-wijk-ten-bergen-a7364b12
# st1300
# problem account
# https://nl.linkedin.com/in/angela-schaeken
# st1300
# problem account
# https://nl.linkedin.com/in/sarah-stone-0bb7ab5
# st1300
# problem account
# https://nl.linkedin.com/in/eva-molenberg-vasas-ab459989
# st1300
# problem account
# https://nl.linkedin.com/in/jan-machiel-butter-422b8b91/en
# st1300
# problem account
# https://nl.linkedin.com/in/audreydebijepopson
# st1300
# problem account
# https://nl.linkedin.com/in/helen-lambert-52225a15/nl
# st1300
# problem account
# https://nl.linkedin.com/in/sarah-jayne-reynolds
# st1300
# problem account
# https://nl.linkedin.com/in/cosmina-pinkster-faur-5bb70b22
# st1300
# problem account
# https://nl.linkedin.com/in/paola-chaves-c
# st1300
# problem account
# https://nl.linkedin.com/in/ysrlee
# st1300
# problem account
# https://nl.linkedin.com/in/meredith-bradt-5429588
# st1300
# problem account
# https://nl.linkedin.com/in/sjoerd-lindenburg-803535101?trk=pub-pbmap
# st1300
# problem account
# https://nl.linkedin.com/in/andy-brown-616b9b5
# st1300
# problem account
# https://nl.linkedin.com/in/ellick-alexander-sutherland-bb6a3617
# st1300
# problem account
# https://nl.linkedin.com/in/rebecca-clyburn-531b4790
# st1300
# problem account
# https://nl.linkedin.com/in/patrick-moore-3a688920
# st1300
# problem account
# https://nl.linkedin.com/in/tom-lewisohn-94237121a
# st1300
# problem account
# https://nl.linkedin.com/in/anaisgarnier/en?trk=public_profile_locale-url
# st1300
# problem account
# https://nl.linkedin.com/in/alexgoodger/en
# st1300
# problem account
# https://nl.linkedin.com/in/maria-steendam-van-de-poll-32081913b
# st1300
# problem account
# https://nl.linkedin.com/in/tara-altena-897690172/en
# st1300
# problem account
# https://nl.linkedin.com/in/hugh-masters-a54371150/en
# st1300
# problem account
# https://nl.linkedin.com/in/martine-de-jong-919b5965
# st1300
# problem account
# https://nl.linkedin.com/in/anastasiia-petrukhina-025174235
# st1300
# problem account
# https://nl.linkedin.com/in/james-fleming-037a9632
# st1300
# problem account
# https://nl.linkedin.com/in/chapterandversetranslations
# st1300
# problem account
# https://nl.linkedin.com/in/pamela-zak-27b4a22a
# st1300
# problem account
# https://nl.linkedin.com/in/niveskreuh
# st1300
# problem account
# https://nl.linkedin.com/in/kelly-pt-092ab411
# st1300
# problem account
# https://nl.linkedin.com/in/lisabeteferreira
# st1300
# problem account
# https://nl.linkedin.com/in/lonnekevanpamelen
# st1300
# problem account
# https://nl.linkedin.com/in/annette-hansen-92687631
# st1300
# problem account
# https://nl.linkedin.com/in/wendy-naylor-2a491164
# st1300
# problem account
# https://nl.linkedin.com/in/ritablesgraaf
# st1300
# problem account
# https://nl.linkedin.com/in/annemiespoorenberg
# st1300
# problem account
# https://nl.linkedin.com/in/rachel-w-898355160
# st1300
# problem account
# https://nl.linkedin.com/in/lisalabeau
# st1300
# problem account
# https://nl.linkedin.com/in/brigitte-lokhorst-9295b831
# st1300
# problem account
# https://nl.linkedin.com/in/els-nijsten-52683411
# st1300
# problem account
# https://nl.linkedin.com/in/marieke-van-leeuwen-0593a429
# st1300
# problem account
# https://nl.linkedin.com/in/stephsmithamsterdam
# st1300
# problem account
# https://nl.linkedin.com/in/milouvandermeij/en
# st1300
# problem account
# https://nl.linkedin.com/in/greg-wilson-459a883
# st1300
# problem account
# https://nl.linkedin.com/in/maaike-van-de-sande-a5626839
# st1300
# problem account
# https://nl.linkedin.com/in/anna-dede-bb824931
# st1300
# problem account
# https://nl.linkedin.com/in/christine-pleisner-37137a27
# st1300
# problem account
# https://nl.linkedin.com/in/kerry-finlayson-92685a28
# st1300
# problem account
# https://nl.linkedin.com/in/esther-westerduin-5808b926
# st1300
# problem account
# https://nl.linkedin.com/in/stef-hover-7a0566215
# st1300
# problem account
# https://nl.linkedin.com/in/robgainey
# st1300
# problem account
# https://nl.linkedin.com/in/wendy-elizabeth-de-pree-/en
# st1300
# problem account
# https://nl.linkedin.com/in/yvonne-scherphof-88733032
# st1300
# problem account
# https://nl.linkedin.com/in/paulina-mysiakowska-aa508b193
# st1300
# problem account
# https://nl.linkedin.com/in/agnieszka-krakowiak-1614a918
# st1300
# problem account
# https://nl.linkedin.com/in/andrew-e-bartha
# st1300
# problem account
# https://nl.linkedin.com/in/karinaefraime
# st1300
# problem account
# https://nl.linkedin.com/in/richard-todd-65b71210/nl
# st1300
# problem account
# https://nl.linkedin.com/in/ania-wistuba-2a362615
# st1300
# problem account
# https://nl.linkedin.com/in/willem-de-blaauw-b160519
# st1300
# problem account
# https://nl.linkedin.com/in/paul-gabriner-96316912
# st1300
# problem account
# https://nl.linkedin.com/in/ute-de-vries-translator/en
# st1300
# problem account
# https://nl.linkedin.com/in/susan-m-van-der-werff-0316521a
# st1300
# problem account
# https://nl.linkedin.com/in/annasliwka
# st1300
# problem account
# https://nl.linkedin.com/in/kate-boswell-a65b59219
# st1300
# problem account
# https://nl.linkedin.com/in/jan-van-dijkhuizen-1ab3211a
# st1300
# problem account
# https://nl.linkedin.com/in/marianne-van-der-kleij-77915457/en
# st1300
# problem account
# https://nl.linkedin.com/in/rob-de-ridder-a9198230
# st1300
# problem account
# https://nl.linkedin.com/in/pascalepotdevin/en
# st1300
# problem account
# https://nl.linkedin.com/in/dorineschreiner
# st1300
# problem account
# https://nl.linkedin.com/in/marlene-van-heel-bradbury-18856a4a
# st1300
# problem account
# https://nl.linkedin.com/in/silvievanderzee
# st1300
# problem account
# https://nl.linkedin.com/in/mindy83
# st1300
# problem account
# https://nl.linkedin.com/in/marta-skrzek-3b32b5126
# st1300
# problem account
# https://nl.linkedin.com/in/gareth-evans-jones-45830923
# st1300
# problem account
# https://nl.linkedin.com/in/annemarieavezaat/en
# st1300
# problem account
# https://nl.linkedin.com/in/traysi-smith-18443744
# st1300
# problem account
# https://nl.linkedin.com/in/ms-nadiia-korobchenko-9011aa84/en
# st1300
# problem account
# https://nl.linkedin.com/in/ryan-wiens
# st1300
# problem account
# https://nl.linkedin.com/in/lindsay-chittick-12571a3b
# st1300
# problem account
# https://nl.linkedin.com/in/julie-leenders/en
# st1300
# problem account
# https://nl.linkedin.com/in/holly-thomas-31126020b
# st1300
# problem account
# https://nl.linkedin.com/in/elizabeth-stanley-1a049746
# st1300
# problem account
# https://nl.linkedin.com/in/mark-kieft-797a0269
# st1300
# problem account
# https://nl.linkedin.com/in/jordan-roberts-01436913a
# st1300
# problem account
# https://nl.linkedin.com/in/tammienolte
# st1300
# problem account
# https://nl.linkedin.com/in/jeremy-ramsay-679b433
# st1300
# problem account
# https://nl.linkedin.com/in/jean-weiss-2864a818b/en
# st1300
# problem account
# https://nl.linkedin.com/in/chiara-guagliardo-1a6881184/en
# st1300
# problem account
# https://nl.linkedin.com/in/anouk-bogaert-1254426
# st1300
# problem account
# https://nl.linkedin.com/in/susanamg
# st1300
# problem account
# https://nl.linkedin.com/in/amy-larsen-5a6699216
# st1300
# problem account
# https://nl.linkedin.com/in/hyun-so-6a221b257
# st1300
# problem account
# https://nl.linkedin.com/in/thea-rebien-64302b197
# st1300
# problem account
# https://nl.linkedin.com/in/leandro-carlos-diaz-arg-nl/en
# st1300
# problem account
# study400
# https://nl.linkedin.com/in/kelly-hoenderdos-183799a2
# st1300
# problem account
# https://nl.linkedin.com/in/arnold-augustijn-6246111b
# st1400
# problem account
# https://nl.linkedin.com/in/-afrane-09606341
# st1400
# problem account
# https://nl.linkedin.com/in/mark-sinnott-2828a199
# st1400
# problem account
# https://nl.linkedin.com/in/susanvergeerhunt
# st1400
# problem account
# https://nl.linkedin.com/in/erick-van-den-bercken-b1a20111
# st1400
# problem account
# https://nl.linkedin.com/in/derek-willis-16bbb25
# st1400
# problem account
# https://nl.linkedin.com/in/joanne-den-bremer-7a8517b0
# st1400
# problem account
# https://nl.linkedin.com/in/paul-robertson-eapteacherandlearningtechnologist
# st1400
# problem account
# https://nl.linkedin.com/in/lenisecollimore
# st1400
# problem account
# https://nl.linkedin.com/in/amanda-paul-366813123
# st1400
# problem account
# https://nl.linkedin.com/in/bernard-robinson-141268a
# st1400
# problem account
# https://nl.linkedin.com/in/annemieke-luijckx-36755412
# st1400
# problem account
# https://nl.linkedin.com/in/danielle-garry-51329b238
# st1400
# problem account
# https://nl.linkedin.com/in/vanja-popovic-8315b396
# st1400
# problem account
# https://nl.linkedin.com/in/merve-pekdemir-69893955/en
# st1400
# problem account
# https://nl.linkedin.com/in/sophie-redfern-13b5a11b8
# st1400
# problem account
# https://nl.linkedin.com/in/nickyeadie
# st1400
# problem account
# https://nl.linkedin.com/in/kevin-poynton-41993139
# st1400
# problem account
# https://nl.linkedin.com/in/christine-gremillet-886900222
# st1400
# problem account
# https://nl.linkedin.com/in/chiaraperacchia
# st1400
# problem account
# https://nl.linkedin.com/in/stefanie-matzer-824bb820a
# st1400
# problem account
# https://nl.linkedin.com/in/oyesi-falmagne-92a690144
# st1400
# problem account
# https://nl.linkedin.com/in/noah-sheriff-b91062146
# st1400
# problem account
# https://nl.linkedin.com/in/ellen-runge-91868bba
# st1400
# problem account
# https://nl.linkedin.com/in/hielke-vriesendorp
# st1400
# problem account
# https://nl.linkedin.com/in/daphne-kamerman-57a8972a
# st1400
# problem account
# https://nl.linkedin.com/in/mauromiceli
# st1400
# problem account
# https://nl.linkedin.com/in/kelli-canterbury-51473711a
# st1400
# problem account
# https://nl.linkedin.com/in/janneke-van-engeland
# st1400
# problem account
# https://nl.linkedin.com/in/dr-david-goulding-04a88965
# st1400
# problem account
# https://nl.linkedin.com/in/david-luque-riera-72522647
# st1400
# problem account
# https://nl.linkedin.com/in/usha-wilbers-450b186
# st1400
# problem account
# https://nl.linkedin.com/in/jill-v-jeffery-4ba3753b
# st1400
# problem account
# https://nl.linkedin.com/in/rossana-ruggiero-de-vries-37638a17
# st1400
# problem account
# https://nl.linkedin.com/in/jan-ten-cate-41837a17
# st1400
# problem account
# https://nl.linkedin.com/in/helena-schroder-rogers-5886a916
# st1400
# problem account
# https://nl.linkedin.com/in/sara-bilska-0a4772ab
# st1400
# problem account
# https://nl.linkedin.com/in/atefeh-kamalian-a4b54767
# st1400
# problem account
# https://nl.linkedin.com/in/john-russey
# st1400
# problem account
# https://nl.linkedin.com/in/liekeadriaansen
# st1400
# problem account
# https://nl.linkedin.com/in/melinda-walraven
# st1400
# problem account
# https://nl.linkedin.com/in/yasha-groot-ba2099168
# st1400
# problem account
# https://nl.linkedin.com/in/carmen-adang-a90a6417b
# st1400
# problem account
# https://nl.linkedin.com/in/marrit-faber-67510510
# st1400
# problem account
# https://nl.linkedin.com/in/yupa-tuytaisong-2aa861b5
# st1400
# problem account
# https://nl.linkedin.com/in/trijnie-potze-70322b27
# st1400
# problem account
# https://nl.linkedin.com/in/olga-diacova-82892271/en
# st1400
# problem account
# https://nl.linkedin.com/in/pauline-turier-03a9a31b9/en?trk=people-guest_people_search-card
# st1400
# problem account
# https://nl.linkedin.com/in/edye-kasteel-a3617680
# st1400
# problem account
# https://nl.linkedin.com/in/evelyne-poggio-69804a13
# st1400
# problem account
# https://nl.linkedin.com/in/monniereva/en
# st1400
# problem account
# https://nl.linkedin.com/in/gwenaelle-pennec-0b875415
# st1400
# problem account
# https://nl.linkedin.com/in/florentarjolconde
# st1400
# problem account
# https://nl.linkedin.com/in/linguae
# st1400
# problem account
# https://nl.linkedin.com/in/hester-van-der-linden-4bb5211
# st1400
# problem account
# https://nl.linkedin.com/in/francoispiquet/en
# st1400
# problem account
# https://nl.linkedin.com/in/vincent-berthiot-a4600b56/en
# st1400
# problem account
# https://nl.linkedin.com/in/marie-christine-allenda-a30a8b9/fr
# st1400
# problem account
# https://nl.linkedin.com/in/elise-van-zande-47850560
# st1400
# problem account
# https://nl.linkedin.com/in/rim-belhadj-slama-88975485/en
# st1400
# problem account
# https://nl.linkedin.com/in/cecile-brosset-2037ba16/en
# st1400
# problem account
# https://nl.linkedin.com/in/dr-marjolein-hageman-32ab4911
# st1400
# problem account
# https://nl.linkedin.com/in/a-bonnivard
# st1400
# problem account
# https://nl.linkedin.com/in/sofie-ghysels-ba290787
# st1400
# problem account
# https://nl.linkedin.com/in/bea-toniolo-bucket-list-french
# st1400
# problem account
# https://nl.linkedin.com/in/luciasalgado/en
# st1400
# problem account
# https://nl.linkedin.com/in/nielsvanduinen
# st1400
# problem account
# https://nl.linkedin.com/in/camille-joyandet-a66b5b160/fr
# st1400
# problem account
# https://nl.linkedin.com/in/nirmala-bridgelalsingh-2b49aa90
# st1400
# problem account
# https://nl.linkedin.com/in/jake-ingenthron-b744301b7
# st1400
# problem account
# https://nl.linkedin.com/in/eline-van-moorsel-a09ab535
# st1400
# problem account
# https://nl.linkedin.com/in/l-amina-tadili-4464436a
# st1400
# problem account
# https://nl.linkedin.com/in/emanuela-florea-6a83b175/en
# st1400
# problem account
# https://nl.linkedin.com/in/silvia-la-rocca-986093152/en
# st1400
# problem account
# https://nl.linkedin.com/in/celine-garay-72772150/en
# st1400
# problem account
# https://nl.linkedin.com/in/sheree-stewart-b8227b261
# st1400
# problem account
# https://nl.linkedin.com/in/ivonne-van-pelt-05073112
# st1400
# problem account
# https://nl.linkedin.com/in/madeline-macleod-679820b2
# st1400
# problem account
# https://nl.linkedin.com/in/sofiademurard
# st1400
# problem account
# https://nl.linkedin.com/in/nathan-viollette
# st1400
# problem account
# https://nl.linkedin.com/in/romainpaugam/en
# st1400
# problem account
# https://nl.linkedin.com/in/mcfransen
# st1400
# problem account
# https://nl.linkedin.com/in/sarahjanemellor/en
# st1400
# problem account
# https://nl.linkedin.com/in/valentina-zanolini-6a91a4198/en
# st1400
# problem account
# https://nl.linkedin.com/in/stijn-klawer-b7047b90
# st1400
# problem account
# https://nl.linkedin.com/in/stephrousseau/en
# st1400
# problem account
# https://nl.linkedin.com/in/kim-saintpo-1bb1ba30
# st1400
# problem account
# https://nl.linkedin.com/in/nicolas-cardon-8778a04b/en
# st1400
# problem account
# https://nl.linkedin.com/in/loladusouich/en?trk=public_profile_locale-url
# st1400
# problem account
# https://nl.linkedin.com/in/morgane-thebault-7475314a/en
# st1400
# problem account
# https://nl.linkedin.com/in/louke-van-hasselt-749855b0
# st1400
# problem account
# https://nl.linkedin.com/in/clairechouzenoux/en
# st1400
# problem account
# https://nl.linkedin.com/in/renzoduin
# st1400
# problem account
# https://nl.linkedin.com/in/willem-verweij-0134038b?trk=people-guest_profile-result-card_result-card_full-click
# st1400
# problem account
# https://nl.linkedin.com/in/john-alex-melnyk
# st1400
# problem account
# https://nl.linkedin.com/in/rik-alberigs-4993a31a
# st1400
# problem account
# https://nl.linkedin.com/in/vincent-bretez
# st1400
# problem account
# https://nl.linkedin.com/in/barbara-doninger-ab2aa487
# st1400
# problem account
# https://nl.linkedin.com/in/quentinfourneyron/en
# st1400
# problem account
# study500
# https://nl.linkedin.com/in/audreylagarde/en
# st1400
# problem account
# https://nl.linkedin.com/in/suzanne-richter-0154b5a1
# st1500
# problem account
# https://nl.linkedin.com/in/john-robin-b01aa8145/fr
# st1500
# problem account
# https://nl.linkedin.com/in/armstrongevelyn
# st1500
# problem account
# https://nl.linkedin.com/in/quynh-anh-do-100b3514b/en
# st1500
# problem account
# https://nl.linkedin.com/in/eleaventuri/en
# st1500
# problem account
# https://nl.linkedin.com/in/fabien-abeille-6a699b85/en
# st1500
# problem account
# https://nl.linkedin.com/in/mearetey-chaillou-8718156a
# st1500
# problem account
# https://nl.linkedin.com/in/ambrosia-french-girl-tries?trk=people_directory
# st1500
# problem account
# https://nl.linkedin.com/in/hans-nikkelen-95410a32
# st1500
# problem account
# https://nl.linkedin.com/in/clairefaugeroux/en
# st1500
# problem account
# https://nl.linkedin.com/in/francesco-cannizzaro-9b12065b/en
# st1500
# problem account
# https://nl.linkedin.com/in/melanielemahieu
# st1500
# problem account
# https://nl.linkedin.com/in/maud-oulhen-a44349108
# st1500
# problem account
# https://nl.linkedin.com/in/ginevracalo/fr
# st1500
# problem account
# https://nl.linkedin.com/in/nina-grange-42050666/en
# st1500
# problem account
# https://nl.linkedin.com/in/ivanovay/en
# st1500
# problem account
# https://nl.linkedin.com/in/elizabeth-dineen-88958683
# st1500
# problem account
# https://nl.linkedin.com/in/marco-bril-44b46245
# st1500
# problem account
# https://nl.linkedin.com/in/giulia-crescenti
# st1500
# problem account
# https://nl.linkedin.com/in/guillotjulie
# st1500
# problem account
# https://nl.linkedin.com/in/corine-barbeau-21517827
# st1500
# problem account
# https://nl.linkedin.com/in/sabrina-ghedjati
# st1500
# problem account
# https://nl.linkedin.com/in/maryse-helbert-2b945056
# st1500
# problem account
# https://nl.linkedin.com/in/katarzyna-michnar
# st1500
# problem account
# https://nl.linkedin.com/in/sarita-bhansing-b06aa945
# st1500
# problem account
# https://nl.linkedin.com/in/bastiaan-rietveld-78530227
# st1500
# problem account
# https://nl.linkedin.com/in/joybates
# st1500
# problem account
# https://nl.linkedin.com/in/gireg-bouillon-a67444107
# st1500
# problem account
# https://nl.linkedin.com/in/tyson-ladale-taylor-gerstner-86101838
# st1500
# problem account
# https://nl.linkedin.com/in/amady-honders-50a1365b/nl
# st1500
# problem account
# https://nl.linkedin.com/in/andrea-aguilera-594a0236/en
# st1500
# problem account
# https://nl.linkedin.com/in/gabrielle-schachter
# st1500
# problem account
# https://nl.linkedin.com/in/damian-plonka-24557a143
# st1500
# problem account
# https://nl.linkedin.com/in/jacqueline-veldhuis-308b9398
# st1500
# problem account
# https://nl.linkedin.com/in/nellekevanderpalen
# st1500
# problem account
# https://nl.linkedin.com/in/benedictebinet
# st1500
# problem account
# https://nl.linkedin.com/in/ilene-petersen-54a25322
# st1500
# problem account
# https://nl.linkedin.com/in/bram-van-leuveren-phd-b71a5244
# st1500
# problem account
# https://nl.linkedin.com/in/martapinosanz
# st1500
# problem account
# https://nl.linkedin.com/in/matteo-cima-35bb527b
# st1500
# problem account
# https://nl.linkedin.com/in/michelle-cheyne-ph-d-ll-m-a0a1841b
# st1500
# problem account
# https://nl.linkedin.com/in/irina-kneller
# st1500
# problem account
# https://nl.linkedin.com/in/justinemuraccioli/nl
# st1500
# problem account
# https://nl.linkedin.com/in/laurenceoge
# st1500
# problem account
# https://nl.linkedin.com/in/annelies-veenstra/en?trk=public_profile_locale-url
# st1500
# problem account
# https://nl.linkedin.com/in/breannamcdonald/nl
# st1500
# problem account
# https://nl.linkedin.com/in/lauracolin
# st1500
# problem account
# https://nl.linkedin.com/in/bronson-grund-0b2960b0
# st1500
# problem account
# https://nl.linkedin.com/in/fabien-ketterer/en
# st1500
# problem account
# https://nl.linkedin.com/in/ines-lion
# st1500
# problem account
# https://nl.linkedin.com/in/danielle-lapouille-b9282416/en
# st1500
# problem account
# https://nl.linkedin.com/in/lisa-morano-67057187
# st1500
# problem account
# https://nl.linkedin.com/in/karim-tamim-b98a0a12b
# st1500
# problem account
# https://nl.linkedin.com/in/anil-almac-09242536/en
# st1500
# problem account
# https://nl.linkedin.com/in/alexandra-lemer/en?trk=public_post_feed-actor-name
# st1500
# problem account
# https://nl.linkedin.com/in/carolegoelitz
# st1500
# problem account
# https://nl.linkedin.com/in/sylvie-ducreux-4a1909142
# st1500
# problem account
# https://nl.linkedin.com/in/sarah-tannoux/en
# st1500
# problem account
# https://nl.linkedin.com/in/muriel-schuermans-bb795621
# st1500
# problem account
# https://nl.linkedin.com/in/nathalielegaultforest
# st1500
# problem account
# https://nl.linkedin.com/in/michelelaine1
# st1500
# problem account
# https://nl.linkedin.com/in/diethoddenbagh
# st1500
# problem account
# https://nl.linkedin.com/in/julie-mills-894894ab
# st1500
# problem account
# https://nl.linkedin.com/in/gregorysecerov/en
# st1500
# problem account
# https://nl.linkedin.com/in/maxvanuden/en
# st1500
# problem account
# https://nl.linkedin.com/in/annemiek-krol-7a46248
# st1500
# problem account
# https://nl.linkedin.com/in/ivan-carbonel
# st1500
# problem account
# https://nl.linkedin.com/in/jslfrench
# st1500
# problem account
# https://nl.linkedin.com/in/karien-van-woerden-7a0b1518
# st1500
# problem account
# https://nl.linkedin.com/in/alexandrebeaurain
# st1500
# problem account
# https://nl.linkedin.com/in/den-boogert-diane-3a336835
# st1500
# problem account
# https://nl.linkedin.com/in/dirk-terhenne-21b1b4a
# st1500
# problem account
# https://nl.linkedin.com/in/mandy-hunter-badur-6b7a7132
# st1500
# problem account
# https://nl.linkedin.com/in/florence-da-silva-lopes-dos-santos/en
# st1500
# problem account
# https://nl.linkedin.com/in/joycevanruiten
# st1500
# problem account
# https://nl.linkedin.com/in/pia-vonck-908280115
# st1500
# problem account
# https://nl.linkedin.com/in/danielleputmancramer/fr
# st1500
# problem account
# https://nl.linkedin.com/in/keila-mcfarland-dias
# st1500
# problem account
# https://nl.linkedin.com/in/teresita-de-vedia/en
# st1500
# problem account
# https://nl.linkedin.com/in/asaservicebyyanntoutant
# st1500
# problem account
# https://nl.linkedin.com/in/isabelpascualustarroz
# st1500
# problem account
# https://nl.linkedin.com/in/arthur-le-layec/en
# st1500
# problem account
# https://nl.linkedin.com/in/fabiencarolillo/en
# st1500
# problem account
# https://nl.linkedin.com/in/pelin-ergenekon01/en
# st1500
# problem account
# https://nl.linkedin.com/in/clairefaugeroux/en?trk=public_profile_share_view_actor-name
# st1500
# problem account
# https://nl.linkedin.com/in/antoine-plenderleith
# st1500
# problem account
# https://nl.linkedin.com/in/madelon-van-den-breemen-4545b624?trk=pub-pbmap
# st1500
# problem account
# https://nl.linkedin.com/in/joan-nformi-b541603b
# st1500
# problem account
# https://nl.linkedin.com/in/emilie-jousset-a72671138/en
# st1500
# problem account
# https://nl.linkedin.com/in/celinemagnenat/en
# st1500
# problem account
# https://nl.linkedin.com/in/jenniferbrokamp
# st1500
# problem account
# https://nl.linkedin.com/in/virginie-ninie-van-den-broek
# st1500
# problem account
# https://nl.linkedin.com/in/josemanuelfernandezdelcanto
# st1500
# problem account
# https://nl.linkedin.com/in/marie-sophie-barreau
# st1500
# problem account
# https://nl.linkedin.com/in/lucienkooijman
# st1500
# problem account
# https://nl.linkedin.com/in/marcchanfreau
# st1500
# problem account
# https://nl.linkedin.com/in/mees-kort-20722767
# st1500
# problem account
# https://nl.linkedin.com/in/richard-deseau-8795533b/en
# st1500
# problem account
# https://nl.linkedin.com/in/marie-elamri-49812127
# st1500
# problem account
# study600
# https://nl.linkedin.com/in/hassan-el-oird-14025313
# st1500
# problem account
# https://nl.linkedin.com/in/xavier-colson-9a581bb
# st1600
# problem account
# https://nl.linkedin.com/in/breannamcdonald/fr
# st1600
# problem account
# https://nl.linkedin.com/in/eliza-mels-81512416/nl
# st1600
# problem account
# https://nl.linkedin.com/in/anja-jetter/en?trk=public_profile_locale-url
# st1600
# problem account
# https://nl.linkedin.com/in/fabienne-guichon-lindholm-37a1436
# st1600
# problem account
# https://nl.linkedin.com/in/camillegrotenbreg
# st1600
# problem account
# https://nl.linkedin.com/in/julia-knapp-20181940
# st1600
# problem account
# https://nl.linkedin.com/in/thomas-labourdette-422384b1/en
# st1600
# problem account
# https://nl.linkedin.com/in/lesliemsnider
# st1600
# problem account
# https://nl.linkedin.com/in/manon-clement-492654152/en
# st1600
# problem account
# https://nl.linkedin.com/in/nahomi-deltombe-8189a6150
# st1600
# problem account
# https://nl.linkedin.com/in/germana-barranca-46b19b11
# st1600
# problem account
# https://nl.linkedin.com/in/sebastien-ducoron-34442114
# st1600
# problem account
# https://nl.linkedin.com/in/owen-norker-74483221
# st1600
# problem account
# https://nl.linkedin.com/in/geraldineferre
# st1600
# problem account
# https://nl.linkedin.com/in/rana-manna-6135b91aa?trk=public_profile_browsemap
# st1600
# problem account
# https://nl.linkedin.com/in/jonathan-corr-02492514b
# st1600
# problem account
# https://nl.linkedin.com/in/nadia-gaaliche
# st1600
# problem account
# https://nl.linkedin.com/in/emmaldailey
# st1600
# problem account
# https://nl.linkedin.com/in/jamal-derrazi-32452545/en
# st1600
# problem account
# https://nl.linkedin.com/in/aurelie-becat
# st1600
# problem account
# https://nl.linkedin.com/in/pietervantienen
# st1600
# problem account
# https://nl.linkedin.com/in/mariekummerlowe
# st1600
# problem account
# https://nl.linkedin.com/in/reneebiele
# st1600
# problem account
# https://nl.linkedin.com/in/kpingen01
# st1600
# problem account
# https://nl.linkedin.com/in/tizianacaricato/en
# st1600
# problem account
# https://nl.linkedin.com/in/erik-rakhou
# st1600
# problem account
# https://nl.linkedin.com/in/olympe-lefloch?trk=public_profile_browsemap
# st1600
# problem account
# https://nl.linkedin.com/in/annelies-van-manen-58685942
# st1600
# problem account
# https://nl.linkedin.com/in/germanfigueroa/en
# st1600
# problem account
# https://nl.linkedin.com/in/rim-belhadj-slama-88975485
# st1600
# problem account
# https://nl.linkedin.com/in/marta-la-placa-4865a5161/en
# st1600
# problem account
# https://nl.linkedin.com/in/olivia-klinkum-531b27b3
# st1600
# problem account
# https://nl.linkedin.com/in/nicomorel
# st1600
# problem account
# https://nl.linkedin.com/in/anne-o-connell-427255133
# st1600
# problem account
# https://nl.linkedin.com/in/fabien-chambon-2943b296/en
# st1600
# problem account
# https://nl.linkedin.com/in/david-saire-41805b76
# st1600
# problem account
# https://nl.linkedin.com/in/bernard-foing-b8835910
# st1600
# problem account
# https://nl.linkedin.com/in/manon-pesso
# st1600
# problem account
# https://nl.linkedin.com/in/nievesarahal/en
# st1600
# problem account
# https://nl.linkedin.com/in/gaia-pontarelli-08517658/en
# st1600
# problem account
# https://nl.linkedin.com/in/gillian-mcbride-310b5b83
# st1600
# problem account
# https://nl.linkedin.com/in/fairuzah-atchulo-03138a199?trk=people_directory
# st1600
# problem account
# https://nl.linkedin.com/in/slavov-sl
# st1600
# problem account
# https://nl.linkedin.com/in/mathildegrenod
# st1600
# problem account
# https://nl.linkedin.com/in/sabine-pera-671a36111
# st1600
# problem account
# https://nl.linkedin.com/in/shin-french-1304b5158
# st1600
# problem account
# https://nl.linkedin.com/in/projects-events-sroberts/en
# st1600
# problem account
# https://nl.linkedin.com/in/susanna-castaldini-6690125
# st1600
# problem account
# https://nl.linkedin.com/in/christophe-denat-83401b13
# st1600
# problem account
# https://nl.linkedin.com/in/simone-zamparini/en
# st1600
# problem account
# https://nl.linkedin.com/in/annaaufill
# st1600
# problem account
# https://nl.linkedin.com/in/eva-van-der-graaf-56b69112
# st1600
# problem account
# https://nl.linkedin.com/in/claire-borelli-8b8797129
# st1600
# problem account
# https://nl.linkedin.com/in/isabelle-beaumont-3288b411
# st1600
# problem account
# https://nl.linkedin.com/in/grecialundkvist/en?trk=public_profile_locale-url
# st1600
# problem account
# https://nl.linkedin.com/in/annika-groeneveld-475a5239
# st1600
# problem account
# https://nl.linkedin.com/in/nicomarech
# st1600
# problem account
# https://nl.linkedin.com/in/abigaillevene
# st1600
# problem account
# https://nl.linkedin.com/in/annoesjkaboesaard
# st1600
# problem account
# https://nl.linkedin.com/in/ava-strowel-8b6bab212
# st1600
# problem account
# https://nl.linkedin.com/in/irene-palmer-bautista-25465865
# st1600
# problem account
# https://nl.linkedin.com/in/margot-mesnard-72665847
# st1600
# problem account
# https://nl.linkedin.com/in/kgiuglianotti
# st1600
# problem account
# https://nl.linkedin.com/in/monica-mauri-chro
# st1600
# problem account
# https://nl.linkedin.com/in/sophie-carrion-aguilar
# st1600
# problem account
# https://nl.linkedin.com/in/olga-zvyeryeva-88ba4212
# st1600
# problem account
# https://nl.linkedin.com/in/simona-d-amico-27b69b26
# st1600
# problem account
# https://nl.linkedin.com/in/coumba-diallo-2ba09244/en
# st1600
# problem account
# https://nl.linkedin.com/in/kemalgezer/en?trk=people-guest_people_search-card
# st1600
# problem account
# https://nl.linkedin.com/in/milan-verwers/en
# st1600
# problem account
# https://nl.linkedin.com/in/chiara-foresti-5ba346119
# st1600
# problem account
# https://nl.linkedin.com/in/soljim
# st1600
# problem account
# https://nl.linkedin.com/in/benoit-lemonnier-042a5756
# st1600
# problem account
# https://nl.linkedin.com/in/alice-illichmann
# st1600
# problem account
# https://nl.linkedin.com/in/niall-mcmahon-70727ba1
# st1600
# problem account
# https://nl.linkedin.com/in/lavinia-margea-325a05106
# st1600
# problem account
# https://nl.linkedin.com/in/lucybevan
# st1600
# problem account
# https://nl.linkedin.com/in/peter-french-21029177
# st1600
# problem account
# https://nl.linkedin.com/in/philippe-pozo-06253b68
# st1600
# problem account
# https://nl.linkedin.com/in/bertrand-chung-0b267859
# st1600
# problem account
# https://nl.linkedin.com/in/danielleputmancramer
# st1600
# problem account
# https://nl.linkedin.com/in/daria-appel-3432b556
# st1600
# problem account
# https://nl.linkedin.com/in/morganebrummelhuis
# st1600
# problem account
# https://nl.linkedin.com/in/sylvie-nieuwland-willems-402a30117/en
# st1600
# problem account
# https://nl.linkedin.com/in/miruna-parchirie
# st1600
# problem account
# https://nl.linkedin.com/in/annemiek-verhoeven-3523a03b
# st1600
# problem account
# https://nl.linkedin.com/in/claude-ebanda-b6023111b
# st1600
# problem account
# https://nl.linkedin.com/in/sophie-hery-4589a212
# st1600
# problem account
# https://nl.linkedin.com/in/christophe-samuel-hutchinson-09489433
# st1600
# problem account
# https://nl.linkedin.com/in/emanuela-campbell-b93a6498
# st1600
# problem account
# https://nl.linkedin.com/in/caroledubbeld
# st1600
# problem account
# https://nl.linkedin.com/in/celine-spanings-pierrot-7680127
# st1600
# problem account
# https://nl.linkedin.com/in/sylvie-pons-1644aa4
# st1600
# problem account
# https://nl.linkedin.com/in/raphaellabbe/en
# st1600
# problem account
# https://nl.linkedin.com/in/anca-mihaela-stanciu-4b359b13a/fr?trk=people-guest_people_search-card
# st1600
# problem account
# https://nl.linkedin.com/in/lydie-gernez-1570045a
# st1600
# problem account
# https://nl.linkedin.com/in/maria-clara-mena
# st1600
# problem account
# https://nl.linkedin.com/in/sonisol/en
# st1600
# problem account
# study700
# https://nl.linkedin.com/in/olivierbertonhg
# st1600
# problem account
# https://nl.linkedin.com/in/theo-paul-charpentier-a64b4850
# st1700
# problem account
# https://nl.linkedin.com/in/stanmonnier
# st1700
# problem account
# https://nl.linkedin.com/in/mischa-ehrens-13797a9b
# st1700
# problem account
# https://nl.linkedin.com/in/paola-westbeek-6b7b697
# st1700
# problem account
# https://nl.linkedin.com/in/giselebidenbach/nl
# st1700
# problem account
# https://nl.linkedin.com/in/karouchkavisscher
# st1700
# problem account
# https://nl.linkedin.com/in/jasperpauwels
# st1700
# problem account
# https://nl.linkedin.com/in/jelena-milicevic-0678591b4
# st1700
# problem account
# https://nl.linkedin.com/in/martanuevofalguera
# st1700
# problem account
# https://nl.linkedin.com/in/joost-derks-a6540489
# st1700
# problem account
# https://nl.linkedin.com/in/virgilev/en
# st1700
# problem account
# https://nl.linkedin.com/in/henkreinds
# st1700
# problem account
# https://nl.linkedin.com/in/tanguy-andre-824700187
# st1700
# problem account
# https://nl.linkedin.com/in/french-legal-translation-82b015aa
# st1700
# problem account
# https://nl.linkedin.com/in/thibaultschrepel/en
# st1700
# problem account
# https://nl.linkedin.com/in/giuseppe-carmignola-898903160/en
# st1700
# problem account
# https://nl.linkedin.com/in/gerdazandberg
# st1700
# problem account
# https://nl.linkedin.com/in/hao-xie-5b8a146
# st1700
# problem account
# https://nl.linkedin.com/in/liamepstein
# st1700
# problem account
# https://nl.linkedin.com/in/gonnie-heres-de-vries-35572314
# st1700
# problem account
# https://nl.linkedin.com/in/benjamin-rozand-74808119b/en
# st1700
# problem account
# https://nl.linkedin.com/in/jaap-keizer-22057516
# st1700
# problem account
# https://nl.linkedin.com/in/sionfrench
# st1700
# problem account
# https://nl.linkedin.com/in/otisfrenchg2
# st1700
# problem account
# https://nl.linkedin.com/in/ed-wichers-83308b27
# st1700
# problem account
# https://nl.linkedin.com/in/translated?trk=public_profile_browsemap_profile-result-card_result-card_full-click
# st1700
# problem account
# https://nl.linkedin.com/in/eva-soares-027100213/en
# st1700
# problem account
# https://nl.linkedin.com/in/ciara-odonoghue-1b701a171
# st1700
# problem account
# https://nl.linkedin.com/in/didierlebon/en
# st1700
# problem account
# https://nl.linkedin.com/in/sylvieducreux
# st1700
# problem account
# https://nl.linkedin.com/in/cosmundsen
# st1700
# problem account
# https://nl.linkedin.com/in/floor-lucas0706
# st1700
# problem account
# https://nl.linkedin.com/in/virginie-krompholtz-75331989
# st1700
# problem account
# https://nl.linkedin.com/in/axeldarut/en
# st1700
# problem account
# https://nl.linkedin.com/in/hyongsil-cho-phd-mba-33045392
# st1700
# problem account
# https://nl.linkedin.com/in/margherita-grassi/fr
# st1700
# problem account
# https://nl.linkedin.com/in/yara-meijer
# st1700
# problem account
# https://nl.linkedin.com/in/mariko-aoki-a2b36b14a
# st1700
# problem account
# https://nl.linkedin.com/in/corinne-bekkers-881a7532
# st1700
# problem account
# https://nl.linkedin.com/in/maureen-poupelin-004428a6/en?trk=public_profile_like_view_actor-name
# st1700
# problem account
# https://nl.linkedin.com/in/valentin-jully
# st1700
# problem account
# https://nl.linkedin.com/in/vblaty
# st1700
# problem account
# https://nl.linkedin.com/in/ynes-dovonou-67639a197/en
# st1700
# problem account
# https://nl.linkedin.com/in/ian-eugene-french-67a3658b?trk=public_profile_browsemap
# st1700
# problem account
# https://nl.linkedin.com/in/guillaumelherbette/en
# st1700
# ...
# st19700
# problem account
# https://nl.linkedin.com/in/massimiliano-scarpellini-0b1a78b
# st19700
# problem account
# https://nl.linkedin.com/in/lisette-lamme-9936b284
# st19700
# problem account
# https://nl.linkedin.com/in/irving14waas
# st19700
# problem account
# https://nl.linkedin.com/in/paul-evans-7b811850
# st19700
# problem account
# https://nl.linkedin.com/in/marcel-molenbeek-3a2143
# st19700
# problem account
# https://nl.linkedin.com/in/alejandraorti
# st19700
# problem account
# https://nl.linkedin.com/in/lissetteisabel/de
# st19700
# problem account
# https://nl.linkedin.com/in/moise-dumitru-b90a31115
# st19700
# problem account
# https://nl.linkedin.com/in/naomicalis
# st19700
# problem account
# https://nl.linkedin.com/in/guillermo-van-dams-6a3740109
# st19700
# problem account
# https://nl.linkedin.com/in/harry-bosman-0a53035b
# st19700
# problem account
# https://nl.linkedin.com/in/allround-coverband-vof-bahama-s-78b88a48
# st19700
# problem account
# https://nl.linkedin.com/in/monique-mies-9397b047
# st19700
# problem account
# https://nl.linkedin.com/in/ronald-beekhof-b9152355
# st19700
# problem account
# study9800
# https://nl.linkedin.com/in/neomi-marsolo-74b637127
# st19700
# problem account
# https://nl.linkedin.com/in/kennet-letterboom-55765875
# st19800
# problem account
# https://nl.linkedin.com/in/marloes-wittebrood-636bb559
# st19800
# problem account
# https://nl.linkedin.com/in/mmjvandijk
# st19800
# problem account
# https://nl.linkedin.com/in/zara-bryant5
# st19800
# problem account
# https://nl.linkedin.com/in/meisinga
# st19800
# problem account
# https://nl.linkedin.com/in/nestor-wester-16152b1bb
# st19800
# problem account
# https://nl.linkedin.com/in/jaap-wiersma-45263262
# st19800
# problem account
# https://nl.linkedin.com/in/theo-verweij-52a40554
# st19800
# problem account
# https://nl.linkedin.com/in/jimmy-halvardsson-85b63b42
# st19800
# problem account
# https://nl.linkedin.com/in/laura-romains-aa660b19
# st19800
# problem account
# https://nl.linkedin.com/in/henno-heijns-262456100
# st19800
# problem account
# https://nl.linkedin.com/in/brechtje-renzema-7311689
# st19800
# problem account
# https://nl.linkedin.com/in/hark-kete-a72784224
# st19800
# problem account
# https://nl.linkedin.com/in/mohamed-osman-kamara-048a63263
# st19800
# problem account
# https://nl.linkedin.com/in/anand-b-3a25a224
# st19800
# problem account
# https://nl.linkedin.com/in/sumarimarx
# st19800
# problem account
# https://nl.linkedin.com/in/david-p-079b1261
# st19800
# problem account
# https://nl.linkedin.com/in/terry-schenk-202563195
# st19800
# problem account
# https://nl.linkedin.com/in/marcel-molenbeek-3a2143/it
# st19800
# problem account
# https://nl.linkedin.com/in/rutger-stuut-943ba8b1
# st19800
# problem account
# https://nl.linkedin.com/in/tomek-trzeciak3005/en?trk=people-guest_people_search-card
# st19800
# problem account
# https://nl.linkedin.com/in/maaike-de-waele-26b6a7a5
# st19800
# problem account
# https://nl.linkedin.com/in/philip-davis-4589566
# st19800
# problem account
# https://nl.linkedin.com/in/jaap-treffers-5050a06b
# st19800
# problem account
# https://nl.linkedin.com/in/errica-alexander-5869457b
# st19800
# problem account
# https://nl.linkedin.com/in/paul-stoop-ba359441
# st19800
# problem account
# https://nl.linkedin.com/in/maksym-kirichenko-8108469b/en?trk=people-guest_people_search-card
# st19800
# problem account
# https://nl.linkedin.com/in/maike-osei-van-der-weijden-84722115
# st19800
# problem account
# https://nl.linkedin.com/in/zita-conroy-7288a289
# st19800
# problem account
# https://nl.linkedin.com/in/majd-sardene-b0064521a
# st19800
# problem account
# https://nl.linkedin.com/in/jan-dippell-ritzinger-182406158
# st19800
# problem account
# https://nl.linkedin.com/in/barbara-voermans-7976b9131
# st19800
# problem account
# https://nl.linkedin.com/in/jade-gardner-b8bbaa26
# st19800
# problem account
# https://nl.linkedin.com/in/peter-van-der-zwet-b684395b
# st19800
# problem account
# https://nl.linkedin.com/in/jurgen-de-ceuster-a88499b
# st19800
# problem account
# https://nl.linkedin.com/in/nataliagonzaleznl
# st19800
# problem account
# https://nl.linkedin.com/in/katinkableeker
# st19800
# problem account
# https://nl.linkedin.com/in/pieter-brinkman-67746a42
# st19800
# problem account
# https://nl.linkedin.com/in/jitse-schol/en
# st19800
# problem account
# https://nl.linkedin.com/in/peter-koster-a7466b1b
# st19800
# problem account
# https://nl.linkedin.com/in/halbeveenstra
# st19800
# problem account
# https://nl.linkedin.com/in/ficsor-cintia
# st19800
# problem account
# https://nl.linkedin.com/in/isabelle-toupense-24505687
# st19800
# problem account
# https://nl.linkedin.com/in/clarence-m-bilong-7094959b
# st19800
# problem account
# https://nl.linkedin.com/in/camille-van-der-vaart-82546222a/en
# st19800
# problem account
# https://nl.linkedin.com/in/arnauquinquilla?trk=public_profile_browsemap
# st19800
# problem account
# https://nl.linkedin.com/in/roxanne-simons-b73035151
# st19800
# problem account
# https://nl.linkedin.com/in/maksimmuneer
# st19800
# problem account
# https://nl.linkedin.com/in/frederieke-boomsma-66281b2
# st19800
# problem account
# https://nl.linkedin.com/in/niek-meijers-9b0a49203
# st19800
# problem account
# https://nl.linkedin.com/in/ricardo-oosterman-b593b1260
# st19800
# problem account
# https://nl.linkedin.com/in/sofiia-chyzhova-756b5a192
# st19800
# problem account
# https://nl.linkedin.com/in/paul-meijboom-8a552321
# st19800
# problem account
# https://nl.linkedin.com/in/frank-bakker-76867785
# st19800
# problem account
# https://nl.linkedin.com/in/robert-de-brueijs-559935a
# st19800
# problem account
# https://nl.linkedin.com/in/elma-van-der-wel-07983a34
# st19800
# problem account
# https://nl.linkedin.com/in/hein-haringsma-813a9913a
# st19800
# problem account
# https://nl.linkedin.com/in/jacqueslangenhuysen
# st19800
# problem account
# https://nl.linkedin.com/in/harry-driessen-3a1a9a177
# st19800
# problem account
# https://nl.linkedin.com/in/danilo-sapienza
# st19800
# problem account
# https://nl.linkedin.com/in/rin-barendsen-24b28922
# st19800
# problem account
# https://nl.linkedin.com/in/okache-ogar-99864478
# st19800
# problem account
# https://nl.linkedin.com/in/irene-kolditz-baa88032
# st19800
# problem account
# https://nl.linkedin.com/in/remment-ter-hofstede-94366113
# st19800
# problem account
# https://nl.linkedin.com/in/shant-ebrahimi-4ab67b19b
# st19800
# problem account
# https://nl.linkedin.com/in/jeny-cm-988014151
# st19800
# problem account
# https://nl.linkedin.com/in/albertjdeheer
# st19800
# problem account
# https://nl.linkedin.com/in/lodewijk-franken-5b34241
# st19800
# problem account
# https://nl.linkedin.com/in/gmodena/KmieZ/
# st19800
# problem account
# https://nl.linkedin.com/in/federico-iavarone
# st19800
# problem account
# https://nl.linkedin.com/in/tanasache-v-9b406a68/tl?trk=public_post_comment_actor-name
# st19800
# problem account
# https://nl.linkedin.com/in/anthony-m-8a1a1220b?trk=people-guest_people_search-card
# st19800
# problem account
# https://nl.linkedin.com/in/kimhuntjens/en
# st19800
# problem account
# https://nl.linkedin.com/in/glenn-van-ijzendoorn-78588061
# st19800
# problem account
# https://nl.linkedin.com/in/sarah-b-haimes/es
# st19800
# problem account
# https://nl.linkedin.com/in/marcin-nawrocki-b655bb137
# st19800
# problem account
# https://nl.linkedin.com/in/rdonata
# st19800
# problem account
# https://nl.linkedin.com/in/andrewbarker14
# st19800
# problem account
# https://nl.linkedin.com/in/pol-robert-castells-castro-4a5974226
# st19800
# problem account
# https://nl.linkedin.com/in/jrvanveen
# st19800
# problem account
# https://nl.linkedin.com/in/francesco-quattromani-57085090
# st19800
# problem account
# https://nl.linkedin.com/in/maarten-hoftijzer-1b07027b
# st19800
# problem account
# https://nl.linkedin.com/in/salazarhan/en?trk=people-guest_people_search-card
# st19800
# problem account
# https://nl.linkedin.com/in/richard-lines-3629175
# st19800
# problem account
# https://nl.linkedin.com/in/alanbondi/en
# st19800
# problem account
# https://nl.linkedin.com/in/san-huizer-van-bremen-294711a6
# st19800
# problem account
# https://nl.linkedin.com/in/koen-houtkamp-382a725
# st19800
# problem account
# https://nl.linkedin.com/in/ilona-verhagen-3674635
# st19800
# problem account
# https://nl.linkedin.com/in/meganstam
# st19800
# problem account
# https://nl.linkedin.com/in/roberto-payer-317247a6
# st19800
# problem account
# https://nl.linkedin.com/in/karin-spruit
# st19800
# problem account
# https://nl.linkedin.com/in/henkvanerk
# st19800
# problem account
# https://nl.linkedin.com/in/joris-hillebrandt-75b44b5
# st19800
# problem account
# https://nl.linkedin.com/in/gijshoutman
# st19800
# problem account
# https://nl.linkedin.com/in/allison-van-dams-7a5b263
# st19800
# problem account
# https://nl.linkedin.com/in/sefrijn
# st19800
# problem account
# https://nl.linkedin.com/in/nataliia-hamanenko-6a5723234
# st19800
# problem account
# https://nl.linkedin.com/in/huib-ouwehand-1b080b70?trk=public_profile_browsemap_profile-result-card_result-card_full-click
# st19800
# problem account
# https://nl.linkedin.com/in/nancy-kroonenberg-301bb4a1
# st19800
# problem account
# study9900
# https://nl.linkedin.com/in/anna-riorden
# st19800
# problem account
# https://nl.linkedin.com/in/lauramarakowits
# st19900
# problem account
# https://nl.linkedin.com/in/arthur-ijdo-a50a48129
# st19900
# problem account
# https://nl.linkedin.com/in/gijs-ten-elshof-716a71185
# st19900
# problem account
# https://nl.linkedin.com/in/marleen-bouma-willemsen-4862942b
# st19900
# problem account
# https://nl.linkedin.com/in/geesje-sicking-77566a3
# st19900
# problem account
# https://nl.linkedin.com/in/michel-johansen
# st19900
# problem account
# https://nl.linkedin.com/in/taj-kroon-b924b310a
# st19900
# problem account
# https://nl.linkedin.com/in/wienand-drenth-190b8a1
# st19900
# problem account
# https://nl.linkedin.com/in/sytske-claassen-8332b523
# st19900
# problem account
# https://nl.linkedin.com/in/joris-meursing-243b05232
# st19900
# problem account
# https://nl.linkedin.com/in/henkverbrugge/nl
# st19900
# problem account
# https://nl.linkedin.com/in/avnerbekkering/en
# st19900
# problem account
# https://nl.linkedin.com/in/roland-hols-124a8018/nl
# st19900
# problem account
# https://nl.linkedin.com/in/wesley-bynoe-61681a103?trk=pub-pbmap
# st19900
# problem account
# https://nl.linkedin.com/in/aisha246estwick
# st19900
# problem account
# https://nl.linkedin.com/in/nigel-harper-83658585
# st19900
# problem account
# https://nl.linkedin.com/in/jamonnroberts
# st19900
# problem account
# https://nl.linkedin.com/in/kerry-lyn-scheper-55669964
# st19900
# problem account
# https://nl.linkedin.com/in/angus-pile-3bb26596
# st19900
# problem account
# https://nl.linkedin.com/in/emma-harriet-morris-20b126170
# st19900
# problem account
# https://nl.linkedin.com/in/radha-zievinger
# st19900
# problem account
# https://nl.linkedin.com/in/paulsisnett
# st19900
# problem account
# https://nl.linkedin.com/in/femke-kraan-030a485
# st19900
# problem account
# https://nl.linkedin.com/in/joanna-yela-6288ba101
# st19900
# problem account
# https://nl.linkedin.com/in/ard-vreugdenhil-186b307
# st19900
# problem account
# https://nl.linkedin.com/in/gerrit-barbados-23a1a249
# st19900
# problem account
# https://nl.linkedin.com/in/james-austin-bynoe-5693a418
# st19900
# problem account
# https://nl.linkedin.com/in/lmamulder
# st19900
# problem account
# https://nl.linkedin.com/in/carlon-knight-b32829134
# st19900
# problem account
# https://nl.linkedin.com/in/ursula-c-romeo-514843131
# st19900
# problem account
# https://nl.linkedin.com/in/troy-callender-3161a9190
# st19900
# problem account
# https://nl.linkedin.com/in/karen-medford-b25a885b
# st19900
# problem account
# https://nl.linkedin.com/in/robin-birchall-ba0268
# st19900
# problem account
# https://nl.linkedin.com/in/alex-cole-26ba2b196
# st19900
# problem account
# https://nl.linkedin.com/in/henk-van-dierendonck-16067b9a
# st19900
# problem account
# https://nl.linkedin.com/in/roselyn-pase-252a6460/en?trk=public_profile_locale-url
# st19900
# problem account
# https://nl.linkedin.com/in/carson-ross-ba8a7167
# st19900
# problem account
# https://nl.linkedin.com/in/alana-mcintosh-clarke-1b6474122
# st19900
# problem account
# https://nl.linkedin.com/in/frances-dorrestein-a3043782
# st19900
# problem account
# https://nl.linkedin.com/in/inga-de-reus-15274843
# st19900
# problem account
# https://nl.linkedin.com/in/ryan-trotman-441070221
# st19900
# problem account
# https://nl.linkedin.com/in/denston-lyte-49565448
# st19900
# problem account
# https://nl.linkedin.com/in/anthony-cummins-73aab2130
# st19900
# problem account
# https://nl.linkedin.com/in/jvddungen
# st19900
# problem account
# https://nl.linkedin.com/in/eriktotte
# st19900
# problem account
# https://nl.linkedin.com/in/joris-van-ependingen-4734b930
# st19900
# problem account
# https://nl.linkedin.com/in/algernon-yearwood-123508aa
# st19900
# problem account
# https://nl.linkedin.com/in/jeaninedupigny
# st19900
# problem account
# https://nl.linkedin.com/in/marcvelzen
# st19900
# problem account
# https://nl.linkedin.com/in/tyeterence
# st19900
# problem account
# https://nl.linkedin.com/in/daan-bouwman-431bb013
# st19900
# problem account
# https://nl.linkedin.com/in/paulhenriquespeopleandrewardleader
# st19900
# problem account
# https://nl.linkedin.com/in/guillaumewarneryhospitalitycoach/ar
# st19900
# problem account
# https://nl.linkedin.com/in/david-green-bbb2421
# st19900
# problem account
# https://nl.linkedin.com/in/serena-ward-449898154
# st19900
# problem account
# https://nl.linkedin.com/in/thomas-speicher-0b9356173
# st19900
# problem account
# https://nl.linkedin.com/in/secretarialservice
# st19900
# problem account
# https://nl.linkedin.com/in/mayara-lima-74241b2b
# st19900
# problem account
# https://nl.linkedin.com/in/milamarkovic
# st19900
# problem account
# https://nl.linkedin.com/in/othniel-rafaela-a7701081
# st19900
# problem account
# https://nl.linkedin.com/in/shirmapetronilia
# st19900
# problem account
# https://nl.linkedin.com/in/ashrafalikm
# st19900
# problem account
# https://nl.linkedin.com/in/patrick-meijer-2105917
# st19900
# problem account
# https://nl.linkedin.com/in/jules-vastert-54944330
# st19900
# problem account
# https://nl.linkedin.com/in/meggie-may-kuijer
# st19900
# problem account
# https://nl.linkedin.com/in/karel-klapstra-68502b11
# st19900
# problem account
# https://nl.linkedin.com/in/timboersmabfcc
# st19900
# problem account
# https://nl.linkedin.com/in/anjella-chigharoe-4a7a0140
# st19900
# problem account
# https://nl.linkedin.com/in/john-kimmel-46223b1
# st19900
# problem account
# https://nl.linkedin.com/in/patrick-wilkinson-608a1a19
# st19900
# problem account
# https://nl.linkedin.com/in/yolande-de-boer-33434092
# st19900
# problem account
# https://nl.linkedin.com/in/patrick-pile-968974232
# st19900
# problem account
# https://nl.linkedin.com/in/zaky-tarek-922167219
# st19900
# problem account
# https://nl.linkedin.com/in/joyce-klaarwater-46868490
# st19900
# problem account
# https://nl.linkedin.com/in/patrickalainricord
# st19900
# problem account
# https://nl.linkedin.com/in/frank-hoencamp-69645910
# st19900
# problem account
# https://nl.linkedin.com/in/bureaukaess
# st19900
# problem account
# https://nl.linkedin.com/in/rebecca-saunders-894b7a129
# st19900
# problem account
# https://nl.linkedin.com/in/kenyatta-daniel-73b3984b
# st19900
# problem account
# https://nl.linkedin.com/in/ina-kotter-14650982
# st19900
# problem account
# https://nl.linkedin.com/in/maartjeoenema
# st19900
# problem account
# https://nl.linkedin.com/in/doreedenhollander
# st19900
# problem account
# https://nl.linkedin.com/in/nina-thomas/en
# st19900
# problem account
# https://nl.linkedin.com/in/vj-lachmansingh8674b815a
# st19900
# problem account
# https://nl.linkedin.com/in/prakaashrostam
# st19900
# problem account
# https://nl.linkedin.com/in/yamilet-gutierrez-a59264209
# st19900
# problem account
# https://nl.linkedin.com/in/karen-du-preez-0220b655
# st19900
# problem account
# https://nl.linkedin.com/in/amy-hereijgers-8991a7b7
# st19900
# problem account
# https://nl.linkedin.com/in/robert-goldmann/en
# st19900
# problem account
# https://nl.linkedin.com/in/altayeb-albarazani-b524b1224
# st19900
# problem account
# https://nl.linkedin.com/in/malissa-blackman
# st19900
# problem account
# https://nl.linkedin.com/in/patrice-stephen-7b02618b
# st19900
# problem account
# https://nl.linkedin.com/in/sidney-van-houts-624234187
# st19900
# problem account
# https://nl.linkedin.com/in/ingridtappin
# st19900
# problem account
# https://nl.linkedin.com/in/perry-oosterlee-0818b7104
# st19900
# problem account
# https://nl.linkedin.com/in/s-jhinkoe-3a975123?trk=public_profile_browsemap
# st19900
# problem account
# https://nl.linkedin.com/in/julianne-lemmens-a5891616
# st19900
# problem account
# https://nl.linkedin.com/in/tamara-gario
# st19900
# problem account
# https://nl.linkedin.com/in/rob-sijmons-16aa351
# st19900
# problem account

# %%
from bs4 import BeautifulSoup
import time
from selenium.webdriver.chrome.options import Options
from selenium import webdriver
from selenium.webdriver.common.by import By
import pandas as pd

options = Options()
options.add_argument("user-data-dir=C:\\Users\\Username\\AppData\\Local\\Google\\Chrome\\User Data")
driver = webdriver.Chrome(options=options)
driver.get('https://www.crystalknows.com/app/ce/installed')
time.sleep(15)
import pandas as pd
list_studies=['Aarde, Economie en Duurzaamheid', 'art-history', 'biochemistry', 'biology']
for study in list_studies:
    dict_={}
    df = pd.read_csv(f'datas/linkedin_aaccount_links/{study}.csv')
    i=0
    for link in df.links[10:]:
        i+=1
        try: 
            link_enterong_button=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/div[1]/nav/div/div[1]/div/div[1]/div/input')
            link_enterong_button.click()
            link_enterong_button.clear()
            link_enterong_button.send_keys(link)
            time.sleep(8) 
        except Exception as e:
            print("problem account")
        try:                          # /html/body/div[2]/div/div/div[2]/div[1]/nav/div/div[1]/div/div[1]/div/div[2]/div/div/div/div/div[2]
            first_user=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/div[1]/nav/div/div[1]/div/div[1]/div/div[2]/div/div/div/div/div[2]')
            first_user.click()
            time.sleep(10)
            src = driver.page_source
            soup = BeautifulSoup(src, 'lxml')
            cs=soup.find('div', {'class':'styles_disc-pill-wrapper__aB3OJ'})
            # print(cs.text.strip())              
            math_cs[link]=cs.text.strip()       #styles_quality_dm_So styles_DI_sElCv
            # print(cs.text.strip())              #styles_container__BY0sl
        except Exception as e:
            math_cs[link]='nan'
            continue
        if i%10==0:
            try:
                dots=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/div[1]/nav/div/div/div/div[6]/div/div[1]/div[2]/div/div/div')
                dots.click()
                time.sleep(2)
                logout=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/div[1]/nav/div/div/div/div[6]/div/div[2]/div[6]/a')
                logout.click()
                time.sleep(5)
                signup=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div[3]/div/form/div[3]/div/a')
                signup.click()
                time.sleep(8)
                try:
                    cookies_button=driver.find_element(By.XPATH, '/html/body/div[2]/div/div[2]/div')
                    cookies_button.click()
                    time.sleep(2)
                    signup_button=driver.find_element(By.XPATH, '/html/body/div[3]/div/div/div[1]/nav/div/div/div[2]')
                    signup_button.click()
                except Exception as e:
                    print('Cookie button not found!')
                try:
                    first_name_input=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div/div[2]/div[1]/input')
                    first_name_input.click()
                    first_name_input.send_keys(f'Alibek+{str(i)}')
                except Exception as e:
                    print('first_name-->problem')
                try:
                    last_name_input=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div/div[2]/div[2]/input')
                    last_name_input.click()
                    last_name_input.send_keys(f'Aliyev{str(i)}')
                except Exception as e:
                    print('last_name-->problem')
                try:
                    comp_email_input=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div/div[3]/div/input')
                    comp_email_input.click()
                    comp_email_input.send_keys(f'{study[:2]}{str(i)}@acf.com')
                except Exception as e:
                    print('comp_email-->problem')
                try:
                    first_pass_input=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div/div[4]/div[1]/input')
                    first_pass_input.click()
                    first_pass_input.send_keys('Aa2301667')
                except Exception as e:
                    print('first_pass-->problem')
                try:    
                    sec_pass_input=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div/div[4]/div[2]/input')
                    sec_pass_input.click()
                    sec_pass_input.send_keys('Aa2301667')
                except Exception as e:
                    print('sec_pass-->problem')
                try:
                    agree_button=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div/div[5]/div/label/div/img')
                    agree_button.click()
                except Exception as e:
                    print('agree_button-->problem')
                try:
                    signup_button=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div/div[6]/button')
                    signup_button.click()
                    time.sleep(10)
                except Exception as e:
                    print('signup_button-->problem')
                try:
                    country_button=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[1]/div[2]/div/div[2]/img')
                    country_button.click()
                    first_country=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[1]/div[2]/div[2]/div[1]')
                    first_country.click()
                except Exception as e:
                    print('country_button-->problem')                                # second country    '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[1]/div[2]/div[2]/div[2]'

                try:
                    job_title_input=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[2]/input')
                    job_title_input.click()
                    job_title_input.send_keys('software engineer')
                except Exception as e:
                    print('job_title-->problem')
                try:    
                    my_department_input=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[2]/div[3]/div/div[2]')
                    my_department_input.click()
                    first_department=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[2]/div[3]/div[2]/div[1]')                              #  second department           '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[2]/div[3]/div[2]/div[2]'
                    first_department.click()
                except Exception as e:
                    print('department-->problem')
                try:    
                    my_company_input=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[3]/div[2]/div/input')
                    my_company_input.click()
                    my_company_input.send_keys(f'{study[:2]}')
                    first_company=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[3]/div[2]/div[2]/div[1]/div')
                    first_company.click()
                except Exception as e:
                    print('my_company-->problem') 
                try:    
                    next_button=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[2]/a')
                    next_button.click()
                    time.sleep(10)
                except Exception as e:
                    print('next_button-->problem')
            except Exception as e:
                print('cannot create new account!')
    df = pd.DataFrame({
    'links':list(dict_.keys()),
    'characters':list(dict_.values())
    })
    df.to_csv(f'datas/cs_values/{study}.csv', index=False)
