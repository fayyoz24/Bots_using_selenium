# %%
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from selenium import webdriver
import time
import pandas as pd
from bs4 import BeautifulSoup
options = Options()
options.add_argument("user-data-dir=C:/Users/dell/AppData/Local/Google/Chrome/User Data/Profile 1")
                                                        #C:\Users\fayyo\Downloads\chromedriver-win32.zip\chromedriver-win32
driver = webdriver.Chrome(options=options,executable_path='C:/Users/dell/OneDrive/Desktop/chromedriver-win64/chromedriver.exe')
# country names
list_items = [
    "Reykjavik",
    "Kopavogur",
    "Hafnarfjordur",
    "Akureyri",
    "Reykjanesbær",
    "Selfoss",
    "Njardvik",
    "Akranes",
    "Egilsstadir",
    "Mosfellsbær",
    "Borgarnes",
    "Husavik",
    "Saudarkrokur",
    "Olafsvik",
    "Fjarðabyggð",
    "Seltjarnarnes",
    "Grindavik",
    "Hveragerdi",
    "Sandgerdi",
    "Vogar",
    "Stykkisholmur",
    "Seydisfjordur",
    "Neskaupstadur",
    "Hornafjordur",
    "Djupivogur",
    "Vopnafjordur",
    "Stokkseyri",
    "Hella",
    "Laugarvatn",
    "Fludir",
    "Hvolsvöllur",
    "Skogar",
    "Vik",
    "Kirkjubaejarklaustur",
    "Hofn",
    "Vatnajokull National Park",
    "Reykjahlid",
    "Husavik",
    "Egilsstadir",
    "Seydisfjordur",
    "Neskaupstadur",
    "Hornafjordur",
    "Djupivogur",
    "Vopnafjordur",
    "Seydisfjordur",
    "Reykjahlid",
    "Siglufjordur",
    "Akureyri",
    "Dalvik",
    "Olafsfjordur",
    "Hrisey",
    "Husavik",
    "Grenivik",
    "Hofsos",
    "Varmahlid",
    "Holar",
    "Blonduos",
    "Saudarkrokur",
    "Varmahlid",
    "Sauðárkrókur",
    "Hof",
    "Akranes",
    "Borgarnes",
    "Grundarfjordur",
    "Olafsvik",
    "Stykkisholmur",
    "Hellissandur",
    "Rif",
    "Hellnar",
    "Budir",
    "Arnarstapi",
    "Hellissandur",
    "Hnifsdalur",
    "Isafjordur",
    "Bolungarvik",
    "Sudureyri",
    "Flateyri",
    "Thingeyri",
    "Holt",
    "Hvanneyri",
    "Bifrost",
    "Reykholt",
    "Hvammstangi",
    "Blonduos",
    "Laugarbakki",
    "Holmavik",
    "Drangsnes",
    "Bildudalur",
    "Talknafjordur",
    "Patreksfjordur",
    "Latrabjarg",
    "Bargi",
    "Stað",
    "Breidavik",
    "Raudisandur",
    "Reykholar",
    "Talafjordur",
    "Flókalundur",
    "Bíldudalur",
    "Tálknafjörður",
    "Patreksfjörður",
    "Látrabjarg",
    "Vogur",
    "Dyrafjordur",
    "Þingeyri",
    "Bolungarvik",
    "Súðavík",
    "Ísafjörður",
    "Hornstrandir",
    "Mjóifjörður",
    "Neskaupstaður",
    "Fáskrúðsfjörður",
    "Reyðarfjörður",
    "Eskifjörður",
    "Seyðisfjörður",
    "Vopnafjörður",
    "Djúpivogur",
    "Höfn",
    "Stöðvarfjörður",
    "Breiðdalsvík",
    "Fellabær",
    "Egilsstaðir",
    "Hallormsstaður",
    "Fáskrúðsfjörður",
    "Möðrudalur",
    "Egilsstaðir",
    "Valþjófsstaður",
    "Breiðdalsvík",
    "Fellabær",
    "Seyðisfjörður",
    "Vestmannaeyjar",
    "Heimaey",
    "Vogur",
    "Djupivogur",
    "Kopasker",
    "Raufarhöfn",
    "Þórshöfn",
    "Melrakkaslétta",
    "Langanesbyggð",
    "Kálfafell",
    "Vopnafjardarhreppur",
    "Borgarfjordur eystri",
    "Hornafjordur",
    "Horn",
    "Djupivogur",
    "Kopasker",
    "Raufarhofn",
    "Thorshofn",
    "Melrakkasletta",
    "Langanesbyggd",
    "Kalfafell",
    "Vopnafjardarhreppur",
    "Borgarfjordur eystra",
    "Faskrudsfjordur",
    "Breiddalsvik",
    "Fellabaer",
    "Seydisfjordur",
    "Vestmannaeyjar",
    "Heimaey",
    "Vatnajokull National Park",
    "Hofn",
    "Djupivogur",
    "Kopasker",
    "Raufarhofn",
    "Thorshofn",
    "Melrakkasletta",
    "Langanesbyggd",
    "Kalfafell",
    "Vopnafjardarhreppur",
    "Borgarfjordur eystra",
    "Faskrudsfjordur",
    "Breiddalsvik",
    "Fellabaer",
    "Seydisfjordur",
    "Hornafjordur",
    "Hofn",
    "Djupivogur",
    "Kopasker",
    "Raufarhofn",
    "Thor"
]
for item  in list_items[:]:
    links = [] # save links here
    for study in ['math', 'physics']:
        driver.get(f'https://www.google.com/search?q=site:nl.linkedin.com/in/+AND+%22{item}+AND+%22{study}')
        time.sleep(5) # to make slower 
        n=30
        while n > 0:
            time.sleep(5)
            print("here")
            initialScroll = 0
            finalScroll = 1000
            start = time.time()
            while True:
                driver.execute_script(f"window.scrollTo({initialScroll}, {finalScroll})")
                initialScroll = finalScroll
                finalScroll += 1000
                time.sleep(3)
                end = time.time()
                if round(end - start) > 25:
                    break
            src = driver.page_source
            soup = BeautifulSoup(src, 'lxml')
            linksed_links=soup.find_all("a", {"jsname":"UWckNb"})
            for i in linksed_links:
                links.append(i.get('href').split("?")[0])
            try:
                next_button = driver.find_element(By.XPATH, '//*[@id="pnnext"]') # clicking next button 
                next_button.click()
            except Exception as e:
                driver.get(f'https://www.google.com/search?q=site:nl.linkedin.com/in/+AND+%22{item}+AND+%22{study}')
                n=1
                # print("")
            # print(f'{n} pages left!')
            n -= 1
        df = pd.DataFrame({
            "links":links
        })
        df1=pd.read_csv('datas/Ismatulla_links/data_Ismatulla4.csv')
        df_sum=pd.concat([df1, df], axis=0, ignore_index=True)
        df_sum = df_sum.drop_duplicates()
        df_sum.to_csv(f'datas/Ismatulla_links/data_Ismatulla4.csv', index=False)
        print(f'I am done ---> {item}')
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_6140\494359207.py:10: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(options=options,executable_path='C:/Users/dell/OneDrive/Desktop/chromedriver-win64/chromedriver.exe')
# here
# I am done ---> Reykjavik
# here
# I am done ---> Reykjavik
# here
# I am done ---> Kopavogur
# here
# I am done ---> Kopavogur
# here
# I am done ---> Hafnarfjordur
# here
# I am done ---> Hafnarfjordur
# here
# I am done ---> Akureyri
# here
# I am done ---> Akureyri
# here
# I am done ---> Reykjanesbær
# here
# I am done ---> Reykjanesbær
# here
# I am done ---> Selfoss
# here
# I am done ---> Selfoss
# here
# I am done ---> Njardvik
# here
# I am done ---> Njardvik
# here
# I am done ---> Akranes
# here
# I am done ---> Akranes
# here
# I am done ---> Egilsstadir
# here
# I am done ---> Egilsstadir
# here
# I am done ---> Mosfellsbær
# here
# I am done ---> Mosfellsbær
# here
# I am done ---> Borgarnes
# here
# I am done ---> Borgarnes
# here
# I am done ---> Husavik
# here
# I am done ---> Husavik
# here
# I am done ---> Saudarkrokur
# here
# I am done ---> Saudarkrokur
# here
# I am done ---> Olafsvik
# here
# I am done ---> Olafsvik
# here
# I am done ---> Fjarðabyggð
# here
# I am done ---> Fjarðabyggð
# here
# I am done ---> Seltjarnarnes
# here
# I am done ---> Seltjarnarnes
# here
# I am done ---> Grindavik
# here
# I am done ---> Grindavik
# here
# I am done ---> Hveragerdi
# here
# I am done ---> Hveragerdi
# here
# I am done ---> Sandgerdi
# here
# I am done ---> Sandgerdi
# here
# I am done ---> Vogar
# here
# I am done ---> Vogar
# here
# I am done ---> Stykkisholmur
# here
# I am done ---> Stykkisholmur
# here
# I am done ---> Seydisfjordur
# here
# I am done ---> Seydisfjordur
# here
# I am done ---> Neskaupstadur
# here
# I am done ---> Neskaupstadur
# here
# I am done ---> Hornafjordur
# here
# I am done ---> Hornafjordur
# here
# I am done ---> Djupivogur
# here
# I am done ---> Djupivogur
# here
# I am done ---> Vopnafjordur
# here
# I am done ---> Vopnafjordur
# here
# I am done ---> Stokkseyri
# here
# I am done ---> Stokkseyri
# here
# I am done ---> Hella
# here
# I am done ---> Hella
# here
# I am done ---> Laugarvatn
# here
# I am done ---> Laugarvatn
# here
# I am done ---> Fludir
# here
# I am done ---> Fludir
# here
# I am done ---> Hvolsvöllur
# here
# I am done ---> Hvolsvöllur
# here
# I am done ---> Skogar
# here
# I am done ---> Skogar
# here
# I am done ---> Vik
# here
# I am done ---> Vik
# here
# I am done ---> Kirkjubaejarklaustur
# here
# I am done ---> Kirkjubaejarklaustur
# here
# I am done ---> Hofn
# here
# I am done ---> Hofn
# here
# I am done ---> Vatnajokull National Park
# here
# I am done ---> Vatnajokull National Park
# here
# I am done ---> Reykjahlid
# here
# I am done ---> Reykjahlid
# here
# I am done ---> Husavik
# here
# I am done ---> Husavik
# here
# I am done ---> Egilsstadir
# here
# I am done ---> Egilsstadir
# here
# I am done ---> Seydisfjordur
# here
# I am done ---> Seydisfjordur
# here
# I am done ---> Neskaupstadur
# here
# I am done ---> Neskaupstadur
# here
# I am done ---> Hornafjordur
# here
# I am done ---> Hornafjordur
# here
# I am done ---> Djupivogur
# here
# I am done ---> Djupivogur
# here
# I am done ---> Vopnafjordur
# here
# I am done ---> Vopnafjordur
# here
# I am done ---> Seydisfjordur
# here
# I am done ---> Seydisfjordur
# here
# I am done ---> Reykjahlid
# here
# I am done ---> Reykjahlid
# here
# I am done ---> Siglufjordur
# here
# I am done ---> Siglufjordur
# here
# I am done ---> Akureyri
# here
# I am done ---> Akureyri
# here
# I am done ---> Dalvik
# here
# I am done ---> Dalvik
# here
# I am done ---> Olafsfjordur
# here
# I am done ---> Olafsfjordur
# here
# I am done ---> Hrisey
# here
# I am done ---> Hrisey
# here
# I am done ---> Husavik
# here
# I am done ---> Husavik
# here
# I am done ---> Grenivik
# here
# I am done ---> Grenivik
# here
# I am done ---> Hofsos
# here
# I am done ---> Hofsos
# here
# I am done ---> Varmahlid
# here
# I am done ---> Varmahlid
# here
# I am done ---> Holar
# here
# I am done ---> Holar
# here
# I am done ---> Blonduos
# here
# I am done ---> Blonduos
# here
# I am done ---> Saudarkrokur
# here
# I am done ---> Saudarkrokur
# here
# I am done ---> Varmahlid
# here
# I am done ---> Varmahlid
# here
# I am done ---> Sauðárkrókur
# here
# I am done ---> Sauðárkrókur
# here
# I am done ---> Hof
# here
# I am done ---> Hof
# here
# I am done ---> Akranes
# here
# I am done ---> Akranes
# here
# I am done ---> Borgarnes
# here
# I am done ---> Borgarnes
# here
# I am done ---> Grundarfjordur
# here
# I am done ---> Grundarfjordur
# here
# I am done ---> Olafsvik
# here
# I am done ---> Olafsvik
# here
# I am done ---> Stykkisholmur
# here
# I am done ---> Stykkisholmur
# here
# I am done ---> Hellissandur
# here
# I am done ---> Hellissandur
# here
# I am done ---> Rif
# here
# I am done ---> Rif
# here
# I am done ---> Hellnar
# here
# I am done ---> Hellnar
# here
# I am done ---> Budir
# here
# I am done ---> Budir
# here
# I am done ---> Arnarstapi
# here
# I am done ---> Arnarstapi
# here
# I am done ---> Hellissandur
# here
# I am done ---> Hellissandur
# here
# I am done ---> Hnifsdalur
# here
# I am done ---> Hnifsdalur
# here
# I am done ---> Isafjordur
# here
# I am done ---> Isafjordur
# here
# I am done ---> Bolungarvik
# here
# I am done ---> Bolungarvik
# here
# I am done ---> Sudureyri
# here
# I am done ---> Sudureyri
# here
# I am done ---> Flateyri
# here
# I am done ---> Flateyri
# here
# I am done ---> Thingeyri
# here
# I am done ---> Thingeyri
# here
# I am done ---> Holt
# here
# I am done ---> Holt
# here
# I am done ---> Hvanneyri
# here
# I am done ---> Hvanneyri
# here
# I am done ---> Bifrost
# here
# I am done ---> Bifrost
# here
# I am done ---> Reykholt
# here
# I am done ---> Reykholt
# here
# I am done ---> Hvammstangi
# here
# I am done ---> Hvammstangi
# here
# I am done ---> Blonduos
# here
# I am done ---> Blonduos
# here
# I am done ---> Laugarbakki
# here
# I am done ---> Laugarbakki
# here
# I am done ---> Holmavik
# here
# I am done ---> Holmavik
# here
# I am done ---> Drangsnes
# here
# I am done ---> Drangsnes
# here
# I am done ---> Bildudalur
# here
# I am done ---> Bildudalur
# here
# I am done ---> Talknafjordur
# here
# I am done ---> Talknafjordur
# here
# I am done ---> Patreksfjordur
# here
# I am done ---> Patreksfjordur
# here
# I am done ---> Latrabjarg
# here
# I am done ---> Latrabjarg
# here
# I am done ---> Bargi
# here
# I am done ---> Bargi
# here
# I am done ---> Stað
# here
# I am done ---> Stað
# here
# I am done ---> Breidavik
# here
# I am done ---> Breidavik
# here
# I am done ---> Raudisandur
# here
# I am done ---> Raudisandur
# here
# I am done ---> Reykholar
# here
# I am done ---> Reykholar
# here
# I am done ---> Talafjordur
# here
# I am done ---> Talafjordur
# here
# I am done ---> Flókalundur
# here
# I am done ---> Flókalundur
# here
# I am done ---> Bíldudalur
# here
# I am done ---> Bíldudalur
# here
# I am done ---> Tálknafjörður
# here
# I am done ---> Tálknafjörður
# here
# I am done ---> Patreksfjörður
# here
# I am done ---> Patreksfjörður
# here
# I am done ---> Látrabjarg
# here
# I am done ---> Látrabjarg
# here
# I am done ---> Vogur
# here
# I am done ---> Vogur
# here
# I am done ---> Dyrafjordur
# here
# I am done ---> Dyrafjordur
# here
# I am done ---> Þingeyri
# here
# I am done ---> Þingeyri
# here
# I am done ---> Bolungarvik
# here
# I am done ---> Bolungarvik
# here
# I am done ---> Súðavík
# here
# I am done ---> Súðavík
# here
# I am done ---> Ísafjörður
# here
# I am done ---> Ísafjörður
# here
# I am done ---> Hornstrandir
# here
# I am done ---> Hornstrandir
# here
# I am done ---> Mjóifjörður
# here
# I am done ---> Mjóifjörður
# here
# I am done ---> Neskaupstaður
# here
# I am done ---> Neskaupstaður
# here
# I am done ---> Fáskrúðsfjörður
# here
# I am done ---> Fáskrúðsfjörður
# here
# I am done ---> Reyðarfjörður
# here
# I am done ---> Reyðarfjörður
# here
# I am done ---> Eskifjörður
# here
# I am done ---> Eskifjörður
# here
# I am done ---> Seyðisfjörður
# here
# I am done ---> Seyðisfjörður
# here
# I am done ---> Vopnafjörður
# here
# I am done ---> Vopnafjörður
# here
# I am done ---> Djúpivogur
# here
# I am done ---> Djúpivogur
# here
# I am done ---> Höfn
# here
# I am done ---> Höfn
# here
# I am done ---> Stöðvarfjörður
# here
# I am done ---> Stöðvarfjörður
# here
# I am done ---> Breiðdalsvík
# here
# I am done ---> Breiðdalsvík
# here
# I am done ---> Fellabær
# here
# I am done ---> Fellabær
# here
# I am done ---> Egilsstaðir
# here
# I am done ---> Egilsstaðir
# here
# I am done ---> Hallormsstaður
# here
# I am done ---> Hallormsstaður
# here
# I am done ---> Fáskrúðsfjörður
# here
# I am done ---> Fáskrúðsfjörður
# here
# I am done ---> Möðrudalur
# here
# I am done ---> Möðrudalur
# here

# %%
clean_url
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 clean_url
#
# NameError: name 'clean_url' is not defined

# %%
df = pd.DataFrame({
    "links":links
})
df1=pd.read_csv('datas/Ismatulla_links/data_Ismatulla.csv')
df_sum=pd.concat([df1, df], axis=0, ignore_index=True)
df_sum = df_sum.drop_duplicates()
df_sum.to_csv(f'datas/Ismatulla_links/data_Ismatulla.csv', index=False)
print(f'I am done ---> {item}')
# Out:
# I am done ---> Algeria

# %%
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from selenium import webdriver
import time
import pandas as pd

options = Options()
options.add_argument("user-data-dir=C:/Users/dell/AppData/Local/Google/Chrome/User Data/Profile 18") 
driver = webdriver.Chrome(options=options,executable_path='C:/Users/dell/OneDrive/Desktop/chromedriver-win64/chromedriver.exe')  
# options.add_argument("user-data-dir=C:\\Users\\Username\\AppData\\Local\\Google\\Chrome\\User Data")
# driver = webdriver.Chrome(options=options)
# 'Mathematics and Bachelor words are used as a default, it is changeble
for j in range(417,418):
    driver.get(f'https://www.google.com/search?q=site:nl.linkedin.com/in/ Eritrea')
    time.sleep(10) # to make slower 
    # n is the number of pages
    links = [] # save links here
    n=30
    while n > 0:
        time.sleep(5)
        for i in range(1, 11): # google uses paginator, every page has 10 urls
            time.sleep(6)
            try:    #/html/body/div[6]/div/div[13]/div/div[2]/div[2]/div/div/div[1]/div/div/div[1]/div/div/a
                    #/html/body/div[6]/div/div[13]/div/div[2]/div[2]/div/div/div[4]/div/div/div[1]/div/div/a
                    #/html/body/div[6]/div/div[13]/div/div[2]/div[2]/div/div/div[9]/div/div/div/div[1]/div/div/a
                elems = driver.find_elements(By.XPATH, '/html/body/div[6]/div/div[12]/div/div[2]/div[2]/div/div/div['+str(i)+']/div/div/div[1]/div/div/a')
                for elem in elems:                     #/html/body/div[6]/div/div[12]/div/div[2]/div[2]/div/div/div[3]/div/div/div[1]/div/div/a
                                                        #/html/body/div[6]/div/div[12]/div/div[2]/div[2]/div/div/div[2]/div/div/div[1]/div/div/a
                    clean_url = elem.get_attribute("href") # extracting url 
                    base_url = "linkedin.com/in/"
                    if clean_url.find(base_url) != -1 and '%' not in clean_url: # sometimes google gives no Ln urls, so clean it
                        links.append(clean_url)
                        print(f"url is --->{clean_url}")
            except Exception as e:
                print(e)
                pass
        try:
            next_button = driver.find_element(By.XPATH, '//*[@id="pnnext"]') # clicking next button 
            next_button.click()
        except Exception as e:
            print(e)
        print(f'{n} pages left!')
        n -= 1
    df = pd.DataFrame({
        "links":links
    })
    df = df.drop_duplicates()
    df.to_csv(f'datas/linkedin_links_29_06/data{str(j)}.csv', index=False)
    print(f'I am done ---> {str(j)}')
    print(f'if there is a problem, start with {str(j+1)}')
# Out:
# C:\Users\fayyo\AppData\Local\Temp\ipykernel_7384\4203283928.py:9: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(options=options,executable_path='C:/Users/dell/OneDrive/Desktop/chromedriver-win64/chromedriver.exe')
# Incompatible release of chromedriver (version 111.0.5563.64) detected in PATH: c:\Users\GitHub\Bots_using_selenium\linkedin_data_Scraping\chromedriver.exe
# ---------------------------------------------------------------------------
# SessionNotCreatedException                Traceback (most recent call last)
# Cell In[2], line 9
#       7 options = Options()
#       8 options.add_argument("user-data-dir=C:/Users/dell/AppData/Local/Google/Chrome/User Data/Profile 18")
# ----> 9 driver = webdriver.Chrome(options=options,executable_path='C:/Users/dell/OneDrive/Desktop/chromedriver-win64/chromedriver.exe')
#      10 # options.add_argument("user-data-dir=C:\\Users\\Username\\AppData\\Local\\Google\\Chrome\\User Data")
#      11 # driver = webdriver.Chrome(options=options)
#      12 # 'Mathematics and Bachelor words are used as a default, it is changeble
#      13 for j in range(417,418):
#
# File c:\Users\GitHub\Bots_using_selenium\venv\lib\site-packages\selenium\webdriver\chrome\webdriver.py:84, in WebDriver.__init__(self, executable_path, port, options, service_args, desired_capabilities, service_log_path, chrome_options, service, keep_alive)
#      81     service = Service(executable_path, port, service_args, service_log_path)
#      82 service.path = DriverFinder.get_path(service, options)
# ---> 84 super().__init__(
#      85     DesiredCapabilities.CHROME["browserName"],
#      86     "goog",
#      87     port,
#      88     options,
#      89     service_args,
#      90     desired_capabilities,
#      91     service_log_path,
#      92     service,
#      93     keep_alive,
#      94 )
#
# File c:\Users\GitHub\Bots_using_selenium\venv\lib\site-packages\selenium\webdriver\chromium\webdriver.py:104, in ChromiumDriver.__init__(self, browser_name, vendor_prefix, port, options, service_args, desired_capabilities, service_log_path, service, keep_alive)
#     101 self.service.start()
#     103 try:
# --> 104     super().__init__(
#     105         command_executor=ChromiumRemoteConnection(
#     106             remote_server_addr=self.service.service_url,
#     107             browser_name=browser_name,
#     108             vendor_prefix=vendor_prefix,
#     109             keep_alive=keep_alive,
#     110             ignore_proxy=_ignore_proxy,
#     111         ),
#     112         options=options,
#     113     )
#     114 except Exception:
#     115     self.quit()
#
# File c:\Users\GitHub\Bots_using_selenium\venv\lib\site-packages\selenium\webdriver\remote\webdriver.py:286, in WebDriver.__init__(self, command_executor, desired_capabilities, browser_profile, proxy, keep_alive, file_detector, options)
#     284 self._authenticator_id = None
#     285 self.start_client()
# --> 286 self.start_session(capabilities, browser_profile)
#
# File c:\Users\GitHub\Bots_using_selenium\venv\lib\site-packages\selenium\webdriver\remote\webdriver.py:378, in WebDriver.start_session(self, capabilities, browser_profile)
#     376 w3c_caps = _make_w3c_caps(capabilities)
#     377 parameters = {"capabilities": w3c_caps}
# --> 378 response = self.execute(Command.NEW_SESSION, parameters)
#     379 if "sessionId" not in response:
#     380     response = response["value"]
#
# File c:\Users\GitHub\Bots_using_selenium\venv\lib\site-packages\selenium\webdriver\remote\webdriver.py:440, in WebDriver.execute(self, driver_command, params)
#     438 response = self.command_executor.execute(driver_command, params)
#     439 if response:
# --> 440     self.error_handler.check_response(response)
#     441     response["value"] = self._unwrap_value(response.get("value", None))
#     442     return response
#
# File c:\Users\GitHub\Bots_using_selenium\venv\lib\site-packages\selenium\webdriver\remote\errorhandler.py:245, in ErrorHandler.check_response(self, response)
#     243         alert_text = value["alert"].get("text")
#     244     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 245 raise exception_class(message, screen, stacktrace)
#
# SessionNotCreatedException: Message: session not created: This version of ChromeDriver only supports Chrome version 114
# Current browser version is 116.0.5845.97 with binary path C:\Program Files\Google\Chrome\Application\chrome.exe
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x00FAA813+48355]
# 	(No symbol) [0x00F3C4B1]
# 	(No symbol) [0x00E45358]
# 	(No symbol) [0x00E661AC]
# 	(No symbol) [0x00E61EF3]
# 	(No symbol) [0x00E60579]
# 	(No symbol) [0x00E90C55]
# 	(No symbol) [0x00E9093C]
# 	(No symbol) [0x00E8A536]
# 	(No symbol) [0x00E682DC]
# 	(No symbol) [0x00E693DD]
# 	GetHandleVerifier [0x0120AABD+2539405]
# 	GetHandleVerifier [0x0124A78F+2800735]
# 	GetHandleVerifier [0x0124456C+2775612]
# 	GetHandleVerifier [0x010351E0+616112]
# 	(No symbol) [0x00F45F8C]
# 	(No symbol) [0x00F42328]
# 	(No symbol) [0x00F4240B]
# 	(No symbol) [0x00F34FF7]
# 	BaseThreadInitThunk [0x768800C9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77947B1E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77947AEE+238]
