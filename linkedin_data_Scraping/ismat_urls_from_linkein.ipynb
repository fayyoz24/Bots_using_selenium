# %%
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from selenium import webdriver
import time
import pandas as pd
from bs4 import BeautifulSoup
options = Options()
options.add_argument("user-data-dir=C:/Users/dell/AppData/Local/Google/Chrome/User Data/Profile 1")
                                                        #C:\Users\fayyo\Downloads\chromedriver-win32.zip\chromedriver-win32
driver = webdriver.Chrome(options=options,executable_path='C:/Users/dell/OneDrive/Desktop/chromedriver-win64/chromedriver.exe')
# country names
list_items = [
    "Zurich (Zürich)",
    "Geneva (Genève)",
    "Bern (Berne)",
    "Lausanne",
    "Basel",
    "Lucerne (Luzern)",
    "St. Gallen",
    "Lugano",
    "Biel/Bienne",
    "Thun",
    "Köniz",
    "La Chaux-de-Fonds",
    "Fribourg (Freiburg)",
    "Schaffhausen",
    "Chur",
    "Vernier",
    "Sion",
    "Uster",
    "Neuchâtel",
    "Emmen",
    "Zug",
    "Yverdon-les-Bains",
    "Dübendorf",
    "Kriens",
    "Rapperswil-Jona",
    "Riehen",
    "Montreux",
    "Kreuzlingen",
    "Risch-Rotkreuz",
    "Olten",
    "Renens",
    "Meyrin",
    "Allschwil",
    "Bellinzona",
    "Vevey",
    "Monthey",
    "Locarno",
    "Wetzikon",
    "Freienbach",
    "Brig-Glis",
    "Cham",
    "Muttenz",
    "Lyss",
    "Horgen",
    "Altstätten",
    "Pully",
    "Burgdorf",
    "Spreitenbach",
    "Horw",
    "Wil",
    "Nyon",
    "Herisau",
    "Aarau",
    "Grenchen",
    "Carouge",
    "Zofingen",
    "Kloten",
    "Pratteln",
    "Regensdorf",
    "Baden",
    "Baden",
    "Liestal",
    "Wohlen",
    "Adliswil",
    "Hochdorf",
    "Möhlin",
    "Davos",
    "Bulle",
    "Köniz",
    "Birsfelden",
    "Gland",
    "Plan-les-Ouates",
    "Aesch",
    "Weinfelden",
    "Bellinzona",
    "Chêne-Bougeries",
    "Lachen",
    "Schlieren",
    "Oberwil",
    "Muri bei Bern",
    "Val-de-Travers",
    "Gland",
    "Bremgarten",
    "Arbon",
    "Münsingen",
    "Flawil",
    "Sursee",
    "Meilen",
    "Steffisburg",
    "Rothrist",
    "Thônex",
    "Männedorf",
    "Bassersdorf",
    "Veyrier",
    "Pfäffikon",
    "Weinfelden",
    "Brugg",
    "Möhlin",
    "Aubonne",
    "Biasca",
    "Ecublens",
    "Untersiggenthal",
    "Neuhausen am Rheinfall",
    "Thalwil",
    "Val-de-Ruz",
    "Le Grand-Saconnex",
    "Neuhausen am Rheinfall",
    "Thalwil",
    "Val-de-Ruz",
    "Le Grand-Saconnex",
    "Lancy",
    "Wädenswil",
    "Montreux",
    "Delémont",
    "Burgdorf",
    "Littau",
    "Olten",
    "Riehen",
    "Männedorf",
    "Renens",
    "Gossau",
    "Peseux",
    "Aarberg",
    "Porrentruy",
    "Echallens",
    "Veyrier",
    "Val-de-Travers",
    "Morges",
    "Romanshorn",
    "Naters",
    "Aubonne",
    "Nyon",
    "Möhlin",
    "Aubonne",
    "Biasca",
    "Ecublens",
    "Untersiggenthal",
    "Nyon",
    "Möhlin",
    "Aubonne",
    "Biasca",
    "Ecublens",
    "Untersiggenthal",
    "Neuhausen am Rheinfall",
    "Thalwil",
    "Val-de-Ruz",
    "Le Grand-Saconnex",
    "Lancy",
    "Wädenswil",
    "Montreux",
    "Delémont",
    "Burgdorf",
    "Littau",
    "Olten",
    "Riehen",
    "Männedorf",
    "Renens",
    "Gossau",
    "Peseux",
    "Aarberg",
    "Porrentruy",
    "Echallens",
    "Veyrier",
    "Val-de-Travers",
    "Morges",
    "Romanshorn",
    "Naters",
    "Aubonne",
    "Nyon",
    "Val-de-Travers",
    "Morges",
    "Romanshorn",
    "Naters",
    "Aubonne",
    "Nyon",
    "Morges",
    "Romanshorn",
    "Naters",
    "Aubonne",
    "Nyon",
    "La Tour-de-Peilz",
    "Schönenwerd",
    "Monthey",
    "Flawil",
    "Sursee",
    "Meilen",
    "Steffisburg",
    "Rothrist",
    "Thônex",
    "Männedorf",
    "Bassersdorf",
    "Veyrier",
    "Pfäffikon",
    "Weinfelden",
    "Brugg",
    "Möhlin",
    "Aubonne",
    "Biasca",
    "Ecublens",
    "Untersiggenthal",
    "Neuhausen am Rheinfall",
    "Thalwil",
    "Val-de-Ruz",
    "Le Grand-Saconnex",
    "Lancy",
    "Wädenswil",
    "Montreux",
    "Delémont",
    "Burgdorf",
    "Littau",
    "Olten",
    "Riehen",
    "Männedorf",
    "Renens",
    "Gossau",
    "Peseux",
    "Aarberg",
    "Porrentruy",
    "Echallens",
    "Veyrier",
    "Val-de-Travers",
    "Morges",
    "Romanshorn",
    "Naters",
    "Aubonne",
    "Nyon",
    "Val-de-Travers",
    "Morges",
    "Romanshorn",
    "Naters",
    "Aubonne",
    "Nyon",
    "La Tour-de-Peilz",
    "Schönenwerd",
    "Monthey",
    "Flawil",
    "Sursee",
    "Meilen",
    "Steffisburg",
    "Rothrist",
    "Thônex",
    "Männedorf",
    "Bassersdorf"
]
for item  in list_items[:]:
    links = [] # save links here
    for study in ['math', 'physics']:
        driver.get(f'https://www.google.com/search?q=site:nl.linkedin.com/in/+AND+%22{item}+AND+%22{study}')
        time.sleep(5) # to make slower 
        n=30
        while n > 0:
            time.sleep(5)
            print("here")
            initialScroll = 0
            finalScroll = 1000
            start = time.time()
            while True:
                driver.execute_script(f"window.scrollTo({initialScroll}, {finalScroll})")
                initialScroll = finalScroll
                finalScroll += 1000
                time.sleep(3)
                end = time.time()
                if round(end - start) > 25:
                    break
            src = driver.page_source
            soup = BeautifulSoup(src, 'lxml')
            linksed_links=soup.find_all("a", {"jsname":"UWckNb"})
            for i in linksed_links:
                links.append(i.get('href').split("?")[0])
            try:
                next_button = driver.find_element(By.XPATH, '//*[@id="pnnext"]') # clicking next button 
                next_button.click()
            except Exception as e:
                driver.get(f'https://www.google.com/search?q=site:nl.linkedin.com/in/+AND+%22{item}+AND+%22{study}')
                n=1
                # print("")
            # print(f'{n} pages left!')
            n -= 1
        df = pd.DataFrame({
            "links":links
        })
        df1=pd.read_csv('datas/Ismatulla_links/data_Ismatulla4.csv')
        df_sum=pd.concat([df1, df], axis=0, ignore_index=True)
        df_sum = df_sum.drop_duplicates()
        df_sum.to_csv(f'datas/Ismatulla_links/data_Ismatulla4.csv', index=False)
        print(f'I am done ---> {item}')
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_15964\3169379457.py:10: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(options=options,executable_path='C:/Users/dell/OneDrive/Desktop/chromedriver-win64/chromedriver.exe')
# here
# I am done ---> Zurich (Zürich)
# here
# I am done ---> Zurich (Zürich)
# here
# I am done ---> Geneva (Genève)
# here
# I am done ---> Geneva (Genève)
# here
# I am done ---> Bern (Berne)
# here
# I am done ---> Bern (Berne)
# here
# I am done ---> Lausanne
# here
# I am done ---> Lausanne
# here
# I am done ---> Basel
# here
# I am done ---> Basel
# here
# I am done ---> Lucerne (Luzern)
# here
# I am done ---> Lucerne (Luzern)
# here
# I am done ---> St. Gallen
# here
# I am done ---> St. Gallen
# here
# I am done ---> Lugano
# here
# I am done ---> Lugano
# here
# I am done ---> Biel/Bienne
# here
# I am done ---> Biel/Bienne
# here
# I am done ---> Thun
# here
# I am done ---> Thun
# here
# I am done ---> Köniz
# here
# I am done ---> Köniz
# here
# I am done ---> La Chaux-de-Fonds
# here
# I am done ---> La Chaux-de-Fonds
# here
# I am done ---> Fribourg (Freiburg)
# here
# I am done ---> Fribourg (Freiburg)
# here
# I am done ---> Schaffhausen
# here
# I am done ---> Schaffhausen
# here
# I am done ---> Chur
# here
# I am done ---> Chur
# here
# I am done ---> Vernier
# here
# I am done ---> Vernier
# here
# I am done ---> Sion
# here
# I am done ---> Sion
# here
# I am done ---> Uster
# here
# I am done ---> Uster
# here
# I am done ---> Neuchâtel
# here
# I am done ---> Neuchâtel
# here
# I am done ---> Emmen
# here
# I am done ---> Emmen
# here
# I am done ---> Zug
# here
# I am done ---> Zug
# here
# I am done ---> Yverdon-les-Bains
# here
# I am done ---> Yverdon-les-Bains
# here
# I am done ---> Dübendorf
# here
# I am done ---> Dübendorf
# here
# I am done ---> Kriens
# here
# I am done ---> Kriens
# here
# I am done ---> Rapperswil-Jona
# here
# I am done ---> Rapperswil-Jona
# here
# I am done ---> Riehen
# here
# I am done ---> Riehen
# here
# I am done ---> Montreux
# here
# I am done ---> Montreux
# here
# I am done ---> Kreuzlingen
# here
# I am done ---> Kreuzlingen
# here
# I am done ---> Risch-Rotkreuz
# here
# I am done ---> Risch-Rotkreuz
# here
# I am done ---> Olten
# here
# I am done ---> Olten
# here
# I am done ---> Renens
# here
# I am done ---> Renens
# here
# I am done ---> Meyrin
# here
# I am done ---> Meyrin
# here
# I am done ---> Allschwil
# here
# I am done ---> Allschwil
# here
# I am done ---> Bellinzona
# here
# I am done ---> Bellinzona
# here
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# c:\Users\dell\OneDrive\Desktop\selenium\Bots_using_selenium\linkedin_data_Scraping\ismat_urls_from_linkein.ipynb Cell 1 line 2
#     <a href='vscode-notebook-cell:/c%3A/Users/dell/OneDrive/Desktop/selenium/Bots_using_selenium/linkedin_data_Scraping/ismat_urls_from_linkein.ipynb#W0sZmlsZQ%3D%3D?line=267'>268</a> start = time.time()
#     <a href='vscode-notebook-cell:/c%3A/Users/dell/OneDrive/Desktop/selenium/Bots_using_selenium/linkedin_data_Scraping/ismat_urls_from_linkein.ipynb#W0sZmlsZQ%3D%3D?line=268'>269</a> while True:
# --> <a href='vscode-notebook-cell:/c%3A/Users/dell/OneDrive/Desktop/selenium/Bots_using_selenium/linkedin_data_Scraping/ismat_urls_from_linkein.ipynb#W0sZmlsZQ%3D%3D?line=269'>270</a>     driver.execute_script(f"window.scrollTo({initialScroll}, {finalScroll})")
#     <a href='vscode-notebook-cell:/c%3A/Users/dell/OneDrive/Desktop/selenium/Bots_using_selenium/linkedin_data_Scraping/ismat_urls_from_linkein.ipynb#W0sZmlsZQ%3D%3D?line=270'>271</a>     initialScroll = finalScroll
#     <a href='vscode-notebook-cell:/c%3A/Users/dell/OneDrive/Desktop/selenium/Bots_using_selenium/linkedin_data_Scraping/ismat_urls_from_linkein.ipynb#W0sZmlsZQ%3D%3D?line=271'>272</a>     finalScroll += 1000
#
# File c:\Users\dell\OneDrive\Desktop\selenium\Bots_using_selenium\venv\lib\site-packages\selenium\webdriver\remote\webdriver.py:500, in WebDriver.execute_script(self, script, *args)
#     497 converted_args = list(args)
#     498 command = Command.W3C_EXECUTE_SCRIPT
# --> 500 return self.execute(command, {"script": script, "args": converted_args})["value"]
#
# File c:\Users\dell\OneDrive\Desktop\selenium\Bots_using_selenium\venv\lib\site-packages\selenium\webdriver\remote\webdriver.py:440, in WebDriver.execute(self, driver_command, params)
#     438 response = self.command_executor.execute(driver_command, params)
#     439 if response:
# --> 440     self.error_handler.check_response(response)
#     441     response["value"] = self._unwrap_value(response.get("value", None))
#     442     return response
#
# File c:\Users\dell\OneDrive\Desktop\selenium\Bots_using_selenium\venv\lib\site-packages\selenium\webdriver\remote\errorhandler.py:245, in ErrorHandler.check_response(self, response)
#     243         alert_text = value["alert"].get("text")
#     244     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 245 raise exception_class(message, screen, stacktrace)
#
# NoSuchWindowException: Message: no such window: target window already closed
# from unknown error: web view not found
#   (Session info: chrome=116.0.5845.188)
# Stacktrace:
# 	GetHandleVerifier [0x00007FF7413A52A2+57122]
# 	(No symbol) [0x00007FF74131EA92]
# 	(No symbol) [0x00007FF7411EE3AB]
# 	(No symbol) [0x00007FF7411CE1B9]
# 	(No symbol) [0x00007FF74124B417]
# 	(No symbol) [0x00007FF74125E24F]
# 	(No symbol) [0x00007FF741246DB3]
# 	(No symbol) [0x00007FF74121D2B1]
# 	(No symbol) [0x00007FF74121E494]
# 	GetHandleVerifier [0x00007FF74164EF82+2849794]
# 	GetHandleVerifier [0x00007FF7416A1D24+3189156]
# 	GetHandleVerifier [0x00007FF74169ACAF+3160367]
# 	GetHandleVerifier [0x00007FF741436D06+653702]
# 	(No symbol) [0x00007FF74132A208]
# 	(No symbol) [0x00007FF7413262C4]
# 	(No symbol) [0x00007FF7413263F6]
# 	(No symbol) [0x00007FF7413167A3]
# 	BaseThreadInitThunk [0x00007FFB86127344+20]
# 	RtlUserThreadStart [0x00007FFB862626B1+33]

# %%
clean_url
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 clean_url
#
# NameError: name 'clean_url' is not defined

# %%
df = pd.DataFrame({
    "links":links
})
df1=pd.read_csv('datas/Ismatulla_links/data_Ismatulla.csv')
df_sum=pd.concat([df1, df], axis=0, ignore_index=True)
df_sum = df_sum.drop_duplicates()
df_sum.to_csv(f'datas/Ismatulla_links/data_Ismatulla.csv', index=False)
print(f'I am done ---> {item}')
# Out:
# I am done ---> Algeria

# %%
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from selenium import webdriver
import time
import pandas as pd

options = Options()
options.add_argument("user-data-dir=C:/Users/dell/AppData/Local/Google/Chrome/User Data/Profile 18") 
driver = webdriver.Chrome(options=options,executable_path='C:/Users/dell/OneDrive/Desktop/chromedriver-win64/chromedriver.exe')  
# options.add_argument("user-data-dir=C:\\Users\\Username\\AppData\\Local\\Google\\Chrome\\User Data")
# driver = webdriver.Chrome(options=options)
# 'Mathematics and Bachelor words are used as a default, it is changeble
for j in range(417,418):
    driver.get(f'https://www.google.com/search?q=site:nl.linkedin.com/in/ Eritrea')
    time.sleep(10) # to make slower 
    # n is the number of pages
    links = [] # save links here
    n=30
    while n > 0:
        time.sleep(5)
        for i in range(1, 11): # google uses paginator, every page has 10 urls
            time.sleep(6)
            try:    #/html/body/div[6]/div/div[13]/div/div[2]/div[2]/div/div/div[1]/div/div/div[1]/div/div/a
                    #/html/body/div[6]/div/div[13]/div/div[2]/div[2]/div/div/div[4]/div/div/div[1]/div/div/a
                    #/html/body/div[6]/div/div[13]/div/div[2]/div[2]/div/div/div[9]/div/div/div/div[1]/div/div/a
                elems = driver.find_elements(By.XPATH, '/html/body/div[6]/div/div[12]/div/div[2]/div[2]/div/div/div['+str(i)+']/div/div/div[1]/div/div/a')
                for elem in elems:                     #/html/body/div[6]/div/div[12]/div/div[2]/div[2]/div/div/div[3]/div/div/div[1]/div/div/a
                                                        #/html/body/div[6]/div/div[12]/div/div[2]/div[2]/div/div/div[2]/div/div/div[1]/div/div/a
                    clean_url = elem.get_attribute("href") # extracting url 
                    base_url = "linkedin.com/in/"
                    if clean_url.find(base_url) != -1 and '%' not in clean_url: # sometimes google gives no Ln urls, so clean it
                        links.append(clean_url)
                        print(f"url is --->{clean_url}")
            except Exception as e:
                print(e)
                pass
        try:
            next_button = driver.find_element(By.XPATH, '//*[@id="pnnext"]') # clicking next button 
            next_button.click()
        except Exception as e:
            print(e)
        print(f'{n} pages left!')
        n -= 1
    df = pd.DataFrame({
        "links":links
    })
    df = df.drop_duplicates()
    df.to_csv(f'datas/linkedin_links_29_06/data{str(j)}.csv', index=False)
    print(f'I am done ---> {str(j)}')
    print(f'if there is a problem, start with {str(j+1)}')
# Out:
# C:\Users\fayyo\AppData\Local\Temp\ipykernel_7384\4203283928.py:9: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(options=options,executable_path='C:/Users/dell/OneDrive/Desktop/chromedriver-win64/chromedriver.exe')
# Incompatible release of chromedriver (version 111.0.5563.64) detected in PATH: c:\Users\GitHub\Bots_using_selenium\linkedin_data_Scraping\chromedriver.exe
# ---------------------------------------------------------------------------
# SessionNotCreatedException                Traceback (most recent call last)
# Cell In[2], line 9
#       7 options = Options()
#       8 options.add_argument("user-data-dir=C:/Users/dell/AppData/Local/Google/Chrome/User Data/Profile 18")
# ----> 9 driver = webdriver.Chrome(options=options,executable_path='C:/Users/dell/OneDrive/Desktop/chromedriver-win64/chromedriver.exe')
#      10 # options.add_argument("user-data-dir=C:\\Users\\Username\\AppData\\Local\\Google\\Chrome\\User Data")
#      11 # driver = webdriver.Chrome(options=options)
#      12 # 'Mathematics and Bachelor words are used as a default, it is changeble
#      13 for j in range(417,418):
#
# File c:\Users\GitHub\Bots_using_selenium\venv\lib\site-packages\selenium\webdriver\chrome\webdriver.py:84, in WebDriver.__init__(self, executable_path, port, options, service_args, desired_capabilities, service_log_path, chrome_options, service, keep_alive)
#      81     service = Service(executable_path, port, service_args, service_log_path)
#      82 service.path = DriverFinder.get_path(service, options)
# ---> 84 super().__init__(
#      85     DesiredCapabilities.CHROME["browserName"],
#      86     "goog",
#      87     port,
#      88     options,
#      89     service_args,
#      90     desired_capabilities,
#      91     service_log_path,
#      92     service,
#      93     keep_alive,
#      94 )
#
# File c:\Users\GitHub\Bots_using_selenium\venv\lib\site-packages\selenium\webdriver\chromium\webdriver.py:104, in ChromiumDriver.__init__(self, browser_name, vendor_prefix, port, options, service_args, desired_capabilities, service_log_path, service, keep_alive)
#     101 self.service.start()
#     103 try:
# --> 104     super().__init__(
#     105         command_executor=ChromiumRemoteConnection(
#     106             remote_server_addr=self.service.service_url,
#     107             browser_name=browser_name,
#     108             vendor_prefix=vendor_prefix,
#     109             keep_alive=keep_alive,
#     110             ignore_proxy=_ignore_proxy,
#     111         ),
#     112         options=options,
#     113     )
#     114 except Exception:
#     115     self.quit()
#
# File c:\Users\GitHub\Bots_using_selenium\venv\lib\site-packages\selenium\webdriver\remote\webdriver.py:286, in WebDriver.__init__(self, command_executor, desired_capabilities, browser_profile, proxy, keep_alive, file_detector, options)
#     284 self._authenticator_id = None
#     285 self.start_client()
# --> 286 self.start_session(capabilities, browser_profile)
#
# File c:\Users\GitHub\Bots_using_selenium\venv\lib\site-packages\selenium\webdriver\remote\webdriver.py:378, in WebDriver.start_session(self, capabilities, browser_profile)
#     376 w3c_caps = _make_w3c_caps(capabilities)
#     377 parameters = {"capabilities": w3c_caps}
# --> 378 response = self.execute(Command.NEW_SESSION, parameters)
#     379 if "sessionId" not in response:
#     380     response = response["value"]
#
# File c:\Users\GitHub\Bots_using_selenium\venv\lib\site-packages\selenium\webdriver\remote\webdriver.py:440, in WebDriver.execute(self, driver_command, params)
#     438 response = self.command_executor.execute(driver_command, params)
#     439 if response:
# --> 440     self.error_handler.check_response(response)
#     441     response["value"] = self._unwrap_value(response.get("value", None))
#     442     return response
#
# File c:\Users\GitHub\Bots_using_selenium\venv\lib\site-packages\selenium\webdriver\remote\errorhandler.py:245, in ErrorHandler.check_response(self, response)
#     243         alert_text = value["alert"].get("text")
#     244     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 245 raise exception_class(message, screen, stacktrace)
#
# SessionNotCreatedException: Message: session not created: This version of ChromeDriver only supports Chrome version 114
# Current browser version is 116.0.5845.97 with binary path C:\Program Files\Google\Chrome\Application\chrome.exe
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x00FAA813+48355]
# 	(No symbol) [0x00F3C4B1]
# 	(No symbol) [0x00E45358]
# 	(No symbol) [0x00E661AC]
# 	(No symbol) [0x00E61EF3]
# 	(No symbol) [0x00E60579]
# 	(No symbol) [0x00E90C55]
# 	(No symbol) [0x00E9093C]
# 	(No symbol) [0x00E8A536]
# 	(No symbol) [0x00E682DC]
# 	(No symbol) [0x00E693DD]
# 	GetHandleVerifier [0x0120AABD+2539405]
# 	GetHandleVerifier [0x0124A78F+2800735]
# 	GetHandleVerifier [0x0124456C+2775612]
# 	GetHandleVerifier [0x010351E0+616112]
# 	(No symbol) [0x00F45F8C]
# 	(No symbol) [0x00F42328]
# 	(No symbol) [0x00F4240B]
# 	(No symbol) [0x00F34FF7]
# 	BaseThreadInitThunk [0x768800C9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77947B1E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77947AEE+238]
