# %%
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from selenium import webdriver
import time
import pandas as pd

options = Options()
options.add_argument("user-data-dir=C:/Users/dell/AppData/Local/Google/Chrome/User Data/Profile 19") 
driver = webdriver.Chrome(options=options,executable_path='C:/Users/dell/OneDrive/Desktop/chromedriver-win64/chromedriver.exe')  
# options.add_argument("user-data-dir=C:\\Users\\Username\\AppData\\Local\\Google\\Chrome\\User Data")
# driver = webdriver.Chrome(options=options)
# 'Mathematics and Bachelor words are used as a default, it is changeble
for j in range(467,468):
    driver.get(f'https://www.google.com/search?q=site:nl.linkedin.com/in/ Equatorial Guinea')
    time.sleep(10) # to make slower 
    # n is the number of pages
    links = [] # save links here/
    n=30
    while n > 0:
        time.sleep(5)
        for i in range(1, 11): # google uses paginator, every page has 10 urls
            time.sleep(6)
            try:
                elems = driver.find_elements(By.XPATH, '//*[@id="rso"]/div['+str(i)+']/div/div/div[1]/div/a')
                for elem in elems:
                    clean_url = elem.get_attribute("href") # extracting url 
                    base_url = "linkedin.com/in/"
                    if clean_url.find(base_url) != -1 and '%' not in clean_url: # sometimes google gives no Ln urls, so clean it
                        links.append(clean_url)
                        # print(f"url is --->{clean_url}")
            except Exception as e:
                print(e)
                pass
        try:
            next_button = driver.find_element(By.XPATH, '//*[@id="pnnext"]') # clicking next button 
            next_button.click()
        except Exception as e:
            print(e)
        print(f'{n} pages left!')
        n -= 1
    df = pd.DataFrame({
        "links":links
    })
    df = df.drop_duplicates()
    df.to_csv(f'datas/linkedin_links_29_06/data{str(j)}.csv', index=False)
    print(f'I am done ---> {str(j)}')
    print(f'if there is a problem, start with {str(j+1)}')
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_2968\3480825181.py:9: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(options=options,executable_path='C:/Users/dell/OneDrive/Desktop/chromedriver-win64/chromedriver.exe')
# 30 pages left!
# 29 pages left!
# 28 pages left!
# 27 pages left!
# 26 pages left!
# 25 pages left!
# 24 pages left!
# 23 pages left!
# 22 pages left!
# 21 pages left!
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="pnnext"]"}
#   (Session info: chrome=115.0.5790.110)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x00007FF72E2D3E62+57250]
# 	(No symbol) [0x00007FF72E24BC02]
# 	(No symbol) [0x00007FF72E11E0BB]
# 	(No symbol) [0x00007FF72E15765E]
# 	(No symbol) [0x00007FF72E15774C]
# 	(No symbol) [0x00007FF72E190267]
# 	(No symbol) [0x00007FF72E1767EF]
# 	(No symbol) [0x00007FF72E18E312]
# 	(No symbol) [0x00007FF72E176583]
# 	(No symbol) [0x00007FF72E14CC71]
# 	(No symbol) [0x00007FF72E14DE54]
# 	GetHandleVerifier [0x00007FF72E584CF2+2879026]
# 	GetHandleVerifier [0x00007FF72E5D6F30+3215472]
# 	GetHandleVerifier [0x00007FF72E5CFD4F+3186319]
# 	GetHandleVerifier [0x00007FF72E365505+652869]
# 	(No symbol) [0x00007FF72E257518]
# 	(No symbol) [0x00007FF72E2535F4]
# 	(No symbol) [0x00007FF72E2536EC]
# 	(No symbol) [0x00007FF72E2438E3]
# 	BaseThreadInitThunk [0x00007FF83E0C7614+20]
# 	RtlUserThreadStart [0x00007FF83E9426B1+33]
#
# 20 pages left!
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="pnnext"]"}
#   (Session info: chrome=115.0.5790.110)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x00007FF72E2D3E62+57250]
# 	(No symbol) [0x00007FF72E24BC02]
# 	(No symbol) [0x00007FF72E11E0BB]
# 	(No symbol) [0x00007FF72E15765E]
# 	(No symbol) [0x00007FF72E15774C]
# 	(No symbol) [0x00007FF72E190267]
# 	(No symbol) [0x00007FF72E1767EF]
# 	(No symbol) [0x00007FF72E18E312]
# 	(No symbol) [0x00007FF72E176583]
# 	(No symbol) [0x00007FF72E14CC71]
# 	(No symbol) [0x00007FF72E14DE54]
# 	GetHandleVerifier [0x00007FF72E584CF2+2879026]
# 	GetHandleVerifier [0x00007FF72E5D6F30+3215472]
# 	GetHandleVerifier [0x00007FF72E5CFD4F+3186319]
# 	GetHandleVerifier [0x00007FF72E365505+652869]
# 	(No symbol) [0x00007FF72E257518]
# 	(No symbol) [0x00007FF72E2535F4]
# 	(No symbol) [0x00007FF72E2536EC]
# 	(No symbol) [0x00007FF72E2438E3]
# 	BaseThreadInitThunk [0x00007FF83E0C7614+20]
# 	RtlUserThreadStart [0x00007FF83E9426B1+33]
#
# 19 pages left!
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="pnnext"]"}
#   (Session info: chrome=115.0.5790.110)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x00007FF72E2D3E62+57250]
# 	(No symbol) [0x00007FF72E24BC02]
# 	(No symbol) [0x00007FF72E11E0BB]
# 	(No symbol) [0x00007FF72E15765E]
# 	(No symbol) [0x00007FF72E15774C]
# 	(No symbol) [0x00007FF72E190267]
# 	(No symbol) [0x00007FF72E1767EF]
# 	(No symbol) [0x00007FF72E18E312]
# 	(No symbol) [0x00007FF72E176583]
# 	(No symbol) [0x00007FF72E14CC71]
# 	(No symbol) [0x00007FF72E14DE54]
# 	GetHandleVerifier [0x00007FF72E584CF2+2879026]
# 	GetHandleVerifier [0x00007FF72E5D6F30+3215472]
# 	GetHandleVerifier [0x00007FF72E5CFD4F+3186319]
# 	GetHandleVerifier [0x00007FF72E365505+652869]
# 	(No symbol) [0x00007FF72E257518]
# 	(No symbol) [0x00007FF72E2535F4]
# 	(No symbol) [0x00007FF72E2536EC]
# 	(No symbol) [0x00007FF72E2438E3]
# 	BaseThreadInitThunk [0x00007FF83E0C7614+20]
# 	RtlUserThreadStart [0x00007FF83E9426B1+33]
#
# 18 pages left!
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="pnnext"]"}
#   (Session info: chrome=115.0.5790.110)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x00007FF72E2D3E62+57250]
# 	(No symbol) [0x00007FF72E24BC02]
# 	(No symbol) [0x00007FF72E11E0BB]
# 	(No symbol) [0x00007FF72E15765E]
# 	(No symbol) [0x00007FF72E15774C]
# 	(No symbol) [0x00007FF72E190267]
# 	(No symbol) [0x00007FF72E1767EF]
# 	(No symbol) [0x00007FF72E18E312]
# 	(No symbol) [0x00007FF72E176583]
# 	(No symbol) [0x00007FF72E14CC71]
# 	(No symbol) [0x00007FF72E14DE54]
# 	GetHandleVerifier [0x00007FF72E584CF2+2879026]
# 	GetHandleVerifier [0x00007FF72E5D6F30+3215472]
# 	GetHandleVerifier [0x00007FF72E5CFD4F+3186319]
# 	GetHandleVerifier [0x00007FF72E365505+652869]
# 	(No symbol) [0x00007FF72E257518]
# 	(No symbol) [0x00007FF72E2535F4]
# 	(No symbol) [0x00007FF72E2536EC]
# 	(No symbol) [0x00007FF72E2438E3]
# 	BaseThreadInitThunk [0x00007FF83E0C7614+20]
# 	RtlUserThreadStart [0x00007FF83E9426B1+33]
#
# 17 pages left!
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="pnnext"]"}
#   (Session info: chrome=115.0.5790.110)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x00007FF72E2D3E62+57250]
# 	(No symbol) [0x00007FF72E24BC02]
# 	(No symbol) [0x00007FF72E11E0BB]
# 	(No symbol) [0x00007FF72E15765E]
# 	(No symbol) [0x00007FF72E15774C]
# 	(No symbol) [0x00007FF72E190267]
# 	(No symbol) [0x00007FF72E1767EF]
# 	(No symbol) [0x00007FF72E18E312]
# 	(No symbol) [0x00007FF72E176583]
# 	(No symbol) [0x00007FF72E14CC71]
# 	(No symbol) [0x00007FF72E14DE54]
# 	GetHandleVerifier [0x00007FF72E584CF2+2879026]
# 	GetHandleVerifier [0x00007FF72E5D6F30+3215472]
# 	GetHandleVerifier [0x00007FF72E5CFD4F+3186319]
# 	GetHandleVerifier [0x00007FF72E365505+652869]
# 	(No symbol) [0x00007FF72E257518]
# 	(No symbol) [0x00007FF72E2535F4]
# 	(No symbol) [0x00007FF72E2536EC]
# 	(No symbol) [0x00007FF72E2438E3]
# 	BaseThreadInitThunk [0x00007FF83E0C7614+20]
# 	RtlUserThreadStart [0x00007FF83E9426B1+33]
#
# 16 pages left!
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="pnnext"]"}
#   (Session info: chrome=115.0.5790.110)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x00007FF72E2D3E62+57250]
# 	(No symbol) [0x00007FF72E24BC02]
# 	(No symbol) [0x00007FF72E11E0BB]
# 	(No symbol) [0x00007FF72E15765E]
# 	(No symbol) [0x00007FF72E15774C]
# 	(No symbol) [0x00007FF72E190267]
# 	(No symbol) [0x00007FF72E1767EF]
# 	(No symbol) [0x00007FF72E18E312]
# 	(No symbol) [0x00007FF72E176583]
# 	(No symbol) [0x00007FF72E14CC71]
# 	(No symbol) [0x00007FF72E14DE54]
# 	GetHandleVerifier [0x00007FF72E584CF2+2879026]
# 	GetHandleVerifier [0x00007FF72E5D6F30+3215472]
# 	GetHandleVerifier [0x00007FF72E5CFD4F+3186319]
# 	GetHandleVerifier [0x00007FF72E365505+652869]
# 	(No symbol) [0x00007FF72E257518]
# 	(No symbol) [0x00007FF72E2535F4]
# 	(No symbol) [0x00007FF72E2536EC]
# 	(No symbol) [0x00007FF72E2438E3]
# 	BaseThreadInitThunk [0x00007FF83E0C7614+20]
# 	RtlUserThreadStart [0x00007FF83E9426B1+33]
#
# 15 pages left!
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="pnnext"]"}
#   (Session info: chrome=115.0.5790.110)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x00007FF72E2D3E62+57250]
# 	(No symbol) [0x00007FF72E24BC02]
# 	(No symbol) [0x00007FF72E11E0BB]
# 	(No symbol) [0x00007FF72E15765E]
# 	(No symbol) [0x00007FF72E15774C]
# 	(No symbol) [0x00007FF72E190267]
# 	(No symbol) [0x00007FF72E1767EF]
# 	(No symbol) [0x00007FF72E18E312]
# 	(No symbol) [0x00007FF72E176583]
# 	(No symbol) [0x00007FF72E14CC71]
# 	(No symbol) [0x00007FF72E14DE54]
# 	GetHandleVerifier [0x00007FF72E584CF2+2879026]
# 	GetHandleVerifier [0x00007FF72E5D6F30+3215472]
# 	GetHandleVerifier [0x00007FF72E5CFD4F+3186319]
# 	GetHandleVerifier [0x00007FF72E365505+652869]
# 	(No symbol) [0x00007FF72E257518]
# 	(No symbol) [0x00007FF72E2535F4]
# 	(No symbol) [0x00007FF72E2536EC]
# 	(No symbol) [0x00007FF72E2438E3]
# 	BaseThreadInitThunk [0x00007FF83E0C7614+20]
# 	RtlUserThreadStart [0x00007FF83E9426B1+33]
#
# 14 pages left!
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="pnnext"]"}
#   (Session info: chrome=115.0.5790.110)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x00007FF72E2D3E62+57250]
# 	(No symbol) [0x00007FF72E24BC02]
# 	(No symbol) [0x00007FF72E11E0BB]
# 	(No symbol) [0x00007FF72E15765E]
# 	(No symbol) [0x00007FF72E15774C]
# 	(No symbol) [0x00007FF72E190267]
# 	(No symbol) [0x00007FF72E1767EF]
# 	(No symbol) [0x00007FF72E18E312]
# 	(No symbol) [0x00007FF72E176583]
# 	(No symbol) [0x00007FF72E14CC71]
# 	(No symbol) [0x00007FF72E14DE54]
# 	GetHandleVerifier [0x00007FF72E584CF2+2879026]
# 	GetHandleVerifier [0x00007FF72E5D6F30+3215472]
# 	GetHandleVerifier [0x00007FF72E5CFD4F+3186319]
# 	GetHandleVerifier [0x00007FF72E365505+652869]
# 	(No symbol) [0x00007FF72E257518]
# 	(No symbol) [0x00007FF72E2535F4]
# 	(No symbol) [0x00007FF72E2536EC]
# 	(No symbol) [0x00007FF72E2438E3]
# 	BaseThreadInitThunk [0x00007FF83E0C7614+20]
# 	RtlUserThreadStart [0x00007FF83E9426B1+33]
#
# 13 pages left!
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="pnnext"]"}
#   (Session info: chrome=115.0.5790.110)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x00007FF72E2D3E62+57250]
# 	(No symbol) [0x00007FF72E24BC02]
# 	(No symbol) [0x00007FF72E11E0BB]
# 	(No symbol) [0x00007FF72E15765E]
# 	(No symbol) [0x00007FF72E15774C]
# 	(No symbol) [0x00007FF72E190267]
# 	(No symbol) [0x00007FF72E1767EF]
# 	(No symbol) [0x00007FF72E18E312]
# 	(No symbol) [0x00007FF72E176583]
# 	(No symbol) [0x00007FF72E14CC71]
# 	(No symbol) [0x00007FF72E14DE54]
# 	GetHandleVerifier [0x00007FF72E584CF2+2879026]
# 	GetHandleVerifier [0x00007FF72E5D6F30+3215472]
# 	GetHandleVerifier [0x00007FF72E5CFD4F+3186319]
# 	GetHandleVerifier [0x00007FF72E365505+652869]
# 	(No symbol) [0x00007FF72E257518]
# 	(No symbol) [0x00007FF72E2535F4]
# 	(No symbol) [0x00007FF72E2536EC]
# 	(No symbol) [0x00007FF72E2438E3]
# 	BaseThreadInitThunk [0x00007FF83E0C7614+20]
# 	RtlUserThreadStart [0x00007FF83E9426B1+33]
#
# 12 pages left!
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="pnnext"]"}
#   (Session info: chrome=115.0.5790.110)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x00007FF72E2D3E62+57250]
# 	(No symbol) [0x00007FF72E24BC02]
# 	(No symbol) [0x00007FF72E11E0BB]
# 	(No symbol) [0x00007FF72E15765E]
# 	(No symbol) [0x00007FF72E15774C]
# 	(No symbol) [0x00007FF72E190267]
# 	(No symbol) [0x00007FF72E1767EF]
# 	(No symbol) [0x00007FF72E18E312]
# 	(No symbol) [0x00007FF72E176583]
# 	(No symbol) [0x00007FF72E14CC71]
# 	(No symbol) [0x00007FF72E14DE54]
# 	GetHandleVerifier [0x00007FF72E584CF2+2879026]
# 	GetHandleVerifier [0x00007FF72E5D6F30+3215472]
# 	GetHandleVerifier [0x00007FF72E5CFD4F+3186319]
# 	GetHandleVerifier [0x00007FF72E365505+652869]
# 	(No symbol) [0x00007FF72E257518]
# 	(No symbol) [0x00007FF72E2535F4]
# 	(No symbol) [0x00007FF72E2536EC]
# 	(No symbol) [0x00007FF72E2438E3]
# 	BaseThreadInitThunk [0x00007FF83E0C7614+20]
# 	RtlUserThreadStart [0x00007FF83E9426B1+33]
#
# 11 pages left!
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="pnnext"]"}
#   (Session info: chrome=115.0.5790.110)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x00007FF72E2D3E62+57250]
# 	(No symbol) [0x00007FF72E24BC02]
# 	(No symbol) [0x00007FF72E11E0BB]
# 	(No symbol) [0x00007FF72E15765E]
# 	(No symbol) [0x00007FF72E15774C]
# 	(No symbol) [0x00007FF72E190267]
# 	(No symbol) [0x00007FF72E1767EF]
# 	(No symbol) [0x00007FF72E18E312]
# 	(No symbol) [0x00007FF72E176583]
# 	(No symbol) [0x00007FF72E14CC71]
# 	(No symbol) [0x00007FF72E14DE54]
# 	GetHandleVerifier [0x00007FF72E584CF2+2879026]
# 	GetHandleVerifier [0x00007FF72E5D6F30+3215472]
# 	GetHandleVerifier [0x00007FF72E5CFD4F+3186319]
# 	GetHandleVerifier [0x00007FF72E365505+652869]
# 	(No symbol) [0x00007FF72E257518]
# 	(No symbol) [0x00007FF72E2535F4]
# 	(No symbol) [0x00007FF72E2536EC]
# 	(No symbol) [0x00007FF72E2438E3]
# 	BaseThreadInitThunk [0x00007FF83E0C7614+20]
# 	RtlUserThreadStart [0x00007FF83E9426B1+33]
#
# 10 pages left!
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="pnnext"]"}
#   (Session info: chrome=115.0.5790.110)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x00007FF72E2D3E62+57250]
# 	(No symbol) [0x00007FF72E24BC02]
# 	(No symbol) [0x00007FF72E11E0BB]
# 	(No symbol) [0x00007FF72E15765E]
# 	(No symbol) [0x00007FF72E15774C]
# 	(No symbol) [0x00007FF72E190267]
# 	(No symbol) [0x00007FF72E1767EF]
# 	(No symbol) [0x00007FF72E18E312]
# 	(No symbol) [0x00007FF72E176583]
# 	(No symbol) [0x00007FF72E14CC71]
# 	(No symbol) [0x00007FF72E14DE54]
# 	GetHandleVerifier [0x00007FF72E584CF2+2879026]
# 	GetHandleVerifier [0x00007FF72E5D6F30+3215472]
# 	GetHandleVerifier [0x00007FF72E5CFD4F+3186319]
# 	GetHandleVerifier [0x00007FF72E365505+652869]
# 	(No symbol) [0x00007FF72E257518]
# 	(No symbol) [0x00007FF72E2535F4]
# 	(No symbol) [0x00007FF72E2536EC]
# 	(No symbol) [0x00007FF72E2438E3]
# 	BaseThreadInitThunk [0x00007FF83E0C7614+20]
# 	RtlUserThreadStart [0x00007FF83E9426B1+33]
#
# 9 pages left!
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="pnnext"]"}
#   (Session info: chrome=115.0.5790.110)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x00007FF72E2D3E62+57250]
# 	(No symbol) [0x00007FF72E24BC02]
# 	(No symbol) [0x00007FF72E11E0BB]
# 	(No symbol) [0x00007FF72E15765E]
# 	(No symbol) [0x00007FF72E15774C]
# 	(No symbol) [0x00007FF72E190267]
# 	(No symbol) [0x00007FF72E1767EF]
# 	(No symbol) [0x00007FF72E18E312]
# 	(No symbol) [0x00007FF72E176583]
# 	(No symbol) [0x00007FF72E14CC71]
# 	(No symbol) [0x00007FF72E14DE54]
# 	GetHandleVerifier [0x00007FF72E584CF2+2879026]
# 	GetHandleVerifier [0x00007FF72E5D6F30+3215472]
# 	GetHandleVerifier [0x00007FF72E5CFD4F+3186319]
# 	GetHandleVerifier [0x00007FF72E365505+652869]
# 	(No symbol) [0x00007FF72E257518]
# 	(No symbol) [0x00007FF72E2535F4]
# 	(No symbol) [0x00007FF72E2536EC]
# 	(No symbol) [0x00007FF72E2438E3]
# 	BaseThreadInitThunk [0x00007FF83E0C7614+20]
# 	RtlUserThreadStart [0x00007FF83E9426B1+33]
#
# 8 pages left!
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="pnnext"]"}
#   (Session info: chrome=115.0.5790.110)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x00007FF72E2D3E62+57250]
# 	(No symbol) [0x00007FF72E24BC02]
# 	(No symbol) [0x00007FF72E11E0BB]
# 	(No symbol) [0x00007FF72E15765E]
# 	(No symbol) [0x00007FF72E15774C]
# 	(No symbol) [0x00007FF72E190267]
# 	(No symbol) [0x00007FF72E1767EF]
# 	(No symbol) [0x00007FF72E18E312]
# 	(No symbol) [0x00007FF72E176583]
# 	(No symbol) [0x00007FF72E14CC71]
# 	(No symbol) [0x00007FF72E14DE54]
# 	GetHandleVerifier [0x00007FF72E584CF2+2879026]
# 	GetHandleVerifier [0x00007FF72E5D6F30+3215472]
# 	GetHandleVerifier [0x00007FF72E5CFD4F+3186319]
# 	GetHandleVerifier [0x00007FF72E365505+652869]
# 	(No symbol) [0x00007FF72E257518]
# 	(No symbol) [0x00007FF72E2535F4]
# 	(No symbol) [0x00007FF72E2536EC]
# 	(No symbol) [0x00007FF72E2438E3]
# 	BaseThreadInitThunk [0x00007FF83E0C7614+20]
# 	RtlUserThreadStart [0x00007FF83E9426B1+33]
#
# 7 pages left!
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="pnnext"]"}
#   (Session info: chrome=115.0.5790.110)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x00007FF72E2D3E62+57250]
# 	(No symbol) [0x00007FF72E24BC02]
# 	(No symbol) [0x00007FF72E11E0BB]
# 	(No symbol) [0x00007FF72E15765E]
# 	(No symbol) [0x00007FF72E15774C]
# 	(No symbol) [0x00007FF72E190267]
# 	(No symbol) [0x00007FF72E1767EF]
# 	(No symbol) [0x00007FF72E18E312]
# 	(No symbol) [0x00007FF72E176583]
# 	(No symbol) [0x00007FF72E14CC71]
# 	(No symbol) [0x00007FF72E14DE54]
# 	GetHandleVerifier [0x00007FF72E584CF2+2879026]
# 	GetHandleVerifier [0x00007FF72E5D6F30+3215472]
# 	GetHandleVerifier [0x00007FF72E5CFD4F+3186319]
# 	GetHandleVerifier [0x00007FF72E365505+652869]
# 	(No symbol) [0x00007FF72E257518]
# 	(No symbol) [0x00007FF72E2535F4]
# 	(No symbol) [0x00007FF72E2536EC]
# 	(No symbol) [0x00007FF72E2438E3]
# 	BaseThreadInitThunk [0x00007FF83E0C7614+20]
# 	RtlUserThreadStart [0x00007FF83E9426B1+33]
#
# 6 pages left!
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="pnnext"]"}
#   (Session info: chrome=115.0.5790.110)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x00007FF72E2D3E62+57250]
# 	(No symbol) [0x00007FF72E24BC02]
# 	(No symbol) [0x00007FF72E11E0BB]
# 	(No symbol) [0x00007FF72E15765E]
# 	(No symbol) [0x00007FF72E15774C]
# 	(No symbol) [0x00007FF72E190267]
# 	(No symbol) [0x00007FF72E1767EF]
# 	(No symbol) [0x00007FF72E18E312]
# 	(No symbol) [0x00007FF72E176583]
# 	(No symbol) [0x00007FF72E14CC71]
# 	(No symbol) [0x00007FF72E14DE54]
# 	GetHandleVerifier [0x00007FF72E584CF2+2879026]
# 	GetHandleVerifier [0x00007FF72E5D6F30+3215472]
# 	GetHandleVerifier [0x00007FF72E5CFD4F+3186319]
# 	GetHandleVerifier [0x00007FF72E365505+652869]
# 	(No symbol) [0x00007FF72E257518]
# 	(No symbol) [0x00007FF72E2535F4]
# 	(No symbol) [0x00007FF72E2536EC]
# 	(No symbol) [0x00007FF72E2438E3]
# 	BaseThreadInitThunk [0x00007FF83E0C7614+20]
# 	RtlUserThreadStart [0x00007FF83E9426B1+33]
#
# 5 pages left!
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="pnnext"]"}
#   (Session info: chrome=115.0.5790.110)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x00007FF72E2D3E62+57250]
# 	(No symbol) [0x00007FF72E24BC02]
# 	(No symbol) [0x00007FF72E11E0BB]
# 	(No symbol) [0x00007FF72E15765E]
# 	(No symbol) [0x00007FF72E15774C]
# 	(No symbol) [0x00007FF72E190267]
# 	(No symbol) [0x00007FF72E1767EF]
# 	(No symbol) [0x00007FF72E18E312]
# 	(No symbol) [0x00007FF72E176583]
# 	(No symbol) [0x00007FF72E14CC71]
# 	(No symbol) [0x00007FF72E14DE54]
# 	GetHandleVerifier [0x00007FF72E584CF2+2879026]
# 	GetHandleVerifier [0x00007FF72E5D6F30+3215472]
# 	GetHandleVerifier [0x00007FF72E5CFD4F+3186319]
# 	GetHandleVerifier [0x00007FF72E365505+652869]
# 	(No symbol) [0x00007FF72E257518]
# 	(No symbol) [0x00007FF72E2535F4]
# 	(No symbol) [0x00007FF72E2536EC]
# 	(No symbol) [0x00007FF72E2438E3]
# 	BaseThreadInitThunk [0x00007FF83E0C7614+20]
# 	RtlUserThreadStart [0x00007FF83E9426B1+33]
#
# 4 pages left!
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="pnnext"]"}
#   (Session info: chrome=115.0.5790.110)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x00007FF72E2D3E62+57250]
# 	(No symbol) [0x00007FF72E24BC02]
# 	(No symbol) [0x00007FF72E11E0BB]
# 	(No symbol) [0x00007FF72E15765E]
# 	(No symbol) [0x00007FF72E15774C]
# 	(No symbol) [0x00007FF72E190267]
# 	(No symbol) [0x00007FF72E1767EF]
# 	(No symbol) [0x00007FF72E18E312]
# 	(No symbol) [0x00007FF72E176583]
# 	(No symbol) [0x00007FF72E14CC71]
# 	(No symbol) [0x00007FF72E14DE54]
# 	GetHandleVerifier [0x00007FF72E584CF2+2879026]
# 	GetHandleVerifier [0x00007FF72E5D6F30+3215472]
# 	GetHandleVerifier [0x00007FF72E5CFD4F+3186319]
# 	GetHandleVerifier [0x00007FF72E365505+652869]
# 	(No symbol) [0x00007FF72E257518]
# 	(No symbol) [0x00007FF72E2535F4]
# 	(No symbol) [0x00007FF72E2536EC]
# 	(No symbol) [0x00007FF72E2438E3]
# 	BaseThreadInitThunk [0x00007FF83E0C7614+20]
# 	RtlUserThreadStart [0x00007FF83E9426B1+33]
#
# 3 pages left!
# 2 pages left!
# 1 pages left!
# I am done ---> 467
# if there is a problem, start with 468

# %%
import pandas as pd
df= pd.read_csv("./da")

# %%
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from selenium import webdriver
import time
import pandas as pd

options = Options()
options.add_argument("user-data-dir=C:/Users/dell/AppData/Local/Google/Chrome/User Data/Profile 2")
                                                        #C:\Users\fayyo\Downloads\chromedriver-win32.zip\chromedriver-win32
driver = webdriver.Chrome(options=options,executable_path='C:/Users/dell/OneDrive/Desktop/chromedriver-win64/chromedriver.exe')
# country names
list_items = [
  "United Kingdom",
  "United States",
  "Germany",
  " Russia",
  "France",
  "Italy",
  "Japan",
  "Poland",
  "Netherlands",
  "Belgium",
  "Norway",
  "China",
  "Greece",
  "Czechoslovakia",
  "Hungary",
  "Romania",
  "Finland",
  "Bulgaria",
  "Denmark",
  "Canada",
  "Australia",
  "New Zealand",
  "South Africa",
  "India",
  "Brazil",
  "Argentina",
  "Mexico",
  "Chile",
  "Peru",
  "Colombia",
  "Venezuela",
  "Ecuador",
  "Uruguay",
  "Paraguay",
  "Bolivia",
  "Guatemala",
  "Honduras",
  "El Salvador",
  "Nicaragua",
  "Costa Rica",
  "Panama",
  "Cuba",
  "Dominican Republic",
  "Puerto Rico",
  "Philippines",
  "Indonesia",
  "Malaysia",
  "Singapore",
  " Myanmar",
  "Thailand",
  "Vietnam",
  "Cambodia",
  "Laos",
  "South Korea",
  "North Korea",
  "China ",
  "Iraq",
  "Iran",
  "Syria",
  "Lebanon",
  "Jordan",
  "Israel",
  "Egypt",
  "Saudi Arabia",
  "Turkey",
  "Ghana",
  "Nigeria",
  "Kenya",
  "South Sudan",
  "Ethiopia",
  "Somalia",
  "Uganda",
  "Tanzania",
  "Zimbabwe",
  "South Africa",
  "Zambia"
];
for item  in list_items[:]:
    links = [] # save links here
    for study in ['master', 'bachelor']:
        driver.get(f'https://www.google.com/search?q=site:nl.linkedin.com/in/+AND+%22{item}+AND+%22{study}')
        time.sleep(10) # to make slower 
        # n is the number of pages
        n=30
        while n > 0:
            time.sleep(5)
            for i in range(1, 11): # google uses paginator, every page has 10 urls
                time.sleep(6)
                try:    #/html/body/div[6]/div/div[13]/div/div[2]/div[2]/div/div/div[1]/div/div/div[1]/div/div/a
                        #/html/body/div[6]/div/div[13]/div/div[2]/div[2]/div/div/div[4]/div/div/div[1]/div/div/a
                        #/html/body/div[6]/div/div[13]/div/div[2]/div[2]/div/div/div[9]/div/div/div/div[1]/div/div/a
                    elems = driver.find_elements(By.XPATH, '/html/body/div[6]/div/div[12]/div/div[2]/div[2]/div/div/div['+str(i)+']/div/div/div[1]/div/div/a')
                    for elem in elems:                     #/html/body/div[6]/div/div[12]/div/div[2]/div[2]/div/div/div[3]/div/div/div[1]/div/div/a
                                                           #/html/body/div[6]/div/div[12]/div/div[2]/div[2]/div/div/div[2]/div/div/div[1]/div/div/a
                        clean_url = elem.get_attribute("href") # extracting url 
                        base_url = "linkedin.com/in/"
                        if clean_url.find(base_url) != -1 and '%' not in clean_url: # sometimes google gives no Ln urls, so clean it
                            links.append(clean_url)
                except Exception as e:
                    print("problem with ELEMS")
                    pass
            try:
                next_button = driver.find_element(By.XPATH, '//*[@id="pnnext"]') # clicking next button 
                next_button.click()
            except Exception as e:
                driver.get(f'https://www.google.com/search?q=site:nl.linkedin.com/in/+AND+%22{item}+AND+%22{study}')
                print("")
            # print(f'{n} pages left!')
            n -= 1
    df = pd.DataFrame({
        "links":links
    })
    df1=pd.read_csv('datas/Ismatulla_links/data_Ismatulla.csv')
    df_sum=pd.concat([df1, df], axis=0, ignore_index=True)
    df_sum = df_sum.drop_duplicates()
    df_sum.to_csv(f'datas/Ismatulla_links/data_Ismatulla.csv', index=False)
    print(f'I am done ---> {item}')
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_16276\2029988128.py:10: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(options=options,executable_path='C:/Users/dell/OneDrive/Desktop/chromedriver-win64/chromedriver.exe')
# I am done ---> United Kingdom
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Cell In[7], line 115
#     114 try:
# --> 115     next_button = driver.find_element(By.XPATH, '//*[@id="pnnext"]') # clicking next button
#     116     next_button.click()
#
# File c:\Users\dell\OneDrive\Desktop\selenium\Bots_using_selenium\venv\lib\site-packages\selenium\webdriver\remote\webdriver.py:830, in WebDriver.find_element(self, by, value)
#     828     value = f'[name="{value}"]'
# --> 830 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File c:\Users\dell\OneDrive\Desktop\selenium\Bots_using_selenium\venv\lib\site-packages\selenium\webdriver\remote\webdriver.py:440, in WebDriver.execute(self, driver_command, params)
#     439 if response:
# --> 440     self.error_handler.check_response(response)
#     441     response["value"] = self._unwrap_value(response.get("value", None))
#
# File c:\Users\dell\OneDrive\Desktop\selenium\Bots_using_selenium\venv\lib\site-packages\selenium\webdriver\remote\errorhandler.py:245, in ErrorHandler.check_response(self, response)
#     244     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 245 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="pnnext"]"}
#   (Session info: chrome=116.0.5845.96)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x00007FF75CDE3E62+57250]
# 	(No symbol) [0x00007FF75CD5BC02]
# 	(No symbol) [0x00007FF75CC2E0BB]
# 	(No symbol) [0x00007FF75CC6765E]
# 	(No symbol) [0x00007FF75CC6774C]
# 	(No symbol) [0x00007FF75CCA0267]
# 	(No symbol) [0x00007FF75CC867EF]
# 	(No symbol) [0x00007FF75CC9E312]
# 	(No symbol) [0x00007FF75CC86583]
# 	(No symbol) [0x00007FF75CC5CC71]
# 	(No symbol) [0x00007FF75CC5DE54]
# 	GetHandleVerifier [0x00007FF75D094CF2+2879026]
# 	GetHandleVerifier [0x00007FF75D0E6F30+3215472]
# 	GetHandleVerifier [0x00007FF75D0DFD4F+3186319]
# 	GetHandleVerifier [0x00007FF75CE75505+652869]
# 	(No symbol) [0x00007FF75CD67518]
# 	(No symbol) [0x00007FF75CD635F4]
# 	(No symbol) [0x00007FF75CD636EC]
# 	(No symbol) [0x00007FF75CD538E3]
# 	BaseThreadInitThunk [0x00007FF8D2DF7614+20]
# 	RtlUserThreadStart [0x00007FF8D4C226B1+33]
#
#
# During handling of the above exception, another exception occurred:
#
# WebDriverException                        Traceback (most recent call last)
# Cell In[7], line 118
#     116     next_button.click()
#     117 except Exception as e:
# --> 118     driver.get(f'https://www.google.com/search?q=site:nl.linkedin.com/in/+AND+%22{item}+AND+%22{study}')
#     119     print("")
#     120 # print(f'{n} pages left!')
#
# File c:\Users\dell\OneDrive\Desktop\selenium\Bots_using_selenium\venv\lib\site-packages\selenium\webdriver\remote\webdriver.py:449, in WebDriver.get(self, url)
#     447 def get(self, url: str) -> None:
#     448     """Loads a web page in the current browser session."""
# --> 449     self.execute(Command.GET, {"url": url})
#
# File c:\Users\dell\OneDrive\Desktop\selenium\Bots_using_selenium\venv\lib\site-packages\selenium\webdriver\remote\webdriver.py:440, in WebDriver.execute(self, driver_command, params)
#     438 response = self.command_executor.execute(driver_command, params)
#     439 if response:
# --> 440     self.error_handler.check_response(response)
#     441     response["value"] = self._unwrap_value(response.get("value", None))
#     442     return response
#
# File c:\Users\dell\OneDrive\Desktop\selenium\Bots_using_selenium\venv\lib\site-packages\selenium\webdriver\remote\errorhandler.py:245, in ErrorHandler.check_response(self, response)
#     243         alert_text = value["alert"].get("text")
#     244     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 245 raise exception_class(message, screen, stacktrace)
#
# WebDriverException: Message: unknown error: net::ERR_INTERNET_DISCONNECTED
#   (Session info: chrome=116.0.5845.96)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x00007FF75CDE3E62+57250]
# 	(No symbol) [0x00007FF75CD5BC02]
# 	(No symbol) [0x00007FF75CC2E0BB]
# 	(No symbol) [0x00007FF75CC29E51]
# 	(No symbol) [0x00007FF75CC1C4EF]
# 	(No symbol) [0x00007FF75CC1D899]
# 	(No symbol) [0x00007FF75CC1C8C8]
# 	(No symbol) [0x00007FF75CC1B9CE]
# 	(No symbol) [0x00007FF75CC1B973]
# 	(No symbol) [0x00007FF75CC1A3F5]
# 	(No symbol) [0x00007FF75CC1AB63]
# 	(No symbol) [0x00007FF75CC2FC6B]
# 	(No symbol) [0x00007FF75CC9E687]
# 	(No symbol) [0x00007FF75CC867AA]
# 	(No symbol) [0x00007FF75CC9E312]
# 	(No symbol) [0x00007FF75CC86583]
# 	(No symbol) [0x00007FF75CC5CC71]
# 	(No symbol) [0x00007FF75CC5DE54]
# 	GetHandleVerifier [0x00007FF75D094CF2+2879026]
# 	GetHandleVerifier [0x00007FF75D0E6F30+3215472]
# 	GetHandleVerifier [0x00007FF75D0DFD4F+3186319]
# 	GetHandleVerifier [0x00007FF75CE75505+652869]
# 	(No symbol) [0x00007FF75CD67518]
# 	(No symbol) [0x00007FF75CD635F4]
# 	(No symbol) [0x00007FF75CD636EC]
# 	(No symbol) [0x00007FF75CD538E3]
# 	BaseThreadInitThunk [0x00007FF8D2DF7614+20]
# 	RtlUserThreadStart [0x00007FF8D4C226B1+33]

# %%
df = pd.DataFrame({
    "links":links
})
df1=pd.read_csv('datas/Fayyoz_links/data_Fayyoz.csv')
# df = df.drop_duplicates()
df_sum=pd.concat([df1, df], axis=0, ignore_index=True)
df_sum = df_sum.drop_duplicates()
df_sum.to_csv(f'datas/Fayyoz_links/data_Fayyoz.csv', index=False)
print(f'I am done ---> {item}')
# Out:
# I am done ---> Algeria
