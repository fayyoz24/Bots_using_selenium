# %%
studies_list=[]

# %%
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from selenium import webdriver
import time
import pandas as pd

options = Options()
options.add_argument("user-data-dir=C:\\Users\\Username\\AppData\\Local\\Google\\Chrome\\User Data")
driver = webdriver.Chrome(options=options)
# 'Mathematics and Bachelor words are used as a default, it is changeble
for study in studies_list:
    driver.get(f'https://www.google.com/search?q=site:nl.linkedin.com/in/+AND+%22{study}%22+AND+%22Bachelor%27s&sxsrf=ALiCzsbOTqrA98wDQf3mtEB03kA_O7eCbQ:1668686082134&ei=AiF2Y4vwB-3JrgS9gpd4&start=50&sa=N&ved=2ahUKEwiL-aqJlLX7AhXtpIsKHT3BBQ84KBDy0wN6BAgBEA0&biw=920&bih=625&dpr=1')
    time.sleep(10) # to make slower 
    # n is the number of pages
    links = [] # save links here
    n=15
    while n > 0:
        time.sleep(5)
        for i in range(1, 11): # google uses paginator, every page has 10 urls
            time.sleep(6)
            try:
                elems = driver.find_elements(By.XPATH, '//*[@id="rso"]/div['+str(i)+']/div/div/div[1]/div/a')
                for elem in elems:
                    clean_url = elem.get_attribute("href") # extracting url 
                    base_url = "linkedin.com/in/"
                    if clean_url.find(base_url) != -1 and '%' not in clean_url: # sometimes google gives no Ln urls, so clean it
                        links.append(clean_url)
                        # print(f"url is --->{clean_url}")
            except Exception as e:
                print(e)
                pass
        try:
            next_button = driver.find_element(By.XPATH, '//*[@id="pnnext"]') # clicking next button 
            next_button.click()
        except Exception as e:
            print(e)
        print(f'{n} pages left!')
        n -= 1
    df = pd.DataFrame({
        "links":links
    })

    df.to_csv(f'datas/linkedin_links/{study}.csv', index=False)
    print(f'I am done ---> {study}')
    print(f'if there is a problem, start with {studies_list.index(study)+1}')
# Out:
# url is --->https://nl.linkedin.com/in/femke-klaver-a295861a4
# url is --->https://nl.linkedin.com/in/sterre-de-jong-4420971b9?trk=public_profile_browsemap_profile-result-card_result-card_full-click
# url is --->https://nl.linkedin.com/in/simone-v
# url is --->https://nl.linkedin.com/in/sybolt-doorn-11303b140
# url is --->https://nl.linkedin.com/in/jorien-hendrix/en-us
# url is --->https://nl.linkedin.com/in/matthiasdejong
# url is --->https://nl.linkedin.com/in/pascal-smeekens-502a031ba/en
# url is --->https://nl.linkedin.com/in/trijsje-franssen-7baaa087
# 6 pages left!
# url is --->https://nl.linkedin.com/in/lisa-meral-jansen
# url is --->https://nl.linkedin.com/in/bernau-streekstra/en?trk=public_profile_locale-url
# url is --->https://nl.linkedin.com/in/tobias-julien-9273a7224?trk=people-guest_people_search-card
# url is --->https://nl.linkedin.com/in/daan-keij-a47814183
# url is --->https://nl.linkedin.com/in/robert-kerssies
# url is --->https://nl.linkedin.com/in/sybolt-friso-0622b01a9
# url is --->https://nl.linkedin.com/in/ewoudabspoel?trk=public_post_comment_actor-image
# url is --->https://nl.linkedin.com/in/roy-dings-71b34b92
# url is --->https://nl.linkedin.com/in/linde-scheepmaker-195153180
# 5 pages left!
# url is --->https://nl.linkedin.com/in/ejwenink
# url is --->https://nl.linkedin.com/in/guido-van-der-knaap
# url is --->https://nl.linkedin.com/in/justin-pollack-3a42161b6/en
# url is --->https://nl.linkedin.com/in/max-v-976756153
# url is --->https://nl.linkedin.com/in/frans-van-der-brugge-847034236?trk=public_profile_browsemap
# url is --->https://nl.linkedin.com/in/leonie-van-wees-570910107
# url is --->https://nl.linkedin.com/in/wouter-gerard-zevenbergen-42980952
# url is --->https://nl.linkedin.com/in/thomas-vlok-4aa908146
# url is --->https://nl.linkedin.com/in/jelmer-visser-0668311b1
# 4 pages left!
# url is --->https://nl.linkedin.com/in/yme-brantjes-6475171a
# url is --->https://nl.linkedin.com/in/tom-broeder-4834871a1
# url is --->https://nl.linkedin.com/in/elisah-verbrugge-a41302204
# url is --->https://nl.linkedin.com/in/robin-hillenbrink-5091541a3
# url is --->https://nl.linkedin.com/in/anouk-lammers-571a717a
# url is --->https://nl.linkedin.com/in/kdepaauw
# url is --->https://nl.linkedin.com/in/mart-kosterman-80b91b175
# url is --->https://nl.linkedin.com/in/lucas-van-straten-8b3b70225
# url is --->https://nl.linkedin.com/in/david-renger-55a925148
# 3 pages left!
# url is --->https://nl.linkedin.com/in/danielfortuin
# url is --->https://nl.linkedin.com/in/emma-ligthart?trk=public_profile_browsemap
# url is --->https://nl.linkedin.com/in/olivierbschroder
# url is --->https://nl.linkedin.com/in/esther-bos-kappert-1b90b020
# url is --->https://nl.linkedin.com/in/jessica-sekreve-336a2884
# url is --->https://nl.linkedin.com/in/monica-langeveld-ba2478198
# url is --->https://nl.linkedin.com/in/simonehuisman
# url is --->https://nl.linkedin.com/in/lisa-van-dolder-7a7657153
# url is --->https://nl.linkedin.com/in/imara-felkers-16b3b046
# 2 pages left!
# url is --->https://nl.linkedin.com/in/yorick-karseboom-8b361b153
# url is --->https://nl.linkedin.com/in/fenna-kortooms
# url is --->https://nl.linkedin.com/in/gertvierwind
# url is --->https://nl.linkedin.com/in/marlijnmulder
# url is --->https://nl.linkedin.com/in/mark-van-der-kooi-a22489195
# url is --->https://nl.linkedin.com/in/kasper-essers-747797253?trk=people_directory
# url is --->https://nl.linkedin.com/in/simone-peters-3aa92525
# url is --->https://nl.linkedin.com/in/sammie-van-engelen-942055254
# url is --->https://nl.linkedin.com/in/julia-swaters-161892149
# 1 pages left!

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By

chrome_driver_path = Service(
    "C:\Development\chromedriver_win32\chromedriver.exe")
driver = webdriver.Chrome(service=chrome_driver_path)
URL = "https://en.wikipedia.org/wiki/Main_Page"
driver.get(URL)

# %%
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from selenium import webdriver
import time
import pandas as pd

chrome_driver_path = Service(
    "chromedriver.exe")
driver = webdriver.Chrome(service=chrome_driver_path)

# options = Options()
# options.add_argument("user-data-dir=C:\\Users\\Username\\AppData\\Local\\Google\\Chrome\\User Data")
# driver = webdriver.Chrome(options=options)
# 'Mathematics and Bachelor words are used as a default, it is changeble
driver.get('https://www.google.com/search?q=site:nl.linkedin.com/in/+AND+%22Computational Social Science%22+AND+%22Bachelor%27s&sxsrf=ALiCzsbOTqrA98wDQf3mtEB03kA_O7eCbQ:1668686082134&ei=AiF2Y4vwB-3JrgS9gpd4&start=50&sa=N&ved=2ahUKEwiL-aqJlLX7AhXtpIsKHT3BBQ84KBDy0wN6BAgBEA0&biw=920&bih=625&dpr=1')
time.sleep(10) # to make slower 

 # n is the number of pages
links = [] # save links here
n=6
while n > 0:
    time.sleep(5)
    for i in range(1, 11): # google uses paginator, every page has 10 urls
        time.sleep(6)
        try:
            elems = driver.find_elements(By.XPATH, '//*[@id="rso"]/div['+str(i)+']/div/div/div[1]/div/a')
            for elem in elems:
                
                clean_url = elem.get_attribute("href") # extracting url 
                base_url = "linkedin.com/in/"
                if clean_url.find(base_url) != -1 and '%' not in clean_url: # sometimes google gives no Ln urls, so clean it
                    links.append(clean_url)
                    print(f"url is --->{clean_url}")
        except Exception as e:
            print(e)
            pass
    try:
        next_button = driver.find_element(By.XPATH, '//*[@id="pnnext"]') # clicking next button 
        next_button.click()
    except Exception as e:
        print(e)
    print(f'{n} pages left!')
    n -= 1
df = pd.DataFrame({
    "links":links
})
df.to_csv('datas/linkedin_aaccount_links/Filosofie.csv', index=False)
