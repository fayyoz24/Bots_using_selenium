# %%
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from selenium import webdriver
import time
import pandas as pd

options = Options()
options.add_argument("user-data-dir=C:/Users/dell/AppData/Local/Google/Chrome/User Data/Profile 17")
driver = webdriver.Chrome(options=options,executable_path='C:/Users/dell/OneDrive/Desktop/chromedriver.exe')
# options.add_argument("user-data-dir=C:\\Users\\Username\\AppData\\Local\\Google\\Chrome\\User Data")
# driver = webdriver.Chrome(options=options)
# 'Mathematics and Bachelor words are used as a default, it is changeble
for j in range(35,50):
    driver.get(f'https://www.google.com/search?q=site:nl.linkedin.com/in/')
    time.sleep(10) # to make slower 
    # n is the number of pages
    links = [] # save links here
    n=30
    while n > 0:
        time.sleep(5)
        for i in range(1, 11): # google uses paginator, every page has 10 urls
            time.sleep(6)
            try:
                elems = driver.find_elements(By.XPATH, '//*[@id="rso"]/div['+str(i)+']/div/div/div[1]/div/a')
                for elem in elems:
                    clean_url = elem.get_attribute("href") # extracting url 
                    base_url = "linkedin.com/in/"
                    if clean_url.find(base_url) != -1 and '%' not in clean_url: # sometimes google gives no Ln urls, so clean it
                        links.append(clean_url)
                        # print(f"url is --->{clean_url}")
            except Exception as e:
                print(e)
                pass
        try:
            next_button = driver.find_element(By.XPATH, '//*[@id="pnnext"]') # clicking next button 
            next_button.click()
        except Exception as e:
            print(e)
        print(f'{n} pages left!')
        n -= 1
    df = pd.DataFrame({
        "links":links
    })
    df = df.drop_duplicates()
    df.to_csv(f'datas/linkedin_links_29_06/data{str(j)}.csv', index=False)
    print(f'I am done ---> {str(j)}')
    print(f'if there is a problem, start with {str(j+1)}')
# Out:
# C:\Users\fayyo\AppData\Local\Temp\ipykernel_13896\2760630007.py:9: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(options=options,executable_path='C:/Users/dell/OneDrive/Desktop/chromedriver.exe')
# Incompatible release of chromedriver (version 111.0.5563.64) detected in PATH: c:\Users\GitHub\Bots_using_selenium\linkedin_data_Scraping\chromedriver.exe
# 30 pages left!
# 29 pages left!
# 28 pages left!
# 27 pages left!
# 26 pages left!
# 25 pages left!
# 24 pages left!
# 23 pages left!
# 22 pages left!
# 21 pages left!
# 20 pages left!
# 19 pages left!
# 18 pages left!
# 17 pages left!
# 16 pages left!
# 15 pages left!
# 14 pages left!
# 13 pages left!
# 12 pages left!
# 11 pages left!
# 10 pages left!
# 9 pages left!
# 8 pages left!
# 7 pages left!
# 6 pages left!
# 5 pages left!
# 4 pages left!
# 3 pages left!
# 2 pages left!
# 1 pages left!
# I am done ---> 27
# if there is a problem, start with 28
# 30 pages left!
# 29 pages left!
# 28 pages left!
# 27 pages left!
# 26 pages left!
# 25 pages left!
# 24 pages left!
# 23 pages left!
# 22 pages left!
# 21 pages left!
# 20 pages left!
# 19 pages left!
# 18 pages left!
# 17 pages left!
# 16 pages left!
# 15 pages left!
# 14 pages left!
# 13 pages left!
# 12 pages left!
# 11 pages left!
# 10 pages left!
# 9 pages left!
# 8 pages left!
# 7 pages left!
# 6 pages left!
# 5 pages left!
# 4 pages left!
# 3 pages left!
# 2 pages left!
# 1 pages left!
# I am done ---> 28
# if there is a problem, start with 29
# 30 pages left!
# 29 pages left!
# 28 pages left!
# 27 pages left!
# 26 pages left!
# 25 pages left!
# 24 pages left!
# 23 pages left!
# 22 pages left!
# 21 pages left!
# 20 pages left!
# 19 pages left!
# 18 pages left!
# 17 pages left!
# 16 pages left!
# 15 pages left!
# 14 pages left!
# 13 pages left!
# 12 pages left!
# 11 pages left!
# 10 pages left!
# 9 pages left!
# 8 pages left!
# 7 pages left!
# 6 pages left!
# 5 pages left!
# 4 pages left!
# 3 pages left!
# 2 pages left!
# 1 pages left!
# I am done ---> 29
# if there is a problem, start with 30
# 30 pages left!
# 29 pages left!
# 28 pages left!
# 27 pages left!
# 26 pages left!
# 25 pages left!
# 24 pages left!
# 23 pages left!
# 22 pages left!
# 21 pages left!
# 20 pages left!
# 19 pages left!
# 18 pages left!
# 17 pages left!
# 16 pages left!
# 15 pages left!
# 14 pages left!
# 13 pages left!
# 12 pages left!
# 11 pages left!
# 10 pages left!
# 9 pages left!
# 8 pages left!
# 7 pages left!
# 6 pages left!
# 5 pages left!
# 4 pages left!
# 3 pages left!
# 2 pages left!
# 1 pages left!
# I am done ---> 30
# if there is a problem, start with 31
# 30 pages left!
# 29 pages left!
# 28 pages left!
# 27 pages left!
# 26 pages left!
# 25 pages left!
# 24 pages left!
# 23 pages left!
# 22 pages left!
# 21 pages left!
# 20 pages left!
# 19 pages left!
# 18 pages left!
# 17 pages left!
# 16 pages left!
# 15 pages left!
# 14 pages left!
# 13 pages left!
# 12 pages left!
# 11 pages left!
# 10 pages left!
# 9 pages left!
# 8 pages left!
# 7 pages left!
# 6 pages left!
# 5 pages left!
# 4 pages left!
# 3 pages left!
# 2 pages left!
# 1 pages left!
# I am done ---> 31
# if there is a problem, start with 32
# 30 pages left!
# 29 pages left!
# 28 pages left!
# 27 pages left!
# 26 pages left!
# 25 pages left!
# 24 pages left!
# 23 pages left!
# 22 pages left!
# 21 pages left!
# 20 pages left!
# 19 pages left!
# 18 pages left!
# 17 pages left!
# 16 pages left!
# 15 pages left!
# 14 pages left!
# 13 pages left!
# 12 pages left!
# 11 pages left!
# 10 pages left!
# 9 pages left!
# 8 pages left!
# 7 pages left!
# 6 pages left!
# 5 pages left!
# 4 pages left!
# 3 pages left!
# 2 pages left!
# 1 pages left!
# I am done ---> 32
# if there is a problem, start with 33
# 30 pages left!
# 29 pages left!
# 28 pages left!
# 27 pages left!
# 26 pages left!
# 25 pages left!
# 24 pages left!
# 23 pages left!
# 22 pages left!
# 21 pages left!
# 20 pages left!
# 19 pages left!
# 18 pages left!
# 17 pages left!
# 16 pages left!
# 15 pages left!
# 14 pages left!
# 13 pages left!
# 12 pages left!
# 11 pages left!
# 10 pages left!
# 9 pages left!
# 8 pages left!
# 7 pages left!
# 6 pages left!
# 5 pages left!
# 4 pages left!
# 3 pages left!
# 2 pages left!
# 1 pages left!
# I am done ---> 33
# if there is a problem, start with 34
# 30 pages left!
# 29 pages left!
# 28 pages left!
# 27 pages left!
# 26 pages left!
# 25 pages left!
# 24 pages left!
# 23 pages left!
# 22 pages left!
# 21 pages left!
# 20 pages left!
# 19 pages left!
# 18 pages left!
# 17 pages left!
# 16 pages left!
# 15 pages left!
# 14 pages left!
# 13 pages left!
# 12 pages left!
# 11 pages left!
# 10 pages left!
# 9 pages left!
# 8 pages left!
# 7 pages left!
# 6 pages left!
# 5 pages left!
# 4 pages left!
# 3 pages left!
# 2 pages left!
# 1 pages left!
# I am done ---> 34
# if there is a problem, start with 35
# 30 pages left!
# 29 pages left!
# 28 pages left!
# 27 pages left!
# Message: disconnected: not connected to DevTools
#   (failed to check if window was closed: disconnected: not connected to DevTools)
#   (Session info: chrome=114.0.5735.135)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x002AA813+48355]
# 	(No symbol) [0x0023C4B1]
# 	(No symbol) [0x00145358]
# 	(No symbol) [0x00137D96]
# 	(No symbol) [0x00137AB9]
# 	(No symbol) [0x001467C0]
# 	(No symbol) [0x0019C4D8]
# 	(No symbol) [0x0018A536]
# 	(No symbol) [0x001682DC]
# 	(No symbol) [0x001693DD]
# 	GetHandleVerifier [0x0050AABD+2539405]
# 	GetHandleVerifier [0x0054A78F+2800735]
# 	GetHandleVerifier [0x0054456C+2775612]
# 	GetHandleVerifier [0x003351E0+616112]
# 	(No symbol) [0x00245F8C]
# 	(No symbol) [0x00242328]
# 	(No symbol) [0x0024240B]
# 	(No symbol) [0x00234FF7]
# 	BaseThreadInitThunk [0x774000C9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77B57B4E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77B57B1E+238]
# 	(No symbol) [0x00000000]
#
# Message: disconnected: not connected to DevTools
#   (failed to check if window was closed: disconnected: not connected to DevTools)
#   (Session info: chrome=114.0.5735.135)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x002AA813+48355]
# 	(No symbol) [0x0023C4B1]
# 	(No symbol) [0x00145358]
# 	(No symbol) [0x00137D96]
# 	(No symbol) [0x00137AB9]
# 	(No symbol) [0x001467C0]
# 	(No symbol) [0x0019C4D8]
# 	(No symbol) [0x0018A536]
# 	(No symbol) [0x001682DC]
# 	(No symbol) [0x001693DD]
# 	GetHandleVerifier [0x0050AABD+2539405]
# 	GetHandleVerifier [0x0054A78F+2800735]
# 	GetHandleVerifier [0x0054456C+2775612]
# 	GetHandleVerifier [0x003351E0+616112]
# 	(No symbol) [0x00245F8C]
# 	(No symbol) [0x00242328]
# 	(No symbol) [0x0024240B]
# 	(No symbol) [0x00234FF7]
# 	BaseThreadInitThunk [0x774000C9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77B57B4E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77B57B1E+238]
# 	(No symbol) [0x00000000]
# Cannot execute code, session has been disposed. Please try restarting the Kernel.
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By

chrome_driver_path = Service(
    "C:\Development\chromedriver_win32\chromedriver.exe")
driver = webdriver.Chrome(service=chrome_driver_path)
URL = "https://en.wikipedia.org/wiki/Main_Page"
driver.get(URL)

# %%
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from selenium import webdriver
import time
import pandas as pd

chrome_driver_path = Service(
    "chromedriver.exe")
driver = webdriver.Chrome(service=chrome_driver_path)

# options = Options()
# options.add_argument("user-data-dir=C:\\Users\\Username\\AppData\\Local\\Google\\Chrome\\User Data")
# driver = webdriver.Chrome(options=options)
# 'Mathematics and Bachelor words are used as a default, it is changeble
driver.get('https://www.google.com/search?q=site:nl.linkedin.com/in/+AND+%22Computational Social Science%22+AND+%22Bachelor%27s&sxsrf=ALiCzsbOTqrA98wDQf3mtEB03kA_O7eCbQ:1668686082134&ei=AiF2Y4vwB-3JrgS9gpd4&start=50&sa=N&ved=2ahUKEwiL-aqJlLX7AhXtpIsKHT3BBQ84KBDy0wN6BAgBEA0&biw=920&bih=625&dpr=1')
time.sleep(10) # to make slower 

 # n is the number of pages
links = [] # save links here
n=6
while n > 0:
    time.sleep(5)
    for i in range(1, 11): # google uses paginator, every page has 10 urls
        time.sleep(6)
        try:
            elems = driver.find_elements(By.XPATH, '//*[@id="rso"]/div['+str(i)+']/div/div/div[1]/div/a')
            for elem in elems:
                
                clean_url = elem.get_attribute("href") # extracting url 
                base_url = "linkedin.com/in/"
                if clean_url.find(base_url) != -1 and '%' not in clean_url: # sometimes google gives no Ln urls, so clean it
                    links.append(clean_url)
                    print(f"url is --->{clean_url}")
        except Exception as e:
            print(e)
            pass
    try:
        next_button = driver.find_element(By.XPATH, '//*[@id="pnnext"]') # clicking next button 
        next_button.click()
    except Exception as e:
        print(e)
    print(f'{n} pages left!')
    n -= 1
df = pd.DataFrame({
    "links":links
})
df.to_csv('datas/linkedin_aaccount_links/Filosofie.csv', index=False)
