# %%
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from selenium import webdriver
import time
import pandas as pd

options = Options()
options.add_argument("user-data-dir=C:/Users/dell/AppData/Local/Google/Chrome/User Data/Profile 17")
driver = webdriver.Chrome(options=options,executable_path='C:/Users/dell/OneDrive/Desktop/chromedriver.exe')
# options.add_argument("user-data-dir=C:\\Users\\Username\\AppData\\Local\\Google\\Chrome\\User Data")
# driver = webdriver.Chrome(options=options)
# 'Mathematics and Bachelor words are used as a default, it is changeble
for j in range(35,50):
    driver.get(f'https://www.google.com/search?q=site:nl.linkedin.com/in/')
    time.sleep(10) # to make slower 
    # n is the number of pages
    links = [] # save links here
    n=30
    while n > 0:
        time.sleep(5)
        for i in range(1, 11): # google uses paginator, every page has 10 urls
            time.sleep(6)
            try:
                elems = driver.find_elements(By.XPATH, '//*[@id="rso"]/div['+str(i)+']/div/div/div[1]/div/a')
                for elem in elems:
                    clean_url = elem.get_attribute("href") # extracting url 
                    base_url = "linkedin.com/in/"
                    if clean_url.find(base_url) != -1 and '%' not in clean_url: # sometimes google gives no Ln urls, so clean it
                        links.append(clean_url)
                        # print(f"url is --->{clean_url}")
            except Exception as e:
                print(e)
                pass
        try:
            next_button = driver.find_element(By.XPATH, '//*[@id="pnnext"]') # clicking next button 
            next_button.click()
        except Exception as e:
            print(e)
        print(f'{n} pages left!')
        n -= 1
    df = pd.DataFrame({
        "links":links
    })
    df = df.drop_duplicates()
    df.to_csv(f'datas/linkedin_links_29_06/data{str(j)}.csv', index=False)
    print(f'I am done ---> {str(j)}')
    print(f'if there is a problem, start with {str(j+1)}')
# Out:
# C:\Users\fayyo\AppData\Local\Temp\ipykernel_7928\2111209113.py:9: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(options=options,executable_path='C:/Users/dell/OneDrive/Desktop/chromedriver.exe')
# Incompatible release of chromedriver (version 111.0.5563.64) detected in PATH: c:\Users\GitHub\Bots_using_selenium\linkedin_data_Scraping\chromedriver.exe
# 30 pages left!
# 29 pages left!
# 28 pages left!
# 27 pages left!
# 26 pages left!
# 25 pages left!
# 24 pages left!
# 23 pages left!
# 22 pages left!
# 21 pages left!
# 20 pages left!
# 19 pages left!
# 18 pages left!
# 17 pages left!
# 16 pages left!
# 15 pages left!
# 14 pages left!
# 13 pages left!
# 12 pages left!
# 11 pages left!
# 10 pages left!
# 9 pages left!
# 8 pages left!
# 7 pages left!
# 6 pages left!
# 5 pages left!
# 4 pages left!
# 3 pages left!
# 2 pages left!
# 1 pages left!
# I am done ---> 35
# if there is a problem, start with 36
# 30 pages left!
# 29 pages left!
# 28 pages left!
# 27 pages left!
# 26 pages left!
# 25 pages left!
# 24 pages left!
# 23 pages left!
# 22 pages left!
# 21 pages left!
# 20 pages left!
# 19 pages left!
# 18 pages left!
# 17 pages left!
# 16 pages left!
# 15 pages left!
# 14 pages left!
# 13 pages left!
# 12 pages left!
# 11 pages left!
# 10 pages left!
# 9 pages left!
# 8 pages left!
# 7 pages left!
# 6 pages left!
# 5 pages left!
# 4 pages left!
# 3 pages left!
# 2 pages left!
# 1 pages left!
# I am done ---> 36
# if there is a problem, start with 37
# 30 pages left!
# 29 pages left!
# 28 pages left!
# 27 pages left!
# 26 pages left!
# 25 pages left!
# 24 pages left!
# 23 pages left!
# 22 pages left!
# 21 pages left!
# 20 pages left!
# 19 pages left!
# 18 pages left!
# 17 pages left!
# 16 pages left!
# 15 pages left!
# 14 pages left!
# 13 pages left!
# 12 pages left!
# 11 pages left!
# 10 pages left!
# 9 pages left!
# 8 pages left!
# 7 pages left!
# 6 pages left!
# 5 pages left!
# 4 pages left!
# 3 pages left!
# 2 pages left!
# 1 pages left!
# I am done ---> 37
# if there is a problem, start with 38
# 30 pages left!
# 29 pages left!
# 28 pages left!
# 27 pages left!
# 26 pages left!
# 25 pages left!
# 24 pages left!
# 23 pages left!
# 22 pages left!
# 21 pages left!
# 20 pages left!
# 19 pages left!
# 18 pages left!
# 17 pages left!
# 16 pages left!
# 15 pages left!
# 14 pages left!
# 13 pages left!
# 12 pages left!
# 11 pages left!
# 10 pages left!
# 9 pages left!
# 8 pages left!
# 7 pages left!
# 6 pages left!
# 5 pages left!
# 4 pages left!
# 3 pages left!
# 2 pages left!
# 1 pages left!
# I am done ---> 38
# if there is a problem, start with 39
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="pnnext"]"}
#   (Session info: chrome=114.0.5735.199)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x0054A813+48355]
# 	(No symbol) [0x004DC4B1]
# 	(No symbol) [0x003E5358]
# 	(No symbol) [0x004109A5]
# 	(No symbol) [0x00410B3B]
# 	(No symbol) [0x0043E232]
# 	(No symbol) [0x0042A784]
# 	(No symbol) [0x0043C922]
# 	(No symbol) [0x0042A536]
# 	(No symbol) [0x004082DC]
# 	(No symbol) [0x004093DD]
# 	GetHandleVerifier [0x007AAABD+2539405]
# 	GetHandleVerifier [0x007EA78F+2800735]
# 	GetHandleVerifier [0x007E456C+2775612]
# 	GetHandleVerifier [0x005D51E0+616112]
# 	(No symbol) [0x004E5F8C]
# 	(No symbol) [0x004E2328]
# 	(No symbol) [0x004E240B]
# 	(No symbol) [0x004D4FF7]
# 	BaseThreadInitThunk [0x762500C9+25]
# 	RtlGetAppContainerNamedObjectPath [0x774E7B4E+286]
# 	RtlGetAppContainerNamedObjectPath [0x774E7B1E+238]
#
# 30 pages left!
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="pnnext"]"}
#   (Session info: chrome=114.0.5735.199)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x0054A813+48355]
# 	(No symbol) [0x004DC4B1]
# 	(No symbol) [0x003E5358]
# 	(No symbol) [0x004109A5]
# 	(No symbol) [0x00410B3B]
# 	(No symbol) [0x0043E232]
# 	(No symbol) [0x0042A784]
# 	(No symbol) [0x0043C922]
# 	(No symbol) [0x0042A536]
# 	(No symbol) [0x004082DC]
# 	(No symbol) [0x004093DD]
# 	GetHandleVerifier [0x007AAABD+2539405]
# 	GetHandleVerifier [0x007EA78F+2800735]
# 	GetHandleVerifier [0x007E456C+2775612]
# 	GetHandleVerifier [0x005D51E0+616112]
# 	(No symbol) [0x004E5F8C]
# 	(No symbol) [0x004E2328]
# 	(No symbol) [0x004E240B]
# 	(No symbol) [0x004D4FF7]
# 	BaseThreadInitThunk [0x762500C9+25]
# 	RtlGetAppContainerNamedObjectPath [0x774E7B4E+286]
# 	RtlGetAppContainerNamedObjectPath [0x774E7B1E+238]
#
# 29 pages left!
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="pnnext"]"}
#   (Session info: chrome=114.0.5735.199)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x0054A813+48355]
# 	(No symbol) [0x004DC4B1]
# 	(No symbol) [0x003E5358]
# 	(No symbol) [0x004109A5]
# 	(No symbol) [0x00410B3B]
# 	(No symbol) [0x0043E232]
# 	(No symbol) [0x0042A784]
# 	(No symbol) [0x0043C922]
# 	(No symbol) [0x0042A536]
# 	(No symbol) [0x004082DC]
# 	(No symbol) [0x004093DD]
# 	GetHandleVerifier [0x007AAABD+2539405]
# 	GetHandleVerifier [0x007EA78F+2800735]
# 	GetHandleVerifier [0x007E456C+2775612]
# 	GetHandleVerifier [0x005D51E0+616112]
# 	(No symbol) [0x004E5F8C]
# 	(No symbol) [0x004E2328]
# 	(No symbol) [0x004E240B]
# 	(No symbol) [0x004D4FF7]
# 	BaseThreadInitThunk [0x762500C9+25]
# 	RtlGetAppContainerNamedObjectPath [0x774E7B4E+286]
# 	RtlGetAppContainerNamedObjectPath [0x774E7B1E+238]
#
# 28 pages left!
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="pnnext"]"}
#   (Session info: chrome=114.0.5735.199)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x0054A813+48355]
# 	(No symbol) [0x004DC4B1]
# 	(No symbol) [0x003E5358]
# 	(No symbol) [0x004109A5]
# 	(No symbol) [0x00410B3B]
# 	(No symbol) [0x0043E232]
# 	(No symbol) [0x0042A784]
# 	(No symbol) [0x0043C922]
# 	(No symbol) [0x0042A536]
# 	(No symbol) [0x004082DC]
# 	(No symbol) [0x004093DD]
# 	GetHandleVerifier [0x007AAABD+2539405]
# 	GetHandleVerifier [0x007EA78F+2800735]
# 	GetHandleVerifier [0x007E456C+2775612]
# 	GetHandleVerifier [0x005D51E0+616112]
# 	(No symbol) [0x004E5F8C]
# 	(No symbol) [0x004E2328]
# 	(No symbol) [0x004E240B]
# 	(No symbol) [0x004D4FF7]
# 	BaseThreadInitThunk [0x762500C9+25]
# 	RtlGetAppContainerNamedObjectPath [0x774E7B4E+286]
# 	RtlGetAppContainerNamedObjectPath [0x774E7B1E+238]
#
# 27 pages left!
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="pnnext"]"}
#   (Session info: chrome=114.0.5735.199)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x0054A813+48355]
# 	(No symbol) [0x004DC4B1]
# 	(No symbol) [0x003E5358]
# 	(No symbol) [0x004109A5]
# 	(No symbol) [0x00410B3B]
# 	(No symbol) [0x0043E232]
# 	(No symbol) [0x0042A784]
# 	(No symbol) [0x0043C922]
# 	(No symbol) [0x0042A536]
# 	(No symbol) [0x004082DC]
# 	(No symbol) [0x004093DD]
# 	GetHandleVerifier [0x007AAABD+2539405]
# 	GetHandleVerifier [0x007EA78F+2800735]
# 	GetHandleVerifier [0x007E456C+2775612]
# 	GetHandleVerifier [0x005D51E0+616112]
# 	(No symbol) [0x004E5F8C]
# 	(No symbol) [0x004E2328]
# 	(No symbol) [0x004E240B]
# 	(No symbol) [0x004D4FF7]
# 	BaseThreadInitThunk [0x762500C9+25]
# 	RtlGetAppContainerNamedObjectPath [0x774E7B4E+286]
# 	RtlGetAppContainerNamedObjectPath [0x774E7B1E+238]
#
# 26 pages left!
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="pnnext"]"}
#   (Session info: chrome=114.0.5735.199)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x0054A813+48355]
# 	(No symbol) [0x004DC4B1]
# 	(No symbol) [0x003E5358]
# 	(No symbol) [0x004109A5]
# 	(No symbol) [0x00410B3B]
# 	(No symbol) [0x0043E232]
# 	(No symbol) [0x0042A784]
# 	(No symbol) [0x0043C922]
# 	(No symbol) [0x0042A536]
# 	(No symbol) [0x004082DC]
# 	(No symbol) [0x004093DD]
# 	GetHandleVerifier [0x007AAABD+2539405]
# 	GetHandleVerifier [0x007EA78F+2800735]
# 	GetHandleVerifier [0x007E456C+2775612]
# 	GetHandleVerifier [0x005D51E0+616112]
# 	(No symbol) [0x004E5F8C]
# 	(No symbol) [0x004E2328]
# 	(No symbol) [0x004E240B]
# 	(No symbol) [0x004D4FF7]
# 	BaseThreadInitThunk [0x762500C9+25]
# 	RtlGetAppContainerNamedObjectPath [0x774E7B4E+286]
# 	RtlGetAppContainerNamedObjectPath [0x774E7B1E+238]
#
# 25 pages left!
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="pnnext"]"}
#   (Session info: chrome=114.0.5735.199)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x0054A813+48355]
# 	(No symbol) [0x004DC4B1]
# 	(No symbol) [0x003E5358]
# 	(No symbol) [0x004109A5]
# 	(No symbol) [0x00410B3B]
# 	(No symbol) [0x0043E232]
# 	(No symbol) [0x0042A784]
# 	(No symbol) [0x0043C922]
# 	(No symbol) [0x0042A536]
# 	(No symbol) [0x004082DC]
# 	(No symbol) [0x004093DD]
# 	GetHandleVerifier [0x007AAABD+2539405]
# 	GetHandleVerifier [0x007EA78F+2800735]
# 	GetHandleVerifier [0x007E456C+2775612]
# 	GetHandleVerifier [0x005D51E0+616112]
# 	(No symbol) [0x004E5F8C]
# 	(No symbol) [0x004E2328]
# 	(No symbol) [0x004E240B]
# 	(No symbol) [0x004D4FF7]
# 	BaseThreadInitThunk [0x762500C9+25]
# 	RtlGetAppContainerNamedObjectPath [0x774E7B4E+286]
# 	RtlGetAppContainerNamedObjectPath [0x774E7B1E+238]
#
# 24 pages left!
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="pnnext"]"}
#   (Session info: chrome=114.0.5735.199)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x0054A813+48355]
# 	(No symbol) [0x004DC4B1]
# 	(No symbol) [0x003E5358]
# 	(No symbol) [0x004109A5]
# 	(No symbol) [0x00410B3B]
# 	(No symbol) [0x0043E232]
# 	(No symbol) [0x0042A784]
# 	(No symbol) [0x0043C922]
# 	(No symbol) [0x0042A536]
# 	(No symbol) [0x004082DC]
# 	(No symbol) [0x004093DD]
# 	GetHandleVerifier [0x007AAABD+2539405]
# 	GetHandleVerifier [0x007EA78F+2800735]
# 	GetHandleVerifier [0x007E456C+2775612]
# 	GetHandleVerifier [0x005D51E0+616112]
# 	(No symbol) [0x004E5F8C]
# 	(No symbol) [0x004E2328]
# 	(No symbol) [0x004E240B]
# 	(No symbol) [0x004D4FF7]
# 	BaseThreadInitThunk [0x762500C9+25]
# 	RtlGetAppContainerNamedObjectPath [0x774E7B4E+286]
# 	RtlGetAppContainerNamedObjectPath [0x774E7B1E+238]
#
# 23 pages left!
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="pnnext"]"}
#   (Session info: chrome=114.0.5735.199)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x0054A813+48355]
# 	(No symbol) [0x004DC4B1]
# 	(No symbol) [0x003E5358]
# 	(No symbol) [0x004109A5]
# 	(No symbol) [0x00410B3B]
# 	(No symbol) [0x0043E232]
# 	(No symbol) [0x0042A784]
# 	(No symbol) [0x0043C922]
# 	(No symbol) [0x0042A536]
# 	(No symbol) [0x004082DC]
# 	(No symbol) [0x004093DD]
# 	GetHandleVerifier [0x007AAABD+2539405]
# 	GetHandleVerifier [0x007EA78F+2800735]
# 	GetHandleVerifier [0x007E456C+2775612]
# 	GetHandleVerifier [0x005D51E0+616112]
# 	(No symbol) [0x004E5F8C]
# 	(No symbol) [0x004E2328]
# 	(No symbol) [0x004E240B]
# 	(No symbol) [0x004D4FF7]
# 	BaseThreadInitThunk [0x762500C9+25]
# 	RtlGetAppContainerNamedObjectPath [0x774E7B4E+286]
# 	RtlGetAppContainerNamedObjectPath [0x774E7B1E+238]
#
# 22 pages left!
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="pnnext"]"}
#   (Session info: chrome=114.0.5735.199)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x0054A813+48355]
# 	(No symbol) [0x004DC4B1]
# 	(No symbol) [0x003E5358]
# 	(No symbol) [0x004109A5]
# 	(No symbol) [0x00410B3B]
# 	(No symbol) [0x0043E232]
# 	(No symbol) [0x0042A784]
# 	(No symbol) [0x0043C922]
# 	(No symbol) [0x0042A536]
# 	(No symbol) [0x004082DC]
# 	(No symbol) [0x004093DD]
# 	GetHandleVerifier [0x007AAABD+2539405]
# 	GetHandleVerifier [0x007EA78F+2800735]
# 	GetHandleVerifier [0x007E456C+2775612]
# 	GetHandleVerifier [0x005D51E0+616112]
# 	(No symbol) [0x004E5F8C]
# 	(No symbol) [0x004E2328]
# 	(No symbol) [0x004E240B]
# 	(No symbol) [0x004D4FF7]
# 	BaseThreadInitThunk [0x762500C9+25]
# 	RtlGetAppContainerNamedObjectPath [0x774E7B4E+286]
# 	RtlGetAppContainerNamedObjectPath [0x774E7B1E+238]
#
# 21 pages left!
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="pnnext"]"}
#   (Session info: chrome=114.0.5735.199)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x0054A813+48355]
# 	(No symbol) [0x004DC4B1]
# 	(No symbol) [0x003E5358]
# 	(No symbol) [0x004109A5]
# 	(No symbol) [0x00410B3B]
# 	(No symbol) [0x0043E232]
# 	(No symbol) [0x0042A784]
# 	(No symbol) [0x0043C922]
# 	(No symbol) [0x0042A536]
# 	(No symbol) [0x004082DC]
# 	(No symbol) [0x004093DD]
# 	GetHandleVerifier [0x007AAABD+2539405]
# 	GetHandleVerifier [0x007EA78F+2800735]
# 	GetHandleVerifier [0x007E456C+2775612]
# 	GetHandleVerifier [0x005D51E0+616112]
# 	(No symbol) [0x004E5F8C]
# 	(No symbol) [0x004E2328]
# 	(No symbol) [0x004E240B]
# 	(No symbol) [0x004D4FF7]
# 	BaseThreadInitThunk [0x762500C9+25]
# 	RtlGetAppContainerNamedObjectPath [0x774E7B4E+286]
# 	RtlGetAppContainerNamedObjectPath [0x774E7B1E+238]
#
# 20 pages left!
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="pnnext"]"}
#   (Session info: chrome=114.0.5735.199)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x0054A813+48355]
# 	(No symbol) [0x004DC4B1]
# 	(No symbol) [0x003E5358]
# 	(No symbol) [0x004109A5]
# 	(No symbol) [0x00410B3B]
# 	(No symbol) [0x0043E232]
# 	(No symbol) [0x0042A784]
# 	(No symbol) [0x0043C922]
# 	(No symbol) [0x0042A536]
# 	(No symbol) [0x004082DC]
# 	(No symbol) [0x004093DD]
# 	GetHandleVerifier [0x007AAABD+2539405]
# 	GetHandleVerifier [0x007EA78F+2800735]
# 	GetHandleVerifier [0x007E456C+2775612]
# 	GetHandleVerifier [0x005D51E0+616112]
# 	(No symbol) [0x004E5F8C]
# 	(No symbol) [0x004E2328]
# 	(No symbol) [0x004E240B]
# 	(No symbol) [0x004D4FF7]
# 	BaseThreadInitThunk [0x762500C9+25]
# 	RtlGetAppContainerNamedObjectPath [0x774E7B4E+286]
# 	RtlGetAppContainerNamedObjectPath [0x774E7B1E+238]
#
# 19 pages left!
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="pnnext"]"}
#   (Session info: chrome=114.0.5735.199)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x0054A813+48355]
# 	(No symbol) [0x004DC4B1]
# 	(No symbol) [0x003E5358]
# 	(No symbol) [0x004109A5]
# 	(No symbol) [0x00410B3B]
# 	(No symbol) [0x0043E232]
# 	(No symbol) [0x0042A784]
# 	(No symbol) [0x0043C922]
# 	(No symbol) [0x0042A536]
# 	(No symbol) [0x004082DC]
# 	(No symbol) [0x004093DD]
# 	GetHandleVerifier [0x007AAABD+2539405]
# 	GetHandleVerifier [0x007EA78F+2800735]
# 	GetHandleVerifier [0x007E456C+2775612]
# 	GetHandleVerifier [0x005D51E0+616112]
# 	(No symbol) [0x004E5F8C]
# 	(No symbol) [0x004E2328]
# 	(No symbol) [0x004E240B]
# 	(No symbol) [0x004D4FF7]
# 	BaseThreadInitThunk [0x762500C9+25]
# 	RtlGetAppContainerNamedObjectPath [0x774E7B4E+286]
# 	RtlGetAppContainerNamedObjectPath [0x774E7B1E+238]
#
# 18 pages left!
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="pnnext"]"}
#   (Session info: chrome=114.0.5735.199)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x0054A813+48355]
# 	(No symbol) [0x004DC4B1]
# 	(No symbol) [0x003E5358]
# 	(No symbol) [0x004109A5]
# 	(No symbol) [0x00410B3B]
# 	(No symbol) [0x0043E232]
# 	(No symbol) [0x0042A784]
# 	(No symbol) [0x0043C922]
# 	(No symbol) [0x0042A536]
# 	(No symbol) [0x004082DC]
# 	(No symbol) [0x004093DD]
# 	GetHandleVerifier [0x007AAABD+2539405]
# 	GetHandleVerifier [0x007EA78F+2800735]
# 	GetHandleVerifier [0x007E456C+2775612]
# 	GetHandleVerifier [0x005D51E0+616112]
# 	(No symbol) [0x004E5F8C]
# 	(No symbol) [0x004E2328]
# 	(No symbol) [0x004E240B]
# 	(No symbol) [0x004D4FF7]
# 	BaseThreadInitThunk [0x762500C9+25]
# 	RtlGetAppContainerNamedObjectPath [0x774E7B4E+286]
# 	RtlGetAppContainerNamedObjectPath [0x774E7B1E+238]
#
# 17 pages left!
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="pnnext"]"}
#   (Session info: chrome=114.0.5735.199)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x0054A813+48355]
# 	(No symbol) [0x004DC4B1]
# 	(No symbol) [0x003E5358]
# 	(No symbol) [0x004109A5]
# 	(No symbol) [0x00410B3B]
# 	(No symbol) [0x0043E232]
# 	(No symbol) [0x0042A784]
# 	(No symbol) [0x0043C922]
# 	(No symbol) [0x0042A536]
# 	(No symbol) [0x004082DC]
# 	(No symbol) [0x004093DD]
# 	GetHandleVerifier [0x007AAABD+2539405]
# 	GetHandleVerifier [0x007EA78F+2800735]
# 	GetHandleVerifier [0x007E456C+2775612]
# 	GetHandleVerifier [0x005D51E0+616112]
# 	(No symbol) [0x004E5F8C]
# 	(No symbol) [0x004E2328]
# 	(No symbol) [0x004E240B]
# 	(No symbol) [0x004D4FF7]
# 	BaseThreadInitThunk [0x762500C9+25]
# 	RtlGetAppContainerNamedObjectPath [0x774E7B4E+286]
# 	RtlGetAppContainerNamedObjectPath [0x774E7B1E+238]
#
# 16 pages left!
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="pnnext"]"}
#   (Session info: chrome=114.0.5735.199)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x0054A813+48355]
# 	(No symbol) [0x004DC4B1]
# 	(No symbol) [0x003E5358]
# 	(No symbol) [0x004109A5]
# 	(No symbol) [0x00410B3B]
# 	(No symbol) [0x0043E232]
# 	(No symbol) [0x0042A784]
# 	(No symbol) [0x0043C922]
# 	(No symbol) [0x0042A536]
# 	(No symbol) [0x004082DC]
# 	(No symbol) [0x004093DD]
# 	GetHandleVerifier [0x007AAABD+2539405]
# 	GetHandleVerifier [0x007EA78F+2800735]
# 	GetHandleVerifier [0x007E456C+2775612]
# 	GetHandleVerifier [0x005D51E0+616112]
# 	(No symbol) [0x004E5F8C]
# 	(No symbol) [0x004E2328]
# 	(No symbol) [0x004E240B]
# 	(No symbol) [0x004D4FF7]
# 	BaseThreadInitThunk [0x762500C9+25]
# 	RtlGetAppContainerNamedObjectPath [0x774E7B4E+286]
# 	RtlGetAppContainerNamedObjectPath [0x774E7B1E+238]
#
# 15 pages left!
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="pnnext"]"}
#   (Session info: chrome=114.0.5735.199)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x0054A813+48355]
# 	(No symbol) [0x004DC4B1]
# 	(No symbol) [0x003E5358]
# 	(No symbol) [0x004109A5]
# 	(No symbol) [0x00410B3B]
# 	(No symbol) [0x0043E232]
# 	(No symbol) [0x0042A784]
# 	(No symbol) [0x0043C922]
# 	(No symbol) [0x0042A536]
# 	(No symbol) [0x004082DC]
# 	(No symbol) [0x004093DD]
# 	GetHandleVerifier [0x007AAABD+2539405]
# 	GetHandleVerifier [0x007EA78F+2800735]
# 	GetHandleVerifier [0x007E456C+2775612]
# 	GetHandleVerifier [0x005D51E0+616112]
# 	(No symbol) [0x004E5F8C]
# 	(No symbol) [0x004E2328]
# 	(No symbol) [0x004E240B]
# 	(No symbol) [0x004D4FF7]
# 	BaseThreadInitThunk [0x762500C9+25]
# 	RtlGetAppContainerNamedObjectPath [0x774E7B4E+286]
# 	RtlGetAppContainerNamedObjectPath [0x774E7B1E+238]
#
# 14 pages left!
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="pnnext"]"}
#   (Session info: chrome=114.0.5735.199)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x0054A813+48355]
# 	(No symbol) [0x004DC4B1]
# 	(No symbol) [0x003E5358]
# 	(No symbol) [0x004109A5]
# 	(No symbol) [0x00410B3B]
# 	(No symbol) [0x0043E232]
# 	(No symbol) [0x0042A784]
# 	(No symbol) [0x0043C922]
# 	(No symbol) [0x0042A536]
# 	(No symbol) [0x004082DC]
# 	(No symbol) [0x004093DD]
# 	GetHandleVerifier [0x007AAABD+2539405]
# 	GetHandleVerifier [0x007EA78F+2800735]
# 	GetHandleVerifier [0x007E456C+2775612]
# 	GetHandleVerifier [0x005D51E0+616112]
# 	(No symbol) [0x004E5F8C]
# 	(No symbol) [0x004E2328]
# 	(No symbol) [0x004E240B]
# 	(No symbol) [0x004D4FF7]
# 	BaseThreadInitThunk [0x762500C9+25]
# 	RtlGetAppContainerNamedObjectPath [0x774E7B4E+286]
# 	RtlGetAppContainerNamedObjectPath [0x774E7B1E+238]
#
# 13 pages left!
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="pnnext"]"}
#   (Session info: chrome=114.0.5735.199)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x0054A813+48355]
# 	(No symbol) [0x004DC4B1]
# 	(No symbol) [0x003E5358]
# 	(No symbol) [0x004109A5]
# 	(No symbol) [0x00410B3B]
# 	(No symbol) [0x0043E232]
# 	(No symbol) [0x0042A784]
# 	(No symbol) [0x0043C922]
# 	(No symbol) [0x0042A536]
# 	(No symbol) [0x004082DC]
# 	(No symbol) [0x004093DD]
# 	GetHandleVerifier [0x007AAABD+2539405]
# 	GetHandleVerifier [0x007EA78F+2800735]
# 	GetHandleVerifier [0x007E456C+2775612]
# 	GetHandleVerifier [0x005D51E0+616112]
# 	(No symbol) [0x004E5F8C]
# 	(No symbol) [0x004E2328]
# 	(No symbol) [0x004E240B]
# 	(No symbol) [0x004D4FF7]
# 	BaseThreadInitThunk [0x762500C9+25]
# 	RtlGetAppContainerNamedObjectPath [0x774E7B4E+286]
# 	RtlGetAppContainerNamedObjectPath [0x774E7B1E+238]
#
# 12 pages left!
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="pnnext"]"}
#   (Session info: chrome=114.0.5735.199)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x0054A813+48355]
# 	(No symbol) [0x004DC4B1]
# 	(No symbol) [0x003E5358]
# 	(No symbol) [0x004109A5]
# 	(No symbol) [0x00410B3B]
# 	(No symbol) [0x0043E232]
# 	(No symbol) [0x0042A784]
# 	(No symbol) [0x0043C922]
# 	(No symbol) [0x0042A536]
# 	(No symbol) [0x004082DC]
# 	(No symbol) [0x004093DD]
# 	GetHandleVerifier [0x007AAABD+2539405]
# 	GetHandleVerifier [0x007EA78F+2800735]
# 	GetHandleVerifier [0x007E456C+2775612]
# 	GetHandleVerifier [0x005D51E0+616112]
# 	(No symbol) [0x004E5F8C]
# 	(No symbol) [0x004E2328]
# 	(No symbol) [0x004E240B]
# 	(No symbol) [0x004D4FF7]
# 	BaseThreadInitThunk [0x762500C9+25]
# 	RtlGetAppContainerNamedObjectPath [0x774E7B4E+286]
# 	RtlGetAppContainerNamedObjectPath [0x774E7B1E+238]
#
# 11 pages left!
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="pnnext"]"}
#   (Session info: chrome=114.0.5735.199)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x0054A813+48355]
# 	(No symbol) [0x004DC4B1]
# 	(No symbol) [0x003E5358]
# 	(No symbol) [0x004109A5]
# 	(No symbol) [0x00410B3B]
# 	(No symbol) [0x0043E232]
# 	(No symbol) [0x0042A784]
# 	(No symbol) [0x0043C922]
# 	(No symbol) [0x0042A536]
# 	(No symbol) [0x004082DC]
# 	(No symbol) [0x004093DD]
# 	GetHandleVerifier [0x007AAABD+2539405]
# 	GetHandleVerifier [0x007EA78F+2800735]
# 	GetHandleVerifier [0x007E456C+2775612]
# 	GetHandleVerifier [0x005D51E0+616112]
# 	(No symbol) [0x004E5F8C]
# 	(No symbol) [0x004E2328]
# 	(No symbol) [0x004E240B]
# 	(No symbol) [0x004D4FF7]
# 	BaseThreadInitThunk [0x762500C9+25]
# 	RtlGetAppContainerNamedObjectPath [0x774E7B4E+286]
# 	RtlGetAppContainerNamedObjectPath [0x774E7B1E+238]
#
# 10 pages left!
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="pnnext"]"}
#   (Session info: chrome=114.0.5735.199)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x0054A813+48355]
# 	(No symbol) [0x004DC4B1]
# 	(No symbol) [0x003E5358]
# 	(No symbol) [0x004109A5]
# 	(No symbol) [0x00410B3B]
# 	(No symbol) [0x0043E232]
# 	(No symbol) [0x0042A784]
# 	(No symbol) [0x0043C922]
# 	(No symbol) [0x0042A536]
# 	(No symbol) [0x004082DC]
# 	(No symbol) [0x004093DD]
# 	GetHandleVerifier [0x007AAABD+2539405]
# 	GetHandleVerifier [0x007EA78F+2800735]
# 	GetHandleVerifier [0x007E456C+2775612]
# 	GetHandleVerifier [0x005D51E0+616112]
# 	(No symbol) [0x004E5F8C]
# 	(No symbol) [0x004E2328]
# 	(No symbol) [0x004E240B]
# 	(No symbol) [0x004D4FF7]
# 	BaseThreadInitThunk [0x762500C9+25]
# 	RtlGetAppContainerNamedObjectPath [0x774E7B4E+286]
# 	RtlGetAppContainerNamedObjectPath [0x774E7B1E+238]
#
# 9 pages left!
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="pnnext"]"}
#   (Session info: chrome=114.0.5735.199)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x0054A813+48355]
# 	(No symbol) [0x004DC4B1]
# 	(No symbol) [0x003E5358]
# 	(No symbol) [0x004109A5]
# 	(No symbol) [0x00410B3B]
# 	(No symbol) [0x0043E232]
# 	(No symbol) [0x0042A784]
# 	(No symbol) [0x0043C922]
# 	(No symbol) [0x0042A536]
# 	(No symbol) [0x004082DC]
# 	(No symbol) [0x004093DD]
# 	GetHandleVerifier [0x007AAABD+2539405]
# 	GetHandleVerifier [0x007EA78F+2800735]
# 	GetHandleVerifier [0x007E456C+2775612]
# 	GetHandleVerifier [0x005D51E0+616112]
# 	(No symbol) [0x004E5F8C]
# 	(No symbol) [0x004E2328]
# 	(No symbol) [0x004E240B]
# 	(No symbol) [0x004D4FF7]
# 	BaseThreadInitThunk [0x762500C9+25]
# 	RtlGetAppContainerNamedObjectPath [0x774E7B4E+286]
# 	RtlGetAppContainerNamedObjectPath [0x774E7B1E+238]
#
# 8 pages left!
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="pnnext"]"}
#   (Session info: chrome=114.0.5735.199)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x0054A813+48355]
# 	(No symbol) [0x004DC4B1]
# 	(No symbol) [0x003E5358]
# 	(No symbol) [0x004109A5]
# 	(No symbol) [0x00410B3B]
# 	(No symbol) [0x0043E232]
# 	(No symbol) [0x0042A784]
# 	(No symbol) [0x0043C922]
# 	(No symbol) [0x0042A536]
# 	(No symbol) [0x004082DC]
# 	(No symbol) [0x004093DD]
# 	GetHandleVerifier [0x007AAABD+2539405]
# 	GetHandleVerifier [0x007EA78F+2800735]
# 	GetHandleVerifier [0x007E456C+2775612]
# 	GetHandleVerifier [0x005D51E0+616112]
# 	(No symbol) [0x004E5F8C]
# 	(No symbol) [0x004E2328]
# 	(No symbol) [0x004E240B]
# 	(No symbol) [0x004D4FF7]
# 	BaseThreadInitThunk [0x762500C9+25]
# 	RtlGetAppContainerNamedObjectPath [0x774E7B4E+286]
# 	RtlGetAppContainerNamedObjectPath [0x774E7B1E+238]
#
# 7 pages left!
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="pnnext"]"}
#   (Session info: chrome=114.0.5735.199)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x0054A813+48355]
# 	(No symbol) [0x004DC4B1]
# 	(No symbol) [0x003E5358]
# 	(No symbol) [0x004109A5]
# 	(No symbol) [0x00410B3B]
# 	(No symbol) [0x0043E232]
# 	(No symbol) [0x0042A784]
# 	(No symbol) [0x0043C922]
# 	(No symbol) [0x0042A536]
# 	(No symbol) [0x004082DC]
# 	(No symbol) [0x004093DD]
# 	GetHandleVerifier [0x007AAABD+2539405]
# 	GetHandleVerifier [0x007EA78F+2800735]
# 	GetHandleVerifier [0x007E456C+2775612]
# 	GetHandleVerifier [0x005D51E0+616112]
# 	(No symbol) [0x004E5F8C]
# 	(No symbol) [0x004E2328]
# 	(No symbol) [0x004E240B]
# 	(No symbol) [0x004D4FF7]
# 	BaseThreadInitThunk [0x762500C9+25]
# 	RtlGetAppContainerNamedObjectPath [0x774E7B4E+286]
# 	RtlGetAppContainerNamedObjectPath [0x774E7B1E+238]
#
# 6 pages left!
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="pnnext"]"}
#   (Session info: chrome=114.0.5735.199)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x0054A813+48355]
# 	(No symbol) [0x004DC4B1]
# 	(No symbol) [0x003E5358]
# 	(No symbol) [0x004109A5]
# 	(No symbol) [0x00410B3B]
# 	(No symbol) [0x0043E232]
# 	(No symbol) [0x0042A784]
# 	(No symbol) [0x0043C922]
# 	(No symbol) [0x0042A536]
# 	(No symbol) [0x004082DC]
# 	(No symbol) [0x004093DD]
# 	GetHandleVerifier [0x007AAABD+2539405]
# 	GetHandleVerifier [0x007EA78F+2800735]
# 	GetHandleVerifier [0x007E456C+2775612]
# 	GetHandleVerifier [0x005D51E0+616112]
# 	(No symbol) [0x004E5F8C]
# 	(No symbol) [0x004E2328]
# 	(No symbol) [0x004E240B]
# 	(No symbol) [0x004D4FF7]
# 	BaseThreadInitThunk [0x762500C9+25]
# 	RtlGetAppContainerNamedObjectPath [0x774E7B4E+286]
# 	RtlGetAppContainerNamedObjectPath [0x774E7B1E+238]
#
# 5 pages left!
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="pnnext"]"}
#   (Session info: chrome=114.0.5735.199)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x0054A813+48355]
# 	(No symbol) [0x004DC4B1]
# 	(No symbol) [0x003E5358]
# 	(No symbol) [0x004109A5]
# 	(No symbol) [0x00410B3B]
# 	(No symbol) [0x0043E232]
# 	(No symbol) [0x0042A784]
# 	(No symbol) [0x0043C922]
# 	(No symbol) [0x0042A536]
# 	(No symbol) [0x004082DC]
# 	(No symbol) [0x004093DD]
# 	GetHandleVerifier [0x007AAABD+2539405]
# 	GetHandleVerifier [0x007EA78F+2800735]
# 	GetHandleVerifier [0x007E456C+2775612]
# 	GetHandleVerifier [0x005D51E0+616112]
# 	(No symbol) [0x004E5F8C]
# 	(No symbol) [0x004E2328]
# 	(No symbol) [0x004E240B]
# 	(No symbol) [0x004D4FF7]
# 	BaseThreadInitThunk [0x762500C9+25]
# 	RtlGetAppContainerNamedObjectPath [0x774E7B4E+286]
# 	RtlGetAppContainerNamedObjectPath [0x774E7B1E+238]
#
# 4 pages left!
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="pnnext"]"}
#   (Session info: chrome=114.0.5735.199)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x0054A813+48355]
# 	(No symbol) [0x004DC4B1]
# 	(No symbol) [0x003E5358]
# 	(No symbol) [0x004109A5]
# 	(No symbol) [0x00410B3B]
# 	(No symbol) [0x0043E232]
# 	(No symbol) [0x0042A784]
# 	(No symbol) [0x0043C922]
# 	(No symbol) [0x0042A536]
# 	(No symbol) [0x004082DC]
# 	(No symbol) [0x004093DD]
# 	GetHandleVerifier [0x007AAABD+2539405]
# 	GetHandleVerifier [0x007EA78F+2800735]
# 	GetHandleVerifier [0x007E456C+2775612]
# 	GetHandleVerifier [0x005D51E0+616112]
# 	(No symbol) [0x004E5F8C]
# 	(No symbol) [0x004E2328]
# 	(No symbol) [0x004E240B]
# 	(No symbol) [0x004D4FF7]
# 	BaseThreadInitThunk [0x762500C9+25]
# 	RtlGetAppContainerNamedObjectPath [0x774E7B4E+286]
# 	RtlGetAppContainerNamedObjectPath [0x774E7B1E+238]
#
# 3 pages left!
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="pnnext"]"}
#   (Session info: chrome=114.0.5735.199)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x0054A813+48355]
# 	(No symbol) [0x004DC4B1]
# 	(No symbol) [0x003E5358]
# 	(No symbol) [0x004109A5]
# 	(No symbol) [0x00410B3B]
# 	(No symbol) [0x0043E232]
# 	(No symbol) [0x0042A784]
# 	(No symbol) [0x0043C922]
# 	(No symbol) [0x0042A536]
# 	(No symbol) [0x004082DC]
# 	(No symbol) [0x004093DD]
# 	GetHandleVerifier [0x007AAABD+2539405]
# 	GetHandleVerifier [0x007EA78F+2800735]
# 	GetHandleVerifier [0x007E456C+2775612]
# 	GetHandleVerifier [0x005D51E0+616112]
# 	(No symbol) [0x004E5F8C]
# 	(No symbol) [0x004E2328]
# 	(No symbol) [0x004E240B]
# 	(No symbol) [0x004D4FF7]
# 	BaseThreadInitThunk [0x762500C9+25]
# 	RtlGetAppContainerNamedObjectPath [0x774E7B4E+286]
# 	RtlGetAppContainerNamedObjectPath [0x774E7B1E+238]
#
# 2 pages left!
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="pnnext"]"}
#   (Session info: chrome=114.0.5735.199)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x0054A813+48355]
# 	(No symbol) [0x004DC4B1]
# 	(No symbol) [0x003E5358]
# 	(No symbol) [0x004109A5]
# 	(No symbol) [0x00410B3B]
# 	(No symbol) [0x0043E232]
# 	(No symbol) [0x0042A784]
# 	(No symbol) [0x0043C922]
# 	(No symbol) [0x0042A536]
# 	(No symbol) [0x004082DC]
# 	(No symbol) [0x004093DD]
# 	GetHandleVerifier [0x007AAABD+2539405]
# 	GetHandleVerifier [0x007EA78F+2800735]
# 	GetHandleVerifier [0x007E456C+2775612]
# 	GetHandleVerifier [0x005D51E0+616112]
# 	(No symbol) [0x004E5F8C]
# 	(No symbol) [0x004E2328]
# 	(No symbol) [0x004E240B]
# 	(No symbol) [0x004D4FF7]
# 	BaseThreadInitThunk [0x762500C9+25]
# 	RtlGetAppContainerNamedObjectPath [0x774E7B4E+286]
# 	RtlGetAppContainerNamedObjectPath [0x774E7B1E+238]
#
# 1 pages left!
# I am done ---> 39
# if there is a problem, start with 40
# 30 pages left!
# 29 pages left!
# 28 pages left!
# 27 pages left!
# 26 pages left!
# 25 pages left!
# 24 pages left!
# 23 pages left!
# 22 pages left!
# 21 pages left!
# 20 pages left!
# 19 pages left!
# 18 pages left!
# 17 pages left!
# 16 pages left!
# 15 pages left!
# 14 pages left!
# 13 pages left!
# 12 pages left!
# 11 pages left!
# 10 pages left!
# 9 pages left!
# 8 pages left!
# 7 pages left!
# 6 pages left!
# 5 pages left!
# 4 pages left!
# 3 pages left!
# 2 pages left!
# 1 pages left!
# I am done ---> 40
# if there is a problem, start with 41
# 30 pages left!
# 29 pages left!
# 28 pages left!
# 27 pages left!
# 26 pages left!
# 25 pages left!
# 24 pages left!
# 23 pages left!
# 22 pages left!
# 21 pages left!
# 20 pages left!
# 19 pages left!
# 18 pages left!
# 17 pages left!
# 16 pages left!
# 15 pages left!
# 14 pages left!
# 13 pages left!
# 12 pages left!
# 11 pages left!
# 10 pages left!
# 9 pages left!
# 8 pages left!
# 7 pages left!
# 6 pages left!
# 5 pages left!
# 4 pages left!
# 3 pages left!
# 2 pages left!
# 1 pages left!
# I am done ---> 41
# if there is a problem, start with 42
# 30 pages left!
# 29 pages left!
# 28 pages left!
# 27 pages left!
# 26 pages left!
# 25 pages left!
# 24 pages left!
# 23 pages left!
# 22 pages left!
# 21 pages left!
# 20 pages left!
# 19 pages left!
# 18 pages left!
# 17 pages left!
# 16 pages left!
# 15 pages left!
# 14 pages left!

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By

chrome_driver_path = Service(
    "C:\Development\chromedriver_win32\chromedriver.exe")
driver = webdriver.Chrome(service=chrome_driver_path)
URL = "https://en.wikipedia.org/wiki/Main_Page"
driver.get(URL)

# %%
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from selenium import webdriver
import time
import pandas as pd

chrome_driver_path = Service(
    "chromedriver.exe")
driver = webdriver.Chrome(service=chrome_driver_path)

# options = Options()
# options.add_argument("user-data-dir=C:\\Users\\Username\\AppData\\Local\\Google\\Chrome\\User Data")
# driver = webdriver.Chrome(options=options)
# 'Mathematics and Bachelor words are used as a default, it is changeble
driver.get('https://www.google.com/search?q=site:nl.linkedin.com/in/+AND+%22Computational Social Science%22+AND+%22Bachelor%27s&sxsrf=ALiCzsbOTqrA98wDQf3mtEB03kA_O7eCbQ:1668686082134&ei=AiF2Y4vwB-3JrgS9gpd4&start=50&sa=N&ved=2ahUKEwiL-aqJlLX7AhXtpIsKHT3BBQ84KBDy0wN6BAgBEA0&biw=920&bih=625&dpr=1')
time.sleep(10) # to make slower 

 # n is the number of pages
links = [] # save links here
n=6
while n > 0:
    time.sleep(5)
    for i in range(1, 11): # google uses paginator, every page has 10 urls
        time.sleep(6)
        try:
            elems = driver.find_elements(By.XPATH, '//*[@id="rso"]/div['+str(i)+']/div/div/div[1]/div/a')
            for elem in elems:
                
                clean_url = elem.get_attribute("href") # extracting url 
                base_url = "linkedin.com/in/"
                if clean_url.find(base_url) != -1 and '%' not in clean_url: # sometimes google gives no Ln urls, so clean it
                    links.append(clean_url)
                    print(f"url is --->{clean_url}")
        except Exception as e:
            print(e)
            pass
    try:
        next_button = driver.find_element(By.XPATH, '//*[@id="pnnext"]') # clicking next button 
        next_button.click()
    except Exception as e:
        print(e)
    print(f'{n} pages left!')
    n -= 1
df = pd.DataFrame({
    "links":links
})
df.to_csv('datas/linkedin_aaccount_links/Filosofie.csv', index=False)
