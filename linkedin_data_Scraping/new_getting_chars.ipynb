# %%
from bs4 import BeautifulSoup
import time
from selenium.webdriver.chrome.options import Options
from selenium import webdriver
from selenium.webdriver.common.by import By
import pandas as pd

options = Options()
options.add_argument("user-data-dir=C:/Users/dell/AppData/Local/Google/Chrome/User Data/Profile 12")
driver = webdriver.Chrome(options=options,executable_path='C:/Users/dell/OneDrive/Desktop/chromedriver.exe')
driver.get('https://www.crystalknows.com/app/register')
time.sleep(10)

df= pd.read_csv(f'../linkedin_data_Scraping/15000_linkedin_profiles.csv')
df=df[4010:6000]
j=0
for study in range(4000,6000):
    j+=1
    try:
        dots=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/div[1]/nav/div/div/div/div[6]/div/div[1]/div[2]/div/div/div')
        dots.click()
        time.sleep(2)
    except:
        print('dots problem')
    try:
        logout=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/div[1]/nav/div/div/div/div[6]/div/div[2]/div[6]/a')
        logout.click()
        time.sleep(5)
    except:
        print('logout problem')
    try:
        signup=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div[3]/div/form/div[3]/div/a')
        signup.click()
        time.sleep(8)
    except:
        print('signup probelm')
    try:
        first_name_input=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div[2]/div[3]/div[1]/input')
        first_name_input.click()
        first_name_input.send_keys(f'Alibek')
    except Exception as e:
        print('first_name-->problem')
    try:
        last_name_input=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div[2]/div[3]/div[2]/input')
        last_name_input.click()
        last_name_input.send_keys(f'Aliyev')
    except Exception as e:
        print('last_name-->problem')
    try:
        comp_email_input=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div[2]/div[4]/div/input')
        comp_email_input.click()
        comp_email_input.send_keys(f'shod2j5vk3{str(j)+str(study)}@mail.ru')
    except Exception as e:
        print('comp_email-->problem')
    try:
        first_pass_input=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div[2]/div[5]/div[1]/input')
        first_pass_input.click()
        first_pass_input.send_keys('Aa2301667')
    except Exception as e:
        print('first_pass-->problem')
    try:    
        sec_pass_input=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div[2]/div[5]/div[2]/input')
        sec_pass_input.click()
        sec_pass_input.send_keys('Aa2301667')
    except Exception as e:
        print('sec_pass-->problem')
    try:
        agree_button=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div[2]/div[6]/div/label/div/img')
        agree_button.click()
    except Exception as e:
        print('agree_button-->problem')
    try:                                            #/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div/div[6]/button
        signup_button=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div[2]/div[7]/button')
        signup_button.click()
        time.sleep(10)
    except Exception as e:
        print('signup_button-->problem')
    try:
        country_button=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[1]/div[2]/div/div[2]/img')
        country_button.click()
        first_country=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[1]/div[2]/div[2]/div[1]')
        first_country.click()
    except Exception as e:
        print('country_button-->problem')                                # second country    '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[1]/div[2]/div[2]/div[2]'
    try:
        job_title_input=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[2]/div[2]/div/input')
        job_title_input.click()
        job_title_input.send_keys('software engineer')
    except Exception as e:
        print('job_title-->problem')
    try:    
        my_department_input=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[2]/div[4]/div[1]/div[2]/img')
        my_department_input.click()
        first_department=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[2]/div[4]/div[2]/div[6]')                              #  second department           '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[2]/div[3]/div[2]/div[2]'
        first_department.click()
    except Exception as e:
        print('department-->problem')
    try:    
        next_button=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[2]/a')
        next_button.click()
        time.sleep(10)
    except Exception as e:
        print('next_button-->problem')
    i=0
    dict_={}
    st1=4010
    for link in df.links[st1:study]:
        print('AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA')
        print(i)
        st1=study
        print(f"ST1{st1}")
        print(f"STUDY1{study}")
        i+=1
        try: 
            link_enterong_button=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/div[1]/nav/div/div[1]/div/div[1]/div/input')
            link_enterong_button.click()
            link_enterong_button.clear()
            link_enterong_button.send_keys(link)
            time.sleep(8) 
        except Exception as e:
            print("linkedin user not found")
        try:                          
            first_user=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/div[1]/nav/div/div[1]/div/div[1]/div/div[2]/div/div/div/div/div[2]')
            first_user.click()
            time.sleep(10)
    
            dict_[link]=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/div[1]/div/div/div[1]/div/span').text
            print(dict_[link])
        except Exception as e:
            dict_[link]='nan'

        print(f'IIIIIIIIIIII{i}')
        if i%10==0:
            print('Matched!!')
            try:
                dots1=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/div[1]/nav/div/div[1]/div/div[6]/div/div[1]/div[2]/div/div')
                dots1.click()
                print(dots1)
                time.sleep(2)

                logout1=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/div[1]/nav/div/div/div/div[6]/div/div[2]/div[6]/a')
                logout1.click()
                time.sleep(5)
                signup=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div[3]/div/form/div[3]/div/a')
                signup.click()
                time.sleep(8)

                first_name_input=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div[2]/div[3]/div[1]/input')
                # first_name_input.click()                        /html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div[2]/div[4]/div/input
                first_name_input.send_keys(f'Abror+{str(i)}')
            
                last_name_input=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div[2]/div[3]/div[2]/input')
                last_name_input.click()
                last_name_input.send_keys(f'Aliyev{str(i)}')
                comp_email_input_for_10=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div[2]/div[4]/div/input')
                comp_email_input_for_10.click()
                comp_email_input_for_10.send_keys(f'ami2skhj66on3{str(study//i)}{str(i)}@mail.ru')
            
                first_pass_input=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div[2]/div[5]/div[1]/input')
                first_pass_input.click()
                first_pass_input.send_keys('12345678')
                
                sec_pass_input=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div[2]/div[5]/div[2]/input')
                sec_pass_input.click()
                sec_pass_input.send_keys('12345678')
            
                agree_button1=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div[2]/div[6]/div/label/div/img')
                agree_button1.click()
        
                signup_button1=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div[2]/div[7]/button')
                signup_button1.click()
                time.sleep(10)
            
                country_button=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[1]/div[2]/div/div[2]/img')
                country_button.click()

                first_country=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[1]/div[2]/div[2]/div[4]')
                first_country.click()
            except Exception as e:
                print('i is divisible 10-->problem')                                # second country    '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[1]/div[2]/div[2]/div[2]'
            try:
                job_title_input=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[2]/div[2]/div/input')
                job_title_input.click()
                job_title_input.send_keys('software engineer')
            except Exception as e:
                print('job_title-->problem')
            try:    
                my_department_input=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[2]/div[4]/div/div[2]/img')
                my_department_input.click()
                first_department=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[2]/div[4]/div[2]/div[4]')
                first_department.click()
            except Exception as e:
                print('department-->problem')
            try:    
                next_button=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[2]/a')
                next_button.click()
                time.sleep(10)
            except Exception as e:
                print('next_button-->problem')
        if len(dict_)%100==0:
            df1 = pd.DataFrame({
            'links':list(dict_.keys()),
            'characters':list(dict_.values())
            })
            x = len(dict_)//100
            df1.to_csv(f'datas/cs_values_new/extra_data/data_till_6000{x}.csv', index=False)
    df1 = pd.DataFrame({
    'links':list(dict_.keys()),
    'characters':list(dict_.values())
    })
    df1.to_csv(f'datas/cs_values_new/data_till_6000{study}.csv', index=False)
    print(list(dict_.values())[-10:])
    print(f'{study} is done!')
# Out:
# C:\Users\fayyo\AppData\Local\Temp\ipykernel_11352\1362979513.py:10: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(options=options,executable_path='C:/Users/dell/OneDrive/Desktop/chromedriver.exe')
# Incompatible release of chromedriver (version 111.0.5563.64) detected in PATH: c:\Users\GitHub\Bots_using_selenium\linkedin_data_Scraping\chromedriver.exe
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# Cell In[3], line 10
#       8 options = Options()
#       9 options.add_argument("user-data-dir=C:/Users/dell/AppData/Local/Google/Chrome/User Data/Profile 12")
# ---> 10 driver = webdriver.Chrome(options=options,executable_path='C:/Users/dell/OneDrive/Desktop/chromedriver.exe')
#      11 driver.get('https://www.crystalknows.com/app/register')
#      12 time.sleep(10)
#
# File c:\Users\GitHub\Bots_using_selenium\venv\lib\site-packages\selenium\webdriver\chrome\webdriver.py:84, in WebDriver.__init__(self, executable_path, port, options, service_args, desired_capabilities, service_log_path, chrome_options, service, keep_alive)
#      81     service = Service(executable_path, port, service_args, service_log_path)
#      82 service.path = DriverFinder.get_path(service, options)
# ---> 84 super().__init__(
#      85     DesiredCapabilities.CHROME["browserName"],
#      86     "goog",
#      87     port,
#      88     options,
#      89     service_args,
#      90     desired_capabilities,
#      91     service_log_path,
#      92     service,
#      93     keep_alive,
#      94 )
#
# File c:\Users\GitHub\Bots_using_selenium\venv\lib\site-packages\selenium\webdriver\chromium\webdriver.py:104, in ChromiumDriver.__init__(self, browser_name, vendor_prefix, port, options, service_args, desired_capabilities, service_log_path, service, keep_alive)
#     101 self.service.start()
#     103 try:
# --> 104     super().__init__(
#     105         command_executor=ChromiumRemoteConnection(
#     106             remote_server_addr=self.service.service_url,
#     107             browser_name=browser_name,
#     108             vendor_prefix=vendor_prefix,
#     109             keep_alive=keep_alive,
#     110             ignore_proxy=_ignore_proxy,
#     111         ),
#     112         options=options,
#     113     )
#     114 except Exception:
#     115     self.quit()
#
# File c:\Users\GitHub\Bots_using_selenium\venv\lib\site-packages\selenium\webdriver\remote\webdriver.py:286, in WebDriver.__init__(self, command_executor, desired_capabilities, browser_profile, proxy, keep_alive, file_detector, options)
#     284 self._authenticator_id = None
#     285 self.start_client()
# --> 286 self.start_session(capabilities, browser_profile)
#
# File c:\Users\GitHub\Bots_using_selenium\venv\lib\site-packages\selenium\webdriver\remote\webdriver.py:378, in WebDriver.start_session(self, capabilities, browser_profile)
#     376 w3c_caps = _make_w3c_caps(capabilities)
#     377 parameters = {"capabilities": w3c_caps}
# --> 378 response = self.execute(Command.NEW_SESSION, parameters)
#     379 if "sessionId" not in response:
#     380     response = response["value"]
#
# File c:\Users\GitHub\Bots_using_selenium\venv\lib\site-packages\selenium\webdriver\remote\webdriver.py:440, in WebDriver.execute(self, driver_command, params)
#     438 response = self.command_executor.execute(driver_command, params)
#     439 if response:
# --> 440     self.error_handler.check_response(response)
#     441     response["value"] = self._unwrap_value(response.get("value", None))
#     442     return response
#
# File c:\Users\GitHub\Bots_using_selenium\venv\lib\site-packages\selenium\webdriver\remote\errorhandler.py:245, in ErrorHandler.check_response(self, response)
#     243         alert_text = value["alert"].get("text")
#     244     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 245 raise exception_class(message, screen, stacktrace)
#
# WebDriverException: Message: unknown error: Chrome failed to start: exited normally.
#   (unknown error: DevToolsActivePort file doesn't exist)
#   (The process started from chrome location C:\Program Files\Google\Chrome\Application\chrome.exe is no longer running, so ChromeDriver is assuming that Chrome has crashed.)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x00A1A813+48355]
# 	(No symbol) [0x009AC4B1]
# 	(No symbol) [0x008B5358]
# 	(No symbol) [0x008D3621]
# 	(No symbol) [0x008D0579]
# 	(No symbol) [0x00900C55]
# 	(No symbol) [0x0090093C]
# 	(No symbol) [0x008FA536]
# 	(No symbol) [0x008D82DC]
# 	(No symbol) [0x008D93DD]
# 	GetHandleVerifier [0x00C7AABD+2539405]
# 	GetHandleVerifier [0x00CBA78F+2800735]
# 	GetHandleVerifier [0x00CB456C+2775612]
# 	GetHandleVerifier [0x00AA51E0+616112]
# 	(No symbol) [0x009B5F8C]
# 	(No symbol) [0x009B2328]
# 	(No symbol) [0x009B240B]
# 	(No symbol) [0x009A4FF7]
# 	BaseThreadInitThunk [0x75D200C9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77EB7B1E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77EB7AEE+238]

# %%
from bs4 import BeautifulSoup
import time
from selenium.webdriver.chrome.options import Options
from selenium import webdriver
from selenium.webdriver.common.by import By
import pandas as pd
from selenium.webdriver.common.keys import Keys

options = Options()
options.add_argument("user-data-dir=C:/Users/dell/AppData/Local/Google/Chrome/User Data/Profile 15")
driver = webdriver.Chrome(options=options,executable_path='C:/Users/dell/OneDrive/Desktop/chromedriver.exe')
driver.get('https://www.crystalknows.com/app/ce/installed')
time.sleep(10)

df= pd.read_csv(f'../linkedin_data_Scraping/15000_linkedin_profiles.csv')
df=df[2010:4000]
j=0
for study in range(8000, 10000, 100):
    j+=1
    try:
        try:
            dots=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/div[1]/nav/div/div/div/div[6]/div/div[1]/div[2]/div/div/div')
            dots.click()
            time.sleep(2)
        except:
            print('dots problem')
        try:
            logout=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/div[1]/nav/div/div/div/div[6]/div/div[2]/div[6]/a')
            logout.click()
            time.sleep(5)
        except:
            print('logout problem')
        try:
            signup=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div[3]/div/form/div[3]/div/a')
            signup.click()
            time.sleep(8)
        except:
            print('signup probelm')
        try:
            first_name_input=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div[2]/div[3]/div[1]/input')
            first_name_input.click()
            first_name_input.send_keys(f'Alibek')
        except Exception as e:
            print('first_name-->problem')
        try:
            last_name_input=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div[2]/div[3]/div[2]/input')
            last_name_input.click()
            last_name_input.send_keys(f'Aliyev')
        except Exception as e:
            print('last_name-->problem')
        try:
            comp_email_input=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div[2]/div[4]/div/input')
            comp_email_input.click()
            comp_email_input.send_keys(f'shodavaldKiFG5{str(j)+str(study)}@mail.ru')
        except Exception as e:
            print('comp_email-->problem')
        try:
            first_pass_input=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div[2]/div[5]/div[1]/input')
            first_pass_input.click()
            first_pass_input.send_keys('Aa2301667')
        except Exception as e:
            print('first_pass-->problem')
        try:    
            sec_pass_input=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div[2]/div[5]/div[2]/input')
            sec_pass_input.click()
            sec_pass_input.send_keys('Aa2301667')
        except Exception as e:
            print('sec_pass-->problem')
        try:
            agree_button=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div[2]/div[6]/div/label/div/img')
            agree_button.click()
        except Exception as e:
            print('agree_button-->problem')
        try:                                            #/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div/div[6]/button
            signup_button=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div[2]/div[7]/button')
            signup_button.click()
            time.sleep(10)
        except Exception as e:
            print('signup_button-->problem')
        try:
            country_button=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[1]/div[2]/div/div[2]/img')
            country_button.click()
            first_country=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[1]/div[2]/div[2]/div[1]')
            first_country.click()
        except Exception as e:
            print('country_button-->problem')                                # second country    '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[1]/div[2]/div[2]/div[2]'
        try:
            job_title_input=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[2]/div[2]/div/input')
            job_title_input.click()
            job_title_input.send_keys('software engineer')
        except Exception as e:
            print('job_title-->problem')
        try:    
            my_department_input=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[2]/div[4]/div[1]/div[2]/img')
            my_department_input.click()
            first_department=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[2]/div[4]/div[2]/div[6]')                              #  second department           '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[2]/div[3]/div[2]/div[2]'
            first_department.click()
        except Exception as e:
            print('department-->problem')
        try:    
            next_button=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[2]/a')
            next_button.click()
            time.sleep(10)
        except Exception as e:
            print('next_button-->problem')
    except Exception as e:
        print('cannot create new account!')

    dict_={}
    try:
        people=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/div[1]/nav/div/div[2]/div[2]/a')
        people.click()
    except Exception as e:
        print("problem with people")
    try:
        add_profile=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/div[1]/nav/div/div[2]/div[2]/div/a[3]')
        add_profile.click()
    except Exception:
        print("problem with add profiles button")
    try:
        input_profiles=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/div/div[2]/div[1]/div[2]')
        input_profiles.click()
    except Exception:
        print('problem with input profiles')
    time.sleep(8)
    d=10
    extra=2000
    for lin in range(extra+d, extra+d+10):
        input_profiles=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/div/div[2]/div[1]/div[2]/input')
        input_profiles.click()
        time.sleep(3)
        # input_profiles.send_keys("olmalar")
        input_profiles.send_keys(str(df.links[lin]))
        time.sleep(3)
        input_profiles.click()
        time.sleep(2)
        input_profiles.send_keys(Keys.SPACE)
        # driver.find_element(By.XPATH,"/html/body/div[2]/div/div/div[4]/div/div[2]/div[1]/div[2]").send_keys(Keys.ENTER)
    d+=10   
    try:
        add_profiles_button=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/div/div[2]/div[2]/div/div/button')
        add_profiles_button.click()
    except Exception:
        print('AAAAAAAAAAAAAAA')
        #   name
    initialScroll = 0
    finalScroll = 1000
    start = time.time()
    while True:
        driver.execute_script(f"window.scrollTo({initialScroll}, {finalScroll})")
        initialScroll = finalScroll
        finalScroll += 1000
        time.sleep(3)
        end = time.time()
        if round(end - start) > 25:
            break
    names=[]
    links=[]
    
    for name in range(1,11):
        full_name=driver.find_element(By.XPATH, f'/html/body/div[2]/div/div/div[4]/div/div[2]/div[3]/table/tbody/tr[{str(name)}]/td[1]')
        names.append(full_name.text)             #/html/body/div[2]/div/div/div[4]/div/div[2]/div[3]/table/tbody/tr[1]/td[1]/a/span

        link_url=driver.find_element(By.XPATH, f"/html/body/div[2]/div/div/div[4]/div/div[2]/div[3]/table/tbody/tr[{str(name)}]/td[4]/a")     
        links.append(link_url.text)
    
    characters=[]
    for nam in names:
        time.sleep(3)
        first_user_input=driver.find_element(By.XPATH,'/html/body/div[2]/div/div/div[2]/div[1]/nav/div[1]/div[1]/div/div/input')
        first_user_input.click()
        first_user_input.send_keys(str(nam))
        time.sleep(2)
        try:
            first=driver.find_element(By.XPATH,'/html/body/div[2]/div/div/div[2]/div[1]/nav/div[1]/div[1]/div/div/div/div/div')
            first.click()
            time.sleep(4)
            char=driver.find_element(By.XPATH,'/html/body/div[2]/div/div/div[4]/div[1]/div/div/div[1]/div/span').text
            characters.append(char)
        except Exception:
            characters.append('nan')
    df=pd.DataFrame({
        "links"     :links,
        'characters':characters
    })
    df.to_csv(f'../linkedin_data_Scraping/datas/cs_values/15000_chars/data_till{extra+d}.csv')
    try:
        dots1=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/div[1]/nav/div/div[1]/div/div[6]/div/div[1]/div[2]/div/div')
        dots1.click()
        print(dots1)
        time.sleep(2)

        logout1=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/div[1]/nav/div/div/div/div[6]/div/div[2]/div[6]/a')
        logout1.click()
        time.sleep(5)
        signup=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div[3]/div/form/div[3]/div/a')
        signup.click()
        time.sleep(8)

        first_name_input=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div[2]/div[3]/div[1]/input')
        # first_name_input.click()                        /html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div[2]/div[4]/div/input
        first_name_input.send_keys(f'Abror+{str(d)}')
    
        last_name_input=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div[2]/div[3]/div[2]/input')
        last_name_input.click()
        last_name_input.send_keys(f'Aliyev{str(d)}')
        comp_email_input_for_10=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div[2]/div[4]/div/input')
        comp_email_input_for_10.click()
        comp_email_input_for_10.send_keys(f'amishohjon5{str(study//d)}{str(d)}@mail.ru')
    
        first_pass_input=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div[2]/div[5]/div[1]/input')
        first_pass_input.click()
        first_pass_input.send_keys('12345678')
        
        sec_pass_input=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div[2]/div[5]/div[2]/input')
        sec_pass_input.click()
        sec_pass_input.send_keys('12345678')
    
        agree_button1=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div[2]/div[6]/div/label/div/img')
        agree_button1.click()

        signup_button1=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div[2]/div[7]/button')
        signup_button1.click()
        time.sleep(10)
    
        country_button=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[1]/div[2]/div/div[2]/img')
        country_button.click()

        first_country=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[1]/div[2]/div[2]/div[4]')
        first_country.click()
    except Exception as e:
        print('i is divisible 10-->problem')                                # second country    '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[1]/div[2]/div[2]/div[2]'
    try:
        job_title_input=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[2]/div[2]/div/input')
        job_title_input.click()
        job_title_input.send_keys('software engineer')
    except Exception as e:
        print('job_title-->problem')
    try:    
        my_department_input=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[2]/div[4]/div/div[2]/img')
        my_department_input.click()
        first_department=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[2]/div[4]/div[2]/div[4]')
        first_department.click()
    except Exception as e:
        print('department-->problem')
    try:    
        next_button=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[2]/a')
        next_button.click()
        time.sleep(10)
    except Exception as e:
        print('next_button-->problem')
# Out:
# C:\Users\fayyo\AppData\Local\Temp\ipykernel_9112\2204273539.py:11: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(options=options,executable_path='C:/Users/dell/OneDrive/Desktop/chromedriver.exe')
# Incompatible release of chromedriver (version 111.0.5563.64) detected in PATH: c:\Users\GitHub\Bots_using_selenium\linkedin_data_Scraping\chromedriver.exe
# dots problem
# logout problem
# signup probelm
# first_name-->problem
# last_name-->problem
# comp_email-->problem
# first_pass-->problem
# sec_pass-->problem
# agree_button-->problem
# signup_button-->problem
# country_button-->problem
# job_title-->problem
# department-->problem
# next_button-->problem
# problem with input profiles
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Cell In[1], line 161
#     158 links=[]
#     160 for name in range(1,11):
# --> 161     full_name=driver.find_element(By.XPATH, f'/html/body/div[2]/div/div/div[4]/div/div[2]/div[3]/table/tbody/tr[{str(name)}]/td[1]')
#     162     names.append(full_name.text)             #/html/body/div[2]/div/div/div[4]/div/div[2]/div[3]/table/tbody/tr[1]/td[1]/a/span
#     164     link_url=driver.find_element(By.XPATH, f"/html/body/div[2]/div/div/div[4]/div/div[2]/div[3]/table/tbody/tr[{str(name)}]/td[4]/a")
#
# File c:\Users\GitHub\Bots_using_selenium\venv\lib\site-packages\selenium\webdriver\remote\webdriver.py:831, in WebDriver.find_element(self, by, value)
#     828     by = By.CSS_SELECTOR
#     829     value = f'[name="{value}"]'
# --> 831 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File c:\Users\GitHub\Bots_using_selenium\venv\lib\site-packages\selenium\webdriver\remote\webdriver.py:440, in WebDriver.execute(self, driver_command, params)
#     438 response = self.command_executor.execute(driver_command, params)
#     439 if response:
# --> 440     self.error_handler.check_response(response)
#     441     response["value"] = self._unwrap_value(response.get("value", None))
#     442     return response
#
# File c:\Users\GitHub\Bots_using_selenium\venv\lib\site-packages\selenium\webdriver\remote\errorhandler.py:245, in ErrorHandler.check_response(self, response)
#     243         alert_text = value["alert"].get("text")
#     244     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 245 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"/html/body/div[2]/div/div/div[4]/div/div[2]/div[3]/table/tbody/tr[1]/td[1]"}
#   (Session info: chrome=115.0.5790.170)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x00BCA813+48355]
# 	(No symbol) [0x00B5C4B1]
# 	(No symbol) [0x00A65358]
# 	(No symbol) [0x00A909A5]
# 	(No symbol) [0x00A90B3B]
# 	(No symbol) [0x00ABE232]
# 	(No symbol) [0x00AAA784]
# 	(No symbol) [0x00ABC922]
# 	(No symbol) [0x00AAA536]
# 	(No symbol) [0x00A882DC]
# 	(No symbol) [0x00A893DD]
# 	GetHandleVerifier [0x00E2AABD+2539405]
# 	GetHandleVerifier [0x00E6A78F+2800735]
# 	GetHandleVerifier [0x00E6456C+2775612]
# 	GetHandleVerifier [0x00C551E0+616112]
# 	(No symbol) [0x00B65F8C]
# 	(No symbol) [0x00B62328]
# 	(No symbol) [0x00B6240B]
# 	(No symbol) [0x00B54FF7]
# 	BaseThreadInitThunk [0x76DE00C9+25]
# 	RtlGetAppContainerNamedObjectPath [0x76F27B1E+286]
# 	RtlGetAppContainerNamedObjectPath [0x76F27AEE+238]

# %%
df.to_csv('linkedin_data_Scraping/datas/cs_values/15000_chars/olma.csv')

# %%
names
# Out:
# ['Lisa Dacosta',
#  'Elena Basilio',
#  'Verity Kerkhoff',
#  'Rosana Benatti',
#  'Olga Gandra',
#  'Asil Asil',
#  'Beth Hutchinson',
#  'Rebekah Lawler',
#  'Susana Matthews',
#  'sa ads']

# %%
for name in range(1,10):
    print(f'/html/body/div[2]/div/div/div[4]/div/div[2]/div[3]/table/tbody/tr[{str(name)}]/td[1]')
    full_name=driver.find_element(By.XPATH, f'/html/body/div[2]/div/div/div[4]/div/div[2]/div[3]/table/tbody/tr[{str(name)}]/td[1]')
# Out:
# /html/body/div[2]/div/div/div[4]/div/div[2]/div[3]/table/tbody/tr[1]/td[1]
# /html/body/div[2]/div/div/div[4]/div/div[2]/div[3]/table/tbody/tr[2]/td[1]
# /html/body/div[2]/div/div/div[4]/div/div[2]/div[3]/table/tbody/tr[3]/td[1]
# /html/body/div[2]/div/div/div[4]/div/div[2]/div[3]/table/tbody/tr[4]/td[1]
# /html/body/div[2]/div/div/div[4]/div/div[2]/div[3]/table/tbody/tr[5]/td[1]
# /html/body/div[2]/div/div/div[4]/div/div[2]/div[3]/table/tbody/tr[6]/td[1]
# /html/body/div[2]/div/div/div[4]/div/div[2]/div[3]/table/tbody/tr[7]/td[1]
# /html/body/div[2]/div/div/div[4]/div/div[2]/div[3]/table/tbody/tr[8]/td[1]
# /html/body/div[2]/div/div/div[4]/div/div[2]/div[3]/table/tbody/tr[9]/td[1]

# %%
full_name
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="2c5e4e2a7cfa3133b90d553ca4d208a3", element="251558039AE98D827B1BCE99BBE7593B_element_229")>

# %%
name
# Out:
# 0

# %%
type(str(df.links[lin]))
# Out:
# str

# %%
from bs4 import BeautifulSoup
import time
from selenium.webdriver.chrome.options import Options
from selenium import webdriver
from selenium.webdriver.common.by import By
import pandas as pd
from selenium.webdriver.common.keys import Keys

options = Options()
options.add_argument("user-data-dir=C:/Users/dell/AppData/Local/Google/Chrome/User Data/Profile 15")
driver = webdriver.Chrome(options=options,executable_path='C:/Users/dell/OneDrive/Desktop/chromedriver.exe')
driver.get('https://www.crystalknows.com/app/ce/installed')
time.sleep(10)

df= pd.read_csv(f'../linkedin_data_Scraping/15000_linkedin_profiles.csv')
j=0
for study in range(8000, 10000, 100):
    j+=1
    # study_num=l.index(study)
    try:
        try:
            dots=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/div[1]/nav/div/div/div/div[6]/div/div[1]/div[2]/div/div/div')
            dots.click()
            time.sleep(2)
        except:
            print('dots problem')
        try:
            logout=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/div[1]/nav/div/div/div/div[6]/div/div[2]/div[6]/a')
            logout.click()
            time.sleep(5)
        except:
            print('logout problem')
        try:
            signup=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div[3]/div/form/div[3]/div/a')
            signup.click()
            time.sleep(8)
        except:
            print('signup probelm')
        try:
            first_name_input=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div[2]/div[3]/div[1]/input')
            first_name_input.click()
            first_name_input.send_keys(f'Alibek')
        except Exception as e:
            print('first_name-->problem')
        try:
            last_name_input=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div[2]/div[3]/div[2]/input')
            last_name_input.click()
            last_name_input.send_keys(f'Aliyev')
        except Exception as e:
            print('last_name-->problem')
        try:
            comp_email_input=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div[2]/div[4]/div/input')
            comp_email_input.click()
            comp_email_input.send_keys(f'shodavaKLKli5{str(j)+str(study)}@mail.ru')
        except Exception as e:
            print('comp_email-->problem')
        try:
            first_pass_input=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div[2]/div[5]/div[1]/input')
            first_pass_input.click()
            first_pass_input.send_keys('Aa2301667')
        except Exception as e:
            print('first_pass-->problem')
        try:    
            sec_pass_input=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div[2]/div[5]/div[2]/input')
            sec_pass_input.click()
            sec_pass_input.send_keys('Aa2301667')
        except Exception as e:
            print('sec_pass-->problem')
        try:
            agree_button=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div[2]/div[6]/div/label/div/img')
            agree_button.click()
        except Exception as e:
            print('agree_button-->problem')
        try:                                            #/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div/div[6]/button
            signup_button=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div[2]/div[7]/button')
            signup_button.click()
            time.sleep(10)
        except Exception as e:
            print('signup_button-->problem')
        try:
            country_button=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[1]/div[2]/div/div[2]/img')
            country_button.click()
            first_country=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[1]/div[2]/div[2]/div[1]')
            first_country.click()
        except Exception as e:
            print('country_button-->problem')                                # second country    '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[1]/div[2]/div[2]/div[2]'
        try:
            job_title_input=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[2]/div[2]/div/input')
            job_title_input.click()
            job_title_input.send_keys('software engineer')
        except Exception as e:
            print('job_title-->problem')
        try:    
            my_department_input=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[2]/div[4]/div[1]/div[2]/img')
            my_department_input.click()
            first_department=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[2]/div[4]/div[2]/div[6]')                              #  second department           '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[2]/div[3]/div[2]/div[2]'
            first_department.click()
        except Exception as e:
            print('department-->problem')
        try:    
            next_button=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[2]/a')
            next_button.click()
            time.sleep(10)
        except Exception as e:
            print('next_button-->problem')
    except Exception as e:
        print('cannot create new account!')

    i=0
    # df_links = pd.read_csv(f'datas/linkedin_links/{study}.csv')
    # df = df_links.drop_duplicates()
    dict_={}
    # st1=0
    # for link in df.links[st1:study]:
    #     print('AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA')
    #     print(i)
    #     st1=study
    #     i+=1
    try:
        people=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/div[1]/nav/div/div[2]/div[2]/a')
        people.click()
    except Exception as e:
        print("problem with people")
    try:
        add_profile=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/div[1]/nav/div/div[2]/div[2]/div/a[3]')
        add_profile.click()
    except Exception:
        print("problem with add profiles button")
    try:
        input_profiles=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/div/div[2]/div[1]/div[2]')
        input_profiles.click()
    except Exception:
        print('problem with input profiles')
    for lin in range(10):
        input_profiles.send_keys(lin)
        driver.find_element_by_name("Value").send_keys(Keys.ENTER)
    
    try: 
        link_enterong_button=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/div[1]/nav/div/div[1]/div/div[1]/div/input')
        link_enterong_button.click()
        link_enterong_button.clear()
        link_enterong_button.send_keys(link)
        time.sleep(8) 
    except Exception as e:
        print("linkedin user not found")
    try:                          # /html/body/div[2]/div/div/div[2]/div[1]/nav/div/div[1]/div/div[1]/div/div[2]/div/div/div/div/div[2]
        first_user=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/div[1]/nav/div/div[1]/div/div[1]/div/div[2]/div/div/div/div/div[2]')
        first_user.click()
        time.sleep(10)
        src = driver.page_source
        soup = BeautifulSoup(src, 'lxml')
        cs=soup.find('div', {'class':'styles_disc-pill-wrapper__aB3OJ'})
        dict_[link]=cs.text.strip()
    except Exception as e:
        dict_[link]='nan'
    
    # price_butt=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/div[1]/nav/div/div[2]/div/div[1]').text
    # print(price_butt)
    print(f'IIIIIIIIIIII{i}')
    if i%10==0 and i!=0:
        print('Matched!!')
        try:
            dots1=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/div[1]/nav/div/div[1]/div/div[6]/div/div[1]/div[2]/div/div')
            dots1.click()
            print(dots1)
            time.sleep(2)

            logout1=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/div[1]/nav/div/div/div/div[6]/div/div[2]/div[6]/a')
            logout1.click()
            time.sleep(5)
            signup=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div[3]/div/form/div[3]/div/a')
            signup.click()
            time.sleep(8)

            first_name_input=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div[2]/div[3]/div[1]/input')
            # first_name_input.click()                        /html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div[2]/div[4]/div/input
            first_name_input.send_keys(f'Abror+{str(i)}')
        
            last_name_input=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div[2]/div[3]/div[2]/input')
            last_name_input.click()
            last_name_input.send_keys(f'Aliyev{str(i)}')
            comp_email_input_for_10=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div[2]/div[4]/div/input')
            comp_email_input_for_10.click()
            comp_email_input_for_10.send_keys(f'amishohjon5{str(study//i)}{str(i)}@mail.ru')
        
            first_pass_input=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div[2]/div[5]/div[1]/input')
            first_pass_input.click()
            first_pass_input.send_keys('12345678')
            
            sec_pass_input=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div[2]/div[5]/div[2]/input')
            sec_pass_input.click()
            sec_pass_input.send_keys('12345678')
        
            agree_button1=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div[2]/div[6]/div/label/div/img')
            agree_button1.click()
    
            signup_button1=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div[2]/div[7]/button')
            signup_button1.click()
            time.sleep(10)
        
            country_button=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[1]/div[2]/div/div[2]/img')
            country_button.click()

            first_country=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[1]/div[2]/div[2]/div[4]')
            first_country.click()
        except Exception as e:
            print('i is divisible 10-->problem')                                # second country    '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[1]/div[2]/div[2]/div[2]'
        try:
            job_title_input=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[2]/div[2]/div/input')
            job_title_input.click()
            job_title_input.send_keys('software engineer')
        except Exception as e:
            print('job_title-->problem')
        try:    
            my_department_input=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[2]/div[4]/div/div[2]/img')
            my_department_input.click()
            first_department=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[2]/div[4]/div[2]/div[4]')
            first_department.click()
        except Exception as e:
            print('department-->problem')
        try:    
            next_button=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[2]/a')
            next_button.click()
            time.sleep(10)
        except Exception as e:
            print('next_button-->problem')
    # except Exception as e:
    #     print('cannot create new account!')
    df1 = pd.DataFrame({
    'links':list(dict_.keys()),
    'characters':list(dict_.values())
    })
    df1.to_csv(f'datas/cs_values/data{study}.csv', index=False)
    print(list(dict_.values())[-10:])
    print(f'{study} is done!')
# Out:
# C:\Users\fayyo\AppData\Local\Temp\ipykernel_2852\4098484206.py:11: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(options=options,executable_path='C:/Users/dell/OneDrive/Desktop/chromedriver.exe')
# Incompatible release of chromedriver (version 111.0.5563.64) detected in PATH: c:\Users\GitHub\Bots_using_selenium\linkedin_data_Scraping\chromedriver.exe
# dots problem
# logout problem
# signup probelm
# problem with people
# problem with add profiles button
# problem with input profiles
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# Cell In[13], line 135
#     133     print('problem with input profiles')
#     134 for lin in range(10):
# --> 135     input_profiles.send_keys(lin)
#     136     driver.find_element_by_name("Value").send_keys(Keys.ENTER)
#     138 try:
#
# File c:\Users\GitHub\Bots_using_selenium\venv\lib\site-packages\selenium\webdriver\remote\webelement.py:231, in WebElement.send_keys(self, *value)
#     228             remote_files.append(self._upload(file))
#     229         value = "\n".join(remote_files)
# --> 231 self._execute(
#     232     Command.SEND_KEYS_TO_ELEMENT, {"text": "".join(keys_to_typing(value)), "value": keys_to_typing(value)}
#     233 )
#
# File c:\Users\GitHub\Bots_using_selenium\venv\lib\site-packages\selenium\webdriver\remote\webelement.py:403, in WebElement._execute(self, command, params)
#     401     params = {}
#     402 params["id"] = self._id
# --> 403 return self._parent.execute(command, params)
#
# File c:\Users\GitHub\Bots_using_selenium\venv\lib\site-packages\selenium\webdriver\remote\webdriver.py:440, in WebDriver.execute(self, driver_command, params)
#     438 response = self.command_executor.execute(driver_command, params)
#     439 if response:
# --> 440     self.error_handler.check_response(response)
#     441     response["value"] = self._unwrap_value(response.get("value", None))
#     442     return response
#
# File c:\Users\GitHub\Bots_using_selenium\venv\lib\site-packages\selenium\webdriver\remote\errorhandler.py:245, in ErrorHandler.check_response(self, response)
#     243         alert_text = value["alert"].get("text")
#     244     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 245 raise exception_class(message, screen, stacktrace)
#
# NoSuchWindowException: Message: no such window: target window already closed
# from unknown error: web view not found
#   (Session info: chrome=115.0.5790.110)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x0115A813+48355]
# 	(No symbol) [0x010EC4B1]
# 	(No symbol) [0x00FF5358]
# 	(No symbol) [0x00FDD293]
# 	(No symbol) [0x0103E37B]
# 	(No symbol) [0x0104C473]
# 	(No symbol) [0x0103A536]
# 	(No symbol) [0x010182DC]
# 	(No symbol) [0x010193DD]
# 	GetHandleVerifier [0x013BAABD+2539405]
# 	GetHandleVerifier [0x013FA78F+2800735]
# 	GetHandleVerifier [0x013F456C+2775612]
# 	GetHandleVerifier [0x011E51E0+616112]
# 	(No symbol) [0x010F5F8C]
# 	(No symbol) [0x010F2328]
# 	(No symbol) [0x010F240B]
# 	(No symbol) [0x010E4FF7]
# 	BaseThreadInitThunk [0x763B00C9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77C57B1E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77C57AEE+238]
