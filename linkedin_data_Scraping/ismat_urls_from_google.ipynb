# %%
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from selenium import webdriver
import time
import pandas as pd
from bs4 import BeautifulSoup
options = Options()
options.add_argument("user-data-dir=C:/Users/dell/AppData/Local/Google/Chrome/User Data/Profile 3")
                                                        #C:\Users\fayyo\Downloads\chromedriver-win32.zip\chromedriver-win32
driver = webdriver.Chrome(options=options,executable_path='C:/Users/dell/OneDrive/Desktop/chromedriver-win64/chromedriver.exe')
# country names
list_items = [
    "Stockholm",
    "Gothenburg (Göteborg)",
    "Malmö",
    "Uppsala",
    "Linköping",
    "Västerås",
    "Örebro",
    "Norrköping",
    "Helsingborg",
    "Jönköping",
    "Umeå",
    "Lund",
    "Gävle",
    "Borås",
    "Eskilstuna",
    "Södertälje",
    "Halmstad",
    "Växjö",
    "Karlstad",
    "Trollhättan",
    "Östersund",
    "Borlänge",
    "Sundsvall",
    "Luleå",
    "Tumba",
    "Skövde",
    "Karlskrona",
    "Kristianstad",
    "Kalmar",
    "Falun",
    "Västerås",
    "Kungsbacka",
    "Nyköping",
    "Motala",
    "Hudiksvall",
    "Norrköping",
    "Varberg",
    "Märsta",
    "Halmstad",
    "Lidingö",
    "Sandviken",
    "Köping",
    "Karlskoga",
    "Kristinehamn",
    "Sundbyberg",
    "Ljungby",
    "Ängelholm",
    "Katrineholm",
    "Enköping",
    "Falkenberg",
    "Marstrand",
    "Nacka",
    "Vallentuna",
    "Kumla",
    "Härnösand",
    "Karlshamn",
    "Lerum",
    "Vänersborg",
    "Kungsör",
    "Hjo",
    "Tranås",
    "Falköping",
    "Bålsta",
    "Örnsköldsvik",
    "Värnamo",
    "Finspång",
    "Säter",
    "Sala",
    "Hudiksvall",
    "Hedemora",
    "Visby",
    "Söderhamn",
    "Strängnäs",
    "Sundsvall",
    "Söderköping",
    "Eksjö",
    "Mariestad",
    "Eslöv",
    "Trelleborg",
    "Landskrona",
    "Falköping",
    "Piteå",
    "Kiruna",
    "Alingsås",
    "Lidköping",
    "Nykvarn",
    "Avesta",
    "Kil",
    "Åkersberga",
    "Arboga",
    "Nässjö",
    "Kungälv",
    "Fagersta",
    "Oskarshamn",
    "Lindesberg",
    "Ljusdal",
    "Solna",
    "Hudiksvall",
    "Svedala",
    "Härnösand",
    "Ludvika",
    "Karlskrona",
    "Sigtuna",
    "Lomma",
    "Älmhult",
    "Åmål",
    "Strömstad",
    "Öregrund",
    "Boden",
    "Söderhamn",
    "Trosa",
    "Simrishamn",
    "Skellefteå",
    "Hagfors",
    "Mölndal",
    "Borlänge",
    "Växjö",
    "Norrköping",
    "Falkenberg",
    "Kalmar",
    "Eksjö",
    "Visby",
    "Mariestad",
    "Kiruna",
    "Alingsås",
    "Lidköping",
    "Avesta",
    "Nässjö",
    "Fagersta",
    "Oskarshamn",
    "Solna",
    "Svedala",
    "Lindesberg",
    "Ljusdal",
    "Hudiksvall",
    "Härnösand",
    "Ludvika",
    "Sigtuna",
    "Lomma",
    "Älmhult",
    "Åmål",
    "Strömstad",
    "Öregrund",
    "Boden",
    "Trosa",
    "Simrishamn",
    "Skellefteå",
    "Hagfors",
    "Mölndal",
    "Falkenberg",
    "Boden",
    "Vänersborg",
    "Mjölby",
    "Piteå",
    "Kil",
    "Arboga",
    "Vallentuna",
    "Eslöv",
    "Trelleborg",
    "Landskrona",
    "Piteå",
    "Kiruna",
    "Mjölby",
    "Örnsköldsvik",
    "Finspång",
    "Säter",
    "Sala",
    "Lidköping",
    "Oskarshamn",
    "Lindesberg",
    "Ljusdal",
    "Solna",
    "Svedala",
    "Härnösand",
    "Ludvika",
    "Simrishamn",
    "Strömstad",
    "Öregrund",
    "Boden",
    "Trosa",
    "Hagfors",
    "Mölndal",
    "Boden",
    "Vänersborg",
    "Mjölby",
    "Kil",
    "Arboga",
]

for item  in list_items[:]:
    links = [] # save links here
    for study in ['math', 'physics']:
        driver.get(f'https://www.google.com/search?q=site:nl.linkedin.com/in/+AND+%22{item}+AND+%22{study}')
        time.sleep(5) # to make slower 
        n=30
        while n > 0:
            time.sleep(5)
            print("here")
            initialScroll = 0
            finalScroll = 1000
            start = time.time()
            while True:
                driver.execute_script(f"window.scrollTo({initialScroll}, {finalScroll})")
                initialScroll = finalScroll
                finalScroll += 1000
                time.sleep(3)
                end = time.time()
                if round(end - start) > 25:
                    break
            src = driver.page_source
            soup = BeautifulSoup(src, 'lxml')
            linksed_links=soup.find_all("a", {"jsname":"UWckNb"})
            for i in linksed_links:
                links.append(i.get('href').split("?")[0])
            try:
                next_button = driver.find_element(By.XPATH, '//*[@id="pnnext"]') # clicking next button 
                next_button.click()
            except Exception as e:
                driver.get(f'https://www.google.com/search?q=site:nl.linkedin.com/in/+AND+%22{item}+AND+%22{study}')
                n=1
                # print("")
            # print(f'{n} pages left!')
            n -= 1
        df = pd.DataFrame({
            "links":links
        })
        df1=pd.read_csv('datas/Ismatulla_links/data_Ismatulla4.csv')
        df_sum=pd.concat([df1, df], axis=0, ignore_index=True)
        df_sum = df_sum.drop_duplicates()
        df_sum.to_csv(f'datas/Ismatulla_links/data_Ismatulla4.csv', index=False)
        print(f'I am done ---> {item}')
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_8516\232504155.py:10: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(options=options,executable_path='C:/Users/dell/OneDrive/Desktop/chromedriver-win64/chromedriver.exe')
# here
# I am done ---> Stockholm
# here
# I am done ---> Stockholm
# here
# I am done ---> Gothenburg (Göteborg)
# here
# I am done ---> Gothenburg (Göteborg)
# here
# I am done ---> Malmö
# here
# I am done ---> Malmö
# here
# I am done ---> Uppsala
# here
# I am done ---> Uppsala
# here
# I am done ---> Linköping
# here
# I am done ---> Linköping
# here
# I am done ---> Västerås
# here
# I am done ---> Västerås
# here
# I am done ---> Örebro
# here
# I am done ---> Örebro
# here
# I am done ---> Norrköping
# here
# I am done ---> Norrköping
# here
# I am done ---> Helsingborg
# here
# I am done ---> Helsingborg
# here
# I am done ---> Jönköping
# here
# I am done ---> Jönköping
# here
# I am done ---> Umeå
# here
# I am done ---> Umeå
# here
# I am done ---> Lund
# here
# I am done ---> Lund
# here
# I am done ---> Gävle
# here
# I am done ---> Gävle
# here
# I am done ---> Borås
# here
# I am done ---> Borås
# here
# I am done ---> Eskilstuna
# here
# I am done ---> Eskilstuna
# here
# I am done ---> Södertälje
# here
# I am done ---> Södertälje
# here
# I am done ---> Halmstad
# here
# I am done ---> Halmstad
# here
# I am done ---> Växjö
# here
# I am done ---> Växjö
# here
# I am done ---> Karlstad
# here
# I am done ---> Karlstad
# here
# I am done ---> Trollhättan
# here
# I am done ---> Trollhättan
# here
# I am done ---> Östersund
# here
# I am done ---> Östersund
# here
# I am done ---> Borlänge
# here
# I am done ---> Borlänge
# here
# I am done ---> Sundsvall
# here
# I am done ---> Sundsvall
# here
# I am done ---> Luleå
# here
# I am done ---> Luleå
# here
# I am done ---> Tumba
# here
# I am done ---> Tumba
# here
# I am done ---> Skövde
# here
# I am done ---> Skövde
# here
# I am done ---> Karlskrona
# here
# I am done ---> Karlskrona
# here
# I am done ---> Kristianstad
# here
# I am done ---> Kristianstad
# here
# I am done ---> Kalmar
# here
# I am done ---> Kalmar
# here
# I am done ---> Falun
# here
# I am done ---> Falun
# here
# I am done ---> Västerås
# here
# I am done ---> Västerås
# here
# I am done ---> Kungsbacka
# here
# I am done ---> Kungsbacka
# here
# I am done ---> Nyköping
# here
# I am done ---> Nyköping
# here
# I am done ---> Motala
# here
# I am done ---> Motala
# here
# I am done ---> Hudiksvall
# here
# I am done ---> Hudiksvall
# here
# I am done ---> Norrköping
# here
# I am done ---> Norrköping
# here
# I am done ---> Varberg
# here
# I am done ---> Varberg
# here
# I am done ---> Märsta
# here
# I am done ---> Märsta
# here
# I am done ---> Halmstad
# here
# I am done ---> Halmstad
# here
# I am done ---> Lidingö
# here
# I am done ---> Lidingö
# here
# I am done ---> Sandviken
# here
# I am done ---> Sandviken
# here
# I am done ---> Köping
# here
# I am done ---> Köping
# here
# I am done ---> Karlskoga
# here
# I am done ---> Karlskoga
# here
# I am done ---> Kristinehamn
# here
# I am done ---> Kristinehamn
# here
# I am done ---> Sundbyberg
# here
# I am done ---> Sundbyberg
# here
# I am done ---> Ljungby
# here
# I am done ---> Ljungby
# here
# I am done ---> Ängelholm
# here
# I am done ---> Ängelholm
# here
# I am done ---> Katrineholm
# here
# I am done ---> Katrineholm
# here
# I am done ---> Enköping
# here
# I am done ---> Enköping
# here
# I am done ---> Falkenberg
# here
# I am done ---> Falkenberg
# here
# I am done ---> Marstrand
# here
# I am done ---> Marstrand
# here
# I am done ---> Nacka
# here
# I am done ---> Nacka
# here
# I am done ---> Vallentuna
# here
# I am done ---> Vallentuna
# here
# I am done ---> Kumla
# here
# I am done ---> Kumla
# here
# I am done ---> Härnösand
# here
# I am done ---> Härnösand
# here
# I am done ---> Karlshamn
# here
# I am done ---> Karlshamn
# here
# I am done ---> Lerum
# here
# I am done ---> Lerum
# here
# I am done ---> Vänersborg
# here
# I am done ---> Vänersborg
# here
# I am done ---> Kungsör
# here
# I am done ---> Kungsör
# here
# I am done ---> Hjo
# here
# I am done ---> Hjo
# here
# I am done ---> Tranås
# here
# I am done ---> Tranås
# here
# I am done ---> Falköping
# here
# I am done ---> Falköping
# here
# I am done ---> Bålsta
# here
# I am done ---> Bålsta
# here
# I am done ---> Örnsköldsvik
# here
# I am done ---> Örnsköldsvik
# here
# I am done ---> Värnamo
# here
# I am done ---> Värnamo
# here
# I am done ---> Finspång
# here
# I am done ---> Finspång
# here
# I am done ---> Säter
# here
# I am done ---> Säter
# here
# I am done ---> Sala
# here
# I am done ---> Sala
# here
# I am done ---> Hudiksvall
# here
# I am done ---> Hudiksvall
# here
# I am done ---> Hedemora
# here
# I am done ---> Hedemora
# here
# I am done ---> Visby
# here
# I am done ---> Visby
# here
# I am done ---> Söderhamn
# here
# I am done ---> Söderhamn
# here
# I am done ---> Strängnäs
# here
# I am done ---> Strängnäs
# here
# I am done ---> Sundsvall
# here
# I am done ---> Sundsvall
# here
# I am done ---> Söderköping
# here
# I am done ---> Söderköping
# here
# I am done ---> Eksjö
# here
# I am done ---> Eksjö
# here
# I am done ---> Mariestad
# here
# I am done ---> Mariestad
# here
# I am done ---> Eslöv
# here
# I am done ---> Eslöv
# here
# I am done ---> Trelleborg
# here
# I am done ---> Trelleborg
# here
# I am done ---> Landskrona
# here
# I am done ---> Landskrona
# here
# I am done ---> Falköping
# here
# I am done ---> Falköping
# here
# I am done ---> Piteå
# here
# I am done ---> Piteå
# here
# I am done ---> Kiruna
# here
# I am done ---> Kiruna
# here
# I am done ---> Alingsås
# here
# I am done ---> Alingsås
# here
# I am done ---> Lidköping
# here
# I am done ---> Lidköping
# here
# I am done ---> Nykvarn
# here
# I am done ---> Nykvarn
# here
# I am done ---> Avesta
# here
# I am done ---> Avesta
# here
# I am done ---> Kil
# here
# I am done ---> Kil
# here
# I am done ---> Åkersberga
# here
# I am done ---> Åkersberga
# here
# I am done ---> Arboga
# here
# I am done ---> Arboga
# here
# I am done ---> Nässjö
# here
# I am done ---> Nässjö
# here
# I am done ---> Kungälv
# here
# I am done ---> Kungälv
# here
# I am done ---> Fagersta
# here
# I am done ---> Fagersta
# here
# I am done ---> Oskarshamn
# here
# I am done ---> Oskarshamn
# here
# I am done ---> Lindesberg
# here
# I am done ---> Lindesberg
# here
# I am done ---> Ljusdal
# here
# I am done ---> Ljusdal
# here
# I am done ---> Solna
# here
# I am done ---> Solna
# here
# I am done ---> Hudiksvall
# here
# I am done ---> Hudiksvall
# here
# I am done ---> Svedala
# here
# I am done ---> Svedala
# here
# I am done ---> Härnösand
# here
# I am done ---> Härnösand
# here
# I am done ---> Ludvika
# here
# I am done ---> Ludvika
# here
# I am done ---> Karlskrona
# here
# I am done ---> Karlskrona
# here
# I am done ---> Sigtuna
# here
# I am done ---> Sigtuna
# here
# I am done ---> Lomma
# here
# I am done ---> Lomma
# here
# I am done ---> Älmhult
# here
# I am done ---> Älmhult
# here
# I am done ---> Åmål
# here
# I am done ---> Åmål
# here
# I am done ---> Strömstad
# here
# I am done ---> Strömstad
# here
# I am done ---> Öregrund
# here
# I am done ---> Öregrund
# here
# I am done ---> Boden
# here
# I am done ---> Boden
# here
# I am done ---> Söderhamn
# here
# I am done ---> Söderhamn
# here
# I am done ---> Trosa
# here
# I am done ---> Trosa
# here
# I am done ---> Simrishamn
# here
# I am done ---> Simrishamn
# here
# I am done ---> Skellefteå
# here
# I am done ---> Skellefteå
# here
# I am done ---> Hagfors
# here
# I am done ---> Hagfors
# here
# I am done ---> Mölndal
# here
# I am done ---> Mölndal
# here
# I am done ---> Borlänge
# here
# I am done ---> Borlänge
# here
# I am done ---> Växjö
# here
# I am done ---> Växjö
# here
# I am done ---> Norrköping
# here
# I am done ---> Norrköping
# here
# I am done ---> Falkenberg
# here
# I am done ---> Falkenberg
# here
# I am done ---> Kalmar
# here
# I am done ---> Kalmar
# here
# I am done ---> Eksjö
# here
# I am done ---> Eksjö
# here
# I am done ---> Visby
# here
# I am done ---> Visby
# here

# %%
# Out:
# []

# %%
df = pd.DataFrame({
    "links":links
})
df1=pd.read_csv('datas/Fayyoz_links/data_Fayyoz.csv')
df_sum=pd.concat([df1, df], axis=0, ignore_index=True)
df_sum = df_sum.drop_duplicates()
df_sum.to_csv(f'datas/Fayyoz_links/data_Fayyoz.csv', index=False)
print(f'I am done ---> {item}')
# Out:
# I am done ---> Dhaka, Bangladesh

# %%
df = pd.DataFrame({
    "links":links
})
df1=pd.read_csv('datas/Fayyoz_links/data_Fayyoz.csv')
# df = df.drop_duplicates()
df_sum=pd.concat([df1, df], axis=0, ignore_index=True)
df_sum = df_sum.drop_duplicates()
df_sum.to_csv(f'datas/Fayyoz_links/data_Fayyoz.csv', index=False)
print(f'I am done ---> {item}')
# Out:
# I am done ---> Shanghai, China

# %%
j=592

# %%
df = pd.DataFrame({
    "links":links
})
df = df.drop_duplicates()
df.to_csv(f'datas/linkedin_links_29_06/data{str(j)}.csv', index=False)
print(f'I am done ---> {str(j)}')
print(f'if there is a problem, start with {str(j+1)}')
# Out:
# I am done ---> 599
# if there is a problem, start with 600

# %%
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from selenium import webdriver
import time
import pandas as pd

chrome_driver_path = Service(
    "chromedriver.exe")
driver = webdriver.Chrome(service=chrome_driver_path)

# options = Options()
# options.add_argument("user-data-dir=C:\\Users\\Username\\AppData\\Local\\Google\\Chrome\\User Data")
# driver = webdriver.Chrome(options=options)
# 'Mathematics and Bachelor words are used as a default, it is changeble
driver.get('https://www.google.com/search?q=site:nl.linkedin.com/in/+AND+%22Computational Social Science%22+AND+%22Bachelor%27s&sxsrf=ALiCzsbOTqrA98wDQf3mtEB03kA_O7eCbQ:1668686082134&ei=AiF2Y4vwB-3JrgS9gpd4&start=50&sa=N&ved=2ahUKEwiL-aqJlLX7AhXtpIsKHT3BBQ84KBDy0wN6BAgBEA0&biw=920&bih=625&dpr=1')
time.sleep(10) # to make slower 

 # n is the number of pages
links = [] # save links here
n=6
while n > 0:
    time.sleep(5)
    for i in range(1, 11): # google uses paginator, every page has 10 urls
        time.sleep(6)
        try:
            elems = driver.find_elements(By.XPATH, '//*[@id="rso"]/div['+str(i)+']/div/div/div[1]/div/a')
            for elem in elems:
                
                clean_url = elem.get_attribute("href") # extracting url 
                base_url = "linkedin.com/in/"
                if clean_url.find(base_url) != -1 and '%' not in clean_url: # sometimes google gives no Ln urls, so clean it
                    links.append(clean_url)
                    print(f"url is --->{clean_url}")
        except Exception as e:
            print(e)
            pass
    try:
        next_button = driver.find_element(By.XPATH, '//*[@id="pnnext"]') # clicking next button 
        next_button.click()
    except Exception as e:
        print(e)
    print(f'{n} pages left!')
    n -= 1
df = pd.DataFrame({
    "links":links
})
df.to_csv('datas/linkedin_aaccount_links/Filosofie.csv', index=False)
