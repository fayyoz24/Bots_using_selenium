# %%
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from selenium import webdriver
import time
import pandas as pd
from bs4 import BeautifulSoup
options = Options()
options.add_argument("user-data-dir=C:/Users/dell/AppData/Local/Google/Chrome/User Data/Profile 3")
                                                        #C:\Users\fayyo\Downloads\chromedriver-win32.zip\chromedriver-win32
driver = webdriver.Chrome(options=options,executable_path='C:/Users/dell/OneDrive/Desktop/chromedriver-win64/chromedriver.exe')
# country names
list_items = [
    "Serangoon",
    "Hougang",
    "Punggol",
    "Sengkang",
    "Serangoon Gardens",
    "Buangkok",
    "Seletar",
    "Lim Chu Kang",
    "Sungei Kadut",
    "Mandai",
    "Yio Chu Kang",
    "Springleaf",
    "Upper Thomson",
    "Sin Ming",
    "Ang Mo Kio",
    "Joo Chiat",
    "Katong",
    "East Coast",
    "MacPherson",
    "Potong Pasir",
    "Boon Keng",
    "Balestier",
    "Novena",
    "Bukit Timah",
    "Holland Village",
    "Bukit Timah",
    "Ghim Moh",
    "Buona Vista",
    "One-North",
    "Kent Ridge",
    "Clementi",
    "Pasir Panjang",
    "West Coast",
    "Jurong",
    "Tuas",
    "Lim Chu Kang",
    "Pioneer",
    "Boon Lay",
    "Joo Koon",
    "Kranji",
    "Woodlands",
    "Admiralty",
    "Sembawang",
    "Yishun",
    "Khatib",
    "Yio Chu Kang",
    "Ang Mo Kio",
    "Lentor",
    "Mayflower",
    "Bishan",
    "Braddell",
    "Toa Payoh",
    "Novena",
    "Newton",
    "Orchard",
    "Somerset",
    "Dhoby Ghaut",
    "City Hall",
    "Raffles Place",
    "Marina Bay",
    "Tanjong Pagar",
    "Outram",
    "HarbourFront",
    "Chinatown",
    "Clarke Quay",
    "Bugis",
    "Lavender",
    "Kallang",
    "Geylang",
    "Paya Lebar",
    "Eunos",
    "Kembangan",
    "Bedok",
    "Tampines",
    "Pasir Ris",
    "Serangoon",
    "Hougang",
    "Punggol",
    "Sengkang",
    "Serangoon Gardens",
    "Buangkok",
    "Seletar",
    "Lim Chu Kang",
    "Sungei Kadut",
    "Mandai",
    "Yio Chu Kang",
    "Springleaf",
    "Upper Thomson",
    "Sin Ming",
    "Ang Mo Kio",
    "Joo Chiat",
    "Katong",
    "East Coast",
    "MacPherson",
    "Potong Pasir",
    "Boon Keng",
    "Balestier",
    "Novena",
    "Bukit Timah",
    "Holland Village",
    "Buona Vista",
    "One-North",
    "Kent Ridge",
    "Clementi",
    "Pasir Panjang",
    "West Coast",
    "Jurong",
    "Tuas",
    "Lim Chu Kang",
    "Pioneer",
    "Boon Lay",
    "Joo Koon",
    "Kranji",
    "Woodlands",
    "Admiralty",
    "Sembawang",
    "Yishun",
    "Khatib",
    "Yio Chu Kang",
    "Ang Mo Kio",
    "Lentor",
    "Mayflower",
    "Bishan",
    "Braddell",
    "Toa Payoh",
    "Novena",
    "Newton",
    "Orchard",
    "Somerset",
    "Dhoby Ghaut",
    "City Hall",
    "Raffles Place",
    "Marina Bay",
    "Tanjong Pagar",
    "Outram",
    "HarbourFront",
    "Chinatown",
    "Clarke Quay",
    "Bugis",
    "Lavender",
    "Kallang",
    "Geylang",
    "Paya Lebar",
    "Eunos",
    "Kembangan",
    "Bedok",
    "Tampines",
    "Pasir Ris",
    "Serangoon",
    "Hougang",
    "Punggol",
    "Sengkang",
    "Serangoon Gardens",
    "Buangkok",
    "Seletar",
    "Lim Chu Kang",
    "Sungei Kadut",
    "Mandai",
    "Yio Chu Kang",
    "Springleaf",
    "Upper Thomson",
    "Sin Ming",
    "Ang Mo Kio",
    "Joo Chiat",
    "Katong",
    "East Coast",
    "MacPherson",
    "Potong Pasir",
    "Boon Keng",
    "Balestier",
    "Novena",
    "Bukit Timah",
    "Holland Village",
    "Buona Vista",
    "One-North",
    "Kent Ridge",
    "Clementi",
    "Pasir Panjang",
    "West Coast",
    "Jurong",
    "Tuas",
    "Lim Chu Kang",
    "Pioneer",
    "Boon Lay",
    "Joo Koon",
    "Kranji",
    "Sungei Kadut",
    "Mandai",
    "Yio Chu Kang",
    "Springleaf",
    "Upper Thomson",
    "Sin Ming",
    "Ang Mo Kio",
    "Joo Chiat",
    "Katong",
    "East Coast",
    "MacPherson",
    "Potong Pasir",
    "Boon Keng",
    "Balestier",
    "Novena",
    "Bukit Timah",
    "Holland Village",
    "Buona Vista",
    "One-North",
    "Kent Ridge",
    "Clementi",
    "Pasir Panjang",
    "West Coast",
    "Jurong",
    "Tuas",
    "Lim Chu Kang",
    "Pioneer",
    "Boon Lay",
    "Joo Koon",
    "Kran"
]
for item  in list_items[:]:
    links = [] # save links here
    for study in ['math', 'physics']:
        driver.get(f'https://www.google.com/search?q=site:nl.linkedin.com/in/+AND+%22{item}+AND+%22{study}')
        time.sleep(5) # to make slower 
        n=30
        while n > 0:
            time.sleep(5)
            print("here")
            initialScroll = 0
            finalScroll = 1000
            start = time.time()
            while True:
                driver.execute_script(f"window.scrollTo({initialScroll}, {finalScroll})")
                initialScroll = finalScroll
                finalScroll += 1000
                time.sleep(3)
                end = time.time()
                if round(end - start) > 25:
                    break
            src = driver.page_source
            soup = BeautifulSoup(src, 'lxml')
            linksed_links=soup.find_all("a", {"jsname":"UWckNb"})
            for i in linksed_links:
                links.append(i.get('href').split("?")[0])
            try:
                next_button = driver.find_element(By.XPATH, '//*[@id="pnnext"]') # clicking next button 
                next_button.click()
            except Exception as e:
                driver.get(f'https://www.google.com/search?q=site:nl.linkedin.com/in/+AND+%22{item}+AND+%22{study}')
                n=1
                # print("")
            # print(f'{n} pages left!')
            n -= 1
        df = pd.DataFrame({
            "links":links
        })
        df1=pd.read_csv('datas/Ismatulla_links/data_Ismatulla5.csv')
        df_sum=pd.concat([df1, df], axis=0, ignore_index=True)
        df_sum = df_sum.drop_duplicates()
        df_sum.to_csv(f'datas/Ismatulla_links/data_Ismatulla5.csv', index=False)
        print(f'I am done ---> {item}')
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_4556\3629920777.py:10: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(options=options,executable_path='C:/Users/dell/OneDrive/Desktop/chromedriver-win64/chromedriver.exe')
# here
# I am done ---> Serangoon
# here
# I am done ---> Serangoon
# here
# I am done ---> Hougang
# here
# I am done ---> Hougang
# here
# I am done ---> Punggol
# here
# I am done ---> Punggol
# here
# I am done ---> Sengkang
# here
# I am done ---> Sengkang
# here
# I am done ---> Serangoon Gardens
# here
# I am done ---> Serangoon Gardens
# here
# I am done ---> Buangkok
# here
# I am done ---> Buangkok
# here
# I am done ---> Seletar
# here
# I am done ---> Seletar
# here
# I am done ---> Lim Chu Kang
# here
# I am done ---> Lim Chu Kang
# here
# I am done ---> Sungei Kadut
# here
# I am done ---> Sungei Kadut
# here
# I am done ---> Mandai
# here
# I am done ---> Mandai
# here
# I am done ---> Yio Chu Kang
# here
# I am done ---> Yio Chu Kang
# here
# I am done ---> Springleaf
# here
# I am done ---> Springleaf
# here
# I am done ---> Upper Thomson
# here
# I am done ---> Upper Thomson
# here
# I am done ---> Sin Ming
# here
# I am done ---> Sin Ming
# here
# I am done ---> Ang Mo Kio
# here
# I am done ---> Ang Mo Kio
# here
# I am done ---> Joo Chiat
# here
# I am done ---> Joo Chiat
# here
# I am done ---> Katong
# here
# I am done ---> Katong
# here
# I am done ---> East Coast
# here
# I am done ---> East Coast
# here
# I am done ---> MacPherson
# here
# I am done ---> MacPherson
# here
# I am done ---> Potong Pasir
# here
# I am done ---> Potong Pasir
# here
# I am done ---> Boon Keng
# here
# I am done ---> Boon Keng
# here
# I am done ---> Balestier
# here
# I am done ---> Balestier
# here
# I am done ---> Novena
# here
# I am done ---> Novena
# here
# I am done ---> Bukit Timah
# here
# I am done ---> Bukit Timah
# here
# I am done ---> Holland Village
# here
# I am done ---> Holland Village
# here
# I am done ---> Bukit Timah
# here
# I am done ---> Bukit Timah
# here
# I am done ---> Ghim Moh
# here
# I am done ---> Ghim Moh
# here
# I am done ---> Buona Vista
# here
# I am done ---> Buona Vista
# here
# I am done ---> One-North
# here
# I am done ---> One-North
# here
# I am done ---> Kent Ridge
# here
# I am done ---> Kent Ridge
# here
# I am done ---> Clementi
# here
# I am done ---> Clementi
# here
# I am done ---> Pasir Panjang
# here
# I am done ---> Pasir Panjang
# here
# I am done ---> West Coast
# here
# I am done ---> West Coast
# here
# I am done ---> Jurong
# here
# I am done ---> Jurong
# here
# I am done ---> Tuas
# here
# I am done ---> Tuas
# here
# I am done ---> Lim Chu Kang
# here
# I am done ---> Lim Chu Kang
# here
# I am done ---> Pioneer
# here
# I am done ---> Pioneer
# here
# I am done ---> Boon Lay
# here
# I am done ---> Boon Lay
# here
# I am done ---> Joo Koon
# here
# I am done ---> Joo Koon
# here
# I am done ---> Kranji
# here
# I am done ---> Kranji
# here
# I am done ---> Woodlands
# here
# I am done ---> Woodlands
# here
# I am done ---> Admiralty
# here
# I am done ---> Admiralty
# here
# I am done ---> Sembawang
# here
# I am done ---> Sembawang
# here
# I am done ---> Yishun
# here
# I am done ---> Yishun
# here
# I am done ---> Khatib
# here
# I am done ---> Khatib
# here
# I am done ---> Yio Chu Kang
# here
# I am done ---> Yio Chu Kang
# here
# I am done ---> Ang Mo Kio
# here
# I am done ---> Ang Mo Kio
# here
# I am done ---> Lentor
# here
# I am done ---> Lentor
# here
# I am done ---> Mayflower
# here
# I am done ---> Mayflower
# here
# I am done ---> Bishan
# here
# I am done ---> Bishan
# here
# I am done ---> Braddell
# here
# I am done ---> Braddell
# here
# I am done ---> Toa Payoh
# here
# I am done ---> Toa Payoh
# here
# I am done ---> Novena
# here
# I am done ---> Novena
# here
# I am done ---> Newton
# here
# I am done ---> Newton
# here
# I am done ---> Orchard
# here
# I am done ---> Orchard
# here
# I am done ---> Somerset
# here
# I am done ---> Somerset
# here
# I am done ---> Dhoby Ghaut
# here
# I am done ---> Dhoby Ghaut
# here
# I am done ---> City Hall
# here
# I am done ---> City Hall
# here
# I am done ---> Raffles Place
# here
# I am done ---> Raffles Place
# here
# I am done ---> Marina Bay
# here
# I am done ---> Marina Bay
# here
# I am done ---> Tanjong Pagar
# here
# I am done ---> Tanjong Pagar
# here
# I am done ---> Outram
# here
# I am done ---> Outram
# here
# I am done ---> HarbourFront
# here
# I am done ---> HarbourFront
# here
# I am done ---> Chinatown
# here
# I am done ---> Chinatown
# here
# I am done ---> Clarke Quay
# here
# I am done ---> Clarke Quay
# here
# I am done ---> Bugis
# here
# I am done ---> Bugis
# here
# I am done ---> Lavender
# here
# I am done ---> Lavender
# here
# I am done ---> Kallang
# here
# I am done ---> Kallang
# here
# I am done ---> Geylang
# here
# I am done ---> Geylang
# here
# I am done ---> Paya Lebar
# here
# I am done ---> Paya Lebar
# here
# I am done ---> Eunos
# here
# I am done ---> Eunos
# here
# I am done ---> Kembangan
# here
# I am done ---> Kembangan
# here
# I am done ---> Bedok
# here
# I am done ---> Bedok
# here
# I am done ---> Tampines
# here
# I am done ---> Tampines
# here
# I am done ---> Pasir Ris
# here
# I am done ---> Pasir Ris
# here
# I am done ---> Serangoon
# here
# I am done ---> Serangoon
# here
# I am done ---> Hougang
# here
# I am done ---> Hougang
# here
# I am done ---> Punggol
# here
# I am done ---> Punggol
# here
# I am done ---> Sengkang
# here
# I am done ---> Sengkang
# here
# I am done ---> Serangoon Gardens
# here
# I am done ---> Serangoon Gardens
# here
# I am done ---> Buangkok
# here
# I am done ---> Buangkok
# here
# I am done ---> Seletar
# here
# I am done ---> Seletar
# here
# I am done ---> Lim Chu Kang
# here
# I am done ---> Lim Chu Kang
# here
# I am done ---> Sungei Kadut
# here
# I am done ---> Sungei Kadut
# here
# I am done ---> Mandai
# here
# I am done ---> Mandai
# here
# I am done ---> Yio Chu Kang
# here
# I am done ---> Yio Chu Kang
# here
# I am done ---> Springleaf
# here
# I am done ---> Springleaf
# here
# I am done ---> Upper Thomson
# here
# I am done ---> Upper Thomson
# here
# I am done ---> Sin Ming
# here
# I am done ---> Sin Ming
# here
# I am done ---> Ang Mo Kio
# here
# I am done ---> Ang Mo Kio
# here
# I am done ---> Joo Chiat
# here
# I am done ---> Joo Chiat
# here
# I am done ---> Katong
# here
# I am done ---> Katong
# here
# I am done ---> East Coast
# here
# I am done ---> East Coast
# here
# I am done ---> MacPherson
# here
# I am done ---> MacPherson
# here
# I am done ---> Potong Pasir
# here
# I am done ---> Potong Pasir
# here
# I am done ---> Boon Keng
# here
# I am done ---> Boon Keng
# here
# I am done ---> Balestier
# here
# I am done ---> Balestier
# here
# I am done ---> Novena
# here
# I am done ---> Novena
# here
# I am done ---> Bukit Timah
# here
# I am done ---> Bukit Timah
# here
# I am done ---> Holland Village
# here
# I am done ---> Holland Village
# here
# I am done ---> Buona Vista
# here
# I am done ---> Buona Vista
# here
# I am done ---> One-North
# here
# I am done ---> One-North
# here
# I am done ---> Kent Ridge
# here
# I am done ---> Kent Ridge
# here
# I am done ---> Clementi
# here
# I am done ---> Clementi
# here
# I am done ---> Pasir Panjang
# here
# I am done ---> Pasir Panjang
# here
# I am done ---> West Coast
# here
# I am done ---> West Coast
# here
# I am done ---> Jurong
# here
# I am done ---> Jurong
# here
# I am done ---> Tuas
# here
# I am done ---> Tuas
# here
# I am done ---> Lim Chu Kang
# here
# I am done ---> Lim Chu Kang
# here
# I am done ---> Pioneer
# here
# I am done ---> Pioneer
# here
# I am done ---> Boon Lay
# here
# I am done ---> Boon Lay
# here
# I am done ---> Joo Koon
# here
# I am done ---> Joo Koon
# here
# I am done ---> Kranji
# here
# I am done ---> Kranji
# here
# I am done ---> Woodlands
# here
# I am done ---> Woodlands
# here
# I am done ---> Admiralty
# here
# I am done ---> Admiralty
# here
# I am done ---> Sembawang
# here
# I am done ---> Sembawang
# here
# I am done ---> Yishun
# here
# I am done ---> Yishun
# here
# I am done ---> Khatib
# here
# I am done ---> Khatib
# here
# I am done ---> Yio Chu Kang
# here
# I am done ---> Yio Chu Kang
# here
# I am done ---> Ang Mo Kio
# here
# I am done ---> Ang Mo Kio
# here
# I am done ---> Lentor
# here
# I am done ---> Lentor
# here
# I am done ---> Mayflower
# here
# I am done ---> Mayflower
# here
# I am done ---> Bishan
# here
# I am done ---> Bishan
# here
# I am done ---> Braddell
# here
# I am done ---> Braddell
# here
# I am done ---> Toa Payoh
# here
# I am done ---> Toa Payoh
# here
# I am done ---> Novena
# here
# I am done ---> Novena
# here
# I am done ---> Newton
# here
# I am done ---> Newton
# here
# I am done ---> Orchard
# here
# I am done ---> Orchard
# here
# I am done ---> Somerset
# here
# I am done ---> Somerset
# here
# I am done ---> Dhoby Ghaut
# here
# I am done ---> Dhoby Ghaut
# here
# I am done ---> City Hall
# here
# I am done ---> City Hall
# here
# I am done ---> Raffles Place
# here
# I am done ---> Raffles Place
# here
# I am done ---> Marina Bay
# here
# I am done ---> Marina Bay
# here
# I am done ---> Tanjong Pagar
# here
# I am done ---> Tanjong Pagar
# here
# I am done ---> Outram
# here
# I am done ---> Outram
# here
# I am done ---> HarbourFront
# here
# I am done ---> HarbourFront
# here
# I am done ---> Chinatown
# here
# I am done ---> Chinatown
# here
# I am done ---> Clarke Quay
# here
# I am done ---> Clarke Quay
# here
# I am done ---> Bugis
# here
# I am done ---> Bugis
# here
# I am done ---> Lavender
# here
# I am done ---> Lavender
# here
# I am done ---> Kallang
# here
# I am done ---> Kallang
# here
# I am done ---> Geylang
# here
# I am done ---> Geylang
# here
# I am done ---> Paya Lebar
# here
# I am done ---> Paya Lebar
# here
# I am done ---> Eunos
# here
# I am done ---> Eunos

# %%
# Out:
# []

# %%
df = pd.DataFrame({
    "links":links
})
df1=pd.read_csv('datas/Fayyoz_links/data_Fayyoz.csv')
df_sum=pd.concat([df1, df], axis=0, ignore_index=True)
df_sum = df_sum.drop_duplicates()
df_sum.to_csv(f'datas/Fayyoz_links/data_Fayyoz.csv', index=False)
print(f'I am done ---> {item}')
# Out:
# I am done ---> Dhaka, Bangladesh

# %%
df = pd.DataFrame({
    "links":links
})
df1=pd.read_csv('datas/Fayyoz_links/data_Fayyoz.csv')
# df = df.drop_duplicates()
df_sum=pd.concat([df1, df], axis=0, ignore_index=True)
df_sum = df_sum.drop_duplicates()
df_sum.to_csv(f'datas/Fayyoz_links/data_Fayyoz.csv', index=False)
print(f'I am done ---> {item}')
# Out:
# I am done ---> Shanghai, China

# %%
j=592

# %%
df = pd.DataFrame({
    "links":links
})
df = df.drop_duplicates()
df.to_csv(f'datas/linkedin_links_29_06/data{str(j)}.csv', index=False)
print(f'I am done ---> {str(j)}')
print(f'if there is a problem, start with {str(j+1)}')
# Out:
# I am done ---> 599
# if there is a problem, start with 600

# %%
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from selenium import webdriver
import time
import pandas as pd

chrome_driver_path = Service(
    "chromedriver.exe")
driver = webdriver.Chrome(service=chrome_driver_path)

# options = Options()
# options.add_argument("user-data-dir=C:\\Users\\Username\\AppData\\Local\\Google\\Chrome\\User Data")
# driver = webdriver.Chrome(options=options)
# 'Mathematics and Bachelor words are used as a default, it is changeble
driver.get('https://www.google.com/search?q=site:nl.linkedin.com/in/+AND+%22Computational Social Science%22+AND+%22Bachelor%27s&sxsrf=ALiCzsbOTqrA98wDQf3mtEB03kA_O7eCbQ:1668686082134&ei=AiF2Y4vwB-3JrgS9gpd4&start=50&sa=N&ved=2ahUKEwiL-aqJlLX7AhXtpIsKHT3BBQ84KBDy0wN6BAgBEA0&biw=920&bih=625&dpr=1')
time.sleep(10) # to make slower 

 # n is the number of pages
links = [] # save links here
n=6
while n > 0:
    time.sleep(5)
    for i in range(1, 11): # google uses paginator, every page has 10 urls
        time.sleep(6)
        try:
            elems = driver.find_elements(By.XPATH, '//*[@id="rso"]/div['+str(i)+']/div/div/div[1]/div/a')
            for elem in elems:
                
                clean_url = elem.get_attribute("href") # extracting url 
                base_url = "linkedin.com/in/"
                if clean_url.find(base_url) != -1 and '%' not in clean_url: # sometimes google gives no Ln urls, so clean it
                    links.append(clean_url)
                    print(f"url is --->{clean_url}")
        except Exception as e:
            print(e)
            pass
    try:
        next_button = driver.find_element(By.XPATH, '//*[@id="pnnext"]') # clicking next button 
        next_button.click()
    except Exception as e:
        print(e)
    print(f'{n} pages left!')
    n -= 1
df = pd.DataFrame({
    "links":links
})
df.to_csv('datas/linkedin_aaccount_links/Filosofie.csv', index=False)
