# %%
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from selenium import webdriver
import time
import pandas as pd
from bs4 import BeautifulSoup
options = Options()
options.add_argument("user-data-dir=C:/Users/dell/AppData/Local/Google/Chrome/User Data/Profile 15")
                                                        #C:\Users\fayyo\Downloads\chromedriver-win32.zip\chromedriver-win32
driver = webdriver.Chrome(options=options,executable_path='C:/Users/dell/OneDrive/Desktop/chromedriver-win64/chromedriver.exe')
# country names
list_items = [
    "Hatta",
    "Dibba Al-Fujairah",
    "Dibba Al-Hisn",
    "Madinat Zayed",
    "Liwa Oasis",
    "Ruwais",
    "Ghayathi",
    "Dhaid",
    "Al Madam",
    "Al Hamra",
    "Al Jazirah Al Hamra",
    "Masafi",
    "Al Mirfa",
    "Muzayri",
    "Ar-Rams",
    "Silat Al-Zahr",
    "Daftah",
    "Al Bithnah",
    "Al Khawaneej",
    "Jumeirah",
    "Hajar Mountains",
    "Hili",
    "Kalba",
    "Nakheel",
    "Manama",
    "Sweihan",
    "Madinat Khalifa",
    "Al Shahama",
    "Khalifa City",
    "Madinat Zayed",
    "Zayed City",
    "Bida Zayed",
    "Ghayathi",
    "Habshan",
    "Huwaylat",
    "Liwa Oasis",
    "Marawah",
    "Ruwais",
    "Sila",
    "Zirku",
    "Dhaid",
    "Dibba Al-Fujairah",
    "Madinat Khalifa",
    "Al Maha Forest",
    "Al Jaddaf",
    "Al Safa",
    "Al Safa",
    "Umm Suqeim",
    "Al Satwa",
    "Al Hamriya Port",
    "Al Hudaiba",
    "Al Shindagha",
    "Al Rashidiya",
    "Al Mankhool",
    "Al Karama",
    "Al Garhoud",
    "Al Jafiliya",
    "Al Qusais",
    "Al Nahda",
    "Al Twar",
    "Al Warqaa",
    "Mirdif",
    "Muhaisnah",
    "Al Quoz",
    "Umm Al Sheif",
    "Al Sufouh",
    "Al Manara",
    "Al Wasl",
    "Al Safa",
    "Madinat Dubai Al Melaheyah",
    "Dubai International Financial Centre",
    "Knowledge Village",
    "Dubai Internet City",
    "Dubai Media City",
    "Dubai Silicon Oasis",
    "Al Sufouh 2",
    "Dubai Maritime City",
    "Al Mamzar",
    "Al Qusais 1",
    "Al Qusais Industrial Area",
    "Al Qusais 3",
    "Al Nahda 2",
    "Umm Ramool",
    "Al Twar 2",
    "Dubai Festival City",
    "Jumeirah Islands",
    "Dubai Sports City",
    "Dubai Studio City",
    "The Villa",
    "Dubailand",
    "Dubai Design District",
    "Al Barsha",
    "The Springs",
    "The Meadows",
    "Emirates Hills",
    "The Lakes",
    "The Greens",
    "Tecom",
    "Jumeirah Beach Residence (JBR)",
    "Al Sufouh 1",
    "Barsha Heights (Tecom)",
    "Dubai Motor City",
    "Al Barsha South",
    "Arabian Ranches",
    "Al Barari",
    "Falcon City of Wonders",
    "Academic City",
    "Jumeirah Golf Estates",
    "Dubai Production City (IMPZ)",
    "Mudon",
    "Al Furjan",
    "Discovery Gardens",
    "Dubai Investment Park (DIP)",
    "Jebel Ali Village",
    "Dubai South",
    "Al Quoz Industrial Area",
    "Al Quoz 1",
    "Al Quoz 2",
    "Al Quoz 3",
    "Al Quoz 4",
    "Industrial Area 18",
    "Dubai World Trade Centre (DWTC)",
    "Dubai Health Care City",
    "Zabeel",
    "Al Karama",
    "Al Mankhool",
    "Al Raffa",
    "Al Souq Al Kabeer",
    "Trade Centre 1",
    "Bur Dubai",
    "Jumeirah 1",
    "Jumeirah 2",
    "Jumeirah 3",
    "Jumeirah Park",
    "Al Safa 1",
    "Al Safa 2",
    "Jumeirah Beach Park",
    "Madinat Jumeirah",
    "Satwa Roundabout",
    "Al Wasl",
    "Jumeirah Mosque",
    "Umm Suqeim 1",
    "Umm Suqeim 2",
    "Umm Suqeim 3",
    "Al Barsha 1",
    "Al Barsha 2",
    "Al Barsha 3",
    "Al Barsha South",
    "Dubai Sports City",
    "Dubai International Cricket Stadium",
    "Dubai International Stadium",
    "Dubai Investments Park",
    "Jebel Ali Free Zone (JAFZA)",
    "Al Furjan",
    "Dubai Sustainable City",
    "Reem Community",
    "Mira Oasis",
    "Mudon",
    "The Sustainable City",
    "Dubai Science Park",
    "Jumeirah Islands",
    "Dubai Design District",
    "City Walk",
    "Dubai Hills Estate",
    "Nad Al Sheba",
    "Nadd Al Shiba Horse Racing",
    "Dubai Safari Park",
    "International City",
    "Warsan",
    "Al Awir",
    "Mirdif",
    "Al Khawaneej",
    "Al Qusais",
    "Al Nahda",
    "Al Twar",
    "Al Mizhar",
    "Muhaisnah",
    "Dubai International Academic City",
    "Dubai International Airport",
    "Dubai World Central",
    "Al Badia",
    "Dubai Festival City",
    "Ras Al Khor",
    "Jebel Ali",
    "Jebel Ali Free Zone (JAFZA)",
    "Dubai Investment Park",
    "Dubai Industrial City",
    "Dubai Investments Park",
    "Dubai Outsource Zone",
    "Dubai Production City (IMPZ)",
    "Dubai Silicon Oasis",
    "Dubai Studio City",
    "Dubai Media City",
    "Dubai Internet City",
    "Knowledge Village",
    "Dubai Knowledge Park",
   
]
for item  in list_items[:]:
    links = [] # save links here
    for study in ['math', 'physics']:
        driver.get(f'https://www.google.com/search?q=site:nl.linkedin.com/in/+AND+%22{item}+AND+%22{study}')
        time.sleep(5) # to make slower 
        n=30
        while n > 0:
            time.sleep(5)
            print("here")
            initialScroll = 0
            finalScroll = 1000
            start = time.time()
            while True:
                driver.execute_script(f"window.scrollTo({initialScroll}, {finalScroll})")
                initialScroll = finalScroll
                finalScroll += 1000
                time.sleep(3)
                end = time.time()
                if round(end - start) > 25:
                    break
            src = driver.page_source
            soup = BeautifulSoup(src, 'lxml')
            linksed_links=soup.find_all("a", {"jsname":"UWckNb"})
            for i in linksed_links:
                links.append(i.get('href').split("?")[0])
            try:
                next_button = driver.find_element(By.XPATH, '//*[@id="pnnext"]') # clicking next button 
                next_button.click()
            except Exception as e:
                driver.get(f'https://www.google.com/search?q=site:nl.linkedin.com/in/+AND+%22{item}+AND+%22{study}')
                n=1
                # print("")
            # print(f'{n} pages left!')
            n -= 1
        df = pd.DataFrame({
            "links":links
        })
        df1=pd.read_csv('datas/Ismatulla_links/data_Ismatulla5.csv')
        df_sum=pd.concat([df1, df], axis=0, ignore_index=True)
        df_sum = df_sum.drop_duplicates()
        df_sum.to_csv(f'datas/Ismatulla_links/data_Ismatulla5.csv', index=False)
        print(f'I am done ---> {item}')
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_4556\926105491.py:10: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(options=options,executable_path='C:/Users/dell/OneDrive/Desktop/chromedriver-win64/chromedriver.exe')
# here
# I am done ---> Hatta
# here
# I am done ---> Hatta
# here
# I am done ---> Dibba Al-Fujairah
# here
# I am done ---> Dibba Al-Fujairah
# here
# I am done ---> Dibba Al-Hisn
# here
# I am done ---> Dibba Al-Hisn
# here
# I am done ---> Madinat Zayed
# here
# I am done ---> Madinat Zayed
# here
# I am done ---> Liwa Oasis
# here
# I am done ---> Liwa Oasis
# here
# I am done ---> Ruwais
# here
# I am done ---> Ruwais
# here
# I am done ---> Ghayathi
# here
# I am done ---> Ghayathi
# here
# I am done ---> Dhaid
# here
# I am done ---> Dhaid
# here
# I am done ---> Al Madam
# here
# I am done ---> Al Madam
# here
# I am done ---> Al Hamra
# here
# I am done ---> Al Hamra
# here
# I am done ---> Al Jazirah Al Hamra
# here
# I am done ---> Al Jazirah Al Hamra
# here
# I am done ---> Masafi
# here
# I am done ---> Masafi
# here
# I am done ---> Al Mirfa
# here
# I am done ---> Al Mirfa
# here
# I am done ---> Muzayri
# here
# I am done ---> Muzayri
# here
# I am done ---> Ar-Rams
# here
# I am done ---> Ar-Rams
# here
# I am done ---> Silat Al-Zahr
# here
# I am done ---> Silat Al-Zahr
# here
# I am done ---> Daftah
# here
# I am done ---> Daftah
# here
# I am done ---> Al Bithnah
# here
# I am done ---> Al Bithnah
# here
# I am done ---> Al Khawaneej
# here
# I am done ---> Al Khawaneej
# here
# I am done ---> Jumeirah
# here
# I am done ---> Jumeirah
# here
# I am done ---> Hajar Mountains
# here
# I am done ---> Hajar Mountains
# here
# I am done ---> Hili
# here
# I am done ---> Hili
# here
# I am done ---> Kalba
# here
# I am done ---> Kalba
# here
# I am done ---> Nakheel
# here
# I am done ---> Nakheel
# here
# I am done ---> Manama
# here
# I am done ---> Manama
# here
# I am done ---> Sweihan
# here
# I am done ---> Sweihan
# here
# I am done ---> Madinat Khalifa
# here
# I am done ---> Madinat Khalifa
# here
# I am done ---> Al Shahama
# here
# I am done ---> Al Shahama
# here
# I am done ---> Khalifa City
# here
# I am done ---> Khalifa City
# here
# I am done ---> Madinat Zayed
# here
# I am done ---> Madinat Zayed
# here
# I am done ---> Zayed City
# here
# I am done ---> Zayed City
# here
# I am done ---> Bida Zayed
# here
# I am done ---> Bida Zayed
# here
# I am done ---> Ghayathi
# here
# I am done ---> Ghayathi
# here
# I am done ---> Habshan
# here
# I am done ---> Habshan
# here
# I am done ---> Huwaylat
# here
# I am done ---> Huwaylat
# here
# I am done ---> Liwa Oasis
# here
# I am done ---> Liwa Oasis
# here
# I am done ---> Marawah
# here
# I am done ---> Marawah
# here
# I am done ---> Ruwais
# here
# I am done ---> Ruwais
# here
# I am done ---> Sila
# here
# I am done ---> Sila
# here
# I am done ---> Zirku
# here
# I am done ---> Zirku
# here
# I am done ---> Dhaid
# here
# I am done ---> Dhaid
# here
# I am done ---> Dibba Al-Fujairah
# here
# I am done ---> Dibba Al-Fujairah
# here
# I am done ---> Madinat Khalifa
# here
# I am done ---> Madinat Khalifa
# here
# I am done ---> Al Maha Forest
# here
# I am done ---> Al Maha Forest
# here
# I am done ---> Al Jaddaf
# here
# I am done ---> Al Jaddaf
# here
# I am done ---> Al Safa
# here
# I am done ---> Al Safa
# here
# I am done ---> Al Safa
# here
# I am done ---> Al Safa
# here
# I am done ---> Umm Suqeim
# here
# I am done ---> Umm Suqeim
# here
# I am done ---> Al Satwa
# here
# I am done ---> Al Satwa
# here
# I am done ---> Al Hamriya Port
# here
# I am done ---> Al Hamriya Port
# here
# I am done ---> Al Hudaiba
# here
# I am done ---> Al Hudaiba
# here
# I am done ---> Al Shindagha
# here
# I am done ---> Al Shindagha
# here
# I am done ---> Al Rashidiya
# here
# I am done ---> Al Rashidiya
# here
# I am done ---> Al Mankhool
# here
# I am done ---> Al Mankhool
# here
# I am done ---> Al Karama
# here
# I am done ---> Al Karama
# here
# I am done ---> Al Garhoud
# here
# I am done ---> Al Garhoud
# here
# I am done ---> Al Jafiliya
# here
# I am done ---> Al Jafiliya
# here
# I am done ---> Al Qusais
# here
# I am done ---> Al Qusais
# here
# I am done ---> Al Nahda
# here
# I am done ---> Al Nahda
# here
# I am done ---> Al Twar
# here
# I am done ---> Al Twar
# here
# I am done ---> Al Warqaa
# here
# I am done ---> Al Warqaa
# here
# I am done ---> Mirdif
# here
# I am done ---> Mirdif
# here
# I am done ---> Muhaisnah
# here
# I am done ---> Muhaisnah
# here
# I am done ---> Al Quoz
# here
# I am done ---> Al Quoz
# here
# I am done ---> Umm Al Sheif
# here
# I am done ---> Umm Al Sheif
# here
# I am done ---> Al Sufouh
# here
# I am done ---> Al Sufouh
# here
# I am done ---> Al Manara
# here
# I am done ---> Al Manara
# here
# I am done ---> Al Wasl
# here
# I am done ---> Al Wasl
# here
# I am done ---> Al Safa
# here
# I am done ---> Al Safa
# here
# I am done ---> Madinat Dubai Al Melaheyah
# here
# I am done ---> Madinat Dubai Al Melaheyah
# here
# I am done ---> Dubai International Financial Centre
# here
# I am done ---> Dubai International Financial Centre
# here
# I am done ---> Knowledge Village
# here
# I am done ---> Knowledge Village
# here
# I am done ---> Dubai Internet City
# here
# I am done ---> Dubai Internet City
# here
# I am done ---> Dubai Media City
# here
# I am done ---> Dubai Media City
# here
# I am done ---> Dubai Silicon Oasis
# here
# I am done ---> Dubai Silicon Oasis
# here
# I am done ---> Al Sufouh 2
# here
# I am done ---> Al Sufouh 2
# here
# I am done ---> Dubai Maritime City
# here
# I am done ---> Dubai Maritime City
# here
# I am done ---> Al Mamzar
# here
# I am done ---> Al Mamzar
# here
# I am done ---> Al Qusais 1
# here
# I am done ---> Al Qusais 1
# here
# I am done ---> Al Qusais Industrial Area
# here
# I am done ---> Al Qusais Industrial Area
# here
# I am done ---> Al Qusais 3
# here
# I am done ---> Al Qusais 3
# here
# I am done ---> Al Nahda 2
# here
# I am done ---> Al Nahda 2
# here
# I am done ---> Umm Ramool
# here
# I am done ---> Umm Ramool
# here
# I am done ---> Al Twar 2
# here
# I am done ---> Al Twar 2
# here
# I am done ---> Dubai Festival City
# here
# I am done ---> Dubai Festival City
# here
# I am done ---> Jumeirah Islands
# here
# I am done ---> Jumeirah Islands
# here
# I am done ---> Dubai Sports City
# here
# I am done ---> Dubai Sports City
# here
# I am done ---> Dubai Studio City
# here
# I am done ---> Dubai Studio City
# here
# I am done ---> The Villa
# here
# I am done ---> The Villa
# here
# I am done ---> Dubailand
# here
# I am done ---> Dubailand
# here
# I am done ---> Dubai Design District
# here
# I am done ---> Dubai Design District
# here
# I am done ---> Al Barsha
# here
# I am done ---> Al Barsha
# here
# I am done ---> The Springs
# here
# I am done ---> The Springs
# here
# I am done ---> The Meadows
# here
# I am done ---> The Meadows
# here
# I am done ---> Emirates Hills
# here
# I am done ---> Emirates Hills
# here
# I am done ---> The Lakes
# here
# I am done ---> The Lakes
# here
# I am done ---> The Greens
# here
# I am done ---> The Greens
# here
# I am done ---> Tecom
# here
# I am done ---> Tecom
# here
# I am done ---> Jumeirah Beach Residence (JBR)
# here
# I am done ---> Jumeirah Beach Residence (JBR)
# here
# I am done ---> Al Sufouh 1
# here
# I am done ---> Al Sufouh 1
# here
# I am done ---> Barsha Heights (Tecom)
# here
# I am done ---> Barsha Heights (Tecom)
# here
# I am done ---> Dubai Motor City
# here
# I am done ---> Dubai Motor City
# here
# I am done ---> Al Barsha South
# here
# I am done ---> Al Barsha South
# here
# I am done ---> Arabian Ranches
# here
# I am done ---> Arabian Ranches
# here
# I am done ---> Al Barari
# here
# I am done ---> Al Barari
# here
# I am done ---> Falcon City of Wonders
# here
# I am done ---> Falcon City of Wonders
# here
# I am done ---> Academic City
# here
# I am done ---> Academic City
# here
# I am done ---> Jumeirah Golf Estates
# here
# I am done ---> Jumeirah Golf Estates
# here
# I am done ---> Dubai Production City (IMPZ)
# here
# I am done ---> Dubai Production City (IMPZ)
# here
# I am done ---> Mudon
# here
# I am done ---> Mudon
# here
# I am done ---> Al Furjan
# here
# I am done ---> Al Furjan
# here
# I am done ---> Discovery Gardens
# here
# I am done ---> Discovery Gardens
# here
# I am done ---> Dubai Investment Park (DIP)
# here
# I am done ---> Dubai Investment Park (DIP)
# here
# I am done ---> Jebel Ali Village
# here
# I am done ---> Jebel Ali Village
# here
# I am done ---> Dubai South
# here
# I am done ---> Dubai South
# here
# I am done ---> Al Quoz Industrial Area
# here
# I am done ---> Al Quoz Industrial Area
# here
# I am done ---> Al Quoz 1
# here
# I am done ---> Al Quoz 1
# here
# I am done ---> Al Quoz 2
# here
# I am done ---> Al Quoz 2
# here
# I am done ---> Al Quoz 3
# here
# I am done ---> Al Quoz 3
# here
# I am done ---> Al Quoz 4
# here
# I am done ---> Al Quoz 4
# here
# I am done ---> Industrial Area 18
# here
# I am done ---> Industrial Area 18
# here
# I am done ---> Dubai World Trade Centre (DWTC)
# here
# I am done ---> Dubai World Trade Centre (DWTC)
# here
# I am done ---> Dubai Health Care City
# here
# I am done ---> Dubai Health Care City
# here
# I am done ---> Zabeel
# here
# I am done ---> Zabeel
# here
# I am done ---> Al Karama
# here
# I am done ---> Al Karama
# here
# I am done ---> Al Mankhool
# here
# I am done ---> Al Mankhool
# here
# I am done ---> Al Raffa
# here
# I am done ---> Al Raffa
# here
# I am done ---> Al Souq Al Kabeer
# here
# I am done ---> Al Souq Al Kabeer
# here
# I am done ---> Trade Centre 1
# here
# I am done ---> Trade Centre 1
# here
# I am done ---> Bur Dubai
# here
# I am done ---> Bur Dubai
# here
# I am done ---> Jumeirah 1
# here
# I am done ---> Jumeirah 1
# here
# I am done ---> Jumeirah 2
# here
# I am done ---> Jumeirah 2
# here
# I am done ---> Jumeirah 3
# here
# I am done ---> Jumeirah 3
# here
# I am done ---> Jumeirah Park
# here
# I am done ---> Jumeirah Park
# here
# I am done ---> Al Safa 1
# here
# I am done ---> Al Safa 1
# here
# I am done ---> Al Safa 2
# here
# I am done ---> Al Safa 2
# here
# I am done ---> Jumeirah Beach Park
# here
# I am done ---> Jumeirah Beach Park
# here
# I am done ---> Madinat Jumeirah
# here
# I am done ---> Madinat Jumeirah
# here
# I am done ---> Satwa Roundabout
# here
# I am done ---> Satwa Roundabout
# here
# I am done ---> Al Wasl
# here
# I am done ---> Al Wasl
# here
# I am done ---> Jumeirah Mosque
# here
# I am done ---> Jumeirah Mosque
# here
# I am done ---> Umm Suqeim 1
# here
# I am done ---> Umm Suqeim 1
# here
# I am done ---> Umm Suqeim 2
# here
# I am done ---> Umm Suqeim 2
# here
# I am done ---> Umm Suqeim 3
# here
# I am done ---> Umm Suqeim 3
# here
# I am done ---> Al Barsha 1
# here
# I am done ---> Al Barsha 1
# here
# I am done ---> Al Barsha 2
# here
# I am done ---> Al Barsha 2
# here
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# c:\Users\dell\OneDrive\Desktop\selenium\Bots_using_selenium\linkedin_data_Scraping\ismat_urls_from_google.ipynb Cell 1 line 2
#     <a href='vscode-notebook-cell:/c%3A/Users/dell/OneDrive/Desktop/selenium/Bots_using_selenium/linkedin_data_Scraping/ismat_urls_from_google.ipynb#W0sZmlsZQ%3D%3D?line=228'>229</a>     if round(end - start) > 25:
#     <a href='vscode-notebook-cell:/c%3A/Users/dell/OneDrive/Desktop/selenium/Bots_using_selenium/linkedin_data_Scraping/ismat_urls_from_google.ipynb#W0sZmlsZQ%3D%3D?line=229'>230</a>         break
# --> <a href='vscode-notebook-cell:/c%3A/Users/dell/OneDrive/Desktop/selenium/Bots_using_selenium/linkedin_data_Scraping/ismat_urls_from_google.ipynb#W0sZmlsZQ%3D%3D?line=230'>231</a> src = driver.page_source
#     <a href='vscode-notebook-cell:/c%3A/Users/dell/OneDrive/Desktop/selenium/Bots_using_selenium/linkedin_data_Scraping/ismat_urls_from_google.ipynb#W0sZmlsZQ%3D%3D?line=231'>232</a> soup = BeautifulSoup(src, 'lxml')
#     <a href='vscode-notebook-cell:/c%3A/Users/dell/OneDrive/Desktop/selenium/Bots_using_selenium/linkedin_data_Scraping/ismat_urls_from_google.ipynb#W0sZmlsZQ%3D%3D?line=232'>233</a> linksed_links=soup.find_all("a", {"jsname":"UWckNb"})
#
# File c:\Users\dell\OneDrive\Desktop\selenium\Bots_using_selenium\venv\lib\site-packages\selenium\webdriver\remote\webdriver.py:541, in WebDriver.page_source(self)
#     532 @property
#     533 def page_source(self) -> str:
#     534     """Gets the source of the current page.
#     535
#     536     :Usage:
#    (...)
#     539             driver.page_source
#     540     """
# --> 541     return self.execute(Command.GET_PAGE_SOURCE)["value"]
#
# File c:\Users\dell\OneDrive\Desktop\selenium\Bots_using_selenium\venv\lib\site-packages\selenium\webdriver\remote\webdriver.py:440, in WebDriver.execute(self, driver_command, params)
#     438 response = self.command_executor.execute(driver_command, params)
#     439 if response:
# --> 440     self.error_handler.check_response(response)
#     441     response["value"] = self._unwrap_value(response.get("value", None))
#     442     return response
#
# File c:\Users\dell\OneDrive\Desktop\selenium\Bots_using_selenium\venv\lib\site-packages\selenium\webdriver\remote\errorhandler.py:245, in ErrorHandler.check_response(self, response)
#     243         alert_text = value["alert"].get("text")
#     244     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 245 raise exception_class(message, screen, stacktrace)
#
# WebDriverException: Message: disconnected: not connected to DevTools
#   (failed to check if window was closed: disconnected: not connected to DevTools)
#   (Session info: chrome=116.0.5845.188)
# Stacktrace:
# 	GetHandleVerifier [0x00007FF7413A52A2+57122]
# 	(No symbol) [0x00007FF74131EA92]
# 	(No symbol) [0x00007FF7411EE3AB]
# 	(No symbol) [0x00007FF7411DBA47]
# 	(No symbol) [0x00007FF7411DB6C0]
# 	(No symbol) [0x00007FF7411EFA71]
# 	(No symbol) [0x00007FF74125E27F]
# 	(No symbol) [0x00007FF741246DB3]
# 	(No symbol) [0x00007FF74121D2B1]
# 	(No symbol) [0x00007FF74121E494]
# 	GetHandleVerifier [0x00007FF74164EF82+2849794]
# 	GetHandleVerifier [0x00007FF7416A1D24+3189156]
# 	GetHandleVerifier [0x00007FF74169ACAF+3160367]
# 	GetHandleVerifier [0x00007FF741436D06+653702]
# 	(No symbol) [0x00007FF74132A208]
# 	(No symbol) [0x00007FF7413262C4]
# 	(No symbol) [0x00007FF7413263F6]
# 	(No symbol) [0x00007FF7413167A3]
# 	BaseThreadInitThunk [0x00007FFB86127344+20]
# 	RtlUserThreadStart [0x00007FFB862626B1+33]

# %%
# Out:
# []

# %%
df = pd.DataFrame({
    "links":links
})
df1=pd.read_csv('datas/Fayyoz_links/data_Fayyoz.csv')
df_sum=pd.concat([df1, df], axis=0, ignore_index=True)
df_sum = df_sum.drop_duplicates()
df_sum.to_csv(f'datas/Fayyoz_links/data_Fayyoz.csv', index=False)
print(f'I am done ---> {item}')
# Out:
# I am done ---> Dhaka, Bangladesh

# %%
df = pd.DataFrame({
    "links":links
})
df1=pd.read_csv('datas/Fayyoz_links/data_Fayyoz.csv')
# df = df.drop_duplicates()
df_sum=pd.concat([df1, df], axis=0, ignore_index=True)
df_sum = df_sum.drop_duplicates()
df_sum.to_csv(f'datas/Fayyoz_links/data_Fayyoz.csv', index=False)
print(f'I am done ---> {item}')
# Out:
# I am done ---> Shanghai, China

# %%
j=592

# %%
df = pd.DataFrame({
    "links":links
})
df = df.drop_duplicates()
df.to_csv(f'datas/linkedin_links_29_06/data{str(j)}.csv', index=False)
print(f'I am done ---> {str(j)}')
print(f'if there is a problem, start with {str(j+1)}')
# Out:
# I am done ---> 599
# if there is a problem, start with 600

# %%
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from selenium import webdriver
import time
import pandas as pd

chrome_driver_path = Service(
    "chromedriver.exe")
driver = webdriver.Chrome(service=chrome_driver_path)

# options = Options()
# options.add_argument("user-data-dir=C:\\Users\\Username\\AppData\\Local\\Google\\Chrome\\User Data")
# driver = webdriver.Chrome(options=options)
# 'Mathematics and Bachelor words are used as a default, it is changeble
driver.get('https://www.google.com/search?q=site:nl.linkedin.com/in/+AND+%22Computational Social Science%22+AND+%22Bachelor%27s&sxsrf=ALiCzsbOTqrA98wDQf3mtEB03kA_O7eCbQ:1668686082134&ei=AiF2Y4vwB-3JrgS9gpd4&start=50&sa=N&ved=2ahUKEwiL-aqJlLX7AhXtpIsKHT3BBQ84KBDy0wN6BAgBEA0&biw=920&bih=625&dpr=1')
time.sleep(10) # to make slower 

 # n is the number of pages
links = [] # save links here
n=6
while n > 0:
    time.sleep(5)
    for i in range(1, 11): # google uses paginator, every page has 10 urls
        time.sleep(6)
        try:
            elems = driver.find_elements(By.XPATH, '//*[@id="rso"]/div['+str(i)+']/div/div/div[1]/div/a')
            for elem in elems:
                
                clean_url = elem.get_attribute("href") # extracting url 
                base_url = "linkedin.com/in/"
                if clean_url.find(base_url) != -1 and '%' not in clean_url: # sometimes google gives no Ln urls, so clean it
                    links.append(clean_url)
                    print(f"url is --->{clean_url}")
        except Exception as e:
            print(e)
            pass
    try:
        next_button = driver.find_element(By.XPATH, '//*[@id="pnnext"]') # clicking next button 
        next_button.click()
    except Exception as e:
        print(e)
    print(f'{n} pages left!')
    n -= 1
df = pd.DataFrame({
    "links":links
})
df.to_csv('datas/linkedin_aaccount_links/Filosofie.csv', index=False)
