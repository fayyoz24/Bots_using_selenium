# %%
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from selenium import webdriver
import time
import pandas as pd
from bs4 import BeautifulSoup
options = Options()
options.add_argument("user-data-dir=C:/Users/dell/AppData/Local/Google/Chrome/User Data/Profile 3")
                                                        #C:\Users\fayyo\Downloads\chromedriver-win32.zip\chromedriver-win32
driver = webdriver.Chrome(options=options,executable_path='C:/Users/dell/OneDrive/Desktop/chromedriver-win64/chromedriver.exe')
# country names
list_items = [
    "Jakarta",
    "Surabaya",
    "Bandung",
    "Medan",
    "Semarang",
    "Makassar",
    "Palembang",
    "Tangerang",
    "Depok",
    "Batam",
    "Bekasi",
    "South Tangerang",
    "Bogor",
    "Pekanbaru",
    "Padang",
    "Bandar Lampung",
    "Denpasar",
    "Malang",
    "Surakarta",
    "Banjarmasin",
    "Yogyakarta",
    "Cimahi",
    "Pontianak",
    "Balikpapan",
    "Jambi",
    "Manado",
    "Ambon",
    "Palu",
    "Kendari",
    "Padangsidempuan",
    "Samarinda",
    "Tasikmalaya",
    "Tanjungpinang",
    "Bengkulu",
    "Mojokerto",
    "Pekalongan",
    "Probolinggo",
    "Cirebon",
    "Binjai",
    "Purwokerto",
    "Salatiga",
    "Kupang",
    "Cianjur",
    "Sibolga",
    "Pematangsiantar",
    "Cilacap",
    "Nabire",
    "Ternate",
    "Magelang",
    "Sukabumi",
    "Parepare",
    "Kediri",
    "Lhokseumawe",
    "Tomohon",
    "Tanjungbalai",
    "Singkawang",
    "Tebingtinggi",
    "Pariaman",
    "Sungai Penuh",
    "Sawahlunto",
    "Langsa",
    "Bitung",
    "Prabumulih",
    "Bontang",
    "Sorong",
    "Palopo",
    "Tidore",
    "Subulussalam",
    "Lubuklinggau",
    "Merauke",
    "Tanjung Redeb",
    "Kotamobagu",
    "Meulaboh",
    "Langsa",
    "Padang Panjang",
    "Blitar",
    "Bima",
    "Pematang Siantar",
    "Pangkal Pinang",
    "Lahat",
    "Pare-Pare",
    "Palopo",
    "Sorong",
    "Tanjung Selor",
    "Samarinda",
    "Dumai",
    "Cilegon",
    "Gorontalo",
    "Banda Aceh",
    "Bukittinggi",
    "Tasikmalaya",
    "Banjarbaru",
    "Tarakan",
    "Metro",
    "Pemalang",
    "Tegal",
    "Lamongan",
    "Kendal",
    "Pasuruan",
    "Magelang",
    "Sorong",
    "Tanjungpinang",
    "Palangka Raya",
    "Sibolga",
    "Padangsidempuan",
    "Singkawang",
    "Tebingtinggi",
    "Pematangsiantar",
    "Bukittinggi",
    "Solok",
    "Padang Panjang",
    "Painan",
    "Payakumbuh",
    "Pariaman",
    "Batusangkar",
    "Lubuklinggau",
    "Prabumulih",
    "Palembang",
    "Cilegon",
    "Cimahi",
    "Kediri",
    "Tangerang Selatan",
    "Banjarbaru",
    "Pontianak",
    "Ambon",
    "Palu",
    "Kendari",
    "Padangsidempuan",
    "Samarinda",
    "Tasikmalaya",
    "Tanjungpinang",
    "Bengkulu",
    "Pematangsiantar",
    "Cilacap",
    "Pariaman",
    "Ternate",
    "Magelang",
    "Sukabumi",
    "Parepare",
    "Tomohon",
    "Tanjungbalai",
    "Singkawang",
    "Tanjung Selor",
    "Langsa",
    "Bitung",
    "Prabumulih",
    "Bontang",
    "Sorong",
    "Palopo",
    "Tidore",
    "Subulussalam",
    "Lubuklinggau",
    "Merauke",
    "Tanjung Redeb",
    "Kotamobagu",
    "Meulaboh",
    "Langsa",
    "Padang Panjang",
    "Blitar",
    "Bima",
    "Pematang Siantar",
    "Pangkal Pinang",
    "Lahat",
    "Pare-Pare",
    "Palopo",
    "Sorong",
    "Tanjung Selor",
    "Samarinda",
    "Dumai",
    "Cilegon",
    "Gorontalo",
    "Banda Aceh",
    "Bukittinggi",
    "Tasikmalaya",
    "Banjarbaru",
    "Tarakan",
    "Metro",
    "Pemalang",
    "Tegal",
    "Lamongan",
    "Kendal",
    "Pasuruan",
    "Magelang",
    "Sorong",
    "Tanjungpinang",
    "Palangka Raya",
    "Sibolga",
    "Padangsidempuan",
    "Singkawang",
    "Tebingtinggi",
    "Pematangsiantar",
    "Bukittinggi",
    "Solok",
    "Padang Panjang",
    "Painan",
    "Payakumbuh",
    "Pariaman",
    "Batusangkar",
    "Lubuklinggau",
    "Prabumulih",
    "Palembang",
    "Cilegon",
    "Cimahi",
    "Kediri",
    "Tangerang Selatan",
    "Banjarbaru",
    "Pontianak",
    "Ambon",
    "Palu",
    "Kendari",
    "Padangsidempuan",
    "Samarinda",
    "Tasikmalaya",
    "Tanjungpinang",
    "Bengkulu",
    "Pematangsiantar",
    "Cilacap",
    "Pariaman",
    "Ternate",
    "Magelang",
    "Sukabumi",
    "Parepare",
    "Tomohon",
    "Tanjungbalai",
    "Singkawang",
    "Tanjung Selor",
    "Langsa",
    "Bitung",
    "Prabumulih",
    "Bontang",
    "Sorong",
]


for item  in list_items[:]:
    links = [] # save links here
    for study in ['math', 'physics']:
        driver.get(f'https://www.google.com/search?q=site:nl.linkedin.com/in/+AND+%22{item}+AND+%22{study}')
        time.sleep(5) # to make slower 
        n=30
        while n > 0:
            time.sleep(5)
            print("here")
            initialScroll = 0
            finalScroll = 1000
            start = time.time()
            while True:
                driver.execute_script(f"window.scrollTo({initialScroll}, {finalScroll})")
                initialScroll = finalScroll
                finalScroll += 1000
                time.sleep(3)
                end = time.time()
                if round(end - start) > 25:
                    break
            src = driver.page_source
            soup = BeautifulSoup(src, 'lxml')
            linksed_links=soup.find_all("a", {"jsname":"UWckNb"})
            for i in linksed_links:
                links.append(i.get('href').split("?")[0])
            try:
                next_button = driver.find_element(By.XPATH, '//*[@id="pnnext"]') # clicking next button 
                next_button.click()
            except Exception as e:
                driver.get(f'https://www.google.com/search?q=site:nl.linkedin.com/in/+AND+%22{item}+AND+%22{study}')
                n=1
                # print("")
            # print(f'{n} pages left!')
            n -= 1
        df = pd.DataFrame({
            "links":links
        })
        df1=pd.read_csv('datas/Ismatulla_links/data_Ismatulla4.csv')
        df_sum=pd.concat([df1, df], axis=0, ignore_index=True)
        df_sum = df_sum.drop_duplicates()
        df_sum.to_csv(f'datas/Ismatulla_links/data_Ismatulla4.csv', index=False)
        print(f'I am done ---> {item}')
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_14948\765163634.py:10: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(options=options,executable_path='C:/Users/dell/OneDrive/Desktop/chromedriver-win64/chromedriver.exe')
# here
# I am done ---> Warsaw
# here
# I am done ---> Warsaw
# here
# I am done ---> Kraków
# here
# I am done ---> Kraków
# here
# I am done ---> Łódź
# here
# I am done ---> Łódź
# here
# I am done ---> Wrocław
# here
# I am done ---> Wrocław
# here
# I am done ---> Poznań
# here
# I am done ---> Poznań
# here
# I am done ---> Gdańsk
# here
# I am done ---> Gdańsk
# here
# I am done ---> Szczecin
# here
# I am done ---> Szczecin
# here
# I am done ---> Bydgoszcz
# here
# I am done ---> Bydgoszcz
# here
# I am done ---> Lublin
# here
# I am done ---> Lublin
# here
# I am done ---> Białystok
# here
# I am done ---> Białystok
# here
# I am done ---> Katowice
# here
# I am done ---> Katowice
# here
# I am done ---> Gdynia
# here
# I am done ---> Gdynia
# here
# I am done ---> Częstochowa
# here
# I am done ---> Częstochowa
# here
# I am done ---> Radom
# here
# I am done ---> Radom
# here
# I am done ---> Sosnowiec
# here
# I am done ---> Sosnowiec
# here
# I am done ---> Toruń
# here
# I am done ---> Toruń
# here
# I am done ---> Kielce
# here
# I am done ---> Kielce
# here
# I am done ---> Rzeszów
# here
# I am done ---> Rzeszów
# here
# I am done ---> Gliwice
# here
# I am done ---> Gliwice
# here
# I am done ---> Zabrze
# here
# I am done ---> Zabrze
# here
# I am done ---> Olsztyn
# here
# I am done ---> Olsztyn
# here
# I am done ---> Bielsko-Biała
# here
# I am done ---> Bielsko-Biała
# here
# I am done ---> Bytom
# here
# I am done ---> Bytom
# here
# I am done ---> Zielona Góra
# here
# I am done ---> Zielona Góra
# here
# I am done ---> Rybnik
# here
# I am done ---> Rybnik
# here
# I am done ---> Ruda Śląska
# here
# I am done ---> Ruda Śląska
# here
# I am done ---> Opole
# here
# I am done ---> Opole
# here
# I am done ---> Tychy
# here
# I am done ---> Tychy
# here
# I am done ---> Gorzów Wielkopolski
# here
# I am done ---> Gorzów Wielkopolski
# here
# I am done ---> Dąbrowa Górnicza
# here
# I am done ---> Dąbrowa Górnicza
# here
# I am done ---> Elbląg
# here
# I am done ---> Elbląg
# here
# I am done ---> Płock
# here
# I am done ---> Płock
# here
# I am done ---> Wałbrzych
# here
# I am done ---> Wałbrzych
# here
# I am done ---> Włocławek
# here
# I am done ---> Włocławek
# here
# I am done ---> Tarnów
# here
# I am done ---> Tarnów
# here
# I am done ---> Chorzów
# here
# I am done ---> Chorzów
# here
# I am done ---> Koszalin
# here
# I am done ---> Koszalin
# here
# I am done ---> Kalisz
# here
# I am done ---> Kalisz
# here
# I am done ---> Legnica
# here
# I am done ---> Legnica
# here
# I am done ---> Grudziądz
# here
# I am done ---> Grudziądz
# here
# I am done ---> Jaworzno
# here
# I am done ---> Jaworzno
# here
# I am done ---> Słupsk
# here
# I am done ---> Słupsk
# here
# I am done ---> Jastrzębie-Zdrój
# here
# I am done ---> Jastrzębie-Zdrój
# here
# I am done ---> Nowy Sącz
# here
# I am done ---> Nowy Sącz
# here
# I am done ---> Jelenia Góra
# here
# I am done ---> Jelenia Góra
# here
# I am done ---> Konin
# here
# I am done ---> Konin
# here
# I am done ---> Piotrków Trybunalski
# here
# I am done ---> Piotrków Trybunalski
# here
# I am done ---> Siedlce
# here
# I am done ---> Siedlce
# here
# I am done ---> Lubin
# here
# I am done ---> Lubin
# here
# I am done ---> Inowrocław
# here
# I am done ---> Inowrocław
# here
# I am done ---> Pabianice
# here
# I am done ---> Pabianice
# here
# I am done ---> Mysłowice
# here
# I am done ---> Mysłowice
# here
# I am done ---> Ostrowiec Świętokrzyski
# here
# I am done ---> Ostrowiec Świętokrzyski
# here
# I am done ---> Siemianowice Śląskie
# here
# I am done ---> Siemianowice Śląskie
# here
# I am done ---> Gniezno
# here
# I am done ---> Gniezno
# here
# I am done ---> Stargard
# here
# I am done ---> Stargard
# here
# I am done ---> Piekary Śląskie
# here
# I am done ---> Piekary Śląskie
# here
# I am done ---> Leszno
# here
# I am done ---> Leszno
# here
# I am done ---> Kędzierzyn-Koźle
# here
# I am done ---> Kędzierzyn-Koźle
# here
# I am done ---> Mikołów
# here
# I am done ---> Mikołów
# here
# I am done ---> Tomaszów Mazowiecki
# here
# I am done ---> Tomaszów Mazowiecki
# here
# I am done ---> Swidnica
# here
# I am done ---> Swidnica
# here
# I am done ---> Lędziny
# here
# I am done ---> Lędziny
# here
# I am done ---> Zamość
# here
# I am done ---> Zamość
# here
# I am done ---> Tarnowskie Góry
# here
# I am done ---> Tarnowskie Góry
# here
# I am done ---> Świdnik
# here
# I am done ---> Świdnik
# here
# I am done ---> Biała Podlaska
# here
# I am done ---> Biała Podlaska
# here
# I am done ---> Sopot
# here
# I am done ---> Sopot
# here
# I am done ---> Krosno
# here
# I am done ---> Krosno
# here
# I am done ---> Grodzisk Mazowiecki
# here
# I am done ---> Grodzisk Mazowiecki
# here
# I am done ---> Radomsko
# here
# I am done ---> Radomsko
# here
# I am done ---> Piła
# here
# I am done ---> Piła
# here
# I am done ---> Ostrołęka
# here
# I am done ---> Ostrołęka
# here
# I am done ---> Głogów
# here
# I am done ---> Głogów
# here
# I am done ---> Puławy
# here
# I am done ---> Puławy
# here
# I am done ---> Ełk
# here
# I am done ---> Ełk
# here
# I am done ---> Kędzierzyn-Koźle
# here
# I am done ---> Kędzierzyn-Koźle
# here
# I am done ---> Przemyśl
# here
# I am done ---> Przemyśl
# here
# I am done ---> Tczew
# here
# I am done ---> Tczew
# here
# I am done ---> Tarnobrzeg
# here
# I am done ---> Tarnobrzeg
# here
# I am done ---> Świętochłowice
# here
# I am done ---> Świętochłowice
# here
# I am done ---> Płock
# here
# I am done ---> Płock
# here
# I am done ---> Nysa
# here
# I am done ---> Nysa
# here
# I am done ---> Wejherowo
# here
# I am done ---> Wejherowo
# here
# I am done ---> Ciechanów
# here
# I am done ---> Ciechanów
# here
# I am done ---> Racibórz
# here
# I am done ---> Racibórz
# here
# I am done ---> Grójec
# here
# I am done ---> Grójec
# here
# I am done ---> Opole
# here
# I am done ---> Opole
# here
# I am done ---> Legionowo
# here
# I am done ---> Legionowo
# here
# I am done ---> Żory
# here
# I am done ---> Żory
# here
# I am done ---> Starachowice
# here
# I am done ---> Starachowice
# here
# I am done ---> Ostrów Wielkopolski
# here
# I am done ---> Ostrów Wielkopolski
# here
# I am done ---> Lubin
# here
# I am done ---> Lubin
# here
# I am done ---> Ostrowiec Świętokrzyski
# here
# I am done ---> Ostrowiec Świętokrzyski
# here
# I am done ---> Suwałki
# here
# I am done ---> Suwałki
# here
# I am done ---> Piaseczno
# here
# I am done ---> Piaseczno
# here
# I am done ---> Wodzisław Śląski
# here
# I am done ---> Wodzisław Śląski
# here
# I am done ---> Zgierz
# here
# I am done ---> Zgierz
# here
# I am done ---> Siedlce
# here
# I am done ---> Siedlce
# here
# I am done ---> Ostrołęka
# here
# I am done ---> Ostrołęka
# here
# I am done ---> Tczew
# here
# I am done ---> Tczew
# here
# I am done ---> Ruda Śląska
# here
# I am done ---> Ruda Śląska
# here
# I am done ---> Świdnica
# here
# I am done ---> Świdnica
# here
# I am done ---> Zabrze
# here
# I am done ---> Zabrze
# here
# I am done ---> Cieszyn
# here
# I am done ---> Cieszyn
# here
# I am done ---> Mława
# here
# I am done ---> Mława
# here
# I am done ---> Szczecinek
# here
# I am done ---> Szczecinek
# here
# I am done ---> Choszczno
# here
# I am done ---> Choszczno
# here
# I am done ---> Pruszcz Gdański
# here
# I am done ---> Pruszcz Gdański
# here
# I am done ---> Sieradz
# here
# I am done ---> Sieradz
# here
# I am done ---> Dzierżoniów
# here
# I am done ---> Dzierżoniów
# here
# I am done ---> Świnoujście
# here
# I am done ---> Świnoujście
# here
# I am done ---> Oława
# here
# I am done ---> Oława
# here
# I am done ---> Jawor
# here
# I am done ---> Jawor
# here
# I am done ---> Pleszew
# here
# I am done ---> Pleszew
# here
# I am done ---> Ostrów Mazowiecka
# here
# I am done ---> Ostrów Mazowiecka
# here
# I am done ---> Krotoszyn
# here
# I am done ---> Krotoszyn
# here
# I am done ---> Pszczyna
# here
# I am done ---> Pszczyna
# here
# I am done ---> Bartoszyce
# here
# I am done ---> Bartoszyce
# here
# I am done ---> Olesno
# here
# I am done ---> Olesno
# here
# I am done ---> Kościerzyna
# here
# I am done ---> Kościerzyna
# here
# I am done ---> Nisko
# here
# I am done ---> Nisko
# here
# I am done ---> Świecie
# here
# I am done ---> Świecie
# here
# I am done ---> Dębica
# here
# I am done ---> Dębica
# here
# I am done ---> Skarżysko-Kamienna
# here
# I am done ---> Skarżysko-Kamienna
# here
# I am done ---> Czarnków
# here
# I am done ---> Czarnków
# here
# I am done ---> Augustów
# here
# I am done ---> Augustów
# here
# I am done ---> Turek
# here
# I am done ---> Turek
# here
# I am done ---> Gorlice
# here
# I am done ---> Gorlice
# here
# I am done ---> Braniewo
# here
# I am done ---> Braniewo
# here
# I am done ---> Żary
# here
# I am done ---> Żary
# here
# I am done ---> Kwidzyn
# here
# I am done ---> Kwidzyn
# here
# I am done ---> Puck
# here
# I am done ---> Puck
# here
# I am done ---> Starogard Gdański
# here
# I am done ---> Starogard Gdański
# here
# I am done ---> Strzelce Opolskie
# here
# I am done ---> Strzelce Opolskie
# here
# I am done ---> Nakło nad Notecią
# here
# I am done ---> Nakło nad Notecią
# here
# I am done ---> Grodzisk Wielkopolski
# here
# I am done ---> Grodzisk Wielkopolski
# here
# I am done ---> Jarocin
# here
# I am done ---> Jarocin
# here
# I am done ---> Jelcz-Laskowice
# here
# I am done ---> Jelcz-Laskowice
# here
# I am done ---> Nowa Ruda
# here
# I am done ---> Nowa Ruda
# here
# I am done ---> Sandomierz
# here
# I am done ---> Sandomierz
# here
# I am done ---> Goleniów
# here
# I am done ---> Goleniów
# here
# I am done ---> Kostrzyn nad Odrą
# here
# I am done ---> Kostrzyn nad Odrą
# here
# I am done ---> Rawicz
# here
# I am done ---> Rawicz
# here
# I am done ---> Lubsko
# here
# I am done ---> Lubsko
# here
# I am done ---> Świebodzin
# here
# I am done ---> Świebodzin
# here
# I am done ---> Myszków
# here
# I am done ---> Myszków
# here
# I am done ---> Działdowo
# here
# I am done ---> Działdowo
# here
# I am done ---> Kutno
# here
# I am done ---> Kutno
# here
# I am done ---> Pisz
# here
# I am done ---> Pisz
# here
# I am done ---> Złotów
# here
# I am done ---> Złotów
# here
# I am done ---> Jaworzyna Śląska
# here
# I am done ---> Jaworzyna Śląska
# here
# I am done ---> Prudnik
# here
# I am done ---> Prudnik
# here
# I am done ---> Biała Rawska
# here
# I am done ---> Biała Rawska
# here
# I am done ---> Włoszczowa
# here
# I am done ---> Włoszczowa
# here
# I am done ---> Pszów
# here
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# Cell In[13], line 232
#     230 start = time.time()
#     231 while True:
# --> 232     driver.execute_script(f"window.scrollTo({initialScroll}, {finalScroll})")
#     233     initialScroll = finalScroll
#     234     finalScroll += 1000
#
# File c:\Users\dell\OneDrive\Desktop\selenium\Bots_using_selenium\venv\lib\site-packages\selenium\webdriver\remote\webdriver.py:500, in WebDriver.execute_script(self, script, *args)
#     497 converted_args = list(args)
#     498 command = Command.W3C_EXECUTE_SCRIPT
# --> 500 return self.execute(command, {"script": script, "args": converted_args})["value"]
#
# File c:\Users\dell\OneDrive\Desktop\selenium\Bots_using_selenium\venv\lib\site-packages\selenium\webdriver\remote\webdriver.py:440, in WebDriver.execute(self, driver_command, params)
#     438 response = self.command_executor.execute(driver_command, params)
#     439 if response:
# --> 440     self.error_handler.check_response(response)
#     441     response["value"] = self._unwrap_value(response.get("value", None))
#     442     return response
#
# File c:\Users\dell\OneDrive\Desktop\selenium\Bots_using_selenium\venv\lib\site-packages\selenium\webdriver\remote\errorhandler.py:245, in ErrorHandler.check_response(self, response)
#     243         alert_text = value["alert"].get("text")
#     244     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 245 raise exception_class(message, screen, stacktrace)
#
# WebDriverException: Message: disconnected: not connected to DevTools
#   (failed to check if window was closed: disconnected: not connected to DevTools)
#   (Session info: chrome=116.0.5845.180)
# Stacktrace:
# 	GetHandleVerifier [0x00007FF79E2552A2+57122]
# 	(No symbol) [0x00007FF79E1CEA92]
# 	(No symbol) [0x00007FF79E09E3AB]
# 	(No symbol) [0x00007FF79E08BA47]
# 	(No symbol) [0x00007FF79E08B6C0]
# 	(No symbol) [0x00007FF79E09FA71]
# 	(No symbol) [0x00007FF79E10E27F]
# 	(No symbol) [0x00007FF79E0F6DB3]
# 	(No symbol) [0x00007FF79E0CD2B1]
# 	(No symbol) [0x00007FF79E0CE494]
# 	GetHandleVerifier [0x00007FF79E4FEF82+2849794]
# 	GetHandleVerifier [0x00007FF79E551D24+3189156]
# 	GetHandleVerifier [0x00007FF79E54ACAF+3160367]
# 	GetHandleVerifier [0x00007FF79E2E6D06+653702]
# 	(No symbol) [0x00007FF79E1DA208]
# 	(No symbol) [0x00007FF79E1D62C4]
# 	(No symbol) [0x00007FF79E1D63F6]
# 	(No symbol) [0x00007FF79E1C67A3]
# 	BaseThreadInitThunk [0x00007FFE3C5C7614+20]
# 	RtlUserThreadStart [0x00007FFE3CA626B1+33]

# %%
# Out:
# []

# %%
df = pd.DataFrame({
    "links":links
})
df1=pd.read_csv('datas/Fayyoz_links/data_Fayyoz.csv')
df_sum=pd.concat([df1, df], axis=0, ignore_index=True)
df_sum = df_sum.drop_duplicates()
df_sum.to_csv(f'datas/Fayyoz_links/data_Fayyoz.csv', index=False)
print(f'I am done ---> {item}')
# Out:
# I am done ---> Dhaka, Bangladesh

# %%
df = pd.DataFrame({
    "links":links
})
df1=pd.read_csv('datas/Fayyoz_links/data_Fayyoz.csv')
# df = df.drop_duplicates()
df_sum=pd.concat([df1, df], axis=0, ignore_index=True)
df_sum = df_sum.drop_duplicates()
df_sum.to_csv(f'datas/Fayyoz_links/data_Fayyoz.csv', index=False)
print(f'I am done ---> {item}')
# Out:
# I am done ---> Shanghai, China

# %%
j=592

# %%
df = pd.DataFrame({
    "links":links
})
df = df.drop_duplicates()
df.to_csv(f'datas/linkedin_links_29_06/data{str(j)}.csv', index=False)
print(f'I am done ---> {str(j)}')
print(f'if there is a problem, start with {str(j+1)}')
# Out:
# I am done ---> 599
# if there is a problem, start with 600

# %%
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from selenium import webdriver
import time
import pandas as pd

chrome_driver_path = Service(
    "chromedriver.exe")
driver = webdriver.Chrome(service=chrome_driver_path)

# options = Options()
# options.add_argument("user-data-dir=C:\\Users\\Username\\AppData\\Local\\Google\\Chrome\\User Data")
# driver = webdriver.Chrome(options=options)
# 'Mathematics and Bachelor words are used as a default, it is changeble
driver.get('https://www.google.com/search?q=site:nl.linkedin.com/in/+AND+%22Computational Social Science%22+AND+%22Bachelor%27s&sxsrf=ALiCzsbOTqrA98wDQf3mtEB03kA_O7eCbQ:1668686082134&ei=AiF2Y4vwB-3JrgS9gpd4&start=50&sa=N&ved=2ahUKEwiL-aqJlLX7AhXtpIsKHT3BBQ84KBDy0wN6BAgBEA0&biw=920&bih=625&dpr=1')
time.sleep(10) # to make slower 

 # n is the number of pages
links = [] # save links here
n=6
while n > 0:
    time.sleep(5)
    for i in range(1, 11): # google uses paginator, every page has 10 urls
        time.sleep(6)
        try:
            elems = driver.find_elements(By.XPATH, '//*[@id="rso"]/div['+str(i)+']/div/div/div[1]/div/a')
            for elem in elems:
                
                clean_url = elem.get_attribute("href") # extracting url 
                base_url = "linkedin.com/in/"
                if clean_url.find(base_url) != -1 and '%' not in clean_url: # sometimes google gives no Ln urls, so clean it
                    links.append(clean_url)
                    print(f"url is --->{clean_url}")
        except Exception as e:
            print(e)
            pass
    try:
        next_button = driver.find_element(By.XPATH, '//*[@id="pnnext"]') # clicking next button 
        next_button.click()
    except Exception as e:
        print(e)
    print(f'{n} pages left!')
    n -= 1
df = pd.DataFrame({
    "links":links
})
df.to_csv('datas/linkedin_aaccount_links/Filosofie.csv', index=False)
