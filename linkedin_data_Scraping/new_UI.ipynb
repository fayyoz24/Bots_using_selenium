# %%
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from selenium import webdriver
import time
import pandas as pd

options = Options()
options.add_argument("user-data-dir=C:/Users/dell/AppData/Local/Google/Chrome/User Data/Profile 23")
                                                        #C:\Users\fayyo\Downloads\chromedriver-win32.zip\chromedriver-win32
driver = webdriver.Chrome(options=options,executable_path='C:/Users/fayyo/Downloads/chromedriver.exe')
# country names
list_items = [
    # "Renewable Energy Management",
    # "Social Policy",
    # "Digital Arts",
    # "Quantum Physics",
    # "Public Sociology",
    # "Environmental Economics",
    # "Forestry",
    # "Applied Chemistry",
    # "Science Communication",
    # "Artificial Life",
    "Environmental Law",
    "Sustainable Development",
    "Clinical Nutrition",
    "Biotechnology",
    "Cultural Studies",
    "Environmental Geology",
    "Materials Engineering",
    "Comparative Religion",
    "Digital Communication",
    "Cognitive Computing",
    "Public Opinion Analysis",
    "Sport and Exercise Science",
    "Equine Science",
    "Aviation Management",
    "Industrial Management",
    "Cellular Biology",
    "Plant Biotechnology",
    "Bioinformatics",
    "Space Engineering",
    "Technical Writing",
    "Digital Humanities",
    "Social Anthropology",
    "Community Development",
    "Developmental Biology",
    "Renewable Energy Policy",
    "Fisheries and Wildlife Management",

]
for item  in list_items[:]:
    links = [] # save links here
    for study in ['master', 'bachelor']:
        driver.get(f'https://www.google.com/search?q=site:nl.linkedin.com/in/+AND+%22{item}+AND+%22{study}')
        time.sleep(10) # to make slower 
        # n is the number of pages
        n=30
        while n > 0:
            time.sleep(5)
            for i in range(1, 11): # google uses paginator, every page has 10 urls
                time.sleep(6)
                try:    #/html/body/div[6]/div/div[13]/div/div[2]/div[2]/div/div/div[1]/div/div/div[1]/div/div/a
                        #/html/body/div[6]/div/div[13]/div/div[2]/div[2]/div/div/div[4]/div/div/div[1]/div/div/a
                        #/html/body/div[6]/div/div[13]/div/div[2]/div[2]/div/div/div[9]/div/div/div/div[1]/div/div/a
                    elems = driver.find_elements(By.XPATH, '/html/body/div[6]/div/div[12]/div/div[2]/div[2]/div/div/div['+str(i)+']/div/div/div[1]/div/div/a')
                    for elem in elems:                     #/html/body/div[6]/div/div[12]/div/div[2]/div[2]/div/div/div[3]/div/div/div[1]/div/div/a
                                                           #/html/body/div[6]/div/div[12]/div/div[2]/div[2]/div/div/div[2]/div/div/div[1]/div/div/a
                        clean_url = elem.get_attribute("href") # extracting url 
                        base_url = "linkedin.com/in/"
                        if clean_url.find(base_url) != -1 and '%' not in clean_url: # sometimes google gives no Ln urls, so clean it
                            links.append(clean_url)
                except Exception as e:
                    print("problem with ELEMS")
                    pass
            try:
                next_button = driver.find_element(By.XPATH, '//*[@id="pnnext"]') # clicking next button 
                next_button.click()
            except Exception as e:
                driver.get(f'https://www.google.com/search?q=site:nl.linkedin.com/in/+AND+%22{item}+AND+%22{study}')
                # print("")
            # print(f'{n} pages left!')
            n -= 1
    df = pd.DataFrame({
        "links":links
    })
    df1=pd.read_csv('datas/Fayyoz_links/data_Fayyoz.csv')
    df_sum=pd.concat([df1, df], axis=0, ignore_index=True)
    df_sum = df_sum.drop_duplicates()
    df_sum.to_csv(f'datas/Fayyoz_links/data_Fayyoz.csv', index=False)
    print(f'I am done ---> {item}')
# Out:
# C:\Users\fayyo\AppData\Local\Temp\ipykernel_8416\2482873663.py:10: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(options=options,executable_path='C:/Users/fayyo/Downloads/chromedriver.exe')
# I am done ---> Environmental Law
# problem with ELEMS
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Cell In[1], line 76
#      75 try:
# ---> 76     next_button = driver.find_element(By.XPATH, '//*[@id="pnnext"]') # clicking next button
#      77     next_button.click()
#
# File c:\Users\GitHub\Bots_using_selenium\venv\lib\site-packages\selenium\webdriver\remote\webdriver.py:831, in WebDriver.find_element(self, by, value)
#     829     value = f'[name="{value}"]'
# --> 831 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# ...

# %%
df = pd.DataFrame({
    "links":links
})
df1=pd.read_csv('datas/Fayyoz_links/data_Fayyoz.csv')
df_sum=pd.concat([df1, df], axis=0, ignore_index=True)
df_sum = df_sum.drop_duplicates()
df_sum.to_csv(f'datas/Fayyoz_links/data_Fayyoz.csv', index=False)
print(f'I am done ---> {item}')
# Out:
# I am done ---> Quantum Physics

# %%
from bs4 import BeautifulSoup
import time
from selenium.webdriver.chrome.options import Options
from selenium import webdriver
from selenium.webdriver.common.by import By
import pandas as pd
from selenium.webdriver.common.keys import Keys

options = Options()
options.add_argument("user-data-dir=C:/Users/dell/AppData/Local/Google/Chrome/User Data/Profile 17")
driver = webdriver.Chrome(options=options,executable_path='C:/Users/dell/OneDrive/Desktop/chromedriver.exe')
driver.get('https://www.crystalknows.com/app/register')
time.sleep(10)

df= pd.read_csv(f'../linkedin_data_Scraping/15000_linkedin_profiles.csv')
# df=df[4010:6000]
j=0
k=2320
dict_={}
for link_num in range(2330, 4000, 10):
    j+=1
    try:
        time.sleep(5)
        dots=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/div[1]/nav/div/div[2]/div[4]/div[2]/div[1]')
        dots.click()                       #/html/body/div[2]/div/div/div[2]/div[1]/nav/div/div[2]/div[4]/div[2]/div[1]/svg
        time.sleep(2)
    except:
        print('dots problem')
    try:
        logout=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/div[1]/nav/div/div[2]/div[4]/div[2]/div[2]/a[5]')
        logout.click()
        time.sleep(5)
    except:
        print('logout problem')
    try:
        signup=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div[3]/div/form/div[3]/div/a')
        signup.click()
        time.sleep(8)
    except:
        print('signup probelm')
    try:
        first_name_input=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div[2]/div[3]/div[1]/input')
        first_name_input.click()
        first_name_input.send_keys(f'Alibek')
    except Exception as e:
        print('first_name-->problem')
    try:
        last_name_input=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div[2]/div[3]/div[2]/input')
        last_name_input.click()
        last_name_input.send_keys(f'Aliyev')
    except Exception as e:
        print('last_name-->problem')
    try:
        comp_email_input=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div[2]/div[4]/div/input')
        comp_email_input.click()
        comp_email_input.send_keys(f'shod2j5v8gm8kklgkk3{str(j)+str(k)}@mail.ru')
    except Exception as e:
        print('comp_email-->problem')
    try:
        first_pass_input=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div[2]/div[5]/div[1]/input')
        first_pass_input.click()
        first_pass_input.send_keys('Aa2301667')
    except Exception as e:
        print('first_pass-->problem')
    try:    
        sec_pass_input=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div[2]/div[5]/div[2]/input')
        sec_pass_input.click()
        sec_pass_input.send_keys('Aa2301667')
    except Exception as e:
        print('sec_pass-->problem')
    try:
        agree_button=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div[2]/div[6]/div/label/div/img')
        agree_button.click()
    except Exception as e:
        print('agree_button-->problem')
    try:                                            #/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div/div[6]/button
        signup_button=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div[2]/div[7]/button')
        signup_button.click()
        time.sleep(10)
    except Exception as e:
        print('signup_button-->problem')
    try:
        country_button=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[1]/div[2]/div/div[2]/img')
        country_button.click()
        first_country=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[1]/div[2]/div[2]/div[1]')
        first_country.click()
    except Exception as e:
        print('country_button-->problem')                                # second country    '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[1]/div[2]/div[2]/div[2]'
    try:
        job_title_input=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[2]/div[2]/div/input')
        job_title_input.click()
        job_title_input.send_keys('software engineer')
    except Exception as e:
        print('job_title-->problem')
    try:    
        my_department_input=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[2]/div[4]/div[1]/div[2]/img')
        my_department_input.click()
        first_department=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[2]/div[4]/div[2]/div[6]')                              #  second department           '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[2]/div[3]/div[2]/div[2]'
        first_department.click()
    except Exception as e:
        print('department-->problem')
    try:    
        next_button=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[2]/a')
        next_button.click()
        time.sleep(10)
    except Exception as e:
        print('next_button-->problem')
    i=0
    dict_={}
    people_butt=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/div[1]/nav/div/div[2]/div[2]')
    people_butt.click()
    time.sleep(1)
    add_profiles_butt=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/div[1]/nav/div/div[2]/div[2]/div/a[3]')
    add_profiles_butt.click()
    time.sleep(3)

    for link in df.links[k:link_num]:
        input_profiles=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/div/div[2]/div[1]/div[2]/input')
        input_profiles.click()
        time.sleep(3)
        # input_profiles.send_keys("olmalar")
        input_profiles.send_keys(str(link))
        time.sleep(3)
        input_profiles.click()
        time.sleep(2)
        input_profiles.send_keys(Keys.SPACE)
    
    add_prof_butt=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/div/div[2]/div[2]/div/div/button')
    add_prof_butt.click()

    initialScroll = 0
    finalScroll = 1000
    start = time.time()
    while True:
        driver.execute_script(f"window.scrollTo({initialScroll}, {finalScroll})")
        initialScroll = finalScroll
        finalScroll += 1000
        time.sleep(3)
        end = time.time()
        if round(end - start) > 25:
            break
    names=[]
    links=[]
    try:
        for name in range(1,11):
            full_name=driver.find_element(By.XPATH, f'/html/body/div[2]/div/div/div[4]/div/div[2]/div[3]/table/tbody/tr[{str(name)}]/td[1]')
            names.append(full_name.text)             

            link_url=driver.find_element(By.XPATH, f"/html/body/div[2]/div/div/div[4]/div/div[2]/div[3]/table/tbody/tr[{str(name)}]/td[4]/a")     
            links.append(link_url.text)
    except:
        print('')
    characters=[]
    for nam in names:
        time.sleep(3)
        first_user_input=driver.find_element(By.XPATH,'/html/body/div[2]/div/div/div[2]/div[1]/nav/div[1]/div[1]/div/div/input')
        first_user_input.click()
        first_user_input.send_keys(str(nam))
        time.sleep(2)
        try:
            first=driver.find_element(By.XPATH,'/html/body/div[2]/div/div/div[2]/div[1]/nav/div[1]/div[1]/div/div/div/div/div')
            first.click()
            time.sleep(4)
            char=driver.find_element(By.XPATH,'/html/body/div[2]/div/div/div[4]/div[1]/div/div/div[1]/div/span').text
            characters.append(char)
        except Exception:
            characters.append('nan')
    k=link_num
    df1=pd.DataFrame(
        {'names':names,
         'links':links,
         'characters':characters}
    )
    df1.to_csv(f'datas/cs_values_new/data_till_4000{k}.csv', index=False)
    print(f'if there is a problem change k to {k}')
# Out:
# C:\Users\fayyo\AppData\Local\Temp\ipykernel_7228\3032004852.py:11: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(options=options,executable_path='C:/Users/dell/OneDrive/Desktop/chromedriver.exe')
# Incompatible release of chromedriver (version 111.0.5563.64) detected in PATH: c:\Users\GitHub\Bots_using_selenium\linkedin_data_Scraping\chromedriver.exe
# if there is a problem change k to 2300
# signup probelm
# first_name-->problem
# last_name-->problem
# comp_email-->problem
# first_pass-->problem
# sec_pass-->problem
# agree_button-->problem
# signup_button-->problem
# country_button-->problem
# job_title-->problem
# department-->problem
# next_button-->problem
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Cell In[4], line 110
#     108 i=0
#     109 dict_={}
# ...

# %%
df1=pd.DataFrame(
    {'names':names,
        'links':links,
        'characters':characters}
)
df1.to_csv(f'datas/cs_values_new/data_till_4000{k}.csv', index=False)

# %%
for link in df.links[k:link_num]:
    print(link)

# %%
from bs4 import BeautifulSoup
import time
from selenium.webdriver.chrome.options import Options
from selenium import webdriver
from selenium.webdriver.common.by import By
import pandas as pd
from selenium.webdriver.common.keys import Keys

df= pd.read_csv(f'../linkedin_data_Scraping/datas/last_50_ths.csv')
j=0
k=8460
dict_={}
for link_num in range(8470, 10000, 10):
    options = Options()

    driver = webdriver.Chrome(options=options,executable_path='C:/Users/fayyo/Downloads/chromedriver.exe')
    driver.get('https://www.crystalknows.com/app/register')
    time.sleep(10)
    j+=1 

    try:
        cookie=driver.find_element(By.XPATH, '/html/body/div[2]/div/div[2]/div/a')
        cookie.click()
        time.sleep(2)
    except:
        print('Cookie')
    try:
        first_name_input=driver.find_element(By.XPATH, '/html/body/div[3]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div[2]/div[3]/div[1]/input')
        first_name_input.click()                        #/html/body/div[3]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div[2]/div[3]/div[1]/input
        first_name_input.send_keys(f'Alibek')
    except Exception as e:
        print('first_name-->problem')
    try:
        last_name_input=driver.find_element(By.XPATH, '/html/body/div[3]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div[2]/div[3]/div[2]/input')
        last_name_input.click()                       #/html/body/div[3]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div[2]/div[3]/div[2]/input
        last_name_input.send_keys(f'Aliyev')
    except Exception as e:
        print('last_name-->problem')
    try:
        comp_email_input=driver.find_element(By.XPATH, '/html/body/div[3]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div[2]/div[4]/div/input')
        comp_email_input.click()                       
        comp_email_input.send_keys(f'awj1usswafhoerjudax{str(j)+str(k)}@gmail.com')
    except Exception as e:
        print('comp_email-->problem')
    try:
        first_pass_input=driver.find_element(By.XPATH, '/html/body/div[3]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div[2]/div[5]/div[1]/input')
        first_pass_input.click()                        #/html/body/div[3]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div[2]/div[5]/div[1]/input
        first_pass_input.send_keys('Aa2301667')
    except Exception as e:
        print('first_pass-->problem')
    try:    
        sec_pass_input=driver.find_element(By.XPATH, '/html/body/div[3]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div[2]/div[5]/div[2]/input')
        sec_pass_input.click()
        sec_pass_input.send_keys('Aa2301667')
    except Exception as e:
        print('sec_pass-->problem')
    try:
        agree_button=driver.find_element(By.XPATH, '/html/body/div[3]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div[2]/div[6]/div/label/div/img')
        agree_button.click()                       #/html/body/div[3]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div[2]/div[6]/div/label/div/img
    except Exception as e:
        print('agree_button-->problem')
    try:                                            #/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div/div[6]/button
        signup_button=driver.find_element(By.XPATH, '/html/body/div[3]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div[2]/div[7]/button')
        signup_button.click()                       #/html/body/div[3]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div[2]/div[7]/button
        time.sleep(10)
    except Exception as e:
        print('signup_button-->problem')
    try:     
        time.sleep(15)                                        #/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[1]/div[2]/div/div[2]/img
        country_button=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[1]/div[2]/div/div[2]/img')
        country_button.click()
        first_country=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[1]/div[2]/div[2]/div[1]')
        first_country.click()
    except Exception as e:
        print('country_button-->problem')                                # second country    '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[1]/div[2]/div[2]/div[2]'
    try:
        job_title_input=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[2]/div[2]/div/input')
        job_title_input.click()
        job_title_input.send_keys('software engineer')
    except Exception as e:
        print('job_title-->problem')
    try:    
        my_department_input=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[2]/div[4]/div[1]/div[2]/img')
        my_department_input.click()
        first_department=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[2]/div[4]/div[2]/div[6]')                              #  second department           '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[2]/div[3]/div[2]/div[2]'
        first_department.click()
    except Exception as e:
        print('department-->problem')
    try:    
        next_button=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[2]/a')
        next_button.click()
        time.sleep(10)
    except Exception as e:
        print('next_button-->problem')
    i=0
    people_butt=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/div[1]/nav/div/div[2]/div[2]/a')
    people_butt.click()                       #/html/body/div[2]/div/div/div[2]/div[1]/nav/div/div[2]/div[2]/div/a[3]
    time.sleep(1)
    add_profiles_butt=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/div[1]/nav/div/div[2]/div[2]/div/a[3]')
    add_profiles_butt.click()                       #/html/body/div[2]/div/div/div[2]/div[1]/nav/div/div[2]/div[2]/div/a[3]
    time.sleep(5)
    try:
        add_profiles_butt1=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/div/div[1]/div[2]/button')
        add_profiles_butt1.click()                       #/html/body/div[2]/div/div/div[4]/div/div[1]/div[2]/button
        time.sleep(2)
        by_linkedin_butt=driver.find_element(By.XPATH, "/html/body/div[2]/div/div/div[4]/div/div[1]/div[3]/div[2]/div/div[1]/div[4]/div[2]")
        by_linkedin_butt.click()
        time.sleep(5)
    except:
        print("add_profiles_butt1 problem")
    try:
        for link in df.links[k:link_num]:
            input_profiles=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/div/div[1]/div[3]/div[2]/div/div[2]/div[2]/div[2]/div/div[2]/input')
            # input_profiles.click()                       /html/body/div[2]/div/div/div[4]/div/div[1]/div[4]/div[2]/div/div[2]/div[2]/div[2]/div/div[2]/input
            # time.sleep(2)
            input_profiles.send_keys(str(link))
            time.sleep(1)
            input_profiles.click()
            time.sleep(1)
            input_profiles.send_keys(Keys.SPACE)
            # add_prof_butt=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/div/div[1]/div[3]/div[2]/div/div[2]/div[3]/div/div/button')
            # add_prof_butt.click()   
            # time.sleep(2)
        try:
            add_prof_butt=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/div/div[1]/div[3]/div[2]/div/div[2]/div[3]/div/div/button')
            add_prof_butt.click()   
            time.sleep(10)
        except:
            print("ADD PROFILE problem")                    #/html/body/div[2]/div/div/div[4]/div/div[1]/div[3]/div[2]/div/div[2]/div[3]/div/div/button
        
        try:
            x=driver.find_element(By.XPATH, "/html/body/div[2]/div/div/div[4]/div/div[1]/div[3]/div[2]/img")
            x.click()
        except:
            print("X problem")
        time.sleep(2)
    
        initialScroll = 0
        finalScroll = 1000
        start = time.time()
        while True:
            driver.execute_script(f"window.scrollTo({initialScroll}, {finalScroll})")
            initialScroll = finalScroll
            finalScroll += 1000
            time.sleep(3)
            end = time.time()
            if round(end - start) > 25:
                break
        src = driver.page_source
        soup = BeautifulSoup(src, 'lxml')
        names=[]
        links=[]
        characters=[]
        linksed_links=soup.find_all("a", {"class":"styles_linkedin-link__HDisz"})
        for i in linksed_links:
            links.append(i.get('href').split("?")[0])
        colors=soup.select('[class^="styles_table-cell__oLmEF styles_text__DPebr styles_disc-color__I4yR3 styles_bold__EvRSI styles_average-section__DEaud styles_"]')
        for color in colors:
            characters.append(color.text)
        names_=soup.find_all("a", {"class":"styles_next-link__3eJtq"})
        for name in names_:
            names.append(name.text)
    except:
        print("1st bot did not work")

    try:
        for link in df.links[k:link_num]:
            input_profiles=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/div/div[2]/div[1]/div[2]/input')
            # input_profiles.click()                       /html/body/div[2]/div/div/div[4]/div/div[1]/div[4]/div[2]/div/div[2]/div[2]/div[2]/div/div[2]/input
            time.sleep(2)
            input_profiles.send_keys(str(link))
            time.sleep(2)
            # input_profiles.click()
            # time.sleep(2)
            input_profiles.send_keys(Keys.SPACE)
        
        add_prof_butt=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/div/div[2]/div[2]/div/div/button')
        add_prof_butt.click()
        time.sleep(15)

        people_butt=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/div[1]/nav/div/div[2]/div[2]/a')
        people_butt.click()
        time.sleep(1)
        add_profiles_butt=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/div[1]/nav/div/div[2]/div[2]/div/a[3]')
        add_profiles_butt.click()
        time.sleep(15)

        initialScroll = 0
        finalScroll = 1000
        start = time.time()
        while True:
            driver.execute_script(f"window.scrollTo({initialScroll}, {finalScroll})")
            initialScroll = finalScroll
            finalScroll += 1000
            time.sleep(3)
            end = time.time()
            if round(end - start) > 25:
                break
        src = driver.page_source
        soup = BeautifulSoup(src, 'lxml')
        names=[]
        links=[]
        characters=[]
        linksed_links=soup.find_all("a", {"class":"styles_linkedin-link__HDisz"})
        for i in linksed_links:
            links.append(i.get('href').split("?")[0])
        colors=soup.select('[class^="styles_table-cell__oLmEF styles_text__DPebr styles_disc-color__I4yR3 styles_bold__EvRSI styles_average-section__DEaud styles_"]')
        for color in colors:
            characters.append(color.text)
        names_=soup.find_all("a", {"class":"styles_next-link__3eJtq"})
        for name in names_:
            names.append(name.text)
    except:
        print("2nd bot did not work")
    k=link_num
    df1=pd.DataFrame(
        {'names':names,
         'links':links,
         'characters':characters}
    )
    df1.to_csv(f'datas/cs_values_50/Is_data_{k}.csv', index=False)
    print(f'if there is a problem change k to {k}')
    driver.close()
# Out:
# C:\Users\fayyo\AppData\Local\Temp\ipykernel_1952\1798443146.py:16: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(options=options,executable_path='C:/Users/fayyo/Downloads/chromedriver.exe')
# ---------------------------------------------------------------------------
# SessionNotCreatedException                Traceback (most recent call last)
# Cell In[46], line 16
#      13 for link_num in range(8470, 10000, 10):
#      14     options = Options()
# ---> 16     driver = webdriver.Chrome(options=options,executable_path='C:/Users/fayyo/Downloads/chromedriver.exe')
#      17     driver.get('https://www.crystalknows.com/app/register')
#      18     time.sleep(10)
#
# ...
