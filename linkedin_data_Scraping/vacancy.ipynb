# %%
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from selenium import webdriver
import time
import pandas as pd

options = Options()
options.add_argument("user-data-dir=C:/Users/dell/AppData/Local/Google/Chrome/User Data/Profile 25")
driver = webdriver.Chrome(options=options,executable_path='C:/Users/fayyo/Downloads/chromedriver.exe')
list_items = [
    "ASMI",
    "CIMC ENRIC Tank and Process",
    "Corbion",
    "Nouryon",
    "Topcon Europe Positioning",
    "Kadaster",
    "Schlumberger",
    "Flow Traders",
    "Boskalis",
    "VMI Group",
    "Corbion",
    "OCI Nitrogen",
    "Royal Vopak",
    "Nederlandse Spoorwegen (NS)",
    "Royal Dutch Shell",
    "Thermo Fisher Scientific",
    "Tesla",
    "Xsens",
    "Fugro",
    "Hexagon",
    "Rockstart",
    "Picnic",
    "MessageBird",
    "WeTransfer",
    "Mollie",
    "Adyen",
    "Bux",
    "Mendix",
    "Backbase",
    "Bynder",
    "Peerby",
    "Framer",
    "GitLab",
    "TomTom",
    "Elastic",
    "MessageBird",
    "Swapfiets",
    "Booking.com",
    "Takeaway.com",
    "Adyen",
    "WeTransfer",
    "Mollie",
    "Bol.com",
    "Picnic",
    "Mendix",
    "Backbase",
    "Bynder",
    "3D Hubs",
    "Peerby",
    "Fugro",
    "Hexagon",
    "Booking.com",
    "Philips",
    "TomTom",
    "NXP Semiconductors",
    "Shell",
    "Unilever",
    "Adyen",
    "Ahold Delhaize",
    "Coolblue",
    "Bux",
    "Xsens",
    "TNO",
    "Elastic",
    "Fugro",
    "Hexagon",
    "Rockstart",
    "Rabobank",
    "ING Group",
    "Nederlandse Spoorwegen (NS)",
    "Topcon Europe Positioning",
    "Kadaster",
    "Schlumberger",
    "Flow Traders",
    "Boskalis",
    "VMI Group",
    "OCI Nitrogen",
    "Corbion",
    "Royal Vopak",
    "Thermo Fisher Scientific",
    "Tesla",
    "VodafoneZiggo",
]

for item  in list_items[:]:
    links = [] 
    for study in ['master', 'bachelor']:
        driver.get(f'https://www.google.com/search?q=site:nl.linkedin.com/in/+AND+%22{item}+AND+%22{study}')
        time.sleep(10) 
        n=30
        while n > 0:
            time.sleep(5)
            for i in range(1, 11): 
                time.sleep(6)
                try:    
                    elems = driver.find_elements(By.XPATH, '/html/body/div[6]/div/div[12]/div/div[2]/div[2]/div/div/div['+str(i)+']/div/div/div[1]/div/div/a')
                    for elem in elems:                    
                                                           
                        clean_url = elem.get_attribute("href") 
                        base_url = "linkedin.com/in/"
                        if clean_url.find(base_url) != -1 and '%' not in clean_url: # sometimes google gives no Ln urls, so clean it
                            links.append(clean_url)
                except Exception as e:
                    print("problem with ELEMS")
                    pass
            try:
                next_button = driver.find_element(By.XPATH, '//*[@id="pnnext"]') # clicking next button 
                next_button.click()
            except Exception as e:
                driver.get(f'https://www.google.com/search?q=site:nl.linkedin.com/in/+AND+%22{item}+AND+%22{study}')
            n -= 1
    df = pd.DataFrame({
        "links":links
    })
    df1=pd.read_csv('datas/Fayyoz_links/data_Fayyoz.csv')
    df_sum=pd.concat([df1, df], axis=0, ignore_index=True)
    df_sum = df_sum.drop_duplicates()
    df_sum.to_csv(f'datas/Fayyoz_links/data_Fayyoz.csv', index=False)
    print(f'I am done ---> {item}')
# Out:
# C:\Users\fayyo\AppData\Local\Temp\ipykernel_13048\668588537.py:9: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(options=options,executable_path='C:/Users/fayyo/Downloads/chromedriver.exe')
# problem with ELEMS
# problem with ELEMS
# problem with ELEMS
# problem with ELEMS
# problem with ELEMS
# problem with ELEMS
# problem with ELEMS
# problem with ELEMS
# problem with ELEMS
# problem with ELEMS
# problem with ELEMS
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# Cell In[5], line 117
#     116 try:
# --> 117     next_button = driver.find_element(By.XPATH, '//*[@id="pnnext"]') # clicking next button
#     118     next_button.click()
#
# File c:\Users\GitHub\Bots_using_selenium\venv\lib\site-packages\selenium\webdriver\remote\webdriver.py:831, in WebDriver.find_element(self, by, value)
#     829     value = f'[name="{value}"]'
# --> 831 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File c:\Users\GitHub\Bots_using_selenium\venv\lib\site-packages\selenium\webdriver\remote\webdriver.py:440, in WebDriver.execute(self, driver_command, params)
#     439 if response:
# --> 440     self.error_handler.check_response(response)
#     441     response["value"] = self._unwrap_value(response.get("value", None))
#
# File c:\Users\GitHub\Bots_using_selenium\venv\lib\site-packages\selenium\webdriver\remote\errorhandler.py:245, in ErrorHandler.check_response(self, response)
#     244     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 245 raise exception_class(message, screen, stacktrace)
#
# NoSuchWindowException: Message: no such window: target window already closed
# from unknown error: web view not found
#   (Session info: chrome=116.0.5845.111)
# Stacktrace:
# 	GetHandleVerifier [0x004F37C3+48947]
# 	(No symbol) [0x00488551]
# 	(No symbol) [0x0038C92D]
# 	(No symbol) [0x003736E5]
# 	(No symbol) [0x003D8CDB]
# 	(No symbol) [0x003E7113]
# 	(No symbol) [0x003D4E86]
# 	(No symbol) [0x003B16C7]
# 	(No symbol) [0x003B284D]
# 	GetHandleVerifier [0x0073FDF9+2458985]
# 	GetHandleVerifier [0x0078744F+2751423]
# 	GetHandleVerifier [0x00781361+2726609]
# 	GetHandleVerifier [0x00570680+560624]
# 	(No symbol) [0x0049238C]
# 	(No symbol) [0x0048E268]
# 	(No symbol) [0x0048E392]
# 	(No symbol) [0x004810B7]
# 	BaseThreadInitThunk [0x773300C9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77937B1E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77937AEE+238]
#
#
# During handling of the above exception, another exception occurred:
#
# NoSuchWindowException                     Traceback (most recent call last)
# Cell In[5], line 120
#     118             next_button.click()
#     119         except Exception as e:
# --> 120             driver.get(f'https://www.google.com/search?q=site:nl.linkedin.com/in/+AND+%22{item}+AND+%22{study}')
#     121         n -= 1
#     122 df = pd.DataFrame({
#     123     "links":links
#     124 })
#
# File c:\Users\GitHub\Bots_using_selenium\venv\lib\site-packages\selenium\webdriver\remote\webdriver.py:449, in WebDriver.get(self, url)
#     447 def get(self, url: str) -> None:
#     448     """Loads a web page in the current browser session."""
# --> 449     self.execute(Command.GET, {"url": url})
#
# File c:\Users\GitHub\Bots_using_selenium\venv\lib\site-packages\selenium\webdriver\remote\webdriver.py:440, in WebDriver.execute(self, driver_command, params)
#     438 response = self.command_executor.execute(driver_command, params)
#     439 if response:
# --> 440     self.error_handler.check_response(response)
#     441     response["value"] = self._unwrap_value(response.get("value", None))
#     442     return response
#
# File c:\Users\GitHub\Bots_using_selenium\venv\lib\site-packages\selenium\webdriver\remote\errorhandler.py:245, in ErrorHandler.check_response(self, response)
#     243         alert_text = value["alert"].get("text")
#     244     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 245 raise exception_class(message, screen, stacktrace)
#
# NoSuchWindowException: Message: no such window: target window already closed
# from unknown error: web view not found
#   (Session info: chrome=116.0.5845.111)
# Stacktrace:
# 	GetHandleVerifier [0x004F37C3+48947]
# 	(No symbol) [0x00488551]
# 	(No symbol) [0x0038C92D]
# 	(No symbol) [0x003736E5]
# 	(No symbol) [0x003D8CDB]
# 	(No symbol) [0x003E7113]
# 	(No symbol) [0x003D4E86]
# 	(No symbol) [0x003B16C7]
# 	(No symbol) [0x003B284D]
# 	GetHandleVerifier [0x0073FDF9+2458985]
# 	GetHandleVerifier [0x0078744F+2751423]
# 	GetHandleVerifier [0x00781361+2726609]
# 	GetHandleVerifier [0x00570680+560624]
# 	(No symbol) [0x0049238C]
# 	(No symbol) [0x0048E268]
# 	(No symbol) [0x0048E392]
# 	(No symbol) [0x004810B7]
# 	BaseThreadInitThunk [0x773300C9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77937B1E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77937AEE+238]

# %%
df = pd.DataFrame({
    "links":links
})
df1=pd.read_csv('datas/Fayyoz_links/data_Fayyoz.csv')
df_sum=pd.concat([df1, df], axis=0, ignore_index=True)
df_sum = df_sum.drop_duplicates()
df_sum.to_csv(f'datas/Fayyoz_links/data_Fayyoz.csv', index=False)
print(f'I am done ---> {item}')
# Out:
# I am done ---> TNO

# %%
from bs4 import BeautifulSoup
import time
from selenium.webdriver.chrome.options import Options
from selenium import webdriver
from selenium.webdriver.common.by import By
import pandas as pd
import re

sectors_physics_and_astronomy={
'Banen in supply chain & logistiek and Banen in klantenondersteuning-service':'https://www.glassdoor.com/Job/netherlands-supply-chain-and-logistics-jobs-SRCH_IL.0,11_IN178_KO12,38_IP30.htm?includeNoSalaryJobs=true', }
# driver = webdriver.Chrome(options=options)
for j in range(1):
    options = Options()
    options.add_argument("user-data-dir=C:/Users/dell/AppData/Local/Google/Chrome/User Data/Profile 17")
    driver = webdriver.Chrome(options=options,executable_path='C:/Users/dell/OneDrive/Desktop/chromedriver.exe')
    site = list(sectors_physics_and_astronomy.values())[j]
    job_desc_Math_teacher={}
    driver.get(site)
    time.sleep(20)
    initialScroll = 0
    finalScroll = 1000
    start = time.time()
    while True:
        driver.execute_script(f"window.scrollTo({initialScroll}, {finalScroll})")
        initialScroll = finalScroll
        finalScroll += 1000
        time.sleep(3)
        end = time.time()
        if round(end - start) > 25:
            break
    try:
        for i in range(1, 30):                          #'/html/body/div[2]/div/div/div/div/div[2]/section/article/div[1]/ul/li[1]/div/div/a'
            job_desc_butt=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div/div/div[2]/section/article/div[1]/ul/li['+str(i)+']')
            job_desc_butt.click()
            time.sleep(5)
            src = driver.page_source
            soup = BeautifulSoup(src, 'lxml')
            job_descript=soup.find('div', {'class':'jobDescriptionContent desc'})
            job_description=job_descript.get_text()
            job_desc_Math_teacher[i]=job_description
    except Exception as e:
        print(e)
    soup = BeautifulSoup(src, 'lxml')
    src = driver.page_source
    jobs=soup.find_all('li',{'class':re.compile("react-job-listing css")})
                            # re.compile("-ab")react-job-listing css

    images=[]
    salaries=[]
    companies=[]
    job_titles=[]
    locations=[]

    for pro in jobs[1:30]:
        try:
            image=pro.find('img')['src']
            images.append(image)
        except Exception as e:
            print(f"images_error--> {e}")
            images.append("nan")
        try:
            salary=pro.find('div', {"class":"salary-estimate"})
            # print(salary)
            salaries.append(salary.text.strip())
        except Exception as e:
            print(f"salaries_error--> {e}")
            salaries.append("nan")
        try:
            company=pro.find('div', {"class":"ml-xsm job-search-1bgdn7m"}).text.strip()
            # print(company)
            companies.append(company)
        except Exception as e:
            print(f"companies_error--> {e}")
            companies.append("nan")
        try:
            job=pro.find('div', {"class":"job-title mt-xsm"})
            # print(job)
            job_titles.append(job.text.strip())
        except Exception as e:
            print(f"job_titles_error--> {e}")
            job_titles.append("nan")
        try:
            loc=pro.find('div', {"class":"location"})
            print(loc)
            locations.append(loc.text.strip())
        except Exception as e:
            print(f"locations_error--> {e}")
            locations.append("nan")
# /html/body/div[2]/div/div/div/div/div[2]/section/article/div[1]/ul/li[1]/div/div/a/div[1]/div[4]/text()[1]
    import pandas as pd
    print("creating df")
    df_teache=pd.DataFrame({
        "job_titles":job_titles,
        "job_description":list(job_desc_Math_teacher.values()),
        "images":images,
        "locations":locations,
        "salaries":salaries,
        "companies":companies
        }
    )
    df_teache.to_csv(f"Banen_in_supply_chain__logistiek_and_Banen_in_klantenondersteuning-service{list(sectors_physics_and_astronomy.keys())[j]}30.csv", sep=',', index=False);
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_5892\205222369.py:15: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(options=options,executable_path='C:/Users/dell/OneDrive/Desktop/chromedriver.exe')
# salaries_error--> 'NoneType' object has no attribute 'text'
# <div class="location mt-xxsm" data-test="emp-location">Eindhoven</div>
# salaries_error--> 'NoneType' object has no attribute 'text'
# <div class="location mt-xxsm" data-test="emp-location">Amstelveen</div>
# images_error--> 'NoneType' object is not subscriptable
# salaries_error--> 'NoneType' object has no attribute 'text'
# <div class="location mt-xxsm" data-test="emp-location">Eindhoven</div>
# <div class="location mt-xxsm" data-test="emp-location">Eindhoven</div>
# images_error--> 'NoneType' object is not subscriptable
# <div class="location mt-xxsm" data-test="emp-location">Geleen</div>
# salaries_error--> 'NoneType' object has no attribute 'text'
# <div class="location mt-xxsm" data-test="emp-location">Amstelveen</div>
# salaries_error--> 'NoneType' object has no attribute 'text'
# <div class="location mt-xxsm" data-test="emp-location">Almere</div>
# <div class="location mt-xxsm" data-test="emp-location">Den Bosch</div>
# salaries_error--> 'NoneType' object has no attribute 'text'
# <div class="location mt-xxsm" data-test="emp-location">Nieuwerkerk aan den IJssel</div>
# salaries_error--> 'NoneType' object has no attribute 'text'
# <div class="location mt-xxsm" data-test="emp-location">Tilburg</div>
# salaries_error--> 'NoneType' object has no attribute 'text'
# <div class="location mt-xxsm" data-test="emp-location">Delft</div>
# salaries_error--> 'NoneType' object has no attribute 'text'
# <div class="location mt-xxsm" data-test="emp-location">Zoetermeer</div>
# salaries_error--> 'NoneType' object has no attribute 'text'
# <div class="location mt-xxsm" data-test="emp-location">Amsterdam</div>
# salaries_error--> 'NoneType' object has no attribute 'text'
# <div class="location mt-xxsm" data-test="emp-location">Best</div>
# salaries_error--> 'NoneType' object has no attribute 'text'
# <div class="location mt-xxsm" data-test="emp-location">Rotterdam</div>
# salaries_error--> 'NoneType' object has no attribute 'text'
# <div class="location mt-xxsm" data-test="emp-location">Amstelveen</div>
# images_error--> 'NoneType' object is not subscriptable
# salaries_error--> 'NoneType' object has no attribute 'text'
# <div class="location mt-xxsm" data-test="emp-location">Eindhoven</div>
# salaries_error--> 'NoneType' object has no attribute 'text'
# <div class="location mt-xxsm" data-test="emp-location">Veghel</div>
# salaries_error--> 'NoneType' object has no attribute 'text'
# <div class="location mt-xxsm" data-test="emp-location">Eindhoven</div>
# salaries_error--> 'NoneType' object has no attribute 'text'
# <div class="location mt-xxsm" data-test="emp-location">Den Bosch</div>
# salaries_error--> 'NoneType' object has no attribute 'text'
# <div class="location mt-xxsm" data-test="emp-location">Den Bosch</div>
# salaries_error--> 'NoneType' object has no attribute 'text'
# <div class="location mt-xxsm" data-test="emp-location">Heerlen</div>
# salaries_error--> 'NoneType' object has no attribute 'text'
# <div class="location mt-xxsm" data-test="emp-location">Heijen</div>
# salaries_error--> 'NoneType' object has no attribute 'text'
# <div class="location mt-xxsm" data-test="emp-location">Eindhoven</div>
# salaries_error--> 'NoneType' object has no attribute 'text'
# <div class="location mt-xxsm" data-test="emp-location">Leiden</div>
# salaries_error--> 'NoneType' object has no attribute 'text'
# <div class="location mt-xxsm" data-test="emp-location">Son</div>
# images_error--> 'NoneType' object is not subscriptable
# <div class="location mt-xxsm" data-test="emp-location">The Hague</div>
# <div class="location mt-xxsm" data-test="emp-location">Eindhoven</div>
# <div class="location mt-xxsm" data-test="emp-location">Cuijk</div>
# creating df

# %%
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from selenium import webdriver
import time
import pandas as pd

options = Options()
options.add_argument("user-data-dir=C:/Users/dell/AppData/Local/Google/Chrome/User Data/Profile 7")
driver = webdriver.Chrome(options=options,executable_path='C:/Users/dell/OneDrive/Desktop/chromedriver.exe')

# 'Mathematics and Bachelor words are used as a default, it is changeble
# math, french, english, russian, german, dutch, SWEDISH, UZBEK, tadjik, chinese, kazakh, turkey, polish
# italy, paris, rome, usa,china
# 1. Afghanistan
# 2. Albania
# 3. Algeria
# 4. Andorra
# 5. Angola
# 6. Antigua and Barbuda
# 7. Argentina
# 8. Armenia
# 9. Australia
# 10. Austria
# 11. Azerbaijan
# 12. Bahamas
# 13. Bahrain
# 14. Bangladesh
# 15. Barbados
# 16. Belarus
# 17. Belgium
# 18. Belize
# 19. Benin
# 20. Bhutan
# 21. Bolivia
# 22. Bosnia and Herzegovina
# 23. Botswana
# 24. Brazil
# 25. Brunei
# 26. Bulgaria
# 27. Burkina Faso
# 28. Burundi
# 29. Cabo Verde
# 30. Cambodia
# 31. Cameroon
# 32. Canada
# 33. Central African Republic
# 34. Chad
# 35. Chile
# 36. China
# 37. Colombia
# 38. Comoros
# 39. Congo (Congo-Brazzaville)
# 40. Costa Rica
# 41. Cote d'Ivoire (Ivory Coast)
# 42. Croatia
# 43. Cuba
# 44. Cyprus
# 45. Czechia (Czech Republic)
# 46. Democratic Republic of the Congo (Congo-Kinshasa)
# 47. Denmark
# 48. Djibouti
# 49. Dominica
# 50. Dominican Republic
# 51. Ecuador
# 52. Egypt
# 53. El Salvador
# 54. Equatorial Guinea
# 55. Eritrea
# 56. Estonia
# 57. Eswatini (fmr. "Swaziland")
# 58. Ethiopia
# 59. Fiji
# 60. Finland
# 61. France
# 62. Gabon
# 63. Gambia
# 64. Georgia
# 65. Germany
# 66. Ghana
# 67. Greece
# 68. Grenada
# 69. Guatemala
# 70. Guinea
# 71. Guinea-Bissau
# 72. Guyana
# 73. Haiti
# 74. Honduras
# 75. Hungary
# 76. Iceland
# 77. India
# 78. Indonesia
# 79. Iran
# 80. Iraq
# 81. Ireland
# 82. Israel
# 83. Italy
# 84. Jamaica
# 85. Japan
# 86. Jordan
# 87. Kazakhstan
# 88. Kenya
# 89. Kiribati
# 90. North Korea
# 91. South Korea
# 92. Kosovo
# 93. Kuwait
# 94. Kyrgyzstan
# 95. Laos
# 96. Latvia
# 97. Lebanon
# 98. Lesotho
# 99. Liberia
# 100. Libya
# 101. Liechtenstein
# 102. Lithuania
# 103. Luxembourg
# 104. Madagascar
# 105. Malawi
# 106. Malaysia
# 107. Maldives
# 108. Mali
# 109. Malta
# 110. Marshall Islands
# 111. Mauritania
# 112. Mauritius
# 113. Mexico
# 114. Micronesia
# 115. Moldova



for j in range(632,670):
    
    driver.get(f'https://www.google.com/search?q=site:nl.linkedin.com/in/+AND+%22Monaco')
    time.sleep(10) # to make slower 
    # n is the number of pages
    links = [] # save links here

    n=30
    while n > 0:
        time.sleep(5)
        for i in range(1, 11): # google uses paginator, every page has 10 urls
            time.sleep(6)
            try:
                elems = driver.find_elements(By.XPATH, '//*[@id="rso"]/div['+str(i)+']/div/div/div[1]/div/a')
                for elem in elems:
                    clean_url = elem.get_attribute("href") # extracting url 
                    base_url = "linkedin.com/in/"
                    if clean_url.find(base_url) != -1 and '%' not in clean_url: # sometimes google gives no Ln urls, so clean it
                        links.append(clean_url)
                        # print(f"url is --->{clean_url}")
            except Exception as e:
                print(e)
                pass
        try:
            next_button = driver.find_element(By.XPATH, '//*[@id="pnnext"]') # clicking next button 
            next_button.click()
        except Exception as e:
            print(e)
        print(f'{n} pages left!')
        n -= 1
    df = pd.DataFrame({
        "links":links
    })
    df = df.drop_duplicates()
    df.to_csv(f'datas/linkedin_links_29_06/data{str(j)}.csv', index=False)
    print(f'I am done ---> {str(j)}')
    print(f'if there is a problem, start with {str(j+1)}')
# Out:
# C:\Users\fayyo\AppData\Local\Temp\ipykernel_8208\2737917453.py:9: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(options=options,executable_path='C:/Users/dell/OneDrive/Desktop/chromedriver.exe')
# Incompatible release of chromedriver (version 111.0.5563.64) detected in PATH: c:\Users\GitHub\Bots_using_selenium\linkedin_data_Scraping\chromedriver.exe
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="pnnext"]"}
#   (Session info: chrome=115.0.5790.110)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x00C7A813+48355]
# 	(No symbol) [0x00C0C4B1]
# 	(No symbol) [0x00B15358]
# 	(No symbol) [0x00B409A5]
# 	(No symbol) [0x00B40B3B]
# 	(No symbol) [0x00B6E232]
# 	(No symbol) [0x00B5A784]
# 	(No symbol) [0x00B6C922]
# 	(No symbol) [0x00B5A536]
# 	(No symbol) [0x00B382DC]
# 	(No symbol) [0x00B393DD]
# 	GetHandleVerifier [0x00EDAABD+2539405]
# 	GetHandleVerifier [0x00F1A78F+2800735]
# 	GetHandleVerifier [0x00F1456C+2775612]
# 	GetHandleVerifier [0x00D051E0+616112]
# 	(No symbol) [0x00C15F8C]
# 	(No symbol) [0x00C12328]
# 	(No symbol) [0x00C1240B]
# 	(No symbol) [0x00C04FF7]
# 	BaseThreadInitThunk [0x75CD00C9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77307B1E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77307AEE+238]
#
# 30 pages left!
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="pnnext"]"}
#   (Session info: chrome=115.0.5790.110)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x00C7A813+48355]
# 	(No symbol) [0x00C0C4B1]
# 	(No symbol) [0x00B15358]
# 	(No symbol) [0x00B409A5]
# 	(No symbol) [0x00B40B3B]
# 	(No symbol) [0x00B6E232]
# 	(No symbol) [0x00B5A784]
# 	(No symbol) [0x00B6C922]
# 	(No symbol) [0x00B5A536]
# 	(No symbol) [0x00B382DC]
# 	(No symbol) [0x00B393DD]
# 	GetHandleVerifier [0x00EDAABD+2539405]
# 	GetHandleVerifier [0x00F1A78F+2800735]
# 	GetHandleVerifier [0x00F1456C+2775612]
# 	GetHandleVerifier [0x00D051E0+616112]
# 	(No symbol) [0x00C15F8C]
# 	(No symbol) [0x00C12328]
# 	(No symbol) [0x00C1240B]
# 	(No symbol) [0x00C04FF7]
# 	BaseThreadInitThunk [0x75CD00C9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77307B1E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77307AEE+238]
#
# 29 pages left!
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="pnnext"]"}
#   (Session info: chrome=115.0.5790.110)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x00C7A813+48355]
# 	(No symbol) [0x00C0C4B1]
# 	(No symbol) [0x00B15358]
# 	(No symbol) [0x00B409A5]
# 	(No symbol) [0x00B40B3B]
# 	(No symbol) [0x00B6E232]
# 	(No symbol) [0x00B5A784]
# 	(No symbol) [0x00B6C922]
# 	(No symbol) [0x00B5A536]
# 	(No symbol) [0x00B382DC]
# 	(No symbol) [0x00B393DD]
# 	GetHandleVerifier [0x00EDAABD+2539405]
# 	GetHandleVerifier [0x00F1A78F+2800735]
# 	GetHandleVerifier [0x00F1456C+2775612]
# 	GetHandleVerifier [0x00D051E0+616112]
# 	(No symbol) [0x00C15F8C]
# 	(No symbol) [0x00C12328]
# 	(No symbol) [0x00C1240B]
# 	(No symbol) [0x00C04FF7]
# 	BaseThreadInitThunk [0x75CD00C9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77307B1E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77307AEE+238]
#
# 28 pages left!
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="pnnext"]"}
#   (Session info: chrome=115.0.5790.110)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x00C7A813+48355]
# 	(No symbol) [0x00C0C4B1]
# 	(No symbol) [0x00B15358]
# 	(No symbol) [0x00B409A5]
# 	(No symbol) [0x00B40B3B]
# 	(No symbol) [0x00B6E232]
# 	(No symbol) [0x00B5A784]
# 	(No symbol) [0x00B6C922]
# 	(No symbol) [0x00B5A536]
# 	(No symbol) [0x00B382DC]
# 	(No symbol) [0x00B393DD]
# 	GetHandleVerifier [0x00EDAABD+2539405]
# 	GetHandleVerifier [0x00F1A78F+2800735]
# 	GetHandleVerifier [0x00F1456C+2775612]
# 	GetHandleVerifier [0x00D051E0+616112]
# 	(No symbol) [0x00C15F8C]
# 	(No symbol) [0x00C12328]
# 	(No symbol) [0x00C1240B]
# 	(No symbol) [0x00C04FF7]
# 	BaseThreadInitThunk [0x75CD00C9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77307B1E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77307AEE+238]
#
# 27 pages left!
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="pnnext"]"}
#   (Session info: chrome=115.0.5790.110)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x00C7A813+48355]
# 	(No symbol) [0x00C0C4B1]
# 	(No symbol) [0x00B15358]
# 	(No symbol) [0x00B409A5]
# 	(No symbol) [0x00B40B3B]
# 	(No symbol) [0x00B6E232]
# 	(No symbol) [0x00B5A784]
# 	(No symbol) [0x00B6C922]
# 	(No symbol) [0x00B5A536]
# 	(No symbol) [0x00B382DC]
# 	(No symbol) [0x00B393DD]
# 	GetHandleVerifier [0x00EDAABD+2539405]
# 	GetHandleVerifier [0x00F1A78F+2800735]
# 	GetHandleVerifier [0x00F1456C+2775612]
# 	GetHandleVerifier [0x00D051E0+616112]
# 	(No symbol) [0x00C15F8C]
# 	(No symbol) [0x00C12328]
# 	(No symbol) [0x00C1240B]
# 	(No symbol) [0x00C04FF7]
# 	BaseThreadInitThunk [0x75CD00C9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77307B1E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77307AEE+238]
#
# 26 pages left!
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="pnnext"]"}
#   (Session info: chrome=115.0.5790.110)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x00C7A813+48355]
# 	(No symbol) [0x00C0C4B1]
# 	(No symbol) [0x00B15358]
# 	(No symbol) [0x00B409A5]
# 	(No symbol) [0x00B40B3B]
# 	(No symbol) [0x00B6E232]
# 	(No symbol) [0x00B5A784]
# 	(No symbol) [0x00B6C922]
# 	(No symbol) [0x00B5A536]
# 	(No symbol) [0x00B382DC]
# 	(No symbol) [0x00B393DD]
# 	GetHandleVerifier [0x00EDAABD+2539405]
# 	GetHandleVerifier [0x00F1A78F+2800735]
# 	GetHandleVerifier [0x00F1456C+2775612]
# 	GetHandleVerifier [0x00D051E0+616112]
# 	(No symbol) [0x00C15F8C]
# 	(No symbol) [0x00C12328]
# 	(No symbol) [0x00C1240B]
# 	(No symbol) [0x00C04FF7]
# 	BaseThreadInitThunk [0x75CD00C9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77307B1E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77307AEE+238]
#
# 25 pages left!
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="pnnext"]"}
#   (Session info: chrome=115.0.5790.110)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x00C7A813+48355]
# 	(No symbol) [0x00C0C4B1]
# 	(No symbol) [0x00B15358]
# 	(No symbol) [0x00B409A5]
# 	(No symbol) [0x00B40B3B]
# 	(No symbol) [0x00B6E232]
# 	(No symbol) [0x00B5A784]
# 	(No symbol) [0x00B6C922]
# 	(No symbol) [0x00B5A536]
# 	(No symbol) [0x00B382DC]
# 	(No symbol) [0x00B393DD]
# 	GetHandleVerifier [0x00EDAABD+2539405]
# 	GetHandleVerifier [0x00F1A78F+2800735]
# 	GetHandleVerifier [0x00F1456C+2775612]
# 	GetHandleVerifier [0x00D051E0+616112]
# 	(No symbol) [0x00C15F8C]
# 	(No symbol) [0x00C12328]
# 	(No symbol) [0x00C1240B]
# 	(No symbol) [0x00C04FF7]
# 	BaseThreadInitThunk [0x75CD00C9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77307B1E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77307AEE+238]
#
# 24 pages left!
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="pnnext"]"}
#   (Session info: chrome=115.0.5790.110)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x00C7A813+48355]
# 	(No symbol) [0x00C0C4B1]
# 	(No symbol) [0x00B15358]
# 	(No symbol) [0x00B409A5]
# 	(No symbol) [0x00B40B3B]
# 	(No symbol) [0x00B6E232]
# 	(No symbol) [0x00B5A784]
# 	(No symbol) [0x00B6C922]
# 	(No symbol) [0x00B5A536]
# 	(No symbol) [0x00B382DC]
# 	(No symbol) [0x00B393DD]
# 	GetHandleVerifier [0x00EDAABD+2539405]
# 	GetHandleVerifier [0x00F1A78F+2800735]
# 	GetHandleVerifier [0x00F1456C+2775612]
# 	GetHandleVerifier [0x00D051E0+616112]
# 	(No symbol) [0x00C15F8C]
# 	(No symbol) [0x00C12328]
# 	(No symbol) [0x00C1240B]
# 	(No symbol) [0x00C04FF7]
# 	BaseThreadInitThunk [0x75CD00C9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77307B1E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77307AEE+238]
#
# 23 pages left!
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="pnnext"]"}
#   (Session info: chrome=115.0.5790.110)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x00C7A813+48355]
# 	(No symbol) [0x00C0C4B1]
# 	(No symbol) [0x00B15358]
# 	(No symbol) [0x00B409A5]
# 	(No symbol) [0x00B40B3B]
# 	(No symbol) [0x00B6E232]
# 	(No symbol) [0x00B5A784]
# 	(No symbol) [0x00B6C922]
# 	(No symbol) [0x00B5A536]
# 	(No symbol) [0x00B382DC]
# 	(No symbol) [0x00B393DD]
# 	GetHandleVerifier [0x00EDAABD+2539405]
# 	GetHandleVerifier [0x00F1A78F+2800735]
# 	GetHandleVerifier [0x00F1456C+2775612]
# 	GetHandleVerifier [0x00D051E0+616112]
# 	(No symbol) [0x00C15F8C]
# 	(No symbol) [0x00C12328]
# 	(No symbol) [0x00C1240B]
# 	(No symbol) [0x00C04FF7]
# 	BaseThreadInitThunk [0x75CD00C9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77307B1E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77307AEE+238]
#
# 22 pages left!
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="pnnext"]"}
#   (Session info: chrome=115.0.5790.110)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x00C7A813+48355]
# 	(No symbol) [0x00C0C4B1]
# 	(No symbol) [0x00B15358]
# 	(No symbol) [0x00B409A5]
# 	(No symbol) [0x00B40B3B]
# 	(No symbol) [0x00B6E232]
# 	(No symbol) [0x00B5A784]
# 	(No symbol) [0x00B6C922]
# 	(No symbol) [0x00B5A536]
# 	(No symbol) [0x00B382DC]
# 	(No symbol) [0x00B393DD]
# 	GetHandleVerifier [0x00EDAABD+2539405]
# 	GetHandleVerifier [0x00F1A78F+2800735]
# 	GetHandleVerifier [0x00F1456C+2775612]
# 	GetHandleVerifier [0x00D051E0+616112]
# 	(No symbol) [0x00C15F8C]
# 	(No symbol) [0x00C12328]
# 	(No symbol) [0x00C1240B]
# 	(No symbol) [0x00C04FF7]
# 	BaseThreadInitThunk [0x75CD00C9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77307B1E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77307AEE+238]
#
# 21 pages left!
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="pnnext"]"}
#   (Session info: chrome=115.0.5790.110)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x00C7A813+48355]
# 	(No symbol) [0x00C0C4B1]
# 	(No symbol) [0x00B15358]
# 	(No symbol) [0x00B409A5]
# 	(No symbol) [0x00B40B3B]
# 	(No symbol) [0x00B6E232]
# 	(No symbol) [0x00B5A784]
# 	(No symbol) [0x00B6C922]
# 	(No symbol) [0x00B5A536]
# 	(No symbol) [0x00B382DC]
# 	(No symbol) [0x00B393DD]
# 	GetHandleVerifier [0x00EDAABD+2539405]
# 	GetHandleVerifier [0x00F1A78F+2800735]
# 	GetHandleVerifier [0x00F1456C+2775612]
# 	GetHandleVerifier [0x00D051E0+616112]
# 	(No symbol) [0x00C15F8C]
# 	(No symbol) [0x00C12328]
# 	(No symbol) [0x00C1240B]
# 	(No symbol) [0x00C04FF7]
# 	BaseThreadInitThunk [0x75CD00C9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77307B1E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77307AEE+238]
#
# 20 pages left!
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="pnnext"]"}
#   (Session info: chrome=115.0.5790.110)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x00C7A813+48355]
# 	(No symbol) [0x00C0C4B1]
# 	(No symbol) [0x00B15358]
# 	(No symbol) [0x00B409A5]
# 	(No symbol) [0x00B40B3B]
# 	(No symbol) [0x00B6E232]
# 	(No symbol) [0x00B5A784]
# 	(No symbol) [0x00B6C922]
# 	(No symbol) [0x00B5A536]
# 	(No symbol) [0x00B382DC]
# 	(No symbol) [0x00B393DD]
# 	GetHandleVerifier [0x00EDAABD+2539405]
# 	GetHandleVerifier [0x00F1A78F+2800735]
# 	GetHandleVerifier [0x00F1456C+2775612]
# 	GetHandleVerifier [0x00D051E0+616112]
# 	(No symbol) [0x00C15F8C]
# 	(No symbol) [0x00C12328]
# 	(No symbol) [0x00C1240B]
# 	(No symbol) [0x00C04FF7]
# 	BaseThreadInitThunk [0x75CD00C9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77307B1E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77307AEE+238]
#
# 19 pages left!
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="pnnext"]"}
#   (Session info: chrome=115.0.5790.110)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x00C7A813+48355]
# 	(No symbol) [0x00C0C4B1]
# 	(No symbol) [0x00B15358]
# 	(No symbol) [0x00B409A5]
# 	(No symbol) [0x00B40B3B]
# 	(No symbol) [0x00B6E232]
# 	(No symbol) [0x00B5A784]
# 	(No symbol) [0x00B6C922]
# 	(No symbol) [0x00B5A536]
# 	(No symbol) [0x00B382DC]
# 	(No symbol) [0x00B393DD]
# 	GetHandleVerifier [0x00EDAABD+2539405]
# 	GetHandleVerifier [0x00F1A78F+2800735]
# 	GetHandleVerifier [0x00F1456C+2775612]
# 	GetHandleVerifier [0x00D051E0+616112]
# 	(No symbol) [0x00C15F8C]
# 	(No symbol) [0x00C12328]
# 	(No symbol) [0x00C1240B]
# 	(No symbol) [0x00C04FF7]
# 	BaseThreadInitThunk [0x75CD00C9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77307B1E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77307AEE+238]
#
# 18 pages left!
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="pnnext"]"}
#   (Session info: chrome=115.0.5790.110)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x00C7A813+48355]
# 	(No symbol) [0x00C0C4B1]
# 	(No symbol) [0x00B15358]
# 	(No symbol) [0x00B409A5]
# 	(No symbol) [0x00B40B3B]
# 	(No symbol) [0x00B6E232]
# 	(No symbol) [0x00B5A784]
# 	(No symbol) [0x00B6C922]
# 	(No symbol) [0x00B5A536]
# 	(No symbol) [0x00B382DC]
# 	(No symbol) [0x00B393DD]
# 	GetHandleVerifier [0x00EDAABD+2539405]
# 	GetHandleVerifier [0x00F1A78F+2800735]
# 	GetHandleVerifier [0x00F1456C+2775612]
# 	GetHandleVerifier [0x00D051E0+616112]
# 	(No symbol) [0x00C15F8C]
# 	(No symbol) [0x00C12328]
# 	(No symbol) [0x00C1240B]
# 	(No symbol) [0x00C04FF7]
# 	BaseThreadInitThunk [0x75CD00C9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77307B1E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77307AEE+238]
#
# 17 pages left!
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="pnnext"]"}
#   (Session info: chrome=115.0.5790.110)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x00C7A813+48355]
# 	(No symbol) [0x00C0C4B1]
# 	(No symbol) [0x00B15358]
# 	(No symbol) [0x00B409A5]
# 	(No symbol) [0x00B40B3B]
# 	(No symbol) [0x00B6E232]
# 	(No symbol) [0x00B5A784]
# 	(No symbol) [0x00B6C922]
# 	(No symbol) [0x00B5A536]
# 	(No symbol) [0x00B382DC]
# 	(No symbol) [0x00B393DD]
# 	GetHandleVerifier [0x00EDAABD+2539405]
# 	GetHandleVerifier [0x00F1A78F+2800735]
# 	GetHandleVerifier [0x00F1456C+2775612]
# 	GetHandleVerifier [0x00D051E0+616112]
# 	(No symbol) [0x00C15F8C]
# 	(No symbol) [0x00C12328]
# 	(No symbol) [0x00C1240B]
# 	(No symbol) [0x00C04FF7]
# 	BaseThreadInitThunk [0x75CD00C9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77307B1E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77307AEE+238]
#
# 16 pages left!
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="pnnext"]"}
#   (Session info: chrome=115.0.5790.110)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x00C7A813+48355]
# 	(No symbol) [0x00C0C4B1]
# 	(No symbol) [0x00B15358]
# 	(No symbol) [0x00B409A5]
# 	(No symbol) [0x00B40B3B]
# 	(No symbol) [0x00B6E232]
# 	(No symbol) [0x00B5A784]
# 	(No symbol) [0x00B6C922]
# 	(No symbol) [0x00B5A536]
# 	(No symbol) [0x00B382DC]
# 	(No symbol) [0x00B393DD]
# 	GetHandleVerifier [0x00EDAABD+2539405]
# 	GetHandleVerifier [0x00F1A78F+2800735]
# 	GetHandleVerifier [0x00F1456C+2775612]
# 	GetHandleVerifier [0x00D051E0+616112]
# 	(No symbol) [0x00C15F8C]
# 	(No symbol) [0x00C12328]
# 	(No symbol) [0x00C1240B]
# 	(No symbol) [0x00C04FF7]
# 	BaseThreadInitThunk [0x75CD00C9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77307B1E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77307AEE+238]
#
# 15 pages left!
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="pnnext"]"}
#   (Session info: chrome=115.0.5790.110)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x00C7A813+48355]
# 	(No symbol) [0x00C0C4B1]
# 	(No symbol) [0x00B15358]
# 	(No symbol) [0x00B409A5]
# 	(No symbol) [0x00B40B3B]
# 	(No symbol) [0x00B6E232]
# 	(No symbol) [0x00B5A784]
# 	(No symbol) [0x00B6C922]
# 	(No symbol) [0x00B5A536]
# 	(No symbol) [0x00B382DC]
# 	(No symbol) [0x00B393DD]
# 	GetHandleVerifier [0x00EDAABD+2539405]
# 	GetHandleVerifier [0x00F1A78F+2800735]
# 	GetHandleVerifier [0x00F1456C+2775612]
# 	GetHandleVerifier [0x00D051E0+616112]
# 	(No symbol) [0x00C15F8C]
# 	(No symbol) [0x00C12328]
# 	(No symbol) [0x00C1240B]
# 	(No symbol) [0x00C04FF7]
# 	BaseThreadInitThunk [0x75CD00C9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77307B1E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77307AEE+238]
#
# 14 pages left!
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="pnnext"]"}
#   (Session info: chrome=115.0.5790.110)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x00C7A813+48355]
# 	(No symbol) [0x00C0C4B1]
# 	(No symbol) [0x00B15358]
# 	(No symbol) [0x00B409A5]
# 	(No symbol) [0x00B40B3B]
# 	(No symbol) [0x00B6E232]
# 	(No symbol) [0x00B5A784]
# 	(No symbol) [0x00B6C922]
# 	(No symbol) [0x00B5A536]
# 	(No symbol) [0x00B382DC]
# 	(No symbol) [0x00B393DD]
# 	GetHandleVerifier [0x00EDAABD+2539405]
# 	GetHandleVerifier [0x00F1A78F+2800735]
# 	GetHandleVerifier [0x00F1456C+2775612]
# 	GetHandleVerifier [0x00D051E0+616112]
# 	(No symbol) [0x00C15F8C]
# 	(No symbol) [0x00C12328]
# 	(No symbol) [0x00C1240B]
# 	(No symbol) [0x00C04FF7]
# 	BaseThreadInitThunk [0x75CD00C9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77307B1E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77307AEE+238]
#
# 13 pages left!
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="pnnext"]"}
#   (Session info: chrome=115.0.5790.110)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x00C7A813+48355]
# 	(No symbol) [0x00C0C4B1]
# 	(No symbol) [0x00B15358]
# 	(No symbol) [0x00B409A5]
# 	(No symbol) [0x00B40B3B]
# 	(No symbol) [0x00B6E232]
# 	(No symbol) [0x00B5A784]
# 	(No symbol) [0x00B6C922]
# 	(No symbol) [0x00B5A536]
# 	(No symbol) [0x00B382DC]
# 	(No symbol) [0x00B393DD]
# 	GetHandleVerifier [0x00EDAABD+2539405]
# 	GetHandleVerifier [0x00F1A78F+2800735]
# 	GetHandleVerifier [0x00F1456C+2775612]
# 	GetHandleVerifier [0x00D051E0+616112]
# 	(No symbol) [0x00C15F8C]
# 	(No symbol) [0x00C12328]
# 	(No symbol) [0x00C1240B]
# 	(No symbol) [0x00C04FF7]
# 	BaseThreadInitThunk [0x75CD00C9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77307B1E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77307AEE+238]
#
# 12 pages left!
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="pnnext"]"}
#   (Session info: chrome=115.0.5790.110)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x00C7A813+48355]
# 	(No symbol) [0x00C0C4B1]
# 	(No symbol) [0x00B15358]
# 	(No symbol) [0x00B409A5]
# 	(No symbol) [0x00B40B3B]
# 	(No symbol) [0x00B6E232]
# 	(No symbol) [0x00B5A784]
# 	(No symbol) [0x00B6C922]
# 	(No symbol) [0x00B5A536]
# 	(No symbol) [0x00B382DC]
# 	(No symbol) [0x00B393DD]
# 	GetHandleVerifier [0x00EDAABD+2539405]
# 	GetHandleVerifier [0x00F1A78F+2800735]
# 	GetHandleVerifier [0x00F1456C+2775612]
# 	GetHandleVerifier [0x00D051E0+616112]
# 	(No symbol) [0x00C15F8C]
# 	(No symbol) [0x00C12328]
# 	(No symbol) [0x00C1240B]
# 	(No symbol) [0x00C04FF7]
# 	BaseThreadInitThunk [0x75CD00C9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77307B1E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77307AEE+238]
#
# 11 pages left!
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="pnnext"]"}
#   (Session info: chrome=115.0.5790.110)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x00C7A813+48355]
# 	(No symbol) [0x00C0C4B1]
# 	(No symbol) [0x00B15358]
# 	(No symbol) [0x00B409A5]
# 	(No symbol) [0x00B40B3B]
# 	(No symbol) [0x00B6E232]
# 	(No symbol) [0x00B5A784]
# 	(No symbol) [0x00B6C922]
# 	(No symbol) [0x00B5A536]
# 	(No symbol) [0x00B382DC]
# 	(No symbol) [0x00B393DD]
# 	GetHandleVerifier [0x00EDAABD+2539405]
# 	GetHandleVerifier [0x00F1A78F+2800735]
# 	GetHandleVerifier [0x00F1456C+2775612]
# 	GetHandleVerifier [0x00D051E0+616112]
# 	(No symbol) [0x00C15F8C]
# 	(No symbol) [0x00C12328]
# 	(No symbol) [0x00C1240B]
# 	(No symbol) [0x00C04FF7]
# 	BaseThreadInitThunk [0x75CD00C9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77307B1E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77307AEE+238]
#
# 10 pages left!
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="pnnext"]"}
#   (Session info: chrome=115.0.5790.110)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x00C7A813+48355]
# 	(No symbol) [0x00C0C4B1]
# 	(No symbol) [0x00B15358]
# 	(No symbol) [0x00B409A5]
# 	(No symbol) [0x00B40B3B]
# 	(No symbol) [0x00B6E232]
# 	(No symbol) [0x00B5A784]
# 	(No symbol) [0x00B6C922]
# 	(No symbol) [0x00B5A536]
# 	(No symbol) [0x00B382DC]
# 	(No symbol) [0x00B393DD]
# 	GetHandleVerifier [0x00EDAABD+2539405]
# 	GetHandleVerifier [0x00F1A78F+2800735]
# 	GetHandleVerifier [0x00F1456C+2775612]
# 	GetHandleVerifier [0x00D051E0+616112]
# 	(No symbol) [0x00C15F8C]
# 	(No symbol) [0x00C12328]
# 	(No symbol) [0x00C1240B]
# 	(No symbol) [0x00C04FF7]
# 	BaseThreadInitThunk [0x75CD00C9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77307B1E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77307AEE+238]
#
# 9 pages left!
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="pnnext"]"}
#   (Session info: chrome=115.0.5790.110)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x00C7A813+48355]
# 	(No symbol) [0x00C0C4B1]
# 	(No symbol) [0x00B15358]
# 	(No symbol) [0x00B409A5]
# 	(No symbol) [0x00B40B3B]
# 	(No symbol) [0x00B6E232]
# 	(No symbol) [0x00B5A784]
# 	(No symbol) [0x00B6C922]
# 	(No symbol) [0x00B5A536]
# 	(No symbol) [0x00B382DC]
# 	(No symbol) [0x00B393DD]
# 	GetHandleVerifier [0x00EDAABD+2539405]
# 	GetHandleVerifier [0x00F1A78F+2800735]
# 	GetHandleVerifier [0x00F1456C+2775612]
# 	GetHandleVerifier [0x00D051E0+616112]
# 	(No symbol) [0x00C15F8C]
# 	(No symbol) [0x00C12328]
# 	(No symbol) [0x00C1240B]
# 	(No symbol) [0x00C04FF7]
# 	BaseThreadInitThunk [0x75CD00C9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77307B1E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77307AEE+238]
#
# 8 pages left!
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="pnnext"]"}
#   (Session info: chrome=115.0.5790.110)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x00C7A813+48355]
# 	(No symbol) [0x00C0C4B1]
# 	(No symbol) [0x00B15358]
# 	(No symbol) [0x00B409A5]
# 	(No symbol) [0x00B40B3B]
# 	(No symbol) [0x00B6E232]
# 	(No symbol) [0x00B5A784]
# 	(No symbol) [0x00B6C922]
# 	(No symbol) [0x00B5A536]
# 	(No symbol) [0x00B382DC]
# 	(No symbol) [0x00B393DD]
# 	GetHandleVerifier [0x00EDAABD+2539405]
# 	GetHandleVerifier [0x00F1A78F+2800735]
# 	GetHandleVerifier [0x00F1456C+2775612]
# 	GetHandleVerifier [0x00D051E0+616112]
# 	(No symbol) [0x00C15F8C]
# 	(No symbol) [0x00C12328]
# 	(No symbol) [0x00C1240B]
# 	(No symbol) [0x00C04FF7]
# 	BaseThreadInitThunk [0x75CD00C9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77307B1E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77307AEE+238]
#
# 7 pages left!
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="pnnext"]"}
#   (Session info: chrome=115.0.5790.110)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x00C7A813+48355]
# 	(No symbol) [0x00C0C4B1]
# 	(No symbol) [0x00B15358]
# 	(No symbol) [0x00B409A5]
# 	(No symbol) [0x00B40B3B]
# 	(No symbol) [0x00B6E232]
# 	(No symbol) [0x00B5A784]
# 	(No symbol) [0x00B6C922]
# 	(No symbol) [0x00B5A536]
# 	(No symbol) [0x00B382DC]
# 	(No symbol) [0x00B393DD]
# 	GetHandleVerifier [0x00EDAABD+2539405]
# 	GetHandleVerifier [0x00F1A78F+2800735]
# 	GetHandleVerifier [0x00F1456C+2775612]
# 	GetHandleVerifier [0x00D051E0+616112]
# 	(No symbol) [0x00C15F8C]
# 	(No symbol) [0x00C12328]
# 	(No symbol) [0x00C1240B]
# 	(No symbol) [0x00C04FF7]
# 	BaseThreadInitThunk [0x75CD00C9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77307B1E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77307AEE+238]
#
# 6 pages left!
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="pnnext"]"}
#   (Session info: chrome=115.0.5790.110)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x00C7A813+48355]
# 	(No symbol) [0x00C0C4B1]
# 	(No symbol) [0x00B15358]
# 	(No symbol) [0x00B409A5]
# 	(No symbol) [0x00B40B3B]
# 	(No symbol) [0x00B6E232]
# 	(No symbol) [0x00B5A784]
# 	(No symbol) [0x00B6C922]
# 	(No symbol) [0x00B5A536]
# 	(No symbol) [0x00B382DC]
# 	(No symbol) [0x00B393DD]
# 	GetHandleVerifier [0x00EDAABD+2539405]
# 	GetHandleVerifier [0x00F1A78F+2800735]
# 	GetHandleVerifier [0x00F1456C+2775612]
# 	GetHandleVerifier [0x00D051E0+616112]
# 	(No symbol) [0x00C15F8C]
# 	(No symbol) [0x00C12328]
# 	(No symbol) [0x00C1240B]
# 	(No symbol) [0x00C04FF7]
# 	BaseThreadInitThunk [0x75CD00C9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77307B1E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77307AEE+238]
#
# 5 pages left!
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="pnnext"]"}
#   (Session info: chrome=115.0.5790.110)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x00C7A813+48355]
# 	(No symbol) [0x00C0C4B1]
# 	(No symbol) [0x00B15358]
# 	(No symbol) [0x00B409A5]
# 	(No symbol) [0x00B40B3B]
# 	(No symbol) [0x00B6E232]
# 	(No symbol) [0x00B5A784]
# 	(No symbol) [0x00B6C922]
# 	(No symbol) [0x00B5A536]
# 	(No symbol) [0x00B382DC]
# 	(No symbol) [0x00B393DD]
# 	GetHandleVerifier [0x00EDAABD+2539405]
# 	GetHandleVerifier [0x00F1A78F+2800735]
# 	GetHandleVerifier [0x00F1456C+2775612]
# 	GetHandleVerifier [0x00D051E0+616112]
# 	(No symbol) [0x00C15F8C]
# 	(No symbol) [0x00C12328]
# 	(No symbol) [0x00C1240B]
# 	(No symbol) [0x00C04FF7]
# 	BaseThreadInitThunk [0x75CD00C9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77307B1E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77307AEE+238]
#
# 4 pages left!
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="pnnext"]"}
#   (Session info: chrome=115.0.5790.110)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x00C7A813+48355]
# 	(No symbol) [0x00C0C4B1]
# 	(No symbol) [0x00B15358]
# 	(No symbol) [0x00B409A5]
# 	(No symbol) [0x00B40B3B]
# 	(No symbol) [0x00B6E232]
# 	(No symbol) [0x00B5A784]
# 	(No symbol) [0x00B6C922]
# 	(No symbol) [0x00B5A536]
# 	(No symbol) [0x00B382DC]
# 	(No symbol) [0x00B393DD]
# 	GetHandleVerifier [0x00EDAABD+2539405]
# 	GetHandleVerifier [0x00F1A78F+2800735]
# 	GetHandleVerifier [0x00F1456C+2775612]
# 	GetHandleVerifier [0x00D051E0+616112]
# 	(No symbol) [0x00C15F8C]
# 	(No symbol) [0x00C12328]
# 	(No symbol) [0x00C1240B]
# 	(No symbol) [0x00C04FF7]
# 	BaseThreadInitThunk [0x75CD00C9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77307B1E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77307AEE+238]
#
# 3 pages left!
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="pnnext"]"}
#   (Session info: chrome=115.0.5790.110)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x00C7A813+48355]
# 	(No symbol) [0x00C0C4B1]
# 	(No symbol) [0x00B15358]
# 	(No symbol) [0x00B409A5]
# 	(No symbol) [0x00B40B3B]
# 	(No symbol) [0x00B6E232]
# 	(No symbol) [0x00B5A784]
# 	(No symbol) [0x00B6C922]
# 	(No symbol) [0x00B5A536]
# 	(No symbol) [0x00B382DC]
# 	(No symbol) [0x00B393DD]
# 	GetHandleVerifier [0x00EDAABD+2539405]
# 	GetHandleVerifier [0x00F1A78F+2800735]
# 	GetHandleVerifier [0x00F1456C+2775612]
# 	GetHandleVerifier [0x00D051E0+616112]
# 	(No symbol) [0x00C15F8C]
# 	(No symbol) [0x00C12328]
# 	(No symbol) [0x00C1240B]
# 	(No symbol) [0x00C04FF7]
# 	BaseThreadInitThunk [0x75CD00C9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77307B1E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77307AEE+238]
#
# 2 pages left!
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="pnnext"]"}
#   (Session info: chrome=115.0.5790.110)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x00C7A813+48355]
# 	(No symbol) [0x00C0C4B1]
# 	(No symbol) [0x00B15358]
# 	(No symbol) [0x00B409A5]
# 	(No symbol) [0x00B40B3B]
# 	(No symbol) [0x00B6E232]
# 	(No symbol) [0x00B5A784]
# 	(No symbol) [0x00B6C922]
# 	(No symbol) [0x00B5A536]
# 	(No symbol) [0x00B382DC]
# 	(No symbol) [0x00B393DD]
# 	GetHandleVerifier [0x00EDAABD+2539405]
# 	GetHandleVerifier [0x00F1A78F+2800735]
# 	GetHandleVerifier [0x00F1456C+2775612]
# 	GetHandleVerifier [0x00D051E0+616112]
# 	(No symbol) [0x00C15F8C]
# 	(No symbol) [0x00C12328]
# 	(No symbol) [0x00C1240B]
# 	(No symbol) [0x00C04FF7]
# 	BaseThreadInitThunk [0x75CD00C9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77307B1E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77307AEE+238]
#
# 1 pages left!
# I am done ---> 632
# if there is a problem, start with 633
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="pnnext"]"}
#   (Session info: chrome=115.0.5790.110)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x00C7A813+48355]
# 	(No symbol) [0x00C0C4B1]
# 	(No symbol) [0x00B15358]
# 	(No symbol) [0x00B409A5]
# 	(No symbol) [0x00B40B3B]
# 	(No symbol) [0x00B6E232]
# 	(No symbol) [0x00B5A784]
# 	(No symbol) [0x00B6C922]
# 	(No symbol) [0x00B5A536]
# 	(No symbol) [0x00B382DC]
# 	(No symbol) [0x00B393DD]
# 	GetHandleVerifier [0x00EDAABD+2539405]
# 	GetHandleVerifier [0x00F1A78F+2800735]
# 	GetHandleVerifier [0x00F1456C+2775612]
# 	GetHandleVerifier [0x00D051E0+616112]
# 	(No symbol) [0x00C15F8C]
# 	(No symbol) [0x00C12328]
# 	(No symbol) [0x00C1240B]
# 	(No symbol) [0x00C04FF7]
# 	BaseThreadInitThunk [0x75CD00C9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77307B1E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77307AEE+238]
#
# 30 pages left!
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="pnnext"]"}
#   (Session info: chrome=115.0.5790.110)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x00C7A813+48355]
# 	(No symbol) [0x00C0C4B1]
# 	(No symbol) [0x00B15358]
# 	(No symbol) [0x00B409A5]
# 	(No symbol) [0x00B40B3B]
# 	(No symbol) [0x00B6E232]
# 	(No symbol) [0x00B5A784]
# 	(No symbol) [0x00B6C922]
# 	(No symbol) [0x00B5A536]
# 	(No symbol) [0x00B382DC]
# 	(No symbol) [0x00B393DD]
# 	GetHandleVerifier [0x00EDAABD+2539405]
# 	GetHandleVerifier [0x00F1A78F+2800735]
# 	GetHandleVerifier [0x00F1456C+2775612]
# 	GetHandleVerifier [0x00D051E0+616112]
# 	(No symbol) [0x00C15F8C]
# 	(No symbol) [0x00C12328]
# 	(No symbol) [0x00C1240B]
# 	(No symbol) [0x00C04FF7]
# 	BaseThreadInitThunk [0x75CD00C9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77307B1E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77307AEE+238]
#
# 29 pages left!
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="pnnext"]"}
#   (Session info: chrome=115.0.5790.110)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x00C7A813+48355]
# 	(No symbol) [0x00C0C4B1]
# 	(No symbol) [0x00B15358]
# 	(No symbol) [0x00B409A5]
# 	(No symbol) [0x00B40B3B]
# 	(No symbol) [0x00B6E232]
# 	(No symbol) [0x00B5A784]
# 	(No symbol) [0x00B6C922]
# 	(No symbol) [0x00B5A536]
# 	(No symbol) [0x00B382DC]
# 	(No symbol) [0x00B393DD]
# 	GetHandleVerifier [0x00EDAABD+2539405]
# 	GetHandleVerifier [0x00F1A78F+2800735]
# 	GetHandleVerifier [0x00F1456C+2775612]
# 	GetHandleVerifier [0x00D051E0+616112]
# 	(No symbol) [0x00C15F8C]
# 	(No symbol) [0x00C12328]
# 	(No symbol) [0x00C1240B]
# 	(No symbol) [0x00C04FF7]
# 	BaseThreadInitThunk [0x75CD00C9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77307B1E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77307AEE+238]
#
# 28 pages left!
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="pnnext"]"}
#   (Session info: chrome=115.0.5790.110)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x00C7A813+48355]
# 	(No symbol) [0x00C0C4B1]
# 	(No symbol) [0x00B15358]
# 	(No symbol) [0x00B409A5]
# 	(No symbol) [0x00B40B3B]
# 	(No symbol) [0x00B6E232]
# 	(No symbol) [0x00B5A784]
# 	(No symbol) [0x00B6C922]
# 	(No symbol) [0x00B5A536]
# 	(No symbol) [0x00B382DC]
# 	(No symbol) [0x00B393DD]
# 	GetHandleVerifier [0x00EDAABD+2539405]
# 	GetHandleVerifier [0x00F1A78F+2800735]
# 	GetHandleVerifier [0x00F1456C+2775612]
# 	GetHandleVerifier [0x00D051E0+616112]
# 	(No symbol) [0x00C15F8C]
# 	(No symbol) [0x00C12328]
# 	(No symbol) [0x00C1240B]
# 	(No symbol) [0x00C04FF7]
# 	BaseThreadInitThunk [0x75CD00C9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77307B1E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77307AEE+238]
#
# 27 pages left!
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="pnnext"]"}
#   (Session info: chrome=115.0.5790.110)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x00C7A813+48355]
# 	(No symbol) [0x00C0C4B1]
# 	(No symbol) [0x00B15358]
# 	(No symbol) [0x00B409A5]
# 	(No symbol) [0x00B40B3B]
# 	(No symbol) [0x00B6E232]
# 	(No symbol) [0x00B5A784]
# 	(No symbol) [0x00B6C922]
# 	(No symbol) [0x00B5A536]
# 	(No symbol) [0x00B382DC]
# 	(No symbol) [0x00B393DD]
# 	GetHandleVerifier [0x00EDAABD+2539405]
# 	GetHandleVerifier [0x00F1A78F+2800735]
# 	GetHandleVerifier [0x00F1456C+2775612]
# 	GetHandleVerifier [0x00D051E0+616112]
# 	(No symbol) [0x00C15F8C]
# 	(No symbol) [0x00C12328]
# 	(No symbol) [0x00C1240B]
# 	(No symbol) [0x00C04FF7]
# 	BaseThreadInitThunk [0x75CD00C9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77307B1E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77307AEE+238]
#
# 26 pages left!
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="pnnext"]"}
#   (Session info: chrome=115.0.5790.110)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x00C7A813+48355]
# 	(No symbol) [0x00C0C4B1]
# 	(No symbol) [0x00B15358]
# 	(No symbol) [0x00B409A5]
# 	(No symbol) [0x00B40B3B]
# 	(No symbol) [0x00B6E232]
# 	(No symbol) [0x00B5A784]
# 	(No symbol) [0x00B6C922]
# 	(No symbol) [0x00B5A536]
# 	(No symbol) [0x00B382DC]
# 	(No symbol) [0x00B393DD]
# 	GetHandleVerifier [0x00EDAABD+2539405]
# 	GetHandleVerifier [0x00F1A78F+2800735]
# 	GetHandleVerifier [0x00F1456C+2775612]
# 	GetHandleVerifier [0x00D051E0+616112]
# 	(No symbol) [0x00C15F8C]
# 	(No symbol) [0x00C12328]
# 	(No symbol) [0x00C1240B]
# 	(No symbol) [0x00C04FF7]
# 	BaseThreadInitThunk [0x75CD00C9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77307B1E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77307AEE+238]
#
# 25 pages left!
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="pnnext"]"}
#   (Session info: chrome=115.0.5790.110)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x00C7A813+48355]
# 	(No symbol) [0x00C0C4B1]
# 	(No symbol) [0x00B15358]
# 	(No symbol) [0x00B409A5]
# 	(No symbol) [0x00B40B3B]
# 	(No symbol) [0x00B6E232]
# 	(No symbol) [0x00B5A784]
# 	(No symbol) [0x00B6C922]
# 	(No symbol) [0x00B5A536]
# 	(No symbol) [0x00B382DC]
# 	(No symbol) [0x00B393DD]
# 	GetHandleVerifier [0x00EDAABD+2539405]
# 	GetHandleVerifier [0x00F1A78F+2800735]
# 	GetHandleVerifier [0x00F1456C+2775612]
# 	GetHandleVerifier [0x00D051E0+616112]
# 	(No symbol) [0x00C15F8C]
# 	(No symbol) [0x00C12328]
# 	(No symbol) [0x00C1240B]
# 	(No symbol) [0x00C04FF7]
# 	BaseThreadInitThunk [0x75CD00C9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77307B1E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77307AEE+238]
#
# 24 pages left!
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="pnnext"]"}
#   (Session info: chrome=115.0.5790.110)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x00C7A813+48355]
# 	(No symbol) [0x00C0C4B1]
# 	(No symbol) [0x00B15358]
# 	(No symbol) [0x00B409A5]
# 	(No symbol) [0x00B40B3B]
# 	(No symbol) [0x00B6E232]
# 	(No symbol) [0x00B5A784]
# 	(No symbol) [0x00B6C922]
# 	(No symbol) [0x00B5A536]
# 	(No symbol) [0x00B382DC]
# 	(No symbol) [0x00B393DD]
# 	GetHandleVerifier [0x00EDAABD+2539405]
# 	GetHandleVerifier [0x00F1A78F+2800735]
# 	GetHandleVerifier [0x00F1456C+2775612]
# 	GetHandleVerifier [0x00D051E0+616112]
# 	(No symbol) [0x00C15F8C]
# 	(No symbol) [0x00C12328]
# 	(No symbol) [0x00C1240B]
# 	(No symbol) [0x00C04FF7]
# 	BaseThreadInitThunk [0x75CD00C9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77307B1E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77307AEE+238]
#
# 23 pages left!
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="pnnext"]"}
#   (Session info: chrome=115.0.5790.110)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x00C7A813+48355]
# 	(No symbol) [0x00C0C4B1]
# 	(No symbol) [0x00B15358]
# 	(No symbol) [0x00B409A5]
# 	(No symbol) [0x00B40B3B]
# 	(No symbol) [0x00B6E232]
# 	(No symbol) [0x00B5A784]
# 	(No symbol) [0x00B6C922]
# 	(No symbol) [0x00B5A536]
# 	(No symbol) [0x00B382DC]
# 	(No symbol) [0x00B393DD]
# 	GetHandleVerifier [0x00EDAABD+2539405]
# 	GetHandleVerifier [0x00F1A78F+2800735]
# 	GetHandleVerifier [0x00F1456C+2775612]
# 	GetHandleVerifier [0x00D051E0+616112]
# 	(No symbol) [0x00C15F8C]
# 	(No symbol) [0x00C12328]
# 	(No symbol) [0x00C1240B]
# 	(No symbol) [0x00C04FF7]
# 	BaseThreadInitThunk [0x75CD00C9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77307B1E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77307AEE+238]
#
# 22 pages left!
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="pnnext"]"}
#   (Session info: chrome=115.0.5790.110)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x00C7A813+48355]
# 	(No symbol) [0x00C0C4B1]
# 	(No symbol) [0x00B15358]
# 	(No symbol) [0x00B409A5]
# 	(No symbol) [0x00B40B3B]
# 	(No symbol) [0x00B6E232]
# 	(No symbol) [0x00B5A784]
# 	(No symbol) [0x00B6C922]
# 	(No symbol) [0x00B5A536]
# 	(No symbol) [0x00B382DC]
# 	(No symbol) [0x00B393DD]
# 	GetHandleVerifier [0x00EDAABD+2539405]
# 	GetHandleVerifier [0x00F1A78F+2800735]
# 	GetHandleVerifier [0x00F1456C+2775612]
# 	GetHandleVerifier [0x00D051E0+616112]
# 	(No symbol) [0x00C15F8C]
# 	(No symbol) [0x00C12328]
# 	(No symbol) [0x00C1240B]
# 	(No symbol) [0x00C04FF7]
# 	BaseThreadInitThunk [0x75CD00C9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77307B1E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77307AEE+238]
#
# 21 pages left!
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="pnnext"]"}
#   (Session info: chrome=115.0.5790.110)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x00C7A813+48355]
# 	(No symbol) [0x00C0C4B1]
# 	(No symbol) [0x00B15358]
# 	(No symbol) [0x00B409A5]
# 	(No symbol) [0x00B40B3B]
# 	(No symbol) [0x00B6E232]
# 	(No symbol) [0x00B5A784]
# 	(No symbol) [0x00B6C922]
# 	(No symbol) [0x00B5A536]
# 	(No symbol) [0x00B382DC]
# 	(No symbol) [0x00B393DD]
# 	GetHandleVerifier [0x00EDAABD+2539405]
# 	GetHandleVerifier [0x00F1A78F+2800735]
# 	GetHandleVerifier [0x00F1456C+2775612]
# 	GetHandleVerifier [0x00D051E0+616112]
# 	(No symbol) [0x00C15F8C]
# 	(No symbol) [0x00C12328]
# 	(No symbol) [0x00C1240B]
# 	(No symbol) [0x00C04FF7]
# 	BaseThreadInitThunk [0x75CD00C9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77307B1E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77307AEE+238]
#
# 20 pages left!
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="pnnext"]"}
#   (Session info: chrome=115.0.5790.110)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x00C7A813+48355]
# 	(No symbol) [0x00C0C4B1]
# 	(No symbol) [0x00B15358]
# 	(No symbol) [0x00B409A5]
# 	(No symbol) [0x00B40B3B]
# 	(No symbol) [0x00B6E232]
# 	(No symbol) [0x00B5A784]
# 	(No symbol) [0x00B6C922]
# 	(No symbol) [0x00B5A536]
# 	(No symbol) [0x00B382DC]
# 	(No symbol) [0x00B393DD]
# 	GetHandleVerifier [0x00EDAABD+2539405]
# 	GetHandleVerifier [0x00F1A78F+2800735]
# 	GetHandleVerifier [0x00F1456C+2775612]
# 	GetHandleVerifier [0x00D051E0+616112]
# 	(No symbol) [0x00C15F8C]
# 	(No symbol) [0x00C12328]
# 	(No symbol) [0x00C1240B]
# 	(No symbol) [0x00C04FF7]
# 	BaseThreadInitThunk [0x75CD00C9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77307B1E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77307AEE+238]
#
# 19 pages left!
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="pnnext"]"}
#   (Session info: chrome=115.0.5790.110)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x00C7A813+48355]
# 	(No symbol) [0x00C0C4B1]
# 	(No symbol) [0x00B15358]
# 	(No symbol) [0x00B409A5]
# 	(No symbol) [0x00B40B3B]
# 	(No symbol) [0x00B6E232]
# 	(No symbol) [0x00B5A784]
# 	(No symbol) [0x00B6C922]
# 	(No symbol) [0x00B5A536]
# 	(No symbol) [0x00B382DC]
# 	(No symbol) [0x00B393DD]
# 	GetHandleVerifier [0x00EDAABD+2539405]
# 	GetHandleVerifier [0x00F1A78F+2800735]
# 	GetHandleVerifier [0x00F1456C+2775612]
# 	GetHandleVerifier [0x00D051E0+616112]
# 	(No symbol) [0x00C15F8C]
# 	(No symbol) [0x00C12328]
# 	(No symbol) [0x00C1240B]
# 	(No symbol) [0x00C04FF7]
# 	BaseThreadInitThunk [0x75CD00C9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77307B1E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77307AEE+238]
#
# 18 pages left!
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="pnnext"]"}
#   (Session info: chrome=115.0.5790.110)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x00C7A813+48355]
# 	(No symbol) [0x00C0C4B1]
# 	(No symbol) [0x00B15358]
# 	(No symbol) [0x00B409A5]
# 	(No symbol) [0x00B40B3B]
# 	(No symbol) [0x00B6E232]
# 	(No symbol) [0x00B5A784]
# 	(No symbol) [0x00B6C922]
# 	(No symbol) [0x00B5A536]
# 	(No symbol) [0x00B382DC]
# 	(No symbol) [0x00B393DD]
# 	GetHandleVerifier [0x00EDAABD+2539405]
# 	GetHandleVerifier [0x00F1A78F+2800735]
# 	GetHandleVerifier [0x00F1456C+2775612]
# 	GetHandleVerifier [0x00D051E0+616112]
# 	(No symbol) [0x00C15F8C]
# 	(No symbol) [0x00C12328]
# 	(No symbol) [0x00C1240B]
# 	(No symbol) [0x00C04FF7]
# 	BaseThreadInitThunk [0x75CD00C9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77307B1E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77307AEE+238]
#
# 17 pages left!
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="pnnext"]"}
#   (Session info: chrome=115.0.5790.110)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x00C7A813+48355]
# 	(No symbol) [0x00C0C4B1]
# 	(No symbol) [0x00B15358]
# 	(No symbol) [0x00B409A5]
# 	(No symbol) [0x00B40B3B]
# 	(No symbol) [0x00B6E232]
# 	(No symbol) [0x00B5A784]
# 	(No symbol) [0x00B6C922]
# 	(No symbol) [0x00B5A536]
# 	(No symbol) [0x00B382DC]
# 	(No symbol) [0x00B393DD]
# 	GetHandleVerifier [0x00EDAABD+2539405]
# 	GetHandleVerifier [0x00F1A78F+2800735]
# 	GetHandleVerifier [0x00F1456C+2775612]
# 	GetHandleVerifier [0x00D051E0+616112]
# 	(No symbol) [0x00C15F8C]
# 	(No symbol) [0x00C12328]
# 	(No symbol) [0x00C1240B]
# 	(No symbol) [0x00C04FF7]
# 	BaseThreadInitThunk [0x75CD00C9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77307B1E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77307AEE+238]
#
# 16 pages left!
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="pnnext"]"}
#   (Session info: chrome=115.0.5790.110)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x00C7A813+48355]
# 	(No symbol) [0x00C0C4B1]
# 	(No symbol) [0x00B15358]
# 	(No symbol) [0x00B409A5]
# 	(No symbol) [0x00B40B3B]
# 	(No symbol) [0x00B6E232]
# 	(No symbol) [0x00B5A784]
# 	(No symbol) [0x00B6C922]
# 	(No symbol) [0x00B5A536]
# 	(No symbol) [0x00B382DC]
# 	(No symbol) [0x00B393DD]
# 	GetHandleVerifier [0x00EDAABD+2539405]
# 	GetHandleVerifier [0x00F1A78F+2800735]
# 	GetHandleVerifier [0x00F1456C+2775612]
# 	GetHandleVerifier [0x00D051E0+616112]
# 	(No symbol) [0x00C15F8C]
# 	(No symbol) [0x00C12328]
# 	(No symbol) [0x00C1240B]
# 	(No symbol) [0x00C04FF7]
# 	BaseThreadInitThunk [0x75CD00C9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77307B1E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77307AEE+238]
#
# 15 pages left!
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="pnnext"]"}
#   (Session info: chrome=115.0.5790.110)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x00C7A813+48355]
# 	(No symbol) [0x00C0C4B1]
# 	(No symbol) [0x00B15358]
# 	(No symbol) [0x00B409A5]
# 	(No symbol) [0x00B40B3B]
# 	(No symbol) [0x00B6E232]
# 	(No symbol) [0x00B5A784]
# 	(No symbol) [0x00B6C922]
# 	(No symbol) [0x00B5A536]
# 	(No symbol) [0x00B382DC]
# 	(No symbol) [0x00B393DD]
# 	GetHandleVerifier [0x00EDAABD+2539405]
# 	GetHandleVerifier [0x00F1A78F+2800735]
# 	GetHandleVerifier [0x00F1456C+2775612]
# 	GetHandleVerifier [0x00D051E0+616112]
# 	(No symbol) [0x00C15F8C]
# 	(No symbol) [0x00C12328]
# 	(No symbol) [0x00C1240B]
# 	(No symbol) [0x00C04FF7]
# 	BaseThreadInitThunk [0x75CD00C9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77307B1E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77307AEE+238]
#
# 14 pages left!
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="pnnext"]"}
#   (Session info: chrome=115.0.5790.110)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x00C7A813+48355]
# 	(No symbol) [0x00C0C4B1]
# 	(No symbol) [0x00B15358]
# 	(No symbol) [0x00B409A5]
# 	(No symbol) [0x00B40B3B]
# 	(No symbol) [0x00B6E232]
# 	(No symbol) [0x00B5A784]
# 	(No symbol) [0x00B6C922]
# 	(No symbol) [0x00B5A536]
# 	(No symbol) [0x00B382DC]
# 	(No symbol) [0x00B393DD]
# 	GetHandleVerifier [0x00EDAABD+2539405]
# 	GetHandleVerifier [0x00F1A78F+2800735]
# 	GetHandleVerifier [0x00F1456C+2775612]
# 	GetHandleVerifier [0x00D051E0+616112]
# 	(No symbol) [0x00C15F8C]
# 	(No symbol) [0x00C12328]
# 	(No symbol) [0x00C1240B]
# 	(No symbol) [0x00C04FF7]
# 	BaseThreadInitThunk [0x75CD00C9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77307B1E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77307AEE+238]
#
# 13 pages left!
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="pnnext"]"}
#   (Session info: chrome=115.0.5790.110)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x00C7A813+48355]
# 	(No symbol) [0x00C0C4B1]
# 	(No symbol) [0x00B15358]
# 	(No symbol) [0x00B409A5]
# 	(No symbol) [0x00B40B3B]
# 	(No symbol) [0x00B6E232]
# 	(No symbol) [0x00B5A784]
# 	(No symbol) [0x00B6C922]
# 	(No symbol) [0x00B5A536]
# 	(No symbol) [0x00B382DC]
# 	(No symbol) [0x00B393DD]
# 	GetHandleVerifier [0x00EDAABD+2539405]
# 	GetHandleVerifier [0x00F1A78F+2800735]
# 	GetHandleVerifier [0x00F1456C+2775612]
# 	GetHandleVerifier [0x00D051E0+616112]
# 	(No symbol) [0x00C15F8C]
# 	(No symbol) [0x00C12328]
# 	(No symbol) [0x00C1240B]
# 	(No symbol) [0x00C04FF7]
# 	BaseThreadInitThunk [0x75CD00C9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77307B1E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77307AEE+238]
#
# 12 pages left!
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="pnnext"]"}
#   (Session info: chrome=115.0.5790.110)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x00C7A813+48355]
# 	(No symbol) [0x00C0C4B1]
# 	(No symbol) [0x00B15358]
# 	(No symbol) [0x00B409A5]
# 	(No symbol) [0x00B40B3B]
# 	(No symbol) [0x00B6E232]
# 	(No symbol) [0x00B5A784]
# 	(No symbol) [0x00B6C922]
# 	(No symbol) [0x00B5A536]
# 	(No symbol) [0x00B382DC]
# 	(No symbol) [0x00B393DD]
# 	GetHandleVerifier [0x00EDAABD+2539405]
# 	GetHandleVerifier [0x00F1A78F+2800735]
# 	GetHandleVerifier [0x00F1456C+2775612]
# 	GetHandleVerifier [0x00D051E0+616112]
# 	(No symbol) [0x00C15F8C]
# 	(No symbol) [0x00C12328]
# 	(No symbol) [0x00C1240B]
# 	(No symbol) [0x00C04FF7]
# 	BaseThreadInitThunk [0x75CD00C9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77307B1E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77307AEE+238]
#
# 11 pages left!
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="pnnext"]"}
#   (Session info: chrome=115.0.5790.110)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x00C7A813+48355]
# 	(No symbol) [0x00C0C4B1]
# 	(No symbol) [0x00B15358]
# 	(No symbol) [0x00B409A5]
# 	(No symbol) [0x00B40B3B]
# 	(No symbol) [0x00B6E232]
# 	(No symbol) [0x00B5A784]
# 	(No symbol) [0x00B6C922]
# 	(No symbol) [0x00B5A536]
# 	(No symbol) [0x00B382DC]
# 	(No symbol) [0x00B393DD]
# 	GetHandleVerifier [0x00EDAABD+2539405]
# 	GetHandleVerifier [0x00F1A78F+2800735]
# 	GetHandleVerifier [0x00F1456C+2775612]
# 	GetHandleVerifier [0x00D051E0+616112]
# 	(No symbol) [0x00C15F8C]
# 	(No symbol) [0x00C12328]
# 	(No symbol) [0x00C1240B]
# 	(No symbol) [0x00C04FF7]
# 	BaseThreadInitThunk [0x75CD00C9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77307B1E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77307AEE+238]
#
# 10 pages left!
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="pnnext"]"}
#   (Session info: chrome=115.0.5790.110)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x00C7A813+48355]
# 	(No symbol) [0x00C0C4B1]
# 	(No symbol) [0x00B15358]
# 	(No symbol) [0x00B409A5]
# 	(No symbol) [0x00B40B3B]
# 	(No symbol) [0x00B6E232]
# 	(No symbol) [0x00B5A784]
# 	(No symbol) [0x00B6C922]
# 	(No symbol) [0x00B5A536]
# 	(No symbol) [0x00B382DC]
# 	(No symbol) [0x00B393DD]
# 	GetHandleVerifier [0x00EDAABD+2539405]
# 	GetHandleVerifier [0x00F1A78F+2800735]
# 	GetHandleVerifier [0x00F1456C+2775612]
# 	GetHandleVerifier [0x00D051E0+616112]
# 	(No symbol) [0x00C15F8C]
# 	(No symbol) [0x00C12328]
# 	(No symbol) [0x00C1240B]
# 	(No symbol) [0x00C04FF7]
# 	BaseThreadInitThunk [0x75CD00C9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77307B1E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77307AEE+238]
#
# 9 pages left!
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="pnnext"]"}
#   (Session info: chrome=115.0.5790.110)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x00C7A813+48355]
# 	(No symbol) [0x00C0C4B1]
# 	(No symbol) [0x00B15358]
# 	(No symbol) [0x00B409A5]
# 	(No symbol) [0x00B40B3B]
# 	(No symbol) [0x00B6E232]
# 	(No symbol) [0x00B5A784]
# 	(No symbol) [0x00B6C922]
# 	(No symbol) [0x00B5A536]
# 	(No symbol) [0x00B382DC]
# 	(No symbol) [0x00B393DD]
# 	GetHandleVerifier [0x00EDAABD+2539405]
# 	GetHandleVerifier [0x00F1A78F+2800735]
# 	GetHandleVerifier [0x00F1456C+2775612]
# 	GetHandleVerifier [0x00D051E0+616112]
# 	(No symbol) [0x00C15F8C]
# 	(No symbol) [0x00C12328]
# 	(No symbol) [0x00C1240B]
# 	(No symbol) [0x00C04FF7]
# 	BaseThreadInitThunk [0x75CD00C9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77307B1E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77307AEE+238]
#
# 8 pages left!
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="pnnext"]"}
#   (Session info: chrome=115.0.5790.110)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x00C7A813+48355]
# 	(No symbol) [0x00C0C4B1]
# 	(No symbol) [0x00B15358]
# 	(No symbol) [0x00B409A5]
# 	(No symbol) [0x00B40B3B]
# 	(No symbol) [0x00B6E232]
# 	(No symbol) [0x00B5A784]
# 	(No symbol) [0x00B6C922]
# 	(No symbol) [0x00B5A536]
# 	(No symbol) [0x00B382DC]
# 	(No symbol) [0x00B393DD]
# 	GetHandleVerifier [0x00EDAABD+2539405]
# 	GetHandleVerifier [0x00F1A78F+2800735]
# 	GetHandleVerifier [0x00F1456C+2775612]
# 	GetHandleVerifier [0x00D051E0+616112]
# 	(No symbol) [0x00C15F8C]
# 	(No symbol) [0x00C12328]
# 	(No symbol) [0x00C1240B]
# 	(No symbol) [0x00C04FF7]
# ...
# 	(No symbol) [0x00B382DC]
# 	(No symbol) [0x00B393DD]
# 	GetHandleVerifier [0x00EDAABD+2539405]
# 	GetHandleVerifier [0x00F1A78F+2800735]
# 	GetHandleVerifier [0x00F1456C+2775612]
# 	GetHandleVerifier [0x00D051E0+616112]
# 	(No symbol) [0x00C15F8C]
# 	(No symbol) [0x00C12328]
# 	(No symbol) [0x00C1240B]
# 	(No symbol) [0x00C04FF7]
# 	BaseThreadInitThunk [0x75CD00C9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77307B1E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77307AEE+238]
#
# 15 pages left!
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="pnnext"]"}
#   (Session info: chrome=115.0.5790.110)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x00C7A813+48355]
# 	(No symbol) [0x00C0C4B1]
# 	(No symbol) [0x00B15358]
# 	(No symbol) [0x00B409A5]
# 	(No symbol) [0x00B40B3B]
# 	(No symbol) [0x00B6E232]
# 	(No symbol) [0x00B5A784]
# 	(No symbol) [0x00B6C922]
# 	(No symbol) [0x00B5A536]
# 	(No symbol) [0x00B382DC]
# 	(No symbol) [0x00B393DD]
# 	GetHandleVerifier [0x00EDAABD+2539405]
# 	GetHandleVerifier [0x00F1A78F+2800735]
# 	GetHandleVerifier [0x00F1456C+2775612]
# 	GetHandleVerifier [0x00D051E0+616112]
# 	(No symbol) [0x00C15F8C]
# 	(No symbol) [0x00C12328]
# 	(No symbol) [0x00C1240B]
# 	(No symbol) [0x00C04FF7]
# 	BaseThreadInitThunk [0x75CD00C9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77307B1E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77307AEE+238]
#
# 14 pages left!
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="pnnext"]"}
#   (Session info: chrome=115.0.5790.110)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x00C7A813+48355]
# 	(No symbol) [0x00C0C4B1]
# 	(No symbol) [0x00B15358]
# 	(No symbol) [0x00B409A5]
# 	(No symbol) [0x00B40B3B]
# 	(No symbol) [0x00B6E232]
# 	(No symbol) [0x00B5A784]
# 	(No symbol) [0x00B6C922]
# 	(No symbol) [0x00B5A536]
# 	(No symbol) [0x00B382DC]
# 	(No symbol) [0x00B393DD]
# 	GetHandleVerifier [0x00EDAABD+2539405]
# 	GetHandleVerifier [0x00F1A78F+2800735]
# 	GetHandleVerifier [0x00F1456C+2775612]
# 	GetHandleVerifier [0x00D051E0+616112]
# 	(No symbol) [0x00C15F8C]
# 	(No symbol) [0x00C12328]
# 	(No symbol) [0x00C1240B]
# 	(No symbol) [0x00C04FF7]
# 	BaseThreadInitThunk [0x75CD00C9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77307B1E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77307AEE+238]
#
# 13 pages left!
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="pnnext"]"}
#   (Session info: chrome=115.0.5790.110)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x00C7A813+48355]
# 	(No symbol) [0x00C0C4B1]
# 	(No symbol) [0x00B15358]
# 	(No symbol) [0x00B409A5]
# 	(No symbol) [0x00B40B3B]
# 	(No symbol) [0x00B6E232]
# 	(No symbol) [0x00B5A784]
# 	(No symbol) [0x00B6C922]
# 	(No symbol) [0x00B5A536]
# 	(No symbol) [0x00B382DC]
# 	(No symbol) [0x00B393DD]
# 	GetHandleVerifier [0x00EDAABD+2539405]
# 	GetHandleVerifier [0x00F1A78F+2800735]
# 	GetHandleVerifier [0x00F1456C+2775612]
# 	GetHandleVerifier [0x00D051E0+616112]
# 	(No symbol) [0x00C15F8C]
# 	(No symbol) [0x00C12328]
# 	(No symbol) [0x00C1240B]
# 	(No symbol) [0x00C04FF7]
# 	BaseThreadInitThunk [0x75CD00C9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77307B1E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77307AEE+238]
#
# 12 pages left!
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="pnnext"]"}
#   (Session info: chrome=115.0.5790.110)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x00C7A813+48355]
# 	(No symbol) [0x00C0C4B1]
# 	(No symbol) [0x00B15358]
# 	(No symbol) [0x00B409A5]
# 	(No symbol) [0x00B40B3B]
# 	(No symbol) [0x00B6E232]
# 	(No symbol) [0x00B5A784]
# 	(No symbol) [0x00B6C922]
# 	(No symbol) [0x00B5A536]
# 	(No symbol) [0x00B382DC]
# 	(No symbol) [0x00B393DD]
# 	GetHandleVerifier [0x00EDAABD+2539405]
# 	GetHandleVerifier [0x00F1A78F+2800735]
# 	GetHandleVerifier [0x00F1456C+2775612]
# 	GetHandleVerifier [0x00D051E0+616112]
# 	(No symbol) [0x00C15F8C]
# 	(No symbol) [0x00C12328]
# 	(No symbol) [0x00C1240B]
# 	(No symbol) [0x00C04FF7]
# 	BaseThreadInitThunk [0x75CD00C9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77307B1E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77307AEE+238]
#
# 11 pages left!
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="pnnext"]"}
#   (Session info: chrome=115.0.5790.110)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x00C7A813+48355]
# 	(No symbol) [0x00C0C4B1]
# 	(No symbol) [0x00B15358]
# 	(No symbol) [0x00B409A5]
# 	(No symbol) [0x00B40B3B]
# 	(No symbol) [0x00B6E232]
# 	(No symbol) [0x00B5A784]
# 	(No symbol) [0x00B6C922]
# 	(No symbol) [0x00B5A536]
# 	(No symbol) [0x00B382DC]
# 	(No symbol) [0x00B393DD]
# 	GetHandleVerifier [0x00EDAABD+2539405]
# 	GetHandleVerifier [0x00F1A78F+2800735]
# 	GetHandleVerifier [0x00F1456C+2775612]
# 	GetHandleVerifier [0x00D051E0+616112]
# 	(No symbol) [0x00C15F8C]
# 	(No symbol) [0x00C12328]
# 	(No symbol) [0x00C1240B]
# 	(No symbol) [0x00C04FF7]
# 	BaseThreadInitThunk [0x75CD00C9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77307B1E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77307AEE+238]
#
# 10 pages left!
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="pnnext"]"}
#   (Session info: chrome=115.0.5790.110)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x00C7A813+48355]
# 	(No symbol) [0x00C0C4B1]
# 	(No symbol) [0x00B15358]
# 	(No symbol) [0x00B409A5]
# 	(No symbol) [0x00B40B3B]
# 	(No symbol) [0x00B6E232]
# 	(No symbol) [0x00B5A784]
# 	(No symbol) [0x00B6C922]
# 	(No symbol) [0x00B5A536]
# 	(No symbol) [0x00B382DC]
# 	(No symbol) [0x00B393DD]
# 	GetHandleVerifier [0x00EDAABD+2539405]
# 	GetHandleVerifier [0x00F1A78F+2800735]
# 	GetHandleVerifier [0x00F1456C+2775612]
# 	GetHandleVerifier [0x00D051E0+616112]
# 	(No symbol) [0x00C15F8C]
# 	(No symbol) [0x00C12328]
# 	(No symbol) [0x00C1240B]
# 	(No symbol) [0x00C04FF7]
# 	BaseThreadInitThunk [0x75CD00C9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77307B1E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77307AEE+238]
#
# 9 pages left!
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="pnnext"]"}
#   (Session info: chrome=115.0.5790.110)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x00C7A813+48355]
# 	(No symbol) [0x00C0C4B1]
# 	(No symbol) [0x00B15358]
# 	(No symbol) [0x00B409A5]
# 	(No symbol) [0x00B40B3B]
# 	(No symbol) [0x00B6E232]
# 	(No symbol) [0x00B5A784]
# 	(No symbol) [0x00B6C922]
# 	(No symbol) [0x00B5A536]
# 	(No symbol) [0x00B382DC]
# 	(No symbol) [0x00B393DD]
# 	GetHandleVerifier [0x00EDAABD+2539405]
# 	GetHandleVerifier [0x00F1A78F+2800735]
# 	GetHandleVerifier [0x00F1456C+2775612]
# 	GetHandleVerifier [0x00D051E0+616112]
# 	(No symbol) [0x00C15F8C]
# 	(No symbol) [0x00C12328]
# 	(No symbol) [0x00C1240B]
# 	(No symbol) [0x00C04FF7]
# 	BaseThreadInitThunk [0x75CD00C9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77307B1E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77307AEE+238]
#
# 8 pages left!
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="pnnext"]"}
#   (Session info: chrome=115.0.5790.110)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x00C7A813+48355]
# 	(No symbol) [0x00C0C4B1]
# 	(No symbol) [0x00B15358]
# 	(No symbol) [0x00B409A5]
# 	(No symbol) [0x00B40B3B]
# 	(No symbol) [0x00B6E232]
# 	(No symbol) [0x00B5A784]
# 	(No symbol) [0x00B6C922]
# 	(No symbol) [0x00B5A536]
# 	(No symbol) [0x00B382DC]
# 	(No symbol) [0x00B393DD]
# 	GetHandleVerifier [0x00EDAABD+2539405]
# 	GetHandleVerifier [0x00F1A78F+2800735]
# 	GetHandleVerifier [0x00F1456C+2775612]
# 	GetHandleVerifier [0x00D051E0+616112]
# 	(No symbol) [0x00C15F8C]
# 	(No symbol) [0x00C12328]
# 	(No symbol) [0x00C1240B]
# 	(No symbol) [0x00C04FF7]
# 	BaseThreadInitThunk [0x75CD00C9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77307B1E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77307AEE+238]
#
# 7 pages left!
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="pnnext"]"}
#   (Session info: chrome=115.0.5790.110)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x00C7A813+48355]
# 	(No symbol) [0x00C0C4B1]
# 	(No symbol) [0x00B15358]
# 	(No symbol) [0x00B409A5]
# 	(No symbol) [0x00B40B3B]
# 	(No symbol) [0x00B6E232]
# 	(No symbol) [0x00B5A784]
# 	(No symbol) [0x00B6C922]
# 	(No symbol) [0x00B5A536]
# 	(No symbol) [0x00B382DC]
# 	(No symbol) [0x00B393DD]
# 	GetHandleVerifier [0x00EDAABD+2539405]
# 	GetHandleVerifier [0x00F1A78F+2800735]
# 	GetHandleVerifier [0x00F1456C+2775612]
# 	GetHandleVerifier [0x00D051E0+616112]
# 	(No symbol) [0x00C15F8C]
# 	(No symbol) [0x00C12328]
# 	(No symbol) [0x00C1240B]
# 	(No symbol) [0x00C04FF7]
# 	BaseThreadInitThunk [0x75CD00C9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77307B1E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77307AEE+238]
#
# 6 pages left!
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="pnnext"]"}
#   (Session info: chrome=115.0.5790.110)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x00C7A813+48355]
# 	(No symbol) [0x00C0C4B1]
# 	(No symbol) [0x00B15358]
# 	(No symbol) [0x00B409A5]
# 	(No symbol) [0x00B40B3B]
# 	(No symbol) [0x00B6E232]
# 	(No symbol) [0x00B5A784]
# 	(No symbol) [0x00B6C922]
# 	(No symbol) [0x00B5A536]
# 	(No symbol) [0x00B382DC]
# 	(No symbol) [0x00B393DD]
# 	GetHandleVerifier [0x00EDAABD+2539405]
# 	GetHandleVerifier [0x00F1A78F+2800735]
# 	GetHandleVerifier [0x00F1456C+2775612]
# 	GetHandleVerifier [0x00D051E0+616112]
# 	(No symbol) [0x00C15F8C]
# 	(No symbol) [0x00C12328]
# 	(No symbol) [0x00C1240B]
# 	(No symbol) [0x00C04FF7]
# 	BaseThreadInitThunk [0x75CD00C9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77307B1E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77307AEE+238]
#
# 5 pages left!
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="pnnext"]"}
#   (Session info: chrome=115.0.5790.110)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x00C7A813+48355]
# 	(No symbol) [0x00C0C4B1]
# 	(No symbol) [0x00B15358]
# 	(No symbol) [0x00B409A5]
# 	(No symbol) [0x00B40B3B]
# 	(No symbol) [0x00B6E232]
# 	(No symbol) [0x00B5A784]
# 	(No symbol) [0x00B6C922]
# 	(No symbol) [0x00B5A536]
# 	(No symbol) [0x00B382DC]
# 	(No symbol) [0x00B393DD]
# 	GetHandleVerifier [0x00EDAABD+2539405]
# 	GetHandleVerifier [0x00F1A78F+2800735]
# 	GetHandleVerifier [0x00F1456C+2775612]
# 	GetHandleVerifier [0x00D051E0+616112]
# 	(No symbol) [0x00C15F8C]
# 	(No symbol) [0x00C12328]
# 	(No symbol) [0x00C1240B]
# 	(No symbol) [0x00C04FF7]
# 	BaseThreadInitThunk [0x75CD00C9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77307B1E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77307AEE+238]
#
# 4 pages left!
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="pnnext"]"}
#   (Session info: chrome=115.0.5790.110)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x00C7A813+48355]
# 	(No symbol) [0x00C0C4B1]
# 	(No symbol) [0x00B15358]
# 	(No symbol) [0x00B409A5]
# 	(No symbol) [0x00B40B3B]
# 	(No symbol) [0x00B6E232]
# 	(No symbol) [0x00B5A784]
# 	(No symbol) [0x00B6C922]
# 	(No symbol) [0x00B5A536]
# 	(No symbol) [0x00B382DC]
# 	(No symbol) [0x00B393DD]
# 	GetHandleVerifier [0x00EDAABD+2539405]
# 	GetHandleVerifier [0x00F1A78F+2800735]
# 	GetHandleVerifier [0x00F1456C+2775612]
# 	GetHandleVerifier [0x00D051E0+616112]
# 	(No symbol) [0x00C15F8C]
# 	(No symbol) [0x00C12328]
# 	(No symbol) [0x00C1240B]
# 	(No symbol) [0x00C04FF7]
# 	BaseThreadInitThunk [0x75CD00C9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77307B1E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77307AEE+238]
#
# 3 pages left!
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="pnnext"]"}
#   (Session info: chrome=115.0.5790.110)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x00C7A813+48355]
# 	(No symbol) [0x00C0C4B1]
# 	(No symbol) [0x00B15358]
# 	(No symbol) [0x00B409A5]
# 	(No symbol) [0x00B40B3B]
# 	(No symbol) [0x00B6E232]
# 	(No symbol) [0x00B5A784]
# 	(No symbol) [0x00B6C922]
# 	(No symbol) [0x00B5A536]
# 	(No symbol) [0x00B382DC]
# 	(No symbol) [0x00B393DD]
# 	GetHandleVerifier [0x00EDAABD+2539405]
# 	GetHandleVerifier [0x00F1A78F+2800735]
# 	GetHandleVerifier [0x00F1456C+2775612]
# 	GetHandleVerifier [0x00D051E0+616112]
# 	(No symbol) [0x00C15F8C]
# 	(No symbol) [0x00C12328]
# 	(No symbol) [0x00C1240B]
# 	(No symbol) [0x00C04FF7]
# 	BaseThreadInitThunk [0x75CD00C9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77307B1E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77307AEE+238]
#
# 2 pages left!
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="pnnext"]"}
#   (Session info: chrome=115.0.5790.110)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x00C7A813+48355]
# 	(No symbol) [0x00C0C4B1]
# 	(No symbol) [0x00B15358]
# 	(No symbol) [0x00B409A5]
# 	(No symbol) [0x00B40B3B]
# 	(No symbol) [0x00B6E232]
# 	(No symbol) [0x00B5A784]
# 	(No symbol) [0x00B6C922]
# 	(No symbol) [0x00B5A536]
# 	(No symbol) [0x00B382DC]
# 	(No symbol) [0x00B393DD]
# 	GetHandleVerifier [0x00EDAABD+2539405]
# 	GetHandleVerifier [0x00F1A78F+2800735]
# 	GetHandleVerifier [0x00F1456C+2775612]
# 	GetHandleVerifier [0x00D051E0+616112]
# 	(No symbol) [0x00C15F8C]
# 	(No symbol) [0x00C12328]
# 	(No symbol) [0x00C1240B]
# 	(No symbol) [0x00C04FF7]
# 	BaseThreadInitThunk [0x75CD00C9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77307B1E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77307AEE+238]
#
# 1 pages left!
# I am done ---> 636
# if there is a problem, start with 637
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="pnnext"]"}
#   (Session info: chrome=115.0.5790.110)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x00C7A813+48355]
# 	(No symbol) [0x00C0C4B1]
# 	(No symbol) [0x00B15358]
# 	(No symbol) [0x00B409A5]
# 	(No symbol) [0x00B40B3B]
# 	(No symbol) [0x00B6E232]
# 	(No symbol) [0x00B5A784]
# 	(No symbol) [0x00B6C922]
# 	(No symbol) [0x00B5A536]
# 	(No symbol) [0x00B382DC]
# 	(No symbol) [0x00B393DD]
# 	GetHandleVerifier [0x00EDAABD+2539405]
# 	GetHandleVerifier [0x00F1A78F+2800735]
# 	GetHandleVerifier [0x00F1456C+2775612]
# 	GetHandleVerifier [0x00D051E0+616112]
# 	(No symbol) [0x00C15F8C]
# 	(No symbol) [0x00C12328]
# 	(No symbol) [0x00C1240B]
# 	(No symbol) [0x00C04FF7]
# 	BaseThreadInitThunk [0x75CD00C9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77307B1E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77307AEE+238]
#
# 30 pages left!
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="pnnext"]"}
#   (Session info: chrome=115.0.5790.110)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x00C7A813+48355]
# 	(No symbol) [0x00C0C4B1]
# 	(No symbol) [0x00B15358]
# 	(No symbol) [0x00B409A5]
# 	(No symbol) [0x00B40B3B]
# 	(No symbol) [0x00B6E232]
# 	(No symbol) [0x00B5A784]
# 	(No symbol) [0x00B6C922]
# 	(No symbol) [0x00B5A536]
# 	(No symbol) [0x00B382DC]
# 	(No symbol) [0x00B393DD]
# 	GetHandleVerifier [0x00EDAABD+2539405]
# 	GetHandleVerifier [0x00F1A78F+2800735]
# 	GetHandleVerifier [0x00F1456C+2775612]
# 	GetHandleVerifier [0x00D051E0+616112]
# 	(No symbol) [0x00C15F8C]
# 	(No symbol) [0x00C12328]
# 	(No symbol) [0x00C1240B]
# 	(No symbol) [0x00C04FF7]
# 	BaseThreadInitThunk [0x75CD00C9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77307B1E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77307AEE+238]
#
# 29 pages left!
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="pnnext"]"}
#   (Session info: chrome=115.0.5790.110)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x00C7A813+48355]
# 	(No symbol) [0x00C0C4B1]
# 	(No symbol) [0x00B15358]
# 	(No symbol) [0x00B409A5]
# 	(No symbol) [0x00B40B3B]
# 	(No symbol) [0x00B6E232]
# 	(No symbol) [0x00B5A784]
# 	(No symbol) [0x00B6C922]
# 	(No symbol) [0x00B5A536]
# 	(No symbol) [0x00B382DC]
# 	(No symbol) [0x00B393DD]
# 	GetHandleVerifier [0x00EDAABD+2539405]
# 	GetHandleVerifier [0x00F1A78F+2800735]
# 	GetHandleVerifier [0x00F1456C+2775612]
# 	GetHandleVerifier [0x00D051E0+616112]
# 	(No symbol) [0x00C15F8C]
# 	(No symbol) [0x00C12328]
# 	(No symbol) [0x00C1240B]
# 	(No symbol) [0x00C04FF7]
# 	BaseThreadInitThunk [0x75CD00C9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77307B1E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77307AEE+238]
#
# 28 pages left!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 147
#     145 time.sleep(5)
#     146 for i in range(1, 11): # google uses paginator, every page has 10 urls
# --> 147     time.sleep(6)
#     148     try:
#     149         elems = driver.find_elements(By.XPATH, '//*[@id="rso"]/div['+str(i)+']/div/div/div[1]/div/a')
#
# KeyboardInterrupt:

# %%
j=622

# %%
df = pd.DataFrame({
    "links":links
})
df = df.drop_duplicates()
df.to_csv(f'datas/linkedin_links_29_06/data{str(j)}.csv', index=False)
print(f'I am done ---> {str(j)}')
print(f'if there is a problem, start with {str(j+1)}')
# Out:
# I am done ---> 631
# if there is a problem, start with 632
