# %%
from bs4 import BeautifulSoup
import time
from selenium.webdriver.chrome.options import Options
from selenium import webdriver
from selenium.webdriver.common.by import By
import pandas as pd

options = Options()
options.add_argument("user-data-dir=C:/Users/dell/AppData/Local/Google/Chrome/User Data/Profile 3")
driver = webdriver.Chrome(options=options,executable_path='C:/Users/dell/OneDrive/Desktop/chromedriver.exe')
driver.get('https://www.crystalknows.com/app/register')
time.sleep(10)

df= pd.read_csv(f'../linkedin_data_Scraping/15000_linkedin_profiles.csv')
df=df[14000:16000]
j=0
for study in range(14000,16000, 100):
    j+=1
    try:
        dots=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/div[1]/nav/div/div/div/div[6]/div/div[1]/div[2]/div/div/div')
        dots.click()
        time.sleep(2)
    except:
        print('dots problem')
    try:
        logout=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/div[1]/nav/div/div/div/div[6]/div/div[2]/div[6]/a')
        logout.click()
        time.sleep(5)
    except:
        print('logout problem')
    try:
        signup=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div[3]/div/form/div[3]/div/a')
        signup.click()
        time.sleep(8)
    except:
        print('signup probelm')
    try:
        first_name_input=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div[2]/div[3]/div[1]/input')
        first_name_input.click()
        first_name_input.send_keys(f'Alibek')
    except Exception as e:
        print('first_name-->problem')
    try:
        last_name_input=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div[2]/div[3]/div[2]/input')
        last_name_input.click()
        last_name_input.send_keys(f'Aliyev')
    except Exception as e:
        print('last_name-->problem')
    try:
        comp_email_input=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div[2]/div[4]/div/input')
        comp_email_input.click()
        comp_email_input.send_keys(f'shoqol3{str(j)+str(study)}@mail.ru')
    except Exception as e:
        print('comp_email-->problem')
    try:
        first_pass_input=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div[2]/div[5]/div[1]/input')
        first_pass_input.click()
        first_pass_input.send_keys('Aa2301667')
    except Exception as e:
        print('first_pass-->problem')
    try:    
        sec_pass_input=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div[2]/div[5]/div[2]/input')
        sec_pass_input.click()
        sec_pass_input.send_keys('Aa2301667')
    except Exception as e:
        print('sec_pass-->problem')
    try:
        agree_button=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div[2]/div[6]/div/label/div/img')
        agree_button.click()
    except Exception as e:
        print('agree_button-->problem')
    try:                                            #/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div/div[6]/button
        signup_button=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div[2]/div[7]/button')
        signup_button.click()
        time.sleep(10)
    except Exception as e:
        print('signup_button-->problem')
    try:
        country_button=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[1]/div[2]/div/div[2]/img')
        country_button.click()
        first_country=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[1]/div[2]/div[2]/div[1]')
        first_country.click()
    except Exception as e:
        print('country_button-->problem')                                # second country    '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[1]/div[2]/div[2]/div[2]'
    try:
        job_title_input=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[2]/div[2]/div/input')
        job_title_input.click()
        job_title_input.send_keys('software engineer')
    except Exception as e:
        print('job_title-->problem')
    try:    
        my_department_input=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[2]/div[4]/div[1]/div[2]/img')
        my_department_input.click()
        first_department=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[2]/div[4]/div[2]/div[6]')                              #  second department           '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[2]/div[3]/div[2]/div[2]'
        first_department.click()
    except Exception as e:
        print('department-->problem')
    try:    
        next_button=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[2]/a')
        next_button.click()
        time.sleep(10)
    except Exception as e:
        print('next_button-->problem')
    i=0
    dict_={}
    st1=0
    for link in df.links[st1:study]:
        print('AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA')
        print(i)
        st1=study
        print(f"ST1{st1}")
        print(f"STUDY1{study}")
        i+=1
        try: 
            link_enterong_button=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/div[1]/nav/div/div[1]/div/div[1]/div/input')
            link_enterong_button.click()
            link_enterong_button.clear()
            link_enterong_button.send_keys(link)
            time.sleep(8) 
        except Exception as e:
            print("linkedin user not found")
        try:                          # /html/body/div[2]/div/div/div[2]/div[1]/nav/div/div[1]/div/div[1]/div/div[2]/div/div/div/div/div[2]
            first_user=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/div[1]/nav/div/div[1]/div/div[1]/div/div[2]/div/div/div/div/div[2]')
            first_user.click()
            time.sleep(10)
            # src = driver.page_source
            # soup = BeautifulSoup(src, 'lxml')
            # cs=soup.find('div', {'class':'styles_disc-pill-wrapper__aB3OJ'})
            # /html/body/div[2]/div/div/div[4]/div[1]/div/div/div[1]/div/span
            dict_[link]=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/div[1]/div/div/div[1]/div/span').text
            print(dict_[link])
        except Exception as e:
            dict_[link]='nan'
        
        # price_butt=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/div[1]/nav/div/div[2]/div/div[1]').text
        # print(price_butt)
        print(f'IIIIIIIIIIII{i}')
        if i%10==0:
            print('Matched!!')
            try:
                dots1=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/div[1]/nav/div/div[1]/div/div[6]/div/div[1]/div[2]/div/div')
                dots1.click()
                print(dots1)
                time.sleep(2)

                logout1=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/div[1]/nav/div/div/div/div[6]/div/div[2]/div[6]/a')
                logout1.click()
                time.sleep(5)
                signup=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div[3]/div/form/div[3]/div/a')
                signup.click()
                time.sleep(8)

                first_name_input=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div[2]/div[3]/div[1]/input')
                # first_name_input.click()                        /html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div[2]/div[4]/div/input
                first_name_input.send_keys(f'Abror+{str(i)}')
            
                last_name_input=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div[2]/div[3]/div[2]/input')
                last_name_input.click()
                last_name_input.send_keys(f'Aliyev{str(i)}')
                comp_email_input_for_10=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div[2]/div[4]/div/input')
                comp_email_input_for_10.click()
                comp_email_input_for_10.send_keys(f'mark3{str(study//i)}{str(i)}@mail.ru')
            
                first_pass_input=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div[2]/div[5]/div[1]/input')
                first_pass_input.click()
                first_pass_input.send_keys('12345678')
                
                sec_pass_input=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div[2]/div[5]/div[2]/input')
                sec_pass_input.click()
                sec_pass_input.send_keys('12345678')
            
                agree_button1=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div[2]/div[6]/div/label/div/img')
                agree_button1.click()
        
                signup_button1=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div[2]/div[7]/button')
                signup_button1.click()
                time.sleep(10)
            
                country_button=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[1]/div[2]/div/div[2]/img')
                country_button.click()

                first_country=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[1]/div[2]/div[2]/div[4]')
                first_country.click()
            except Exception as e:
                print('i is divisible 10-->problem')                                # second country    '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[1]/div[2]/div[2]/div[2]'
            try:
                job_title_input=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[2]/div[2]/div/input')
                job_title_input.click()
                job_title_input.send_keys('software engineer')
            except Exception as e:
                print('job_title-->problem')
            try:    
                my_department_input=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[2]/div[4]/div/div[2]/img')
                my_department_input.click()
                first_department=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[2]/div[4]/div[2]/div[4]')
                first_department.click()
            except Exception as e:
                print('department-->problem')
            try:    
                next_button=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[2]/a')
                next_button.click()
                time.sleep(10)
            except Exception as e:
                print('next_button-->problem')
        if len(dict_)%100==0:
            df1 = pd.DataFrame({
            'links':list(dict_.keys()),
            'characters':list(dict_.values())
            })
            x = len(dict_)//100
            df1.to_csv(f'datas/cs_values_new/extra_data/data_till_16000{x}.csv', index=False)
    df1 = pd.DataFrame({
    'links':list(dict_.keys()),
    'characters':list(dict_.values())
    })
    df1.to_csv(f'datas/cs_values_new/data_till_16000{study}.csv', index=False)
    print(list(dict_.values())[-10:])
    print(f'{study} is done!')
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_1764\1418088416.py:10: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(options=options,executable_path='C:/Users/dell/OneDrive/Desktop/chromedriver.exe')
# dots problem
# logout problem
# signup probelm
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 0
# ST114000
# STUDY114000
# Encourager (Is)
# IIIIIIIIIIII1
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 1
# ST114000
# STUDY114000
# Counselor (Si)
# IIIIIIIIIIII2
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 2
# ST114000
# STUDY114000
# Counselor (Si)
# IIIIIIIIIIII3
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 3
# ST114000
# STUDY114000
# Counselor (Si)
# IIIIIIIIIIII4
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 4
# ST114000
# STUDY114000
# Counselor (Si)
# IIIIIIIIIIII5
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 5
# ST114000
# STUDY114000
# Harmonizer (IS)
# IIIIIIIIIIII6
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 6
# ST114000
# STUDY114000
# Supporter (S)
# IIIIIIIIIIII7
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 7
# ST114000
# STUDY114000
# Supporter (S)
# IIIIIIIIIIII8
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 8
# ST114000
# STUDY114000
# Supporter (S)
# IIIIIIIIIIII9
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 9
# ST114000
# STUDY114000
# Supporter (S)
# IIIIIIIIIIII10
# Matched!!
# <selenium.webdriver.remote.webelement.WebElement (session="6e8d165d5c31728ebea4ecd188b30898", element="4D5D187736DF15C485BEC3703C3936EE_element_149")>
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 10
# ST114000
# STUDY114000
# Counselor (Si)
# IIIIIIIIIIII11
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 11
# ST114000
# STUDY114000
# Harmonizer (IS)
# IIIIIIIIIIII12
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 12
# ST114000
# STUDY114000
# Supporter (S)
# IIIIIIIIIIII13
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 13
# ST114000
# STUDY114000
# Supporter (S)
# IIIIIIIIIIII14
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 14
# ST114000
# STUDY114000
# IIIIIIIIIIII15
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 15
# ST114000
# STUDY114000
# Influencer (Id)
# IIIIIIIIIIII16
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 16
# ST114000
# STUDY114000
# Motivator (I)
# IIIIIIIIIIII17
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 17
# ST114000
# STUDY114000
# Supporter (S)
# IIIIIIIIIIII18
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 18
# ST114000
# STUDY114000
# Influencer (Id)
# IIIIIIIIIIII19
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 19
# ST114000
# STUDY114000
# Counselor (Si)
# IIIIIIIIIIII20
# Matched!!
# <selenium.webdriver.remote.webelement.WebElement (session="6e8d165d5c31728ebea4ecd188b30898", element="512E3D4DA43260E613C59213880C37D8_element_348")>
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 20
# ST114000
# STUDY114000
# Supporter (S)
# IIIIIIIIIIII21
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 21
# ST114000
# STUDY114000
# IIIIIIIIIIII22
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 22
# ST114000
# STUDY114000
# IIIIIIIIIIII23
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 23
# ST114000
# STUDY114000
# Harmonizer (IS)
# IIIIIIIIIIII24
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 24
# ST114000
# STUDY114000
# Planner (Sc)
# IIIIIIIIIIII25
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 25
# ST114000
# STUDY114000
# Harmonizer (IS)
# IIIIIIIIIIII26
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 26
# ST114000
# STUDY114000
# Harmonizer (IS)
# IIIIIIIIIIII27
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 27
# ST114000
# STUDY114000
# Supporter (S)
# IIIIIIIIIIII28
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 28
# ST114000
# STUDY114000
# Counselor (Si)
# IIIIIIIIIIII29
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 29
# ST114000
# STUDY114000
# Harmonizer (IS)
# IIIIIIIIIIII30
# Matched!!
# <selenium.webdriver.remote.webelement.WebElement (session="6e8d165d5c31728ebea4ecd188b30898", element="A729387FA3C2DE76A9130EBA58D53EB6_element_489")>
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 30
# ST114000
# STUDY114000
# Counselor (Si)
# IIIIIIIIIIII31
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 31
# ST114000
# STUDY114000
# IIIIIIIIIIII32
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 32
# ST114000
# STUDY114000
# Counselor (Si)
# IIIIIIIIIIII33
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 33
# ST114000
# STUDY114000
# Supporter (S)
# IIIIIIIIIIII34
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 34
# ST114000
# STUDY114000
# Harmonizer (IS)
# IIIIIIIIIIII35
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 35
# ST114000
# STUDY114000
# Harmonizer (IS)
# IIIIIIIIIIII36
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 36
# ST114000
# STUDY114000
# Motivator (I)
# IIIIIIIIIIII37
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 37
# ST114000
# STUDY114000
# Counselor (Si)
# IIIIIIIIIIII38
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 38
# ST114000
# STUDY114000
# IIIIIIIIIIII39
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 39
# ST114000
# STUDY114000
# Counselor (Si)
# IIIIIIIIIIII40
# Matched!!
# <selenium.webdriver.remote.webelement.WebElement (session="6e8d165d5c31728ebea4ecd188b30898", element="CD52058FAA0AB15F04121632D6D2B65B_element_624")>
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 40
# ST114000
# STUDY114000
# Editor (Cs)
# IIIIIIIIIIII41
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 41
# ST114000
# STUDY114000
# Counselor (Si)
# IIIIIIIIIIII42
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 42
# ST114000
# STUDY114000
# Encourager (Is)
# IIIIIIIIIIII43
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 43
# ST114000
# STUDY114000
# Influencer (Id)
# IIIIIIIIIIII44
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 44
# ST114000
# STUDY114000
# Counselor (Si)
# IIIIIIIIIIII45
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 45
# ST114000
# STUDY114000
# Counselor (Si)
# IIIIIIIIIIII46
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 46
# ST114000
# STUDY114000
# Counselor (Si)
# IIIIIIIIIIII47
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 47
# ST114000
# STUDY114000
# Encourager (Is)
# IIIIIIIIIIII48
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 48
# ST114000
# STUDY114000
# IIIIIIIIIIII49
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 49
# ST114000
# STUDY114000
# Stabilizer (SC)
# IIIIIIIIIIII50
# Matched!!
# <selenium.webdriver.remote.webelement.WebElement (session="6e8d165d5c31728ebea4ecd188b30898", element="27F3F373A487F4F2BE7717BD11578640_element_754")>
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 50
# ST114000
# STUDY114000
# Supporter (S)
# IIIIIIIIIIII51
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 51
# ST114000
# STUDY114000
# Harmonizer (IS)
# IIIIIIIIIIII52
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 52
# ST114000
# STUDY114000
# Harmonizer (IS)
# IIIIIIIIIIII53
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 53
# ST114000
# STUDY114000
# Supporter (S)
# IIIIIIIIIIII54
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 54
# ST114000
# STUDY114000
# Supporter (S)
# IIIIIIIIIIII55
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 55
# ST114000
# STUDY114000
# Counselor (Si)
# IIIIIIIIIIII56
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 56
# ST114000
# STUDY114000
# Harmonizer (IS)
# IIIIIIIIIIII57
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 57
# ST114000
# STUDY114000
# Motivator (I)
# IIIIIIIIIIII58
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 58
# ST114000
# STUDY114000
# Supporter (S)
# IIIIIIIIIIII59
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 59
# ST114000
# STUDY114000
# IIIIIIIIIIII60
# Matched!!
# <selenium.webdriver.remote.webelement.WebElement (session="6e8d165d5c31728ebea4ecd188b30898", element="2EE71916CBD7FDB9C03430DEEC0CA201_element_884")>
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 60
# ST114000
# STUDY114000
#
# IIIIIIIIIIII61
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 61
# ST114000
# STUDY114000
# IIIIIIIIIIII62
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 62
# ST114000
# STUDY114000
#
# IIIIIIIIIIII63
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 63
# ST114000
# STUDY114000
# IIIIIIIIIIII64
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 64
# ST114000
# STUDY114000
#
# IIIIIIIIIIII65
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 65
# ST114000
# STUDY114000
#
# IIIIIIIIIIII66
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 66
# ST114000
# STUDY114000
#
# IIIIIIIIIIII67
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 67
# ST114000
# STUDY114000
#
# IIIIIIIIIIII68
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 68
# ST114000
# STUDY114000
#
# IIIIIIIIIIII69
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 69
# ST114000
# STUDY114000
#
# IIIIIIIIIIII70
# Matched!!
# <selenium.webdriver.remote.webelement.WebElement (session="6e8d165d5c31728ebea4ecd188b30898", element="A0B1FB5081270921033DBDB4895EAEB3_element_961")>
# i is divisible 10-->problem
# job_title-->problem
# department-->problem
# next_button-->problem
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 70
# ST114000
# STUDY114000
#
# IIIIIIIIIIII71
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 71
# ST114000
# STUDY114000
#
# IIIIIIIIIIII72
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 72
# ST114000
# STUDY114000
# IIIIIIIIIIII73
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 73
# ST114000
# STUDY114000
# IIIIIIIIIIII74
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 74
# ST114000
# STUDY114000
# IIIIIIIIIIII75
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 75
# ST114000
# STUDY114000
# IIIIIIIIIIII76
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 76
# ST114000
# STUDY114000
# IIIIIIIIIIII77
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 77
# ST114000
# STUDY114000
# IIIIIIIIIIII78
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 78
# ST114000
# STUDY114000
# IIIIIIIIIIII79
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 79
# ST114000
# STUDY114000
# IIIIIIIIIIII80
# Matched!!
# <selenium.webdriver.remote.webelement.WebElement (session="6e8d165d5c31728ebea4ecd188b30898", element="A0B1FB5081270921033DBDB4895EAEB3_element_973")>
# i is divisible 10-->problem
# job_title-->problem
# department-->problem
# next_button-->problem
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 80
# ST114000
# STUDY114000
# IIIIIIIIIIII81
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 81
# ST114000
# STUDY114000
# IIIIIIIIIIII82
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 82
# ST114000
# STUDY114000
# IIIIIIIIIIII83
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 83
# ST114000
# STUDY114000
# IIIIIIIIIIII84
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 84
# ST114000
# STUDY114000
# IIIIIIIIIIII85
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 85
# ST114000
# STUDY114000
# IIIIIIIIIIII86
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 86
# ST114000
# STUDY114000
# IIIIIIIIIIII87
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 87
# ST114000
# STUDY114000
# IIIIIIIIIIII88
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 88
# ST114000
# STUDY114000
# IIIIIIIIIIII89
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 89
# ST114000
# STUDY114000
# IIIIIIIIIIII90
# Matched!!
# <selenium.webdriver.remote.webelement.WebElement (session="6e8d165d5c31728ebea4ecd188b30898", element="A0B1FB5081270921033DBDB4895EAEB3_element_973")>
# i is divisible 10-->problem
# job_title-->problem
# department-->problem
# next_button-->problem
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 90
# ST114000
# STUDY114000
# IIIIIIIIIIII91
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 91
# ST114000
# STUDY114000
# IIIIIIIIIIII92
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 92
# ST114000
# STUDY114000
# IIIIIIIIIIII93
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 93
# ST114000
# STUDY114000
# IIIIIIIIIIII94
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 94
# ST114000
# STUDY114000
# IIIIIIIIIIII95
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 95
# ST114000
# STUDY114000
# IIIIIIIIIIII96
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 96
# ST114000
# STUDY114000
# IIIIIIIIIIII97
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 97
# ST114000
# STUDY114000
# IIIIIIIIIIII98
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 98
# ST114000
# STUDY114000
# IIIIIIIIIIII99
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 99
# ST114000
# STUDY114000
# IIIIIIIIIIII100
# Matched!!
# <selenium.webdriver.remote.webelement.WebElement (session="6e8d165d5c31728ebea4ecd188b30898", element="A0B1FB5081270921033DBDB4895EAEB3_element_973")>
# i is divisible 10-->problem
# job_title-->problem
# department-->problem
# next_button-->problem
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[2], line 210
#     205         df1 = pd.DataFrame({
#     206         'links':list(dict_.keys()),
#     207         'characters':list(dict_.values())
#     208         })
#     209         x = len(dict_)//100
# --> 210         df1.to_csv(f'datas/cs_values_new/extra_data/data_till_16000{x}.csv', index=False)
#     211 df1 = pd.DataFrame({
#     212 'links':list(dict_.keys()),
#     213 'characters':list(dict_.values())
#     214 })
#     215 df1.to_csv(f'datas/cs_values_new/data_till_16000{study}.csv', index=False)
#
# File c:\Users\dell\OneDrive\Desktop\selenium\Bots_using_selenium\venv\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File c:\Users\dell\OneDrive\Desktop\selenium\Bots_using_selenium\venv\lib\site-packages\pandas\core\generic.py:3720, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3709 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3711 formatter = DataFrameFormatter(
#    3712     frame=df,
#    3713     header=header,
#    (...)
#    3717     decimal=decimal,
#    3718 )
# -> 3720 return DataFrameRenderer(formatter).to_csv(
#    3721     path_or_buf,
#    3722     lineterminator=lineterminator,
#    3723     sep=sep,
#    3724     encoding=encoding,
#    3725     errors=errors,
#    3726     compression=compression,
#    3727     quoting=quoting,
#    3728     columns=columns,
#    3729     index_label=index_label,
#    3730     mode=mode,
#    3731     chunksize=chunksize,
#    3732     quotechar=quotechar,
#    3733     date_format=date_format,
#    3734     doublequote=doublequote,
#    3735     escapechar=escapechar,
#    3736     storage_options=storage_options,
#    3737 )
#
# File c:\Users\dell\OneDrive\Desktop\selenium\Bots_using_selenium\venv\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File c:\Users\dell\OneDrive\Desktop\selenium\Bots_using_selenium\venv\lib\site-packages\pandas\io\formats\format.py:1189, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1168     created_buffer = False
#    1170 csv_formatter = CSVFormatter(
#    1171     path_or_buf=path_or_buf,
#    1172     lineterminator=lineterminator,
#    (...)
#    1187     formatter=self.fmt,
#    1188 )
# -> 1189 csv_formatter.save()
#    1191 if created_buffer:
#    1192     assert isinstance(path_or_buf, StringIO)
#
# File c:\Users\dell\OneDrive\Desktop\selenium\Bots_using_selenium\venv\lib\site-packages\pandas\io\formats\csvs.py:241, in CSVFormatter.save(self)
#     237 """
#     238 Create the writer & save.
#     239 """
#     240 # apply compression and byte/text conversion
# --> 241 with get_handle(
#     242     self.filepath_or_buffer,
#     243     self.mode,
#     244     encoding=self.encoding,
#     245     errors=self.errors,
#     246     compression=self.compression,
#     247     storage_options=self.storage_options,
#     248 ) as handles:
#     249
#     250     # Note: self.encoding is irrelevant here
#     251     self.writer = csvlib.writer(
#     252         handles.handle,
#     253         lineterminator=self.lineterminator,
#    (...)
#     258         quotechar=self.quotechar,
#     259     )
#     261     self._save()
#
# File c:\Users\dell\OneDrive\Desktop\selenium\Bots_using_selenium\venv\lib\site-packages\pandas\io\common.py:734, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     732 # Only for write methods
#     733 if "r" not in mode and is_path:
# --> 734     check_parent_directory(str(handle))
#     736 if compression:
#     737     if compression != "zstd":
#     738         # compression libraries do not like an explicit text-mode
#
# File c:\Users\dell\OneDrive\Desktop\selenium\Bots_using_selenium\venv\lib\site-packages\pandas\io\common.py:597, in check_parent_directory(path)
#     595 parent = Path(path).parent
#     596 if not parent.is_dir():
# --> 597     raise OSError(rf"Cannot save file into a non-existent directory: '{parent}'")
#
# OSError: Cannot save file into a non-existent directory: 'datas\cs_values_new\extra_data'
