# %%
from bs4 import BeautifulSoup
import time
from selenium.webdriver.chrome.options import Options
from selenium import webdriver
from selenium.webdriver.common.by import By
import pandas as pd

options = Options()
options.add_argument("user-data-dir=C:/Users/dell/AppData/Local/Google/Chrome/User Data/Profile 4")
driver = webdriver.Chrome(options=options,executable_path='C:/Users/dell/OneDrive/Desktop/chromedriver.exe')
driver.get('https://www.crystalknows.com/app/register')
time.sleep(10)

df= pd.read_csv(f'../linkedin_data_Scraping/15000_linkedin_profiles.csv')
df=df[16000:18000]
j=0
for study in range(16000,18000, 100):
    j+=1
    try:
        dots=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/div[1]/nav/div/div/div/div[6]/div/div[1]/div[2]/div/div/div')
        dots.click()
        time.sleep(2)
    except:
        print('dots problem')
    try:
        logout=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/div[1]/nav/div/div/div/div[6]/div/div[2]/div[6]/a')
        logout.click()
        time.sleep(5)
    except:
        print('logout problem')
    try:
        signup=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div[3]/div/form/div[3]/div/a')
        signup.click()
        time.sleep(8)
    except:
        print('signup probelm')
    try:
        first_name_input=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div[2]/div[3]/div[1]/input')
        first_name_input.click()
        first_name_input.send_keys(f'Alibek')
    except Exception as e:
        print('first_name-->problem')
    try:
        last_name_input=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div[2]/div[3]/div[2]/input')
        last_name_input.click()
        last_name_input.send_keys(f'Aliyev')
    except Exception as e:
        print('last_name-->problem')
    try:
        comp_email_input=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div[2]/div[4]/div/input')
        comp_email_input.click()
        comp_email_input.send_keys(f'shoqol4{str(j)+str(study)}@mail.ru')
    except Exception as e:
        print('comp_email-->problem')
    try:
        first_pass_input=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div[2]/div[5]/div[1]/input')
        first_pass_input.click()
        first_pass_input.send_keys('Aa2301667')
    except Exception as e:
        print('first_pass-->problem')
    try:    
        sec_pass_input=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div[2]/div[5]/div[2]/input')
        sec_pass_input.click()
        sec_pass_input.send_keys('Aa2301667')
    except Exception as e:
        print('sec_pass-->problem')
    try:
        agree_button=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div[2]/div[6]/div/label/div/img')
        agree_button.click()
    except Exception as e:
        print('agree_button-->problem')
    try:                                            #/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div/div[6]/button
        signup_button=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div[2]/div[7]/button')
        signup_button.click()
        time.sleep(10)
    except Exception as e:
        print('signup_button-->problem')
    try:
        country_button=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[1]/div[2]/div/div[2]/img')
        country_button.click()
        first_country=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[1]/div[2]/div[2]/div[1]')
        first_country.click()
    except Exception as e:
        print('country_button-->problem')                                # second country    '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[1]/div[2]/div[2]/div[2]'
    try:
        job_title_input=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[2]/div[2]/div/input')
        job_title_input.click()
        job_title_input.send_keys('software engineer')
    except Exception as e:
        print('job_title-->problem')
    try:    
        my_department_input=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[2]/div[4]/div[1]/div[2]/img')
        my_department_input.click()
        first_department=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[2]/div[4]/div[2]/div[6]')                              #  second department           '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[2]/div[3]/div[2]/div[2]'
        first_department.click()
    except Exception as e:
        print('department-->problem')
    try:    
        next_button=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[2]/a')
        next_button.click()
        time.sleep(10)
    except Exception as e:
        print('next_button-->problem')
    i=0
    dict_={}
    st1=0
    for link in df.links[st1:study]:
        print('AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA')
        print(i)
        st1=study
        print(f"ST1{st1}")
        print(f"STUDY1{study}")
        i+=1
        try: 
            link_enterong_button=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/div[1]/nav/div/div[1]/div/div[1]/div/input')
            link_enterong_button.click()
            link_enterong_button.clear()
            link_enterong_button.send_keys(link)
            time.sleep(8) 
        except Exception as e:
            print("linkedin user not found")
        try:                          # /html/body/div[2]/div/div/div[2]/div[1]/nav/div/div[1]/div/div[1]/div/div[2]/div/div/div/div/div[2]
            first_user=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/div[1]/nav/div/div[1]/div/div[1]/div/div[2]/div/div/div/div/div[2]')
            first_user.click()
            time.sleep(10)
            # src = driver.page_source
            # soup = BeautifulSoup(src, 'lxml')
            # cs=soup.find('div', {'class':'styles_disc-pill-wrapper__aB3OJ'})
            # /html/body/div[2]/div/div/div[4]/div[1]/div/div/div[1]/div/span
            dict_[link]=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/div[1]/div/div/div[1]/div/span').text
            print(dict_[link])
        except Exception as e:
            dict_[link]='nan'
        
        # price_butt=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/div[1]/nav/div/div[2]/div/div[1]').text
        # print(price_butt)
        print(f'IIIIIIIIIIII{i}')
        if i%10==0:
            print('Matched!!')
            try:
                dots1=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/div[1]/nav/div/div[1]/div/div[6]/div/div[1]/div[2]/div/div')
                dots1.click()
                print(dots1)
                time.sleep(2)

                logout1=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/div[1]/nav/div/div/div/div[6]/div/div[2]/div[6]/a')
                logout1.click()
                time.sleep(5)
                signup=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div[3]/div/form/div[3]/div/a')
                signup.click()
                time.sleep(8)

                first_name_input=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div[2]/div[3]/div[1]/input')
                # first_name_input.click()                        /html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div[2]/div[4]/div/input
                first_name_input.send_keys(f'Abror+{str(i)}')
            
                last_name_input=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div[2]/div[3]/div[2]/input')
                last_name_input.click()
                last_name_input.send_keys(f'Aliyev{str(i)}')
                comp_email_input_for_10=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div[2]/div[4]/div/input')
                comp_email_input_for_10.click()
                comp_email_input_for_10.send_keys(f'mark4{str(study//i)}{str(i)}@mail.ru')
            
                first_pass_input=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div[2]/div[5]/div[1]/input')
                first_pass_input.click()
                first_pass_input.send_keys('12345678')
                
                sec_pass_input=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div[2]/div[5]/div[2]/input')
                sec_pass_input.click()
                sec_pass_input.send_keys('12345678')
            
                agree_button1=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div[2]/div[6]/div/label/div/img')
                agree_button1.click()
        
                signup_button1=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div[2]/div[7]/button')
                signup_button1.click()
                time.sleep(10)
            
                country_button=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[1]/div[2]/div/div[2]/img')
                country_button.click()

                first_country=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[1]/div[2]/div[2]/div[4]')
                first_country.click()
            except Exception as e:
                print('i is divisible 10-->problem')                                # second country    '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[1]/div[2]/div[2]/div[2]'
            try:
                job_title_input=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[2]/div[2]/div/input')
                job_title_input.click()
                job_title_input.send_keys('software engineer')
            except Exception as e:
                print('job_title-->problem')
            try:    
                my_department_input=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[2]/div[4]/div/div[2]/img')
                my_department_input.click()
                first_department=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[2]/div[4]/div[2]/div[4]')
                first_department.click()
            except Exception as e:
                print('department-->problem')
            try:    
                next_button=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[2]/a')
                next_button.click()
                time.sleep(10)
            except Exception as e:
                print('next_button-->problem')
        if len(dict_)%100==0:
            df1 = pd.DataFrame({
            'links':list(dict_.keys()),
            'characters':list(dict_.values())
            })
            x = len(dict_)//100
            df1.to_csv(f'datas/cs_values_new/extra_data/data_till_18000{x}.csv', index=False)
    df1 = pd.DataFrame({
    'links':list(dict_.keys()),
    'characters':list(dict_.values())
    })
    df1.to_csv(f'datas/cs_values_new/data_till_18000{study}.csv', index=False)
    print(list(dict_.values())[-10:])
    print(f'{study} is done!')
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_15472\1208803486.py:10: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(options=options,executable_path='C:/Users/dell/OneDrive/Desktop/chromedriver.exe')
# dots problem
# logout problem
# signup probelm
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 0
# ST116000
# STUDY116000
# Encourager (Is)
# IIIIIIIIIIII1
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 1
# ST116000
# STUDY116000
# Counselor (Si)
# IIIIIIIIIIII2
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 2
# ST116000
# STUDY116000
# Counselor (Si)
# IIIIIIIIIIII3
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 3
# ST116000
# STUDY116000
# Counselor (Si)
# IIIIIIIIIIII4
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 4
# ST116000
# STUDY116000
# Counselor (Si)
# IIIIIIIIIIII5
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 5
# ST116000
# STUDY116000
# Harmonizer (IS)
# IIIIIIIIIIII6
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 6
# ST116000
# STUDY116000
# Supporter (S)
# IIIIIIIIIIII7
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 7
# ST116000
# STUDY116000
# Supporter (S)
# IIIIIIIIIIII8
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 8
# ST116000
# STUDY116000
# Supporter (S)
# IIIIIIIIIIII9
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 9
# ST116000
# STUDY116000
# Supporter (S)
# IIIIIIIIIIII10
# Matched!!
# <selenium.webdriver.remote.webelement.WebElement (session="ebb734c415ad4a2c6bd5e22fed9a506f", element="242A73C6DC82C8AA46BF6B6C517BF7C7_element_190")>
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 10
# ST116000
# STUDY116000
# Counselor (Si)
# IIIIIIIIIIII11
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 11
# ST116000
# STUDY116000
# Harmonizer (IS)
# IIIIIIIIIIII12
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 12
# ST116000
# STUDY116000
# Supporter (S)
# IIIIIIIIIIII13
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 13
# ST116000
# STUDY116000
# Supporter (S)
# IIIIIIIIIIII14
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 14
# ST116000
# STUDY116000
# IIIIIIIIIIII15
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 15
# ST116000
# STUDY116000
# Influencer (Id)
# IIIIIIIIIIII16
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 16
# ST116000
# STUDY116000
# Motivator (I)
# IIIIIIIIIIII17
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 17
# ST116000
# STUDY116000
# Supporter (S)
# IIIIIIIIIIII18
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 18
# ST116000
# STUDY116000
# Influencer (Id)
# IIIIIIIIIIII19
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 19
# ST116000
# STUDY116000
# Counselor (Si)
# IIIIIIIIIIII20
# Matched!!
# <selenium.webdriver.remote.webelement.WebElement (session="ebb734c415ad4a2c6bd5e22fed9a506f", element="740DF23AC2AD85EF84B746CA8BDDF92A_element_400")>
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 20
# ST116000
# STUDY116000
# Supporter (S)
# IIIIIIIIIIII21
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 21
# ST116000
# STUDY116000
# IIIIIIIIIIII22
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 22
# ST116000
# STUDY116000
# IIIIIIIIIIII23
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 23
# ST116000
# STUDY116000
# Harmonizer (IS)
# IIIIIIIIIIII24
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 24
# ST116000
# STUDY116000
# Planner (Sc)
# IIIIIIIIIIII25
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 25
# ST116000
# STUDY116000
# Harmonizer (IS)
# IIIIIIIIIIII26
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 26
# ST116000
# STUDY116000
# Harmonizer (IS)
# IIIIIIIIIIII27
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 27
# ST116000
# STUDY116000
# Supporter (S)
# IIIIIIIIIIII28
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 28
# ST116000
# STUDY116000
# Counselor (Si)
# IIIIIIIIIIII29
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 29
# ST116000
# STUDY116000
# Harmonizer (IS)
# IIIIIIIIIIII30
# Matched!!
# <selenium.webdriver.remote.webelement.WebElement (session="ebb734c415ad4a2c6bd5e22fed9a506f", element="CA4739CD1024A7BDD022A28F71401332_element_575")>
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 30
# ST116000
# STUDY116000
# Counselor (Si)
# IIIIIIIIIIII31
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 31
# ST116000
# STUDY116000
# IIIIIIIIIIII32
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 32
# ST116000
# STUDY116000
# Counselor (Si)
# IIIIIIIIIIII33
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 33
# ST116000
# STUDY116000
# Supporter (S)
# IIIIIIIIIIII34
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 34
# ST116000
# STUDY116000
# Harmonizer (IS)
# IIIIIIIIIIII35
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 35
# ST116000
# STUDY116000
# Harmonizer (IS)
# IIIIIIIIIIII36
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 36
# ST116000
# STUDY116000
# Motivator (I)
# IIIIIIIIIIII37
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 37
# ST116000
# STUDY116000
# Counselor (Si)
# IIIIIIIIIIII38
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 38
# ST116000
# STUDY116000
# IIIIIIIIIIII39
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 39
# ST116000
# STUDY116000
# Counselor (Si)
# IIIIIIIIIIII40
# Matched!!
# <selenium.webdriver.remote.webelement.WebElement (session="ebb734c415ad4a2c6bd5e22fed9a506f", element="5D63AA0A884DA2504F7E3C688A3D6C0D_element_739")>
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 40
# ST116000
# STUDY116000
# Editor (Cs)
# IIIIIIIIIIII41
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 41
# ST116000
# STUDY116000
# IIIIIIIIIIII42
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 42
# ST116000
# STUDY116000
# IIIIIIIIIIII43
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 43
# ST116000
# STUDY116000
# IIIIIIIIIIII44
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 44
# ST116000
# STUDY116000
#
# IIIIIIIIIIII45
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 45
# ST116000
# STUDY116000
#
# IIIIIIIIIIII46
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 46
# ST116000
# STUDY116000
#
# IIIIIIIIIIII47
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 47
# ST116000
# STUDY116000
# IIIIIIIIIIII48
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 48
# ST116000
# STUDY116000
# IIIIIIIIIIII49
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 49
# ST116000
# STUDY116000
#
# IIIIIIIIIIII50
# Matched!!
# <selenium.webdriver.remote.webelement.WebElement (session="ebb734c415ad4a2c6bd5e22fed9a506f", element="749C6631C2A2B37F4EA2CAE20C6A3E3B_element_816")>
# i is divisible 10-->problem
# job_title-->problem
# department-->problem
# next_button-->problem
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 50
# ST116000
# STUDY116000
#
# IIIIIIIIIIII51
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 51
# ST116000
# STUDY116000
#
# IIIIIIIIIIII52
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 52
# ST116000
# STUDY116000
#
# IIIIIIIIIIII53
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 53
# ST116000
# STUDY116000
#
# IIIIIIIIIIII54
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 54
# ST116000
# STUDY116000
# IIIIIIIIIIII55
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 55
# ST116000
# STUDY116000
# IIIIIIIIIIII56
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 56
# ST116000
# STUDY116000
# IIIIIIIIIIII57
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 57
# ST116000
# STUDY116000
# IIIIIIIIIIII58
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 58
# ST116000
# STUDY116000
# IIIIIIIIIIII59
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 59
# ST116000
# STUDY116000
# IIIIIIIIIIII60
# Matched!!
# <selenium.webdriver.remote.webelement.WebElement (session="ebb734c415ad4a2c6bd5e22fed9a506f", element="749C6631C2A2B37F4EA2CAE20C6A3E3B_element_855")>
# i is divisible 10-->problem
# job_title-->problem
# department-->problem
# next_button-->problem
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 60
# ST116000
# STUDY116000
# IIIIIIIIIIII61
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 61
# ST116000
# STUDY116000
# IIIIIIIIIIII62
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 62
# ST116000
# STUDY116000
# IIIIIIIIIIII63
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 63
# ST116000
# STUDY116000
# IIIIIIIIIIII64
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 64
# ST116000
# STUDY116000
# IIIIIIIIIIII65
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 65
# ST116000
# STUDY116000
# IIIIIIIIIIII66
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 66
# ST116000
# STUDY116000
# IIIIIIIIIIII67
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 67
# ST116000
# STUDY116000
# IIIIIIIIIIII68
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 68
# ST116000
# STUDY116000
# IIIIIIIIIIII69
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 69
# ST116000
# STUDY116000
# IIIIIIIIIIII70
# Matched!!
# <selenium.webdriver.remote.webelement.WebElement (session="ebb734c415ad4a2c6bd5e22fed9a506f", element="749C6631C2A2B37F4EA2CAE20C6A3E3B_element_855")>
# i is divisible 10-->problem
# job_title-->problem
# department-->problem
# next_button-->problem
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 70
# ST116000
# STUDY116000
# IIIIIIIIIIII71
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 71
# ST116000
# STUDY116000
# IIIIIIIIIIII72
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 72
# ST116000
# STUDY116000
# IIIIIIIIIIII73
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 73
# ST116000
# STUDY116000
# IIIIIIIIIIII74
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 74
# ST116000
# STUDY116000
# IIIIIIIIIIII75
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 75
# ST116000
# STUDY116000
# IIIIIIIIIIII76
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 76
# ST116000
# STUDY116000
# IIIIIIIIIIII77
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 77
# ST116000
# STUDY116000
# IIIIIIIIIIII78
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 78
# ST116000
# STUDY116000
# IIIIIIIIIIII79
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 79
# ST116000
# STUDY116000
# IIIIIIIIIIII80
# Matched!!
# <selenium.webdriver.remote.webelement.WebElement (session="ebb734c415ad4a2c6bd5e22fed9a506f", element="749C6631C2A2B37F4EA2CAE20C6A3E3B_element_855")>
# i is divisible 10-->problem
# job_title-->problem
# department-->problem
# next_button-->problem
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 80
# ST116000
# STUDY116000
# IIIIIIIIIIII81
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 81
# ST116000
# STUDY116000
# IIIIIIIIIIII82
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 82
# ST116000
# STUDY116000
# IIIIIIIIIIII83
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 83
# ST116000
# STUDY116000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 117
#     115     link_enterong_button.click()
#     116     link_enterong_button.clear()
# --> 117     link_enterong_button.send_keys(link)
#     118     time.sleep(8)
#     119 except Exception as e:
#
# File c:\Users\dell\OneDrive\Desktop\selenium\Bots_using_selenium\venv\lib\site-packages\selenium\webdriver\remote\webelement.py:230, in WebElement.send_keys(self, *value)
#     227             remote_files.append(self._upload(file))
#     228         value = "\n".join(remote_files)
# --> 230 self._execute(
#     231     Command.SEND_KEYS_TO_ELEMENT, {"text": "".join(keys_to_typing(value)), "value": keys_to_typing(value)}
#     232 )
#
# File c:\Users\dell\OneDrive\Desktop\selenium\Bots_using_selenium\venv\lib\site-packages\selenium\webdriver\remote\webelement.py:403, in WebElement._execute(self, command, params)
#     401     params = {}
#     402 params["id"] = self._id
# --> 403 return self._parent.execute(command, params)
#
# File c:\Users\dell\OneDrive\Desktop\selenium\Bots_using_selenium\venv\lib\site-packages\selenium\webdriver\remote\webdriver.py:438, in WebDriver.execute(self, driver_command, params)
#     435     elif "sessionId" not in params:
#     436         params["sessionId"] = self.session_id
# --> 438 response = self.command_executor.execute(driver_command, params)
#     439 if response:
#     440     self.error_handler.check_response(response)
#
# File c:\Users\dell\OneDrive\Desktop\selenium\Bots_using_selenium\venv\lib\site-packages\selenium\webdriver\remote\remote_connection.py:290, in RemoteConnection.execute(self, command, params)
#     288 data = utils.dump_json(params)
#     289 url = f"{self._url}{path}"
# --> 290 return self._request(command_info[0], url, body=data)
#
# File c:\Users\dell\OneDrive\Desktop\selenium\Bots_using_selenium\venv\lib\site-packages\selenium\webdriver\remote\remote_connection.py:311, in RemoteConnection._request(self, method, url, body)
#     308     body = None
#     310 if self.keep_alive:
# --> 311     response = self._conn.request(method, url, body=body, headers=headers)
#     312     statuscode = response.status
#     313 else:
#
# File c:\Users\dell\OneDrive\Desktop\selenium\Bots_using_selenium\venv\lib\site-packages\urllib3\request.py:78, in RequestMethods.request(self, method, url, fields, headers, **urlopen_kw)
#      74     return self.request_encode_url(
#      75         method, url, fields=fields, headers=headers, **urlopen_kw
#      76     )
#      77 else:
# ---> 78     return self.request_encode_body(
#      79         method, url, fields=fields, headers=headers, **urlopen_kw
#      80     )
#
# File c:\Users\dell\OneDrive\Desktop\selenium\Bots_using_selenium\venv\lib\site-packages\urllib3\request.py:170, in RequestMethods.request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     167 extra_kw["headers"].update(headers)
#     168 extra_kw.update(urlopen_kw)
# --> 170 return self.urlopen(method, url, **extra_kw)
#
# File c:\Users\dell\OneDrive\Desktop\selenium\Bots_using_selenium\venv\lib\site-packages\urllib3\poolmanager.py:376, in PoolManager.urlopen(self, method, url, redirect, **kw)
#     374     response = conn.urlopen(method, url, **kw)
#     375 else:
# --> 376     response = conn.urlopen(method, u.request_uri, **kw)
#     378 redirect_location = redirect and response.get_redirect_location()
#     379 if not redirect_location:
#
# File c:\Users\dell\OneDrive\Desktop\selenium\Bots_using_selenium\venv\lib\site-packages\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File c:\Users\dell\OneDrive\Desktop\selenium\Bots_using_selenium\venv\lib\site-packages\urllib3\connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444             httplib_response = conn.getresponse()
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File c:\Users\dell\OneDrive\Desktop\selenium\Bots_using_selenium\venv\lib\site-packages\urllib3\connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     441 except TypeError:
#     442     # Python 3
#     443     try:
# --> 444         httplib_response = conn.getresponse()
#     445     except BaseException as e:
#     446         # Remove the TypeError from the exception chain in
#     447         # Python 3 (including for exceptions like SystemExit).
#     448         # Otherwise it looks like a bug in the code.
#     449         six.raise_from(e, None)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\http\client.py:1374, in HTTPConnection.getresponse(self)
#    1372 try:
#    1373     try:
# -> 1374         response.begin()
#    1375     except ConnectionError:
#    1376         self.close()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\http\client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File ~\AppData\Local\Programs\Python\Python310\lib\http\client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File ~\AppData\Local\Programs\Python\Python310\lib\socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# KeyboardInterrupt:
