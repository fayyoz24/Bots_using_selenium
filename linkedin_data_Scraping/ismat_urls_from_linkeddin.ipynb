# %%
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from selenium import webdriver
import time
import pandas as pd
from bs4 import BeautifulSoup
options = Options()
options.add_argument("user-data-dir=C:/Users/dell/AppData/Local/Google/Chrome/User Data/Profile 2")
                                                        #C:\Users\fayyo\Downloads\chromedriver-win32.zip\chromedriver-win32
driver = webdriver.Chrome(options=options,executable_path='C:/Users/dell/OneDrive/Desktop/chromedriver-win64/chromedriver.exe')
# country names
list_items = [  
    "Chrisoupoli",
    "Pangaea",
    "Doxato",
    "Eleftheroupoli",
    "Kos",
    "Kefalos",
    "Antimacheia",
    "Irakleides",
    "Kalymnos",
    "Leros",
    "Agathonisi",
    "Kalymnos",
    "Leipsoi",
    "Arkalochori",
    "Karteros",
    "Malia",
    "Heraklion",
    "Gazi",
    "Chersonissos",
    "Anissaras",
    "Matala",
    "Ierapetra",
    "Sitia",
    "Neapoli",
    "Agios Nikolaos",
    "Elounda",
    "Hersonissos",
    "Sissi",
    "Aghios Nikolaos",
    "Agios Nikolaos",
    "Agia Pelagia",
    "Fodele",
    "Kokkini Hani",
    "Gournes",
    "Hersonissos",
    "Malia",
    "Stalida",
    "Ano Viannos",
    "Tsoutsouras",
    "Ierapetra",
    "Goudouras",
    "Makry Gialos",
    "Koutsouras",
    "Gra Ligia",
    "Sitia",
    "Kionia",
    "Chora",
    "Mesi",
    "Karystos",
    "Marmari",
    "Nea Styra",
    "Kymi",
    "Aliveri",
    "Nea Artaki",
    "Kymi",
    "Koroni",
    "Filiates",
    "Arta",
    "Amfilochia",
    "Vonitsa",
    "Parga",
    "Ammoudia",
    "Perdika",
    "Sivota",
    "Kastrosykia",
    "Kanali",
    "Preveza",
    "Lefkada",
    "Agios Nikitas",
    "Nydri",
    "Vassiliki",
    "Sivros",
    "Lefkada",
    "Karya",
    "Kalamitsi",
    "Syvota",
    "Arta",
    "Megalopolis",
    "Gargalianoi",
    "Pylos",
    "Filiatra",
    "Chora",
    "Gytheio",
    "Areopoli",
    "Gerolimenas",
    "Kotronas",
    "Oitylo",
    "Stoupa",
]
for item  in list_items[:]:
    links = [] # save links here
    for study in ['math', 'physics']:
        driver.get(f'https://www.google.com/search?q=site:nl.linkedin.com/in/+AND+%22{item}+AND+%22{study}')
        time.sleep(5) # to make slower 
        n=30
        while n > 0:
            time.sleep(5)
            print("here")
            initialScroll = 0
            finalScroll = 1000
            start = time.time()
            while True:
                driver.execute_script(f"window.scrollTo({initialScroll}, {finalScroll})")
                initialScroll = finalScroll
                finalScroll += 1000
                time.sleep(3)
                end = time.time()
                if round(end - start) > 25:
                    break
            src = driver.page_source
            soup = BeautifulSoup(src, 'lxml')
            linksed_links=soup.find_all("a", {"jsname":"UWckNb"})
            for i in linksed_links:
                links.append(i.get('href').split("?")[0])
            try:
                next_button = driver.find_element(By.XPATH, '//*[@id="pnnext"]') # clicking next button 
                next_button.click()
            except Exception as e:
                driver.get(f'https://www.google.com/search?q=site:nl.linkedin.com/in/+AND+%22{item}+AND+%22{study}')
                n=1
                # print("")
            # print(f'{n} pages left!')
            n -= 1
        df = pd.DataFrame({
            "links":links
        })
        df1=pd.read_csv('datas/Ismatulla_links/data_Ismatulla4.csv')
        df_sum=pd.concat([df1, df], axis=0, ignore_index=True)
        df_sum = df_sum.drop_duplicates()
        df_sum.to_csv(f'datas/Ismatulla_links/data_Ismatulla4.csv', index=False)
        print(f'I am done ---> {item}')
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_14648\4182796927.py:10: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(options=options,executable_path='C:/Users/dell/OneDrive/Desktop/chromedriver-win64/chromedriver.exe')
# here
# I am done ---> Athens
# here
# I am done ---> Athens
# here
# I am done ---> Thessaloniki
# here
# I am done ---> Thessaloniki
# here
# I am done ---> Patras
# here
# I am done ---> Patras
# here
# I am done ---> Heraklion
# here
# I am done ---> Heraklion
# here
# I am done ---> Larissa
# here
# I am done ---> Larissa
# here
# I am done ---> Volos
# here
# I am done ---> Volos
# here
# I am done ---> Ioannina
# here
# I am done ---> Ioannina
# here
# I am done ---> Chania
# here
# I am done ---> Chania
# here
# I am done ---> Chalcis
# here
# I am done ---> Chalcis
# here
# I am done ---> Heraklion
# here
# I am done ---> Heraklion
# here
# I am done ---> Katerini
# here
# I am done ---> Katerini
# here
# I am done ---> Trikala
# here
# I am done ---> Trikala
# here
# I am done ---> Lamia
# here
# I am done ---> Lamia
# here
# I am done ---> Serres
# here
# I am done ---> Serres
# here
# I am done ---> Rhodes
# here
# I am done ---> Rhodes
# here
# I am done ---> Komotini
# here
# I am done ---> Komotini
# here
# I am done ---> Kavala
# here
# I am done ---> Kavala
# here
# I am done ---> Alexandroupoli
# here
# I am done ---> Alexandroupoli
# here
# I am done ---> Kalamata
# here
# I am done ---> Kalamata
# here
# I am done ---> Kozani
# here
# I am done ---> Kozani
# here
# I am done ---> Veria
# here
# I am done ---> Veria
# here
# I am done ---> Preveza
# here
# I am done ---> Preveza
# here
# I am done ---> Sparti
# here
# I am done ---> Sparti
# here
# I am done ---> Mytilene
# here
# I am done ---> Mytilene
# here
# I am done ---> Lamia
# here
# I am done ---> Lamia
# here
# I am done ---> Rethymno
# here
# I am done ---> Rethymno
# here
# I am done ---> Chalkida
# here
# I am done ---> Chalkida
# here
# I am done ---> Chios
# here
# I am done ---> Chios
# here
# I am done ---> Pyrgos
# here
# I am done ---> Pyrgos
# here
# I am done ---> Drama
# here
# I am done ---> Drama
# here
# I am done ---> Karditsa
# here
# I am done ---> Karditsa
# here
# I am done ---> Tripoli
# here
# I am done ---> Tripoli
# here
# I am done ---> Giannitsa
# here
# I am done ---> Giannitsa
# here
# I am done ---> Tinos
# here
# I am done ---> Tinos
# here
# I am done ---> Syros
# here
# I am done ---> Syros
# here
# I am done ---> Agrinio
# here
# I am done ---> Agrinio
# here
# I am done ---> Megara
# here
# I am done ---> Megara
# here
# I am done ---> Kilkis
# here
# I am done ---> Kilkis
# here
# I am done ---> Amfissa
# here
# I am done ---> Amfissa
# here
# I am done ---> Kalambaka
# here
# I am done ---> Kalambaka
# here
# I am done ---> Edessa
# here
# I am done ---> Edessa
# here
# I am done ---> Korinthos
# here
# I am done ---> Korinthos
# here
# I am done ---> Kastoria
# here
# I am done ---> Kastoria
# here
# I am done ---> Orestiada
# here
# I am done ---> Orestiada
# here
# I am done ---> Grevena
# here
# I am done ---> Grevena
# here
# I am done ---> Xanthi
# here
# I am done ---> Xanthi
# here
# I am done ---> Nafplio
# here
# I am done ---> Nafplio
# here
# I am done ---> Argos
# here
# I am done ---> Argos
# here
# I am done ---> Kos
# here
# I am done ---> Kos
# here
# I am done ---> Kefalonia
# here
# I am done ---> Kefalonia
# here
# I am done ---> Zakynthos
# here
# I am done ---> Zakynthos
# here
# I am done ---> Lefkada
# here
# I am done ---> Lefkada
# here
# I am done ---> Kavala
# here
# I am done ---> Kavala
# here
# I am done ---> Samos
# here
# I am done ---> Samos
# here
# I am done ---> Thasos
# here
# I am done ---> Thasos
# here
# I am done ---> Naxos
# here
# I am done ---> Naxos
# here
# I am done ---> Andros
# here
# I am done ---> Andros
# here
# I am done ---> Karpathos
# here
# I am done ---> Karpathos
# here
# I am done ---> Rodos
# here
# I am done ---> Rodos
# here
# I am done ---> Skiathos
# here
# I am done ---> Skiathos
# here
# I am done ---> Paros
# here
# I am done ---> Paros
# here
# I am done ---> Milos
# here
# I am done ---> Milos
# here
# I am done ---> Leros
# here
# I am done ---> Leros
# here
# I am done ---> Kalymnos
# here
# I am done ---> Kalymnos
# here
# I am done ---> Chios
# here
# I am done ---> Chios
# here
# I am done ---> Ikaria
# here
# I am done ---> Ikaria
# here
# I am done ---> Kos
# here
# I am done ---> Kos
# here
# I am done ---> Hydra
# here
# I am done ---> Hydra
# here
# I am done ---> Poros
# here
# I am done ---> Poros
# here
# I am done ---> Spetses
# here
# I am done ---> Spetses
# here
# I am done ---> Aegina
# here
# I am done ---> Aegina
# here
# I am done ---> Agios Nikolaos
# here
# I am done ---> Agios Nikolaos
# here
# I am done ---> Malia
# here
# I am done ---> Malia
# here
# I am done ---> Hersonissos
# here
# I am done ---> Hersonissos
# here
# I am done ---> Kardamena
# here
# I am done ---> Kardamena
# here
# I am done ---> Paleochora
# here
# I am done ---> Paleochora
# here
# I am done ---> Sitia
# here
# I am done ---> Sitia
# here
# I am done ---> Ierapetra
# here
# I am done ---> Ierapetra
# here
# I am done ---> Fira
# here
# I am done ---> Fira
# here
# I am done ---> Kamari
# here
# I am done ---> Kamari
# here
# I am done ---> Oia
# here
# I am done ---> Oia
# here
# I am done ---> Akrotiri
# here
# I am done ---> Akrotiri
# here
# I am done ---> Pylos
# here
# I am done ---> Pylos
# here
# I am done ---> Kalamata
# here
# I am done ---> Kalamata
# here
# I am done ---> Gytheio
# here
# I am done ---> Gytheio
# here
# I am done ---> Stoupa
# here
# I am done ---> Stoupa
# here
# I am done ---> Kardamyli
# here
# I am done ---> Kardamyli
# here
# I am done ---> Kyparissia
# here
# I am done ---> Kyparissia
# here
# I am done ---> Zakynthos
# here
# I am done ---> Zakynthos
# here
# I am done ---> Laganas
# here
# I am done ---> Laganas
# here
# I am done ---> Keri
# here
# I am done ---> Keri
# here
# I am done ---> Alykes
# here
# I am done ---> Alykes
# here
# I am done ---> Tsilivi
# here
# I am done ---> Tsilivi
# here
# I am done ---> Argostoli
# here
# I am done ---> Argostoli
# here
# I am done ---> Lixouri
# here
# I am done ---> Lixouri
# here
# I am done ---> Fiskardo
# here
# I am done ---> Fiskardo
# here
# I am done ---> Ermioni
# here
# I am done ---> Ermioni
# here
# I am done ---> Porto Heli
# here
# I am done ---> Porto Heli
# here
# I am done ---> Kranidi
# here
# I am done ---> Kranidi
# here
# I am done ---> Leonidio
# here
# I am done ---> Leonidio
# here
# I am done ---> Neapoli
# here
# I am done ---> Neapoli
# here
# I am done ---> Neos Marmaras
# here
# I am done ---> Neos Marmaras
# here
# I am done ---> Ormos Panagias
# here
# I am done ---> Ormos Panagias
# here
# I am done ---> Kallithea
# here
# I am done ---> Kallithea
# here
# I am done ---> Afytos
# here
# I am done ---> Afytos
# here
# I am done ---> Poligiros
# here
# I am done ---> Poligiros
# here
# I am done ---> Nikiti
# here
# I am done ---> Nikiti
# here
# I am done ---> Ouranoupolis
# here
# I am done ---> Ouranoupolis
# here
# I am done ---> Amfipoli
# here
# I am done ---> Amfipoli
# here
# I am done ---> Serres
# here
# I am done ---> Serres
# here
# I am done ---> Arnaia
# here
# I am done ---> Arnaia
# here
# I am done ---> Nea Moudania
# here
# I am done ---> Nea Moudania
# here
# I am done ---> Litochoro
# here
# I am done ---> Litochoro
# here
# I am done ---> Paralia Katerinis
# here
# I am done ---> Paralia Katerinis
# here
# I am done ---> Olympiaki Akti
# here
# I am done ---> Olympiaki Akti
# here
# I am done ---> Agios Dimitrios
# here
# I am done ---> Agios Dimitrios
# here
# I am done ---> Asprovalta
# here
# I am done ---> Asprovalta
# here
# I am done ---> Stavros
# here
# I am done ---> Stavros
# here
# I am done ---> Olympiada
# here
# I am done ---> Olympiada
# here
# I am done ---> Kavala
# here
# I am done ---> Kavala
# here
# I am done ---> Nea Peramos
# here
# I am done ---> Nea Peramos
# here
# I am done ---> Drama
# here
# I am done ---> Drama
# here
# I am done ---> Prosotsani
# here
# I am done ---> Prosotsani
# here
# I am done ---> Karditsa
# here
# I am done ---> Karditsa
# here
# I am done ---> Mouzaki
# here
# I am done ---> Mouzaki
# here
# I am done ---> Metsovo
# here
# I am done ---> Metsovo
# here
# I am done ---> Trikala
# here
# I am done ---> Trikala
# here
# I am done ---> Kalampaka
# here
# I am done ---> Kalampaka
# here
# I am done ---> Grevena
# here
# I am done ---> Grevena
# here
# I am done ---> Nigrita
# here
# I am done ---> Nigrita
# here
# I am done ---> Arnea
# here
# I am done ---> Arnea
# here
# I am done ---> Stavroupoli
# here
# I am done ---> Stavroupoli
# here
# I am done ---> Thermi
# here
# I am done ---> Thermi
# here
# I am done ---> Pylaia
# here
# I am done ---> Pylaia
# here
# I am done ---> Kallithea
# here
# I am done ---> Kallithea
# here
# I am done ---> Nea Kallikratia
# here
# I am done ---> Nea Kallikratia
# here
# I am done ---> Aristotelis
# here
# I am done ---> Aristotelis
# here
# I am done ---> Ierissos
# here
# I am done ---> Ierissos
# here
# I am done ---> Stratonikeia
# here
# I am done ---> Stratonikeia
# here
# I am done ---> Xanthi
# here
# I am done ---> Xanthi
# here
# I am done ---> Kimonos
# here
# I am done ---> Kimonos
# here
# I am done ---> Orestiada
# here
# I am done ---> Orestiada
# here
# I am done ---> Nea Vyssa
# here
# I am done ---> Nea Vyssa
# here
# I am done ---> Didymoteicho
# here
# I am done ---> Didymoteicho
# here
# I am done ---> Alexandroupoli
# here
# I am done ---> Alexandroupoli
# here
# I am done ---> Sapes
# here
# I am done ---> Sapes
# here
# I am done ---> Feres
# here
# I am done ---> Feres
# here
# I am done ---> Tychero
# here
# I am done ---> Tychero
# here
# I am done ---> Komotini
# here
# I am done ---> Komotini
# here
# I am done ---> Maronia
# here
# I am done ---> Maronia
# here
# I am done ---> Nestos
# here
# I am done ---> Nestos
# here
# I am done ---> Soufli
# here
# I am done ---> Soufli
# here
# I am done ---> Samothrace
# here
# I am done ---> Samothrace
# here
# I am done ---> Thasos
# here
# I am done ---> Thasos
# here
# I am done ---> Kavala
# here
# I am done ---> Kavala
# here
# I am done ---> Chrysoupoli
# here
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# Cell In[13], line 271
#     269 start = time.time()
#     270 while True:
# --> 271     driver.execute_script(f"window.scrollTo({initialScroll}, {finalScroll})")
#     272     initialScroll = finalScroll
#     273     finalScroll += 1000
#
# File c:\Users\dell\OneDrive\Desktop\selenium\Bots_using_selenium\venv\lib\site-packages\selenium\webdriver\remote\webdriver.py:500, in WebDriver.execute_script(self, script, *args)
#     497 converted_args = list(args)
#     498 command = Command.W3C_EXECUTE_SCRIPT
# --> 500 return self.execute(command, {"script": script, "args": converted_args})["value"]
#
# File c:\Users\dell\OneDrive\Desktop\selenium\Bots_using_selenium\venv\lib\site-packages\selenium\webdriver\remote\webdriver.py:440, in WebDriver.execute(self, driver_command, params)
#     438 response = self.command_executor.execute(driver_command, params)
#     439 if response:
# --> 440     self.error_handler.check_response(response)
#     441     response["value"] = self._unwrap_value(response.get("value", None))
#     442     return response
#
# File c:\Users\dell\OneDrive\Desktop\selenium\Bots_using_selenium\venv\lib\site-packages\selenium\webdriver\remote\errorhandler.py:245, in ErrorHandler.check_response(self, response)
#     243         alert_text = value["alert"].get("text")
#     244     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 245 raise exception_class(message, screen, stacktrace)
#
# WebDriverException: Message: disconnected: not connected to DevTools
#   (failed to check if window was closed: disconnected: not connected to DevTools)
#   (Session info: chrome=116.0.5845.180)
# Stacktrace:
# 	GetHandleVerifier [0x00007FF79E2552A2+57122]
# 	(No symbol) [0x00007FF79E1CEA92]
# 	(No symbol) [0x00007FF79E09E3AB]
# 	(No symbol) [0x00007FF79E08BA47]
# 	(No symbol) [0x00007FF79E08B6C0]
# 	(No symbol) [0x00007FF79E09FA71]
# 	(No symbol) [0x00007FF79E10E27F]
# 	(No symbol) [0x00007FF79E0F6DB3]
# 	(No symbol) [0x00007FF79E0CD2B1]
# 	(No symbol) [0x00007FF79E0CE494]
# 	GetHandleVerifier [0x00007FF79E4FEF82+2849794]
# 	GetHandleVerifier [0x00007FF79E551D24+3189156]
# 	GetHandleVerifier [0x00007FF79E54ACAF+3160367]
# 	GetHandleVerifier [0x00007FF79E2E6D06+653702]
# 	(No symbol) [0x00007FF79E1DA208]
# 	(No symbol) [0x00007FF79E1D62C4]
# 	(No symbol) [0x00007FF79E1D63F6]
# 	(No symbol) [0x00007FF79E1C67A3]
# 	BaseThreadInitThunk [0x00007FFE3C5C7614+20]
# 	RtlUserThreadStart [0x00007FFE3CA626B1+33]

# %%
df = pd.DataFrame({
    "links":links
})
df1=pd.read_csv('datas/Fayyoz_links/data_Fayyoz.csv')
# df = df.drop_duplicates()
df_sum=pd.concat([df1, df], axis=0, ignore_index=True)
df_sum = df_sum.drop_duplicates()
df_sum.to_csv(f'datas/Fayyoz_links/data_Fayyoz.csv', index=False)
print(f'I am done ---> {item}')
# Out:
# I am done ---> Algeria

# %%
links
# Out:
# []
