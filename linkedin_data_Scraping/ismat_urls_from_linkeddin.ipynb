# %%
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from selenium import webdriver
import time
import pandas as pd
from bs4 import BeautifulSoup
options = Options()
options.add_argument("user-data-dir=C:/Users/dell/AppData/Local/Google/Chrome/User Data/Profile 2")
                                                        #C:\Users\fayyo\Downloads\chromedriver-win32.zip\chromedriver-win32
driver = webdriver.Chrome(options=options,executable_path='C:/Users/dell/OneDrive/Desktop/chromedriver-win64/chromedriver.exe')
# country names
list_items = [
    "Montpellier",
    "Bordeaux",
    "Lille",
    "Rennes",
    "Reims",
    "Le Havre",
    "Cergy-Pontoise",
    "Saint-Étienne",
    "Toulon",
    "Angers",
    "Grenoble",
    "Dijon",
    "Nîmes",
    "Aix-en-Provence",
    "Saint-Quentin-en-Yvelines",
    "Brest",
    "Le Mans",
    "Amiens",
    "Tours",
    "Limoges",
    "Clermont-Ferrand",
    "Villeurbanne",
    "Besançon",
    "Orléans",
    "Metz",
    "Rouen",
    "Mulhouse",
    "Perpignan",
    "Caen",
    "Boulogne-Billancourt",
    "Nancy",
    "Argenteuil",
    "Montreuil",
    "Roubaix",
    "Tourcoing",
    "Avignon",
    "Nanterre",
    "Vitry-sur-Seine",
    "Créteil",
    "Dunkerque",
    "Aubervilliers",
    "Versailles",
    "Courbevoie",
    "Cergy",
    "Nîmes",
    "Saint-Denis",
    "La Rochelle",
    "Antibes",
    "Saint-Maur-des-Fossés",
    "Calais",
    "Beauvais",
    "Drancy",
    "Chambery",
    "Saint-Nazaire",
    "Colombes",
    "La Seyne-sur-Mer",
    "Mérignac",
    "Valence",
    "Quimper",
    "Antony",
    "Troyes",
    "Lorient",
    "Sarcelles",
    "Niort",
    "Pessac",
    "Vénissieux",
    "Châteauroux",
    "Clichy",
    "Ivry-sur-Seine",
    "Montauban",
    "Villejuif",
    "Les Abymes",
    "Sartrouville",
    "Evry",
    "Niort",
    "Meaux",
    "Pantin",
    "Chalon-sur-Saône",
    "Saint-Malo",
    "Caluire-et-Cuire",
    "Gagny",
    "Rezé",
    "Le Blanc-Mesnil",
    "Vincennes",
    "Épinay-sur-Seine",
    "Mantes-la-Jolie",
    "Sevran",
    "Albi",
    "Suresnes",
    "Clamart",
    "Grigny",
    "Blois",
    "Clichy-sous-Bois",
    "Bondy",
    "Évreux",
    "Chambéry",
    "Villepinte",
    "Bezons",
    "Gap",
    "Bagneux",
    "Compiègne",
    "Thionville",
    "Trappes",
    "Saint-Herblain",
    "Le Cannet",
    "Saint-Laurent-du-Maroni",
    "Saint-André",
    "Bagnolet",
    "Douai",
    "Rodez",
    "Mamoudzou",
    "Meudon",
    "Pontoise",
    "Châtillon",
    "Livry-Gargan",
    "Saint-Joseph",
    "La Courneuve",
    "Saint-Martin",
    "Colmar",
    "Saint-Priest",
    "Boulogne-sur-Mer",
    "Grasse",
    "Villeneuve-Saint-Georges",
    "Suresnes",
    "Trappes",
    "Alès",
    "Rosny-sous-Bois",
    "Annecy",
    "Le Port",
    "Nevers",
    "Cholet",
    "Montluçon",
    "Clichy-sous-Bois",
    "La Roche-sur-Yon",
    "Salon-de-Provence",
    "Baie-Mahault",
    "Cholet",
    "Agen",
    "Épinal",
    "Bobigny",
    "Talence",
    "Castres",
    "Maisons-Alfort",
    "Saint-Leu",
    "Fréjus",
    "Chartres",
    "Charleville-Mézières",
    "Sarreguemines",
    "Lens",
    "Angoulême",
    "Pessac",
    "Ivry-sur-Seine",
    "Cayenne",
    "Lorient",
    "Garges-lès-Gonesse",
    "Roanne",
    "Thonon-les-Bains",
    "Romainville",
    "Aubagne",
    "Saint-Martin-d'Hères",
    "Saint-Ouen",
    "Périgueux",
    "Chelles",
    "Ajaccio",
    "Rueil-Malmaison",
    "Vannes",
    "Saint-Chamond",
    "Muret",
    "Massy",
    "Gap",
    "Sète",
    "Istres",
    "Haguenau",
    "Le Lamentin",
    "Noisy-le-Grand",
    "Gonesse",
    "Échirolles",
    "Liévin",
    "Anglet",
    "Tarbes",
    "Chartres",
    "Villefranche-sur-Saône",
    "Colomiers",
    "La Ciotat",
    "Angers",
    "Neuilly-sur-Marne",
    "Aix-les-Bains",
    "Chartres",
    "Vierzon",
    "Puteaux",
    "Savigny-sur-Orge",
    "Le Perreux-sur-Marne",
    "Montélimar",
    "Saint-Brieuc",
    "La Courneuve",
    "Le Tampon",
    "Saint-Raphaël",
    "Saint-Louis",
    "Charenton-le-Pont",
    "Villeneuve-sur-Lot",
    "Conflans-Sainte-Honorine",
    "Châtellerault",
    "Pontault-Combault",
    "Roissy-en-Brie",
    "Montgeron",
    "Franconville",
    "Nevers",
    "Creil",
    "Palaiseau",
    "Champs-sur-Marne",
    "Talence",
    "Biarritz",
    "Savigny-le-Temple",
    "Le Cannet",
    "Thionville",
    "Sainte-Geneviève-des-Bois",
    "Saint-Malo",
    "Liévin",
]
for item  in list_items[:]:
    links = [] # save links here
    for study in ['math', 'physics']:
        driver.get(f'https://www.google.com/search?q=site:nl.linkedin.com/in/+AND+%22{item}+AND+%22{study}')
        time.sleep(5) # to make slower 
        n=30
        while n > 0:
            time.sleep(5)
            print("here")
            initialScroll = 0
            finalScroll = 1000
            start = time.time()
            while True:
                driver.execute_script(f"window.scrollTo({initialScroll}, {finalScroll})")
                initialScroll = finalScroll
                finalScroll += 1000
                time.sleep(3)
                end = time.time()
                if round(end - start) > 25:
                    break
            src = driver.page_source
            soup = BeautifulSoup(src, 'lxml')
            linksed_links=soup.find_all("a", {"jsname":"UWckNb"})
            for i in linksed_links:
                links.append(i.get('href').split("?")[0])
            try:
                next_button = driver.find_element(By.XPATH, '//*[@id="pnnext"]') # clicking next button 
                next_button.click()
            except Exception as e:
                driver.get(f'https://www.google.com/search?q=site:nl.linkedin.com/in/+AND+%22{item}+AND+%22{study}')
                n=1
                # print("")
            # print(f'{n} pages left!')
            n -= 1
        df = pd.DataFrame({
            "links":links
        })
        df1=pd.read_csv('datas/Ismatulla_links/data_Ismatulla4.csv')
        df_sum=pd.concat([df1, df], axis=0, ignore_index=True)
        df_sum = df_sum.drop_duplicates()
        df_sum.to_csv(f'datas/Ismatulla_links/data_Ismatulla4.csv', index=False)
        print(f'I am done ---> {item}')
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_13980\1671519440.py:10: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(options=options,executable_path='C:/Users/dell/OneDrive/Desktop/chromedriver-win64/chromedriver.exe')
# here
# I am done ---> Montpellier
# here
# I am done ---> Montpellier
# here
# I am done ---> Bordeaux
# here
# I am done ---> Bordeaux
# here
# I am done ---> Lille
# here
# I am done ---> Lille
# here
# I am done ---> Rennes
# here
# I am done ---> Rennes
# here
# I am done ---> Reims
# here
# I am done ---> Reims
# here
# I am done ---> Le Havre
# here
# I am done ---> Le Havre
# here
# I am done ---> Cergy-Pontoise
# here
# I am done ---> Cergy-Pontoise
# here
# I am done ---> Saint-Étienne
# here
# I am done ---> Saint-Étienne
# here
# I am done ---> Toulon
# here
# I am done ---> Toulon
# here
# I am done ---> Angers
# here
# I am done ---> Angers
# here
# I am done ---> Grenoble
# here
# I am done ---> Grenoble
# here
# I am done ---> Dijon
# here
# I am done ---> Dijon
# here
# I am done ---> Nîmes
# here
# I am done ---> Nîmes
# here
# I am done ---> Aix-en-Provence
# here
# I am done ---> Aix-en-Provence
# here
# I am done ---> Saint-Quentin-en-Yvelines
# here
# I am done ---> Saint-Quentin-en-Yvelines
# here
# I am done ---> Brest
# here
# I am done ---> Brest
# here
# I am done ---> Le Mans
# here
# I am done ---> Le Mans
# here
# I am done ---> Amiens
# here
# I am done ---> Amiens
# here
# I am done ---> Tours
# here
# I am done ---> Tours
# here
# I am done ---> Limoges
# here
# I am done ---> Limoges
# here
# I am done ---> Clermont-Ferrand
# here
# I am done ---> Clermont-Ferrand
# here
# I am done ---> Villeurbanne
# here
# I am done ---> Villeurbanne
# here
# I am done ---> Besançon
# here
# I am done ---> Besançon
# here
# I am done ---> Orléans
# here
# I am done ---> Orléans
# here
# I am done ---> Metz
# here
# I am done ---> Metz
# here
# I am done ---> Rouen
# here
# I am done ---> Rouen
# here
# I am done ---> Mulhouse
# here
# I am done ---> Mulhouse
# here
# I am done ---> Perpignan
# here
# I am done ---> Perpignan
# here
# I am done ---> Caen
# here
# I am done ---> Caen
# here
# I am done ---> Boulogne-Billancourt
# here
# I am done ---> Boulogne-Billancourt
# here
# I am done ---> Nancy
# here
# I am done ---> Nancy
# here
# I am done ---> Argenteuil
# here
# I am done ---> Argenteuil
# here
# I am done ---> Montreuil
# here
# I am done ---> Montreuil
# here
# I am done ---> Roubaix
# here
# I am done ---> Roubaix
# here
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# c:\Users\dell\OneDrive\Desktop\selenium\Bots_using_selenium\linkedin_data_Scraping\ismat_urls_from_linkeddin.ipynb Cell 1 line 2
#     <a href='vscode-notebook-cell:/c%3A/Users/dell/OneDrive/Desktop/selenium/Bots_using_selenium/linkedin_data_Scraping/ismat_urls_from_linkeddin.ipynb#W0sZmlsZQ%3D%3D?line=242'>243</a> start = time.time()
#     <a href='vscode-notebook-cell:/c%3A/Users/dell/OneDrive/Desktop/selenium/Bots_using_selenium/linkedin_data_Scraping/ismat_urls_from_linkeddin.ipynb#W0sZmlsZQ%3D%3D?line=243'>244</a> while True:
# --> <a href='vscode-notebook-cell:/c%3A/Users/dell/OneDrive/Desktop/selenium/Bots_using_selenium/linkedin_data_Scraping/ismat_urls_from_linkeddin.ipynb#W0sZmlsZQ%3D%3D?line=244'>245</a>     driver.execute_script(f"window.scrollTo({initialScroll}, {finalScroll})")
#     <a href='vscode-notebook-cell:/c%3A/Users/dell/OneDrive/Desktop/selenium/Bots_using_selenium/linkedin_data_Scraping/ismat_urls_from_linkeddin.ipynb#W0sZmlsZQ%3D%3D?line=245'>246</a>     initialScroll = finalScroll
#     <a href='vscode-notebook-cell:/c%3A/Users/dell/OneDrive/Desktop/selenium/Bots_using_selenium/linkedin_data_Scraping/ismat_urls_from_linkeddin.ipynb#W0sZmlsZQ%3D%3D?line=246'>247</a>     finalScroll += 1000
#
# File c:\Users\dell\OneDrive\Desktop\selenium\Bots_using_selenium\venv\lib\site-packages\selenium\webdriver\remote\webdriver.py:500, in WebDriver.execute_script(self, script, *args)
#     497 converted_args = list(args)
#     498 command = Command.W3C_EXECUTE_SCRIPT
# --> 500 return self.execute(command, {"script": script, "args": converted_args})["value"]
#
# File c:\Users\dell\OneDrive\Desktop\selenium\Bots_using_selenium\venv\lib\site-packages\selenium\webdriver\remote\webdriver.py:440, in WebDriver.execute(self, driver_command, params)
#     438 response = self.command_executor.execute(driver_command, params)
#     439 if response:
# --> 440     self.error_handler.check_response(response)
#     441     response["value"] = self._unwrap_value(response.get("value", None))
#     442     return response
#
# File c:\Users\dell\OneDrive\Desktop\selenium\Bots_using_selenium\venv\lib\site-packages\selenium\webdriver\remote\errorhandler.py:245, in ErrorHandler.check_response(self, response)
#     243         alert_text = value["alert"].get("text")
#     244     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 245 raise exception_class(message, screen, stacktrace)
#
# NoSuchWindowException: Message: no such window: target window already closed
# from unknown error: web view not found
#   (Session info: chrome=116.0.5845.188)
# Stacktrace:
# 	GetHandleVerifier [0x00007FF7413A52A2+57122]
# 	(No symbol) [0x00007FF74131EA92]
# 	(No symbol) [0x00007FF7411EE3AB]
# 	(No symbol) [0x00007FF7411CE1B9]
# 	(No symbol) [0x00007FF74124B417]
# 	(No symbol) [0x00007FF74125E24F]
# 	(No symbol) [0x00007FF741246DB3]
# 	(No symbol) [0x00007FF74121D2B1]
# 	(No symbol) [0x00007FF74121E494]
# 	GetHandleVerifier [0x00007FF74164EF82+2849794]
# 	GetHandleVerifier [0x00007FF7416A1D24+3189156]
# 	GetHandleVerifier [0x00007FF74169ACAF+3160367]
# 	GetHandleVerifier [0x00007FF741436D06+653702]
# 	(No symbol) [0x00007FF74132A208]
# 	(No symbol) [0x00007FF7413262C4]
# 	(No symbol) [0x00007FF7413263F6]
# 	(No symbol) [0x00007FF7413167A3]
# 	BaseThreadInitThunk [0x00007FFB86127344+20]
# 	RtlUserThreadStart [0x00007FFB862626B1+33]

# %%
df = pd.DataFrame({
    "links":links
})
df1=pd.read_csv('datas/Fayyoz_links/data_Fayyoz.csv')
# df = df.drop_duplicates()
df_sum=pd.concat([df1, df], axis=0, ignore_index=True)
df_sum = df_sum.drop_duplicates()
df_sum.to_csv(f'datas/Fayyoz_links/data_Fayyoz.csv', index=False)
print(f'I am done ---> {item}')
# Out:
# I am done ---> Algeria

# %%
links
# Out:
# []
