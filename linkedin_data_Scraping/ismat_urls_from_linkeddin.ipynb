# %%
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from selenium import webdriver
import time
import pandas as pd
from bs4 import BeautifulSoup
options = Options()
options.add_argument("user-data-dir=C:/Users/dell/AppData/Local/Google/Chrome/User Data/Profile 2")
                                                        #C:\Users\fayyo\Downloads\chromedriver-win32.zip\chromedriver-win32
driver = webdriver.Chrome(options=options,executable_path='C:/Users/dell/OneDrive/Desktop/chromedriver-win64/chromedriver.exe')
# country names
list_items = [
    "Tourcoing",
    "Avignon",
    "Nanterre",
    "Vitry-sur-Seine",
    "Créteil",
    "Dunkerque",
    "Aubervilliers",
    "Versailles",
    "Courbevoie",
    "Cergy",
    "Nîmes",
    "Saint-Denis",
    "La Rochelle",
    "Antibes",
    "Saint-Maur-des-Fossés",
    "Calais",
    "Beauvais",
    "Drancy",
    "Chambery",
    "Saint-Nazaire",
    "Colombes",
    "La Seyne-sur-Mer",
    "Mérignac",
    "Valence",
    "Quimper",
    "Antony",
    "Troyes",
    "Lorient",
    "Sarcelles",
    "Niort",
    "Pessac",
    "Vénissieux",
    "Châteauroux",
    "Clichy",
    "Ivry-sur-Seine",
    "Montauban",
    "Villejuif",
    "Les Abymes",
    "Sartrouville",
    "Evry",
    "Niort",
    "Meaux",
    "Pantin",
    "Chalon-sur-Saône",
    "Saint-Malo",
    "Caluire-et-Cuire",
    "Gagny",
    "Rezé",
    "Le Blanc-Mesnil",
    "Vincennes",
    "Épinay-sur-Seine",
    "Mantes-la-Jolie",
    "Sevran",
    "Albi",
    "Suresnes",
    "Clamart",
    "Grigny",
    "Blois",
    "Clichy-sous-Bois",
    "Bondy",
    "Évreux",
    "Chambéry",
    "Villepinte",
    "Bezons",
    "Gap",
    "Bagneux",
    "Compiègne",
    "Thionville",
    "Trappes",
    "Saint-Herblain",
    "Le Cannet",
    "Saint-Laurent-du-Maroni",
    "Saint-André",
    "Bagnolet",
    "Douai",
    "Rodez",
    "Mamoudzou",
    "Meudon",
    "Pontoise",
    "Châtillon",
    "Livry-Gargan",
    "Saint-Joseph",
    "La Courneuve",
    "Saint-Martin",
    "Colmar",
    "Saint-Priest",
    "Boulogne-sur-Mer",
    "Grasse",
    "Villeneuve-Saint-Georges",
    "Suresnes",
    "Trappes",
    "Alès",
    "Rosny-sous-Bois",
    "Annecy",
    "Le Port",
    "Nevers",
    "Cholet",
    "Montluçon",
    "Clichy-sous-Bois",
    "La Roche-sur-Yon",
    "Salon-de-Provence",
    "Baie-Mahault",
    "Cholet",
    "Agen",
    "Épinal",
    "Bobigny",
    "Talence",
    "Castres",
    "Maisons-Alfort",
    "Saint-Leu",
    "Fréjus",
    "Chartres",
    "Charleville-Mézières",
    "Sarreguemines",
    "Lens",
    "Angoulême",
    "Pessac",
    "Ivry-sur-Seine",
    "Cayenne",
    "Lorient",
    "Garges-lès-Gonesse",
    "Roanne",
    "Thonon-les-Bains",
    "Romainville",
    "Aubagne",
    "Saint-Martin-d'Hères",
    "Saint-Ouen",
    "Périgueux",
    "Chelles",
    "Ajaccio",
    "Rueil-Malmaison",
    "Vannes",
    "Saint-Chamond",
    "Muret",
    "Massy",
    "Gap",
    "Sète",
    "Istres",
    "Haguenau",
    "Le Lamentin",
    "Noisy-le-Grand",
    "Gonesse",
    "Échirolles",
    "Liévin",
    "Anglet",
    "Tarbes",
    "Chartres",
    "Villefranche-sur-Saône",
    "Colomiers",
    "La Ciotat",
    "Angers",
    "Neuilly-sur-Marne",
    "Aix-les-Bains",
    "Chartres",
    "Vierzon",
    "Puteaux",
    "Savigny-sur-Orge",
    "Le Perreux-sur-Marne",
    "Montélimar",
    "Saint-Brieuc",
    "La Courneuve",
    "Le Tampon",
    "Saint-Raphaël",
    "Saint-Louis",
    "Charenton-le-Pont",
    "Villeneuve-sur-Lot",
    "Conflans-Sainte-Honorine",
    "Châtellerault",
    "Pontault-Combault",
    "Roissy-en-Brie",
    "Montgeron",
    "Franconville",
    "Nevers",
    "Creil",
    "Palaiseau",
    "Champs-sur-Marne",
    "Talence",
    "Biarritz",
    "Savigny-le-Temple",
    "Le Cannet",
    "Thionville",
    "Sainte-Geneviève-des-Bois",
    "Saint-Malo",
    "Liévin",
]
for item  in list_items[:]:
    links = [] # save links here
    for study in ['math', 'physics']:
        driver.get(f'https://www.google.com/search?q=site:nl.linkedin.com/in/+AND+%22{item}+AND+%22{study}')
        time.sleep(5) # to make slower 
        n=30
        while n > 0:
            time.sleep(5)
            print("here")
            initialScroll = 0
            finalScroll = 1000
            start = time.time()
            while True:
                driver.execute_script(f"window.scrollTo({initialScroll}, {finalScroll})")
                initialScroll = finalScroll
                finalScroll += 1000
                time.sleep(3)
                end = time.time()
                if round(end - start) > 25:
                    break
            src = driver.page_source
            soup = BeautifulSoup(src, 'lxml')
            linksed_links=soup.find_all("a", {"jsname":"UWckNb"})
            for i in linksed_links:
                links.append(i.get('href').split("?")[0])
            try:
                next_button = driver.find_element(By.XPATH, '//*[@id="pnnext"]') # clicking next button 
                next_button.click()
            except Exception as e:
                driver.get(f'https://www.google.com/search?q=site:nl.linkedin.com/in/+AND+%22{item}+AND+%22{study}')
                n=1
                # print("")
            # print(f'{n} pages left!')
            n -= 1
        df = pd.DataFrame({
            "links":links
        })
        df1=pd.read_csv('datas/Ismatulla_links/data_Ismatulla5.csv')
        df_sum=pd.concat([df1, df], axis=0, ignore_index=True)
        df_sum = df_sum.drop_duplicates()
        df_sum.to_csv(f'datas/Ismatulla_links/data_Ismatulla5.csv', index=False)
        print(f'I am done ---> {item}')
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_13980\2262508296.py:10: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(options=options,executable_path='C:/Users/dell/OneDrive/Desktop/chromedriver-win64/chromedriver.exe')
# here
# I am done ---> Tourcoing
# here
# I am done ---> Tourcoing
# here
# I am done ---> Avignon
# here
# I am done ---> Avignon
# here
# I am done ---> Nanterre
# here
# I am done ---> Nanterre
# here
# I am done ---> Vitry-sur-Seine
# here
# I am done ---> Vitry-sur-Seine
# here
# I am done ---> Créteil
# here
# I am done ---> Créteil
# here
# I am done ---> Dunkerque
# here
# I am done ---> Dunkerque
# here
# I am done ---> Aubervilliers
# here
# I am done ---> Aubervilliers
# here
# I am done ---> Versailles
# here
# I am done ---> Versailles
# here
# I am done ---> Courbevoie
# here
# I am done ---> Courbevoie
# here
# I am done ---> Cergy
# here
# I am done ---> Cergy
# here
# I am done ---> Nîmes
# here
# I am done ---> Nîmes
# here
# I am done ---> Saint-Denis
# here
# I am done ---> Saint-Denis
# here
# I am done ---> La Rochelle
# here
# I am done ---> La Rochelle
# here
# I am done ---> Antibes
# here
# I am done ---> Antibes
# here
# I am done ---> Saint-Maur-des-Fossés
# here
# I am done ---> Saint-Maur-des-Fossés
# here
# I am done ---> Calais
# here
# I am done ---> Calais
# here
# I am done ---> Beauvais
# here
# I am done ---> Beauvais
# here
# I am done ---> Drancy
# here
# I am done ---> Drancy
# here
# I am done ---> Chambery
# here
# I am done ---> Chambery
# here
# I am done ---> Saint-Nazaire
# here
# I am done ---> Saint-Nazaire
# here
# I am done ---> Colombes
# here
# I am done ---> Colombes
# here
# I am done ---> La Seyne-sur-Mer
# here
# I am done ---> La Seyne-sur-Mer
# here
# I am done ---> Mérignac
# here
# I am done ---> Mérignac
# here
# I am done ---> Valence
# here
# I am done ---> Valence
# here
# I am done ---> Quimper
# here
# I am done ---> Quimper
# here
# I am done ---> Antony
# here
# I am done ---> Antony
# here
# I am done ---> Troyes
# here
# I am done ---> Troyes
# here
# I am done ---> Lorient
# here
# I am done ---> Lorient
# here
# I am done ---> Sarcelles
# here
# I am done ---> Sarcelles
# here
# I am done ---> Niort
# here
# I am done ---> Niort
# here
# I am done ---> Pessac
# here
# I am done ---> Pessac
# here
# I am done ---> Vénissieux
# here
# I am done ---> Vénissieux
# here
# I am done ---> Châteauroux
# here
# I am done ---> Châteauroux
# here
# I am done ---> Clichy
# here
# I am done ---> Clichy
# here
# I am done ---> Ivry-sur-Seine
# here
# I am done ---> Ivry-sur-Seine
# here
# I am done ---> Montauban
# here
# I am done ---> Montauban
# here
# I am done ---> Villejuif
# here
# I am done ---> Villejuif
# here
# I am done ---> Les Abymes
# here
# I am done ---> Les Abymes
# here
# I am done ---> Sartrouville
# here
# I am done ---> Sartrouville
# here
# I am done ---> Evry
# here
# I am done ---> Evry
# here
# I am done ---> Niort
# here
# I am done ---> Niort
# here
# I am done ---> Meaux
# here
# I am done ---> Meaux
# here
# I am done ---> Pantin
# here
# I am done ---> Pantin
# here
# I am done ---> Chalon-sur-Saône
# here
# I am done ---> Chalon-sur-Saône
# here
# I am done ---> Saint-Malo
# here
# I am done ---> Saint-Malo
# here
# I am done ---> Caluire-et-Cuire
# here
# I am done ---> Caluire-et-Cuire
# here
# I am done ---> Gagny
# here
# I am done ---> Gagny
# here
# I am done ---> Rezé
# here
# I am done ---> Rezé
# here
# I am done ---> Le Blanc-Mesnil
# here
# I am done ---> Le Blanc-Mesnil
# here
# I am done ---> Vincennes
# here
# I am done ---> Vincennes
# here
# I am done ---> Épinay-sur-Seine
# here
# I am done ---> Épinay-sur-Seine
# here
# I am done ---> Mantes-la-Jolie
# here
# I am done ---> Mantes-la-Jolie
# here
# I am done ---> Sevran
# here
# I am done ---> Sevran
# here
# I am done ---> Albi
# here
# I am done ---> Albi
# here
# I am done ---> Suresnes
# here
# I am done ---> Suresnes
# here
# I am done ---> Clamart
# here
# I am done ---> Clamart
# here
# I am done ---> Grigny
# here
# I am done ---> Grigny
# here
# I am done ---> Blois
# here
# I am done ---> Blois
# here
# I am done ---> Clichy-sous-Bois
# here
# I am done ---> Clichy-sous-Bois
# here
# I am done ---> Bondy
# here
# I am done ---> Bondy
# here
# I am done ---> Évreux
# here
# I am done ---> Évreux
# here
# I am done ---> Chambéry
# here
# I am done ---> Chambéry
# here
# I am done ---> Villepinte
# here
# I am done ---> Villepinte
# here
# I am done ---> Bezons
# here
# I am done ---> Bezons
# here
# I am done ---> Gap
# here
# I am done ---> Gap
# here
# I am done ---> Bagneux
# here
# I am done ---> Bagneux
# here
# I am done ---> Compiègne
# here
# I am done ---> Compiègne
# here
# I am done ---> Thionville
# here
# I am done ---> Thionville
# here
# I am done ---> Trappes
# here
# I am done ---> Trappes
# here
# I am done ---> Saint-Herblain
# here
# I am done ---> Saint-Herblain
# here
# I am done ---> Le Cannet
# here
# I am done ---> Le Cannet
# here
# I am done ---> Saint-Laurent-du-Maroni
# here
# I am done ---> Saint-Laurent-du-Maroni
# here
# I am done ---> Saint-André
# here
# I am done ---> Saint-André
# here
# I am done ---> Bagnolet
# here
# I am done ---> Bagnolet
# here
# I am done ---> Douai
# here
# I am done ---> Douai
# here
# I am done ---> Rodez
# here
# I am done ---> Rodez
# here
# I am done ---> Mamoudzou
# here
# I am done ---> Mamoudzou
# here
# I am done ---> Meudon
# here
# I am done ---> Meudon
# here
# I am done ---> Pontoise
# here
# I am done ---> Pontoise
# here
# I am done ---> Châtillon
# here
# I am done ---> Châtillon
# here
# I am done ---> Livry-Gargan
# here
# I am done ---> Livry-Gargan
# here
# I am done ---> Saint-Joseph
# here
# I am done ---> Saint-Joseph
# here
# I am done ---> La Courneuve
# here
# I am done ---> La Courneuve
# here
# I am done ---> Saint-Martin
# here
# I am done ---> Saint-Martin
# here
# I am done ---> Colmar
# here
# I am done ---> Colmar
# here
# I am done ---> Saint-Priest
# here
# I am done ---> Saint-Priest
# here
# I am done ---> Boulogne-sur-Mer
# here
# I am done ---> Boulogne-sur-Mer
# here
# I am done ---> Grasse
# here
# I am done ---> Grasse
# here
# I am done ---> Villeneuve-Saint-Georges
# here
# I am done ---> Villeneuve-Saint-Georges
# here
# I am done ---> Suresnes
# here
# I am done ---> Suresnes
# here
# I am done ---> Trappes
# here
# I am done ---> Trappes
# here
# I am done ---> Alès
# here
# I am done ---> Alès
# here
# I am done ---> Rosny-sous-Bois
# here
# I am done ---> Rosny-sous-Bois
# here
# I am done ---> Annecy
# here
# I am done ---> Annecy
# here
# I am done ---> Le Port
# here
# I am done ---> Le Port
# here
# I am done ---> Nevers
# here
# I am done ---> Nevers
# here
# I am done ---> Cholet
# here
# I am done ---> Cholet
# here
# I am done ---> Montluçon
# here
# I am done ---> Montluçon
# here
# I am done ---> Clichy-sous-Bois
# here
# I am done ---> Clichy-sous-Bois
# here
# I am done ---> La Roche-sur-Yon
# here
# I am done ---> La Roche-sur-Yon
# here
# I am done ---> Salon-de-Provence
# here
# I am done ---> Salon-de-Provence
# here
# I am done ---> Baie-Mahault
# here
# I am done ---> Baie-Mahault
# here
# I am done ---> Cholet
# here
# I am done ---> Cholet
# here
# I am done ---> Agen
# here
# I am done ---> Agen
# here
# I am done ---> Épinal
# here
# I am done ---> Épinal
# here
# I am done ---> Bobigny
# here
# I am done ---> Bobigny
# here
# I am done ---> Talence
# here
# I am done ---> Talence
# here
# I am done ---> Castres
# here
# I am done ---> Castres
# here
# I am done ---> Maisons-Alfort
# here
# I am done ---> Maisons-Alfort
# here
# I am done ---> Saint-Leu
# here
# I am done ---> Saint-Leu
# here
# I am done ---> Fréjus
# here
# I am done ---> Fréjus
# here
# I am done ---> Chartres
# here
# I am done ---> Chartres
# here
# I am done ---> Charleville-Mézières
# here
# I am done ---> Charleville-Mézières
# here
# I am done ---> Sarreguemines
# here
# I am done ---> Sarreguemines
# here
# I am done ---> Lens
# here
# I am done ---> Lens
# here
# I am done ---> Angoulême
# here
# I am done ---> Angoulême
# here
# I am done ---> Pessac
# here
# I am done ---> Pessac
# here
# I am done ---> Ivry-sur-Seine
# here
# I am done ---> Ivry-sur-Seine
# here
# I am done ---> Cayenne
# here
# I am done ---> Cayenne
# here
# I am done ---> Lorient
# here
# I am done ---> Lorient
# here
# I am done ---> Garges-lès-Gonesse
# here
# I am done ---> Garges-lès-Gonesse
# here
# I am done ---> Roanne
# here
# I am done ---> Roanne
# here
# I am done ---> Thonon-les-Bains
# here
# I am done ---> Thonon-les-Bains
# here
# I am done ---> Romainville
# here
# I am done ---> Romainville
# here
# I am done ---> Aubagne
# here
# I am done ---> Aubagne
# here
# I am done ---> Saint-Martin-d'Hères
# here
# I am done ---> Saint-Martin-d'Hères
# here
# I am done ---> Saint-Ouen
# here
# I am done ---> Saint-Ouen
# here
# I am done ---> Périgueux
# here
# I am done ---> Périgueux
# here
# I am done ---> Chelles
# here
# I am done ---> Chelles
# here
# I am done ---> Ajaccio
# here
# I am done ---> Ajaccio
# here
# I am done ---> Rueil-Malmaison
# here
# I am done ---> Rueil-Malmaison
# here
# I am done ---> Vannes
# here
# I am done ---> Vannes
# here
# I am done ---> Saint-Chamond
# here
# I am done ---> Saint-Chamond
# here
# I am done ---> Muret
# here
# I am done ---> Muret
# here
# I am done ---> Massy
# here
# I am done ---> Massy
# here
# I am done ---> Gap
# here
# I am done ---> Gap
# here
# I am done ---> Sète
# here
# I am done ---> Sète
# here
# I am done ---> Istres
# here
# I am done ---> Istres
# here
# I am done ---> Haguenau
# here
# I am done ---> Haguenau
# here
# I am done ---> Le Lamentin
# here
# I am done ---> Le Lamentin
# here
# I am done ---> Noisy-le-Grand
# here
# I am done ---> Noisy-le-Grand
# here
# I am done ---> Gonesse
# here
# I am done ---> Gonesse
# here
# I am done ---> Échirolles
# here
# I am done ---> Échirolles
# here
# I am done ---> Liévin
# here
# I am done ---> Liévin
# here
# I am done ---> Anglet
# here
# I am done ---> Anglet

# %%
df = pd.DataFrame({
    "links":links
})
df1=pd.read_csv('datas/Fayyoz_links/data_Fayyoz.csv')
# df = df.drop_duplicates()
df_sum=pd.concat([df1, df], axis=0, ignore_index=True)
df_sum = df_sum.drop_duplicates()
df_sum.to_csv(f'datas/Fayyoz_links/data_Fayyoz.csv', index=False)
print(f'I am done ---> {item}')
# Out:
# I am done ---> Algeria

# %%
links
# Out:
# []
