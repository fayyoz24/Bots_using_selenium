# %%
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from selenium import webdriver
import time
import pandas as pd
from bs4 import BeautifulSoup
options = Options()
options.add_argument("user-data-dir=C:/Users/dell/AppData/Local/Google/Chrome/User Data/Profile 14")
                                                        #C:\Users\fayyo\Downloads\chromedriver-win32.zip\chromedriver-win32
driver = webdriver.Chrome(options=options,executable_path='C:/Users/dell/OneDrive/Desktop/chromedriver-win64/chromedriver.exe')
# country names
list_items = [
    "Windhoek",
    "Rundu",
    "Walvis Bay",
    "Oshakati",
    "Swakopmund",
    "Katima Mulilo",
    "Grootfontein",
    "Keetmanshoop",
    "Tsumeb",
    "Ondangwa",
    "Rehoboth",
    "Otjiwarongo",
    "Okahandja",
    "Gobabis",
    "Usakos",
    "Mariental",
    "Outapi",
    "Ongwediva",
    "Okakarara",
    "Eenhana",
    "Opuwo",
    "Oniipa",
    "Oshikango",
    "Lüderitz",
    "Henties Bay",
    "Karibib",
    "Tsumkwe",
    "Edundja",
    "Rosh Pinah",
    "Khorixas",
    "Otavi",
    "Omaruru",
    "Omuthiya",
    "Tsumeb",
    "Oshikuku",
    "Onandjokwe",
    "Ruacana",
    "Ongandjera",
    "Okongo",
    "Omungwelume",
    "Tsandi",
    "Outjo",
    "Oshifo",
    "Omatunda",
    "Outapi",
    "Opuwo",
    "Oshikoshi",
    "Uukwangula",
    "Ekuku",
    "Okalongo",
    "Okangwati",
    "Omundaungilo",
    "Epembe",
    "Ongenga",
    "Olukonda",
    "Oshitayi",
    "Ondjiva",
    "Ruacana",
    "Iipumbu",
    "Nehale lyaMpingana",
    "Laluno",
    "Nankudu",
    "Katima Mulilo",
    "Katere",
    "Bukalo",
    "Ngoma",
    "Kongola",
    "Judea Lyaboloma",
    "Linyanti",
    "Kaisosi",
    "Chinchimane",
    "Kahenge",
    "Makalani",
    "Luhonono",
    "Namiyundu",
    "Nyondo",
    "Mayara",
    "Mutikitila",
    "Mukwe",
    "Nankudu",
    "Sangwali",
    "Sikalongo",
    "Siya",
    "Sizongoro",
    "Wakadeni",
    "Nechimon",
    "Purros",
    "Puros",
    "Nechiras",
    "Torra Bay",
    "Karibib",
    "Usakos",
    "Omaruru",
    "Arandis",
    "Swakopmund",
    "Henties Bay",
    "Sokota",
    "Karibib",
    "Spitzkoppe",
    "Omatjete",
    "Henties Bay",
    "Walvis Bay",
    "Swakopmund",
    "Karibib",
    "Otavi",
    "Grootfontein",
    "Tsumeb",
    "Nkurenkuru",
    "Kahenge",
    "Ndiyona",
    "Divundu",
    "Sikondo",
    "Nkurenkuru",
    "Bukalo",
    "Sibbinda",
    "Mukwe",
    "Kahenge",
    "Ndiyona",
    "Nkurenkuru",
    "Divundu",
    "Kapako",
    "Tondoro",
    "Sikondo",
    "Ndiyona",
    "Luhonono",
    "Siya",
    "Linyanti",
    "Sikalongo",
    "Makalani",
    "Sangwali",
    "Nankudu",
    "Bukalo",
    "Kongola",
    "Judea Lyaboloma",
    "Laluno",
    "Rundu",
    "Nankudu",
    "Katima Mulilo",
    "Katere",
    "Ngoma",
    "Kongola",
    "Judea Lyaboloma",
    "Laluno",
    "Rundu",
    "Nankudu",
    "Katima Mulilo",
    "Katere",
    "Bukalo",
    "Ngoma",
    "Kongola",
    "Judea Lyaboloma",
    "Laluno",
    "Sikalongo",
    "Kaisosi",
    "Chinchimane",
    "Kahenge",
    "Makalani",
    "Luhonono",
    "Namiyundu",
    "Nyondo",
    "Mayara",
    "Mutikitila",
    "Mukwe",
    "Nankudu",
    "Sangwali",
    "Sikondo",
    "Wakadeni",
    "Nechimon",
    "Purros",
    "Puros",
    "Nechiras",
    "Torra Bay",
    "Karibib",
    "Usakos",
    "Omaruru",
    "Arandis",
    "Swakopmund",
    "Henties Bay",
    "Sokota",
    "Karibib",
    "Spitzkoppe",
    "Omatjete",
    "Henties Bay",
    "Walvis Bay",
    "Swakopmund",
    "Karibib",
    "Otavi",
    "Grootfontein",
    "Tsumeb",
    "Nkurenkuru",
    "Kahenge",
    "Ndiyona",
    "Divundu",
    "Sikondo",
    "Nkurenkuru",
    "Bukalo",
    "Sibbinda",
    "Mukwe",
    "Kahenge",
    "Ndiyona",
    "Nkurenkuru",
    "Divundu",
    "Kapako",
    "Tondoro",
    "Sikondo",
    "Ndiyona",
    "Luhonono",
    "Siya",
    "Linyanti",
    "Sikalongo",
    "Makalani",
    "Sangwali",
    "Nankudu",
    "Bukalo",
    "Kongola",
    "Judea Lyaboloma",
    "Laluno",
    "Rundu",
    "Nankudu",
    "Katima Mulilo",
    "Katere",
    "Ngoma",
    "Kongola",
    "Judea Lyaboloma",
    "Laluno",
    "Rundu",
    "Nankudu",
    "Katima Mulilo",
    "Katere",
    "Bukalo",
    "Ngoma",
    "Kongola",
    "Judea Lyaboloma",
    "Laluno",
    "Sikalongo",
    "Kaisosi",
    "Chinchimane",
    "Kahenge",
]

for item  in list_items[:]:
    links = [] # save links here
    for study in ['math', 'physics']:
        driver.get(f'https://www.google.com/search?q=site:nl.linkedin.com/in/+AND+%22{item}+AND+%22{study}')
        time.sleep(5) # to make slower 
        n=30
        while n > 0:
            time.sleep(5)
            print("here")
            initialScroll = 0
            finalScroll = 1000
            start = time.time()
            while True:
                driver.execute_script(f"window.scrollTo({initialScroll}, {finalScroll})")
                initialScroll = finalScroll
                finalScroll += 1000
                time.sleep(3)
                end = time.time()
                if round(end - start) > 25:
                    break
            src = driver.page_source
            soup = BeautifulSoup(src, 'lxml')
            linksed_links=soup.find_all("a", {"jsname":"UWckNb"})
            for i in linksed_links:
                links.append(i.get('href').split("?")[0])
            try:
                next_button = driver.find_element(By.XPATH, '//*[@id="pnnext"]') # clicking next button 
                next_button.click()
            except Exception as e:
                driver.get(f'https://www.google.com/search?q=site:nl.linkedin.com/in/+AND+%22{item}+AND+%22{study}')
                n=1
                # print("")
            # print(f'{n} pages left!')
            n -= 1
        df = pd.DataFrame({
            "links":links
        })
        df1=pd.read_csv('datas/Ismatulla_links/data_Ismatulla5.csv')
        df_sum=pd.concat([df1, df], axis=0, ignore_index=True)
        df_sum = df_sum.drop_duplicates()
        df_sum.to_csv(f'datas/Ismatulla_links/data_Ismatulla5.csv', index=False)
        print(f'I am done ---> {item}')
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_13980\2490811650.py:10: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(options=options,executable_path='C:/Users/dell/OneDrive/Desktop/chromedriver-win64/chromedriver.exe')
# here
# I am done ---> Windhoek
# here
# I am done ---> Windhoek
# here
# I am done ---> Rundu
# here
# I am done ---> Rundu
# here
# I am done ---> Walvis Bay
# here
# I am done ---> Walvis Bay
# here
# I am done ---> Oshakati
# here
# I am done ---> Oshakati
# here
# I am done ---> Swakopmund
# here
# I am done ---> Swakopmund
# here
# I am done ---> Katima Mulilo
# here
# I am done ---> Katima Mulilo
# here
# I am done ---> Grootfontein
# here
# I am done ---> Grootfontein
# here
# I am done ---> Keetmanshoop
# here
# I am done ---> Keetmanshoop
# here
# I am done ---> Tsumeb
# here
# I am done ---> Tsumeb
# here
# I am done ---> Ondangwa
# here
# I am done ---> Ondangwa
# here
# I am done ---> Rehoboth
# here
# I am done ---> Rehoboth
# here
# I am done ---> Otjiwarongo
# here
# I am done ---> Otjiwarongo
# here
# I am done ---> Okahandja
# here
# I am done ---> Okahandja
# here
# I am done ---> Gobabis
# here
# I am done ---> Gobabis
# here
# I am done ---> Usakos
# here
# I am done ---> Usakos
# here
# I am done ---> Mariental
# here
# I am done ---> Mariental
# here
# I am done ---> Outapi
# here
# I am done ---> Outapi
# here
# I am done ---> Ongwediva
# here
# I am done ---> Ongwediva
# here
# I am done ---> Okakarara
# here
# I am done ---> Okakarara
# here
# I am done ---> Eenhana
# here
# I am done ---> Eenhana
# here
# I am done ---> Opuwo
# here
# I am done ---> Opuwo
# here
# I am done ---> Oniipa
# here
# I am done ---> Oniipa
# here
# I am done ---> Oshikango
# here
# I am done ---> Oshikango
# here
# I am done ---> Lüderitz
# here
# I am done ---> Lüderitz
# here
# I am done ---> Henties Bay
# here
# I am done ---> Henties Bay
# here
# I am done ---> Karibib
# here
# I am done ---> Karibib
# here
# I am done ---> Tsumkwe
# here
# I am done ---> Tsumkwe
# here
# I am done ---> Edundja
# here
# I am done ---> Edundja
# here
# I am done ---> Rosh Pinah
# here
# I am done ---> Rosh Pinah
# here
# I am done ---> Khorixas
# here
# I am done ---> Khorixas
# here
# I am done ---> Otavi
# here
# I am done ---> Otavi
# here
# I am done ---> Omaruru
# here
# I am done ---> Omaruru
# here
# I am done ---> Omuthiya
# here
# I am done ---> Omuthiya
# here
# I am done ---> Tsumeb
# here
# I am done ---> Tsumeb
# here
# I am done ---> Oshikuku
# here
# I am done ---> Oshikuku
# here
# I am done ---> Onandjokwe
# here
# I am done ---> Onandjokwe
# here
# I am done ---> Ruacana
# here
# I am done ---> Ruacana
# here
# I am done ---> Ongandjera
# here
# I am done ---> Ongandjera
# here
# I am done ---> Okongo
# here
# I am done ---> Okongo
# here
# I am done ---> Omungwelume
# here
# I am done ---> Omungwelume
# here
# I am done ---> Tsandi
# here
# I am done ---> Tsandi
# here
# I am done ---> Outjo
# here
# I am done ---> Outjo
# here
# I am done ---> Oshifo
# here
# I am done ---> Oshifo
# here
# I am done ---> Omatunda
# here
# I am done ---> Omatunda
# here
# I am done ---> Outapi
# here
# I am done ---> Outapi
# here
# I am done ---> Opuwo
# here
# I am done ---> Opuwo
# here
# I am done ---> Oshikoshi
# here
# I am done ---> Oshikoshi
# here
# I am done ---> Uukwangula
# here
# I am done ---> Uukwangula
# here
# I am done ---> Ekuku
# here
# I am done ---> Ekuku
# here
# I am done ---> Okalongo
# here
# I am done ---> Okalongo
# here
# I am done ---> Okangwati
# here
# I am done ---> Okangwati
# here
# I am done ---> Omundaungilo
# here
# I am done ---> Omundaungilo
# here
# I am done ---> Epembe
# here
# I am done ---> Epembe
# here
# I am done ---> Ongenga
# here
# I am done ---> Ongenga
# here
# I am done ---> Olukonda
# here
# I am done ---> Olukonda
# here
# I am done ---> Oshitayi
# here
# I am done ---> Oshitayi
# here
# I am done ---> Ondjiva
# here
# I am done ---> Ondjiva
# here
# I am done ---> Ruacana
# here
# I am done ---> Ruacana
# here
# I am done ---> Iipumbu
# here
# I am done ---> Iipumbu
# here
# I am done ---> Nehale lyaMpingana
# here
# I am done ---> Nehale lyaMpingana
# here
# I am done ---> Laluno
# here
# I am done ---> Laluno
# here
# I am done ---> Nankudu
# here
# I am done ---> Nankudu
# here
# I am done ---> Katima Mulilo
# here
# I am done ---> Katima Mulilo
# here
# I am done ---> Katere
# here
# I am done ---> Katere
# here
# I am done ---> Bukalo
# here
# I am done ---> Bukalo
# here
# I am done ---> Ngoma
# here
# I am done ---> Ngoma
# here
# I am done ---> Kongola
# here
# I am done ---> Kongola
# here
# I am done ---> Judea Lyaboloma
# here
# I am done ---> Judea Lyaboloma
# here
# I am done ---> Linyanti
# here
# I am done ---> Linyanti
# here
# I am done ---> Kaisosi
# here
# I am done ---> Kaisosi
# here
# I am done ---> Chinchimane
# here
# I am done ---> Chinchimane
# here
# I am done ---> Kahenge
# here
# I am done ---> Kahenge
# here
# I am done ---> Makalani
# here
# I am done ---> Makalani
# here
# I am done ---> Luhonono
# here
# I am done ---> Luhonono
# here
# I am done ---> Namiyundu
# here
# I am done ---> Namiyundu
# here
# I am done ---> Nyondo
# here
# I am done ---> Nyondo
# here
# I am done ---> Mayara
# here
# I am done ---> Mayara
# here
# I am done ---> Mutikitila
# here
# I am done ---> Mutikitila
# here
# I am done ---> Mukwe
# here
# I am done ---> Mukwe
# here
# I am done ---> Nankudu
# here
# I am done ---> Nankudu
# here
# I am done ---> Sangwali
# here
# I am done ---> Sangwali
# here
# I am done ---> Sikalongo
# here
# I am done ---> Sikalongo
# here
# I am done ---> Siya
# here
# I am done ---> Siya
# here
# I am done ---> Sizongoro
# here
# I am done ---> Sizongoro
# here
# I am done ---> Wakadeni
# here
# I am done ---> Wakadeni
# here
# I am done ---> Nechimon
# here
# I am done ---> Nechimon
# here
# I am done ---> Purros
# here
# ---------------------------------------------------------------------------
# UnexpectedAlertPresentException           Traceback (most recent call last)
# c:\Users\dell\OneDrive\Desktop\selenium\Bots_using_selenium\linkedin_data_Scraping\ismat_urls_from_linkeddin.ipynb Cell 1 line 2
#     <a href='vscode-notebook-cell:/c%3A/Users/dell/OneDrive/Desktop/selenium/Bots_using_selenium/linkedin_data_Scraping/ismat_urls_from_linkeddin.ipynb#W0sZmlsZQ%3D%3D?line=263'>264</a> start = time.time()
#     <a href='vscode-notebook-cell:/c%3A/Users/dell/OneDrive/Desktop/selenium/Bots_using_selenium/linkedin_data_Scraping/ismat_urls_from_linkeddin.ipynb#W0sZmlsZQ%3D%3D?line=264'>265</a> while True:
# --> <a href='vscode-notebook-cell:/c%3A/Users/dell/OneDrive/Desktop/selenium/Bots_using_selenium/linkedin_data_Scraping/ismat_urls_from_linkeddin.ipynb#W0sZmlsZQ%3D%3D?line=265'>266</a>     driver.execute_script(f"window.scrollTo({initialScroll}, {finalScroll})")
#     <a href='vscode-notebook-cell:/c%3A/Users/dell/OneDrive/Desktop/selenium/Bots_using_selenium/linkedin_data_Scraping/ismat_urls_from_linkeddin.ipynb#W0sZmlsZQ%3D%3D?line=266'>267</a>     initialScroll = finalScroll
#     <a href='vscode-notebook-cell:/c%3A/Users/dell/OneDrive/Desktop/selenium/Bots_using_selenium/linkedin_data_Scraping/ismat_urls_from_linkeddin.ipynb#W0sZmlsZQ%3D%3D?line=267'>268</a>     finalScroll += 1000
#
# File c:\Users\dell\OneDrive\Desktop\selenium\Bots_using_selenium\venv\lib\site-packages\selenium\webdriver\remote\webdriver.py:500, in WebDriver.execute_script(self, script, *args)
#     497 converted_args = list(args)
#     498 command = Command.W3C_EXECUTE_SCRIPT
# --> 500 return self.execute(command, {"script": script, "args": converted_args})["value"]
#
# File c:\Users\dell\OneDrive\Desktop\selenium\Bots_using_selenium\venv\lib\site-packages\selenium\webdriver\remote\webdriver.py:440, in WebDriver.execute(self, driver_command, params)
#     438 response = self.command_executor.execute(driver_command, params)
#     439 if response:
# --> 440     self.error_handler.check_response(response)
#     441     response["value"] = self._unwrap_value(response.get("value", None))
#     442     return response
#
# File c:\Users\dell\OneDrive\Desktop\selenium\Bots_using_selenium\venv\lib\site-packages\selenium\webdriver\remote\errorhandler.py:244, in ErrorHandler.check_response(self, response)
#     242     elif "alert" in value:
#     243         alert_text = value["alert"].get("text")
# --> 244     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
#     245 raise exception_class(message, screen, stacktrace)
#
# UnexpectedAlertPresentException: Alert Text: Cannot contact reCAPTCHA. Check your connection and try again.
# Message: unexpected alert open: {Alert text : Cannot contact reCAPTCHA. Check your connection and try again.}
#   (Session info: chrome=116.0.5845.188)
# Stacktrace:
# 	GetHandleVerifier [0x00007FF7413A52A2+57122]
# 	(No symbol) [0x00007FF74131EA92]
# 	(No symbol) [0x00007FF7411EE3AB]
# 	(No symbol) [0x00007FF74125EDC2]
# 	(No symbol) [0x00007FF741246DB3]
# 	(No symbol) [0x00007FF74121D2B1]
# 	(No symbol) [0x00007FF74121E494]
# 	GetHandleVerifier [0x00007FF74164EF82+2849794]
# 	GetHandleVerifier [0x00007FF7416A1D24+3189156]
# 	GetHandleVerifier [0x00007FF74169ACAF+3160367]
# 	GetHandleVerifier [0x00007FF741436D06+653702]
# 	(No symbol) [0x00007FF74132A208]
# 	(No symbol) [0x00007FF7413262C4]
# 	(No symbol) [0x00007FF7413263F6]
# 	(No symbol) [0x00007FF7413167A3]
# 	BaseThreadInitThunk [0x00007FFB86127344+20]
# 	RtlUserThreadStart [0x00007FFB862626B1+33]

# %%
df = pd.DataFrame({
    "links":links
})
df1=pd.read_csv('datas/Fayyoz_links/data_Fayyoz.csv')
# df = df.drop_duplicates()
df_sum=pd.concat([df1, df], axis=0, ignore_index=True)
df_sum = df_sum.drop_duplicates()
df_sum.to_csv(f'datas/Fayyoz_links/data_Fayyoz.csv', index=False)
print(f'I am done ---> {item}')
# Out:
# I am done ---> Algeria

# %%
links
# Out:
# []
