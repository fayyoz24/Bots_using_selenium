# %%
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from selenium import webdriver
import time
import pandas as pd

options = Options()
options.add_argument("user-data-dir=C:/Users/dell/AppData/Local/Google/Chrome/User Data/Profile 20")
                                                        #C:\Users\fayyo\Downloads\chromedriver-win32.zip\chromedriver-win32
driver = webdriver.Chrome(options=options,executable_path='C:/Users/fayyo/Downloads/chromedriver.exe')
# country names
list_items =[
    # "Royal Dutch Shell",
    # "ING Group",
    # "Unilever",
    # "ASML",
    # "Philips",
    # "Ahold Delhaize",
    # "KLM Royal Dutch Airlines",
    # "Heineken",
    # "AkzoNobel",
    # "Randstad Holding",
    # "ABN AMRO",
    # "DSM (Koninklijke DSM)",
    # "Arcadis",
    # "TomTom",
    # "Adyen",
    "NN Group",
    "RELX Group",
    "Vopak",
    "Fugro",
    "SBM Offshore",
    "Signify (formerly Philips Lighting)",
    "INGKA Group (IKEA)",
    "OCI N.V.",
    "KPN",
    "Boskalis",
    "NXP Semiconductors",
    "ASR Nederland",
    "Cargill",
    "Vivat",
    "Kuehne + Nagel",
    "Van Oord",
    "AEGON",
    "Air France-KLM",
    "Refresco",
    "Wolters Kluwer",
    "Vattenfall",
    "Stork",
    "Euronext",
    "PostNL",
    "Flow Traders",
    "Galapagos NV",
    "Wereldhave",
    "Royal Boskalis Westminster",
    "OCI N.V.",
    "LyondellBasell",
    "Corbion",
    "Aalberts Industries",
    "Wessanen",
    "Accell Group",
    "Takeaway.com",
    "Sligro Food Group",
    "Coca-Cola European Partners",
    "Van Lanschot Kempen",
    "SBM Offshore",
    "IMCD",
    "ForFarmers",
    "Beter Bed",
    "Brunel International",
    "Lucas Bols",
    "Eurocommercial Properties",
    "Basic-Fit",
    "GrandVision",
    "BAM Group",
    "OCI N.V.",
    "Beter Bed",
    "AkzoNobel",
    "Boskalis",
    "ASML",
    "Tata Steel Nederland",
    "OCI N.V.",
    "TomTom",
    "Corbion",
    "Vopak",
    "Takeaway.com",
    "RELX Group",
    "OCI N.V.",
    "Heineken",
    "Randstad Holding",
    "ING Group",
    "ABN AMRO",
    "Philips",
    "Ahold Delhaize",
    "Royal Dutch Shell",
    "KLM Royal Dutch Airlines",
    "Adyen",
    "AkzoNobel",
    "NN Group",
    "Koninklijke Wessanen",
    "ASR Nederland",
    "Air France-KLM",
    "Vattenfall",
    "Arcadis",
    "Cargill",
    "OCI N.V.",
    "Kuehne + Nagel",
    "AEGON",
    "NXP Semiconductors",
    "Stork",
    "IMCD",
    "Vivat",
    "INGKA Group (IKEA)",
    "PostNL",
    "SBM Offshore",
    "Euronext",
    "Aalberts Industries",
    "Lucas Bols",
    "Vopak",
    "Boskalis",
    "Wereldhave",
    "Beter Bed",
    "Takeaway.com",
    "AkzoNobel",
    "Corbion",
    "Heineken",
    "LyondellBasell",
    "Van Lanschot Kempen",
    "Eurocommercial Properties",
    "OCI N.V.",
    "Koninklijke Wessanen",
    "Aalberts Industries",
    "GrandVision",
    "Tata Steel Nederland",
    "INGKA Group (IKEA)"
    "Temma"
]

for item  in list_items[:]:
    links = [] # save links here
    for study in ['master', 'bachelor']:
        driver.get(f'https://www.google.com/search?q=site:nl.linkedin.com/in/+AND+%22{item}+AND+%22{study}')
        time.sleep(10) # to make slower 
        # n is the number of pages
        n=30
        while n > 0:
            time.sleep(5)
            for i in range(1, 11): # google uses paginator, every page has 10 urls
                time.sleep(6)
                try:    #/html/body/div[6]/div/div[13]/div/div[2]/div[2]/div/div/div[1]/div/div/div[1]/div/div/a
                        #/html/body/div[6]/div/div[13]/div/div[2]/div[2]/div/div/div[4]/div/div/div[1]/div/div/a
                        #/html/body/div[6]/div/div[13]/div/div[2]/div[2]/div/div/div[9]/div/div/div/div[1]/div/div/a
                    elems = driver.find_elements(By.XPATH, '/html/body/div[6]/div/div[12]/div/div[2]/div[2]/div/div/div['+str(i)+']/div/div/div[1]/div/div/a')
                    for elem in elems:                     #/html/body/div[6]/div/div[12]/div/div[2]/div[2]/div/div/div[3]/div/div/div[1]/div/div/a
                                                           #/html/body/div[6]/div/div[12]/div/div[2]/div[2]/div/div/div[2]/div/div/div[1]/div/div/a
                        clean_url = elem.get_attribute("href") # extracting url 
                        base_url = "linkedin.com/in/"
                        if clean_url.find(base_url) != -1 and '%' not in clean_url: # sometimes google gives no Ln urls, so clean it
                            links.append(clean_url)
                except Exception as e:
                    print("problem with ELEMS")
                    pass
            try:
                next_button = driver.find_element(By.XPATH, '//*[@id="pnnext"]') # clicking next button 
                next_button.click()
            except Exception as e:
                driver.get(f'https://www.google.com/search?q=site:nl.linkedin.com/in/+AND+%22{item}+AND+%22{study}')
                # print("")
            # print(f'{n} pages left!')
            n -= 1
    df = pd.DataFrame({
        "links":links
    })
    df1=pd.read_csv('datas/Fayyoz_links/data_Fayyoz.csv')
    df_sum=pd.concat([df1, df], axis=0, ignore_index=True)
    df_sum = df_sum.drop_duplicates()
    df_sum.to_csv(f'datas/Fayyoz_links/data_Fayyoz.csv', index=False)
    print(f'I am done ---> {item}')
# Out:
# C:\Users\fayyo\AppData\Local\Temp\ipykernel_4468\4176275535.py:10: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(options=options,executable_path='C:/Users/fayyo/Downloads/chromedriver.exe')
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Cell In[4], line 164
#     163 try:
# --> 164     next_button = driver.find_element(By.XPATH, '//*[@id="pnnext"]') # clicking next button
#     165     next_button.click()
#
# File c:\Users\GitHub\Bots_using_selenium\venv\lib\site-packages\selenium\webdriver\remote\webdriver.py:831, in WebDriver.find_element(self, by, value)
#     829     value = f'[name="{value}"]'
# --> 831 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# ...

# %%
df = pd.DataFrame({
    "links":links
})
df1=pd.read_csv('datas/Fayyoz_links/data_Fayyoz.csv')
df_sum=pd.concat([df1, df], axis=0, ignore_index=True)
df_sum = df_sum.drop_duplicates()
df_sum.to_csv(f'datas/Fayyoz_links/data_Fayyoz.csv', index=False)
print(f'I am done ---> {item}')
# Out:
# I am done ---> Adyen

# %%
from bs4 import BeautifulSoup
import time
from selenium.webdriver.chrome.options import Options
from selenium import webdriver
from selenium.webdriver.common.by import By
import pandas as pd

options = Options()
options.add_argument("user-data-dir=C:/Users/dell/AppData/Local/Google/Chrome/User Data/Profile 14")
driver = webdriver.Chrome(options=options,executable_path='C:/Users/dell/OneDrive/Desktop/chromedriver.exe')
driver.get('https://www.crystalknows.com/app/register')
time.sleep(10)

df= pd.read_csv(f'../linkedin_data_Scraping/15000_linkedin_profiles.csv')
j=0
for study in range(100,2000, 100):
    j+=1
    try:
        dots=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/div[1]/nav/div/div/div/div[6]/div/div[1]/div[2]/div/div/div')
        dots.click()
        time.sleep(2)
    except:
        print('dots problem')
    try:
        logout=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/div[1]/nav/div/div/div/div[6]/div/div[2]/div[6]/a')
        logout.click()
        time.sleep(5)
    except:
        print('logout problem')
    try:
        signup=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div[3]/div/form/div[3]/div/a')
        signup.click()
        time.sleep(8)
    except:
        print('signup probelm')
    try:
        first_name_input=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div[2]/div[3]/div[1]/input')
        first_name_input.click()
        first_name_input.send_keys(f'Alibek')
    except Exception as e:
        print('first_name-->problem')
    try:
        last_name_input=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div[2]/div[3]/div[2]/input')
        last_name_input.click()
        last_name_input.send_keys(f'Aliyev')
    except Exception as e:
        print('last_name-->problem')
    try:
        comp_email_input=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div[2]/div[4]/div/input')
        comp_email_input.click()
        comp_email_input.send_keys(f'shodjk3{str(j)+str(study)}@mail.ru')
    except Exception as e:
        print('comp_email-->problem')
    try:
        first_pass_input=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div[2]/div[5]/div[1]/input')
        first_pass_input.click()
        first_pass_input.send_keys('Aa2301667')
    except Exception as e:
        print('first_pass-->problem')
    try:    
        sec_pass_input=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div[2]/div[5]/div[2]/input')
        sec_pass_input.click()
        sec_pass_input.send_keys('Aa2301667')
    except Exception as e:
        print('sec_pass-->problem')
    try:
        agree_button=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div[2]/div[6]/div/label/div/img')
        agree_button.click()
    except Exception as e:
        print('agree_button-->problem')
    try:                                            #/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div/div[6]/button
        signup_button=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div[2]/div[7]/button')
        signup_button.click()
        time.sleep(10)
    except Exception as e:
        print('signup_button-->problem')
    try:
        country_button=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[1]/div[2]/div/div[2]/img')
        country_button.click()
        first_country=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[1]/div[2]/div[2]/div[1]')
        first_country.click()
    except Exception as e:
        print('country_button-->problem')                                # second country    '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[1]/div[2]/div[2]/div[2]'
    try:
        job_title_input=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[2]/div[2]/div/input')
        job_title_input.click()
        job_title_input.send_keys('software engineer')
    except Exception as e:
        print('job_title-->problem')
    try:    
        my_department_input=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[2]/div[4]/div[1]/div[2]/img')
        my_department_input.click()
        first_department=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[2]/div[4]/div[2]/div[6]')                              #  second department           '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[2]/div[3]/div[2]/div[2]'
        first_department.click()
    except Exception as e:
        print('department-->problem')
    try:    
        next_button=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[2]/a')
        next_button.click()
        time.sleep(10)
    except Exception as e:
        print('next_button-->problem')
    i=0
    dict_={}
    st1=0
    for link in df.links[st1:study]:
        print('AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA')
        print(i)
        st1=study
        print(f"ST1{st1}")
        print(f"STUDY1{study}")
        i+=1
        try: 
            link_enterong_button=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/div[1]/nav/div/div[1]/div/div[1]/div/input')
            link_enterong_button.click()
            link_enterong_button.clear()
            link_enterong_button.send_keys(link)
            time.sleep(8) 
        except Exception as e:
            print("linkedin user not found")
        try:                          # /html/body/div[2]/div/div/div[2]/div[1]/nav/div/div[1]/div/div[1]/div/div[2]/div/div/div/div/div[2]
            first_user=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/div[1]/nav/div/div[1]/div/div[1]/div/div[2]/div/div/div/div/div[2]')
            first_user.click()
            time.sleep(10)
            # src = driver.page_source
            # soup = BeautifulSoup(src, 'lxml')
            # cs=soup.find('div', {'class':'styles_disc-pill-wrapper__aB3OJ'})
            # /html/body/div[2]/div/div/div[4]/div[1]/div/div/div[1]/div/span
            dict_[link]=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/div[1]/div/div/div[1]/div/span').text
            print(dict_[link])
        except Exception as e:
            dict_[link]='nan'
        
        # price_butt=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/div[1]/nav/div/div[2]/div/div[1]').text
        # print(price_butt)
        print(f'IIIIIIIIIIII{i}')
        if i%10==0:
            print('Matched!!')
            try:
                dots1=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/div[1]/nav/div/div[1]/div/div[6]/div/div[1]/div[2]/div/div')
                dots1.click()
                print(dots1)
                time.sleep(2)

                logout1=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/div[1]/nav/div/div/div/div[6]/div/div[2]/div[6]/a')
                logout1.click()
                time.sleep(5)
                signup=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div[3]/div/form/div[3]/div/a')
                signup.click()
                time.sleep(8)

                first_name_input=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div[2]/div[3]/div[1]/input')
                # first_name_input.click()                        /html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div[2]/div[4]/div/input
                first_name_input.send_keys(f'Abror+{str(i)}')
            
                last_name_input=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div[2]/div[3]/div[2]/input')
                last_name_input.click()
                last_name_input.send_keys(f'Aliyev{str(i)}')
                comp_email_input_for_10=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div[2]/div[4]/div/input')
                comp_email_input_for_10.click()
                comp_email_input_for_10.send_keys(f'amiskhjon3{str(study//i)}{str(i)}@mail.ru')
            
                first_pass_input=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div[2]/div[5]/div[1]/input')
                first_pass_input.click()
                first_pass_input.send_keys('12345678')
                
                sec_pass_input=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div[2]/div[5]/div[2]/input')
                sec_pass_input.click()
                sec_pass_input.send_keys('12345678')
            
                agree_button1=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div[2]/div[6]/div/label/div/img')
                agree_button1.click()
        
                signup_button1=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div[2]/div[7]/button')
                signup_button1.click()
                time.sleep(10)
            
                country_button=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[1]/div[2]/div/div[2]/img')
                country_button.click()

                first_country=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[1]/div[2]/div[2]/div[4]')
                first_country.click()
            except Exception as e:
                print('i is divisible 10-->problem')                                # second country    '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[1]/div[2]/div[2]/div[2]'
            try:
                job_title_input=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[2]/div[2]/div/input')
                job_title_input.click()
                job_title_input.send_keys('software engineer')
            except Exception as e:
                print('job_title-->problem')
            try:    
                my_department_input=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[2]/div[4]/div/div[2]/img')
                my_department_input.click()
                first_department=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[2]/div[4]/div[2]/div[4]')
                first_department.click()
            except Exception as e:
                print('department-->problem')
            try:    
                next_button=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[2]/a')
                next_button.click()
                time.sleep(10)
            except Exception as e:
                print('next_button-->problem')
        if len(dict_)%100==0:
            df1 = pd.DataFrame({
            'links':list(dict_.keys()),
            'characters':list(dict_.values())
            })
            x = len(dict_)//100
            df1.to_csv(f'datas/cs_values_new/extra_data/data_till_2000{x}.csv', index=False)
    df1 = pd.DataFrame({
    'links':list(dict_.keys()),
    'characters':list(dict_.values())
    })
    df1.to_csv(f'datas/cs_values_new/data_till_2000{study}.csv', index=False)
    print(list(dict_.values())[-10:])
    print(f'{study} is done!')
# Out:
# C:\Users\fayyo\AppData\Local\Temp\ipykernel_11216\3107878509.py:10: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(options=options,executable_path='C:/Users/dell/OneDrive/Desktop/chromedriver.exe')
# Incompatible release of chromedriver (version 111.0.5563.64) detected in PATH: c:\Users\GitHub\Bots_using_selenium\linkedin_data_Scraping\chromedriver.exe
# dots problem
# logout problem
# signup probelm
# first_name-->problem
# last_name-->problem
# comp_email-->problem
# first_pass-->problem
# sec_pass-->problem
# agree_button-->problem
# signup_button-->problem
# country_button-->problem
# job_title-->problem
# department-->problem
# next_button-->problem
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 0
# ST1100
# STUDY1100
# linkedin user not found
# IIIIIIIIIIII1
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 1
# ST1100
# STUDY1100
# linkedin user not found
# IIIIIIIIIIII2
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 2
# ...

# %%
studies=[                                                               
 '    Italy studies',
 '    Literary and Cultural Analysis (literary studies)',
 '    Modern Greek language and culture',
 '    Ancient sciences',
 '    Russian and Slavic Studies',
 '    Scandinavian Studies',
 '    Sign Language Linguistics (Linguistics)',
 '    Ispanic and Latin American Studies',
 '    Amsterdam University Pabo',
 '    Administrative and organizational science',
 '    Movement Science',
 '    Cultural Anthropology and Development Sociology',
 '    Econometrics and Operations Research: Econometrics and Data Science',
 '    Econometrics and Business economics',
 '    English Language and Communication Studies',
 '    History and International Studies',
 '    Language and Media ',
 '    Language Learning and Language Teaching',
 '    Literature and Society',
 '    Media, Art, Design and Architecture',
 '    Ancient sciences',
 ]

# %% [markdown]
# '    Sign Language Linguistics (Linguistics)'=='    Sign Language Linguistics'
# '    Beta-gamma (Natural and Social Sciences)'=='   Natural and Social Sciences'
# Computational Social Science (Data- en sociale wetenschap)==Computational Social Science
# Literary and Cultural Analysis (literary studies)==Literary and Cultural Analysis
#
#  '    Oudheidwetenschappen'==Ancient sciences

# %%
l=['    Natural and Social Sciences',
 '    Cognition, Language and Communication',
 '    Communication Social Science',
 '    Computational Social Science',
 '    Duitslandstudies',
 '    Economics and Business Economics',
 '    Englisch language and Culture',
 '    European Studies',
 '    Fiscaal recht',
 '    Fiscale Economie',
 '    Global Arts, Culture and Politics ',
 '    Hebreeuwse taal en cultuur',
 '    Informatica',
 '    Italië studies',
 '    Literary and Cultural Analysis',
 '    Nieuwgriekse taal en cultuur',
 '    Ancient sciences',
 '    Politics, Psychology, Law and Economics (PPLE)',
 '    Religiewetenschappen',
 '    Russische en Slavische studies',
 '    Scandinavië studies',
 '    Sign Language Linguistics',
 '    Spaanse en Latijns-Amerikaanse studies',
 '    Theaterwetenschap',
 '    Universitaire Pabo van Amsterdam',
 '    Aarde, Economie en Duurzaamheid',
 '    Bestuurs- en organistatiewetenschap',
 '    Bewegingswetenschap',
 '    Culturele antropologie en Ontwikkelingssociolgie',
 '    Econometrics and Business economics',
 '    English Language and Communication Studies',
 '    History and International Studies',
 '    Language and Media ',
 '    Language Learning and Language Teaching',
 '    Law in Society',
 '    Literature and Society',
 '    Media en Journalistiek',
 '    Media, Art, Design and Architecture',
 '    Oudheidwetenschappen',
 '    Political Science and Economics',
 '    Universitaire Pabo']

# %%
list_old=[
'    Bestuurs- en organistatiewetenschap',
'    Beta-gamma (Natural and Social Sciences)',
'    Bewegingswetenschap',
'    Computational Social Science (Data- en sociale wetenschap)',
'    Culturele antropologie en Ontwikkelingssociolgie',
'    Duitslandstudies',
'    Englisch language and Culture',
'    Russische en Slavische studies',
]

# %%
studies="""Actuarial Science
    Actuariële Wetenschappen
    Ancient studies
    Arabische taal en cultuur
    Archeologie
    Biomedische wetenschappen
    Business administration (bedrijfskunde)
    Business Analytics
    Cognition, Language and Communication
    Communicatiewetenschap
    Communication Social Science
    Computational Social Science (Data- en sociale wetenschap)
    Cultural anthropology and Development Sociology
    Culturele antropologie en ontwikkelingssociologie 
    Cultuurwetenschappen
    Duitslandstudies
    Economics and Business Economics
    Englisch language and Culture
    European Studies
    Fiscaal recht
    Fiscale Economie
    Franse taal en cultuur
    Future Planet Studies
    Geneeskunde
    Geschiedenis
    Global Arts, Culture and Politics 
    Griekse en Latijnse taal en cultuur
    Hebreeuwse taal en cultuur
    Informatica
    Informatiekunde
    Interdisciplinaire sociale wetenschap
    Italië studies
    Kunstgeschiedenis
    Kunstmatige intelligentie
    Liberal Arts and Science
    Linguistics
    Literary and Cultural Analysis (literary studies)
    Media and Culture
    Media and Information
    Media en cultuur
    Medische informatiekunde
    Muziekwetenschap
    Natuur- en Sterrenkunde
    Nederlandse taal en cultuur
    Nieuwgriekse taal en cultuur
    Onderwijswetenschappen
    Oudheidwetenschappen
    Pedagogische wetenschappen
    Political Science
    Politicologie
    Politics, Psychology, Law and Economics (PPLE)
    Psychobiologie
    Rechtsgeleerdheid
    Religiewetenschappen
    Russische en Slavische studies
    Scandinavië studies
    Scheikunde
    Sign Language Linguistics (Linguistics)
    Sociale geografie en Planologie
    Sociology
    Spaanse en Latijns-Amerikaanse studies
    Tandheelkunde
    Theaterwetenschap
    Universitaire Pabo van Amsterdam
    Wiskunde
    Duitse Taal en Cultuur
    Literatuurwetenschap 
    Taalwetenschap
    Econometrie
    Artificial Intelligence
    Aarde, Economie en Duurzaamheid
    Aardewetenschappen
    Ancient studies
    Archeologie
    Bedrijfskunde
    Bestuurs- en organistatiewetenschap
    Bewegingswetenschap
    Business analytics
    Communicatie- en informatiewetenschappen
    communicatiewetenschap
    Communication and Information Studies
    Criminologie
    Cultural Anthropology and Development Sociology
    Culturele antropologie en Ontwikkelingssociolgie
    Econometrie en Operationele Research
    Econometrics and Business economics
    Economie en Bedrijfskunde
    English Language and Communication Studies
    Farmaceutische Wetenschappen
    Filosofie
    Geneeskunde 
    Geschiedenis
    Gezondheidswetenschappen
    Griekse en Latijnse Taal en Cultuur
    History and International Studies
    International Business Administration
    Language and Media 
    Language Learning and Language Teaching
    Law in Society
    Literature and Society
    Mechanical Engineering
    Media en Journalistiek
    Media, Art, Design and Architecture
    Media, Kunst, Design en Architectuur
    Natuur- en sterrenkunde
    Notarieel Recht
    Oudheidwetenschappen
    Philosophy, Politics and Economics
    Political Science and Economics
    scheikunde
    tandheelkunde
    Theology
    Universitaire Pabo"""
list_studies=studies.split("\n")

# %%
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from selenium import webdriver
import time
import pandas as pd

options = Options()
options.add_argument("user-data-dir=C:/Users/dell/AppData/Local/Google/Chrome/User Data/Profile 17")
driver = webdriver.Chrome(options=options)
# 'Mathematics and Bachelor words are used as a default, it is changeble
for study in list_studies:
    stud=study.strip()
    driver.get(f'https://www.google.com/search?q=site:nl.linkedin.com/in/+AND+%22{stud}%27&sxsrf=ALiCzsbOTqrA98wDQf3mtEB03kA_O7eCbQ:1668686082134&ei=AiF2Y4vwB-3JrgS9gpd4&start=50&sa=N&ved=2ahUKEwiL-aqJlLX7AhXtpIsKHT3BBQ84KBDy0wN6BAgBEA0&biw=920&bih=625&dpr=1')
    time.sleep(10) # to make slower 
    # n is the number of pages
    links = [] # save links here
    n=24
    while n > 0:
        time.sleep(5)
        for i in range(1, 11): # google uses paginator, every page has 10 urls
            time.sleep(6)
            try:
                elems = driver.find_elements(By.XPATH, '//*[@id="rso"]/div['+str(i)+']/div/div/div[1]/div/a')
                for elem in elems:
                    clean_url = elem.get_attribute("href") # extracting url 
                    base_url = "linkedin.com/in/"
                    if clean_url.find(base_url) != -1 and '%' not in clean_url: # sometimes google gives no Ln urls, so clean it
                        if clean_url not in links:
                            links.append(clean_url)
            except Exception as e:
                print(e)
                pass
        try:
            next_button = driver.find_element(By.XPATH, '//*[@id="pnnext"]') # clicking next button 
            next_button.click()
        except Exception as e:
            print(e)
        print(f'{n} pages left!')
        n -= 1
        if len(links)>=150:
            break
    df = pd.DataFrame({
        "links":links
    })

    try:
        df1=pd.read_csv(f'datas/linkedin_aaccount_links/{study}.csv')
        df=df.append(df1)
    except:
        pass
    try:
        df2=pd.read_csv(f'datas/linkedin_links/{study}.csv')
        df=df.append(df2)
    except:
        pass
    try:
        df3=pd.read_csv(f'datas/linkedin_links_04_04/{study}.csv')
        df=df.append(df2)
    except:
        pass
    try:
        df4=pd.read_csv(f'datas/linkedin_links_04_08/{study}.csv')
        df=df.append(df2)
    except:
        pass
    df = df.drop_duplicates()
    df.to_csv(f'datas/linkedin_links_05_01/{study}.csv', index=False)
    print(f'{study} is done')
# Out:
# 24 pages left!
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="pnnext"]"}
#   (Session info: chrome=112.0.5615.138)
# Stacktrace:
# Backtrace:
# 	(No symbol) [0x0065DCE3]
# 	(No symbol) [0x005F39D1]
# 	(No symbol) [0x00504DA8]
# 	(No symbol) [0x0053019F]
# 	(No symbol) [0x005303AB]
# 	(No symbol) [0x0055EE62]
# 	(No symbol) [0x0054AF14]
# 	(No symbol) [0x0055D57C]
# 	(No symbol) [0x0054ACC6]
# 	(No symbol) [0x00526F68]
# 	(No symbol) [0x005280CD]
# 	GetHandleVerifier [0x008D3832+2506274]
# 	GetHandleVerifier [0x00909794+2727300]
# 	GetHandleVerifier [0x0090E36C+2746716]
# 	GetHandleVerifier [0x00706690+617600]
# 	(No symbol) [0x005FC712]
# 	(No symbol) [0x00601FF8]
# 	(No symbol) [0x006020DB]
# 	(No symbol) [0x0060C63B]
# 	BaseThreadInitThunk [0x76860099+25]
# 	RtlGetAppContainerNamedObjectPath [0x77D87B6E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77D87B3E+238]
#
# 23 pages left!
# ...

# %%
df.to_csv(f'datas/linkedin_links_04_08/{study}.csv', index=False)

# %%
{             'Captain (D)': ['Ancient studies',
              'Future Planet Studies',
              'Wiskunde'],}
{             'Captain (D)': ['Culturele antropologie en ontwikkelingssociologie',
              'Geneeskunde',
              'Natuur- en Sterrenkunde',
              'Psychobiologie',
              'Geneeskunde',
              'Natuur- en sterrenkunde']}
# Out:
#                                                 links
# 0   https://nl.linkedin.com/in/carlien-rouschop-81...
# 1   https://nl.linkedin.com/in/jurriaan-mors-3446b...
# 2             https://nl.linkedin.com/in/henkscholder
# 3   https://nl.linkedin.com/in/diana-willemsen-624...
# 4   https://nl.linkedin.com/in/naomi-mestrum-0a535321
# 5                  https://nl.linkedin.com/in/c-nooij
# 6          https://nl.linkedin.com/in/renate-smithuis
# 7   https://nl.linkedin.com/in/joram-markerink-1b0...
# 8   https://nl.linkedin.com/in/dodo-van-uden-154a5385
# 9     https://nl.linkedin.com/in/rob-dekker-42557a18a
# 10  https://nl.linkedin.com/in/wilco-boekhorst-18b...
# 11   https://nl.linkedin.com/in/kees-duijzer-184144a8
# 12  https://nl.linkedin.com/in/auke-zeldenrust-669...
# 13  https://nl.linkedin.com/in/niek-de-wilde-9231b216
# 14   https://nl.linkedin.com/in/communicatieworkshops
# 15  https://nl.linkedin.com/in/judith-bosscher-6b8...
# ...

# %%
import pandas as pd

# %%
df1 = pd.read_csv('datas/linkedin_aaccount_links/    Aarde, Economie en Duurzaamheid.csv')
df2 = pd.read_csv('datas/linkedin_aaccount_links/    Aardewetenschappen.csv')
df3=df1.append(df2)
# Out:
# C:\Users\fayyo\AppData\Local\Temp\ipykernel_12556\3735331325.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df3=df1.append(df2)

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 96 entries, 0 to 53
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   links   96 non-null     object
# dtypes: object(1)
# memory usage: 1.5+ KB

# %%
doct_={1:'natural-and-social-sciences'}
doct_

# %%
l=['    Natural and Social Sciences',
 '    Cognition, Language and Communication',
 '    Communication Social Science',
 '    Computational Social Science',
 '    Duitslandstudies',
 '    Economics and Business Economics',
 '    Englisch language and Culture',
 '    European Studies',
 '    Fiscaal recht',
 '    Fiscale Economie',
 '    Global Arts, Culture and Politics ',
 '    Hebreeuwse taal en cultuur',
 '    Informatica',
 '    Italië studies',
 '    Literary and Cultural Analysis',
 '    Nieuwgriekse taal en cultuur',
 '    Ancient sciences',
 '    Politics, Psychology, Law and Economics (PPLE)',
 '    Religiewetenschappen',
 '    Russische en Slavische studies',
 '    Scandinavië studies',
 '    Sign Language Linguistics',
 '    Spaanse en Latijns-Amerikaanse studies',
 '    Theaterwetenschap',
 '    Universitaire Pabo van Amsterdam',
 '    Aarde, Economie en Duurzaamheid',
 '    Bestuurs- en organistatiewetenschap',
 '    Bewegingswetenschap',
 '    Culturele antropologie en Ontwikkelingssociolgie',
 '    Econometrics and Business economics',
 '    English Language and Communication Studies',
 '    History and International Studies',
 '    Language and Media ',
 '    Language Learning and Language Teaching',
 '    Law in Society',
 '    Literature and Society',
 '    Media en Journalistiek',
 '    Media, Art, Design and Architecture',
 '    Oudheidwetenschappen',
 '    Political Science and Economics',
 '    Universitaire Pabo']

# %%
list_old=[
'    Bestuurs- en organistatiewetenschap',
'    Beta-gamma (Natural and Social Sciences)',
'    Bewegingswetenschap',
'    Computational Social Science (Data- en sociale wetenschap)',
'    Culturele antropologie en Ontwikkelingssociolgie',
'    Duitslandstudies',
'    Englisch language and Culture',
'    Russische en Slavische studies',
]

# %%
list_nans=[
    '    Media, Art, Design and Architecture',
    '    Oudheidwetenschappen',
    '    Political Science and Economics',
    '    Englisch language and Culture',
    '    Duitslandstudies',
    
    ''
]

# %%
studies="""Actuarial Science
    Actuariële Wetenschappen
    Ancient studies
    Arabische taal en cultuur
    Archeologie
    Biomedische wetenschappen
    Business administration (bedrijfskunde)
    Business Analytics
    Cognition, Language and Communication
    Communicatiewetenschap
    Communication Social Science
    Computational Social Science (Data- en sociale wetenschap)
    Cultural anthropology and Development Sociology
    Culturele antropologie en ontwikkelingssociologie 
    Cultuurwetenschappen
    Duitslandstudies
    Economics and Business Economics
    Englisch language and Culture
    European Studies
    Fiscaal recht
    Fiscale Economie
    Franse taal en cultuur
    Future Planet Studies
    Geneeskunde
    Geschiedenis
    Global Arts, Culture and Politics 
    Griekse en Latijnse taal en cultuur
    Hebreeuwse taal en cultuur
    Informatica
    Informatiekunde
    Interdisciplinaire sociale wetenschap
    Italië studies
    Kunstgeschiedenis
    Kunstmatige intelligentie
    Liberal Arts and Science
    Linguistics
    Literary and Cultural Analysis (literary studies)
    Media and Culture
    Media and Information
    Media en cultuur
    Medische informatiekunde
    Muziekwetenschap
    Natuur- en Sterrenkunde
    Nederlandse taal en cultuur
    Nieuwgriekse taal en cultuur
    Onderwijswetenschappen
    Oudheidwetenschappen
    Pedagogische wetenschappen
    Political Science
    Politicologie
    Politics, Psychology, Law and Economics (PPLE)
    Psychobiologie
    Rechtsgeleerdheid
    Religiewetenschappen
    Russische en Slavische studies
    Scandinavië studies
    Scheikunde
    Sign Language Linguistics (Linguistics)
    Sociale geografie en Planologie
    Sociology
    Spaanse en Latijns-Amerikaanse studies
    Tandheelkunde
    Theaterwetenschap
    Universitaire Pabo van Amsterdam
    Wiskunde
    Duitse Taal en Cultuur
    Literatuurwetenschap 
    Taalwetenschap
    Econometrie
    Artificial Intelligence
    Aarde, Economie en Duurzaamheid
    Aardewetenschappen
    Ancient studies
    Archeologie
    Bedrijfskunde
    Bestuurs- en organistatiewetenschap
    Bewegingswetenschap
    Business analytics
    Communicatie- en informatiewetenschappen
    communicatiewetenschap
    Communication and Information Studies
    Criminologie
    Cultural Anthropology and Development Sociology
    Culturele antropologie en Ontwikkelingssociolgie
    Econometrie en Operationele Research
    Econometrics and Business economics
    Economie en Bedrijfskunde
    English Language and Communication Studies
    Farmaceutische Wetenschappen
    Filosofie
    Geneeskunde 
    Geschiedenis
    Gezondheidswetenschappen
    Griekse en Latijnse Taal en Cultuur
    History and International Studies
    International Business Administration
    Language and Media 
    Language Learning and Language Teaching
    Law in Society
    Literature and Society
    Mechanical Engineering
    Media en Journalistiek
    Media, Art, Design and Architecture
    Media, Kunst, Design en Architectuur
    Natuur- en sterrenkunde
    Notarieel Recht
    Oudheidwetenschappen
    Philosophy, Politics and Economics
    Political Science and Economics
    scheikunde
    tandheelkunde
    Theology
    Universitaire Pabo"""
list_studies=studies.split("\n")

# %%
from bs4 import BeautifulSoup
import time
from selenium.webdriver.chrome.options import Options
from selenium import webdriver
from selenium.webdriver.common.by import By
import pandas as pd

options = Options()
options.add_argument("user-data-dir=C:\\Users\\Username\\AppData\\Local\\Google\\Chrome\\User Data")
driver = webdriver.Chrome(options=options)
driver.get('https://www.crystalknows.com/app/ce/installed')
time.sleep(11)

for study in list_studies:
    print(study)
    study_num=list_studies.index(study)
    try:
        try:
            dots=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/div[1]/nav/div/div/div/div[6]/div/div[1]/div[2]/div/div/div')
            dots.click()
            time.sleep(2)
        except:
            print('dots problem')
        try:
            logout=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/div[1]/nav/div/div/div/div[6]/div/div[2]/div[6]/a')
            logout.click()
            time.sleep(5)
        except:
            print('logout problem')
        try:
            signup=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div[3]/div/form/div[3]/div/a')
            signup.click()
            time.sleep(8)
        except:
            print('signup probelm')
        try:
            first_name_input=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div/div[2]/div[1]/input')
            first_name_input.click()
            first_name_input.send_keys(f'Alibek')
        except Exception as e:
            print('first_name-->problem')
        try:
            last_name_input=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div/div[2]/div[2]/input')
            last_name_input.click()
            last_name_input.send_keys(f'Aliyev')
        except Exception as e:
            print('last_name-->problem')
        try:
            comp_email_input=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div/div[3]/div/input')
            comp_email_input.click()
            comp_email_input.send_keys(f'wg{str(study_num)}@mail.ru')
        except Exception as e:
            print('comp_email-->problem')
        try:
            first_pass_input=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div/div[4]/div[1]/input')
            first_pass_input.click()
            first_pass_input.send_keys('Aa2301667')
        except Exception as e:
            print('first_pass-->problem')
        try:    
            sec_pass_input=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div/div[4]/div[2]/input')
            sec_pass_input.click()
            sec_pass_input.send_keys('Aa2301667')
        except Exception as e:
            print('sec_pass-->problem')
        try:
            agree_button=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div/div[5]/div/label/div/img')
            agree_button.click()
        except Exception as e:
            print('agree_button-->problem')
        try:                                            #/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div/div[6]/button
            signup_button=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div/div[6]/button')
            signup_button.click()
            time.sleep(10)
        except Exception as e:
            print('signup_button-->problem')
        try:
            country_button=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[1]/div[2]/div/div[2]/img')
            country_button.click()
            first_country=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[1]/div[2]/div[2]/div[1]')
            first_country.click()
        except Exception as e:
            print('country_button-->problem')                                # second country    '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[1]/div[2]/div[2]/div[2]'
        try:
            job_title_input=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[2]/input')
            job_title_input.click()
            job_title_input.send_keys('software engineer')
        except Exception as e:
            print('job_title-->problem')
        try:    
            my_department_input=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[2]/div[3]/div/div[2]')
            my_department_input.click()
            first_department=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[2]/div[3]/div[2]/div[1]')                              #  second department           '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[2]/div[3]/div[2]/div[2]'
            first_department.click()
        except Exception as e:
            print('department-->problem')
        try:    
            next_button=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[2]/a')
            next_button.click()
            time.sleep(10)
        except Exception as e:
            print('next_button-->problem')
    except Exception as e:
        print('cannot create new account!')

    i=0

    df_links = pd.read_csv(f'datas/linkedin_links_05_01/{study}.csv')
    df = df_links.drop_duplicates()
    dict_={}
    for link in df.links[:70]:
        i+=1
        try: 
            link_enterong_button=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/div[1]/nav/div/div[1]/div/div[1]/div/input')
            link_enterong_button.click()
            link_enterong_button.clear()
            link_enterong_button.send_keys(link)
            time.sleep(8) 
        except Exception as e:
            print("linkedin user not found")
        try:                          # /html/body/div[2]/div/div/div[2]/div[1]/nav/div/div[1]/div/div[1]/div/div[2]/div/div/div/div/div[2]
            first_user=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/div[1]/nav/div/div[1]/div/div[1]/div/div[2]/div/div/div/div/div[2]')
            first_user.click()
            time.sleep(10)
            src = driver.page_source
            soup = BeautifulSoup(src, 'lxml')
            cs=soup.find('div', {'class':'styles_disc-pill-wrapper__aB3OJ'})
            dict_[link]=cs.text.strip()
        except Exception as e:
            dict_[link]='nan'
            continue
        price_butt=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/div[1]/nav/div/div[2]/div/div[1]').text
        if price_butt=='0 of 10 profiles remaining':
            print('Matched!!')
            dots1=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/div[1]/nav/div/div[1]/div/div[6]/div/div[1]/div[2]/div/div')
            dots1.click()
            print(dots1)
            time.sleep(2)

            logout1=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/div[1]/nav/div/div/div/div[6]/div/div[2]/div[6]/a')
            logout1.click()
            time.sleep(5)
            signup=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div[3]/div/form/div[3]/div/a')
            signup.click()
            time.sleep(8)

            first_name_input=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div/div[2]/div[1]/input')
            first_name_input.click()
            first_name_input.send_keys(f'Alibek+{str(i)}')
          
            last_name_input=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div/div[2]/div[2]/input')
            last_name_input.click()
            last_name_input.send_keys(f'Aliyev{str(i)}')
            comp_email_input_for_10=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div/div[3]/div/input')
            comp_email_input_for_10.click()
            comp_email_input_for_10.send_keys(f'wg{str(study_num)}{str(i)}@mail.ru')
          
            first_pass_input=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div/div[4]/div[1]/input')
            first_pass_input.click()
            first_pass_input.send_keys('Aa2301667')
             
            sec_pass_input=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div/div[4]/div[2]/input')
            sec_pass_input.click()
            sec_pass_input.send_keys('Aa2301667')
        
            agree_button1=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div/div[5]/div/label/div/img')
            agree_button1.click()
       
            signup_button1=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/header/div[2]/div[2]/div/div/div[3]/form/div/div[6]/button')
            signup_button1.click()
            time.sleep(10)
          
            country_button=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[1]/div[2]/div/div[2]/img')
            country_button.click()
            first_country=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[1]/div[2]/div[2]/div[1]')
            first_country.click()

            job_title_input=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[2]/input')
            job_title_input.click()
            job_title_input.send_keys('software engineer')

            try:    
                my_department_input=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[2]/div[3]/div/div[2]')
                my_department_input.click()
                first_department=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[2]/div[3]/div[2]/div[1]')                              #  second department           '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[1]/div/div/div/div[1]/div[2]/div[3]/div[2]/div[2]'
                first_department.click()
            except Exception as e:
                print('department-->problem')
            # try:    
            next_button=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div[4]/header/div[2]/div[2]/div/div[2]/a')
            next_button.click()
            time.sleep(10)

    df1 = pd.DataFrame({
    'links':list(dict_.keys()),
    'characters':list(dict_.values())
    })
    df1.to_csv(f'datas/cs_values/{study}1.csv', index=False)
    print(list(dict_.values())[-10:])
    print(f'{study} is done!')
# Out:
#     Ancient sciences
# Matched!!
# <selenium.webdriver.remote.webelement.WebElement (session="a136b9e6bf0188997330251f09029757", element="6260d39f-04b3-4eb0-bbfd-7fd558592ba8")>
# Matched!!
# <selenium.webdriver.remote.webelement.WebElement (session="a136b9e6bf0188997330251f09029757", element="2f398377-3cc6-4941-9ab8-23a29bda9feb")>
# Matched!!
# <selenium.webdriver.remote.webelement.WebElement (session="a136b9e6bf0188997330251f09029757", element="39123d3d-b15e-4d05-a966-f8f36c6424ed")>
# Matched!!
# <selenium.webdriver.remote.webelement.WebElement (session="a136b9e6bf0188997330251f09029757", element="b3ebc420-9100-423f-ae14-40e03db750a9")>
# Matched!!
# <selenium.webdriver.remote.webelement.WebElement (session="a136b9e6bf0188997330251f09029757", element="a2db728d-0412-477a-b720-aa7c7e8823ef")>
# Matched!!
# <selenium.webdriver.remote.webelement.WebElement (session="a136b9e6bf0188997330251f09029757", element="17c51110-e9f6-462d-9639-39bcba7110c1")>
# ...

# %%
# theese studies filled with nan values, but more than 50 users:
list_nans=[
    "    Ancient sciences", 
    "    Biomedische wetenschappen",
    '    Econometrie1',
    '    Media, Art, Design and Architecture1',
    '    Oudheidwetenschappen1',
    '    Political Science and Economics1',
    '    Sociale geografie en Planologie1',
    '    Theology1',
    '    Wiskunde1',
]

# %%
no_linkedin_links=[
    '    Bestuurs- en organistatiewetenschap',
    '    Beta-gamma (Natural and Social Sciences)',
    '    Bewegingswetenschap1',
    '    Computational Social Science (Data- en sociale wetenschap)1'
    '    Culturele antropologie en Ontwikkelingssociolgie1'
]

# %%
a="""
recommended_jobs_Chemistry=['analytical, formulation, medicinal or process chemist',
 'chemical or geochemical engineer',
 'biotechnologist',
 'drug discovery and chemical industries',
 'environmental, forensic or materials scientist',
 'food technologist',
 'nanotechnologist ',
 'patent attorney',
 'pharmacologist ',
 'science writer',
 'scientific laboratory technician',
 'teacher',
 'toxicologist',
 'accountant',
 'banking',
 'IT consultant',
 'journalist',
 'management consultant',
 'marketer or salesperson']

recommended_jobs_MATH=[
    "Aerospace engineer",
    "Astronomer",
    "CAD technician",
    "Financial trader",
    "Game designer",
    "Market researcher",
    "Meteorologist",
    "Neuropsychologist",
    "Quantity surveyor",
    "Software tester",
    "Acoustic specialist",
    "Actuary",
    "Chartered accountant",
    "Cryptographer",
    "Data scientist",
    "Economist",
    "Investment analyst",
    "Mathematician",
    "Medical statistician",
    "Meteorologist",
    "Operations research analyst",
    "Research scientist",
    "Risk management officer",
    "Software engineer",
    "Statistician",
    "Teacher or lecturer",
    "Technician"
]

recommended_jobs_Art_History=['ArithmeticErrorarchivist ',
 'conservationist',
 'education',
 'exhibitions officer in a gallery or museum',
 'gallery curator',
 'heritage manager',
 'historic buildings inspector',
 'journalist',
 'librarian',
 'marketing',
 'museum curator',
 'publisher',
 'teacher']

recommended_jobs_BioChemistry=['analytical, formulation, medicinal or process chemist',
 'chemical or geochemical engineer',
 'biotechnologist',
 'drug discovery and chemical industries',
 'environmental, forensic or materials scientist',
 'food technologist',
 'nanotechnologist ',
 'patent attorney',
 'pharmacologist ',
 'science writer',
 'scientific laboratory technician',
 'teacher',
 'toxicologist',
 'accountant',
 'banking',
 'IT consultant',
 'journalist',
 'management consultant',
 'marketer or salesperson']

recommended_jobs_Biology=['biotechnologist',
 'marine biologist',
 'microbiologist',
 'nanotechnologist ',
 'nature conservation officer',
 'pharmacologist ',
 'research scientist',
 'scientific laboratory technician',
 'soil scientist',
 'teaching laboratory technician',
 'academic researcher',
 'higher education lecturer',
 'secondary school teacher']

recommended_jobs_Biomedical_Science=['analytical chemist',
 'biomedical, clinical, forensic or research scientist',
 'biotechnologist',
 'crime scene investigator',
 'dental therapist',
 'environmental engineer',
 'genetic counsellor',
 'medical chemist',
 'medical science liaison',
 'nanotechnologist',
 'neuroscientist',
 'physician associate',
 'science writer',
 'toxicologist']

recommended_jobs_Computer_Science=['advertiser, marketer and publicist',
 'applications, games or web developer',
 'banker',
 'digital content writer ',
 'forensic computer analyst',
 'SEO specialist',
 'social media or web content manager',
 'software engineer',
 'system analyst',
 'telecommunications and media production',
 'UX (user experience) or web designe']


recommended_jobs_English_Literature=['archivist',
 'the arts',
 'the civil service',
 'content editor',
 'copywriter',
 'digital content officer or manager',
 'editorial assistant',
 'journalist',
 'librarian',
 'marketing executive',
 'media',
 'the museum sector',
 'proofreader',
 'public relations officer',
 'publishing editor',
 'social media officer or manager',
 'teacher',
 'writer']

recommended_jobs_History=['archaeologist',
 'archivist',
 'broadcaster',
 'charity worker',
 'the civil service and government',
 'copywriter',
 'editorial assistant',
 'education',
 'exhibitions officer',
 'heritage manager',
 'historic buildings inspector',
 'politics and international development',
 'librarian',
 'marketing executive',
 'museum curator',
 'the media',
 'policy officer',
 'social researcher',
 'teacher']

recommended_jobs_neuroscience=['biotechnologist',
 'clinical research assistant',
 'clinical scientist ',
 'forensic science technician',
 'laboratory or pharmacy technician',
 'medical and healthcare or natural sciences manager',
 'pharmaceutical researcher',
 'psychometrist',
 'residential counsellor',
 'sales engineer']

recommended_jobs_philosophy=['advertising executive',
 'arts',
 'civil service officer',
 'communications officer',
 'non-governmental organisations',
 'health and social worker',
 'human relations officer',
 'journalist and writer',
 'local government officer',
 'manager',
 'marketing executive',
 'media',
 'public relations officer',
 'politics ',
 'publishing',
 'school teacher']

recommended_jobs_Physics=['associate technologist',
 'business analyst',
 'business consultant',
 'business technologies associate',
 'data analyst',
 'data engineer',
 'development engineer',
 'geophysicist',
 'graduate financial software developer',
 'industry data analyst',
 'instrumentation researcher and developer',
 'MWM consultant',
 'performance analyst',
 'software developer',
 'systems engineer',
 'technical director',
 'trainee project manager',
 'trainee solutions developer']

recommended_jobs_actuariële_wetenschappen=['Actuary',
 'Risk Manager',
 'Insurance Analyst',
 'Pension Consultant',
 'Investment Analyst',
 'Financial Planner',
 'Underwriter',
 'Business Analyst',
 'Data Analyst',
 'Product Manager',
 'Claims Analyst',
 'Loss Control Specialist',
 'Reinsurance Specialist',
 'Pricing Analyst',
 'Asset Liability Management (ALM) Analyst',
 'Solvency II Specialist',
 'Catastrophe Risk Analyst',
 'Liability Management Specialist',
 'Derivatives Pricing Analyst',
 'Retirement Consultant'] 

recommended_jobs_ancient_studies=['Archaeologist',
 'Museum Curator',
 'Historian',
 'Academic Researcher',
 'Art Historian',
 'Conservation Specialist',
 'Archivist',
 'Classics Professor',
 'Anthropologist',
 'Heritage Consultant',
 'Tour Guide',
 'Cultural Resource Manager',
 'Historical Interpreter',
 'Epigrapher',
 'Language Specialist',
 'Numismatist',
 'Manuscript Editor',
 'Philologist',
 'Digital Humanities Specialist',
 'Academic Advisor']      
           
recommended_jobs_business_administration=['Business Analyst',
 'Management Consultant',
 'Financial Analyst',
 'Marketing Manager',
 'Human Resource Manager',
 'Sales Manager',
 'Project Manager',
 'Procurement Manager',
 'Operations Manager',
 'Supply Chain Manager',
 'Business Development Manager',
 'Account Manager',
 'Risk Manager',
 'Commercial Manager',
 'Customer Experience Manager',
 'Change Management Consultant',
 'Data Analyst',
 'Brand Manager',
 'Product Manager',
 'Logistics Manager   '] 

recommended_jobs_cognition_language_and_communication= ['university instructor,',
 'human factors consultant, ',
 'industrial-organizational manager,',
 'communication trainer,',
 'communication consultant,',
 '(online) content manager,',
 'editor,',
 'copywriter,',
 'journalist',
 'Business and marketing',
 'Information technology',
 'Health care',
 'Law',
 'Education',
 'Research and development',
 'Government and politics',
 'Psychology ']

recommended_jobs_communicatiewetenschap=['Public Relations Specialist',
 'Marketing Manager',
 'Social Media Manager',
 'Advertising Account Executive',
 'Corporate Communications Manager',
 'Market Research Analyst',
 'Media Planner',
 'Event Planner',
 'Content Strategist',
 'Journalist ']

recommended_jobs_communication_social_science=['',
 'Public Relations Specialist',
 'Marketing Coordinator',
 'Advertising Manager',
 'Social Media Specialist',
 'Media Planner',
 'Corporate Communications Manager',
 'Event Planner',
 'Content Writer',
 'Grant Writer',
 'Community Relations Specialist',
 'Digital Content Strategist',
 'Market Research Analyst',
 'Journalist',
 'Nonprofit Fundraiser',
 'Speechwriter',
 'Public Affairs Officer',
 'Political Campaign Manager',
 'Lobbyist',
 'Customer Experience Specialist',
 'Brand Manager'] 

recommended_jobs_computational_social_science_data_en_sociale_wetenschap=[                   '' 
 'Data Scientist',
 'Quantitative Researcher',
 'Machine Learning Engineer',
 'Research Analyst',
 'Social Network Analyst',
 'Computational Linguist',
 'Information Scientist',
 'Business Intelligence Analyst',
 'Data Analyst',
 'Market Researcher',
 'UX Researcher',
 'Statistician',
 'Operations Research Analyst',
 'Digital Marketing Analyst',
 'Predictive Modeler',
 'Risk Analyst',
 'Data Mining Analyst',
 'Big Data Engineer',
 'Bioinformatics Scientist',
 'Computational Economis']
recommended_jobs_cultural_anthropology_and_development_sociology=['',
 'Anthropologist',
 'Sociologist',
 'Ethnographer',
 'Social Researcher',
 'Human Rights Officer',
 'Cultural Advisor',
 'Social Justice Advocate',
 'Policy Analyst',
 'Development Consultant',
 'Gender Specialist',
 'Community Development Officer',
 'Nonprofit Program Manager',
 'Public Health Researcher',
 'International Aid Worker',
 'Conflict Resolution Specialist',
 'Humanitarian Relief Coordinator',
 'Cultural Resource Manager',
 'Community Organizer',
 'Educator',
 'Environmental Justice Advocate',
 '']
recommended_jobs_cultuurwetenschappen= ['',
 'English Language Teacher/Instructor',
 'Translator/Interpreter',
 'Content Writer/Editor',
 'Copywriter',
 'Linguist',
 'Language and Culture Consultant',
 'Cultural Analyst',
 'Cross-Cultural Trainer',
 'Foreign Correspondent/Journalist',
 'Language Program Director',
 'Public Relations Specialist',
 'Travel Writer/Blogger',
 'Film/TV Critic',
 'Speechwriter',
 'International Sales Representative',
 'Marketing Manager',
 'Human Resources Specialist',
 'Social Media Manager',
 'Customer Service Representative',
 'Event Planner.',
 '']
recommended_jobs_duitslandstudies=['',
 'Diplomat',
 'International Development Specialist',
 'International Relations Specialist',
 'Policy Analyst',
 'Researcher',
 'Political Scientist',
 'Historian',
 'Journalist',
 'Translator/Interpreter',
 'Cultural Attaché',
 'International Trade Specialist',
 'International Business Manager',
 'Public Affairs Specialist',
 'Human Rights Advocate',
 'Immigration Specialist',
 'NGO Program Manager',
 'European Union (EU) Policy Advisor',
 'European Parliament Member/Assistant',
 'Foreign Service Officer',
 'European Economic and Financial Analyst.',
 '']
recommended_jobs_fiscaal_recht=['',
 'Tax lawyer',
 'Tax advisor',
 'Tax consultant',
 'Tax manager',
 'Tax inspector',
 'Tax accountant',
 'Corporate tax specialist',
 'International tax specialist',
 'Estate planning attorney',
 'Trust and estate tax attorney',
 'Tax court judge',
 'Tax policy analyst',
 'Tax examiner',
 'Tax law professor',
 'Transfer pricing specialist',
 'Customs compliance specialist',
 'VAT specialist',
 'Tax compliance officer',
 'Tax systems analyst',
 'Tax software developer.',
 '']
recommended_jobs_franse_taal_en_cultuur=['',
 'Tax lawyer',
 'Tax advisor',
 'Tax consultant',
 'Tax manager',
 'Tax inspector',
 'Tax accountant',
 'Corporate tax specialist',
 'International tax specialist',
 'Estate planning attorney',
 'Trust and estate tax attorney',
 'Tax court judge',
 'Tax policy analyst',
 'Tax examiner',
 'Tax law professor',
 'Transfer pricing specialist',
 'Customs compliance specialist',
 'VAT specialist',
 'Tax compliance officer',
 'Tax systems analyst',
 'Tax software developer.',
 '']
recommended_jobs_future_Planet_Studies=['',
 'Environmental Scientist',
 'Climate Change Analyst',
 'Sustainability Coordinator',
 'Renewable Energy Engineer',
 'Environmental Lawyer',
 'Environmental Educator',
 'Green Building Architect',
 'Sustainable Agriculture Specialist',
 'Environmental Economist',
 'Conservation Biologist.',
 'Environmental Policy Analyst',
 'Water Resource Manager',
 'Environmental Health and Safety Specialist',
 'Carbon Footprint Analyst',
 'Wildlife Biologist',
 'Urban Planner (with an emphasis on sustainable development)',
 'Environmental Communications Specialist',
 'Ecotourism Coordinator',
 'Green Business Manager',
 'Natural Resource Manager',
 '']
recommended_jobs_geneeskunde=['',
 'General Practitioner/Family Medicine Physician',
 'Surgeon',
 'Obstetrician/Gynecologist',
 'Pediatrician',
 'Cardiologist',
 'Oncologist',
 'Anesthesiologist',
 'Neurologist',
 'Dermatologist',
 'Psychiatrist',
 'Radiologist',
 'Pathologist',
 'Emergency Medicine Physician',
 'Endocrinologist',
 'Infectious Disease Specialist',
 'Geriatrician',
 'Pulmonologist',
 'Allergist/Immunologist',
 'Ophthalmologist',
 'Sports Medicine Physician',
 '']
recommended_jobs_geschiedenis= ['',
 'Historian',
 'Archivist',
 'Curator',
 'Museum Educator',
 'Researcher',
 'Writer/Author',
 'Journalist',
 'Teacher/Professor',
 'Heritage Consultant',
 'Historical Interpreter',
 'Tour Guide',
 'Preservation Specialist',
 'Public Historian',
 'Documentary Filmmaker',
 'Genealogist',
 'Cultural Resource Manager',
 'Historical Society Administrator',
 'Government Historian',
 'Archaeologist',
 'Film or TV Historical Consultant',
 '']                                                                                                                                                      
recommended_jobs_global_arts_culture_and_politics=['',
 'Cultural Affairs Officer',
 'International Relations Specialist',
 'Diplomat',
 'Arts Program Manager',
 'Museum Curator',
 'Art Historian',
 'Cultural Anthropologist',
 'Public Policy Analyst',
 'Nonprofit Program Director',
 'International Development Consultant',
 'Foreign Correspondent',
 'Documentary Filmmaker',
 'Cultural Heritage Manager',
 'International Trade Specialist',
 'Cross-Cultural Trainer',
 'Global Marketing Manager',
 'International Education Coordinator',
 'International Human Rights Advocate',
 'International Conflict Resolution Specialist',
 'International Business Consultant',
 '']
recommended_jobs_griekse_en_latijnse_taal_en_cultuur=['',
 'Classicist',
 'Latin Teacher',
 'Greek Teacher',
 'Museum Curator (of classical art and artifacts)',
 'Archaeologist (specializing in Greek and Roman cultures)',
 'Historical Fiction Writer',
 'Translator (of ancient Greek and Latin texts)',
 'Philology Professor',
 'Mythology Researcher',
 'Ancient History Professor',
 'Epigraphy Specialist',
 'Manuscript Librarian (for ancient texts)',
 'Classics Book Editor',
 'Classical Musician',
 'Art Historian (with specialization in Greek and Roman art)',
 'Latin Language Analyst (for language-based jobs such as translation, interpretation or speech writing)',
 'Classical Archaeology Researcher',
 'Academic Advisor (for Classics majors)',
 'Classics Curriculum Developer',
 'Lecturer in Ancient Languages and Cultures',
 '']
recommended_jobs_hebreeuwse_taal_en_cultuur=['',
 'Translator/Interpreter',
 'Language Teacher',
 'Cultural Consultant',
 'Museum Curator',
 'Historian',
 'Researcher',
 'Archivist',
 'Linguist',
 'Tour Guide',
 'Non-profit Administrator',
 'Community Outreach Coordinator',
 'Intercultural Communication Specialist',
 'Foreign Language Correspondent',
 'Diplomat',
 'Peace Corps Volunteer',
 'Travel Writer',
 'Cultural Event Planner',
 'Human Rights Advocate',
 'Media Relations Specialist',
 'Social Media Manager',
 ]
recommended_jobs_informatica=[
 'ETL Developer',
 'Data Analyst',
 'Data Architect',
 'Business Intelligence Analyst',
 'Informatica Administrator',
 'Data Warehouse Developer',
 'Data Engineer',
 'Software Engineer',
 'Integration Specialist',
 'Technical Lead',
 'Project Manager',
 'Database Administrator',
 'Solution Architect',
 'Data Modeler',
 'Data Scientist',
 'Big Data Developer',
 'Technical Consultant',
 'Systems Analyst',
 'Informatica Developer',
 'Quality Assurance Engineer',
 ]
recommended_jobs_informatiekunde=[
 'Data Analyst',
 'Business Analyst',
 'Information Architect',
 'Database Administrator',
 'Systems Analyst',
 'Data Scientist',
 'IT Project Manager',
 'Data Warehouse Specialist',
 'IT Consultant',
 'Technical Writer',
 'Software Developer',
 'Information Security Analyst',
 'Business Intelligence Analyst',
 'Technical Support Specialist',
 'Network Administrator',
 'Information Systems Manager',
 'User Experience Designer',
 'Web Developer',
 'Cloud Engineer',
 'Quality Assurance Tester',
 '']
recommended_jobs_interdisciplinaire_sociale_wetenschap=['',
 'Social Researcher',
 'Policy Analyst',
 'Project Coordinator',
 'Community Development Officer',
 'Nonprofit Program Manager',
 'Social Impact Analyst',
 'Program Evaluation Specialist',
 'Social Work Case Manager',
 'Youth Outreach Worker',
 'Health Educator',
 'Human Services Coordinator',
 'Community Outreach Coordinator',
 'Grant Writer',
 'Social Media Strategist',
 'Diversity and Inclusion Specialist',
 'Public Relations Specialist',
 'Marketing Research Analyst',
 'Fundraising Manager',
 'Social Policy Advocate',
 'International Development Coordinator',
 '']
recommended_jobs_italië_studies=['',
 'Italian Language Teacher',
 'Tour Guide in Italy',
 'Italian Culture Specialist',
 'Italian History Researcher',
 'Italian Cuisine Chef',
 'Italian Fashion Designer',
 'Italian Music Instructor',
 'Italian Art Historian',
 'Italian Wine Sommelier',
 'Italian Translator',
 'Italian Literature Professor',
 'Italian Archaeologist',
 'Italian Film Critic',
 'Italian Travel Writer',
 'Italian Business Consultant',
 'Italian Immigration Lawyer',
 'Italian Religious Studies Professor',
 'Italian Environmental Researcher',
 'Italian Sports Reporter',
 'Italian Opera Singer.',
 '']  
recommended_jobs_kunstgeschiedenis=['',
 'Art Historian',
 'Museum Curator',
 'Art Appraiser',
 'Gallery Manager',
 'Art Conservator',
 'Art Auction Specialist',
 'Art Researcher',
 'Art Critic',
 'Art Consultant',
 'Art Educator',
 'Art Cataloguer',
 'Art Librarian',
 'Art Writer',
 'Art Authentication Specialist',
 'Art Collections Manager',
 'Art Registrar',
 'Art Archivist',
 'Art Historiographer',
 'Art Documentation Specialist',
 'Art Gallery Owner.',
 '']
recommended_jobs_linguistics=['',
 'Linguistic Consultant',
 'Language Analyst',
 'Computational Linguist',
 'Speech Language Pathologist',
 'Language Teacher',
 'Lexicographer',
 'Bilingual Education Coordinator',
 'Discourse Analyst',
 'Translation Specialist',
 'Language Technologist',
 'Language Localization Manager',
 'Forensic Linguist',
 'Language Project Manager',
 'Language Documentation Specialist',
 'Applied Linguist',
 'Language Assessment Specialist',
 'Language Data Analyst',
 'Language Policy Analyst',
 'Speech Scientist',
 'Language Access Coordinator',
 '']                            
recommended_jobs_literary_and_cultural_analysis_literary_studies=['Literary Editor',
 'Literary Critic',
 'Cultural Analyst',
 'Literature Professor',
 'Literary Agent',
 'Copy Editor',
 'Literary Translator',
 'Researcher',
 'Manuscript Editor',
 'Freelance Writer',
 'Writing Consultant',
 'Content Manager',
 'Creative Writing Instructor',
 'Literary Publicist',
 'Literary Reviewer',
 'Literary Archivist',
 'Literary Event Coordinator',
 'Literary Grant Writer',
 'Literary Research Assistant',
 'Literary Magazine ',
 '']
recommended_jobs_media_and_culture=['',
 'Media Producer',
 'Culture Writer',
 'Media Analyst',
 'Communications Specialist',
 'Social Media Manager',
 'Content Creator',
 'Media Planner',
 'Cultural Anthropologist',
 'Media Relations Manager',
 'Broadcast Journalist',
 'Digital Media Strategist',
 'Public Relations Specialist',
 'Media Buyer',
 'Culture Curator',
 'Film Critic',
 'Media Consultant',
 'Cultural Heritage Manager',
 'Multimedia Specialist',
 'Brand Manager',
 'Media Researcher',
 '']
recommended_jobs_media_and_information=['',
 'Information Analyst',
 'Media Manager',
 'Digital Content Strategist',
 'Information Architect',
 'Media Planner',
 'Content Manager',
 'Media Analyst',
 'Information Specialist',
 'Social Media Coordinator',
 'Information Consultant',
 'Digital Librarian',
 'Media Relations Specialist',
 'Information Security Analyst',
 'Content Editor',
 'Media Buyer',
 'Information Scientist',
 'User Experience Designer',
 'Digital Asset Manager',
 'Media Researcher',
 'Information Officer',
 '']
recommended_jobs_medische_informatiekunde=['',
 'Medical Informatics Specialist',
 'Health Information Manager',
 'Clinical Informatics Analyst',
 'Data Scientist',
 'Healthcare Data Analyst',
 'Clinical Data Coordinator',
 'Health Information Technician',
 'Healthcare Informatics Consultant',
 'Medical Software Developer',
 'Clinical Informatics Manager',
 'Health Informatics Researcher',
 'Electronic Medical Record (EMR) Implementation Specialist',
 'Clinical Decision Support Analyst',
 'Health Information Systems Administrator',
 'Telehealth Solutions Specialist',
 'Medical Informatics Educator',
 'Health IT Project Manager',
 'Healthcare Compliance Analyst',
 'Population Health Analyst',
 'Health Data Quality Analyst',
 '']
recommended_jobs_natuur_en_sterrenkunde=['',
 'Astrophysicist',
 'Research Scientist',
 'Data Scientist',
 'Physicist',
 'Astronomy Software Engineer',
 'Science Writer',
 'Observatory Technician',
 'Science Educator',
 'Aerospace Engineer',
 'Planetarium Director',
 'Science Illustrator',
 'Cosmologist',
 'Astronomy Outreach Specialist',
 'Science Museum Curator',
 'Spacecraft Engineer',
 'Astronomical Instrumentation Engineer',
 'Meteorologist',
 'Science Policy Advisor',
 'Science Fiction Writer',
 'Amateur Astronomer',
 ''] 
recommended_jobs_nederlandse_taal_en_cultuur=['',
 'Dutch Language Teacher',
 'Copywriter',
 'Translator',
 'Editor',
 'Journalist',
 'Interpreter',
 'Language Program Coordinator',
 'Museum Curator',
 'Cultural Heritage Manager',
 'Tour Guide',
 'Public Relations Specialist',
 'Marketing Coordinator',
 'Content Creator',
 'Localization Specialist',
 'Speech Therapist',
 'Language Assessor',
 'Linguistic Researcher',
 'Archivist',
 'Dutch Language Editor',
 'Cultural Event Coordinator',
 '']                                                                    
recommended_jobs_onderwijswetenschappen= ['',
 'Docent Onderwijswetenschappen',
 'Onderwijskundig adviseur',
 'Projectleider onderwijsontwikkeling',
 'Beleidsmedewerker onderwijs',
 'Onderzoeker onderwijs',
 'Onderwijsontwikkelaar',
 'Kwaliteitsmedewerker onderwijs',
 'Toetsdeskundige',
 'Adviseur leertrajecten',
 'Trainer/Coach onderwijs',
 'Coördinator educatie',
 'Programmacoördinator',
 'Docent Pedagogiek',
 'Onderwijsmanager',
 'Studieadviseur',
 'Examencoördinator',
 'Onderwijsinspecteur',
 'Loopbaancoach onderwijs',
 'Begeleider studiekeuze',
 'Begeleider studenten met functiebeperkingen',
 '']                                                                            
recommended_jobs_oudheidwetenschappen=['',
 'Museum curator',
 'Archivist',
 'Librarian',
 'Historical researcher',
 'Archaeologist',
 'Teacher or professor',
 'Academic advisor',
 'Tour guide or travel writer',
 'Art historian',
 'Journalist or writer',
 'Translator',
 'Cultural heritage consultant',
 'Preservationist',
 'Philologist',
 'Linguist',
 'Historic preservation planner',
 'Historic site manager',
 'Editorial assistant',
 'Exhibition designer',
 'Academic librarian',
 '']                           
recommended_jobs_pedagogische_wetenschappen=['',
 'Onderwijskundige ',
 'Kindercoach ',
 'Schoolpsycholoog ',
 'Pedagogisch adviseur ',
 'Docent of professor',
 'Didactisch ontwikkelaar ',
 'Beleidsadviseur onderwijs',
 'Trainer of coach',
 'Opleidingsadviseur',
 'Onderwijskwaliteitsmedewerker ',
 'Jeugdhulpverlener ',
 'Jeugd- en gezinscoach ',
 'Schoolbegeleider ',
 'Opleidingscoördinator',
 'Loopbaanadviseur',
 'Pedagogisch medewerker ',
 'Assessmentpsycholoog',
 'Begeleider speciaal onderwijs',
 'Studieadviseur ',
 'Kennismanager onderwijs',
 '']                                                   
recommended_jobs_political_science=['',
 'Policy advisor',
 'Political consultant',
 'Research analyst',
 'Public affairs consultant',
 'International development specialist',
 'Government affairs director',
 'Human rights advocate',
 'Campaign manager',
 'Diplomat',
 'International relations specialist',
 'Lobbyist',
 'Non-profit program director',
 'Political journalist',
 'Public opinion researcher',
 'Strategic communications specialist',
 'Social media manager',
 'Public relations specialist',
 'Foreign service officer',
 'Political risk analyst',
 'Civil service ',
 '']                                                                
recommended_jobs_politicologie=  ['',
 'Political analyst',
 'Public policy advisor',
 'Government affairs director',
 'Campaign strategist',
 'Diplomat',
 'Research analyst',
 'Public opinion researcher',
 'Political journalist',
 'Communications specialist',
 'Political consultant',
 'Public affairs director',
 'Non-profit program director',
 'Lobbyist',
 'Human rights advocate',
 'International development specialist',
 'Foreign service officer',
 'Public relations specialist',
 'Social media manager',
 'Conflict resolution specialist',
 'Academic researcher',
 '']                                                                
recommended_jobs_politics=['',
 'Political analyst',
 'Policy advisor',
 'Government affairs director',
 'Campaign strategist',
 'Diplomat',
 'Research analyst',
 'Public opinion researcher',
 'Political journalist',
 'Communications specialist',
 'Political consultant',
 'Public affairs director',
 'Non-profit program director',
 'Lobbyist',
 'Human rights advocate',
 'International development specialist',
 'Foreign service officer',
 'Public relations specialist',
 'Social media manager',
 'Conflict resolution specialist',
 'Academic researcher',
 '']         
                                                                            
recommended_jobs_psychology=['',
 'Clinical Psychologist',
 'Research Psychologist',
 'School Psychologist',
 'Neuropsychologist',
 'Industrial-Organizational Psychologist',
 'Forensic Psychologist',
 'Developmental Psychologist',
 'Educational Psychologist',
 'Social Psychologist',
 'Health Psychologist',
 'Consumer Psychologist',
 'Counseling Psychologist',
 'Experimental Psychologist',
 'Rehabilitation Psychologist',
 'Sports Psychologist',
 'Cognitive Psychologist',
 'Environmental Psychologist',
 'Media Psychologist',
 'Geriatric Psychologist',
 'Child Psychologist',
 '']
recommended_jobs_law_and_economics=['',
 'Corporate Counsel',
 'Mergers and Acquisitions Lawyer',
 'Tax Lawyer',
 'Antitrust Lawyer',
 'Securities Lawyer',
 'Intellectual Property Lawyer',
 'Contract Lawyer',
 'Compliance Officer',
 'Risk Manager',
 'Arbitrator',
 'Mediator',
 'Economic Analyst',
 'Financial Analyst',
 'Investment Banker',
 'Business Consultant',
 'Data Analyst',
 'Operations Manager',
 'Human Resources Manager',
 'Marketing Manager',
 'Product Managerchologist',
 'Child Psychologist',
 '']                                                          
recommended_jobs_ancient_studies=['',
 'Archaeologist',
 'Museum Curator',
 'Cultural Heritage Specialist',
 'Tour Guide',
 'Researcher',
 'Historian',
 'Teacher or Professor of Ancient History or Archaeology',
 'Archaeological Technician',
 'Conservationist',
 'Collection Manager',
 'Field Technician',
 'Interpretive Specialist',
 'Archivist',
 'GIS Specialist',
 'Scientific Illustrator',
 'Forensic Archaeologist',
 'Academic Editor',
 'Digital Humanities Specialist',
 'Exhibit Designer',
 'Grant Writer',
 '']                                                                       
recommended_jobs_rechtsgeleerdheid=['',
 'Lawyer',
 'Legal Advisor',
 'Legal Counsel',
 'Legal Consultant',
 'Corporate Lawyer',
 'Tax Lawyer',
 'Intellectual Property Lawyer',
 'Human Rights Lawyer',
 'Environmental Lawyer',
 'Criminal Defense Lawyer',
 'Employment Lawyer',
 'Immigration Lawyer',
 'Family Lawyer',
 'Insurance Lawyer',
 'Litigation Lawyer',
 'Public Defender',
 'Legal Analyst',
 'Legal Researcher',
 'Compliance Officer',
 'Mediator',
 '']                                                                             
recommended_jobs_religiewetenschappen=['',
 'Religious Studies Researcher',
 'Professor of Religious Studies',
 'Interfaith Coordinator',
 'Chaplain',
 'Youth Minister',
 'Religious Educator',
 'Church Administrator',
 'Missionary',
 'Pastoral Counselor',
 'Spiritual Director',
 'Nonprofit Director',
 'Humanitarian Aid Worker',
 'Conflict Resolution Specialist',
 'Interfaith Dialogue Facilitator',
 'Theology Teacher',
 'Bible Translator',
 'Religious Writer',
 'Museum Curator',
 'Religious Tour Guide',
 'Religious Musician',
 '']                                                                            
recommended_jobs_scandinavië_studies=['',
 'Researcher in Scandinavian Studies',
 'Professor of Scandinavian Studies',
 'Translator of Scandinavian Languages',
 'Language Instructor of Scandinavian Languages',
 'Nordic Culture Specialist',
 'Nordic Art Expert',
 'Scandinavian History Scholar',
 'Scandinavian Literature Critic',
 'Nordic Film and TV Expert',
 'Study Abroad Program Coordinator for Scandinavia',
 'Cultural Exchange Program Coordinator for Scandinavia',
 'Nordic Business Specialist',
 'Scandinavian Tourism Expert',
 'Import/Export Specialist for Scandinavian Products',
 'Nordic Environmental Policy Expert',
 'Nordic Political Analyst',
 'Scandinavian Food and Beverage Specialist',
 'Scandinavian Fashion and Design Expert',
 'Nordic Music and Performing Arts Specialist',
 'Scandinavian Marketing and Advertising Consultant',
 '']                                                                        
recommended_jobs_sign_language_linguistics_linguistics=['',
 'Lecturer in Sign Language and Deaf Studies',
 'Sign Language Interpreter',
 'Researcher in Sign Linguistics',
 'Sign Language Teacher',
 'Communication Advisor for Deaf and Hard of Hearing Persons',
 'Sign Language Coordinator',
 'Sign Language Expert',
 'Sign Language Tutor',
 'Accessibility Coordinator for Deaf and Hard of Hearing Persons',
 'Sign Language Consultant',
 'Sign Language and Deaf Culture Specialist',
 'Speech Therapist for Deaf and Hard of Hearing Persons',
 'Sign Language Instructor',
 'Disability Support Specialist',
 'Sign Language Program Coordinator',
 'Language and Communication Specialist for Deaf and Hard of Hearing Persons',
 'Sign Language Expert for Media and Entertainment Industry',
 'Sign Language Research Assistant',
 'Sign Language Outreach Coordinator',
 'Sign Language Technology Specialist',
 '']   
recommended_jobs_sectors_physics_and_astronomy=['',
 'Stedenbouwkundig ontwerper',
 'Beleidsadviseur Ruimtelijke Ordening',
 'Projectleider Gebiedsontwikkeling',
 'Adviseur Mobiliteit',
 'Onderzoeker Sociale Geografie',
 'Data-analist Ruimtelijke Ordening',
 'Beleidsmedewerker Duurzaamheid',
 'Gebiedsmanager',
 'Stedelijk planner',
 'Procesmanager Ruimtelijke Ordening',
 'Omgevingsmanager',
 'Adviseur Landschapsarchitectuur',
 'Programmacoördinator Gebiedsontwikkeling',
 'Consultant Vastgoedontwikkeling',
 'Medewerker Gebiedsinrichting',
 'Landschapsontwerper',
 'Beleidsadviseur Wonen',
 'Duurzaamheidsadviseur',
 'Milieukundig adviseur',
 'Projectontwikkelaar',
 '']
recommended_jobs_sociology=['',
 'Policy advisor',
 'Social researcher',
 'Human resources specialist',
 'Data analyst',
 'Marketing research analyst',
 'Project coordinator',
 'Social media specialist',
 'Event planner',
 'Public relations specialist',
 'Communications officer',
 'Non-profit program coordinator',
 'Diversity and inclusion officer',
 'Social impact consultant',
 'Community outreach specialist',
 'Governmental affairs specialist',
 'Health care coordinator',
 'Youth development specialist',
 'Training and development coordinator',
 'Humanitarian aid worker',
 'Crisis intervention specialist',
 '']  
recommended_jobs_tandheelkunde= ['',
 'Tandarts',
 'Orthodontist',
 'Mondhygiënist',
 'Kaakchirurg',
 'Parodontoloog',
 'Endodontoloog',
 'Klinisch tandprotheticus',
 'Tandtechnicus',
 'Tandprotheticus',
 'Implantoloog',
 'Esthetisch tandarts',
 'Kindertandarts',
 'Gnatholoog',
 'Orale patholoog',
 'Forensisch odontoloog',
 'Cariësconsulent',
 'Preventie-assistent',
 'Tandheelkundig adviseur',
 'Tandheelkundig docent',
 'Tandheelkundig onderzoeker',
 '']          
recommended_jobs_theaterwetenschap=['',
 'Dramaturg',
 'Theaterwetenschapper',
 'Regisseur',
 'Productieleider',
 'Toneelmeester',
 'Scenograaf',
 'Acteur',
 'Theatertechnicus',
 'Lichtontwerper',
 'Geluidsontwerper',
 'Kostuumontwerper',
 'Decorontwerper',
 'Dramadocent',
 'Theatercriticus',
 'Programmamaker',
 'Theatermarketingmedewerker',
 'Zakelijk leider',
 'Cultureel ondernemer',
 'Festivalorganisator',
 'Theatermaker',
 '']
recommended_jobs_duitse_taal_en_cultuur=['',
 'Vertaler Duits',
 'Docent Duits',
 'Duitse taaltrainer',
 'Redacteur Duits',
 'Tolken Duits',
 'Cultureel adviseur Duitsland',
 'Internationaal marketingmedewerker',
 'Verkoper Duitstalig gebied',
 'Duitslanddeskundige',
 'Accountmanager Duitstalige klanten',
 'Zakelijke correspondent Duits',
 'PR-adviseur Duitsland',
 'Content specialist Duitse taal',
 'Vertegenwoordiger Duitse markt',
 'Customer service medewerker Duitstalige klanten',
 'Onderzoeker Duitse cultuur en geschiedenis',
 'Duitse literatuurwetenschapper',
 'Duitsland-analist',
 'Webcare medewerker Duitstalige klanten',
 'Duitslandjournalist    ',
 '']                                                                          
recommended_jobs_literatuurwetenschap= ['',
 'Content Writer',
 'Editor',
 'Copywriter',
 'Proofreader',
 'Literary Agent',
 'Researcher',
 'Librarian',
 'Archivist',
 'Communications Specialist',
 'Public Relations Specialist',
 'Translator',
 'Blogger',
 'Social Media Manager',
 'Journalist',
 'Scriptwriter',
 'Screenwriter',
 'Creative Writer',
 'Grant Writer',
 'Academic Advisor',
 'Bookstore Manag   ',
 '']                                                                           
recommended_jobs_taalwetenschap=['',
 'Linguistic Data Analyst',
 'Computational Linguist',
 'Language Teacher/Instructor',
 'Lexicographer',
 'Speech Language Pathologist',
 'Translator/Interpreter',
 'Foreign Language Teacher',
 'Editor/Proofreader',
 'Language Technologist',
 'Speech Scientist',
 'Sociolinguist',
 'Semantics Analyst',
 'Phonetics Researcher',
 'Morphologist',
 'Syntax Analyst',
 'Discourse Analyst',
 'Psycholinguist',
 'Neurolinguist',
 'Dialectologist',
 'Language Documentation Specialist ',
 '']                                                                   
recommended_jobs_econometrie=['',
 'Data Analyst',
 'Risk Analyst',
 'Quantitative Researcher',
 'Business Analyst',
 'Financial Analyst',
 'Investment Analyst',
 'Marketing Analyst',
 'Econometrician',
 'Statistician',
 'Operations Research Analyst',
 'Machine Learning Engineer',
 'Actuary',
 'Pricing Analyst',
 'Product Analyst',
 'Forecasting Analyst',
 'Credit Risk Analyst',
 'Economic Consultant',
 'Supply Chain Analyst',
 'Asset Management Analyst',
 'Portfolio ',
 '']                                                                       
recommended_jobs_artificial_intelligence=['',
 'AI Researcher',
 'Machine Learning Engineer',
 'Data Scientist',
 'Computer Vision Engineer',
 'Natural Language Processing Engineer',
 'Robotics Engineer',
 'AI Architect',
 'AI Consultant',
 'AI Project Manager',
 'Deep Learning Engineer',
 'AI Programmer',
 'Cognitive Computing Engineer',
 'AI System Administrator',
 'AI Marketing Analyst',
 'AI Business Analyst',
 'AI Chatbot Developer',
 'AI Operations Manager',
 'AI Security Analyst',
 'AI Infrastructure Engineer',
 'AI Product Manager  ',
 '']                                                                        
recommended_jobs_aarde_economie_en_duurzaamheid=['',
 'Sustainability Consultant',
 'Environmental Policy Analyst',
 'Renewable Energy Specialist',
 'Green Building Architect',
 'Sustainable Agriculture Manager',
 'Carbon Footprint Analyst',
 'Environmental Economist',
 'Waste Reduction Coordinator',
 'Water Resource Manager',
 'Corporate Social Responsibility Coordinator',
 'Climate Change Researcher',
 'Natural Resource Manager',
 'Eco-Tourism Specialist',
 'Sustainable Transportation Planner',
 'Sustainable Packaging Designer',
 'Green Supply Chain Manager',
 'Biodiversity Conservationist',
 'Sustainable Business Manager',
 'Community Outreach Coordinator',
 'Sustainable Development Specialist                                                                                       ',
 '']     
recommended_jobs_aardewetenschappen=['',
 '  Geologist',
 'Hydrologist',
 'Geophysicist',
 'Seismologist',
 'Environmental Scientist',
 'Soil Scientist',
 'Mineralogist',
 'Paleontologist',
 'Oceanographer',
 'Geochemist',
 'Petroleum Geologist',
 'GIS Specialist',
 'Geomorphologist',
 'Volcanologist',
 'Climate Scientist',
 'Glaciologist',
 'Planetary Scientist',
 'Geotechnical Engineer',
 'Remote Sensing Scientist',
 'Geospatial Analyst                                                                                      ',
 ''] 
recommended_jobs_archeologie=['',
 ' Archaeologist',
 'Museum Curator',
 'Cultural Resource Manager',
 'Historical Interpreter',
 'Archaeological Field Technician',
 'Cultural Heritage Manager',
 'Research Archaeologist',
 'Academic Researcher',
 'Heritage Consultant',
 'Archaeological Conservator',
 'Collections Manager',
 'Site Supervisor',
 'GIS Analyst',
 'Archaeological Illustrator',
 'Historical Consultant',
 'Archaeological Surveyor',
 'Laboratory Analyst',
 'Geoarchaeologist',
 'Osteoarchaeologist',
 'Public Outreach Coordinator   ',
 '']
recommended_jobs_bedrijfskunde=['',
 'Business Analyst',
 'Financial Analyst',
 'Project Manager',
 'Operations Manager',
 'Human Resources Manager',
 'Marketing Manager',
 'Sales Manager',
 'Procurement Manager',
 'Logistics Manager',
 'Supply Chain Manager',
 'Business Development Manager',
 'Risk Manager',
 'Compliance Officer',
 'Internal Auditor',
 'External Auditor',
 'Management Consultant',
 'Strategic Advisor',
 'Change Manager',
 'Data Analyst',
 'Business Intelligence Analyst ',
 '']  
recommended_jobs_bestuurs_en_organistatiewetenschap=['',
 ' Policy Advisor',
 'Public Relations Manager',
 'Government Affairs Specialist',
 'Public Affairs Officer',
 'Public Administration Consultant',
 'Business Operations Manager',
 'Strategy Consultant',
 'Change Management Consultant',
 'Human Resources Manager',
 'Talent Acquisition Specialist',
 'Recruitment Manager',
 'Compensation and Benefits Specialist',
 'Learning and Development Manager',
 'Organizational Development Consultant',
 'Performance Management Specialist',
 'Project Manager',
 'Risk Management Specialist',
 'Compliance Officer',
 'Internal Auditor',
 'Quality Assurance Manager  ',
 '']                
recommended_jobs_bewegingswetensch=['',
 'Sports Scientist',
 'Exercise Physiologist',
 'Rehabilitation Specialist',
 'Performance Coach',
 'Biomechanist',
 'Fitness Consultant',
 'Health Coach',
 'Physical Therapist',
 'Athletic Trainer',
 'Ergonomist',
 'Occupational Therapist',
 'Sport Psychology Consultant',
 'Data Analyst',
 'Health and Safety Specialist',
 'Research Scientist',
 'Product Manager - Sports Equipment',
 'Medical Writer',
 'Content Creator - Sports and Fitness',
 'Nutritionist',
 'Wellness Coach  ',
 '']                                                                       

recommended_jobs_business_analytics=['',
 'Data Analyst',
 'Business Intelligence Analyst',
 'Data Scientist',
 'Operations Analyst',
 'Marketing Analyst',
 'Financial Analyst',
 'Supply Chain Analyst',
 'Pricing Analyst',
 'Risk Analyst',
 'Sales Analyst',
 'HR Analyst',
 'Customer Analyst',
 'Fraud Analyst',
 'Procurement Analyst',
 'IT Analyst',
 'Digital Analyst',
 'Strategic Analyst',
 'Management Analyst',
 'Healthcare Data Analyst',
 'Cybersecurity Analyst  ',
 '']
recommended_jobs_communicatiewetensch=['',
 'Communications Specialist',
 'Social Media Manager',
 'Content Marketer',
 'Public Relations Manager',
 'Marketing Manager',
 'Advertising Copywriter',
 'Digital Media Producer',
 'Event Coordinator',
 'Brand Manager',
 'Corporate Communications Manager',
 'Market Research Analyst',
 'Media Planner',
 'Journalist',
 'Film and Video Editor',
 'Web Content Manager',
 'UX Writer',
 'Technical Writer',
 'Multimedia Designer',
 'Art Director',
 'Creative Director  ',
 '']
recommended_jobs_communication_and_information_studies=['',
 'Communication Specialist',
 'Public Relations Manager',
 'Content Marketer',
 'Marketing Manager',
 'Advertising Copywriter',
 'Digital Media Producer',
 'Event Coordinator',
 'Brand Manager',
 'Social Media Manager',
 'Corporate Communications Manager',
 'Market Research Analyst',
 'Media Planner',
 'Journalist',
 'UX Writer',
 'Technical Writer',
 'Multimedia Designer',
 'Art Director',
 'Creative Director',
 'User Experience Researcher',
 'Information Architect         ',
 '']  
recommended_jobs_criminology=['',
 'Criminologist',
 'Policy Analyst',
 'Law Enforcement Officer',
 'Intelligence Analyst',
 'Victim Advocate',
 'Probation Officer',
 'Parole Officer',
 'Security Analyst',
 'Investigator',
 'Forensic Psychologist',
 'Crime Analyst',
 'Criminal Justice Researcher',
 'Juvenile Justice Specialist',
 'Criminal Defense Attorney',
 'Criminal Prosecutor',
 'Corrections Officer',
 'Criminal Investigator',
 'Evidence Technician',
 'Crime Prevention Specialist',
 'Community Outreach Coordinator          ',
 '']    
recommended_jobs_cultural_anthropology_and_development_sociology=['',
 'Social Researcher',
 'Policy Analyst',
 'Non-Profit Program Manager',
 'Community Organizer',
 'Cultural Heritage Specialist',
 'Intercultural Communication Specialist',
 'Human Rights Advocate',
 'Social Justice Educator',
 'Cross-Cultural Trainer',
 'Social Impact Consultant',
 'Community Development Specialist',
 'Diversity and Inclusion Specialist',
 'Advocacy Coordinator',
 'Program Evaluator',
 'Sustainability Consultant',
 'Humanitarian Aid Worker',
 'Refugee Resettlement Specialist',
 'Peacebuilding and Conflict Resolution Specialist',
 'Gender and Development Specialist',
 'International Development Consultant         ',
 '']
recommended_jobs_econometrie_en_operationele_research=['',
 ' Data Scientist',
 'Financial Analyst',
 'Quantitative Risk Analyst',
 'Supply Chain Analyst',
 'Business Intelligence Analyst',
 'Pricing Analyst',
 'Operations Research Analyst',
 'Investment Analyst',
 'Forecasting Analyst',
 'Econometric Analyst',
 'Marketing Analytics Manager',
 'Logistics Analyst',
 'Portfolio Analyst',
 'Credit Risk Analyst',
 'Quantitative Developer',
 'Statistical Analyst',
 'Machine Learning Engineer',
 'Quantitative Trader',
 'Energy Analyst',
 'Economic Research Analyst         ',
 '']    
recommended_jobs_econometrics_and_business_economics=['',
 'Financial Analyst',
 'Risk Management Analyst',
 'Data Analyst',
 'Quantitative Analyst',
 'Business Intelligence Analyst',
 'Market Research Analyst',
 'Marketing Analyst',
 'Operations Research Analyst',
 'Pricing Analyst',
 'Forecasting Analyst',
 'Investment Analyst',
 'Portfolio Analyst',
 'Credit Risk Analyst',
 'Statistical Analyst',
 'Machine Learning Engineer',
 'Actuarial Analyst',
 'Regulatory Risk Analyst',
 'Asset Management Analyst',
 'Quantitative Developer',
 'Research Economist         ',
 '']                    
recommended_jobs_economie_en_bedrijfsk=['',
 'Financial Analyst',
 'Management Consultant',
 'Business Development Manager',
 'Market Research Analyst',
 'Investment Analyst',
 'Operations Manager',
 'Project Manager',
 'Risk Management Analyst',
 'Marketing Manager',
 'Sales Manager',
 'Supply Chain Manager',
 'Human Resource Manager',
 'Data Analyst',
 'Procurement Manager',
 'Product Manager',
 'Customer Success Manager',
 'Business Intelligence Analyst',
 'Pricing Analyst',
 'Corporate Strategy Manager',
 'Treasury Analyst        ',
 '']                                                           
recommended_jobs_english_language_and_communication_studies=['',
 'Content Writer',
 'Copywriter',
 'Communications Specialist',
 'Public Relations Manager',
 'Social Media Manager',
 'Marketing Communications Manager',
 'Technical Writer',
 'Editorial Assistant',
 'Grant Writer',
 'Brand Manager',
 'Advertising Copywriter',
 'Event Coordinator',
 'Communications Officer',
 'Media Planner',
 'Community Manager',
 'Press Officer',
 'Digital Marketing Manager',
 'Content Marketing Manager',
 'Market Researcher',
 'Fundraiser      ',
 '']
recommended_jobs_farmaceutische_wetenschappen=['',
 'Quality Control Analyst',
 'Pharmaceutical Scientist',
 'Research and Development Manager',
 'Regulatory Affairs Associate',
 'Clinical Research Coordinator',
 'Medical Science Liaison',
 'Product Manager',
 'Formulation Scientist',
 'Pharmacovigilance Officer',
 'Sales Representative',
 'Medical Writer',
 'Clinical Research Associate',
 'Validation Engineer',
 'Quality Assurance Specialist',
 'Drug Safety Specialist',
 'Medical Affairs Manager',
 'Analytical Chemist',
 'Biostatistician',
 'Process Development Scientist',
 'Pharmacy Manager   ',
 '']     
recommended_jobs_filosofie=['',
 'Philosopher',
 'Ethics consultant',
 'Teacher or professor of philosophy',
 'Researcher in philosophy',
 'Policy advisor',
 'Consultant for cultural institutions',
 'Journalist or writer specializing in philosophy',
 'Public relations or communication specialist',
 'Legal advisor',
 'Human resources consultant',
 'Social media specialist',
 'Marketing consultant',
 'Fundraiser for non-profit organizations',
 'Community outreach coordinator',
 'Public speaker or presenter',
 'Philanthropy advisor',
 'Cultural heritage advisor',
 'Museum curator or educator',
 'Archivist or librarian',
 'Translator or interpreter   ',
 '']       

recommended_jobs_geneeskunde=['',
 'General Practitioner ',
 'Specialist Doctor',
 'Medical Researcher ',
 'Medical Advisor ',
 'Medical Manager',
 'Surgeon ',
 'Anesthesiologist ',
 'Pediatrician',
 'Gynecologist ',
 'Cardiologist ',
 'Oncologist ',
 'Neurologist ',
 'Psychiatrist ',
 'Radiologist ',
 'Dermatologist ',
 'Ophthalmologist ',
 'Pathologist ',
 'Rehabilitation Specialist ',
 'Public Health Officer ',
 'Occupational Health Physician                                                                                         ',
 '']       
recommended_jobs_geschiedenis=['',
 'Museum Curator ',
 'Historian ',
 'Archivist ',
 'Heritage Manager ',
 'Academic Researcher',
 'Writer/Journalist ',
 'Teacher/Professor',
 'Education Policy Advisor ',
 'Cultural Heritage Specialist ',
 'Art Historian ',
 'Political Advisor ',
 'Public Relations Officer ',
 'Content Marketer ',
 'Genealogist ',
 'Documentary Filmmaker ',
 'Legal Researcher ',
 'Policy Analyst ',
 'Diplomat ',
 'Curator of Historical Sites ',
 'Cultural Anthropologist                                                                                             ',
 '']     
recommended_jobs_gezondheidswetenschappen=['',
 'Healthcare Consultant',
 'Health Policy Advisor',
 'Health Promotion Specialist',
 'Public Health Officer',
 'Epidemiologist',
 'Medical Writer',
 'Health Educator',
 'Researcher',
 'Biostatistician',
 'Healthcare Manager',
 'Health Program Manager',
 'Health Data Analyst',
 'Health Informatics Specialist',
 'Occupational Health and Safety Specialist',
 'Pharmaceutical Sales Representative',
 'Health Psychologist',
 'Medical Social Worker',
 'Health Economist',
 'Healthcare Quality Improvement Specialist',
 'Health Technology Assessment (HTA) Specialist                                                                                            ',
 '']

recommended_jobs_griekse_en_latijnse_taal_en_cultuur=['',
 'Classics Professor',
 'Museum Curator',
 'Historical Translator',
 'Researcher',
 'Librarian',
 'Writer/Journalist',
 'Archivist',
 'Teacher/Professor',
 'Tour Guide',
 'Publishing Editor',
 'Academic Program Manager',
 'Public Relations Officer',
 'Literary Agent',
 'Editorial Assistant',
 'Film/TV Script Consultant',
 'Language Teacher (of Greek and Latin)',
 'Heritage Manager',
 'Museum Educator',
 'Cultural Heritage Specialist',
 'Content Writer/Creator     ',
 '']
recommended_jobs_history_and_international_studies=['',
 'Historian',
 'International Relations Specialist',
 'Diplomat',
 'Political Analyst',
 'Researcher',
 'Policy Advisor',
 'Journalist',
 'Archivist',
 'Museum Curator',
 'Cultural Heritage Manager',
 'International Development Consultant',
 'Human Rights Officer',
 'NGO Program Coordinator',
 'Foreign Affairs Specialist',
 'Intelligence Analyst',
 'International Trade Specialist',
 'Immigration Specialist',
 'Peacekeeping Officer',
 'International Education Coordinator',
 'Conflict Resolution Specialist  ',
 '']  
recommended_jobs_international_business_administration=['',
 'Management Consultant',
 'Financial Analyst',
 'Marketing Manager',
 'Business Development Manager',
 'Project Manager',
 'Sales Manager',
 'Supply Chain Manager',
 'Operations Manager',
 'Human Resources Manager',
 'Account Manager',
 'Investment Banker',
 'Risk Manager',
 'Management Trainee',
 'Business Analyst',
 'Entrepreneur',
 'International Trade Specialist',
 'E-commerce Manager',
 'Public Relations Specialist',
 'Product Manager',
 'Brand Manager',
 '']                        
recommended_jobs_language_and_media=['',
 'Copywriter',
 'Editor',
 'Content Manager',
 'Public Relations Specialist',
 'Marketing Manager',
 'Social Media Manager',
 'Journalist',
 'Communications Officer',
 'Advertising Executive',
 'Script Writer',
 'Audio-Visual Specialist',
 'Translator',
 'Voice Over Artist',
 'Event Coordinator',
 'Community Manager',
 'Media Planner',
 'Brand Strategist',
 'Graphic Designer',
 'Digital Marketing Specialist',
 'Content Strategist',
 '']         
recommended_jobs_language_learning_and_language_teaching=['',
 'Language Teacher',
 'Curriculum Developer',
 'Language Program Coordinator',
 'Language School Manager',
 'Tutor',
 'Translator',
 'Interpreter',
 'Linguist',
 'Language Assessment Specialist',
 'Materials Developer',
 'Language Researcher',
 'Online Language Instructor',
 'Language Consultant',
 'Language Coach',
 'Corporate Language Trainer',
 'Educational Technology Specialist',
 'Study Abroad Advisor',
 'Language Testing Coordinator',
 'Foreign Language Correspondent',
 'Language Learning App Developer',
 '']                                                   
recommended_jobs_law_in_society=['',
 'Lawyer',
 'Judge',
 'Legal Advisor',
 'Prosecutor',
 'Legal Researcher',
 'Human Rights Advocate',
 'Policy Advisor',
 'Compliance Officer',
 'Lobbyist',
 'Mediator',
 'Law Enforcement Officer',
 'Paralegal',
 'Legal Secretary',
 'Corporate Counsel',
 'Arbitrator',
 'Legal Aid Worker',
 'Intellectual Property Specialist',
 'Labor Relations Specialist',
 'Immigration Lawyer',
 'Environmental Lawyer',
 '']                                                                  
recommended_jobs_literature_and_sociaty=['',
 'Author',
 'Editor',
 'Publisher',
 'Literary Agent',
 'Copywriter',
 'Creative Writer',
 'Content Strategist',
 'Communications Specialist',
 'Public Relations Manager',
 'Social Media Manager',
 'Marketing Manager',
 'Journalist',
 'Archivist',
 'Librarian',
 'Literary Critic',
 'English Language Instructor',
 'Cultural Events Coordinator',
 'Grant Writer',
 'Researcher',
 'Museum Curator',
 '']                                                                    
recommended_jobs_mechanical_engineering=['',
 'Mechanical Engineer',
 'Design Engineer',
 'Manufacturing Engineer',
 'Process Engineer',
 'Project Engineer',
 'Quality Engineer',
 'Maintenance Engineer',
 'Robotics Engineer',
 'Energy Engineer',
 'Control Engineer',
 'Materials Engineer',
 'Acoustic Engineer',
 'Aerospace Engineer',
 'Automotive Engineer',
 'Biomedical Engineer',
 'HVAC Engineer',
 'Marine Engineer',
 'Mining Engineer',
 'Nuclear Engineer',
 'Systems Engineer',
 '']                                                      
recommended_jobs_media_en_journalistiek=['',
 'Journalist',
 'Editor',
 'News Reporter',
 'Broadcast Presenter',
 'Online Content Creator',
 'Social Media Specialist',
 'Communications Officer',
 'Public Relations Manager',
 'Advertising Executive',
 'Media Planner',
 'Content Strategist',
 'Digital Marketing Specialist',
 'Video Producer',
 'Photojournalist',
 'Media Analyst',
 'Documentary Filmmaker',
 'News Anchor',
 'Scriptwriter',
 'Corporate Communications Manager',
 'Creative Director',
 ''];                                                                
recommended_jobs_media_art_design_and_architecture=['',
 'Graphic Designer',
 'Web Designer',
 'UX/UI Designer',
 'Animator',
 'Game Designer',
 'Interior Designer',
 'Architect',
 'Landscape Architect',
 'Industrial Designer',
 'Fashion Designer',
 'Art Director',
 'Photographer',
 'Film Director',
 'Production Designer',
 'Visual Effects Specialist',
 'Exhibition Designer',
 'Museum Curator',
 'Art Conservator',
 'Creative Producer',
 'Sound Designer',
'']
recommended_jobs_natuur_en_sterrenkunde=['',
 'Physicist',
 'Astrophysicist',
 'Astronomer',
 'Data Scientist',
 'Aerospace Engineer',
 'Research Scientist',
 'Computational Physicist',
 'Nuclear Engineer',
 'Meteorologist',
 'Spacecraft Engineer',
 'Optical Engineer',
 'Geophysicist',
 'Materials Scientist',
 'Instrumentation Engineer',
 'Mathematical Physicist',
 'Solar Physicist',
 'Technical Writer',
 'Research Fellow',
 'Professor',
 'Observatory Director',
 '']
recommended_jobs_notarieel_recht=['',
 'Notary',
 'Deputy Notary',
 'Legal Counsel',
 'Estate Planner',
 'Trust Officer',
 'Wealth Manager',
 'Tax Consultant',
 'Financial Advisor',
 'Corporate Lawyer',
 'Real Estate Lawyer',
 'Contract Specialist',
 'Compliance Officer',
 'Human Resources Specialist',
 'Banking Consultant',
 'Insurance Agent',
 'Investment Advisor',
 'M&A Specialist',
 'Litigation Lawyer',
 'Arbitrator',
 'Legal Writer',
 '']
recommended_jobs_political_science_and_economics=[
 'Economist',
 'Policy Advisor',
 'Financial Analyst',
 'Government Relations Specialist',
 'International Development Consultant',
 'Public Affairs Manager',
 'Market Research Analyst',
 'Political Consultant',
 'Strategic Advisor',
 'Investment Banker',
 'Management Consultant',
 'Risk Analyst',
 'Economic Researcher',
 'Diplomat',
 'Lobbyist',
 'Foreign Service Officer',
 'Trade Specialist',
 'Data Analyst',
 'Development Economist',
 'Corporate Social Responsibility Manager',
]

recommended_jobs_scheikunde=['',
 'Chemist',
 'Analytical Chemist',
 'Research Scientist',
 'Quality Control Analyst',
 'Materials Scientist',
 'Chemical Engineer',
 'Process Development Scientist',
 'Pharmaceutical Scientist',
 'Environmental Scientist',
 'Petrochemical Engineer',
 'Forensic Scientist',
 'Food Scientist',
 'Biomedical Scientist',
 'Water Treatment Specialist',
 'Polymer Scientist',
 'Patent Lawyer',
 'Science Writer',
 'Technical Sales Representative',
 'Professor',
 'Lab Technician',
 '']
recommended_jobs_tandheelkunde=['',
 'Dentist',
 'Orthodontist',
 'Endodontist',
 'Periodontist',
 'Prosthodontist',
 'Oral Surgeon',
 'Dental Hygienist',
 'Dental Therapist',
 'Dental Assistant',
 'Dental Lab Technician',
 'Dental Sales Representative',
 'Dental Researcher',
 'Dental Public Health Specialist',
 'Dental Educator',
 'Dental Consultant',
 'Dental Insurance Claims Analyst',
 'Dental Practice Manager',
 'Dental Anesthesiologist',
 'Forensic Odontologist',
 'Military Dentist',
 '']
recommended_jobs_psychobiologie=['',
 'Clinical Psychologist',
 'Neuropsychologist',
 'Behavioral Therapist',
 'Research Scientist in Psychobiology',
 'Academic Researcher in Neuroscience',
 'Psychiatric Nurse',
 'Psychology Professor',
 'Psychopharmacologist',
 'Cognitive Psychologist',
 'Psychiatric Technician',
 'Medical Science Liaison',
 'Behavioral Analyst',
 'Mental Health Counselor',
 'Neuroscience Researcher',
 'Rehabilitation Counselor',
 'Social Worker',
 'Occupational Therapist',
 'Human Resource Manager',
 'Medical Sales Representative',
 'Data Analyst in Psychology and Neuroscience.',
 '']"""

# %%
# b = a.strip('\n').split(',')
b=''.join(a.splitlines()).split(',')

# %%
for i in b:
    i=i.lstrip()
    if 'recommended_jobs' in i:
        b.remove(i)

# %%
q = [string.strip().strip("'").strip('"').lower().strip() for string in b]

# %%
d = list(set(q))

# %%
sorted(d)
# Out:
# ['(online) content manager',
#  'academic advisor',
#  'academic advisor (for classics majors)',
#  'academic editor',
#  'academic librarian',
#  'academic program manager',
#  'academic researcher',
#  'academic researcher in neuroscience',
#  'accessibility coordinator for deaf and hard of hearing persons',
#  'account manager',
#  'accountant',
#  'accountmanager duitstalige klanten',
#  'acoustic engineer',
#  'acoustic specialist',
#  'acteur',
#  'actuarial analyst',
#  'actuary',
#  'advertising account executive',
#  'advertising copywriter',
#  'advertising executive',
#  'advertising manager',
#  'adviseur landschapsarchitectuur',
#  'adviseur leertrajecten',
#  'adviseur mobiliteit',
#  'advocacy coordinator',
#  'aerospace engineer',
#  'ai architect',
#  'ai business analyst',
#  'ai chatbot developer',
#  'ai consultant',
#  'ai infrastructure engineer',
#  'ai marketing analyst',
#  'ai operations manager',
#  'ai product manager',
#  'ai programmer',
# ...

# %%
Aarde, Economie en Duurzaamheid
Business Analytics
Econometrics and Business economics
Econometrie
Economie en Bedrijfskunde
Fiscale Economie
Informatica
Informatiekunde
Italië studies
Mechanical Engineering
Aardewetenschappen
Actuariële Wetenschappen
Archeologie
Artificial Intelligence
Bedrijfskunde
Business Analytics
Business administration (bedrijfskunde)
Business analytics
Cognition, Language and Communication
Criminologie
Econometrics and Business economics
Econometrie
Econometrie en Operationele Research
Economics and Business Economics
Economie en Bedrijfskunde
European Studies
Farmaceutische Wetenschappen
Filosofie
Fiscaal recht
Fiscale Economie
Actuarial Science
Ancient studies
Arabische taal en cultuur
Bestuurs- en organistatiewetenschap
Bewegingswetenschap
Communicatiewetenschap
Communication Social Science
Communication and Information Studies
Computational Social Science (Data- en sociale wetenschap)
Cultural Anthropology and Development Sociology
Culturele antropologie en Ontwikkelingssociolgie
Cultuurwetenschappen
Duitse Taal en Cultuur
Duitslandstudies
Englisch language and Culture
English Language and Communication Studies
Franse taal en cultuur
Future Planet Studies
Geneeskunde
Geschiedenis
Gezondheidswetenschappen
Global Arts, Culture and Politics
Griekse en Latijnse Taal en Cultuur
Hebreeuwse taal en cultuur
History and International Studies
Informatica
Informatiekunde
Interdisciplinaire sociale wetenschap
International Business Administration
Italië studies
Kunstmatige intelligentie
Language Learning and Language Teaching
Language and Media
Law in Society
Linguistics
Literature and Society
Literatuurwetenschap
Mechanical Engineering
Media and Culture
Media and Information
Media en Journalistiek
Media, Art, Design and Architecture
Medische informatiekunde
Natuur- en Sterrenkunde
Natuur- en sterrenkunde
Nederlandse taal en cultuur
Notarieel Recht
Onderwijswetenschappen
Oudheidwetenschappen
Oudheidwetenschappen
Pedagogische wetenschappen
Political Science
Politicologie
Politics, Psychology, Law and Economics (PPLE)
Psychobiologie
Rechtsgeleerdheid
Scandinavië studies
Scheikunde
Sociale geografie en Planologie
Sociology
Taalwetenschap
Tandheelkunde
Theaterwetenschap
communicatiewetenschap
scheikunde
tandheelkunde

# %%
"""Natural Sciences:"""
"""Aarde, Economie en Duurzaamheid
Aardewetenschappen
Future Planet Studies
Geneeskunde
Natuur- en Sterrenkunde
Scheikunde"""
"""Social Sciences:"""
"""Actuariële Wetenschappen
Bedrijfskunde
Business administration (bedrijfskunde)
Business Analytics
Communication Social Science
Communicatiewetenschap
Criminologie
Econometrics and Business economics
Econometrie
Econometrie en Operationele Research
Economics and Business Economics
Economie en Bedrijfskunde
European Studies
Farmaceutische Wetenschappen
Fiscaal recht
Fiscale Economie
Geschiedenis
Gezondheidswetenschappen
Global Arts, Culture and Politics
Interdisciplinaire sociale wetenschap
International Business Administration
Linguistics
Literature and Society
Literatuurwetenschap
Media and Culture
Media and Information
Media en Journalistiek
Media, Art, Design and Architecture
Medische informatiekunde
Nederlandse taal en cultuur
Notarieel Recht
Onderwijswetenschappen
Pedagogische wetenschappen
Political Science
Politicologie
Politics, Psychology, Law and Economics (PPLE)
Scandinavië studies
Sociale geografie en Planologie
Sociology
Taalwetenschap
Theaterwetenschap"""
"""Engineering and Technology:"""
"""Artificial Intelligence
Informatica
Informatiekunde
Italië studies
Mechanical Engineering
Tandheelkunde"""
"""Humanities:"""
"""Ancient studies
Archeologie
Cultuurwetenschappen
Duitse Taal en Cultuur
Duitslandstudies
Englisch language and Culture
English Language and Communication Studies
Filosofie
Franse taal en cultuur
Griekse en Latijnse Taal en Cultuur
Hebreeuwse taal en cultuur
History and International Studies
Language Learning and Language Teaching
Language and Media
Law in Society
Literatuurwetenschap
Oudheidwetenschappen
Oudheidwetenschappen
Theaterwetenschap"""

# %%
"""1. Business and Economics:
    - Actuarial Science
    - Bedrijfskunde (Business Administration)
    - Business Analytics
    - Economics and Business Economics
    - European Studies
    - Fiscale Economie (Taxation)
    - Global Arts, Culture and Politics
    - Liberal Arts and Science
    - Politics, Psychology, Law and Economics (PPLE)
    - Econometrie (Econometrics)
    - International Business Administration

2. Humanities and Social Sciences:
    - Ancient studies
    - Arabische taal en cultuur (Arabic language and culture)
    - Archeologie (Archaeology)
    - Beta-gamma (Natural and Social Sciences)
    - Cognition, Language and Communication
    - Communicatiewetenschap (Communication Science)
    - Communication Social Science
    - Computational Social Science (Data and Social Science)
    - Cultural anthropology and Development Sociology
    - Culturele antropologie en ontwikkelingssociologie (Cultural anthropology and Development Sociology)
    - Cultuurwetenschappen (Cultural Studies)
    - Duitslandstudies (German Studies)
    - Englisch language and Culture
    - Franse taal en cultuur (French Language and Culture)
    - Griekse en Latijnse taal en cultuur (Greek and Latin Language and Culture)
    - Hebreeuwse taal en cultuur (Hebrew Language and Culture)
    - Interdisciplinaire sociale wetenschap (Interdisciplinary Social Science)
    - Italië studies (Italian Studies)
    - Kunstgeschiedenis (Art History)
    - Linguistics
    - Literary and Cultural Analysis (literary studies)
    - Media and Culture
    - Media and Information
    - Media en cultuur (Media and Culture)
    - Muziekwetenschap (Musicology)
    - Nederlandse taal en cultuur (Dutch Language and Culture)
    - Nieuwgriekse taal en cultuur (Modern Greek Language and Culture)
    - Onderwijswetenschappen (Educational Sciences)
    - Oudheidwetenschappen (Classics)
    - Pedagogische wetenschappen (Pedagogical Sciences)
    - Political Science
    - Politicologie (Political Science)
    - Psychology
    - Religiewetenschappen (Religious Studies)
    - Russische en Slavische studies (Russian and Slavic Studies)
    - Scandinavië studies (Scandinavian Studies)
    - Sign Language Linguistics (Linguistics)
    - Social Geography and Planning
    - Sociology
    - Spaanse en Latijns-Amerikaanse studies (Spanish and Latin American Studies)
    - Theaterwetenschap (Theater Studies)
    - Taalwetenschap (Language Science)
    - Literatuurwetenschap (Literary Studies)
    - Philosophy
    - Theology

3. Science and Technology:
    - Biomedische wetenschappen (Biomedical Sciences)
    - Informatica (Computer Science)
    - Informatiekunde (Information Science)
    - Kunstmatige intelligentie (Artificial Intelligence)
    - Natuur- en Sterrenkunde (Physics and Astronomy)
    - Aardewetenschappen (Earth Sciences)
    - Bewegingswetenschap (Movement Sciences)
    - Mechanical Engineering
    - Farmaceutische Wetenschappen (Pharmaceutical Sciences)
    - scheikunde (Chemistry)
    - Tandheelkunde (Dentistry)
    - Wiskunde (Mathematics)
    - Econ"""

# %%
disc_char=['Driver (Di)','Driver (Di)','Driver (Di)','Skeptic (Cd)',
           'Planner (Sc)','Motivator (I)','Motivator (I)',
           'Architect (Dc)','Planner (Sc)','Motivator (I)',
           'Analyst (C)','Stabilizer (SC)','Counselor (Si)',
           'Architect (Dc)','Planner (Sc)','Motivator (I)',
           'Motivator (I)','Driver (Di)']
name=['Berend Ballot','Ingrid Thuis','Barbara Wendrich','Merijn Straijer',
     'Maran Jansen','Carine Boom','Ellen Ophoff','Nanno Kruizinga',
     'Coline Schoonbeek','Véronique Van hoogmoed','Wietze Van der werf',
     'Rachel Van beem','Fiona Van lingen','Rutger Koning','Maret Heems',
     'Tessa Deurloo','Jessica Bruijnincx','Louise Henderickx']
short_text=['Berend is likely to be an ambitious and persuasive achiever with a casual and direct communication style.',
            "Ingrid tends to be an enthusiastic adventurer, serious and decisive in execution.",
            "Barbara tends to communicate directly and make decisions independently.",
            "Merijn tends to be stoic about decisions, but is willing to take a risk if backed up by logic.",
            "Maran tends to be meticulous, detail-oriented, skeptical of change, and methodical.",
            "Carine is likely flexible with change and avoids getting stuck in a routine.",
            "Ellen often explores many new ideas and can easily handle frequent change.",
            "Nanno tends to be ambitious, fast-paced, critical, and efficient.",
            "Coline is likely to appreciate building long-term trust based on a track record of dependability in others.",
            "Véronique tends to be inventive and prefers long, thoughtful conversation.",
            "Wietze is primarily driven by logic: accurate, task-oriented, cautious, and logical decision-making.",
            "Rachel is often realistic and thoughtful, preferring to plan and ensure all of the details are accounted for.",
            "Fiona is likely to be thoughtful, genuine and friendly when collaborating with others.",
            "Rutger is likely fast-paced, goal-oriented, and direct, appreciating brevity and efficiency.",
            "Maret tends to be a thoughtful, cautious communicator who values consistency, stability, and loyalty.",
            "Tessa often prefers exploring many new things, and may energetically share ideas with others.",
            "Jessica often prefers exploring many new things, and may energetically share ideas with others.",
            "Louise tends to communicate directly and make decisions independently."]
long_text=["Berend is likely to thrive in the spotlight, since he is vocal, charismatic, and upbeat. He may eagerly pursue innovative solutions, often preferring to take swift action. Don't be surprised if he avoids tasks or projects that simply don't excite him.",
           "Ingrid may feel most comfortable taking charge of a situation. Her natural energy, drive for improvement, and desire for constant stimulation can help make her an influential leader.",
           "Barbara likely feels most comfortable as a leader and is likely to be assertive and to push her teammates towards a successful outcome. Barbara's abilities to be decisive and to work under pressure are likely to suit her well in stressful situations.",
           "Merijn tends to be an objective thinker who prioritizes accuracy and results. They will likely pay attention to small details and take a systematic approach to solving problems.",
           "Maran is likely an easy-going, cooperative supporter. Because of her calming presence, she has a gift for helping others feel comfortable in otherwise stressful circumstances.",
           "Carine tends to be a social butterfly, constantly engaging with the world around them. Their enthusiasm for new things likely excites and encourages others. They likely thrive as a guest at a dinner party.",
           "Ellen tends to be an open-minded, excitable idealist with a passion for finding new ways to solve problems. She is likely to enjoy meeting new people, brainstorming new ideas, and encouraging others.",
           "Nanno is likely to seek autonomy and pursue their own path. They may tend to crave efficiency and push for more effective, practical ways to help others improve. Don't be surprised if they offer suggestions to improve anything that appears unproductive.",
           "Coline is likely to be peaceful and cooperative when working closely with others. She may tend to enjoy checking in regularly with her friends and colleagues, often asking mindful, personal questions.",
           "Véronique is likely a confident visionary, who enjoys thinking on her feet and connecting with others. She may enjoy pursuing innovative ideas and exciting opportunities. Be sure to articulate the essence of an idea before you point out potential flaws in it.",
           "Wietze is most likely skeptical, reserved, and analytical. He tends to be serious and exacting in his work, often seeking to establish procedures that can help others improve, as well. Don't be surprised if he communicates with excessive detail.",
           "Rachel tends to be exacting, organized, and cautious in behavior. She is likely to support others, seek stable routines, and appreciate constructive feedback. Though she values her privacy, she enjoys spending time with the people she loves most.",
           "Fiona is likely to be expressive and encouraging around others. She tends to enjoy talking and collaborating frequently. Her enthusiastic and positive demeanor help inspire those around her.",
           "Rutger is probably comfortable with conflict and productive arguments. He will usually speak up and offer constructive criticism if it helps create efficiency. However, he may say something bluntly.",
           "Maret is likely an easy-going, cooperative supporter. Because of her calming presence, she has a gift for helping others feel comfortable in otherwise stressful circumstances.",
           "Tessa is most likely an optimist who strives to leave a positive impact on those around her. She may appreciate spending a lot of time talking with others. There's a chance she may occasionally be late to a meeting, but when she arrives, she will likely bring a lively, colorful story.",
           "Jessica tends to be an open-minded, excitable idealist with a passion for finding new ways to solve problems. She is likely to enjoy meeting new people, brainstorming new ideas, and encouraging others.",
           "Louise likely feels most comfortable as a leader and is likely to be assertive and to push her teammates towards a successful outcome. Louise's abilities to be decisive and to work under pressure are likely to suit her well in stressful situations."]

# %%
print(len(disc_char))
print(len(name))
print(len(short_text))
print(len(long_text))
# Out:
# 18
# 18
# 18
# 18

# %%
import pandas as pd
th=pd.DataFrame({
    'Name':name,
    'Disctype':disc_char,
    'Short about':short_text,
    "Long about":long_text
})

# %%
th.to_csv('Thierno.csv', index=False)
