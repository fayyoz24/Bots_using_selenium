# %%
from bs4 import BeautifulSoup
import time
from selenium.webdriver.chrome.options import Options
from selenium import webdriver
from selenium.webdriver.common.by import By
import pandas as pd
from selenium.webdriver.common.keys import Keys

df= pd.read_csv(f'../linkedin_data_Scraping/datas/partly_45878_reach_50.csv')

# for k in range(12,7000, 100):

all_skills=[]
all_abouts=[]
all_positions=[]
all_degrees=[]

for link in df.links[30:100]:
    print(link)
    options = Options()
    options.add_argument("user-data-dir=C:/Users/user/AppData/Local/Google/Chrome/User Data/Profile 3")
    driver = webdriver.Chrome(options=options)
    driver.get(link)
    time.sleep(10)
    src = driver.page_source
    soup = BeautifulSoup(src, 'lxml')

    # Find the element with the id "experience"
    positions=[]
    try:
        experience_element = soup.find('div', {'id': 'experience'})

        next_divs = experience_element.find_next_siblings('div')

        lis=next_divs[1].find_all("li", {"class":"artdeco-list__item pvs-list__item--line-separated pvs-list__item--one-column"})
        
        for li in lis:
            # experience=li.find_all("span", {"class":"t-14 t-normal t-black--light"})[0]
            # experiences.append(experience)
            position=li.find_all("span", {"aria-hidden":"true"})[0]
            positions.append(position.text)
            print(f"postion :{position.text}")
        # print(f"experience :{experience.text[:(len(experience.text)//2)].split(' · ')[1]}")
    except:
        print("not position")
        positions.append('nan')
    # Find the element with the id "education"
    degrees=[]
    try:
        education_element = soup.find('div', {'id': 'education'})

        next_divs = education_element.find_next_siblings('div')
        
        lis=next_divs[1].find_all("li", {"class":"artdeco-list__item pvs-list__item--line-separated pvs-list__item--one-column"})
        for li in lis:
            degree=li.find_all("span", {"aria-hidden":"true"})[1]
            degrees.append(degree.text)
            print(f"degree :{degree.text}")
    except:
        degrees.append('nan')

    # Find the element with the id "about"
    try:
        about_element = soup.find('div', {'id': 'about'})

        next_divs = about_element.find_next_siblings('div')
        print(next_divs[1].text.strip().split('…see more')[0])
        about=next_divs[1].text.strip().split('…see more')[0]
    except:
        about='nan'
        print("not about")
    driver.close()

    options = Options()
    options.add_argument("user-data-dir=C:/Users/user/AppData/Local/Google/Chrome/User Data/")
    driver = webdriver.Chrome(options=options)
    driver.get(str(link)+"/details/skills/")
    time.sleep(5)
    
    # Find the element with the id "skills"
    src = driver.page_source
    soup = BeautifulSoup(src, 'lxml')
    skills=[]    
    try:                           
        skills_element = soup.find_all('div', {'class': 'display-flex flex-row justify-space-between'})

        #artdeco-list__item pvs-list__item--line-separated pvs-list__item--one-column
        for li in skills_element:
        
            print(f"skills :{li.text.strip()[:(len(li.text.strip())//2)]}")
            skills.append(li.text.strip()[:(len(li.text.strip())//2)])
    except:
        print("Don't have skills")
        skills.append('nan')
    driver.close()
    
    all_skills.append(skills)
    all_abouts.append(about)
    all_degrees.append(degrees)
    all_positions.append(positions)
df_data=pd.DataFrame({
    "skills":all_skills,
    "positions":all_positions,
    "about":all_abouts,
    "degree":all_degrees,
    # "link":df.links[:100]
})
df_data.to_csv(f"./datas/data_{12-100}.csv")
# Out:
# https://www.linkedin.com/in/annisaklaila
# not position
# not about
# skills :Hydrology
# skills :Water Resources
# skills :Water
# skills :Water Management
# skills :Environmental Impact Assessment
# skills :Environmental Engineering
# skills :Coastal Engineering
# skills :Coastal Zone Management
# skills :ANSYS
# skills :Delft-3D
# skills :Flow-3D
# skills :Geographic Information Systems (GIS)
# skills :Hydrology
# skills :Water Resources
# skills :Water Management
# skills :Environmental Impact Assessment
# skills :Environmental Engineering
# skills :Coastal Engineering
# skills :Coastal Zone Management
# skills :ANSYS
# skills :Geographic Information Systems (GIS)
# skills :Water
# https://www.linkedin.com/in/christine-merie-fox-phd-70512733
# postion :UMC Utrecht
# postion :Coordinator for the History of Medicine and Biomedical Sciences MA course UMC/UU
# postion :Freelance Historical Researcher and Writer
# postion :Consultant Editor and Proofreader
# postion :Consultant Academic Tutor/Advisor
# degree :Doctor of Philosophy (Ph.D.), Medieval and Renaissance Studies
# degree :Master's degree, Medieval History
# degree :Bachelor of Arts and Humanities, History
# Experienced academic researcher and writer with a demonstrated history of working in and outside of higher education. Accomplished published author in academic journals, books, and popular history. Strong education professional with a Doctor of Philosophy (Ph.D.) in History from Royal Holloway, University of London. Through my experience as a research and writing advisor I have gained wide-ranging knowledge in a number of different fields from Dentistry, Pharma, Psychology, Housing, Cyber Security, and Finance.  For the last two years, I have been working as a research and writing advisor for the Graduate School of Life Science at University Medical Center Utrecht. In this role, I supervise the capstone projects for the Life Science and Society Profile, co-coordinate and teach the Logical Argumentation in Science course, coordinate and teach the interdisciplinary History of Medicine course, in addition to advising Biomedical Education PhD students with their theses and publications.Experienced academic researcher and writer with a demonstrated history of working in and outside of higher education. Accomplished published author in academic journals, books, and popular history. Strong education professional with a Doctor of Philosophy (Ph.D.) in History from Royal Holloway, University of London. Through my experience as a research and writing advisor I have gained wide-ranging knowledge in a number of different fields from Dentistry, Pharma, Psychology, Housing, Cyber Security, and Finance.  For the last two years, I have been working as a research and writing advisor for the Graduate School of Life Science at University Medical Center Utrecht. In this role, I supervise the capstone projects for the Life Science and Society Profile, co-coordinate and teach the Logical Argumentation in Science course, coordinate and teach the interdisciplinary History of Medicine course, in addition to advising Biomedical Education PhD students with their theses and publications.
#
#
#
# skills :Social Sciences
# skills :Analytical Skills
# skills :Research
# skills :Teaching
# skills :History
# skills :Literature
# skills :Report Writing
# skills :Publishing
# skills :Editing
# skills :Data Analysis
# skills :Policy Analysis
# skills :International Relations
# skills :Politics
# skills :Public Policy
# skills :Higher Education
# skills :Writing
# skills :Content Management
# skills :Content Strategy
# skills :Content Development
# skills :Social Media
# skills :Social Sciences
# skills :Research
# skills :Teaching
# skills :History
# skills :Literature
# skills :Report Writing
# skills :Publishing
# skills :Editing
# skills :Data Analysis
# skills :Policy Analysis
# skills :International Relations
# skills :Politics
# skills :Public Policy
# skills :Higher Education
# skills :Content Management
# skills :Content Strategy
# skills :Content Development
# skills :Social Media
# skills :Academic Advising
# skills :Quantitative Research
# skills :Analytical Skills
# skills :Writing
# skills :Creative Strategy
# skills :Analysing
# skills :Public Speaking
# skills :Problem Solving
# skills :Creative Problem Solving
# skills :Mentoring
# skills :Organization Skills
# skills :Communication
# skills :Problem solving
# skills :Leadership
# skills :English
# skills :CDD
# https://www.linkedin.com/in/fikretkarabulut
# postion :Design Architect
# postion :Design Architect
# postion :Intern
# postion :Intern
# postion :Intern
# degree :Master of Architecture (M.Arch.), Architectural Design
# degree :Bachelor of Architecture (B.Arch.), Architecture
# degree :Architecture
# I’m an architect with almost 12 years of experience gathered working in renowned architecture practices in the Netherlands, the United Kingdom, and Turkey. I have been currently working at TconcepT as a design architect for 6 years now and most recently I’ve been involved in masterplan projects, residential and retail-based large-scale projects located in Europe, Middle-East, and Russia.Committed, detail oriented and creative, I’m an architect interested in all aspects of master planning and architectural design. From the early strategic thinking to the technical design and the delivery of buildings on site, I have quite a diverse experience through different phases of a project, especially concept design, schematic design and also 3D visualization. When given ownership of a project, I swiftly outline a work plan, set key project deliverables, align my work to given budget and time, and move forward along with my team members to achieve the best results. Throughout my career, I’ve worked on a variety of international challenging large scale projects, with rewarding feedback from clients, superiors, and peers.In Istanbul, I was a part of over 10 large scale masterplan projects (varies from 100K to 420K sqm) and I coordinated the external engineering and consultant teams, focusing on the masterplan and façade design. I developed retail-based urban densification projects, providing new residential and office building on top of retail schemes to meet inner-city needed in Sheffield, London, Belfast, and Stockholm. I managed to produce more than 300 in-house renderings, meanwhile working on various mixed-use schemes not only in Den Haag, Rotterdam and, Amsterdam but in Dubai, Duqm, and Moscow.My vast understanding of diverse cultures in different countries, coupled with my strong capacity for design thinking and execution of it, internal and external communications, and project management, make me a great fit for your team.I’m an architect with almost 12 years of experience gathered working in renowned architecture practices in the Netherlands, the United Kingdom, and Turkey. I have been currently working at TconcepT as a design architect for 6 years now and most recently I’ve been involved in masterplan projects, residential and retail-based large-scale projects located in Europe, Middle-East, and Russia.
#
# Committed, detail oriented and creative, I’m an architect interested in all aspects of master planning and architectural design. From the early strategic thinking to the technical design and the delivery of buildings on site, I have quite a diverse experience through different phases of a project, especially concept design, schematic design and also 3D visualization.
#
# When given ownership of a project, I swiftly outline a work plan, set key project deliverables, align my work to given budget and time, and move forward along with my team members to achieve the best results. Throughout my career, I’ve worked on a variety of international challenging large scale projects, with rewarding feedback from clients, superiors, and peers.
#
# In Istanbul, I was a part of over 10 large scale masterplan projects (varies from 100K to 420K sqm) and I coordinated the external engineering and consultant teams, focusing on the masterplan and façade design. I developed retail-based urban densification projects, providing new residential and office building on top of retail schemes to meet inner-city needed in Sheffield, London, Belfast, and Stockholm. I managed to produce more than 300 in-house renderings, meanwhile working on various mixed-use schemes not only in Den Haag, Rotterdam and, Amsterdam but in Dubai, Duqm, and Moscow.
#
# My vast understanding of diverse cultures in different countries, coupled with my strong capacity for design thinking and execution of it, internal and external communications, and project management, make me a great fit for your team.
#
#
#
# skills :Architectural Design
# skills :Adobe Photoshop
# skills :SketchUp
# skills :Urban Design
# skills :Sketching
# skills :CAD
# skills :Interior Architecture
# skills :Rendering
# skills :Concept Design
# skills :Sustainable Design
# skills :Design Research
# skills :3D Visualization
# skills :AutoCAD
# skills :Adobe InDesign
# skills :Illustrator
# skills :Revit
# skills :Masterplanning
# skills :Architectural Details
# skills :Adobe Audition
# skills :Permit Drawings
# skills :Architectural Design
# skills :Urban Design
# skills :Sketching
# skills :CAD
# skills :Interior Architecture
# skills :Rendering
# skills :Concept Design
# skills :Sustainable Design
# skills :Design Research
# skills :3D Visualization
# skills :Masterplanning
# skills :Architectural Details
# skills :Permit Drawings
# skills :Lumion
# skills :Visualization
# skills :Adobe Photoshop
# skills :SketchUp
# skills :AutoCAD
# skills :Adobe InDesign
# skills :Illustrator
# skills :Revit
# skills :Adobe Audition
# skills :V-Ray
# skills :Adobe Indesign CC
# https://www.linkedin.com/in/anneliemonnier
# postion :Radboudumc
# postion :PhD Candidate
# postion :Postdoctoral Researcher
# postion :Postdoctoral Researcher
# postion :Internship
# degree :Doctor of Philosophy - PhD, Biomedical Sciences
# degree :Doctor of Philosophy - PhD, Biomedical Sciences
# degree :Master of Science (MS), Biomedische wetenschappen / Biomedical sciences
# not about
# https://www.linkedin.com/in/digamberrawat
# postion :Global CRM and Social Technology Product Manager
# postion :Tata Consultancy Services
# postion :Consultant
# postion :Project Lead - Marketing Automation(Marketo) Implementation
# postion :Product Owner | Lead Business Analyst
# degree :Engineer’s Degree, Computer Science
# I am a highly motivated and result oriented IT consultant with more than 15 years of experience in project management, stake holder management, requirement elicitation & analysis, data & process mapping, solution design, development, testing and maintenance of solutions built-in digital technologies like Salesforce Marketing Cloud, SAP-Hybris Commerce, Marketo - Marketing Automation, etc.- Working as the Delivery Manager and Salesforce Marketing Cloud Solution Architect with Upfield since June 2020- Has worked as Marketing Automation(Marketo) and Marketing Technology consultant with Staples-Europe and as SAP-Hybris consultant for Fabory in the previous roles- Proven track record in playing customer-facing roles like Business Analyst , Project Manager and Product Owner in different geographies - the US , UK, and Netherlands- In-depth knowledge of Marketing Technology(MarTech), eCommerce and Retail business domains- Extensive working experience in Agile/Scrum development methodologies- Certified Salesforce Marketing Cloud Specialist- Certified Salesforce Marketing Cloud Admin- Certified Salesforce Marketing Cloud Consultant- Sun Certified Programmer for Java (SCJP 1.4)I am a highly motivated and result oriented IT consultant with more than 15 years of experience in project management, stake holder management, requirement elicitation & analysis, data & process mapping, solution design, development, testing and maintenance of solutions built-in digital technologies like Salesforce Marketing Cloud, SAP-Hybris Commerce, Marketo - Marketing Automation, etc.
#
# - Working as the Delivery Manager and Salesforce Marketing Cloud Solution Architect with Upfield since June 2020
# - Has worked as Marketing Automation(Marketo) and Marketing Technology consultant with Staples-Europe and as SAP-Hybris consultant for Fabory in the previous roles
# - Proven track record in playing customer-facing roles like Business Analyst , Project Manager and Product Owner in different geographies - the US , UK, and Netherlands
# - In-depth knowledge of Marketing Technology(MarTech), eCommerce and Retail business domains
# - Extensive working experience in Agile/Scrum development methodologies
# - Certified Salesforce Marketing Cloud Specialist
# - Certified Salesforce Marketing Cloud Admin
# - Certified Salesforce Marketing Cloud Consultant
# - Sun Certified Programmer for Java (SCJP 1.4)
#
#
#
# skills :Requirements Analysis
# skills :E-commerce
# skills :Business-to-Business (B2B)
# skills :Systems Analysis
# skills :Project Management
# skills :Product Management
# skills :Business Analysis
# skills :Agile Methodologies
# skills :Project management
# skills :product management
# skills :Business Process Mapping
# skills :Requirements Gathering
# skills :Hybris
# skills :Marketo
# skills :Salesforce Marketing Cloud
# skills :Marketing Automation
# skills :Email Deliverability
# skills :Salesforce CRM
# skills :B2B Punchout
# skills :Requirements Analysis
# skills :E-commerce
# skills :Business-to-Business (B2B)
# skills :Systems Analysis
# skills :Project Management
# skills :Product Management
# skills :Business Analysis
# skills :Agile Methodologies
# skills :Project management
# skills :product management
# skills :Business Process Mapping
# skills :Requirements Gathering
# skills :Marketing Automation
# skills :Email Deliverability
# skills :Hybris
# skills :Marketo
# skills :Salesforce Marketing Cloud
# https://www.linkedin.com/in/sharonhaans
# postion :Content Coordinator
# postion :Entrepreneur at Gem Interior - E-commerce Specialist
# postion :MarCom Projectmanager & Marketer
# postion :Roadtrip / Worldtrip
# postion :Project- and Process manager
# degree :MSc, MSc Business Communication and Digital Media
# degree :Pre master, Communication and Information Sciences
# degree :Bachelor of Applied Science (B.A.Sc.), Pedagogic
# Passionate about the dynamic world of #content management, #events, #seo, #socialmedia, and #digitalmarketing, I'm driven by the passion for crafting impactful experiences and texts. With a knack for writing and organizing, I'm your go-to person for developing strategic campaigns, potent social media strategies, and efficient project execution. In 2021, my love for interior design led me on a new adventure, the start of the Gem Interior webshop. As the founder, I became fully immersed in shaping Gem Interior with exquisite gemstones and high-quality interior pieces. Ready to synergize ideas or explore opportunities? Feel free to connect with me at sharonhaans@gmail.com. Let's craft experiences together!Passionate about the dynamic world of #content management, #events, #seo, #socialmedia, and #digitalmarketing, I'm driven by the passion for crafting impactful experiences and texts. With a knack for writing and organizing, I'm your go-to person for developing strategic campaigns, potent social media strategies, and efficient project execution.
#
# In 2021, my love for interior design led me on a new adventure, the start of the Gem Interior webshop. As the founder, I became fully immersed in shaping Gem Interior with exquisite gemstones and high-quality interior pieces.
#
# Ready to synergize ideas or explore opportunities? Feel free to connect with me at sharonhaans@gmail.com. Let's craft experiences together!
# skills :SEO-copywriting
# skills :Campagnestrategieën
# skills :Bedrijfsproces
# skills :Business planning
# skills :Duurzaamheid
# skills :Detailhandel
# skills :Overheid
# skills :Duurzame ontwikkeling
# skills :Omnichannel-marketing
# skills :Online retail
# skills :Content-strategie
# skills :Partnermanagement
# skills :E-commerce
# skills :E-commerce SEO
# skills :Contentmanagement
# skills :Contentmarketing
# skills :Marketingstrategie
# skills :Social Media
# skills :Strategic Communications
# skills :Management Consulting
# skills :SEO-copywriting
# skills :Campagnestrategieën
# skills :Bedrijfsproces
# skills :Business planning
# skills :Duurzaamheid
# skills :Detailhandel
# skills :Overheid
# skills :Duurzame ontwikkeling
# skills :Omnichannel-marketing
# skills :Online retail
# skills :Content-strategie
# skills :Partnermanagement
# skills :E-commerce
# skills :E-commerce SEO
# skills :Contentmanagement
# skills :Contentmarketing
# skills :Marketingstrategie
# skills :Social Media
# skills :Strategic Communications
# skills :Management Consulting
# https://www.linkedin.com/in/siwar-douss
# not position
# not about
# https://www.linkedin.com/in/mieke-oldeman-8886b71b4
# not position
# not about
# https://www.linkedin.com/in/annewolfrat
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# d:\Temma\Bots_using_selenium\crystal_linkedin\profile3.ipynb Cell 1 line 2
#      <a href='vscode-notebook-cell:/d%3A/Temma/Bots_using_selenium/crystal_linkedin/profile3.ipynb#W0sZmlsZQ%3D%3D?line=22'>23</a> driver.get(link)
#      <a href='vscode-notebook-cell:/d%3A/Temma/Bots_using_selenium/crystal_linkedin/profile3.ipynb#W0sZmlsZQ%3D%3D?line=23'>24</a> time.sleep(10)
# ---> <a href='vscode-notebook-cell:/d%3A/Temma/Bots_using_selenium/crystal_linkedin/profile3.ipynb#W0sZmlsZQ%3D%3D?line=24'>25</a> src = driver.page_source
#      <a href='vscode-notebook-cell:/d%3A/Temma/Bots_using_selenium/crystal_linkedin/profile3.ipynb#W0sZmlsZQ%3D%3D?line=25'>26</a> soup = BeautifulSoup(src, 'lxml')
#      <a href='vscode-notebook-cell:/d%3A/Temma/Bots_using_selenium/crystal_linkedin/profile3.ipynb#W0sZmlsZQ%3D%3D?line=27'>28</a> # Find the element with the id "experience"
#
# File d:\Temma\Bots_using_selenium\.venv\Lib\site-packages\selenium\webdriver\remote\webdriver.py:445, in WebDriver.page_source(self)
#     436 @property
#     437 def page_source(self) -> str:
#     438     """Gets the source of the current page.
#     439
#     440     :Usage:
#    (...)
#     443             driver.page_source
#     444     """
# --> 445     return self.execute(Command.GET_PAGE_SOURCE)["value"]
#
# File d:\Temma\Bots_using_selenium\.venv\Lib\site-packages\selenium\webdriver\remote\webdriver.py:344, in WebDriver.execute(self, driver_command, params)
#     342 response = self.command_executor.execute(driver_command, params)
#     343 if response:
# --> 344     self.error_handler.check_response(response)
#     345     response["value"] = self._unwrap_value(response.get("value", None))
#     346     return response
#
# File d:\Temma\Bots_using_selenium\.venv\Lib\site-packages\selenium\webdriver\remote\errorhandler.py:229, in ErrorHandler.check_response(self, response)
#     227         alert_text = value["alert"].get("text")
#     228     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229 raise exception_class(message, screen, stacktrace)
#
# NoSuchWindowException: Message: no such window: target window already closed
# from unknown error: web view not found
#   (Session info: chrome=117.0.5938.89)
# Stacktrace:
# 	GetHandleVerifier [0x00007FF6E1467892+54818]
# 	(No symbol) [0x00007FF6E13D6AC2]
# 	(No symbol) [0x00007FF6E128DA3B]
# 	(No symbol) [0x00007FF6E126DEE8]
# 	(No symbol) [0x00007FF6E12F3237]
# 	(No symbol) [0x00007FF6E1306C6F]
# 	(No symbol) [0x00007FF6E12EE883]
# 	(No symbol) [0x00007FF6E12C3691]
# 	(No symbol) [0x00007FF6E12C48D4]
# 	GetHandleVerifier [0x00007FF6E17CB992+3610402]
# 	GetHandleVerifier [0x00007FF6E1821860+3962352]
# 	GetHandleVerifier [0x00007FF6E1819D4F+3930847]
# 	GetHandleVerifier [0x00007FF6E1503646+693206]
# 	(No symbol) [0x00007FF6E13E1628]
# 	(No symbol) [0x00007FF6E13DD934]
# 	(No symbol) [0x00007FF6E13DDA62]
# 	(No symbol) [0x00007FF6E13CE113]
# 	BaseThreadInitThunk [0x00007FFECA1D7034+20]
# 	RtlUserThreadStart [0x00007FFECA9026A1+33]

# %%
df_data.to_csv("./datas/12-30.csv")

# %%
all_abouts[-1]
# Out:
# 'Experienced and proactive researcher with 8+ years of demonstrated history of working in the wind energy field. Strong research professional with a PhD focused in advanced wind turbine condition monitoring from Durham University. Interested in the operation and maintenance aspects of wind energy, both onshore and offshore, with regard to reducing the cost of energy from wind by adopting reliable and cost-effective condition monitoring approaches. This is achieved by combining experimental testing, numerical simulation results from algorithm implementation, and experimental and industrial data analysis.Experienced and proactive researcher with 8+ years of demonstrated history of working in the wind energy field. Strong research professional with a PhD focused in advanced wind turbine condition monitoring from Durham University. Interested in the operation and maintenance aspects of wind energy, both onshore and offshore, with regard to reducing the cost of energy from wind by adopting reliable and cost-effective condition monitoring approaches. This is achieved by combining experimental testing, numerical simulation results from algorithm implementation, and experimental and industrial data analysis.\n\n \n              '

# %%
df_data.to_csv("./datas/0-12.csv")

# %%
all_abouts
# Out:
# ['nan',
#  'Experienced academic researcher and writer with a demonstrated history of working in and outside of higher education. Accomplished published author in academic journals, books, and popular history. Strong education professional with a Doctor of Philosophy (Ph.D.) in History from Royal Holloway, University of London. Through my experience as a research and writing advisor I have gained wide-ranging knowledge in a number of different fields from Dentistry, Pharma, Psychology, Housing, Cyber Security, and Finance.  For the last two years, I have been working as a research and writing advisor for the Graduate School of Life Science at University Medical Center Utrecht. In this role, I supervise the capstone projects for the Life Science and Society Profile, co-coordinate and teach the Logical Argumentation in Science course, coordinate and teach the interdisciplinary History of Medicine course, in addition to advising Biomedical Education PhD students with their theses and publications.Experienced academic researcher and writer with a demonstrated history of working in and outside of higher education. Accomplished published author in academic journals, books, and popular history. Strong education professional with a Doctor of Philosophy (Ph.D.) in History from Royal Holloway, University of London. Through my experience as a research and writing advisor I have gained wide-ranging knowledge in a number of different fields from Dentistry, Pharma, Psychology, Housing, Cyber Security, and Finance.  For the last two years, I have been working as a research and writing advisor for the Graduate School of Life Science at University Medical Center Utrecht. In this role, I supervise the capstone projects for the Life Science and Society Profile, co-coordinate and teach the Logical Argumentation in Science course, coordinate and teach the interdisciplinary History of Medicine course, in addition to advising Biomedical Education PhD students with their theses and publications.\n\n \n              ',
#  'I’m an architect with almost 12 years of experience gathered working in renowned architecture practices in the Netherlands, the United Kingdom, and Turkey. I have been currently working at TconcepT as a design architect for 6 years now and most recently I’ve been involved in masterplan projects, residential and retail-based large-scale projects located in Europe, Middle-East, and Russia.Committed, detail oriented and creative, I’m an architect interested in all aspects of master planning and architectural design. From the early strategic thinking to the technical design and the delivery of buildings on site, I have quite a diverse experience through different phases of a project, especially concept design, schematic design and also 3D visualization. When given ownership of a project, I swiftly outline a work plan, set key project deliverables, align my work to given budget and time, and move forward along with my team members to achieve the best results. Throughout my career, I’ve worked on a variety of international challenging large scale projects, with rewarding feedback from clients, superiors, and peers.In Istanbul, I was a part of over 10 large scale masterplan projects (varies from 100K to 420K sqm) and I coordinated the external engineering and consultant teams, focusing on the masterplan and façade design. I developed retail-based urban densification projects, providing new residential and office building on top of retail schemes to meet inner-city needed in Sheffield, London, Belfast, and Stockholm. I managed to produce more than 300 in-house renderings, meanwhile working on various mixed-use schemes not only in Den Haag, Rotterdam and, Amsterdam but in Dubai, Duqm, and Moscow.My vast understanding of diverse cultures in different countries, coupled with my strong capacity for design thinking and execution of it, internal and external communications, and project management, make me a great fit for your team.I’m an architect with almost 12 years of experience gathered working in renowned architecture practices in the Netherlands, the United Kingdom, and Turkey. I have been currently working at TconcepT as a design architect for 6 years now and most recently I’ve been involved in masterplan projects, residential and retail-based large-scale projects located in Europe, Middle-East, and Russia.\n\nCommitted, detail oriented and creative, I’m an architect interested in all aspects of master planning and architectural design. From the early strategic thinking to the technical design and the delivery of buildings on site, I have quite a diverse experience through different phases of a project, especially concept design, schematic design and also 3D visualization. \n\nWhen given ownership of a project, I swiftly outline a work plan, set key project deliverables, align my work to given budget and time, and move forward along with my team members to achieve the best results. Throughout my career, I’ve worked on a variety of international challenging large scale projects, with rewarding feedback from clients, superiors, and peers.\n\nIn Istanbul, I was a part of over 10 large scale masterplan projects (varies from 100K to 420K sqm) and I coordinated the external engineering and consultant teams, focusing on the masterplan and façade design. I developed retail-based urban densification projects, providing new residential and office building on top of retail schemes to meet inner-city needed in Sheffield, London, Belfast, and Stockholm. I managed to produce more than 300 in-house renderings, meanwhile working on various mixed-use schemes not only in Den Haag, Rotterdam and, Amsterdam but in Dubai, Duqm, and Moscow.\n\nMy vast understanding of diverse cultures in different countries, coupled with my strong capacity for design thinking and execution of it, internal and external communications, and project management, make me a great fit for your team.\n\n \n              ',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan']

# %%
"skills":all_skills,
"positions":all_positions,
"about":all_abouts,
"degree":all_degrees,
"link":df.links[:100]

# %%
all_positions[-1]
# Out:
# [<span aria-hidden="true"><!-- -->Projectcoördinator<!-- --></span>,
#  <span aria-hidden="true"><!-- -->A.Hak<!-- --></span>,
#  <span aria-hidden="true"><!-- -->Document Control Manager<!-- --></span>,
#  <span aria-hidden="true"><!-- -->Project Coördinator<!-- --></span>,
#  <span aria-hidden="true"><!-- -->Fun Industries<!-- --></span>]

# %%
len(all_degrees)
# Out:
# 11

# %%
experience
# Out:
# <span class="t-14 t-normal t-black--light">
# <span aria-hidden="true"><!-- -->Amsterdam, North Holland, Netherlands<!-- --></span><span class="visually-hidden"><!-- -->Amsterdam, North Holland, Netherlands<!-- --></span>
# </span>
